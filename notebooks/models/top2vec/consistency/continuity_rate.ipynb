# %% [markdown]
# # Top2Vec: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/top2vec/temporal")
RESULT_DIR = Path("../../../../results/top2vec/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/top2vec/temporal
# Saving to: ../../../../results/top2vec/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def build_word_matrix(topic_ids, topic_words_dict, year, vocab_index):
    matrix = np.zeros((len(topic_ids), len(vocab_index)))
    for i, tid in enumerate(topic_ids):
        words = topic_words_dict.get((year, tid), [])
        for w in words:
            if w in vocab_index:
                matrix[i, vocab_index[w]] = 1.0
    return matrix

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_words = set()
    for words in topic_words.values():
        all_words.update(words)
    vocab_index = {w: i for i, w in enumerate(sorted(all_words))}

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        mat_t = build_word_matrix(topics_t, topic_words, t, vocab_index)
        mat_t1 = build_word_matrix(topics_t1, topic_words, t_next, vocab_index)
        sim_matrix = cosine_similarity(mat_t, mat_t1)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=57 (54%)  Merge=0 (0%)  Disappear=49 (46%)  New=51
#   2001→2002: Stable=66 (61%)  Merge=0 (0%)  Disappear=42 (39%)  New=54
#   2002→2003: Stable=70 (58%)  Merge=0 (0%)  Disappear=50 (42%)  New=57
#   2003→2004: Stable=75 (59%)  Merge=0 (0%)  Disappear=52 (41%)  New=67
#   2004→2005: Stable=83 (58%)  Merge=2 (1%)  Disappear=57 (40%)  New=59
#   2005→2006: Stable=82 (57%)  Merge=0 (0%)  Disappear=61 (43%)  New=59
#   2006→2007: Stable=79 (56%)  Merge=0 (0%)  Disappear=62 (44%)  New=69
#   2007→2008: Stable=88 (59%)  Merge=0 (0%)  Disappear=60 (41%)  New=52
#   2008→2009: Stable=90 (64%)  Merge=0 (0%)  Disappear=50 (36%)  New=62
#   2009→2010: Stable=112 (74%)  Merge=0 (0%)  Disappear=40 (26%)  New=57
#   2010→2011: Stable=115 (68%)  Merge=0 (0%)  Disappear=54 (32%)  New=61
#   2011→2012: Stable=136 (77%)  Merge=0 (0%)  Disappear=40 (23%)  New=64
#   2012→2013: Stable=165 (82%)  Merge=0 (0%)  Disappear=35 (18%)  New=48
#   2013→2014: Stable=177 (83%)  Merge=2 (1%)  Disappear=34 (16%)  New=37
#   2014→2015: Stable=187 (87%)  Merge=0 (0%)  Disappear=28 (13%)  New=50
#   2015→2016: Stable=220 (93%)  Merge=0 (0%)  Disappear=17 (7%)  New=23
#   2016→2017: Stable=237 (98%)  Merge=0 (0%)  Disappear=6 (2%)  New=12
#   2017→2018: Stable=248 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=3
#   2018→2019: Stable=249 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=4
#   2019→2020: Stable=253 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=251 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=1
#   2021→2022: Stable=250 (99%)  Merge=2 (1%)  Disappear=0 (0%)  New=2
#   2022→2023: Stable=253 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=253 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=253 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=79.5%  Merge=0.1%  Disappear=20.4%  New=892
#   Saved: ../../../../results/top2vec/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (Top2Vec)
# ======================================================================
#   2000→2001: Stable=104 (67%)  Merge=0 (0%)  Disappear=51 (33%)  New=59
#   2001→2002: Stable=106 (65%)  Merge=0 (0%)  Disappear=57 (35%)  New=58
#   2002→2003: Stable=125 (76%)  Merge=0 (0%)  Disappear=39 (24%)  New=48
#   2003→2004: Stable=139 (80%)  Merge=0 (0%)  Disappear=34 (20%)  New=44
#   2004→2005: Stable=148 (81%)  Merge=0 (0%)  Disappear=35 (19%)  New=41
#   2005→2006: Stable=159 (84%)  Merge=6 (3%)  Disappear=24 (13%)  New=35
#   2006→2007: Stable=178 (90%)  Merge=0 (0%)  Disappear=19 (10%)  New=24
#   2007→2008: Stable=180 (89%)  Merge=0 (0%)  Disappear=22 (11%)  New=24
#   2008→2009: Stable=187 (92%)  Merge=0 (0%)  Disappear=17 (8%)  New=22
#   2009→2010: Stable=198 (95%)  Merge=0 (0%)  Disappear=11 (5%)  New=11
#   2010→2011: Stable=197 (94%)  Merge=2 (1%)  Disappear=10 (5%)  New=12
#   2011→2012: Stable=203 (97%)  Merge=0 (0%)  Disappear=7 (3%)  New=8
#   2012→2013: Stable=207 (98%)  Merge=0 (0%)  Disappear=4 (2%)  New=3
#   2013→2014: Stable=209 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=2
#   2014→2015: Stable=209 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=2
#   2015→2016: Stable=209 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=1
#   2016→2017: Stable=210 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2017→2018: Stable=209 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=2
#   2018→2019: Stable=211 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=211 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=211 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=211 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=211 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=211 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=211 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=92.2%  Merge=0.2%  Disappear=7.6%  New=397
#   Saved: ../../../../results/top2vec/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=103 (73%)  Merge=0 (0%)  Disappear=39 (27%)  New=52
#   2001→2002: Stable=109 (70%)  Merge=0 (0%)  Disappear=46 (30%)  New=49
#   2002→2003: Stable=108 (68%)  Merge=0 (0%)  Disappear=50 (32%)  New=55
#   2003→2004: Stable=115 (71%)  Merge=0 (0%)  Disappear=48 (29%)  New=57
#   2004→2005: Stable=127 (74%)  Merge=0 (0%)  Disappear=45 (26%)  New=56
#   2005→2006: Stable=146 (80%)  Merge=0 (0%)  Disappear=37 (20%)  New=38
#   2006→2007: Stable=154 (84%)  Merge=0 (0%)  Disappear=30 (16%)  New=37
#   2007→2008: Stable=160 (84%)  Merge=2 (1%)  Disappear=29 (15%)  New=27
#   2008→2009: Stable=164 (87%)  Merge=0 (0%)  Disappear=24 (13%)  New=32
#   2009→2010: Stable=180 (92%)  Merge=2 (1%)  Disappear=14 (7%)  New=23
#   2010→2011: Stable=192 (94%)  Merge=0 (0%)  Disappear=12 (6%)  New=8
#   2011→2012: Stable=188 (94%)  Merge=2 (1%)  Disappear=10 (5%)  New=12
#   2012→2013: Stable=194 (97%)  Merge=0 (0%)  Disappear=7 (3%)  New=7
#   2013→2014: Stable=195 (97%)  Merge=0 (0%)  Disappear=6 (3%)  New=7
#   2014→2015: Stable=196 (97%)  Merge=0 (0%)  Disappear=6 (3%)  New=7
#   2015→2016: Stable=198 (98%)  Merge=0 (0%)  Disappear=5 (2%)  New=5
#   2016→2017: Stable=201 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=3
#   2017→2018: Stable=202 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=1
#   2018→2019: Stable=203 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2019→2020: Stable=203 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=1
#   2020→2021: Stable=204 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=204 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=204 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=204 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=204 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=90.2%  Merge=0.1%  Disappear=9.7%  New=478
#   Saved: ../../../../results/top2vec/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 742 events
#   Per year:
#     2000: 49 topics
#     2001: 42 topics
#     2002: 50 topics
#     2003: 52 topics
#     2004: 57 topics
#     2005: 61 topics
#     2006: 62 topics
#     2007: 60 topics
#     2008: 50 topics
#     2009: 40 topics
#     2010: 54 topics
#     2011: 40 topics
#     2012: 35 topics
#     2013: 34 topics
#     2014: 28 topics
#     2015: 17 topics
#     2016: 6 topics
#     2017: 1 topics
#     2018: 2 topics
#     2020: 2 topics
#
#   Permanently gone: 0
#
#   🔗 MERGE GROUPS: 3 events
#   Top 10 merges (most sources):
#     T130 @ 2005 ← [130, 135] (sims=[0.8, 0.5]) | query, queries, data, relational, databa
#     T  9 @ 2014 ← [9, 111] (sims=[0.8, 0.5]) | object, detection, segmentation, image,
#     T 73 @ 2022 ← [73, 100] (sims=[0.8, 0.6]) | transformer, attention, transformers, mo
#
#   🆕 NEW TOPICS: 892 events
#   Per year:
#     2001: 51 new topics
#     2002: 54 new topics
#     2003: 57 new topics
#     2004: 67 new topics
#     2005: 59 new topics
#     2006: 59 new topics
#     2007: 69 new topics
#     2008: 52 new topics
#     2009: 62 new topics
#     2010: 57 new topics
#     2011: 61 new topics
#     2012: 64 new topics
#     2013: 48 new topics
#     2014: 37 new topics
#     2015: 50 new topics
#     2016: 23 new topics
#     2017: 12 new topics
#     2018: 3 new topics
#     2019: 4 new topics
#     2021: 1 new topics
#     2022: 2 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  1 | 100% stable (25S 0M 0D)
#     T  4 | 100% stable (25S 0M 0D)
#     T  3 | 100% stable (25S 0M 0D)
#     T 10 | 100% stable (25S 0M 0D)
#     T  7 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T252 | 60% stable (12S 0M 8D)
#     T 75 | 56% stable (10S 0M 8D)
#     T191 | 47% stable (8S 0M 9D)
#     T149 | 46% stable (11S 0M 13D)
#     T 26 | 41% stable (9S 0M 13D)
#
#
# ======================================================================
# Analysis Review: MATH (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 337 events
#   Per year:
#     2000: 51 topics
#     2001: 57 topics
#     2002: 39 topics
#     2003: 34 topics
#     2004: 35 topics
#     2005: 24 topics
#     2006: 19 topics
#     2007: 22 topics
#     2008: 17 topics
#     2009: 11 topics
#     2010: 10 topics
#     2011: 7 topics
#     2012: 4 topics
#     2013: 1 topics
#     2014: 2 topics
#     2015: 2 topics
#     2017: 2 topics
#
#   Permanently gone: 0
#
#   🔗 MERGE GROUPS: 4 events
#   Top 10 merges (most sources):
#     T 23 @ 2006 ← [23, 98] (sims=[0.9, 0.5]) | stochastic, noise, equations, equation,
#     T 27 @ 2006 ← [27, 200] (sims=[0.9, 0.5]) | dinger, schr, operators, operator, spect
#     T 40 @ 2006 ← [40, 67] (sims=[0.9, 0.5]) | schr, dinger, equation, nonlinear, wave,
#     T100 @ 2011 ← [100, 162] (sims=[0.9, 0.7]) | graphs, graph, transitive, cayley, autom
#
#   🆕 NEW TOPICS: 397 events
#   Per year:
#     2001: 59 new topics
#     2002: 58 new topics
#     2003: 48 new topics
#     2004: 44 new topics
#     2005: 41 new topics
#     2006: 35 new topics
#     2007: 24 new topics
#     2008: 24 new topics
#     2009: 22 new topics
#     2010: 11 new topics
#     2011: 12 new topics
#     2012: 8 new topics
#     2013: 3 new topics
#     2014: 2 new topics
#     2015: 2 new topics
#     2016: 1 new topics
#     2017: 1 new topics
#     2018: 2 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  1 | 100% stable (25S 0M 0D)
#     T  2 | 100% stable (25S 0M 0D)
#     T  3 | 100% stable (25S 0M 0D)
#     T 17 | 100% stable (25S 0M 0D)
#     T  4 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T133 | 76% stable (19S 0M 6D)
#     T 92 | 72% stable (18S 0M 7D)
#     T188 | 72% stable (18S 0M 7D)
#     T199 | 65% stable (15S 0M 8D)
#     T167 | 64% stable (16S 0M 9D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 413 events
#   Per year:
#     2000: 39 topics
#     2001: 46 topics
#     2002: 50 topics
#     2003: 48 topics
#     2004: 45 topics
#     2005: 37 topics
#     2006: 30 topics
#     2007: 29 topics
#     2008: 24 topics
#     2009: 14 topics
#     2010: 12 topics
#     2011: 10 topics
#     2012: 7 topics
#     2013: 6 topics
#     2014: 6 topics
#     2015: 5 topics
#     2016: 2 topics
#     2017: 2 topics
#     2019: 1 topics
#
#   Permanently gone: 0
#
#   🔗 MERGE GROUPS: 3 events
#   Top 10 merges (most sources):
#     T 34 @ 2008 ← [34, 177] (sims=[0.9, 0.5]) | students, student, education, physics, l
#     T 34 @ 2010 ← [34, 177] (sims=[0.8, 0.6]) | students, physics, student, learning, ed
#     T  3 @ 2012 ← [3, 144] (sims=[1.0, 0.5]) | plasmonic, plasmon, dielectric, optical,
#
#   🆕 NEW TOPICS: 478 events
#   Per year:
#     2001: 52 new topics
#     2002: 49 new topics
#     2003: 55 new topics
#     2004: 57 new topics
#     2005: 56 new topics
#     2006: 38 new topics
#     2007: 37 new topics
#     2008: 27 new topics
#     2009: 32 new topics
#     2010: 23 new topics
#     2011: 8 new topics
#     2012: 12 new topics
#     2013: 7 new topics
#     2014: 7 new topics
#     2015: 7 new topics
#     2016: 5 new topics
#     2017: 3 new topics
#     2018: 1 new topics
#     2019: 1 new topics
#     2020: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0M 0D)
#     T  2 | 100% stable (25S 0M 0D)
#     T  8 | 100% stable (25S 0M 0D)
#     T  5 | 100% stable (25S 0M 0D)
#     T 10 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T  7 | 64% stable (14S 0M 8D)
#     T139 | 62% stable (13S 0M 8D)
#     T161 | 60% stable (12S 0M 8D)
#     T156 | 59% stable (13S 0M 9D)
#     T194 | 44% stable (7S 0M 9D)
