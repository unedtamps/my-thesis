# %% [markdown]
# # Top2Vec: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/top2vec/temporal")
RESULT_DIR = Path("../../../../results/top2vec/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/top2vec/temporal
# Saving to: ../../../../results/top2vec/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for i, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for j, tid_t1 in enumerate(topics_t1):
                words_t1 = topic_words.get((t_next, tid_t1), [])
                sim_matrix[i, j] = rbo(words_t, words_t1, p=0.9)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=56 (45%)  Merge=0 (0%)  Disappear=69 (55%)  New=67
#   2001→2002: Stable=42 (34%)  Merge=0 (0%)  Disappear=81 (66%)  New=93
#   2002→2003: Stable=42 (31%)  Merge=0 (0%)  Disappear=93 (69%)  New=103
#   2003→2004: Stable=57 (39%)  Merge=0 (0%)  Disappear=88 (61%)  New=109
#   2004→2005: Stable=54 (33%)  Merge=0 (0%)  Disappear=112 (67%)  New=110
#   2005→2006: Stable=50 (30%)  Merge=0 (0%)  Disappear=114 (70%)  New=112
#   2006→2007: Stable=50 (31%)  Merge=0 (0%)  Disappear=112 (69%)  New=113
#   2007→2008: Stable=61 (37%)  Merge=0 (0%)  Disappear=102 (63%)  New=106
#   2008→2009: Stable=60 (36%)  Merge=0 (0%)  Disappear=107 (64%)  New=114
#   2009→2010: Stable=82 (47%)  Merge=2 (1%)  Disappear=90 (52%)  New=113
#   2010→2011: Stable=87 (44%)  Merge=0 (0%)  Disappear=109 (56%)  New=115
#   2011→2012: Stable=113 (56%)  Merge=0 (0%)  Disappear=89 (44%)  New=125
#   2012→2013: Stable=129 (54%)  Merge=0 (0%)  Disappear=109 (46%)  New=116
#   2013→2014: Stable=159 (65%)  Merge=0 (0%)  Disappear=86 (35%)  New=93
#   2014→2015: Stable=176 (70%)  Merge=0 (0%)  Disappear=76 (30%)  New=104
#   2015→2016: Stable=213 (76%)  Merge=0 (0%)  Disappear=67 (24%)  New=79
#   2016→2017: Stable=239 (82%)  Merge=0 (0%)  Disappear=53 (18%)  New=61
#   2017→2018: Stable=263 (88%)  Merge=2 (1%)  Disappear=35 (12%)  New=39
#   2018→2019: Stable=271 (89%)  Merge=4 (1%)  Disappear=28 (9%)  New=31
#   2019→2020: Stable=290 (95%)  Merge=0 (0%)  Disappear=14 (5%)  New=15
#   2020→2021: Stable=294 (96%)  Merge=0 (0%)  Disappear=11 (4%)  New=10
#   2021→2022: Stable=293 (96%)  Merge=2 (1%)  Disappear=9 (3%)  New=11
#   2022→2023: Stable=300 (98%)  Merge=0 (0%)  Disappear=5 (2%)  New=5
#   2023→2024: Stable=302 (99%)  Merge=0 (0%)  Disappear=3 (1%)  New=3
#   2024→2025: Stable=304 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=1
#
#   Overall: Stable=62.9%  Merge=0.1%  Disappear=36.9%  New=1848
#   Saved: ../../../../results/top2vec/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (Top2Vec)
# ======================================================================
#   2000→2001: Stable=79 (54%)  Merge=0 (0%)  Disappear=68 (46%)  New=76
#   2001→2002: Stable=79 (51%)  Merge=0 (0%)  Disappear=76 (49%)  New=79
#   2002→2003: Stable=89 (56%)  Merge=0 (0%)  Disappear=69 (44%)  New=75
#   2003→2004: Stable=101 (62%)  Merge=0 (0%)  Disappear=63 (38%)  New=70
#   2004→2005: Stable=101 (59%)  Merge=0 (0%)  Disappear=70 (41%)  New=79
#   2005→2006: Stable=129 (72%)  Merge=0 (0%)  Disappear=51 (28%)  New=59
#   2006→2007: Stable=130 (69%)  Merge=0 (0%)  Disappear=58 (31%)  New=60
#   2007→2008: Stable=135 (71%)  Merge=0 (0%)  Disappear=55 (29%)  New=55
#   2008→2009: Stable=141 (74%)  Merge=0 (0%)  Disappear=49 (26%)  New=52
#   2009→2010: Stable=144 (75%)  Merge=0 (0%)  Disappear=49 (25%)  New=49
#   2010→2011: Stable=150 (78%)  Merge=0 (0%)  Disappear=43 (22%)  New=45
#   2011→2012: Stable=170 (87%)  Merge=0 (0%)  Disappear=25 (13%)  New=26
#   2012→2013: Stable=171 (87%)  Merge=2 (1%)  Disappear=23 (12%)  New=24
#   2013→2014: Stable=183 (93%)  Merge=0 (0%)  Disappear=13 (7%)  New=13
#   2014→2015: Stable=186 (95%)  Merge=0 (0%)  Disappear=10 (5%)  New=10
#   2015→2016: Stable=182 (93%)  Merge=0 (0%)  Disappear=14 (7%)  New=14
#   2016→2017: Stable=185 (94%)  Merge=0 (0%)  Disappear=11 (6%)  New=11
#   2017→2018: Stable=188 (96%)  Merge=0 (0%)  Disappear=8 (4%)  New=8
#   2018→2019: Stable=193 (98%)  Merge=0 (0%)  Disappear=3 (2%)  New=3
#   2019→2020: Stable=192 (98%)  Merge=0 (0%)  Disappear=4 (2%)  New=4
#   2020→2021: Stable=192 (98%)  Merge=0 (0%)  Disappear=4 (2%)  New=4
#   2021→2022: Stable=190 (97%)  Merge=0 (0%)  Disappear=6 (3%)  New=6
#   2022→2023: Stable=193 (98%)  Merge=0 (0%)  Disappear=3 (2%)  New=3
#   2023→2024: Stable=193 (98%)  Merge=0 (0%)  Disappear=3 (2%)  New=3
#   2024→2025: Stable=192 (98%)  Merge=0 (0%)  Disappear=4 (2%)  New=4
#
#   Overall: Stable=82.1%  Merge=0.0%  Disappear=17.9%  New=832
#   Saved: ../../../../results/top2vec/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=81 (55%)  Merge=0 (0%)  Disappear=67 (45%)  New=77
#   2001→2002: Stable=82 (52%)  Merge=0 (0%)  Disappear=76 (48%)  New=77
#   2002→2003: Stable=64 (40%)  Merge=0 (0%)  Disappear=95 (60%)  New=104
#   2003→2004: Stable=84 (50%)  Merge=0 (0%)  Disappear=84 (50%)  New=86
#   2004→2005: Stable=96 (56%)  Merge=0 (0%)  Disappear=74 (44%)  New=85
#   2005→2006: Stable=104 (57%)  Merge=0 (0%)  Disappear=77 (43%)  New=84
#   2006→2007: Stable=115 (61%)  Merge=2 (1%)  Disappear=71 (38%)  New=79
#   2007→2008: Stable=120 (62%)  Merge=0 (0%)  Disappear=75 (38%)  New=73
#   2008→2009: Stable=120 (62%)  Merge=0 (0%)  Disappear=73 (38%)  New=78
#   2009→2010: Stable=142 (72%)  Merge=0 (0%)  Disappear=56 (28%)  New=63
#   2010→2011: Stable=154 (75%)  Merge=0 (0%)  Disappear=51 (25%)  New=50
#   2011→2012: Stable=165 (81%)  Merge=0 (0%)  Disappear=39 (19%)  New=40
#   2012→2013: Stable=165 (80%)  Merge=0 (0%)  Disappear=40 (20%)  New=40
#   2013→2014: Stable=160 (78%)  Merge=0 (0%)  Disappear=45 (22%)  New=46
#   2014→2015: Stable=171 (83%)  Merge=0 (0%)  Disappear=35 (17%)  New=35
#   2015→2016: Stable=176 (85%)  Merge=0 (0%)  Disappear=30 (15%)  New=30
#   2016→2017: Stable=189 (92%)  Merge=0 (0%)  Disappear=17 (8%)  New=18
#   2017→2018: Stable=194 (94%)  Merge=0 (0%)  Disappear=13 (6%)  New=13
#   2018→2019: Stable=196 (95%)  Merge=0 (0%)  Disappear=11 (5%)  New=11
#   2019→2020: Stable=202 (98%)  Merge=0 (0%)  Disappear=5 (2%)  New=5
#   2020→2021: Stable=201 (97%)  Merge=0 (0%)  Disappear=6 (3%)  New=6
#   2021→2022: Stable=202 (98%)  Merge=0 (0%)  Disappear=5 (2%)  New=5
#   2022→2023: Stable=201 (97%)  Merge=0 (0%)  Disappear=6 (3%)  New=6
#   2023→2024: Stable=202 (98%)  Merge=0 (0%)  Disappear=5 (2%)  New=5
#   2024→2025: Stable=200 (97%)  Merge=0 (0%)  Disappear=7 (3%)  New=7
#
#   Overall: Stable=76.6%  Merge=0.0%  Disappear=23.4%  New=1123
#   Saved: ../../../../results/top2vec/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 1663 events
#   Per year:
#     2000: 69 topics
#     2001: 81 topics
#     2002: 93 topics
#     2003: 88 topics
#     2004: 112 topics
#     2005: 114 topics
#     2006: 112 topics
#     2007: 102 topics
#     2008: 107 topics
#     2009: 90 topics
#     2010: 109 topics
#     2011: 89 topics
#     2012: 109 topics
#     2013: 86 topics
#     2014: 76 topics
#     2015: 67 topics
#     2016: 53 topics
#     2017: 35 topics
#     2018: 28 topics
#     2019: 14 topics
#     2020: 11 topics
#     2021: 9 topics
#     2022: 5 topics
#     2023: 3 topics
#     2024: 1 topics
#
#   Permanently gone: 1
#     T253 last @ 2024 (sim=0.446) | word, lyndon_factorization, parikh, icfl, morphism
#
#   🔗 MERGE GROUPS: 5 events
#   Top 10 merges (most sources):
#     T112 @ 2010 ← [31, 112] (sims=[0.5192, 0.796]) | channel, cognitive_radio, network, trans
#     T  2 @ 2018 ← [2, 70] (sims=[0.7315, 0.5336]) | gpu, memory, parallel, processor, core,
#     T  7 @ 2019 ← [7, 185] (sims=[0.8707, 0.5209]) | neural_network, deep, network, layer, tr
#     T172 @ 2019 ← [172, 251] (sims=[0.7665, 0.6452]) | anomaly_detection, anomaly, normal, dete
#     T 32 @ 2022 ← [32, 198] (sims=[1.0, 0.5247]) | word, embedding, sentence, language, ber
#
#   🆕 NEW TOPICS: 1848 events
#   Per year:
#     2001: 67 new topics
#     2002: 93 new topics
#     2003: 103 new topics
#     2004: 109 new topics
#     2005: 110 new topics
#     2006: 112 new topics
#     2007: 113 new topics
#     2008: 106 new topics
#     2009: 114 new topics
#     2010: 113 new topics
#     2011: 115 new topics
#     2012: 125 new topics
#     2013: 116 new topics
#     2014: 93 new topics
#     2015: 104 new topics
#     2016: 79 new topics
#     2017: 61 new topics
#     2018: 39 new topics
#     2019: 31 new topics
#     2020: 15 new topics
#     2021: 10 new topics
#     2022: 11 new topics
#     2023: 5 new topics
#     2024: 3 new topics
#     2025: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T273 | 100% stable (8S 0M 0D)
#     T 55 | 100% stable (25S 0M 0D)
#     T 33 | 100% stable (10S 0M 0D)
#     T270 | 100% stable (12S 0M 0D)
#     T 36 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T154 | 36% stable (5S 0M 9D)
#     T263 | 36% stable (5S 0M 9D)
#     T160 | 35% stable (8S 0M 15D)
#     T250 | 24% stable (6S 0M 19D)
#     T229 | 24% stable (6S 0M 19D)
#
#
# ======================================================================
# Analysis Review: MATH (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 782 events
#   Per year:
#     2000: 68 topics
#     2001: 76 topics
#     2002: 69 topics
#     2003: 63 topics
#     2004: 70 topics
#     2005: 51 topics
#     2006: 58 topics
#     2007: 55 topics
#     2008: 49 topics
#     2009: 49 topics
#     2010: 43 topics
#     2011: 25 topics
#     2012: 23 topics
#     2013: 13 topics
#     2014: 10 topics
#     2015: 14 topics
#     2016: 11 topics
#     2017: 8 topics
#     2018: 3 topics
#     2019: 4 topics
#     2020: 4 topics
#     2021: 6 topics
#     2022: 3 topics
#     2023: 3 topics
#     2024: 4 topics
#
#   Permanently gone: 4
#     T128 last @ 2024 (sim=0.407) | lattice, poset, nelson, sasaki, element, congruenc
#     T175 last @ 2024 (sim=0.457) | painlev, heile, function, mumford, soliton, tusi,
#     T177 last @ 2024 (sim=0.454) | mapping, convergence, point, operator, algorithm,
#     T195 last @ 2024 (sim=0.334) | camassa_holm, solitary_wave, wave, dark_breather,
#
#   🔗 MERGE GROUPS: 1 events
#   Top 10 merges (most sources):
#     T 90 @ 2013 ← [81, 90] (sims=[0.5206, 0.7112]) | network, algorithm, optimization, sensor
#
#   🆕 NEW TOPICS: 832 events
#   Per year:
#     2001: 76 new topics
#     2002: 79 new topics
#     2003: 75 new topics
#     2004: 70 new topics
#     2005: 79 new topics
#     2006: 59 new topics
#     2007: 60 new topics
#     2008: 55 new topics
#     2009: 52 new topics
#     2010: 49 new topics
#     2011: 45 new topics
#     2012: 26 new topics
#     2013: 24 new topics
#     2014: 13 new topics
#     2015: 10 new topics
#     2016: 14 new topics
#     2017: 11 new topics
#     2018: 8 new topics
#     2019: 3 new topics
#     2020: 4 new topics
#     2021: 4 new topics
#     2022: 6 new topics
#     2023: 3 new topics
#     2024: 3 new topics
#     2025: 4 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0M 0D)
#     T  2 | 100% stable (25S 0M 0D)
#     T  9 | 100% stable (25S 0M 0D)
#     T 11 | 100% stable (25S 0M 0D)
#     T 55 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T174 | 54% stable (12S 0M 10D)
#     T172 | 48% stable (11S 0M 12D)
#     T133 | 46% stable (11S 0M 13D)
#     T187 | 44% stable (10S 0M 13D)
#     T175 | 40% stable (10S 0M 15D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 1063 events
#   Per year:
#     2000: 67 topics
#     2001: 76 topics
#     2002: 95 topics
#     2003: 84 topics
#     2004: 74 topics
#     2005: 77 topics
#     2006: 71 topics
#     2007: 75 topics
#     2008: 73 topics
#     2009: 56 topics
#     2010: 51 topics
#     2011: 39 topics
#     2012: 40 topics
#     2013: 45 topics
#     2014: 35 topics
#     2015: 30 topics
#     2016: 17 topics
#     2017: 13 topics
#     2018: 11 topics
#     2019: 5 topics
#     2020: 6 topics
#     2021: 5 topics
#     2022: 6 topics
#     2023: 5 topics
#     2024: 7 topics
#
#   Permanently gone: 7
#     T103 last @ 2024 (sim=0.471) | relativity, special_relativity, einstein, clock, t
#     T147 last @ 2024 (sim=0.148) | calendar, astronomical, catalogue, star, sundial,
#     T169 last @ 2024 (sim=0.441) | superconductivity, superconductor, vortex, phase,
#     T173 last @ 2024 (sim=0.447) | nanoparticle, magnetic, hyperthermia, mpi, cell, m
#     T189 last @ 2024 (sim=0.463) | lightning, sprite, thunderstorm, ball_lightning, a
#     T196 last @ 2024 (sim=0.359) | fullerene, c60, radical, anion, c20, electron, ato
#     T197 last @ 2024 (sim=0.373) | ventilation, airborne, droplet, aerosol, depositio
#
#   🔗 MERGE GROUPS: 1 events
#   Top 10 merges (most sources):
#     T 30 @ 2007 ← [30, 83] (sims=[0.7733, 0.5434]) | plasma, wave, electron, ion, dust, dusty
#
#   🆕 NEW TOPICS: 1123 events
#   Per year:
#     2001: 77 new topics
#     2002: 77 new topics
#     2003: 104 new topics
#     2004: 86 new topics
#     2005: 85 new topics
#     2006: 84 new topics
#     2007: 79 new topics
#     2008: 73 new topics
#     2009: 78 new topics
#     2010: 63 new topics
#     2011: 50 new topics
#     2012: 40 new topics
#     2013: 40 new topics
#     2014: 46 new topics
#     2015: 35 new topics
#     2016: 30 new topics
#     2017: 18 new topics
#     2018: 13 new topics
#     2019: 11 new topics
#     2020: 5 new topics
#     2021: 6 new topics
#     2022: 5 new topics
#     2023: 6 new topics
#     2024: 5 new topics
#     2025: 7 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  3 | 100% stable (25S 0M 0D)
#     T  5 | 100% stable (25S 0M 0D)
#     T  9 | 100% stable (25S 0M 0D)
#     T 11 | 100% stable (25S 0M 0D)
#     T 12 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T197 | 35% stable (6S 0M 11D)
#     T166 | 32% stable (8S 0M 17D)
#     T127 | 32% stable (7S 0M 15D)
#     T147 | 32% stable (7S 0M 15D)
#     T157 | 26% stable (6S 0M 17D)
