# %% [markdown]
# # Top2Vec: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/top2vec/temporal")
RESULT_DIR = Path("../../../../results/top2vec/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/top2vec/temporal
# Saving to: ../../../../results/top2vec/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list_1, list_2, p=0.9):
    k = min(len(list_1), len(list_2))
    if k == 0:
        return 0.0
    score = 0.0
    for d in range(1, k + 1):
        agreement = len(set(list_1[:d]) & set(list_2[:d])) / d
        score += (p ** (d - 1)) * agreement
    return score * (1 - p)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for i, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for j, tid_t1 in enumerate(topics_t1):
                words_t1 = topic_words.get((t_next, tid_t1), [])
                sim_matrix[i, j] = rbo(words_t, words_t1, p=0.9)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=16 (15%)  Merge=0 (0%)  Disappear=93 (85%)  New=95
#   2001→2002: Stable=10 (9%)  Merge=0 (0%)  Disappear=101 (91%)  New=114
#   2002→2003: Stable=15 (12%)  Merge=0 (0%)  Disappear=109 (88%)  New=110
#   2003→2004: Stable=22 (18%)  Merge=0 (0%)  Disappear=103 (82%)  New=129
#   2004→2005: Stable=25 (17%)  Merge=0 (0%)  Disappear=126 (83%)  New=129
#   2005→2006: Stable=24 (16%)  Merge=0 (0%)  Disappear=130 (84%)  New=123
#   2006→2007: Stable=26 (18%)  Merge=0 (0%)  Disappear=121 (82%)  New=118
#   2007→2008: Stable=29 (20%)  Merge=0 (0%)  Disappear=115 (80%)  New=123
#   2008→2009: Stable=38 (25%)  Merge=0 (0%)  Disappear=114 (75%)  New=122
#   2009→2010: Stable=44 (28%)  Merge=0 (0%)  Disappear=116 (72%)  New=128
#   2010→2011: Stable=53 (31%)  Merge=0 (0%)  Disappear=119 (69%)  New=131
#   2011→2012: Stable=65 (35%)  Merge=0 (0%)  Disappear=119 (65%)  New=144
#   2012→2013: Stable=79 (38%)  Merge=0 (0%)  Disappear=130 (62%)  New=140
#   2013→2014: Stable=106 (48%)  Merge=0 (0%)  Disappear=113 (52%)  New=117
#   2014→2015: Stable=113 (51%)  Merge=0 (0%)  Disappear=110 (49%)  New=129
#   2015→2016: Stable=140 (58%)  Merge=0 (0%)  Disappear=102 (42%)  New=108
#   2016→2017: Stable=167 (67%)  Merge=0 (0%)  Disappear=81 (33%)  New=86
#   2017→2018: Stable=197 (78%)  Merge=0 (0%)  Disappear=56 (22%)  New=60
#   2018→2019: Stable=214 (83%)  Merge=0 (0%)  Disappear=43 (17%)  New=45
#   2019→2020: Stable=236 (91%)  Merge=0 (0%)  Disappear=23 (9%)  New=22
#   2020→2021: Stable=234 (91%)  Merge=0 (0%)  Disappear=24 (9%)  New=24
#   2021→2022: Stable=240 (93%)  Merge=0 (0%)  Disappear=18 (7%)  New=19
#   2022→2023: Stable=245 (95%)  Merge=0 (0%)  Disappear=14 (5%)  New=14
#   2023→2024: Stable=246 (95%)  Merge=0 (0%)  Disappear=13 (5%)  New=13
#   2024→2025: Stable=249 (96%)  Merge=0 (0%)  Disappear=10 (4%)  New=10
#
#   Overall: Stable=49.0%  Merge=0.0%  Disappear=51.0%  New=2253
#   Saved: ../../../../results/top2vec/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (Top2Vec)
# ======================================================================
#   2000→2001: Stable=35 (23%)  Merge=0 (0%)  Disappear=115 (77%)  New=126
#   2001→2002: Stable=49 (30%)  Merge=0 (0%)  Disappear=112 (70%)  New=108
#   2002→2003: Stable=53 (34%)  Merge=0 (0%)  Disappear=104 (66%)  New=112
#   2003→2004: Stable=66 (40%)  Merge=0 (0%)  Disappear=99 (60%)  New=114
#   2004→2005: Stable=79 (44%)  Merge=0 (0%)  Disappear=101 (56%)  New=107
#   2005→2006: Stable=81 (44%)  Merge=0 (0%)  Disappear=105 (56%)  New=114
#   2006→2007: Stable=91 (47%)  Merge=0 (0%)  Disappear=104 (53%)  New=109
#   2007→2008: Stable=110 (55%)  Merge=0 (0%)  Disappear=90 (45%)  New=91
#   2008→2009: Stable=124 (62%)  Merge=0 (0%)  Disappear=77 (38%)  New=79
#   2009→2010: Stable=132 (65%)  Merge=0 (0%)  Disappear=71 (35%)  New=74
#   2010→2011: Stable=136 (66%)  Merge=0 (0%)  Disappear=70 (34%)  New=72
#   2011→2012: Stable=145 (70%)  Merge=0 (0%)  Disappear=63 (30%)  New=63
#   2012→2013: Stable=163 (78%)  Merge=0 (0%)  Disappear=45 (22%)  New=45
#   2013→2014: Stable=178 (86%)  Merge=0 (0%)  Disappear=30 (14%)  New=30
#   2014→2015: Stable=179 (86%)  Merge=0 (0%)  Disappear=29 (14%)  New=30
#   2015→2016: Stable=192 (92%)  Merge=0 (0%)  Disappear=17 (8%)  New=16
#   2016→2017: Stable=184 (88%)  Merge=0 (0%)  Disappear=24 (12%)  New=25
#   2017→2018: Stable=192 (92%)  Merge=0 (0%)  Disappear=17 (8%)  New=17
#   2018→2019: Stable=185 (89%)  Merge=0 (0%)  Disappear=24 (11%)  New=24
#   2019→2020: Stable=191 (91%)  Merge=0 (0%)  Disappear=18 (9%)  New=18
#   2020→2021: Stable=192 (92%)  Merge=0 (0%)  Disappear=17 (8%)  New=17
#   2021→2022: Stable=193 (92%)  Merge=0 (0%)  Disappear=16 (8%)  New=16
#   2022→2023: Stable=199 (95%)  Merge=0 (0%)  Disappear=10 (5%)  New=10
#   2023→2024: Stable=202 (97%)  Merge=0 (0%)  Disappear=7 (3%)  New=7
#   2024→2025: Stable=201 (96%)  Merge=0 (0%)  Disappear=8 (4%)  New=8
#
#   Overall: Stable=70.1%  Merge=0.0%  Disappear=29.9%  New=1432
#   Saved: ../../../../results/top2vec/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=39 (26%)  Merge=0 (0%)  Disappear=111 (74%)  New=121
#   2001→2002: Stable=38 (24%)  Merge=0 (0%)  Disappear=122 (76%)  New=126
#   2002→2003: Stable=34 (21%)  Merge=0 (0%)  Disappear=130 (79%)  New=133
#   2003→2004: Stable=45 (27%)  Merge=0 (0%)  Disappear=122 (73%)  New=131
#   2004→2005: Stable=57 (32%)  Merge=0 (0%)  Disappear=119 (68%)  New=129
#   2005→2006: Stable=75 (40%)  Merge=0 (0%)  Disappear=111 (60%)  New=115
#   2006→2007: Stable=94 (49%)  Merge=0 (0%)  Disappear=96 (51%)  New=106
#   2007→2008: Stable=95 (48%)  Merge=0 (0%)  Disappear=105 (52%)  New=100
#   2008→2009: Stable=93 (48%)  Merge=0 (0%)  Disappear=102 (52%)  New=110
#   2009→2010: Stable=115 (57%)  Merge=0 (0%)  Disappear=88 (43%)  New=94
#   2010→2011: Stable=125 (60%)  Merge=0 (0%)  Disappear=84 (40%)  New=81
#   2011→2012: Stable=144 (70%)  Merge=0 (0%)  Disappear=62 (30%)  New=64
#   2012→2013: Stable=151 (73%)  Merge=0 (0%)  Disappear=57 (27%)  New=55
#   2013→2014: Stable=151 (73%)  Merge=0 (0%)  Disappear=55 (27%)  New=57
#   2014→2015: Stable=158 (76%)  Merge=0 (0%)  Disappear=50 (24%)  New=51
#   2015→2016: Stable=162 (78%)  Merge=0 (0%)  Disappear=47 (22%)  New=47
#   2016→2017: Stable=172 (82%)  Merge=0 (0%)  Disappear=37 (18%)  New=38
#   2017→2018: Stable=179 (85%)  Merge=0 (0%)  Disappear=31 (15%)  New=31
#   2018→2019: Stable=187 (89%)  Merge=0 (0%)  Disappear=23 (11%)  New=23
#   2019→2020: Stable=189 (90%)  Merge=0 (0%)  Disappear=21 (10%)  New=21
#   2020→2021: Stable=195 (93%)  Merge=0 (0%)  Disappear=15 (7%)  New=15
#   2021→2022: Stable=197 (94%)  Merge=0 (0%)  Disappear=13 (6%)  New=13
#   2022→2023: Stable=198 (94%)  Merge=0 (0%)  Disappear=12 (6%)  New=12
#   2023→2024: Stable=195 (93%)  Merge=0 (0%)  Disappear=15 (7%)  New=15
#   2024→2025: Stable=198 (94%)  Merge=0 (0%)  Disappear=12 (6%)  New=12
#
#   Overall: Stable=64.6%  Merge=0.0%  Disappear=35.4%  New=1700
#   Saved: ../../../../results/top2vec/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 2103 events
#   Per year:
#     2000: 93 topics
#     2001: 101 topics
#     2002: 109 topics
#     2003: 103 topics
#     2004: 126 topics
#     2005: 130 topics
#     2006: 121 topics
#     2007: 115 topics
#     2008: 114 topics
#     2009: 116 topics
#     2010: 119 topics
#     2011: 119 topics
#     2012: 130 topics
#     2013: 113 topics
#     2014: 110 topics
#     2015: 102 topics
#     2016: 81 topics
#     2017: 56 topics
#     2018: 43 topics
#     2019: 23 topics
#     2020: 24 topics
#     2021: 18 topics
#     2022: 14 topics
#     2023: 13 topics
#     2024: 10 topics
#
#   Permanently gone: 10
#     T 41 last @ 2024 (sim=0.475) | wireless, networks, network, interference, cellula
#     T 56 last @ 2024 (sim=0.457) | test, software, bugs, bug, code, testing, program,
#     T 58 last @ 2024 (sim=0.471) | data, patient, patients, clinical, health, learnin
#     T137 last @ 2024 (sim=0.450) | models, training, llms, tuning, language, fine, lo
#     T153 last @ 2024 (sim=0.480) | relay, deepjscc, relaying, channel, relays, cooper
#     T161 last @ 2024 (sim=0.380) | spectrum, wireless, energy, radio, channel, sensin
#     T206 last @ 2024 (sim=0.484) | access, security, policies, authorization, policy,
#     T212 last @ 2024 (sim=0.398) | codes, storage, repair, dna, data, code, erasure,
#     T222 last @ 2024 (sim=0.425) | phylogenetic, trees, tree, phylogenies, phylogeny,
#     T228 last @ 2024 (sim=0.460) | rppg, heart, ppg, physiological, monitoring, photo
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 2253 events
#   Per year:
#     2001: 95 new topics
#     2002: 114 new topics
#     2003: 110 new topics
#     2004: 129 new topics
#     2005: 129 new topics
#     2006: 123 new topics
#     2007: 118 new topics
#     2008: 123 new topics
#     2009: 122 new topics
#     2010: 128 new topics
#     2011: 131 new topics
#     2012: 144 new topics
#     2013: 140 new topics
#     2014: 117 new topics
#     2015: 129 new topics
#     2016: 108 new topics
#     2017: 86 new topics
#     2018: 60 new topics
#     2019: 45 new topics
#     2020: 22 new topics
#     2021: 24 new topics
#     2022: 19 new topics
#     2023: 14 new topics
#     2024: 13 new topics
#     2025: 10 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0M 0D)
#     T  1 | 100% stable (25S 0M 0D)
#     T 69 | 100% stable (25S 0M 0D)
#     T  8 | 95% stable (20S 0M 1D)
#     T 36 | 92% stable (23S 0M 2D)
#   Top 5 most unstable:
#     T179 | 20% stable (3S 0M 12D)
#     T228 | 18% stable (3S 0M 14D)
#     T225 | 18% stable (3S 0M 14D)
#     T258 | 15% stable (3S 0M 17D)
#     T190 | 12% stable (3S 0M 22D)
#
#
# ======================================================================
# Analysis Review: MATH (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 1373 events
#   Per year:
#     2000: 115 topics
#     2001: 112 topics
#     2002: 104 topics
#     2003: 99 topics
#     2004: 101 topics
#     2005: 105 topics
#     2006: 104 topics
#     2007: 90 topics
#     2008: 77 topics
#     2009: 71 topics
#     2010: 70 topics
#     2011: 63 topics
#     2012: 45 topics
#     2013: 30 topics
#     2014: 29 topics
#     2015: 17 topics
#     2016: 24 topics
#     2017: 17 topics
#     2018: 24 topics
#     2019: 18 topics
#     2020: 17 topics
#     2021: 16 topics
#     2022: 10 topics
#     2023: 7 topics
#     2024: 8 topics
#
#   Permanently gone: 8
#     T 17 last @ 2024 (sim=0.494) | mathcal, category, categories, modules, algebras,
#     T 36 last @ 2024 (sim=0.479) | lie, poisson, algebra, symplectic, mathcal, algebr
#     T 48 last @ 2024 (sim=0.461) | dirichlet, eigenvalue, boundary, laplacian, eigenv
#     T 60 last @ 2024 (sim=0.399) | numerical, time, methods, kutta, method, runge, or
#     T 75 last @ 2024 (sim=0.482) | model, spin, ising, temperature, gibbs, random, fi
#     T 83 last @ 2024 (sim=0.469) | mathbb, frac, set, mathcal, sum, ldots, sets, subs
#     T 87 last @ 2024 (sim=0.483) | mathbb, functions, mathcal, infty, function, univa
#     T166 last @ 2024 (sim=0.456) | conformal, cft, mathcal, field, sle, algebras, mat
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 1432 events
#   Per year:
#     2001: 126 new topics
#     2002: 108 new topics
#     2003: 112 new topics
#     2004: 114 new topics
#     2005: 107 new topics
#     2006: 114 new topics
#     2007: 109 new topics
#     2008: 91 new topics
#     2009: 79 new topics
#     2010: 74 new topics
#     2011: 72 new topics
#     2012: 63 new topics
#     2013: 45 new topics
#     2014: 30 new topics
#     2015: 30 new topics
#     2016: 16 new topics
#     2017: 25 new topics
#     2018: 17 new topics
#     2019: 24 new topics
#     2020: 18 new topics
#     2021: 17 new topics
#     2022: 16 new topics
#     2023: 10 new topics
#     2024: 7 new topics
#     2025: 8 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  1 | 100% stable (25S 0M 0D)
#     T 11 | 100% stable (25S 0M 0D)
#     T  8 | 100% stable (25S 0M 0D)
#     T 40 | 100% stable (25S 0M 0D)
#     T 32 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 97 | 36% stable (9S 0M 16D)
#     T189 | 32% stable (8S 0M 17D)
#     T110 | 29% stable (7S 0M 17D)
#     T166 | 20% stable (5S 0M 20D)
#     T206 | 19% stable (4S 0M 17D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 1640 events
#   Per year:
#     2000: 111 topics
#     2001: 122 topics
#     2002: 130 topics
#     2003: 122 topics
#     2004: 119 topics
#     2005: 111 topics
#     2006: 96 topics
#     2007: 105 topics
#     2008: 102 topics
#     2009: 88 topics
#     2010: 84 topics
#     2011: 62 topics
#     2012: 57 topics
#     2013: 55 topics
#     2014: 50 topics
#     2015: 47 topics
#     2016: 37 topics
#     2017: 31 topics
#     2018: 23 topics
#     2019: 21 topics
#     2020: 15 topics
#     2021: 13 topics
#     2022: 12 topics
#     2023: 15 topics
#     2024: 12 topics
#
#   Permanently gone: 12
#     T 21 last @ 2024 (sim=0.490) | waves, wave, equation, water, nonlinear, surface,
#     T113 last @ 2024 (sim=0.445) | alloys, gpa, phase, fe, corrosion, temperature, pr
#     T153 last @ 2024 (sim=0.297) | astronomical, calendar, century, moon, sun, astron
#     T158 last @ 2024 (sim=0.398) | hydrogel, scaffolds, hydrogels, polymer, tissue, m
#     T164 last @ 2024 (sim=0.451) | readout, detector, noise, ghz, detectors, inductan
#     T165 last @ 2024 (sim=0.476) | memristive, neuromorphic, memristors, memristor, s
#     T186 last @ 2024 (sim=0.385) | cavities, niobium, srf, superconducting, nb, cavit
#     T187 last @ 2024 (sim=0.423) | life, technosignatures, extraterrestrial, seti, ci
#     T201 last @ 2024 (sim=0.367) | covid, ventilation, sars, cov, airborne, air, infe
#     T203 last @ 2024 (sim=0.447) | reinforcement, drl, learning, control, flow, deep,
#     ... +2 more
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 1700 events
#   Per year:
#     2001: 121 new topics
#     2002: 126 new topics
#     2003: 133 new topics
#     2004: 131 new topics
#     2005: 129 new topics
#     2006: 115 new topics
#     2007: 106 new topics
#     2008: 100 new topics
#     2009: 110 new topics
#     2010: 94 new topics
#     2011: 81 new topics
#     2012: 64 new topics
#     2013: 55 new topics
#     2014: 57 new topics
#     2015: 51 new topics
#     2016: 47 new topics
#     2017: 38 new topics
#     2018: 31 new topics
#     2019: 23 new topics
#     2020: 21 new topics
#     2021: 15 new topics
#     2022: 13 new topics
#     2023: 12 new topics
#     2024: 15 new topics
#     2025: 12 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 13 | 100% stable (25S 0M 0D)
#     T  2 | 100% stable (25S 0M 0D)
#     T 27 | 100% stable (25S 0M 0D)
#     T 29 | 100% stable (25S 0M 0D)
#     T 42 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T144 | 22% stable (5S 0M 18D)
#     T139 | 14% stable (3S 0M 19D)
#     T153 | 14% stable (3S 0M 19D)
#     T201 | 6% stable (1S 0M 16D)
#     T158 | 4% stable (1S 0M 21D)
