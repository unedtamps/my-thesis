# %% [markdown]
# # Top2Vec: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment with mismatch detection.
#
# | Priority | Category | Condition |
# |----------|----------|-----------|
# | 1 | **Disappear** | sim ≤ 0.2 |
# | 2 | **Merge** | sim > 0.2, and the t+1-topic has >1 source |
# | 3 | **Mismatch** | sim > 0.2, single source, best-match ID ≠ own topic ID |
# | 4 | **Stable** | sim > 0.6, best-match ID = own topic ID |
# | 5 | **Evolve** | 0.2 < sim ≤ 0.6, best-match ID = own topic ID |
# | — | **New** | t+1-topic has no incoming source with sim > 0.2 |
#
#
# From t-side: Disappear + Merge + Mismatch + Stable + Evolve = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/top2vec/temporal")
RESULT_DIR = Path("../../../../results/top2vec/consistency")
THRESHOLD_DISAPPEAR = 0.2  # sim <= 0.2 → disappear
THRESHOLD_STABLE    = 0.6  # sim > 0.5  → stable (if same ID)

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold Disappear : sim <= {THRESHOLD_DISAPPEAR}")
print(f"Threshold Stable    : sim > {THRESHOLD_STABLE}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold Disappear : sim <= 0.2
# Threshold Stable    : sim > 0.6
# Reading from: ../../../../results/top2vec/temporal
# Saving to: ../../../../results/top2vec/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n'======================================================================'")
    print(f"Continuity Rate: {subject.upper()} (Top2Vec)")
    print(f"'======================================================================'")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t  = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        # Build full RBO similarity matrix (t → t+1)
        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for ii, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for jj, tid_t1 in enumerate(topics_t1):
                words_t1_tmp = topic_words.get((t_next, tid_t1), [])
                sim_matrix[ii, jj] = rbo(words_t, words_t1_tmp, p=0.9)

        # ── Step 1: Each t-topic → its best t+1-topic ────────────────────────
        best_match_idx = np.argmax(sim_matrix, axis=1)
        best_match_sim = np.max(sim_matrix, axis=1)

        # ── Step 2: Count sources (sim > 0.2) per t+1-topic ──────────────────
        target_counts = Counter()
        for idx in range(len(topics_t)):
            if float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR:
                target_counts[topics_t1[best_match_idx[idx]]] += 1

        # merge_targets: t+1-topics claimed by >1 source with sim > 0.2
        merge_targets = {tgt for tgt, cnt in target_counts.items() if cnt > 1}

        # ── Step 3: Classify each t-topic ─────────────────────────────────────
        n_stable = n_evolve = n_merge = n_disappear = n_mismatch = 0

        for idx, tid in enumerate(topics_t):
            sim_val    = float(best_match_sim[idx])
            target_tid = topics_t1[best_match_idx[idx]]
            words_t    = ", ".join(topic_words.get((t, tid), []))

            # ── 1. DISAPPEAR: sim <= 0.2 ──────────────────────────────────────
            if sim_val <= THRESHOLD_DISAPPEAR:
                category = "disappear"
                n_disappear += 1

            # ── 2. MERGE: sim > 0.2 AND target has >1 source ─────────────────
            elif tid in merge_targets:
                tar_id = tid
                sources = [tid for idx, tid in enumerate(topics_t)
                       if topics_t1[best_match_idx[idx]] == tar_id
                       and float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR]
                if tid in sources:
                    category = "merge"
                    n_merge += 1
                else:
                    category = "mismatch"
                    n_merge += 1

            # ── 3. MISMATCH: sim > 0.2, single source, target ID ≠ own ID ────
            elif target_tid != tid:
                category   = "mismatch"
                n_mismatch += 1

            # ── 4. STABLE: sim > 0.5, target ID = own ID ─────────────────────
            elif sim_val > THRESHOLD_STABLE:
                category = "stable"
                n_stable += 1

            # ── 5. EVOLVE: 0.2 < sim <= 0.5, target ID = own ID ─────────────
            else:
                category = "evolve"
                n_evolve += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target_tid,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # ── Step 4: Record merge groups ────────────────────────────────────────
        for target_tid in merge_targets:
            sources = [tid for idx, tid in enumerate(topics_t)
                       if topics_t1[best_match_idx[idx]] == target_tid
                       and float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR]
            source_sims = [round(float(sim_matrix[topics_t.index(s),
                                                   topics_t1.index(target_tid)]), 4)
                           for s in sources]
            words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
            all_merge_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "target_topic": target_tid,
                "n_sources": len(sources),
                "source_topics": str(sources),
                "source_sims": str(source_sims),
                "target_words": words_t1,
            })

        # ── Step 5: New topics — no incoming source with sim > 0.2 ────────────
        matched_t1 = set(topics_t[idx]
                         for idx in range(len(topics_t))
                         if float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR)
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t        = len(topics_t)
        n_new          = len(new_topics)
        n_merge_groups = len(merge_targets)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_evolve": n_evolve, "n_merge": n_merge,
            "n_mismatch": n_mismatch, "n_disappear": n_disappear,
            "n_merge_groups": n_merge_groups, "n_new": n_new,
            "pct_stable":    round(n_stable    / total_t * 100, 2),
            "pct_evolve":    round(n_evolve    / total_t * 100, 2),
            "pct_merge":     round(n_merge     / total_t * 100, 2),
            "pct_mismatch":  round(n_mismatch  / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Evolve={n_evolve} ({n_evolve/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Mismatch={n_mismatch} ({n_mismatch/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject,
        "threshold_disappear": THRESHOLD_DISAPPEAR,
        "threshold_stable":    THRESHOLD_STABLE,
        "avg_pct_stable":    round(subj_sum["pct_stable"].mean(),    2),
        "avg_pct_evolve":    round(subj_sum["pct_evolve"].mean(),    2),
        "avg_pct_merge":     round(subj_sum["pct_merge"].mean(),     2),
        "avg_pct_mismatch":  round(subj_sum["pct_mismatch"].mean(),  2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new":          int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Evolve={overall['avg_pct_evolve']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Mismatch={overall['avg_pct_mismatch']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=3 (1%)  New=3
#   2018→2019: Stable=186 (90%)  Evolve=18 (9%)  Merge=1 (0%)  Mismatch=1 (0%)  Disappear=1 (0%)  New=1
#   2019→2020: Stable=189 (91%)  Evolve=17 (8%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (0%)  New=1
#   2020→2021: Stable=191 (92%)  Evolve=16 (8%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=190 (92%)  Evolve=15 (7%)  Merge=1 (0%)  Mismatch=1 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=190 (92%)  Evolve=17 (8%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=189 (91%)  Evolve=18 (9%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=195 (94%)  Evolve=11 (5%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (0%)  New=1
#
#   Overall: Stable=64.0%  Evolve=27.2%  Merge=1.5%  Mismatch=1.7%  Disappear=5.7%  New=324
#   Saved: ../../../../results/top2vec/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n'======================================================================'")
    print(f"Analysis Review: {subject.upper()} (Top2Vec)")
    print(f"'======================================================================'")

    trans_df   = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df   = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path   = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df     = pd.read_csv(new_path)   if new_path.stat().st_size   > 10 else pd.DataFrame()
    evo_df     = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- MERGE ---
    merged = trans_df[trans_df["category"] == "merge"]
    print(f"\n  🔗 MERGE (sim > {THRESHOLD_DISAPPEAR}, >1 source): {len(merged)} events")
    if len(merge_df) > 0:
        print("  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(min(10, len(merge_df)), "n_sources").iterrows():
            w = str(r["target_words"])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- MISMATCH ---
    mismatch = trans_df[trans_df["category"] == "mismatch"]
    print(f"\n  ⚠️  MISMATCH (sim > {THRESHOLD_DISAPPEAR}, target ID ≠ own ID): {len(mismatch)} events")
    if len(mismatch) > 0:
        per_year = mismatch.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")
        print("  Sample (up to 5):")
        for _, r in mismatch.head(5).iterrows():
            print(f"    T{int(r['topic_id']):>3} @ {int(r['year_from'])}→{int(r['year_to'])} "
                  f"best→T{int(r['best_match_topic'])} (sim={r['best_match_sim']:.3f}) | {str(r['words'])[:50]}")

    # --- STABLE ---
    stable = trans_df[trans_df["category"] == "stable"]
    print(f"\n  🟢 STABLE (sim > {THRESHOLD_STABLE}, same ID): {len(stable)} events")
    if len(stable) > 0:
        per_year = stable.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

    # --- EVOLVE ---
    evolved = trans_df[trans_df["category"] == "evolve"]
    print(f"\n  🔄 EVOLVE ({THRESHOLD_DISAPPEAR} < sim <= {THRESHOLD_STABLE}, same ID): {len(evolved)} events")
    if len(evolved) > 0:
        per_year = evolved.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

    # --- DISAPPEAR ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED (sim <= {THRESHOLD_DISAPPEAR}): {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")
        perm = []
        for _, r in disappeared.iterrows():
            tid   = int(r["topic_id"])
            later = evo_df[(evo_df["topic_id"] == tid) & (evo_df["year"] > int(r["year_to"]))]
            if len(later) == 0:
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {str(r['words'])[:50]}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS (no incoming sim > {THRESHOLD_DISAPPEAR}): {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print("\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "evolve", "merge", "mismatch", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)
    print("  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev "
              f"{int(r.get('merge',0))}M {int(r.get('mismatch',0))}Mm {int(r.get('disappear',0))}D)")
    print("  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev "
              f"{int(r.get('merge',0))}M {int(r.get('mismatch',0))}Mm {int(r.get('disappear',0))}D)")
    print()
# Out:
# '======================================================================'
# Analysis Review: CS (Top2Vec)
# '======================================================================'
#   🔗 MERGE (sim > 0.2, >1 source): 121 events
#   Top 10 merges (most sources):
#     T246 @ 2002 ← [18, 145, 246] (sims=[0.209, 0.2372, 0.3147]) | cable, internet, access, incumbent, broa
#     T218 @ 2003 ← [60, 120, 218] (sims=[0.2703, 0.2703, 0.7099]) | rbf, rbfs, manifold, gmst, geodesic, rad
#     T 99 @ 2007 ← [58, 99, 182] (sims=[0.4406, 0.692, 0.2236]) | network, routing, wireless, sensor, node
#     T  7 @ 2007 ← [7, 176, 230] (sims=[0.2703, 0.2703, 0.3756]) | functional, teacher, perceptron, general
#     T178 @ 2010 ← [47, 136, 178] (sims=[0.4676, 0.3998, 0.5859]) | query, database, schema, datum, relation
#     T122 @ 2013 ← [20, 118, 122] (sims=[0.3372, 0.3503, 0.2607]) | robot, arm, motion, dof, manipulator, co
#     T265 @ 2001 ← [265, 277] (sims=[0.5055, 0.3686]) | mining, rule, association, datum, web, s
#     T 79 @ 2001 ← [38, 79] (sims=[0.2703, 0.4472]) | agent, maxi, observable, game, cooperati
#     T 49 @ 2001 ← [28, 49] (sims=[0.2198, 0.5653]) | grammar, xml, circularity, language, red
#     T 50 @ 2001 ← [50, 288] (sims=[0.5884, 0.2686]) | program, debugger, debugging, aadebug, r
#
#   ⚠️  MISMATCH (sim > 0.2, target ID ≠ own ID): 147 events
#   Per year:
#     2000: 7 topics
#     2001: 7 topics
#     2002: 11 topics
#     2003: 6 topics
#     2004: 13 topics
#     2005: 4 topics
#     2006: 6 topics
#     2007: 6 topics
#     2008: 14 topics
#     2009: 9 topics
#     2010: 8 topics
#     2011: 7 topics
#     2012: 9 topics
#     2013: 15 topics
#     2014: 5 topics
#     2015: 8 topics
#     2016: 2 topics
#     2017: 3 topics
#     2018: 4 topics
#     2019: 1 topics
#     2021: 1 topics
#     2022: 1 topics
#   Sample (up to 5):
#     T 28 @ 2000→2001 best→T49 (sim=0.220) | asf, grammar, sdf, rewrite, compiler, testsuite, r
#     T 38 @ 2000→2001 best→T79 (sim=0.270) | agent, autonomy, request, brainstorm, emph, mas, s
#     T 76 @ 2000→2001 best→T55 (sim=0.415) | logic, entrenchment, conditional, semantic, defaul
#     T111 @ 2000→2001 best→T82 (sim=0.277) | retrieval, caption, captioned, anvil, natural_lang
#     T180 @ 2000→2001 best→T250 (sim=0.327) | homology, globular, corner, resp, positive, negati
#
#   🟢 STABLE (sim > 0.6, same ID): 3333 events
#   Per year:
#     2000: 39 topics
#     2001: 25 topics
#     2002: 17 topics
#     2003: 34 topics
#     2004: 32 topics
#     2005: 31 topics
#     2006: 30 topics
#     2007: 36 topics
#     2008: 35 topics
#     2009: 54 topics
#     2010: 56 topics
#     2011: 78 topics
#     2012: 87 topics
#     2013: 107 topics
#     2014: 132 topics
#     2015: 160 topics
#     2016: 191 topics
#     2017: 234 topics
#     2018: 241 topics
#     2019: 266 topics
#     2020: 281 topics
#     2021: 280 topics
#     2022: 291 topics
#     2023: 292 topics
#     2024: 304 topics
#
#   🔄 EVOLVE (0.2 < sim <= 0.6, same ID): 1512 events
#   Per year:
#     2000: 35 topics
#     2001: 51 topics
#     2002: 66 topics
#     2003: 69 topics
#     2004: 68 topics
#     2005: 75 topics
#     2006: 67 topics
#     2007: 71 topics
#     2008: 67 topics
#     2009: 73 topics
#     2010: 77 topics
#     2011: 95 topics
#     2012: 114 topics
#     2013: 90 topics
#     2014: 92 topics
#     2015: 96 topics
#     2016: 90 topics
#     2017: 57 topics
#     2018: 53 topics
#     2019: 36 topics
#     2020: 22 topics
#     2021: 22 topics
#     2022: 12 topics
#     2023: 13 topics
#     2024: 1 topics
#
#   📉 DISAPPEARED (sim <= 0.2): 547 events
#   Per year:
#     2000: 37 topics
#     2001: 35 topics
#     2002: 31 topics
#     2003: 32 topics
#     2004: 43 topics
#     2005: 52 topics
#     2006: 55 topics
#     2007: 47 topics
#     2008: 39 topics
#     2009: 31 topics
#     2010: 47 topics
#     2011: 16 topics
#     2012: 21 topics
#     2013: 20 topics
#     2014: 18 topics
#     2015: 9 topics
#     2016: 7 topics
#     2017: 3 topics
#     2018: 2 topics
#     2020: 2 topics
#
#   Permanently gone: 0
#
#   🆕 NEW TOPICS (no incoming sim > 0.2): 789 events
#   Per year:
#     2001: 40 new topics
#     2002: 52 new topics
#     2003: 47 new topics
#     2004: 55 new topics
#     2005: 48 new topics
#     2006: 52 new topics
#     2007: 61 new topics
#     2008: 51 new topics
#     2009: 50 new topics
#     2010: 57 new topics
#     2011: 57 new topics
#     2012: 55 new topics
#     2013: 33 new topics
#     2014: 34 new topics
#     2015: 47 new topics
#     2016: 23 new topics
#     2017: 15 new topics
#     2018: 6 new topics
#     2019: 3 new topics
#     2020: 1 new topics
#     2021: 1 new topics
#     2022: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T270 | 100% stable (12S 0Ev 0M 0Mm 0D)
#     T 33 | 100% stable (10S 0Ev 0M 0Mm 0D)
#     T243 | 100% stable (9S 0Ev 0M 0Mm 0D)
#     T123 | 100% stable (8S 0Ev 0M 0Mm 0D)
#     T 23 | 95% stable (20S 0Ev 1M 0Mm 0D)
#   Top 5 most unstable:
#     T154 | 21% stable (3S 6Ev 0M 1Mm 4D)
#     T289 | 19% stable (3S 9Ev 0M 0Mm 4D)
#     T253 | 17% stable (4S 17Ev 0M 2Mm 0D)
#     T250 | 16% stable (4S 18Ev 1M 0Mm 2D)
#     T 38 | 12% stable (3S 16Ev 2M 3Mm 0D)
#
#
# '======================================================================'
# Analysis Review: MATH (Top2Vec)
# '======================================================================'
#
#   🔗 MERGE (sim > 0.2, >1 source): 33 events
#   Top 10 merges (most sources):
#     T107 @ 2001 ← [98, 107] (sims=[0.2703, 0.6865]) | quantum, group, corepresentation, repres
#     T 74 @ 2002 ← [74, 144] (sims=[0.6755, 0.2703]) | cohomology, algebra, operad, coring, hom
#     T  7 @ 2002 ← [7, 78] (sims=[0.5916, 0.2703]) | diffeomorphism, entropy, fractal, measur
#     T178 @ 2003 ← [14, 178] (sims=[0.2703, 0.6715]) | spr, ortholattice, polynomial, orthogona
#     T 10 @ 2003 ← [10, 79] (sims=[0.516, 0.3956]) | operator, bnat, space, inequality, nyman
#     T 59 @ 2003 ← [59, 159] (sims=[0.426, 0.231]) | laplacian, boundary, eigenvalue, domain,
#     T117 @ 2003 ← [21, 117] (sims=[0.3661, 0.8133]) | periodic, function, convergence, oscilla
#     T 64 @ 2004 ← [64, 178] (sims=[0.6517, 0.2236]) | polynomial, orthogonal, unit_circle, fun
#     T 34 @ 2004 ← [34, 115] (sims=[0.3633, 0.2138]) | brownian_motion, space, levy, stochastic
#     T  4 @ 2004 ← [4, 156] (sims=[0.4239, 0.4406]) | boundary, domain, neumann, operator, ell
#
#   ⚠️  MISMATCH (sim > 0.2, target ID ≠ own ID): 33 events
#   Per year:
#     2000: 1 topics
#     2001: 2 topics
#     2002: 4 topics
#     2003: 5 topics
#     2004: 2 topics
#     2005: 4 topics
#     2006: 3 topics
#     2007: 4 topics
#     2008: 3 topics
#     2009: 2 topics
#     2010: 1 topics
#     2011: 1 topics
#     2012: 1 topics
#   Sample (up to 5):
#     T 98 @ 2000→2001 best→T107 (sim=0.270) | quantum, poly, measurement, locality, fisher_infor
#     T 78 @ 2001→2002 best→T7 (sim=0.270) | diffeomorphism, retract, flow, tanaka_webster, mea
#     T144 @ 2001→2002 best→T74 (sim=0.270) | cohomology, milnor, curving, gerbe, serre, bundle,
#     T 14 @ 2002→2003 best→T178 (sim=0.270) | spr, control, lineal, output_feedback, law, contro
#     T 21 @ 2002→2003 best→T117 (sim=0.366) | periodic, lienard, rfde, hamiltonian, nonlinear, v
#
#   🟢 STABLE (sim > 0.6, same ID): 3376 events
#   Per year:
#     2000: 54 topics
#     2001: 46 topics
#     2002: 65 topics
#     2003: 79 topics
#     2004: 68 topics
#     2005: 93 topics
#     2006: 93 topics
#     2007: 105 topics
#     2008: 111 topics
#     2009: 116 topics
#     2010: 124 topics
#     2011: 137 topics
#     2012: 151 topics
#     2013: 161 topics
#     2014: 165 topics
#     2015: 166 topics
#     2016: 172 topics
#     2017: 179 topics
#     2018: 182 topics
#     2019: 184 topics
#     2020: 179 topics
#     2021: 184 topics
#     2022: 185 topics
#     2023: 189 topics
#     2024: 188 topics
#
#   🔄 EVOLVE (0.2 < sim <= 0.6, same ID): 1090 events
#   Per year:
#     2000: 68 topics
#     2001: 80 topics
#     2002: 61 topics
#     2003: 61 topics
#     2004: 84 topics
#     2005: 72 topics
#     2006: 82 topics
#     2007: 71 topics
#     2008: 61 topics
#     2009: 70 topics
#     2010: 65 topics
#     2011: 55 topics
#     2012: 42 topics
#     2013: 35 topics
#     2014: 31 topics
#     2015: 30 topics
#     2016: 24 topics
#     2017: 17 topics
#     2018: 14 topics
#     2019: 12 topics
#     2020: 17 topics
#     2021: 12 topics
#     2022: 11 topics
#     2023: 7 topics
#     2024: 8 topics
#
#   📉 DISAPPEARED (sim <= 0.2): 140 events
#   Per year:
#     2000: 23 topics
#     2001: 25 topics
#     2002: 24 topics
#     2003: 14 topics
#     2004: 15 topics
#     2005: 7 topics
#     2006: 7 topics
#     2007: 6 topics
#     2008: 12 topics
#     2009: 3 topics
#     2010: 2 topics
#     2011: 1 topics
#     2012: 1 topics
#
#   Permanently gone: 0
#
#   🆕 NEW TOPICS (no incoming sim > 0.2): 191 events
#   Per year:
#     2001: 31 new topics
#     2002: 28 new topics
#     2003: 30 new topics
#     2004: 22 new topics
#     2005: 25 new topics
#     2006: 15 new topics
#     2007: 9 new topics
#     2008: 6 new topics
#     2009: 15 new topics
#     2010: 3 new topics
#     2011: 4 new topics
#     2012: 2 new topics
#     2013: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T 13 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T 16 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T 11 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T 31 | 100% stable (25S 0Ev 0M 0Mm 0D)
#   Top 5 most unstable:
#     T193 | 32% stable (6S 8Ev 0M 0Mm 5D)
#     T175 | 24% stable (6S 19Ev 0M 0Mm 0D)
#     T172 | 22% stable (5S 14Ev 0M 0Mm 4D)
#     T128 | 20% stable (5S 20Ev 0M 0Mm 0D)
#     T187 | 17% stable (4S 17Ev 0M 0Mm 2D)
#
#
# '======================================================================'
# Analysis Review: PHYSICS (Top2Vec)
# '======================================================================'
#
#   🔗 MERGE (sim > 0.2, >1 source): 68 events
#   Top 10 merges (most sources):
#     T 87 @ 2002 ← [59, 87, 108] (sims=[0.2896, 0.5904, 0.3198]) | frequency, clock, 199hg, optical, transi
#     T201 @ 2001 ← [65, 201] (sims=[0.3242, 0.8217]) | conversion, formaldehyde, spin, polycarb
#     T 11 @ 2001 ← [11, 185] (sims=[0.9242, 0.2686]) | beam, bessel, polarization, incoherent,
#     T 39 @ 2001 ← [37, 39] (sims=[0.2703, 0.6772]) | relativity, space, gravitational, quantu
#     T  7 @ 2001 ← [7, 189] (sims=[0.5624, 0.2503]) | geomagnetic, gps, ionosphere, strange, t
#     T 32 @ 2002 ← [14, 32] (sims=[0.2956, 0.6728]) | electromagnetic, gauge, field, maxwell,
#     T 24 @ 2002 ← [24, 124] (sims=[0.5003, 0.2703]) | drop, deltac, hump, deformable, selectiv
#     T 25 @ 2002 ← [16, 25] (sims=[0.3537, 0.7057]) | turbulence, flow, velocity, exponent, sc
#     T 94 @ 2002 ← [89, 94] (sims=[0.3943, 0.8264]) | beam, anzatze, subscale, bone, dynamical
#     T  3 @ 2003 ← [3, 22] (sims=[0.6552, 0.2703]) | detector, pixel, silicon, cdf, track, cm
#
#   ⚠️  MISMATCH (sim > 0.2, target ID ≠ own ID): 75 events
#   Per year:
#     2000: 8 topics
#     2001: 7 topics
#     2002: 7 topics
#     2003: 5 topics
#     2004: 9 topics
#     2005: 3 topics
#     2006: 5 topics
#     2007: 6 topics
#     2008: 9 topics
#     2009: 4 topics
#     2010: 1 topics
#     2011: 2 topics
#     2012: 1 topics
#     2013: 4 topics
#     2014: 1 topics
#     2015: 1 topics
#     2018: 1 topics
#     2021: 1 topics
#   Sample (up to 5):
#     T 37 @ 2000→2001 best→T39 (sim=0.270) | relativity, curriculum, excalc, programming, compu
#     T 65 @ 2000→2001 best→T201 (sim=0.324) | spin, cch4, mshg, conversion, ortho_para, ethylene
#     T129 @ 2000→2001 best→T193 (sim=0.309) | gallium, necrosis, reflectivity, laser, tissue, li
#     T152 @ 2000→2001 best→T26 (sim=0.270) | wire, transformer, polyphase, igbt, graneau, klyst
#     T180 @ 2000→2001 best→T165 (sim=0.270) | cavity, ttf, linac, evaporative_cooling, gradient,
#
#   🟢 STABLE (sim > 0.6, same ID): 3191 events
#   Per year:
#     2000: 61 topics
#     2001: 46 topics
#     2002: 36 topics
#     2003: 57 topics
#     2004: 60 topics
#     2005: 72 topics
#     2006: 81 topics
#     2007: 80 topics
#     2008: 86 topics
#     2009: 112 topics
#     2010: 131 topics
#     2011: 134 topics
#     2012: 135 topics
#     2013: 130 topics
#     2014: 152 topics
#     2015: 151 topics
#     2016: 163 topics
#     2017: 174 topics
#     2018: 186 topics
#     2019: 189 topics
#     2020: 191 topics
#     2021: 190 topics
#     2022: 190 topics
#     2023: 189 topics
#     2024: 195 topics
#
#   🔄 EVOLVE (0.2 < sim <= 0.6, same ID): 1269 events
#   Per year:
#     2000: 53 topics
#     2001: 78 topics
#     2002: 78 topics
#     2003: 69 topics
#     2004: 70 topics
#     2005: 79 topics
#     2006: 79 topics
#     2007: 92 topics
#     2008: 74 topics
#     2009: 72 topics
#     2010: 61 topics
#     2011: 57 topics
#     2012: 64 topics
#     2013: 59 topics
#     2014: 50 topics
#     2015: 50 topics
#     2016: 42 topics
#     2017: 30 topics
#     2018: 18 topics
#     2019: 17 topics
#     2020: 16 topics
#     2021: 15 topics
#     2022: 17 topics
#     2023: 18 topics
#     2024: 11 topics
#
#   📉 DISAPPEARED (sim <= 0.2): 248 events
#   Per year:
#     2000: 22 topics
#     2001: 22 topics
#     2002: 31 topics
#     2003: 32 topics
#     2004: 22 topics
#     2005: 24 topics
#     2006: 18 topics
#     2007: 12 topics
#     2008: 15 topics
#     2009: 6 topics
#     2010: 11 topics
#     2011: 9 topics
#     2012: 4 topics
#     2013: 8 topics
#     2014: 2 topics
#     2015: 3 topics
#     2016: 1 topics
#     2017: 3 topics
#     2018: 1 topics
#     2019: 1 topics
#     2024: 1 topics
#
#   Permanently gone: 1
#     T147 last @ 2024 (sim=0.148) | calendar, astronomical, catalogue, star, sundial,
#
#   🆕 NEW TOPICS (no incoming sim > 0.2): 324 events
#   Per year:
#     2001: 37 new topics
#     2002: 25 new topics
#     2003: 42 new topics
#     2004: 35 new topics
#     2005: 35 new topics
#     2006: 31 new topics
#     2007: 26 new topics
#     2008: 11 new topics
#     2009: 21 new topics
#     2010: 13 new topics
#     2011: 10 new topics
#     2012: 10 new topics
#     2013: 5 new topics
#     2014: 9 new topics
#     2015: 3 new topics
#     2016: 3 new topics
#     2017: 2 new topics
#     2018: 3 new topics
#     2019: 1 new topics
#     2020: 1 new topics
#     2025: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  5 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T 90 | 100% stable (16S 0Ev 0M 0Mm 0D)
#     T  9 | 96% stable (24S 0Ev 1M 0Mm 0D)
#     T 51 | 96% stable (24S 0Ev 1M 0Mm 0D)
#     T 64 | 96% stable (24S 1Ev 0M 0Mm 0D)
#   Top 5 most unstable:
#     T157 | 17% stable (4S 9Ev 0M 1Mm 9D)
#     T189 | 17% stable (4S 18Ev 0M 1Mm 1D)
#     T166 | 16% stable (4S 16Ev 0M 0Mm 5D)
#     T127 | 9% stable (2S 10Ev 0M 0Mm 10D)
#     T147 | 4% stable (1S 17Ev 0M 0Mm 4D)
