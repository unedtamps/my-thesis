# %% [markdown]
# # Top2Vec: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/top2vec/temporal")
RESULT_DIR = Path("../../../../results/top2vec/consistency")
THRESHOLD_LOW = 0.2   # below → disappear
THRESHOLD_HIGH = 0.5  # [0.3, 0.7) → evolve; >= 0.7 → stable

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold Low  (disappear): {THRESHOLD_LOW}")
print(f"Threshold High (stable)   : {THRESHOLD_HIGH}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold Low  (disappear): 0.2
# Threshold High (stable)   : 0.5
# Reading from: ../../../../results/top2vec/temporal
# Saving to: ../../../../results/top2vec/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t  = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for i, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for j, tid_t1 in enumerate(topics_t1):
                words_t1 = topic_words.get((t_next, tid_t1), [])
                sim_matrix[i, j] = rbo(words_t, words_t1, p=0.9)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map
        # Disappear : sim < THRESHOLD_LOW
        # Evolve    : THRESHOLD_LOW <= sim < THRESHOLD_HIGH, single source
        # Stable    : sim >= THRESHOLD_HIGH, single source
        # Merge     : sim >= THRESHOLD_LOW AND >1 source for same t+1-topic
        assignment = {}            # topic_t → best topic_t1 (or None)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD_LOW:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_evolve, n_merge, n_disappear = 0, 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target  = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] > 1:
                category = "merge"
                n_merge += 1
            elif sim_val >= THRESHOLD_HIGH:
                category = "stable"
                n_stable += 1
            else:
                category = "evolve"
                n_evolve += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new   = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_evolve": n_evolve, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable":    round(n_stable   / total_t * 100, 2),
            "pct_evolve":    round(n_evolve   / total_t * 100, 2),
            "pct_merge":     round(n_merge    / total_t * 100, 2),
            "pct_disappear": round(n_disappear/ total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Evolve={n_evolve} ({n_evolve/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject,
        "threshold_low": THRESHOLD_LOW, "threshold_high": THRESHOLD_HIGH,
        "avg_pct_stable":    round(subj_sum["pct_stable"].mean(),    2),
        "avg_pct_evolve":    round(subj_sum["pct_evolve"].mean(),    2),
        "avg_pct_merge":     round(subj_sum["pct_merge"].mean(),     2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new":          int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Evolve={overall['avg_pct_evolve']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=51 (41%)  Evolve=23 (18%)  Merge=14 (11%)  Disappear=37 (30%)  New=42
#   2001→2002: Stable=39 (32%)  Evolve=38 (31%)  Merge=11 (9%)  Disappear=35 (28%)  New=53
#   2002→2003: Stable=35 (26%)  Evolve=48 (36%)  Merge=21 (16%)  Disappear=31 (23%)  New=52
#   2003→2004: Stable=55 (38%)  Evolve=50 (34%)  Merge=8 (6%)  Disappear=32 (22%)  New=57
#   2004→2005: Stable=51 (31%)  Evolve=52 (31%)  Merge=20 (12%)  Disappear=43 (26%)  New=51
#   2005→2006: Stable=48 (29%)  Evolve=60 (37%)  Merge=4 (2%)  Disappear=52 (32%)  New=52
#   2006→2007: Stable=48 (30%)  Evolve=49 (30%)  Merge=10 (6%)  Disappear=55 (34%)  New=62
#   2007→2008: Stable=58 (36%)  Evolve=52 (32%)  Merge=6 (4%)  Disappear=47 (29%)  New=54
#   2008→2009: Stable=53 (32%)  Evolve=51 (31%)  Merge=24 (14%)  Disappear=39 (23%)  New=58
#   2009→2010: Stable=78 (45%)  Evolve=50 (29%)  Merge=15 (9%)  Disappear=31 (18%)  New=61
#   2010→2011: Stable=80 (41%)  Evolve=53 (27%)  Merge=16 (8%)  Disappear=47 (24%)  New=61
#   2011→2012: Stable=110 (54%)  Evolve=64 (32%)  Merge=12 (6%)  Disappear=16 (8%)  New=58
#   2012→2013: Stable=124 (52%)  Evolve=78 (33%)  Merge=15 (6%)  Disappear=21 (9%)  New=36
#   2013→2014: Stable=148 (60%)  Evolve=51 (21%)  Merge=26 (11%)  Disappear=20 (8%)  New=40
#   2014→2015: Stable=171 (68%)  Evolve=53 (21%)  Merge=10 (4%)  Disappear=18 (7%)  New=51
#   2015→2016: Stable=207 (74%)  Evolve=50 (18%)  Merge=14 (5%)  Disappear=9 (3%)  New=28
#   2016→2017: Stable=237 (81%)  Evolve=44 (15%)  Merge=4 (1%)  Disappear=7 (2%)  New=17
#   2017→2018: Stable=261 (87%)  Evolve=30 (10%)  Merge=6 (2%)  Disappear=3 (1%)  New=9
#   2018→2019: Stable=270 (89%)  Evolve=25 (8%)  Merge=6 (2%)  Disappear=2 (1%)  New=6
#   2019→2020: Stable=289 (95%)  Evolve=13 (4%)  Merge=2 (1%)  Disappear=0 (0%)  New=2
#   2020→2021: Stable=294 (96%)  Evolve=9 (3%)  Merge=0 (0%)  Disappear=2 (1%)  New=1
#   2021→2022: Stable=293 (96%)  Evolve=9 (3%)  Merge=2 (1%)  Disappear=0 (0%)  New=2
#   2022→2023: Stable=299 (98%)  Evolve=4 (1%)  Merge=2 (1%)  Disappear=0 (0%)  New=1
#   2023→2024: Stable=302 (99%)  Evolve=3 (1%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=304 (100%)  Evolve=1 (0%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=61.2%  Evolve=20.2%  Merge=5.4%  Disappear=13.1%  New=854
#   Saved: ../../../../results/top2vec/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (Top2Vec)
# ======================================================================
#   2000→2001: Stable=78 (53%)  Evolve=44 (30%)  Merge=2 (1%)  Disappear=23 (16%)  New=32
#   2001→2002: Stable=77 (50%)  Evolve=49 (32%)  Merge=4 (3%)  Disappear=25 (16%)  New=30
#   2002→2003: Stable=86 (54%)  Evolve=40 (25%)  Merge=8 (5%)  Disappear=24 (15%)  New=34
#   2003→2004: Stable=98 (60%)  Evolve=42 (26%)  Merge=10 (6%)  Disappear=14 (9%)  New=26
#   2004→2005: Stable=99 (58%)  Evolve=53 (31%)  Merge=4 (2%)  Disappear=15 (9%)  New=26
#   2005→2006: Stable=128 (71%)  Evolve=37 (21%)  Merge=8 (4%)  Disappear=7 (4%)  New=19
#   2006→2007: Stable=127 (68%)  Evolve=48 (26%)  Merge=6 (3%)  Disappear=7 (4%)  New=12
#   2007→2008: Stable=131 (69%)  Evolve=45 (24%)  Merge=8 (4%)  Disappear=6 (3%)  New=10
#   2008→2009: Stable=138 (73%)  Evolve=34 (18%)  Merge=6 (3%)  Disappear=12 (6%)  New=18
#   2009→2010: Stable=142 (74%)  Evolve=44 (23%)  Merge=4 (2%)  Disappear=3 (2%)  New=5
#   2010→2011: Stable=149 (77%)  Evolve=40 (21%)  Merge=2 (1%)  Disappear=2 (1%)  New=5
#   2011→2012: Stable=169 (87%)  Evolve=23 (12%)  Merge=2 (1%)  Disappear=1 (1%)  New=3
#   2012→2013: Stable=171 (87%)  Evolve=22 (11%)  Merge=2 (1%)  Disappear=1 (1%)  New=2
#   2013→2014: Stable=183 (93%)  Evolve=13 (7%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2014→2015: Stable=186 (95%)  Evolve=10 (5%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2015→2016: Stable=182 (93%)  Evolve=14 (7%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2016→2017: Stable=185 (94%)  Evolve=11 (6%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2017→2018: Stable=188 (96%)  Evolve=8 (4%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2018→2019: Stable=193 (98%)  Evolve=3 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=192 (98%)  Evolve=4 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=192 (98%)  Evolve=4 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=190 (97%)  Evolve=6 (3%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=193 (98%)  Evolve=3 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=193 (98%)  Evolve=3 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=192 (98%)  Evolve=4 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=81.5%  Evolve=13.6%  Merge=1.5%  Disappear=3.4%  New=222
#   Saved: ../../../../results/top2vec/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=77 (52%)  Evolve=41 (28%)  Merge=8 (5%)  Disappear=22 (15%)  New=36
#   2001→2002: Stable=77 (49%)  Evolve=48 (30%)  Merge=11 (7%)  Disappear=22 (14%)  New=29
#   2002→2003: Stable=58 (36%)  Evolve=56 (35%)  Merge=14 (9%)  Disappear=31 (19%)  New=47
#   2003→2004: Stable=81 (48%)  Evolve=45 (27%)  Merge=10 (6%)  Disappear=32 (19%)  New=39
#   2004→2005: Stable=90 (53%)  Evolve=40 (24%)  Merge=18 (11%)  Disappear=22 (13%)  New=42
#   2005→2006: Stable=101 (56%)  Evolve=50 (28%)  Merge=6 (3%)  Disappear=24 (13%)  New=34
#   2006→2007: Stable=113 (60%)  Evolve=47 (25%)  Merge=10 (5%)  Disappear=18 (10%)  New=30
#   2007→2008: Stable=115 (59%)  Evolve=58 (30%)  Merge=10 (5%)  Disappear=12 (6%)  New=15
#   2008→2009: Stable=112 (58%)  Evolve=48 (25%)  Merge=18 (9%)  Disappear=15 (8%)  New=29
#   2009→2010: Stable=138 (70%)  Evolve=46 (23%)  Merge=8 (4%)  Disappear=6 (3%)  New=17
#   2010→2011: Stable=153 (75%)  Evolve=39 (19%)  Merge=2 (1%)  Disappear=11 (5%)  New=11
#   2011→2012: Stable=163 (80%)  Evolve=28 (14%)  Merge=4 (2%)  Disappear=9 (4%)  New=12
#   2012→2013: Stable=164 (80%)  Evolve=35 (17%)  Merge=2 (1%)  Disappear=4 (2%)  New=5
#   2013→2014: Stable=156 (76%)  Evolve=33 (16%)  Merge=8 (4%)  Disappear=8 (4%)  New=13
#   2014→2015: Stable=170 (83%)  Evolve=32 (16%)  Merge=2 (1%)  Disappear=2 (1%)  New=3
#   2015→2016: Stable=175 (85%)  Evolve=26 (13%)  Merge=2 (1%)  Disappear=3 (1%)  New=4
#   2016→2017: Stable=189 (92%)  Evolve=16 (8%)  Merge=0 (0%)  Disappear=1 (0%)  New=2
#   2017→2018: Stable=194 (94%)  Evolve=10 (5%)  Merge=0 (0%)  Disappear=3 (1%)  New=3
#   2018→2019: Stable=195 (94%)  Evolve=9 (4%)  Merge=2 (1%)  Disappear=1 (0%)  New=2
#   2019→2020: Stable=202 (98%)  Evolve=4 (2%)  Merge=0 (0%)  Disappear=1 (0%)  New=1
#   2020→2021: Stable=201 (97%)  Evolve=6 (3%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=201 (97%)  Evolve=4 (2%)  Merge=2 (1%)  Disappear=0 (0%)  New=1
#   2022→2023: Stable=201 (97%)  Evolve=6 (3%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=202 (98%)  Evolve=5 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=200 (97%)  Evolve=6 (3%)  Merge=0 (0%)  Disappear=1 (0%)  New=1
#
#   Overall: Stable=75.3%  Evolve=16.0%  Merge=3.1%  Disappear=5.7%  New=376
#   Saved: ../../../../results/top2vec/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    trans_df   = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df   = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path   = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df     = pd.read_csv(new_path)   if new_path.stat().st_size   > 10 else pd.DataFrame()
    evo_df     = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED (sim < THRESHOLD_LOW) ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED (sim < {THRESHOLD_LOW}): {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid   = int(r["topic_id"])
            later = evo_df[(evo_df["topic_id"] == tid) & (evo_df["year"] > int(r["year_to"]))]
            if len(later) == 0:
                w = str(r["words"])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- EVOLVE (THRESHOLD_LOW <= sim < THRESHOLD_HIGH, single source) ---
    evolved = trans_df[trans_df["category"] == "evolve"]
    print(f"\n  🔄 EVOLVE ({THRESHOLD_LOW} <= sim < {THRESHOLD_HIGH}): {len(evolved)} events")
    if len(evolved) > 0:
        per_year = evolved.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

    # --- MERGE GROUPS (>1 source, sim >= THRESHOLD_LOW) ---
    print(f"\n  🔗 MERGE GROUPS (sim >= {THRESHOLD_LOW}, >1 source): {len(merge_df)} events")
    if len(merge_df) > 0:
        print("  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, "n_sources").iterrows():
            w = str(r["target_words"])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print("\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "evolve", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print("  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev {int(r['merge'])}M {int(r['disappear'])}D)")
    print("  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED (sim < 0.2): 547 events
#   Per year:
#     2000: 37 topics
#     2001: 35 topics
#     2002: 31 topics
#     2003: 32 topics
#     2004: 43 topics
#     2005: 52 topics
#     2006: 55 topics
#     2007: 47 topics
#     2008: 39 topics
#     2009: 31 topics
#     2010: 47 topics
#     2011: 16 topics
#     2012: 21 topics
#     2013: 20 topics
#     2014: 18 topics
#     2015: 9 topics
#     2016: 7 topics
#     2017: 3 topics
#     2018: 2 topics
#     2020: 2 topics
#
#   Permanently gone: 0
#
#   🔄 EVOLVE (0.2 <= sim < 0.5): 960 events
#   Per year:
#     2000: 23 topics
#     2001: 38 topics
#     2002: 48 topics
#     2003: 50 topics
#     2004: 52 topics
#     2005: 60 topics
#     2006: 49 topics
#     2007: 52 topics
#     2008: 51 topics
#     2009: 50 topics
#     2010: 53 topics
#     2011: 64 topics
#     2012: 78 topics
#     2013: 51 topics
#     2014: 53 topics
#     2015: 50 topics
#     2016: 44 topics
#     2017: 30 topics
#     2018: 25 topics
#     2019: 13 topics
#     2020: 9 topics
#     2021: 9 topics
#     2022: 4 topics
#     2023: 3 topics
#     2024: 1 topics
#
#   🔗 MERGE GROUPS (sim >= 0.2, >1 source): 121 events
#   Top 10 merges (most sources):
#     T246 @ 2002 ← [18, 145, 246] (sims=[0.209, 0.2372, 0.3147]) | cable, internet, access, incumbent, broa
#     T218 @ 2003 ← [60, 120, 218] (sims=[0.2703, 0.2703, 0.7099]) | rbf, rbfs, manifold, gmst, geodesic, rad
#     T  7 @ 2007 ← [7, 176, 230] (sims=[0.2703, 0.2703, 0.3756]) | functional, teacher, perceptron, general
#     T 99 @ 2007 ← [58, 99, 182] (sims=[0.4406, 0.692, 0.2236]) | network, routing, wireless, sensor, node
#     T178 @ 2010 ← [47, 136, 178] (sims=[0.4676, 0.3998, 0.5859]) | query, database, schema, datum, relation
#     T122 @ 2013 ← [20, 118, 122] (sims=[0.3372, 0.3503, 0.2607]) | robot, arm, motion, dof, manipulator, co
#     T 49 @ 2001 ← [28, 49] (sims=[0.2198, 0.5653]) | grammar, xml, circularity, language, red
#     T 79 @ 2001 ← [38, 79] (sims=[0.2703, 0.4472]) | agent, maxi, observable, game, cooperati
#     T 50 @ 2001 ← [50, 288] (sims=[0.5884, 0.2686]) | program, debugger, debugging, aadebug, r
#     T 55 @ 2001 ← [55, 76] (sims=[0.8938, 0.4147]) | logic, program, programming, termination
#
#   🆕 NEW TOPICS: 854 events
#   Per year:
#     2001: 42 new topics
#     2002: 53 new topics
#     2003: 52 new topics
#     2004: 57 new topics
#     2005: 51 new topics
#     2006: 52 new topics
#     2007: 62 new topics
#     2008: 54 new topics
#     2009: 58 new topics
#     2010: 61 new topics
#     2011: 61 new topics
#     2012: 58 new topics
#     2013: 36 new topics
#     2014: 40 new topics
#     2015: 51 new topics
#     2016: 28 new topics
#     2017: 17 new topics
#     2018: 9 new topics
#     2019: 6 new topics
#     2020: 2 new topics
#     2021: 1 new topics
#     2022: 2 new topics
#     2023: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T270 | 100% stable (12S 0Ev 0M 0D)
#     T273 | 100% stable (8S 0Ev 0M 0D)
#     T 33 | 100% stable (10S 0Ev 0M 0D)
#     T298 | 100% stable (11S 0Ev 0M 0D)
#     T243 | 100% stable (9S 0Ev 0M 0D)
#   Top 5 most unstable:
#     T154 | 36% stable (5S 4Ev 1M 4D)
#     T263 | 36% stable (5S 5Ev 1M 3D)
#     T160 | 35% stable (8S 8Ev 0M 7D)
#     T250 | 24% stable (6S 16Ev 1M 2D)
#     T229 | 24% stable (6S 13Ev 0M 6D)
#
#
# ======================================================================
# Analysis Review: MATH (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED (sim < 0.2): 140 events
#   Per year:
#     2000: 23 topics
#     2001: 25 topics
#     2002: 24 topics
#     2003: 14 topics
#     2004: 15 topics
#     2005: 7 topics
#     2006: 7 topics
#     2007: 6 topics
#     2008: 12 topics
#     2009: 3 topics
#     2010: 2 topics
#     2011: 1 topics
#     2012: 1 topics
#
#   Permanently gone: 0
#
#   🔄 EVOLVE (0.2 <= sim < 0.5): 604 events
#   Per year:
#     2000: 44 topics
#     2001: 49 topics
#     2002: 40 topics
#     2003: 42 topics
#     2004: 53 topics
#     2005: 37 topics
#     2006: 48 topics
#     2007: 45 topics
#     2008: 34 topics
#     2009: 44 topics
#     2010: 40 topics
#     2011: 23 topics
#     2012: 22 topics
#     2013: 13 topics
#     2014: 10 topics
#     2015: 14 topics
#     2016: 11 topics
#     2017: 8 topics
#     2018: 3 topics
#     2019: 4 topics
#     2020: 4 topics
#     2021: 6 topics
#     2022: 3 topics
#     2023: 3 topics
#     2024: 4 topics
#
#   🔗 MERGE GROUPS (sim >= 0.2, >1 source): 33 events
#   Top 10 merges (most sources):
#     T107 @ 2001 ← [98, 107] (sims=[0.2703, 0.6865]) | quantum, group, corepresentation, repres
#     T  7 @ 2002 ← [7, 78] (sims=[0.5916, 0.2703]) | diffeomorphism, entropy, fractal, measur
#     T 74 @ 2002 ← [74, 144] (sims=[0.6755, 0.2703]) | cohomology, algebra, operad, coring, hom
#     T 10 @ 2003 ← [10, 79] (sims=[0.516, 0.3956]) | operator, bnat, space, inequality, nyman
#     T178 @ 2003 ← [14, 178] (sims=[0.2703, 0.6715]) | spr, ortholattice, polynomial, orthogona
#     T117 @ 2003 ← [21, 117] (sims=[0.3661, 0.8133]) | periodic, function, convergence, oscilla
#     T 59 @ 2003 ← [59, 159] (sims=[0.426, 0.231]) | laplacian, boundary, eigenvalue, domain,
#     T  4 @ 2004 ← [4, 156] (sims=[0.4239, 0.4406]) | boundary, domain, neumann, operator, ell
#     T 40 @ 2004 ← [10, 40] (sims=[0.2703, 0.5727]) | operator, self_adjoint, convolution, dil
#     T 30 @ 2004 ← [30, 170] (sims=[0.6234, 0.3526]) | group, finite, automorphism, subgroup, c
#
#   🆕 NEW TOPICS: 222 events
#   Per year:
#     2001: 32 new topics
#     2002: 30 new topics
#     2003: 34 new topics
#     2004: 26 new topics
#     2005: 26 new topics
#     2006: 19 new topics
#     2007: 12 new topics
#     2008: 10 new topics
#     2009: 18 new topics
#     2010: 5 new topics
#     2011: 5 new topics
#     2012: 3 new topics
#     2013: 2 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0Ev 0M 0D)
#     T 13 | 100% stable (25S 0Ev 0M 0D)
#     T  9 | 100% stable (25S 0Ev 0M 0D)
#     T 11 | 100% stable (25S 0Ev 0M 0D)
#     T 55 | 100% stable (25S 0Ev 0M 0D)
#   Top 5 most unstable:
#     T174 | 54% stable (12S 7Ev 0M 3D)
#     T172 | 48% stable (11S 8Ev 0M 4D)
#     T133 | 46% stable (11S 10Ev 0M 3D)
#     T187 | 44% stable (10S 11Ev 0M 2D)
#     T175 | 40% stable (10S 15Ev 0M 0D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED (sim < 0.2): 248 events
#   Per year:
#     2000: 22 topics
#     2001: 22 topics
#     2002: 31 topics
#     2003: 32 topics
#     2004: 22 topics
#     2005: 24 topics
#     2006: 18 topics
#     2007: 12 topics
#     2008: 15 topics
#     2009: 6 topics
#     2010: 11 topics
#     2011: 9 topics
#     2012: 4 topics
#     2013: 8 topics
#     2014: 2 topics
#     2015: 3 topics
#     2016: 1 topics
#     2017: 3 topics
#     2018: 1 topics
#     2019: 1 topics
#     2024: 1 topics
#
#   Permanently gone: 1
#     T147 last @ 2024 (sim=0.148) | calendar, astronomical, catalogue, star, sundial,
#
#   🔄 EVOLVE (0.2 <= sim < 0.5): 738 events
#   Per year:
#     2000: 41 topics
#     2001: 48 topics
#     2002: 56 topics
#     2003: 45 topics
#     2004: 40 topics
#     2005: 50 topics
#     2006: 47 topics
#     2007: 58 topics
#     2008: 48 topics
#     2009: 46 topics
#     2010: 39 topics
#     2011: 28 topics
#     2012: 35 topics
#     2013: 33 topics
#     2014: 32 topics
#     2015: 26 topics
#     2016: 16 topics
#     2017: 10 topics
#     2018: 9 topics
#     2019: 4 topics
#     2020: 6 topics
#     2021: 4 topics
#     2022: 6 topics
#     2023: 5 topics
#     2024: 6 topics
#
#   🔗 MERGE GROUPS (sim >= 0.2, >1 source): 68 events
#   Top 10 merges (most sources):
#     T 87 @ 2002 ← [59, 87, 108] (sims=[0.2896, 0.5904, 0.3198]) | frequency, clock, 199hg, optical, transi
#     T  7 @ 2001 ← [7, 189] (sims=[0.5624, 0.2503]) | geomagnetic, gps, ionosphere, strange, t
#     T 11 @ 2001 ← [11, 185] (sims=[0.9242, 0.2686]) | beam, bessel, polarization, incoherent,
#     T 39 @ 2001 ← [37, 39] (sims=[0.2703, 0.6772]) | relativity, space, gravitational, quantu
#     T201 @ 2001 ← [65, 201] (sims=[0.3242, 0.8217]) | conversion, formaldehyde, spin, polycarb
#     T 32 @ 2002 ← [14, 32] (sims=[0.2956, 0.6728]) | electromagnetic, gauge, field, maxwell,
#     T 25 @ 2002 ← [16, 25] (sims=[0.3537, 0.7057]) | turbulence, flow, velocity, exponent, sc
#     T 24 @ 2002 ← [24, 124] (sims=[0.5003, 0.2703]) | drop, deltac, hump, deformable, selectiv
#     T 94 @ 2002 ← [89, 94] (sims=[0.3943, 0.8264]) | beam, anzatze, subscale, bone, dynamical
#     T  3 @ 2003 ← [3, 22] (sims=[0.6552, 0.2703]) | detector, pixel, silicon, cdf, track, cm
#
#   🆕 NEW TOPICS: 376 events
#   Per year:
#     2001: 36 new topics
#     2002: 29 new topics
#     2003: 47 new topics
#     2004: 39 new topics
#     2005: 42 new topics
#     2006: 34 new topics
#     2007: 30 new topics
#     2008: 15 new topics
#     2009: 29 new topics
#     2010: 17 new topics
#     2011: 11 new topics
#     2012: 12 new topics
#     2013: 5 new topics
#     2014: 13 new topics
#     2015: 3 new topics
#     2016: 4 new topics
#     2017: 2 new topics
#     2018: 3 new topics
#     2019: 2 new topics
#     2020: 1 new topics
#     2022: 1 new topics
#     2025: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  5 | 100% stable (25S 0Ev 0M 0D)
#     T 12 | 100% stable (25S 0Ev 0M 0D)
#     T 34 | 100% stable (25S 0Ev 0M 0D)
#     T 54 | 100% stable (25S 0Ev 0M 0D)
#     T 92 | 100% stable (25S 0Ev 0M 0D)
#   Top 5 most unstable:
#     T197 | 35% stable (6S 5Ev 1M 5D)
#     T166 | 32% stable (8S 12Ev 0M 5D)
#     T127 | 32% stable (7S 5Ev 0M 10D)
#     T147 | 32% stable (7S 11Ev 0M 4D)
#     T157 | 26% stable (6S 7Ev 1M 9D)
