# %% [markdown]
# # Top2Vec: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/top2vec/temporal")
RESULT_DIR = Path("../../../../results/top2vec/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/top2vec/temporal
# Saving to: ../../../../results/top2vec/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for i, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for j, tid_t1 in enumerate(topics_t1):
                words_t1 = topic_words.get((t_next, tid_t1), [])
                sim_matrix[i, j] = rbo(words_t, words_t1, p=0.9)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=57 (50%)  Merge=0 (0%)  Disappear=56 (50%)  New=61
#   2001→2002: Stable=62 (53%)  Merge=0 (0%)  Disappear=56 (47%)  New=70
#   2002→2003: Stable=73 (55%)  Merge=0 (0%)  Disappear=59 (45%)  New=69
#   2003→2004: Stable=77 (54%)  Merge=0 (0%)  Disappear=65 (46%)  New=81
#   2004→2005: Stable=74 (47%)  Merge=2 (1%)  Disappear=82 (52%)  New=90
#   2005→2006: Stable=71 (43%)  Merge=2 (1%)  Disappear=92 (56%)  New=82
#   2006→2007: Stable=73 (47%)  Merge=0 (0%)  Disappear=81 (53%)  New=87
#   2007→2008: Stable=89 (56%)  Merge=0 (0%)  Disappear=71 (44%)  New=73
#   2008→2009: Stable=82 (51%)  Merge=0 (0%)  Disappear=80 (49%)  New=88
#   2009→2010: Stable=104 (61%)  Merge=0 (0%)  Disappear=66 (39%)  New=83
#   2010→2011: Stable=120 (64%)  Merge=0 (0%)  Disappear=67 (36%)  New=79
#   2011→2012: Stable=148 (74%)  Merge=0 (0%)  Disappear=51 (26%)  New=87
#   2012→2013: Stable=169 (72%)  Merge=2 (1%)  Disappear=64 (27%)  New=82
#   2013→2014: Stable=195 (77%)  Merge=0 (0%)  Disappear=57 (23%)  New=52
#   2014→2015: Stable=206 (83%)  Merge=4 (2%)  Disappear=37 (15%)  New=68
#   2015→2016: Stable=245 (89%)  Merge=0 (0%)  Disappear=31 (11%)  New=47
#   2016→2017: Stable=274 (94%)  Merge=0 (0%)  Disappear=18 (6%)  New=24
#   2017→2018: Stable=288 (97%)  Merge=0 (0%)  Disappear=10 (3%)  New=16
#   2018→2019: Stable=298 (98%)  Merge=0 (0%)  Disappear=6 (2%)  New=10
#   2019→2020: Stable=303 (98%)  Merge=0 (0%)  Disappear=5 (2%)  New=4
#   2020→2021: Stable=302 (98%)  Merge=0 (0%)  Disappear=5 (2%)  New=5
#   2021→2022: Stable=306 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=2
#   2022→2023: Stable=308 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2023→2024: Stable=309 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=309 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=74.5%  Merge=0.2%  Disappear=25.3%  New=1261
#   Saved: ../../../../results/top2vec/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (Top2Vec)
# ======================================================================
#   2000→2001: Stable=88 (60%)  Merge=0 (0%)  Disappear=59 (40%)  New=67
#   2001→2002: Stable=102 (66%)  Merge=0 (0%)  Disappear=53 (34%)  New=56
#   2002→2003: Stable=112 (71%)  Merge=0 (0%)  Disappear=46 (29%)  New=52
#   2003→2004: Stable=134 (82%)  Merge=0 (0%)  Disappear=30 (18%)  New=37
#   2004→2005: Stable=141 (82%)  Merge=0 (0%)  Disappear=30 (18%)  New=39
#   2005→2006: Stable=157 (87%)  Merge=0 (0%)  Disappear=23 (13%)  New=31
#   2006→2007: Stable=166 (88%)  Merge=0 (0%)  Disappear=22 (12%)  New=24
#   2007→2008: Stable=171 (90%)  Merge=0 (0%)  Disappear=19 (10%)  New=19
#   2008→2009: Stable=173 (91%)  Merge=0 (0%)  Disappear=17 (9%)  New=20
#   2009→2010: Stable=184 (95%)  Merge=0 (0%)  Disappear=9 (5%)  New=9
#   2010→2011: Stable=188 (97%)  Merge=0 (0%)  Disappear=5 (3%)  New=7
#   2011→2012: Stable=190 (97%)  Merge=0 (0%)  Disappear=5 (3%)  New=6
#   2012→2013: Stable=193 (98%)  Merge=0 (0%)  Disappear=3 (2%)  New=3
#   2013→2014: Stable=195 (99%)  Merge=0 (0%)  Disappear=1 (1%)  New=1
#   2014→2015: Stable=195 (99%)  Merge=0 (0%)  Disappear=1 (1%)  New=1
#   2015→2016: Stable=196 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2016→2017: Stable=196 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2017→2018: Stable=196 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2018→2019: Stable=196 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=196 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=196 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=196 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=195 (99%)  Merge=0 (0%)  Disappear=1 (1%)  New=1
#   2023→2024: Stable=196 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=196 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=92.2%  Merge=0.0%  Disappear=7.8%  New=373
#   Saved: ../../../../results/top2vec/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=95 (64%)  Merge=0 (0%)  Disappear=53 (36%)  New=63
#   2001→2002: Stable=105 (66%)  Merge=2 (1%)  Disappear=51 (32%)  New=53
#   2002→2003: Stable=97 (61%)  Merge=0 (0%)  Disappear=62 (39%)  New=71
#   2003→2004: Stable=116 (69%)  Merge=0 (0%)  Disappear=52 (31%)  New=54
#   2004→2005: Stable=123 (72%)  Merge=0 (0%)  Disappear=47 (28%)  New=58
#   2005→2006: Stable=142 (78%)  Merge=0 (0%)  Disappear=39 (22%)  New=46
#   2006→2007: Stable=154 (82%)  Merge=0 (0%)  Disappear=34 (18%)  New=41
#   2007→2008: Stable=159 (82%)  Merge=0 (0%)  Disappear=36 (18%)  New=34
#   2008→2009: Stable=158 (82%)  Merge=0 (0%)  Disappear=35 (18%)  New=40
#   2009→2010: Stable=176 (89%)  Merge=0 (0%)  Disappear=22 (11%)  New=29
#   2010→2011: Stable=187 (91%)  Merge=0 (0%)  Disappear=18 (9%)  New=17
#   2011→2012: Stable=188 (92%)  Merge=0 (0%)  Disappear=16 (8%)  New=17
#   2012→2013: Stable=196 (96%)  Merge=0 (0%)  Disappear=9 (4%)  New=9
#   2013→2014: Stable=192 (94%)  Merge=0 (0%)  Disappear=13 (6%)  New=14
#   2014→2015: Stable=198 (96%)  Merge=0 (0%)  Disappear=8 (4%)  New=8
#   2015→2016: Stable=199 (97%)  Merge=0 (0%)  Disappear=7 (3%)  New=7
#   2016→2017: Stable=202 (98%)  Merge=0 (0%)  Disappear=4 (2%)  New=5
#   2017→2018: Stable=204 (99%)  Merge=0 (0%)  Disappear=3 (1%)  New=3
#   2018→2019: Stable=205 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=2
#   2019→2020: Stable=204 (99%)  Merge=0 (0%)  Disappear=3 (1%)  New=3
#   2020→2021: Stable=207 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=206 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=1
#   2022→2023: Stable=207 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=206 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=1
#   2024→2025: Stable=206 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=1
#
#   Overall: Stable=88.2%  Merge=0.1%  Disappear=11.8%  New=577
#   Saved: ../../../../results/top2vec/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 1060 events
#   Per year:
#     2000: 56 topics
#     2001: 56 topics
#     2002: 59 topics
#     2003: 65 topics
#     2004: 82 topics
#     2005: 92 topics
#     2006: 81 topics
#     2007: 71 topics
#     2008: 80 topics
#     2009: 66 topics
#     2010: 67 topics
#     2011: 51 topics
#     2012: 64 topics
#     2013: 57 topics
#     2014: 37 topics
#     2015: 31 topics
#     2016: 18 topics
#     2017: 10 topics
#     2018: 6 topics
#     2019: 5 topics
#     2020: 5 topics
#     2021: 1 topics
#
#   Permanently gone: 0
#
#   🔗 MERGE GROUPS: 5 events
#   Top 10 merges (most sources):
#     T 37 @ 2005 ← [37, 170] (sims=[0.8101, 0.6165]) | games, game, equilibria, nash, player, e
#     T137 @ 2006 ← [64, 137] (sims=[0.5127, 0.819]) | query, queries, relational, data, databa
#     T137 @ 2013 ← [137, 166] (sims=[0.9159, 0.6256]) | query, queries, data, datalog, relationa
#     T 37 @ 2015 ← [37, 170] (sims=[0.9434, 0.6674]) | games, game, players, nash, player, equi
#     T113 @ 2015 ← [113, 250] (sims=[0.6815, 0.5472]) | anomaly, detection, outlierness, outlyin
#
#   🆕 NEW TOPICS: 1261 events
#   Per year:
#     2001: 61 new topics
#     2002: 70 new topics
#     2003: 69 new topics
#     2004: 81 new topics
#     2005: 90 new topics
#     2006: 82 new topics
#     2007: 87 new topics
#     2008: 73 new topics
#     2009: 88 new topics
#     2010: 83 new topics
#     2011: 79 new topics
#     2012: 87 new topics
#     2013: 82 new topics
#     2014: 52 new topics
#     2015: 68 new topics
#     2016: 47 new topics
#     2017: 24 new topics
#     2018: 16 new topics
#     2019: 10 new topics
#     2020: 4 new topics
#     2021: 5 new topics
#     2022: 2 new topics
#     2023: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T285 | 100% stable (12S 0M 0D)
#     T280 | 100% stable (9S 0M 0D)
#     T 16 | 100% stable (10S 0M 0D)
#     T 18 | 100% stable (25S 0M 0D)
#     T 26 | 100% stable (24S 0M 0D)
#   Top 5 most unstable:
#     T174 | 50% stable (8S 0M 8D)
#     T204 | 48% stable (12S 0M 13D)
#     T205 | 47% stable (9S 0M 10D)
#     T192 | 47% stable (7S 0M 8D)
#     T218 | 44% stable (7S 0M 9D)
#
#
# ======================================================================
# Analysis Review: MATH (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 324 events
#   Per year:
#     2000: 59 topics
#     2001: 53 topics
#     2002: 46 topics
#     2003: 30 topics
#     2004: 30 topics
#     2005: 23 topics
#     2006: 22 topics
#     2007: 19 topics
#     2008: 17 topics
#     2009: 9 topics
#     2010: 5 topics
#     2011: 5 topics
#     2012: 3 topics
#     2013: 1 topics
#     2014: 1 topics
#     2022: 1 topics
#
#   Permanently gone: 0
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 373 events
#   Per year:
#     2001: 67 new topics
#     2002: 56 new topics
#     2003: 52 new topics
#     2004: 37 new topics
#     2005: 39 new topics
#     2006: 31 new topics
#     2007: 24 new topics
#     2008: 19 new topics
#     2009: 20 new topics
#     2010: 9 new topics
#     2011: 7 new topics
#     2012: 6 new topics
#     2013: 3 new topics
#     2014: 1 new topics
#     2015: 1 new topics
#     2023: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0M 0D)
#     T  2 | 100% stable (25S 0M 0D)
#     T  9 | 100% stable (25S 0M 0D)
#     T  7 | 100% stable (25S 0M 0D)
#     T 60 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 91 | 74% stable (14S 0M 5D)
#     T193 | 74% stable (14S 0M 5D)
#     T174 | 73% stable (16S 0M 6D)
#     T 50 | 72% stable (18S 0M 7D)
#     T 33 | 62% stable (10S 0M 6D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 517 events
#   Per year:
#     2000: 53 topics
#     2001: 51 topics
#     2002: 62 topics
#     2003: 52 topics
#     2004: 47 topics
#     2005: 39 topics
#     2006: 34 topics
#     2007: 36 topics
#     2008: 35 topics
#     2009: 22 topics
#     2010: 18 topics
#     2011: 16 topics
#     2012: 9 topics
#     2013: 13 topics
#     2014: 8 topics
#     2015: 7 topics
#     2016: 4 topics
#     2017: 3 topics
#     2018: 2 topics
#     2019: 3 topics
#     2021: 1 topics
#     2023: 1 topics
#     2024: 1 topics
#
#   Permanently gone: 1
#     T147 last @ 2024 (sim=0.443) | astronomical, calendar, century, sun, astronomy, m
#
#   🔗 MERGE GROUPS: 1 events
#   Top 10 merges (most sources):
#     T 25 @ 2002 ← [16, 25] (sims=[0.5179, 0.782]) | turbulence, turbulent, flow, velocity, f
#
#   🆕 NEW TOPICS: 577 events
#   Per year:
#     2001: 63 new topics
#     2002: 53 new topics
#     2003: 71 new topics
#     2004: 54 new topics
#     2005: 58 new topics
#     2006: 46 new topics
#     2007: 41 new topics
#     2008: 34 new topics
#     2009: 40 new topics
#     2010: 29 new topics
#     2011: 17 new topics
#     2012: 17 new topics
#     2013: 9 new topics
#     2014: 14 new topics
#     2015: 8 new topics
#     2016: 7 new topics
#     2017: 5 new topics
#     2018: 3 new topics
#     2019: 2 new topics
#     2020: 3 new topics
#     2022: 1 new topics
#     2024: 1 new topics
#     2025: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0M 0D)
#     T  1 | 100% stable (25S 0M 0D)
#     T  3 | 100% stable (25S 0M 0D)
#     T  5 | 100% stable (25S 0M 0D)
#     T  4 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 63 | 50% stable (12S 0M 12D)
#     T 38 | 46% stable (10S 0M 12D)
#     T197 | 41% stable (7S 0M 10D)
#     T127 | 41% stable (9S 0M 13D)
#     T157 | 39% stable (9S 0M 14D)
