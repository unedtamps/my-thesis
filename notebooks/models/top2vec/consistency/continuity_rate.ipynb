# %% [markdown]
# # Top2Vec: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/top2vec/temporal")
RESULT_DIR = Path("../../../../results/top2vec/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/top2vec/temporal
# Saving to: ../../../../results/top2vec/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def build_word_matrix(topic_ids, topic_words_dict, year, vocab_index):
    matrix = np.zeros((len(topic_ids), len(vocab_index)))
    for i, tid in enumerate(topic_ids):
        words = topic_words_dict.get((year, tid), [])
        for w in words:
            if w in vocab_index:
                matrix[i, vocab_index[w]] = 1.0
    return matrix

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_words = set()
    for words in topic_words.values():
        all_words.update(words)
    vocab_index = {w: i for i, w in enumerate(sorted(all_words))}

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        mat_t = build_word_matrix(topics_t, topic_words, t, vocab_index)
        mat_t1 = build_word_matrix(topics_t1, topic_words, t_next, vocab_index)
        sim_matrix = cosine_similarity(mat_t, mat_t1)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=2 (2%)  Merge=0 (0%)  Disappear=104 (98%)  New=106
#   2001→2002: Stable=4 (4%)  Merge=0 (0%)  Disappear=104 (96%)  New=116
#   2002→2003: Stable=1 (1%)  Merge=0 (0%)  Disappear=119 (99%)  New=126
#   2003→2004: Stable=1 (1%)  Merge=0 (0%)  Disappear=126 (99%)  New=141
#   2004→2005: Stable=4 (3%)  Merge=0 (0%)  Disappear=138 (97%)  New=139
#   2005→2006: Stable=5 (3%)  Merge=0 (0%)  Disappear=138 (97%)  New=136
#   2006→2007: Stable=3 (2%)  Merge=0 (0%)  Disappear=138 (98%)  New=145
#   2007→2008: Stable=6 (4%)  Merge=0 (0%)  Disappear=142 (96%)  New=134
#   2008→2009: Stable=8 (6%)  Merge=0 (0%)  Disappear=132 (94%)  New=144
#   2009→2010: Stable=9 (6%)  Merge=0 (0%)  Disappear=143 (94%)  New=160
#   2010→2011: Stable=7 (4%)  Merge=2 (1%)  Disappear=160 (95%)  New=168
#   2011→2012: Stable=14 (8%)  Merge=0 (0%)  Disappear=162 (92%)  New=186
#   2012→2013: Stable=19 (10%)  Merge=0 (0%)  Disappear=181 (90%)  New=194
#   2013→2014: Stable=22 (10%)  Merge=0 (0%)  Disappear=191 (90%)  New=193
#   2014→2015: Stable=26 (12%)  Merge=0 (0%)  Disappear=189 (88%)  New=211
#   2015→2016: Stable=45 (19%)  Merge=0 (0%)  Disappear=192 (81%)  New=198
#   2016→2017: Stable=51 (21%)  Merge=0 (0%)  Disappear=192 (79%)  New=198
#   2017→2018: Stable=75 (30%)  Merge=8 (3%)  Disappear=166 (67%)  New=172
#   2018→2019: Stable=106 (42%)  Merge=10 (4%)  Disappear=135 (54%)  New=143
#   2019→2020: Stable=151 (60%)  Merge=2 (1%)  Disappear=100 (40%)  New=101
#   2020→2021: Stable=172 (68%)  Merge=4 (2%)  Disappear=77 (30%)  New=78
#   2021→2022: Stable=173 (69%)  Merge=10 (4%)  Disappear=69 (27%)  New=75
#   2022→2023: Stable=165 (65%)  Merge=10 (4%)  Disappear=78 (31%)  New=83
#   2023→2024: Stable=203 (80%)  Merge=2 (1%)  Disappear=48 (19%)  New=49
#   2024→2025: Stable=208 (82%)  Merge=4 (2%)  Disappear=41 (16%)  New=43
#
#   Overall: Stable=24.5%  Merge=0.8%  Disappear=74.7%  New=3439
#   Saved: ../../../../results/top2vec/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (Top2Vec)
# ======================================================================
#   2000→2001: Stable=1 (1%)  Merge=0 (0%)  Disappear=154 (99%)  New=162
#   2001→2002: Stable=4 (2%)  Merge=0 (0%)  Disappear=159 (98%)  New=160
#   2002→2003: Stable=3 (2%)  Merge=0 (0%)  Disappear=161 (98%)  New=170
#   2003→2004: Stable=7 (4%)  Merge=2 (1%)  Disappear=164 (95%)  New=175
#   2004→2005: Stable=5 (3%)  Merge=0 (0%)  Disappear=178 (97%)  New=184
#   2005→2006: Stable=18 (10%)  Merge=0 (0%)  Disappear=171 (90%)  New=179
#   2006→2007: Stable=19 (10%)  Merge=0 (0%)  Disappear=178 (90%)  New=183
#   2007→2008: Stable=20 (10%)  Merge=0 (0%)  Disappear=182 (90%)  New=184
#   2008→2009: Stable=23 (11%)  Merge=4 (2%)  Disappear=177 (87%)  New=184
#   2009→2010: Stable=36 (17%)  Merge=0 (0%)  Disappear=173 (83%)  New=173
#   2010→2011: Stable=36 (17%)  Merge=3 (1%)  Disappear=170 (81%)  New=173
#   2011→2012: Stable=44 (21%)  Merge=4 (2%)  Disappear=162 (77%)  New=165
#   2012→2013: Stable=61 (29%)  Merge=6 (3%)  Disappear=144 (68%)  New=146
#   2013→2014: Stable=68 (32%)  Merge=0 (0%)  Disappear=142 (68%)  New=143
#   2014→2015: Stable=83 (39%)  Merge=2 (1%)  Disappear=126 (60%)  New=127
#   2015→2016: Stable=95 (45%)  Merge=2 (1%)  Disappear=114 (54%)  New=114
#   2016→2017: Stable=96 (46%)  Merge=6 (3%)  Disappear=108 (51%)  New=112
#   2017→2018: Stable=99 (47%)  Merge=4 (2%)  Disappear=108 (51%)  New=110
#   2018→2019: Stable=91 (43%)  Merge=10 (5%)  Disappear=110 (52%)  New=115
#   2019→2020: Stable=107 (51%)  Merge=2 (1%)  Disappear=102 (48%)  New=103
#   2020→2021: Stable=118 (56%)  Merge=8 (4%)  Disappear=85 (40%)  New=89
#   2021→2022: Stable=116 (55%)  Merge=12 (6%)  Disappear=83 (39%)  New=89
#   2022→2023: Stable=116 (55%)  Merge=10 (5%)  Disappear=85 (40%)  New=90
#   2023→2024: Stable=131 (62%)  Merge=10 (5%)  Disappear=70 (33%)  New=75
#   2024→2025: Stable=145 (69%)  Merge=8 (4%)  Disappear=58 (27%)  New=62
#
#   Overall: Stable=29.4%  Merge=1.8%  Disappear=68.8%  New=3467
#   Saved: ../../../../results/top2vec/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=2 (1%)  Merge=0 (0%)  Disappear=140 (99%)  New=153
#   2001→2002: Stable=5 (3%)  Merge=0 (0%)  Disappear=150 (97%)  New=153
#   2002→2003: Stable=6 (4%)  Merge=0 (0%)  Disappear=152 (96%)  New=157
#   2003→2004: Stable=5 (3%)  Merge=0 (0%)  Disappear=158 (97%)  New=167
#   2004→2005: Stable=9 (5%)  Merge=0 (0%)  Disappear=163 (95%)  New=174
#   2005→2006: Stable=17 (9%)  Merge=0 (0%)  Disappear=166 (91%)  New=167
#   2006→2007: Stable=17 (9%)  Merge=0 (0%)  Disappear=167 (91%)  New=174
#   2007→2008: Stable=24 (13%)  Merge=0 (0%)  Disappear=167 (87%)  New=164
#   2008→2009: Stable=24 (13%)  Merge=0 (0%)  Disappear=164 (87%)  New=172
#   2009→2010: Stable=31 (16%)  Merge=0 (0%)  Disappear=165 (84%)  New=173
#   2010→2011: Stable=47 (23%)  Merge=0 (0%)  Disappear=157 (77%)  New=153
#   2011→2012: Stable=55 (28%)  Merge=4 (2%)  Disappear=141 (70%)  New=144
#   2012→2013: Stable=67 (33%)  Merge=0 (0%)  Disappear=134 (67%)  New=134
#   2013→2014: Stable=73 (36%)  Merge=0 (0%)  Disappear=128 (64%)  New=129
#   2014→2015: Stable=82 (41%)  Merge=0 (0%)  Disappear=120 (59%)  New=121
#   2015→2016: Stable=80 (39%)  Merge=0 (0%)  Disappear=123 (61%)  New=123
#   2016→2017: Stable=98 (48%)  Merge=0 (0%)  Disappear=105 (52%)  New=106
#   2017→2018: Stable=93 (46%)  Merge=2 (1%)  Disappear=109 (53%)  New=109
#   2018→2019: Stable=103 (51%)  Merge=0 (0%)  Disappear=100 (49%)  New=101
#   2019→2020: Stable=111 (54%)  Merge=2 (1%)  Disappear=91 (45%)  New=92
#   2020→2021: Stable=119 (58%)  Merge=0 (0%)  Disappear=85 (42%)  New=85
#   2021→2022: Stable=119 (58%)  Merge=5 (2%)  Disappear=80 (39%)  New=83
#   2022→2023: Stable=122 (60%)  Merge=0 (0%)  Disappear=82 (40%)  New=82
#   2023→2024: Stable=124 (61%)  Merge=4 (2%)  Disappear=76 (37%)  New=78
#   2024→2025: Stable=142 (70%)  Merge=2 (1%)  Disappear=60 (29%)  New=61
#
#   Overall: Stable=31.3%  Merge=0.4%  Disappear=68.3%  New=3255
#   Saved: ../../../../results/top2vec/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 3265 events
#   Per year:
#     2000: 104 topics
#     2001: 104 topics
#     2002: 119 topics
#     2003: 126 topics
#     2004: 138 topics
#     2005: 138 topics
#     2006: 138 topics
#     2007: 142 topics
#     2008: 132 topics
#     2009: 143 topics
#     2010: 160 topics
#     2011: 162 topics
#     2012: 181 topics
#     2013: 191 topics
#     2014: 189 topics
#     2015: 192 topics
#     2016: 192 topics
#     2017: 166 topics
#     2018: 135 topics
#     2019: 100 topics
#     2020: 77 topics
#     2021: 69 topics
#     2022: 78 topics
#     2023: 48 topics
#     2024: 41 topics
#
#   Permanently gone: 41
#     T 34 last @ 2024 (sim=0.400) | channel, coding, converse, optimal, channels, info
#     T 54 last @ 2024 (sim=0.400) | varepsilon, signal, sparse, log, tilde, reconstruc
#     T 59 last @ 2024 (sim=0.400) | entropy, perp, information, divergences, mathbb, i
#     T 71 last @ 2024 (sim=0.300) | bier, packet, network, networking, queue, flows, l
#     T 74 last @ 2024 (sim=0.400) | sat, varphi, nae, polynomial, mathsf, satisfiabili
#     T 97 last @ 2024 (sim=0.400) | log, communication, leader, agents, protocols, gra
#     T104 last @ 2024 (sim=0.300) | security, authentication, secure, attack, wireless
#     T128 last @ 2024 (sim=0.400) | parsing, language, syntactic, garden, parsers, gra
#     T130 last @ 2024 (sim=0.300) | relational, query, queries, hcq, database, swp, fr
#     T133 last @ 2024 (sim=0.400) | log, varepsilon, plbf, frac, algorithm, hash, algo
#     ... +31 more
#
#   🔗 MERGE GROUPS: 25 events
#   Top 10 merges (most sources):
#     T 39 @ 2019 ← [39, 80, 137, 152] (sims=[0.9, 0.5, 0.5, 0.6]) | convolutional, neural, networks, deep, i
#     T 34 @ 2011 ← [34, 145] (sims=[0.8, 0.5]) | channel, coding, rate, region, broadcast
#     T 21 @ 2018 ← [21, 33] (sims=[0.8, 0.5]) | neural, networks, deep, learning, mathbf
#     T 25 @ 2018 ← [25, 79] (sims=[0.8, 0.5]) | games, game, equilibrium, players, nash,
#     T 29 @ 2018 ← [29, 172] (sims=[0.7, 0.5]) | social, twitter, media, political, users
#     T136 @ 2018 ← [136, 173] (sims=[0.7, 0.5]) | face, facial, recognition, images, age,
#     T 16 @ 2019 ← [16, 154] (sims=[0.5, 0.5]) | neural, differential, equations, learnin
#     T 25 @ 2019 ← [25, 79] (sims=[0.8, 0.5]) | games, game, nash, equilibrium, equilibr
#     T108 @ 2019 ← [108, 211] (sims=[0.5, 0.5]) | anomaly, detection, anomalies, data, nor
#     T 30 @ 2020 ← [30, 105] (sims=[0.7, 0.8]) | gradient, stochastic, convex, convergenc
#
#   🆕 NEW TOPICS: 3439 events
#   Per year:
#     2001: 106 new topics
#     2002: 116 new topics
#     2003: 126 new topics
#     2004: 141 new topics
#     2005: 139 new topics
#     2006: 136 new topics
#     2007: 145 new topics
#     2008: 134 new topics
#     2009: 144 new topics
#     2010: 160 new topics
#     2011: 168 new topics
#     2012: 186 new topics
#     2013: 194 new topics
#     2014: 193 new topics
#     2015: 211 new topics
#     2016: 198 new topics
#     2017: 198 new topics
#     2018: 172 new topics
#     2019: 143 new topics
#     2020: 101 new topics
#     2021: 78 new topics
#     2022: 75 new topics
#     2023: 83 new topics
#     2024: 49 new topics
#     2025: 43 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 36 | 90% stable (9S 0M 1D)
#     T  8 | 86% stable (19S 0M 3D)
#     T  1 | 76% stable (19S 0M 6D)
#     T102 | 75% stable (18S 0M 6D)
#     T235 | 75% stable (9S 0M 3D)
#   Top 5 most unstable:
#     T223 | 0% stable (0S 0M 25D)
#     T239 | 0% stable (0S 0M 15D)
#     T250 | 0% stable (0S 0M 10D)
#     T251 | 0% stable (0S 0M 19D)
#     T252 | 0% stable (0S 0M 20D)
#
#
# ======================================================================
# Analysis Review: MATH (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 3364 events
#   Per year:
#     2000: 154 topics
#     2001: 159 topics
#     2002: 161 topics
#     2003: 164 topics
#     2004: 178 topics
#     2005: 171 topics
#     2006: 178 topics
#     2007: 182 topics
#     2008: 177 topics
#     2009: 173 topics
#     2010: 170 topics
#     2011: 162 topics
#     2012: 144 topics
#     2013: 142 topics
#     2014: 126 topics
#     2015: 114 topics
#     2016: 108 topics
#     2017: 108 topics
#     2018: 110 topics
#     2019: 102 topics
#     2020: 85 topics
#     2021: 83 topics
#     2022: 85 topics
#     2023: 70 topics
#     2024: 58 topics
#
#   Permanently gone: 58
#     T 38 last @ 2024 (sim=0.400) | lie, poisson, algebras, symplectic, mathcal, quant
#     T 55 last @ 2024 (sim=0.400) | mathcal, gauge, operatorname, bps, theory, theorie
#     T 63 last @ 2024 (sim=0.400) | mathbb, polynomials, polynomial, ldots, mathrm, pe
#     T 77 last @ 2024 (sim=0.400) | hopf, algebras, braided, algebra, module, categori
#     T 78 last @ 2024 (sim=0.400) | log, mathop, riemann, frac, zeta, mathcal, li, fun
#     T 93 last @ 2024 (sim=0.400) | inequality, inequalities, frac, log, convex, conve
#     T 94 last @ 2024 (sim=0.400) | method, quadrature, numerical, accuracy, fast, pol
#     T 96 last @ 2024 (sim=0.400) | mathbb, mfib, frac, pm, mathsf, left, geq, right,
#     T 97 last @ 2024 (sim=0.400) | hamiltonian, nonholonomic, systems, port, lie, ham
#     T106 last @ 2024 (sim=0.400) | time, test, data, series, detection, high, change,
#     ... +48 more
#
#   🔗 MERGE GROUPS: 46 events
#   Top 10 merges (most sources):
#     T 18 @ 2011 ← [18, 28, 35] (sims=[0.6, 0.5, 0.6]) | hler, manifolds, einstein, metrics, curv
#     T 18 @ 2004 ← [18, 35] (sims=[0.6, 0.5]) | kaehler, einstein, manifolds, kahler, hl
#     T 14 @ 2009 ← [14, 69] (sims=[0.6, 0.5]) | curvature, surfaces, hypersurfaces, surf
#     T 18 @ 2009 ← [18, 28] (sims=[0.5, 0.5]) | hler, manifolds, kahler, metrics, einste
#     T 18 @ 2012 ← [18, 28] (sims=[0.7, 0.5]) | hler, manifolds, kaehler, manifold, herm
#     T 41 @ 2012 ← [41, 107] (sims=[0.8, 0.5]) | processes, process, vy, brownian, time,
#     T  6 @ 2013 ← [6, 39] (sims=[0.6, 0.5]) | graphs, graph, vertices, overrightarrow,
#     T  8 @ 2013 ← [8, 143] (sims=[0.6, 0.5]) | modules, rr, ring, axs, rings, ideal, ma
#     T 24 @ 2013 ← [24, 173] (sims=[0.6, 0.5]) | navier, stokes, incompressible, equation
#     T 42 @ 2015 ← [42, 88] (sims=[0.5, 0.5]) | mathcal, operators, operator, mathbb, or
#
#   🆕 NEW TOPICS: 3467 events
#   Per year:
#     2001: 162 new topics
#     2002: 160 new topics
#     2003: 170 new topics
#     2004: 175 new topics
#     2005: 184 new topics
#     2006: 179 new topics
#     2007: 183 new topics
#     2008: 184 new topics
#     2009: 184 new topics
#     2010: 173 new topics
#     2011: 173 new topics
#     2012: 165 new topics
#     2013: 146 new topics
#     2014: 143 new topics
#     2015: 127 new topics
#     2016: 114 new topics
#     2017: 112 new topics
#     2018: 110 new topics
#     2019: 115 new topics
#     2020: 103 new topics
#     2021: 89 new topics
#     2022: 89 new topics
#     2023: 90 new topics
#     2024: 75 new topics
#     2025: 62 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 10 | 88% stable (22S 0M 3D)
#     T  8 | 84% stable (21S 1M 3D)
#     T 18 | 80% stable (20S 4M 1D)
#     T 27 | 80% stable (20S 0M 5D)
#     T  1 | 76% stable (19S 2M 4D)
#   Top 5 most unstable:
#     T196 | 0% stable (0S 0M 23D)
#     T202 | 0% stable (0S 0M 20D)
#     T206 | 0% stable (0S 0M 17D)
#     T208 | 0% stable (0S 0M 23D)
#     T207 | 0% stable (0S 0M 21D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 3183 events
#   Per year:
#     2000: 140 topics
#     2001: 150 topics
#     2002: 152 topics
#     2003: 158 topics
#     2004: 163 topics
#     2005: 166 topics
#     2006: 167 topics
#     2007: 167 topics
#     2008: 164 topics
#     2009: 165 topics
#     2010: 157 topics
#     2011: 141 topics
#     2012: 134 topics
#     2013: 128 topics
#     2014: 120 topics
#     2015: 123 topics
#     2016: 105 topics
#     2017: 109 topics
#     2018: 100 topics
#     2019: 91 topics
#     2020: 85 topics
#     2021: 80 topics
#     2022: 82 topics
#     2023: 76 topics
#     2024: 60 topics
#
#   Permanently gone: 60
#     T 37 last @ 2024 (sim=0.300) | gauge, group, mathbb, algebra, quantum, su, vec, f
#     T 39 last @ 2024 (sim=0.400) | quantum, bose, condensation, einstein, polaron, fe
#     T 47 last @ 2024 (sim=0.400) | plasma, discharge, electron, discharges, divertor,
#     T 48 last @ 2024 (sim=0.300) | scattering, ultracold, collisions, energy, collisi
#     T 52 last @ 2024 (sim=0.400) | text, water, hydrogen, mixtures, liquid, molecular
#     T 59 last @ 2024 (sim=0.300) | graphene, carbon, materials, ir13, gfet, bng, adhe
#     T 66 last @ 2024 (sim=0.200) | uncertainty, data, uncertainties, uq, hpb, likelih
#     T 70 last @ 2024 (sim=0.300) | population, prey, predator, species, mbox, allee,
#     T 77 last @ 2024 (sim=0.300) | hamiltonian, mechanics, systems, mathcal, fractons
#     T 86 last @ 2024 (sim=0.300) | knitted, elastic, design, elasticity, stress, stra
#     ... +50 more
#
#   🔗 MERGE GROUPS: 9 events
#   Top 10 merges (most sources):
#     T 64 @ 2022 ← [7, 12, 64] (sims=[0.7, 0.8, 0.7]) | learning, neural, machine, data, deep, t
#     T 35 @ 2012 ← [21, 35] (sims=[0.5, 0.5]) | turbulent, flow, flows, shear, reynolds,
#     T 39 @ 2012 ← [39, 130] (sims=[0.6, 0.5]) | bose, condensate, einstein, vortex, cond
#     T  1 @ 2020 ← [1, 95] (sims=[0.6, 0.5]) | optical, comb, soliton, frequency, combs
#     T 91 @ 2018 ← [65, 91] (sims=[0.5, 0.7]) | electron, xfel, laser, beam, ray, fel, p
#     T  5 @ 2022 ← [5, 54] (sims=[0.8, 0.5]) | atoms, optical, quantum, atomic, atom, l
#     T 35 @ 2024 ← [35, 97] (sims=[0.8, 0.5]) | wall, flow, turbulent, reynolds, turbule
#     T136 @ 2024 ← [57, 136] (sims=[0.5, 0.9]) | battery, batteries, lithium, ion, electr
#     T  3 @ 2025 ← [3, 81] (sims=[0.7, 0.5]) | plasmonic, metasurfaces, dielectric, opt
#
#   🆕 NEW TOPICS: 3255 events
#   Per year:
#     2001: 153 new topics
#     2002: 153 new topics
#     2003: 157 new topics
#     2004: 167 new topics
#     2005: 174 new topics
#     2006: 167 new topics
#     2007: 174 new topics
#     2008: 164 new topics
#     2009: 172 new topics
#     2010: 173 new topics
#     2011: 153 new topics
#     2012: 144 new topics
#     2013: 134 new topics
#     2014: 129 new topics
#     2015: 121 new topics
#     2016: 123 new topics
#     2017: 106 new topics
#     2018: 109 new topics
#     2019: 101 new topics
#     2020: 92 new topics
#     2021: 85 new topics
#     2022: 83 new topics
#     2023: 82 new topics
#     2024: 78 new topics
#     2025: 61 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  5 | 96% stable (24S 1M 0D)
#     T 62 | 90% stable (19S 0M 2D)
#     T 25 | 88% stable (22S 0M 3D)
#     T 29 | 84% stable (21S 0M 4D)
#     T104 | 83% stable (15S 0M 3D)
#   Top 5 most unstable:
#     T173 | 0% stable (0S 0M 20D)
#     T195 | 0% stable (0S 0M 25D)
#     T191 | 0% stable (0S 0M 24D)
#     T199 | 0% stable (0S 0M 22D)
#     T200 | 0% stable (0S 0M 24D)
