# %% [markdown]
# # Top2Vec: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/top2vec/temporal")
RESULT_DIR = Path("../../../../results/top2vec/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/top2vec/temporal
# Saving to: ../../../../results/top2vec/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def build_word_matrix(topic_ids, topic_words_dict, year, vocab_index):
    matrix = np.zeros((len(topic_ids), len(vocab_index)))
    for i, tid in enumerate(topic_ids):
        words = topic_words_dict.get((year, tid), [])
        for w in words:
            if w in vocab_index:
                matrix[i, vocab_index[w]] = 1.0
    return matrix

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_words = set()
    for words in topic_words.values():
        all_words.update(words)
    vocab_index = {w: i for i, w in enumerate(sorted(all_words))}

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        mat_t = build_word_matrix(topics_t, topic_words, t, vocab_index)
        mat_t1 = build_word_matrix(topics_t1, topic_words, t_next, vocab_index)
        sim_matrix = cosine_similarity(mat_t, mat_t1)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=59 (54%)  Merge=0 (0%)  Disappear=50 (46%)  New=52
#   2001→2002: Stable=63 (57%)  Merge=0 (0%)  Disappear=48 (43%)  New=61
#   2002→2003: Stable=69 (56%)  Merge=0 (0%)  Disappear=55 (44%)  New=56
#   2003→2004: Stable=77 (62%)  Merge=0 (0%)  Disappear=48 (38%)  New=74
#   2004→2005: Stable=88 (58%)  Merge=2 (1%)  Disappear=61 (40%)  New=65
#   2005→2006: Stable=86 (56%)  Merge=0 (0%)  Disappear=68 (44%)  New=61
#   2006→2007: Stable=78 (53%)  Merge=0 (0%)  Disappear=69 (47%)  New=66
#   2007→2008: Stable=84 (58%)  Merge=0 (0%)  Disappear=60 (42%)  New=68
#   2008→2009: Stable=91 (60%)  Merge=0 (0%)  Disappear=61 (40%)  New=69
#   2009→2010: Stable=114 (71%)  Merge=0 (0%)  Disappear=46 (29%)  New=58
#   2010→2011: Stable=118 (69%)  Merge=2 (1%)  Disappear=52 (30%)  New=65
#   2011→2012: Stable=147 (80%)  Merge=0 (0%)  Disappear=37 (20%)  New=62
#   2012→2013: Stable=167 (80%)  Merge=0 (0%)  Disappear=42 (20%)  New=52
#   2013→2014: Stable=183 (84%)  Merge=0 (0%)  Disappear=36 (16%)  New=40
#   2014→2015: Stable=196 (88%)  Merge=0 (0%)  Disappear=27 (12%)  New=46
#   2015→2016: Stable=223 (92%)  Merge=0 (0%)  Disappear=19 (8%)  New=25
#   2016→2017: Stable=238 (96%)  Merge=0 (0%)  Disappear=10 (4%)  New=15
#   2017→2018: Stable=249 (98%)  Merge=0 (0%)  Disappear=4 (2%)  New=8
#   2018→2019: Stable=254 (99%)  Merge=0 (0%)  Disappear=3 (1%)  New=5
#   2019→2020: Stable=258 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=0
#   2020→2021: Stable=256 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=2
#   2021→2022: Stable=258 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2022→2023: Stable=258 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=1
#   2023→2024: Stable=259 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=259 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=78.7%  Merge=0.1%  Disappear=21.2%  New=952
#   Saved: ../../../../results/top2vec/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (Top2Vec)
# ======================================================================
#   2000→2001: Stable=104 (69%)  Merge=0 (0%)  Disappear=46 (31%)  New=57
#   2001→2002: Stable=106 (66%)  Merge=0 (0%)  Disappear=55 (34%)  New=51
#   2002→2003: Stable=121 (77%)  Merge=0 (0%)  Disappear=36 (23%)  New=44
#   2003→2004: Stable=135 (82%)  Merge=0 (0%)  Disappear=30 (18%)  New=45
#   2004→2005: Stable=147 (82%)  Merge=2 (1%)  Disappear=31 (17%)  New=38
#   2005→2006: Stable=160 (86%)  Merge=2 (1%)  Disappear=24 (13%)  New=34
#   2006→2007: Stable=174 (89%)  Merge=0 (0%)  Disappear=21 (11%)  New=26
#   2007→2008: Stable=181 (90%)  Merge=0 (0%)  Disappear=19 (10%)  New=20
#   2008→2009: Stable=182 (91%)  Merge=0 (0%)  Disappear=19 (9%)  New=21
#   2009→2010: Stable=186 (92%)  Merge=2 (1%)  Disappear=15 (7%)  New=19
#   2010→2011: Stable=199 (97%)  Merge=0 (0%)  Disappear=7 (3%)  New=9
#   2011→2012: Stable=204 (98%)  Merge=0 (0%)  Disappear=4 (2%)  New=4
#   2012→2013: Stable=204 (98%)  Merge=0 (0%)  Disappear=4 (2%)  New=4
#   2013→2014: Stable=206 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=2
#   2014→2015: Stable=206 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=3
#   2015→2016: Stable=208 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=0
#   2016→2017: Stable=207 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=2
#   2017→2018: Stable=205 (98%)  Merge=2 (1%)  Disappear=2 (1%)  New=3
#   2018→2019: Stable=209 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=209 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=209 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=209 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=209 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=209 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=209 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=92.5%  Merge=0.2%  Disappear=7.4%  New=382
#   Saved: ../../../../results/top2vec/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (Top2Vec)
# ======================================================================
#   2000→2001: Stable=106 (71%)  Merge=0 (0%)  Disappear=44 (29%)  New=54
#   2001→2002: Stable=114 (71%)  Merge=0 (0%)  Disappear=46 (29%)  New=50
#   2002→2003: Stable=105 (64%)  Merge=2 (1%)  Disappear=57 (35%)  New=61
#   2003→2004: Stable=127 (76%)  Merge=0 (0%)  Disappear=40 (24%)  New=49
#   2004→2005: Stable=134 (76%)  Merge=0 (0%)  Disappear=42 (24%)  New=52
#   2005→2006: Stable=148 (80%)  Merge=2 (1%)  Disappear=36 (19%)  New=41
#   2006→2007: Stable=165 (87%)  Merge=0 (0%)  Disappear=25 (13%)  New=35
#   2007→2008: Stable=167 (84%)  Merge=2 (1%)  Disappear=31 (16%)  New=27
#   2008→2009: Stable=164 (84%)  Merge=0 (0%)  Disappear=31 (16%)  New=39
#   2009→2010: Stable=181 (89%)  Merge=2 (1%)  Disappear=20 (10%)  New=27
#   2010→2011: Stable=196 (94%)  Merge=0 (0%)  Disappear=13 (6%)  New=10
#   2011→2012: Stable=192 (93%)  Merge=0 (0%)  Disappear=14 (7%)  New=16
#   2012→2013: Stable=201 (97%)  Merge=0 (0%)  Disappear=7 (3%)  New=5
#   2013→2014: Stable=199 (97%)  Merge=0 (0%)  Disappear=7 (3%)  New=9
#   2014→2015: Stable=203 (98%)  Merge=0 (0%)  Disappear=5 (2%)  New=6
#   2015→2016: Stable=205 (98%)  Merge=0 (0%)  Disappear=4 (2%)  New=4
#   2016→2017: Stable=207 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=3
#   2017→2018: Stable=208 (99%)  Merge=0 (0%)  Disappear=2 (1%)  New=2
#   2018→2019: Stable=209 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=1
#   2019→2020: Stable=210 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=210 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=210 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=210 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=210 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=209 (100%)  Merge=0 (0%)  Disappear=1 (0%)  New=1
#
#   Overall: Stable=90.2%  Merge=0.2%  Disappear=9.7%  New=492
#   Saved: ../../../../results/top2vec/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (Top2Vec)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 800 events
#   Per year:
#     2000: 50 topics
#     2001: 48 topics
#     2002: 55 topics
#     2003: 48 topics
#     2004: 61 topics
#     2005: 68 topics
#     2006: 69 topics
#     2007: 60 topics
#     2008: 61 topics
#     2009: 46 topics
#     2010: 52 topics
#     2011: 37 topics
#     2012: 42 topics
#     2013: 36 topics
#     2014: 27 topics
#     2015: 19 topics
#     2016: 10 topics
#     2017: 4 topics
#     2018: 3 topics
#     2019: 1 topics
#     2020: 2 topics
#     2022: 1 topics
#   Permanently gone: 0
#
#   🔗 MERGE GROUPS: 2 events
#   Top 10 merges (most sources):
#     T116 @ 2005 ← [116, 127] (sims=[0.8, 0.6]) | query, queries, data, relational, databa
#     T 94 @ 2011 ← [94, 130] (sims=[0.9, 0.5]) | log, agents, problem, time, nodes, distr
#
#   🆕 NEW TOPICS: 952 events
#   Per year:
#     2001: 52 new topics
#     2002: 61 new topics
#     2003: 56 new topics
#     2004: 74 new topics
#     2005: 65 new topics
#     2006: 61 new topics
#     2007: 66 new topics
#     2008: 68 new topics
#     2009: 69 new topics
#     2010: 58 new topics
#     2011: 65 new topics
#     2012: 62 new topics
#     2013: 52 new topics
#     2014: 40 new topics
#     2015: 46 new topics
#     2016: 25 new topics
#     2017: 15 new topics
#     2018: 8 new topics
#     2019: 5 new topics
#     2021: 2 new topics
#     2022: 1 new topics
#     2023: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T238 | 100% stable (14S 0M 0D)
#     T237 | 100% stable (12S 0M 0D)
#     T229 | 100% stable (12S 0M 0D)
#     T 31 | 100% stable (10S 0M 0D)
#     T 35 | 100% stable (24S 0M 0D)
#   Top 5 most unstable:
#     T258 | 55% stable (11S 0M 9D)
#     T234 | 55% stable (11S 0M 9D)
#     T220 | 53% stable (9S 0M 8D)
#     T177 | 53% stable (10S 0M 9D)
#     T147 | 50% stable (12S 0M 12D)
#
#
# ======================================================================
# Analysis Review: MATH (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 319 events
#   Per year:
#     2000: 46 topics
#     2001: 55 topics
#     2002: 36 topics
#     2003: 30 topics
#     2004: 31 topics
#     2005: 24 topics
#     2006: 21 topics
#     2007: 19 topics
#     2008: 19 topics
#     2009: 15 topics
#     2010: 7 topics
#     2011: 4 topics
#     2012: 4 topics
#     2013: 2 topics
#     2014: 2 topics
#     2015: 1 topics
#     2016: 1 topics
#     2017: 2 topics
#
#   Permanently gone: 0
#
#   🔗 MERGE GROUPS: 4 events
#   Top 10 merges (most sources):
#     T  0 @ 2005 ← [0, 204] (sims=[0.9, 0.5]) | equation, solutions, equations, wave, di
#     T 21 @ 2006 ← [21, 28] (sims=[0.8, 0.5]) | stochastic, noise, equations, equation,
#     T  4 @ 2010 ← [4, 151] (sims=[1.0, 0.6]) | lie, mathfrak, algebras, algebra, module
#     T  6 @ 2018 ← [6, 206] (sims=[0.8, 0.5]) | graphs, graph, gg, vertices, vertex, edg
#
#   🆕 NEW TOPICS: 382 events
#   Per year:
#     2001: 57 new topics
#     2002: 51 new topics
#     2003: 44 new topics
#     2004: 45 new topics
#     2005: 38 new topics
#     2006: 34 new topics
#     2007: 26 new topics
#     2008: 20 new topics
#     2009: 21 new topics
#     2010: 19 new topics
#     2011: 9 new topics
#     2012: 4 new topics
#     2013: 4 new topics
#     2014: 2 new topics
#     2015: 3 new topics
#     2017: 2 new topics
#     2018: 3 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  1 | 100% stable (25S 0M 0D)
#     T 14 | 100% stable (25S 0M 0D)
#     T  3 | 100% stable (25S 0M 0D)
#     T  7 | 100% stable (25S 0M 0D)
#     T  8 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T126 | 73% stable (16S 0M 6D)
#     T179 | 73% stable (16S 0M 6D)
#     T 97 | 72% stable (18S 0M 7D)
#     T206 | 71% stable (15S 1M 5D)
#     T189 | 68% stable (17S 0M 8D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (Top2Vec)
# ======================================================================
#
#   📉 DISAPPEARED: 428 events
#   Per year:
#     2000: 44 topics
#     2001: 46 topics
#     2002: 57 topics
#     2003: 40 topics
#     2004: 42 topics
#     2005: 36 topics
#     2006: 25 topics
#     2007: 31 topics
#     2008: 31 topics
#     2009: 20 topics
#     2010: 13 topics
#     2011: 14 topics
#     2012: 7 topics
#     2013: 7 topics
#     2014: 5 topics
#     2015: 4 topics
#     2016: 2 topics
#     2017: 2 topics
#     2018: 1 topics
#     2024: 1 topics
#
#   Permanently gone: 1
#     T153 last @ 2024 (sim=0.400) | astronomical, calendar, century, moon, sun, astron
#
#   🔗 MERGE GROUPS: 4 events
#   Top 10 merges (most sources):
#     T 25 @ 2003 ← [3, 25] (sims=[0.5, 0.9]) | atoms, atom, atomic, quantum, optical, p
#     T  9 @ 2006 ← [9, 75] (sims=[0.8, 0.5]) | imaging, image, optical, images, diffrac
#     T 37 @ 2008 ← [37, 183] (sims=[0.9, 0.5]) | students, student, education, physics, l
#     T 37 @ 2010 ← [37, 183] (sims=[0.8, 0.6]) | students, physics, student, learning, ed
#
#   🆕 NEW TOPICS: 492 events
#   Per year:
#     2001: 54 new topics
#     2002: 50 new topics
#     2003: 61 new topics
#     2004: 49 new topics
#     2005: 52 new topics
#     2006: 41 new topics
#     2007: 35 new topics
#     2008: 27 new topics
#     2009: 39 new topics
#     2010: 27 new topics
#     2011: 10 new topics
#     2012: 16 new topics
#     2013: 5 new topics
#     2014: 9 new topics
#     2015: 6 new topics
#     2016: 4 new topics
#     2017: 3 new topics
#     2018: 2 new topics
#     2019: 1 new topics
#     2025: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0M 0D)
#     T  1 | 100% stable (25S 0M 0D)
#     T  2 | 100% stable (25S 0M 0D)
#     T  5 | 100% stable (25S 0M 0D)
#     T  8 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T167 | 57% stable (12S 0M 9D)
#     T158 | 54% stable (12S 0M 10D)
#     T201 | 53% stable (9S 0M 8D)
#     T 63 | 52% stable (12S 0M 11D)
#     T139 | 50% stable (11S 0M 11D)
