# %% [markdown]
# # TopicGPT: Topic Term Drift (TTD)
#
# **Scenario 3a** — Three complementary drift metrics:
# 1. **Endpoint TTD**: cosine distance from first to last year (total drift)
# 2. **Trajectory from baseline**: cosine_sim(t₀, t) per year (when drift happens)
# 3. **Year-over-year drift**: cosine_sim(t, t+1) per year (smoothness of evolution)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/topicGpt/temporal")
RESULT_DIR = Path("../../../../results/topicGpt/consistency")

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Reading from: ../../../../results/topicGpt/temporal
# Saving to: ../../../../results/topicGpt/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def words_to_vector(words, vocab_index):
    vec = np.zeros(len(vocab_index))
    for w in words:
        if w in vocab_index:
            vec[vocab_index[w]] = 1.0
    return vec


def cos_sim(v1, v2):
    """Cosine similarity between two vectors."""
    return float(cosine_similarity(v1.reshape(1, -1), v2.reshape(1, -1))[0, 0])

# %% [markdown]
# ## 1. Endpoint TTD
# Total drift: `TTD = 1 - cosine_sim(words_first, words_last)`

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Endpoint TTD: {subject.upper()} (TopicGPT)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())

    # Build global vocabulary
    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t_first, t_last = topic_years[0], topic_years[-1]
        v_first = words_to_vector(topic_words[(t_first, tid)], vocab_index)
        v_last = words_to_vector(topic_words[(t_last, tid)], vocab_index)
        sim = cos_sim(v_first, v_last)

        rows.append({
            "subject": subject, "topic_id": tid,
            "first_year": t_first, "last_year": t_last,
            "n_years": len(topic_years),
            "cosine_sim": round(sim, 6),
            "ttd": round(1.0 - sim, 6),
            "words_first": ", ".join(topic_words[(t_first, tid)]),
            "words_last": ", ".join(topic_words[(t_last, tid)]),
        })

    df = pd.DataFrame(rows)
    df.to_csv(RESULT_DIR / subject / "topic_term_drift.csv", index=False)

    summary = {"subject": subject, "n_topics": len(df),
               "ttd_mean": round(df["ttd"].mean(), 6),
               "ttd_std": round(df["ttd"].std(), 6),
               "ttd_median": round(df["ttd"].median(), 6),
               "pct_stable": round((df["ttd"] < 0.5).mean() * 100, 2),
               "pct_drifted": round((df["ttd"] >= 0.5).mean() * 100, 2)}
    pd.DataFrame([summary]).to_csv(RESULT_DIR / subject / "ttd_summary.csv", index=False)

    print(f"  TTD: mean={summary['ttd_mean']:.4f} ± {summary['ttd_std']:.4f}, "
          f"median={summary['ttd_median']:.4f}")
    print(f"  Stable (TTD<0.5): {summary['pct_stable']:.1f}%  |  "
          f"Drifted (TTD≥0.5): {summary['pct_drifted']:.1f}%")

    print(f"\n  🔥 Top 5 most DRIFTED:")
    for _, r in df.nlargest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | "
              f"{r['words_first'][:40]}... → {r['words_last'][:40]}...")

    print(f"  🔒 Top 5 most STABLE:")
    for _, r in df.nsmallest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | {r['words_first'][:60]}")
# Out:
# ======================================================================
# Endpoint TTD: CS (TopicGPT)
# ======================================================================
#   TTD: mean=0.8913 ± 0.1057, median=0.9000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   🔥 Top 5 most DRIFTED:
#     T  1 | TTD=1.0000 | story, understanding, 1970s, depth, 1990... → models, llms, social, language, ai, sent...
#     T  3 | TTD=1.0000 | parsing, dop, ilp, semantic, tilde, indu... → reasoning, language, llms, models, logic...
#     T  5 | TTD=1.0000 | word, hypotheses, rate, words, recognize... → models, language, llms, model, context, ...
#     T  6 | TTD=1.0000 | distortion, channels, bounds, rates, ach... → channel, djscc, csi, scheme, coding, ris...
#     T  7 | TTD=1.0000 | lightest, derivation, abstractions, sear... → 3d, document, point, models, diffusion, ...
#   🔒 Top 5 most STABLE:
#     T 60 | TTD=0.5000 | 2d, 3d, hypothesis, shapes, image, object, reconstruction, p
#     T113 | TTD=0.6000 | salient, saliency, hypergraph, object, hyperedges, regions,
#     T114 | TTD=0.6000 | privacy, private, kanonymity, inferencebased, data, differen
#     T127 | TTD=0.6000 | policy, learning, tasks, task, policies, generalizes, reinfo
#     T 18 | TTD=0.7000 | policy, observable, grep, partially, reinforcement, market,
#
# ======================================================================
# Endpoint TTD: MATH (TopicGPT)
# ======================================================================
#   TTD: mean=0.8254 ± 0.1191, median=0.8000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   🔥 Top 5 most DRIFTED:
#     T  3 | TTD=1.0000 | sedenions, assessors, log, bf, singulari... → mathcal, ct, quot, sheaves, tautological...
#     T  9 | TTD=1.0000 | tree, continued, incidence, fraction, ca... → graph, graphs, trees, ex, permutations, ...
#     T 16 | TTD=1.0000 | widetilde, mirror, curve, witten, mm, di... → mathbb, gauge, coulomb, mathfrak, branch...
#     T 30 | TTD=1.0000 | probability, chains, twice, sampled, mea... → population, branching, processes, proces...
#     T 34 | TTD=1.0000 | copositive, quadratic, l1, ball, bound, ... → optimization, convex, problems, problem,...
#   🔒 Top 5 most STABLE:
#     T  7 | TTD=0.6000 | braid, representations, group, quantum, krammer, algebra, te
#     T 10 | TTD=0.6000 | dinger, schr, quasiperiodic, spectral, titchmarsh, adjoint,
#     T 11 | TTD=0.6000 | superconformal, algebra, schrodinger, algebras, quantum, def
#     T 22 | TTD=0.6000 | kaehler, einstein, ew, dkp, curvature, metric, xd, mabuchi,
#     T 35 | TTD=0.6000 | galois, group, wf, groups, arithmetically, field, ring, coho
#
# ======================================================================
# Endpoint TTD: PHYSICS (TopicGPT)
# ======================================================================
#   TTD: mean=0.8568 ± 0.1160, median=0.9000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   🔥 Top 5 most DRIFTED:
#     T 10 | TTD=1.0000 | deforming, inherit, energetic, automatic... → fluid, relativistic, fluids, hydrodynami...
#     T 11 | TTD=1.0000 | attractor, viscosity, inertial, eigenfre... → flow, reynolds, flows, fluid, rey, vorte...
#     T 16 | TTD=1.0000 | rfq, charge, prestripper, lebt, cherenko... → splendor, stcf, energy, 3sn, nb, neutron...
#     T 23 | TTD=1.0000 | translocation, rouse, polymer, monomers,... → diffusion, pore, solute, transport, subd...
#     T 27 | TTD=1.0000 | c1, breaking, decoherence, infinity, pai... → quantum, cooling, tls, magnon, mechanica...
#   🔒 Top 5 most STABLE:
#     T  4 | TTD=0.5000 | cooling, cesium, evaporative, trap, optical, sideband, 10muk
#     T  0 | TTD=0.6000 | colliders, gamma, plasma, beam, muon, converter, ions, elect
#     T  5 | TTD=0.6000 | photonic, crystal, terahertz, rectification, impedance, micr
#     T 24 | TTD=0.6000 | single, detectors, photon, 1300nm, apds, superconducting, ss
#     T 26 | TTD=0.6000 | relativity, transformations, tt, spacetime, qtr, true, speci

# %% [markdown]
# ## 2. Drift Trajectory from Baseline
# For each topic: `cosine_sim(words_t₀, words_t)` per year — shows **when** drift happens

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Drift Trajectory: {subject.upper()} (TopicGPT)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())

    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    traj_rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t0 = topic_years[0]
        v_baseline = words_to_vector(topic_words[(t0, tid)], vocab_index)

        for y in topic_years:
            v_y = words_to_vector(topic_words[(y, tid)], vocab_index)
            sim = cos_sim(v_baseline, v_y)
            traj_rows.append({
                "subject": subject, "topic_id": tid,
                "baseline_year": t0, "year": y,
                "years_elapsed": y - t0,
                "cosine_sim_to_baseline": round(sim, 6),
                "drift_from_baseline": round(1.0 - sim, 6),
            })

    traj_df = pd.DataFrame(traj_rows)
    traj_df.to_csv(RESULT_DIR / subject / "ttd_trajectory.csv", index=False)

    # Average drift trajectory across all topics per year
    avg_traj = traj_df.groupby("year").agg(
        avg_sim=("cosine_sim_to_baseline", "mean"),
        avg_drift=("drift_from_baseline", "mean"),
        n_topics=("topic_id", "count")
    ).reset_index()
    avg_traj.insert(0, "subject", subject)
    avg_traj.to_csv(RESULT_DIR / subject / "ttd_trajectory_avg.csv", index=False)

    print(f"  Avg drift from baseline per year:")
    for _, r in avg_traj.iterrows():
        bar = '█' * int(r['avg_drift'] * 50)
        print(f"    {int(r['year'])}: sim={r['avg_sim']:.4f}  drift={r['avg_drift']:.4f}  {bar}")
    print(f"  Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv")
# Out:
# ======================================================================
# Drift Trajectory: CS (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.5429  drift=0.4571  ██████████████████████
#     2002: sim=0.3457  drift=0.6543  ████████████████████████████████
#     2003: sim=0.2226  drift=0.7774  ██████████████████████████████████████
#     2004: sim=0.2257  drift=0.7743  ██████████████████████████████████████
#     2005: sim=0.1821  drift=0.8179  ████████████████████████████████████████
#     2006: sim=0.2026  drift=0.7974  ███████████████████████████████████████
#     2007: sim=0.1878  drift=0.8122  ████████████████████████████████████████
#     2008: sim=0.2178  drift=0.7822  ███████████████████████████████████████
#     2009: sim=0.1025  drift=0.8975  ████████████████████████████████████████████
#     2010: sim=0.1765  drift=0.8235  █████████████████████████████████████████
#     2011: sim=0.2145  drift=0.7855  ███████████████████████████████████████
#     2012: sim=0.2347  drift=0.7653  ██████████████████████████████████████
#     2013: sim=0.1880  drift=0.8120  ████████████████████████████████████████
#     2014: sim=0.1250  drift=0.8750  ███████████████████████████████████████████
#     2015: sim=0.1457  drift=0.8543  ██████████████████████████████████████████
#     2016: sim=0.1087  drift=0.8913  ████████████████████████████████████████████
#     2017: sim=0.1119  drift=0.8881  ████████████████████████████████████████████
#     2018: sim=0.1072  drift=0.8928  ████████████████████████████████████████████
#     2019: sim=0.1095  drift=0.8905  ████████████████████████████████████████████
#     2020: sim=0.1159  drift=0.8841  ████████████████████████████████████████████
#     2021: sim=0.1123  drift=0.8877  ████████████████████████████████████████████
#     2022: sim=0.1123  drift=0.8877  ████████████████████████████████████████████
#     2023: sim=0.1152  drift=0.8848  ████████████████████████████████████████████
#     2024: sim=0.1109  drift=0.8891  ████████████████████████████████████████████
#     2025: sim=0.1087  drift=0.8913  ████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: MATH (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.2102  drift=0.7898  ███████████████████████████████████████
#     2002: sim=0.1981  drift=0.8019  ████████████████████████████████████████
#     2003: sim=0.1673  drift=0.8327  █████████████████████████████████████████
#     2004: sim=0.1218  drift=0.8782  ███████████████████████████████████████████
#     2005: sim=0.1351  drift=0.8649  ███████████████████████████████████████████
#     2006: sim=0.1732  drift=0.8268  █████████████████████████████████████████
#     2007: sim=0.1667  drift=0.8333  █████████████████████████████████████████
#     2008: sim=0.1443  drift=0.8557  ██████████████████████████████████████████
#     2009: sim=0.1678  drift=0.8322  █████████████████████████████████████████
#     2010: sim=0.1672  drift=0.8328  █████████████████████████████████████████
#     2011: sim=0.1710  drift=0.8290  █████████████████████████████████████████
#     2012: sim=0.1500  drift=0.8500  ██████████████████████████████████████████
#     2013: sim=0.1532  drift=0.8468  ██████████████████████████████████████████
#     2014: sim=0.1629  drift=0.8371  █████████████████████████████████████████
#     2015: sim=0.1710  drift=0.8290  █████████████████████████████████████████
#     2016: sim=0.1565  drift=0.8435  ██████████████████████████████████████████
#     2017: sim=0.1714  drift=0.8286  █████████████████████████████████████████
#     2018: sim=0.1683  drift=0.8317  █████████████████████████████████████████
#     2019: sim=0.1746  drift=0.8254  █████████████████████████████████████████
#     2020: sim=0.1635  drift=0.8365  █████████████████████████████████████████
#     2021: sim=0.1714  drift=0.8286  █████████████████████████████████████████
#     2022: sim=0.1714  drift=0.8286  █████████████████████████████████████████
#     2023: sim=0.1825  drift=0.8175  ████████████████████████████████████████
#     2024: sim=0.1746  drift=0.8254  █████████████████████████████████████████
#     2025: sim=0.1746  drift=0.8254  █████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: PHYSICS (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.2932  drift=0.7068  ███████████████████████████████████
#     2002: sim=0.2980  drift=0.7020  ███████████████████████████████████
#     2003: sim=0.2176  drift=0.7824  ███████████████████████████████████████
#     2004: sim=0.1315  drift=0.8685  ███████████████████████████████████████████
#     2005: sim=0.2069  drift=0.7931  ███████████████████████████████████████
#     2006: sim=0.1262  drift=0.8738  ███████████████████████████████████████████
#     2007: sim=0.1045  drift=0.8955  ████████████████████████████████████████████
#     2008: sim=0.1206  drift=0.8794  ███████████████████████████████████████████
#     2009: sim=0.1127  drift=0.8873  ████████████████████████████████████████████
#     2010: sim=0.1162  drift=0.8838  ████████████████████████████████████████████
#     2011: sim=0.1297  drift=0.8703  ███████████████████████████████████████████
#     2012: sim=0.1274  drift=0.8726  ███████████████████████████████████████████
#     2013: sim=0.1230  drift=0.8770  ███████████████████████████████████████████
#     2014: sim=0.1392  drift=0.8608  ███████████████████████████████████████████
#     2015: sim=0.1257  drift=0.8743  ███████████████████████████████████████████
#     2016: sim=0.1257  drift=0.8743  ███████████████████████████████████████████
#     2017: sim=0.1324  drift=0.8676  ███████████████████████████████████████████
#     2018: sim=0.1527  drift=0.8473  ██████████████████████████████████████████
#     2019: sim=0.1459  drift=0.8541  ██████████████████████████████████████████
#     2020: sim=0.1446  drift=0.8554  ██████████████████████████████████████████
#     2021: sim=0.1473  drift=0.8527  ██████████████████████████████████████████
#     2022: sim=0.1486  drift=0.8514  ██████████████████████████████████████████
#     2023: sim=0.1500  drift=0.8500  ██████████████████████████████████████████
#     2024: sim=0.1486  drift=0.8514  ██████████████████████████████████████████
#     2025: sim=0.1432  drift=0.8568  ██████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv

# %% [markdown]
# ## 3. Year-over-Year Drift
# `cosine_sim(words_t, words_t+1)` — detects **sudden jumps** vs gradual evolution

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Year-over-Year Drift: {subject.upper()}")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row['year']), int(row['topic_id']))
        topic_words[key] = parse_words(row['top_words'])

    years = sorted(evo_df['year'].unique())

    # Build global vocabulary
    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    yoy_rows = []

    # Iterate by CONSECUTIVE CALENDAR YEARS
    for i in range(len(years) - 1):
        t, t1 = int(years[i]), int(years[i + 1])

        # Find topics present in BOTH years
        topics_t = {tid for (y, tid) in topic_words if y == t}
        topics_t1 = {tid for (y, tid) in topic_words if y == t1}
        common_topics = sorted(topics_t & topics_t1)

        for tid in common_topics:
            v_t = words_to_vector(topic_words[(t, tid)], vocab_index)
            v_t1 = words_to_vector(topic_words[(t1, tid)], vocab_index)
            sim = cos_sim(v_t, v_t1)

            yoy_rows.append({
                'subject': subject, 'topic_id': tid,
                'year_from': t, 'year_to': t1,
                'cosine_sim': round(sim, 6),
                'drift': round(1.0 - sim, 6),
            })

    yoy_df = pd.DataFrame(yoy_rows)
    yoy_df.to_csv(RESULT_DIR / subject / "ttd_year_over_year.csv", index=False)

    # Per-topic summary
    topic_yoy = yoy_df.groupby('topic_id').agg(
        avg_yoy_sim=('cosine_sim', 'mean'),
        min_yoy_sim=('cosine_sim', 'min'),
        avg_yoy_drift=('drift', 'mean'),
        max_single_jump=('drift', 'max'),
    ).reset_index()
    topic_yoy.insert(0, 'subject', subject)
    topic_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_per_topic.csv", index=False)

    # Avg across all topics per year transition
    avg_yoy = yoy_df.groupby(['year_from', 'year_to']).agg(
        avg_sim=('cosine_sim', 'mean'),
        avg_drift=('drift', 'mean'),
        n_topics=('topic_id', 'count')
    ).reset_index()
    avg_yoy.insert(0, 'subject', subject)
    avg_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_avg.csv", index=False)

    print(f"  Avg year-over-year drift (consecutive calendar years):")
    for _, r in avg_yoy.iterrows():
        bar = chr(9608) * int(r['avg_drift'] * 50)
        print(f"    {int(r['year_from'])}→{int(r['year_to'])}: sim={r['avg_sim']:.4f}  "
              f"drift={r['avg_drift']:.4f}  ({int(r['n_topics'])} topics)  {bar}")

    # Top 5 biggest single-year jumps
    print(f"\n  Top 5 biggest single-year JUMPS:")
    for _, r in yoy_df.nlargest(5, 'drift').iterrows():
        print(f"    T{int(r['topic_id']):>3} | {int(r['year_from'])}→{int(r['year_to'])} | "
              f"drift={r['drift']:.4f}")

    overall_sim = yoy_df['cosine_sim'].mean()
    overall_drift = yoy_df['drift'].mean()
    print(f"\n  Overall: avg_yoy_sim={overall_sim:.4f}  avg_yoy_drift={overall_drift:.4f}")
    print(f"  Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv")
# Out:
# ======================================================================
# Year-over-Year Drift: CS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.1111  drift=0.8889  (18 topics)  ████████████████████████████████████████████
#     2001→2002: sim=0.0870  drift=0.9130  (23 topics)  █████████████████████████████████████████████
#     2002→2003: sim=0.1500  drift=0.8500  (20 topics)  ██████████████████████████████████████████
#     2003→2004: sim=0.1000  drift=0.9000  (23 topics)  █████████████████████████████████████████████
#     2004→2005: sim=0.1862  drift=0.8138  (29 topics)  ████████████████████████████████████████
#     2005→2006: sim=0.1643  drift=0.8357  (28 topics)  █████████████████████████████████████████
#     2006→2007: sim=0.1241  drift=0.8759  (29 topics)  ███████████████████████████████████████████
#     2007→2008: sim=0.1529  drift=0.8471  (34 topics)  ██████████████████████████████████████████
#     2008→2009: sim=0.1406  drift=0.8594  (32 topics)  ██████████████████████████████████████████
#     2009→2010: sim=0.1441  drift=0.8559  (34 topics)  ██████████████████████████████████████████
#     2010→2011: sim=0.1444  drift=0.8556  (45 topics)  ██████████████████████████████████████████
#     2011→2012: sim=0.1615  drift=0.8385  (52 topics)  █████████████████████████████████████████
#     2012→2013: sim=0.1627  drift=0.8373  (67 topics)  █████████████████████████████████████████
#     2013→2014: sim=0.1603  drift=0.8397  (78 topics)  █████████████████████████████████████████
#     2014→2015: sim=0.1787  drift=0.8213  (89 topics)  █████████████████████████████████████████
#     2015→2016: sim=0.1812  drift=0.8187  (112 topics)  ████████████████████████████████████████
#     2016→2017: sim=0.2365  drift=0.7635  (126 topics)  ██████████████████████████████████████
#     2017→2018: sim=0.3230  drift=0.6770  (135 topics)  █████████████████████████████████
#     2018→2019: sim=0.3891  drift=0.6109  (137 topics)  ██████████████████████████████
#     2019→2020: sim=0.4693  drift=0.5307  (137 topics)  ██████████████████████████
#     2020→2021: sim=0.5116  drift=0.4884  (138 topics)  ████████████████████████
#     2021→2022: sim=0.5254  drift=0.4746  (138 topics)  ███████████████████████
#     2022→2023: sim=0.5500  drift=0.4500  (138 topics)  ██████████████████████
#     2023→2024: sim=0.5855  drift=0.4145  (138 topics)  ████████████████████
#     2024→2025: sim=0.6507  drift=0.3493  (138 topics)  █████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T  5 | 2000→2001 | drift=1.0000
#     T 10 | 2000→2001 | drift=1.0000
#     T 11 | 2000→2001 | drift=1.0000
#     T 13 | 2000→2001 | drift=1.0000
#     T 28 | 2000→2001 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.3574  avg_yoy_drift=0.6426
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: MATH
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.1587  drift=0.8413  (46 topics)  ██████████████████████████████████████████
#     2001→2002: sim=0.1596  drift=0.8404  (47 topics)  ██████████████████████████████████████████
#     2002→2003: sim=0.1224  drift=0.8776  (49 topics)  ███████████████████████████████████████████
#     2003→2004: sim=0.1600  drift=0.8400  (50 topics)  ██████████████████████████████████████████
#     2004→2005: sim=0.1741  drift=0.8259  (54 topics)  █████████████████████████████████████████
#     2005→2006: sim=0.1852  drift=0.8148  (54 topics)  ████████████████████████████████████████
#     2006→2007: sim=0.2143  drift=0.7857  (56 topics)  ███████████████████████████████████████
#     2007→2008: sim=0.2183  drift=0.7817  (60 topics)  ███████████████████████████████████████
#     2008→2009: sim=0.2288  drift=0.7712  (59 topics)  ██████████████████████████████████████
#     2009→2010: sim=0.2525  drift=0.7475  (59 topics)  █████████████████████████████████████
#     2010→2011: sim=0.2590  drift=0.7410  (61 topics)  █████████████████████████████████████
#     2011→2012: sim=0.2903  drift=0.7097  (62 topics)  ███████████████████████████████████
#     2012→2013: sim=0.3194  drift=0.6806  (62 topics)  ██████████████████████████████████
#     2013→2014: sim=0.3323  drift=0.6677  (62 topics)  █████████████████████████████████
#     2014→2015: sim=0.3613  drift=0.6387  (62 topics)  ███████████████████████████████
#     2015→2016: sim=0.3984  drift=0.6016  (62 topics)  ██████████████████████████████
#     2016→2017: sim=0.4032  drift=0.5968  (62 topics)  █████████████████████████████
#     2017→2018: sim=0.4032  drift=0.5968  (63 topics)  █████████████████████████████
#     2018→2019: sim=0.4270  drift=0.5730  (63 topics)  ████████████████████████████
#     2019→2020: sim=0.4381  drift=0.5619  (63 topics)  ████████████████████████████
#     2020→2021: sim=0.4476  drift=0.5524  (63 topics)  ███████████████████████████
#     2021→2022: sim=0.4476  drift=0.5524  (63 topics)  ███████████████████████████
#     2022→2023: sim=0.4746  drift=0.5254  (63 topics)  ██████████████████████████
#     2023→2024: sim=0.4794  drift=0.5206  (63 topics)  ██████████████████████████
#     2024→2025: sim=0.5286  drift=0.4714  (63 topics)  ███████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T  9 | 2000→2001 | drift=1.0000
#     T 24 | 2000→2001 | drift=1.0000
#     T 25 | 2000→2001 | drift=1.0000
#     T 27 | 2000→2001 | drift=1.0000
#     T 33 | 2000→2001 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.3247  avg_yoy_drift=0.6753
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: PHYSICS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.1114  drift=0.8886  (35 topics)  ████████████████████████████████████████████
#     2001→2002: sim=0.1395  drift=0.8605  (38 topics)  ███████████████████████████████████████████
#     2002→2003: sim=0.1421  drift=0.8579  (38 topics)  ██████████████████████████████████████████
#     2003→2004: sim=0.1452  drift=0.8548  (42 topics)  ██████████████████████████████████████████
#     2004→2005: sim=0.1356  drift=0.8644  (45 topics)  ███████████████████████████████████████████
#     2005→2006: sim=0.1500  drift=0.8500  (54 topics)  ██████████████████████████████████████████
#     2006→2007: sim=0.1672  drift=0.8328  (61 topics)  █████████████████████████████████████████
#     2007→2008: sim=0.1769  drift=0.8231  (65 topics)  █████████████████████████████████████████
#     2008→2009: sim=0.2029  drift=0.7971  (68 topics)  ███████████████████████████████████████
#     2009→2010: sim=0.1972  drift=0.8028  (71 topics)  ████████████████████████████████████████
#     2010→2011: sim=0.2351  drift=0.7649  (74 topics)  ██████████████████████████████████████
#     2011→2012: sim=0.2904  drift=0.7096  (73 topics)  ███████████████████████████████████
#     2012→2013: sim=0.2986  drift=0.7014  (73 topics)  ███████████████████████████████████
#     2013→2014: sim=0.3216  drift=0.6784  (74 topics)  █████████████████████████████████
#     2014→2015: sim=0.3203  drift=0.6797  (74 topics)  █████████████████████████████████
#     2015→2016: sim=0.3378  drift=0.6622  (74 topics)  █████████████████████████████████
#     2016→2017: sim=0.3595  drift=0.6405  (74 topics)  ████████████████████████████████
#     2017→2018: sim=0.3473  drift=0.6527  (74 topics)  ████████████████████████████████
#     2018→2019: sim=0.3892  drift=0.6108  (74 topics)  ██████████████████████████████
#     2019→2020: sim=0.4041  drift=0.5959  (74 topics)  █████████████████████████████
#     2020→2021: sim=0.4365  drift=0.5635  (74 topics)  ████████████████████████████
#     2021→2022: sim=0.4284  drift=0.5716  (74 topics)  ████████████████████████████
#     2022→2023: sim=0.4216  drift=0.5784  (74 topics)  ████████████████████████████
#     2023→2024: sim=0.4446  drift=0.5554  (74 topics)  ███████████████████████████
#     2024→2025: sim=0.4716  drift=0.5284  (74 topics)  ██████████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T 11 | 2000→2001 | drift=1.0000
#     T 13 | 2000→2001 | drift=1.0000
#     T 14 | 2000→2001 | drift=1.0000
#     T 16 | 2000→2001 | drift=1.0000
#     T 18 | 2000→2001 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.3023  avg_yoy_drift=0.6977
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv

# %% [markdown]
# ## Inspect Individual Topics
# Two helper functions to drill into specific topics.

# %%
def show_topic_yoy(topic_id, subject):
    """
    Show year-over-year drift for a specific topic with drift labels.
    Labels: Stable (<0.3), Moderate (0.3-0.6), Aggressive (0.6-0.8), Extreme (>0.8)
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    all_words_set = set()
    tw = {}
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())

    print(f"\n{'='*70}")
    print(f"YoY Drift: Topic {topic_id} — {subject.upper()}")
    print(f"Active: {topic_years[0]}–{topic_years[-1]} ({len(topic_years)} years)")
    print(f"{'='*70}")

    drifts = []
    for i in range(len(topic_years) - 1):
        t, t1 = topic_years[i], topic_years[i + 1]
        v_t = words_to_vector(tw[t], vi)
        v_t1 = words_to_vector(tw[t1], vi)
        sim = cos_sim(v_t, v_t1)
        drift = 1.0 - sim
        drifts.append(drift)

        # Label
        if drift < 0.3:
            label = "🟢 Stable"
        elif drift < 0.6:
            label = "🟡 Moderate"
        elif drift < 0.8:
            label = "🟠 Aggressive"
        else:
            label = "🔴 Extreme"

        bar = chr(9608) * int(drift * 30)
        print(f"  {t}→{t1}: sim={sim:.4f}  drift={drift:.4f}  {bar}  {label}")

        # Show word changes
        added = set(tw[t1]) - set(tw[t])
        removed = set(tw[t]) - set(tw[t1])
        if added or removed:
            if removed:
                print(f"           − {', '.join(sorted(removed))}")
            if added:
                print(f"           + {', '.join(sorted(added))}")

    # Summary
    avg_d = np.mean(drifts)
    max_d = np.max(drifts)
    if avg_d < 0.3:
        verdict = "🟢 STABLE — vocabulary is consistent over time"
    elif avg_d < 0.5:
        verdict = "🟡 MODERATE — topic evolves gradually"
    elif avg_d < 0.7:
        verdict = "🟠 DRIFTING — significant vocabulary changes"
    else:
        verdict = "🔴 HIGHLY UNSTABLE — topic vocabulary reshuffles frequently"

    print(f"\n  Avg drift: {avg_d:.4f} | Max jump: {max_d:.4f}")
    print(f"  Verdict: {verdict}")


def show_topic_endpoint(topic_id, subject):
    """
    Show endpoint drift for a specific topic: first year vs last year.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    all_words_set = set()
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())
    t_first, t_last = topic_years[0], topic_years[-1]

    v_first = words_to_vector(tw[t_first], vi)
    v_last = words_to_vector(tw[t_last], vi)
    sim = cos_sim(v_first, v_last)
    ttd = 1.0 - sim

    # Words analysis
    w_first = set(tw[t_first])
    w_last = set(tw[t_last])
    kept = sorted(w_first & w_last)
    removed = sorted(w_first - w_last)
    added = sorted(w_last - w_first)

    if ttd < 0.3:
        verdict = "🟢 STABLE — topic maintained its core vocabulary"
    elif ttd < 0.5:
        verdict = "🟡 MODERATE — topic evolved but recognizable"
    elif ttd < 0.7:
        verdict = "🟠 SIGNIFICANT DRIFT — topic substantially changed"
    else:
        verdict = "🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced"

    print(f"\n{'='*70}")
    print(f"Endpoint Drift: Topic {topic_id} — {subject.upper()}")
    print(f"{'='*70}")
    print(f"  Active: {t_first}–{t_last} ({len(topic_years)} years)")
    print(f"  Cosine similarity: {sim:.4f}")
    print(f"  TTD (drift):       {ttd:.4f}")
    print(f"  Verdict: {verdict}")
    print(f"\n  First year ({t_first}): {', '.join(tw[t_first])}")
    print(f"  Last year  ({t_last}): {', '.join(tw[t_last])}")
    print(f"\n  🔒 Kept ({len(kept)}):    {', '.join(kept) if kept else '(none)'}")
    print(f"  ➖ Removed ({len(removed)}): {', '.join(removed) if removed else '(none)'}")
    print(f"  ➕ Added ({len(added)}):   {', '.join(added) if added else '(none)'}")


def show_topic_trajectory(topic_id, subject):
    """
    Show drift trajectory from baseline (first year) for a specific topic.
    cosine_sim(words_t0, words_t) per year — shows when drift accelerates.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    tw = {}
    all_words_set = set()
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())
    t0 = topic_years[0]
    v_baseline = words_to_vector(tw[t0], vi)

    print(f"\n{'='*70}")
    print(f"Drift Trajectory: Topic {topic_id} — {subject.upper()}")
    print(f"Baseline: {t0} → {', '.join(tw[t0])}")
    print(f"{'='*70}")

    prev_drift = 0.0
    for y in topic_years:
        v_y = words_to_vector(tw[y], vi)
        sim = cos_sim(v_baseline, v_y)
        drift = 1.0 - sim

        # Delta from previous year
        delta = drift - prev_drift
        if delta > 0.1:
            delta_label = f" ↑{delta:+.3f} ⚡"
        elif delta > 0.02:
            delta_label = f" ↑{delta:+.3f}"
        elif delta < -0.02:
            delta_label = f" ↓{delta:+.3f} 🔄"
        else:
            delta_label = f"  {delta:+.3f} —"
        prev_drift = drift

        # Shared words with baseline
        shared = sorted(set(tw[t0]) & set(tw[y]))
        n_shared = len(shared)
        n_total = len(tw[t0])

        bar = chr(9608) * int(drift * 30)
        print(f"  {y}: sim={sim:.4f}  drift={drift:.4f}  {bar}{delta_label}  "
              f"({n_shared}/{n_total} baseline words kept)")

    # Final summary
    final_sim = cos_sim(v_baseline, words_to_vector(tw[topic_years[-1]], vi))
    final_drift = 1.0 - final_sim
    kept = sorted(set(tw[t0]) & set(tw[topic_years[-1]]))
    lost = sorted(set(tw[t0]) - set(tw[topic_years[-1]]))

    print(f"\n  Total drift ({t0}→{topic_years[-1]}): {final_drift:.4f}")
    print(f"  Baseline words kept: {', '.join(kept) if kept else '(none)'}")
    print(f"  Baseline words lost: {', '.join(lost) if lost else '(none)'}")

# %% [markdown]
# ### Usage
# ```python
# show_topic_yoy(topic_id=5, subject="cs")
# show_topic_endpoint(topic_id=5, subject="cs")
# ```

# %%
# Example: inspect a specific topic
show_topic_yoy(topic_id=0, subject="cs")
show_topic_trajectory(topic_id=0, subject="cs")
show_topic_endpoint(topic_id=0, subject="cs")
# Out:
# ======================================================================
# YoY Drift: Topic 0 — CS
# Active: 2000–2025 (26 years)
# ======================================================================
#   2000→2001: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − apweb, categories, databases, descriptions, mining, ontologies, research, talkmine, text
#            + database, gsa, html, link, mragyati, pages, query, search, sites
#   2001→2002: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − database, gsa, html, link, mragyati, pages, query, search, sites
#            + c4, genex, keyphrase, keyphrases, learning, phrases, prints, recommender, topic
#   2002→2003: sim=0.3000  drift=0.7000  █████████████████████  🟠 Aggressive
#            − c4, genex, learning, phrases, prints, recommender, topic
#            + algorithm, dn, documents, google, nearest, recommendation, trails
#   2003→2004: sim=0.0000  drift=1.0000  ██████████████████████████████  🔴 Extreme
#            − algorithm, dn, documents, google, keyphrase, keyphrases, nearest, recommendation, trails, web
#            + concepts, document, hierarchy, nrc, probabilities, relevancy, semantic, word, words, wsd
#   2004→2005: sim=0.0000  drift=1.0000  ██████████████████████████████  🔴 Extreme
#            − concepts, document, hierarchy, nrc, probabilities, relevancy, semantic, word, words, wsd
#            + des, documents, donn, es, le, requ, sources, te, treillis, une
#   2005→2006: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − des, donn, es, le, requ, sources, te, treillis, une
#            + cores, document, elps, gps, grs, hypertextual, ontology, query, ranking
#   2006→2007: sim=0.0000  drift=1.0000  ██████████████████████████████  🔴 Extreme
#            − cores, document, documents, elps, gps, grs, hypertextual, ontology, query, ranking
#            + bookmarking, citeulike, collaborative, communities, content, del, discovery, icio, metadata, tagging
#   2007→2008: sim=0.0000  drift=1.0000  ██████████████████████████████  🔴 Extreme
#            − bookmarking, citeulike, collaborative, communities, content, del, discovery, icio, metadata, tagging
#            + database, filtering, index, indexing, mails, profile, subcorpora, user, wiki, wikipedia
#   2008→2009: sim=0.0000  drift=1.0000  ██████████████████████████████  🔴 Extreme
#            − database, filtering, index, indexing, mails, profile, subcorpora, user, wiki, wikipedia
#            + attachments, biomedical, board, bulletin, document, documents, priscrawler, relativeness, scir, search
#   2009→2010: sim=0.3000  drift=0.7000  █████████████████████  🟠 Aggressive
#            − attachments, biomedical, board, bulletin, priscrawler, relativeness, scir
#            + apriori, association, intent, lda, text, web, xml
#   2010→2011: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − apriori, association, document, documents, intent, lda, search, text, xml
#            + art1, biclustering, browsing, clickstream, pages, presy, reformulation, returned, users
#   2011→2012: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − art1, biclustering, browsing, clickstream, pages, presy, reformulation, returned, users
#            + articles, documents, html, information, newspaper, ocr, retrieval, search, tags
#   2012→2013: sim=0.3000  drift=0.7000  █████████████████████  🟠 Aggressive
#            − articles, html, information, newspaper, ocr, retrieval, tags
#            + arabic, blogs, cqa, engines, ontology, pages, stc
#   2013→2014: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − arabic, blogs, cqa, engines, ontology, pages, search, stc
#            + albanian, classification, clustering, phrase, relatedness, semantic, text, tomaco
#   2014→2015: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − albanian, classification, clustering, documents, phrase, relatedness, semantic, text, tomaco
#            + cohesive, data, hunter, keyword, queries, rdf, search, ssds, swmh
#   2015→2016: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − cohesive, data, hunter, keyword, queries, rdf, ssds, swmh
#            + crawl, document, documents, job, namespace, namespaces, timemachine, title
#   2016→2017: sim=0.3000  drift=0.7000  █████████████████████  🟠 Aggressive
#            − crawl, documents, job, namespace, namespaces, timemachine, title
#            + expansion, ontology, query, retrieval, semantic, text, xtreepath
#   2017→2018: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − expansion, ontology, retrieval, semantic, xtreepath
#            + av, documents, entities, named, queries
#   2018→2019: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − av, document, documents, entities, named, queries, query, text
#            + data, ewaq, keyword, mementomap, perspectroscope, privileged, relatedness, wikipedia
#   2019→2020: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − data, ewaq, keyword, mementomap, perspectroscope, privileged, relatedness, web, wikipedia
#            + clarification, concept, documents, information, language, queries, query, retrieval, taxonomy
#   2020→2021: sim=0.3000  drift=0.7000  █████████████████████  🟠 Aggressive
#            − clarification, concept, information, language, queries, retrieval, taxonomy
#            + based, data, metadata, qeps, tags, text, topic
#   2021→2022: sim=0.3000  drift=0.7000  █████████████████████  🟠 Aggressive
#            − based, data, documents, metadata, qeps, query, tags
#            + bug, classification, document, information, q4eda, queries, taxonomy
#   2022→2023: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − bug, information, q4eda, taxonomy, topic
#            + craml, dataset, documents, query, serp
#   2023→2024: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − classification, craml, dataset, document, documents, queries, query, serp, text
#            + articles, energetics, engine, engines, khmer, knowledge, llms, retrieval, sql
#   2024→2025: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − articles, energetics, engine, engines, khmer, knowledge, llms, sql
#            + based, document, documents, queries, query, semantic, text, web
#
#   Avg drift: 0.8240 | Max jump: 1.0000
#   Verdict: 🔴 HIGHLY UNSTABLE — topic vocabulary reshuffles frequently
#
# ======================================================================
# Drift Trajectory: Topic 0 — CS
# Baseline: 2000 → web, apweb, databases, talkmine, mining, text, research, categories, ontologies, descriptions
# ======================================================================
#   2000: sim=1.0000  drift=-0.0000    -0.000 —  (10/10 baseline words kept)
#   2001: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.900 ⚡  (1/10 baseline words kept)
#   2002: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2003: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2004: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2005: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2006: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2007: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2008: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2009: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2010: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.200 🔄  (2/10 baseline words kept)
#   2011: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2012: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2013: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2014: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.100 🔄  (2/10 baseline words kept)
#   2015: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2016: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2017: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.100 🔄  (2/10 baseline words kept)
#   2018: sim=0.2000  drift=0.8000  ████████████████████████  +0.000 —  (2/10 baseline words kept)
#   2019: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2020: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2021: sim=0.1000  drift=0.9000  ███████████████████████████ ↓-0.100 🔄  (1/10 baseline words kept)
#   2022: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2023: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2024: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2025: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.200 🔄  (2/10 baseline words kept)
#
#   Total drift (2000→2025): 0.8000
#   Baseline words kept: text, web
#   Baseline words lost: apweb, categories, databases, descriptions, mining, ontologies, research, talkmine
#
# ======================================================================
# Endpoint Drift: Topic 0 — CS
# ======================================================================
#   Active: 2000–2025 (26 years)
#   Cosine similarity: 0.2000
#   TTD (drift):       0.8000
#   Verdict: 🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced
#
#   First year (2000): web, apweb, databases, talkmine, mining, text, research, categories, ontologies, descriptions
#   Last year  (2025): search, query, web, queries, document, text, semantic, retrieval, based, documents
#
#   🔒 Kept (2):    text, web
#   ➖ Removed (8): apweb, categories, databases, descriptions, mining, ontologies, research, talkmine
#   ➕ Added (8):   based, document, documents, queries, query, retrieval, search, semantic
