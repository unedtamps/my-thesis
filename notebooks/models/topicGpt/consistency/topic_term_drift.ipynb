# %% [markdown]
# # TopicGPT: Topic Term Drift (TTD)
#
# **Scenario 3a** — Three complementary drift metrics:
# 1. **Endpoint TTD**: cosine distance from first to last year (total drift)
# 2. **Trajectory from baseline**: cosine_sim(t₀, t) per year (when drift happens)
# 3. **Year-over-year drift**: cosine_sim(t, t+1) per year (smoothness of evolution)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/topicGpt/temporal")
RESULT_DIR = Path("../../../../results/topicGpt/consistency")

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Reading from: ../../../../results/topicGpt/temporal
# Saving to: ../../../../results/topicGpt/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list_1, list_2, p=0.9):
    k = min(len(list_1), len(list_2))
    if k == 0:
        return 0.0
    score = 0.0
    for d in range(1, k + 1):
        agreement = len(set(list_1[:d]) & set(list_2[:d])) / d
        score += (p ** (d - 1)) * agreement
    return score * (1 - p)

# %% [markdown]
# ## 1. Endpoint TTD
# Total drift: `TTD = 1 - cosine_sim(words_first, words_last)`

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Endpoint TTD: {subject.upper()} (TopicGPT)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())


    rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t_first, t_last = topic_years[0], topic_years[-1]
        sim = rbo(topic_words[(t_first, tid)], topic_words[(t_last, tid)], p=0.9)

        rows.append({
            "subject": subject, "topic_id": tid,
            "first_year": t_first, "last_year": t_last,
            "n_years": len(topic_years),
            "cosine_sim": round(sim, 6),
            "ttd": round(1.0 - sim, 6),
            "words_first": ", ".join(topic_words[(t_first, tid)]),
            "words_last": ", ".join(topic_words[(t_last, tid)]),
        })

    df = pd.DataFrame(rows)
    df.to_csv(RESULT_DIR / subject / "topic_term_drift.csv", index=False)

    summary = {"subject": subject, "n_topics": len(df),
               "ttd_mean": round(df["ttd"].mean(), 6),
               "ttd_std": round(df["ttd"].std(), 6),
               "ttd_median": round(df["ttd"].median(), 6),
               "pct_stable": round((df["ttd"] < 0.5).mean() * 100, 2),
               "pct_drifted": round((df["ttd"] >= 0.5).mean() * 100, 2)}
    pd.DataFrame([summary]).to_csv(RESULT_DIR / subject / "ttd_summary.csv", index=False)

    print(f"  TTD: mean={summary['ttd_mean']:.4f} ± {summary['ttd_std']:.4f}, "
          f"median={summary['ttd_median']:.4f}")
    print(f"  Stable (TTD<0.5): {summary['pct_stable']:.1f}%  |  "
          f"Drifted (TTD≥0.5): {summary['pct_drifted']:.1f}%")

    print(f"\n  🔥 Top 5 most DRIFTED:")
    for _, r in df.nlargest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | "
              f"{r['words_first'][:40]}... → {r['words_last'][:40]}...")

    print(f"  🔒 Top 5 most STABLE:")
    for _, r in df.nsmallest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | {r['words_first'][:60]}")
# Out:
# ======================================================================
# Endpoint TTD: CS (TopicGPT)
# ======================================================================
#   TTD: mean=0.9367 ± 0.0788, median=0.9753
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   🔥 Top 5 most DRIFTED:
#     T  1 | TTD=1.0000 | story, understanding, 1970s, depth, 1990... → models, language, llms, dialogue, social...
#     T  3 | TTD=1.0000 | parsing, dop, ilp, semantic, tilde, indu... → reasoning, language, models, llms, logic...
#     T  5 | TTD=1.0000 | word, hypotheses, rate, words, recognize... → models, language, model, llms, generatio...
#     T  7 | TTD=1.0000 | lightest, derivation, abstractions, sear... → 3d, point, segmentation, document, cloud...
#     T 11 | TTD=1.0000 | object, multicomputers, server, semaphor... → memory, cxl, data, storage, performance,...
#   🔒 Top 5 most STABLE:
#     T114 | TTD=0.6143 | privacy, private, kanonymity, inferencebased, data, differen
#     T 38 | TTD=0.7461 | manifold, tangent, unorganized, nonlinear, spaces, eigendeco
#     T 60 | TTD=0.7505 | 2d, 3d, hypothesis, shapes, image, object, reconstruction, p
#     T113 | TTD=0.7632 | salient, saliency, hypergraph, object, hyperedges, regions,
#     T  9 | TTD=0.7646 | privacy, tools, site, web, practices, notice, infomediary, p
#
# ======================================================================
# Endpoint TTD: MATH (TopicGPT)
# ======================================================================
#   TTD: mean=0.8986 ± 0.0954, median=0.9096
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   🔥 Top 5 most DRIFTED:
#     T  9 | TTD=1.0000 | tree, continued, incidence, fraction, ca... → permutations, graphs, graph, trees, ex, ...
#     T 16 | TTD=1.0000 | widetilde, mirror, curve, witten, mm, di... → mathcal, gauge, theories, mathbb, cal, m...
#     T 27 | TTD=1.0000 | kappa, popescu, gamma, eisenbud, spec, s... → modules, rr, rings, module, gorenstein, ...
#     T 30 | TTD=1.0000 | probability, chains, twice, sampled, mea... → branching, population, process, processe...
#     T 34 | TTD=1.0000 | copositive, quadratic, l1, ball, bound, ... → optimization, convex, problems, method, ...
#   🔒 Top 5 most STABLE:
#     T 36 | TTD=0.5710 | symplectic, hamiltonian, group, hyperkaehler, quasifolds, qu
#     T 37 | TTD=0.5961 | hodge, cohomology, manifolds, kahler, rham, gelfand, lielie,
#     T 13 | TTD=0.6865 | knots, legendrian, vassiliev, knot, moves, invariants, linki
#     T 35 | TTD=0.7231 | galois, group, wf, groups, arithmetically, field, ring, coho
#     T 61 | TTD=0.7253 | learning, neural, data, chemical, equations, differential, n
#
# ======================================================================
# Endpoint TTD: PHYSICS (TopicGPT)
# ======================================================================
#   TTD: mean=0.8955 ± 0.1076, median=0.9366
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   🔥 Top 5 most DRIFTED:
#     T 10 | TTD=1.0000 | deforming, inherit, energetic, automatic... → fluid, relativistic, hydrodynamics, sph,...
#     T 11 | TTD=1.0000 | attractor, viscosity, inertial, eigenfre... → flow, vortex, reynolds, flows, fluid, in...
#     T 16 | TTD=1.0000 | rfq, charge, prestripper, lebt, cherenko... → muon, beam, energy, neutron, electron, m...
#     T 36 | TTD=1.0000 | pbpb, finder, cdf, tevatron, alice, mult... → detector, reconstruction, calorimeter, l...
#     T 39 | TTD=1.0000 | ergodic, metric, walking, tempering, mon... → quantum, sampling, dynamics, stochastic,...
#   🔒 Top 5 most STABLE:
#     T 62 | TTD=0.5658 | solitons, soliton, media, nonlinear, bullets, modulational,
#     T  4 | TTD=0.6434 | cooling, cesium, evaporative, trap, optical, sideband, 10muk
#     T 26 | TTD=0.6703 | relativity, transformations, tt, spacetime, qtr, true, speci
#     T 44 | TTD=0.6884 | cities, urban, centrality, traffic, commuting, city, backbon
#     T 20 | TTD=0.7012 | polymer, op, brush, polymers, melt, grafted, dna, gg, 0r, pu

# %% [markdown]
# ## 2. Drift Trajectory from Baseline
# For each topic: `cosine_sim(words_t₀, words_t)` per year — shows **when** drift happens

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Drift Trajectory: {subject.upper()} (TopicGPT)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())


    traj_rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t0 = topic_years[0]
        words_baseline = topic_words[(t0, tid)]

        for y in topic_years:
            words_y = topic_words[(y, tid)]
            sim = rbo(words_baseline, words_y, p=0.9)
            traj_rows.append({
                "subject": subject, "topic_id": tid,
                "baseline_year": t0, "year": y,
                "years_elapsed": y - t0,
                "cosine_sim_to_baseline": round(sim, 6),
                "drift_from_baseline": round(1.0 - sim, 6),
            })

    traj_df = pd.DataFrame(traj_rows)
    traj_df.to_csv(RESULT_DIR / subject / "ttd_trajectory.csv", index=False)

    # Average drift trajectory across all topics per year
    avg_traj = traj_df.groupby("year").agg(
        avg_sim=("cosine_sim_to_baseline", "mean"),
        avg_drift=("drift_from_baseline", "mean"),
        n_topics=("topic_id", "count")
    ).reset_index()
    avg_traj.insert(0, "subject", subject)
    avg_traj.to_csv(RESULT_DIR / subject / "ttd_trajectory_avg.csv", index=False)

    print(f"  Avg drift from baseline per year:")
    for _, r in avg_traj.iterrows():
        bar = '█' * int(r['avg_drift'] * 50)
        print(f"    {int(r['year'])}: sim={r['avg_sim']:.4f}  drift={r['avg_drift']:.4f}  {bar}")
    print(f"  Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv")
# Out:
# ======================================================================
# Drift Trajectory: CS (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=0.6513  drift=0.3487  █████████████████
#     2001: sim=0.4961  drift=0.5039  █████████████████████████
#     2002: sim=0.3559  drift=0.6441  ████████████████████████████████
#     2003: sim=0.1913  drift=0.8087  ████████████████████████████████████████
#     2004: sim=0.1616  drift=0.8384  █████████████████████████████████████████
#     2005: sim=0.1402  drift=0.8598  ██████████████████████████████████████████
#     2006: sim=0.1496  drift=0.8504  ██████████████████████████████████████████
#     2007: sim=0.1153  drift=0.8847  ████████████████████████████████████████████
#     2008: sim=0.1420  drift=0.8580  ██████████████████████████████████████████
#     2009: sim=0.0814  drift=0.9186  █████████████████████████████████████████████
#     2010: sim=0.1171  drift=0.8829  ████████████████████████████████████████████
#     2011: sim=0.1481  drift=0.8519  ██████████████████████████████████████████
#     2012: sim=0.1731  drift=0.8269  █████████████████████████████████████████
#     2013: sim=0.1630  drift=0.8370  █████████████████████████████████████████
#     2014: sim=0.1195  drift=0.8805  ████████████████████████████████████████████
#     2015: sim=0.1163  drift=0.8837  ████████████████████████████████████████████
#     2016: sim=0.1095  drift=0.8905  ████████████████████████████████████████████
#     2017: sim=0.0990  drift=0.9010  █████████████████████████████████████████████
#     2018: sim=0.0900  drift=0.9100  █████████████████████████████████████████████
#     2019: sim=0.0791  drift=0.9209  ██████████████████████████████████████████████
#     2020: sim=0.0800  drift=0.9200  █████████████████████████████████████████████
#     2021: sim=0.0750  drift=0.9250  ██████████████████████████████████████████████
#     2022: sim=0.0733  drift=0.9267  ██████████████████████████████████████████████
#     2023: sim=0.0693  drift=0.9307  ██████████████████████████████████████████████
#     2024: sim=0.0628  drift=0.9372  ██████████████████████████████████████████████
#     2025: sim=0.0633  drift=0.9367  ██████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: MATH (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=0.6513  drift=0.3487  █████████████████
#     2001: sim=0.3553  drift=0.6447  ████████████████████████████████
#     2002: sim=0.2130  drift=0.7870  ███████████████████████████████████████
#     2003: sim=0.1736  drift=0.8264  █████████████████████████████████████████
#     2004: sim=0.1113  drift=0.8887  ████████████████████████████████████████████
#     2005: sim=0.0934  drift=0.9066  █████████████████████████████████████████████
#     2006: sim=0.1094  drift=0.8906  ████████████████████████████████████████████
#     2007: sim=0.1063  drift=0.8937  ████████████████████████████████████████████
#     2008: sim=0.1049  drift=0.8951  ████████████████████████████████████████████
#     2009: sim=0.0983  drift=0.9017  █████████████████████████████████████████████
#     2010: sim=0.1057  drift=0.8943  ████████████████████████████████████████████
#     2011: sim=0.1078  drift=0.8922  ████████████████████████████████████████████
#     2012: sim=0.1002  drift=0.8998  ████████████████████████████████████████████
#     2013: sim=0.0999  drift=0.9001  █████████████████████████████████████████████
#     2014: sim=0.0990  drift=0.9010  █████████████████████████████████████████████
#     2015: sim=0.0991  drift=0.9009  █████████████████████████████████████████████
#     2016: sim=0.1021  drift=0.8979  ████████████████████████████████████████████
#     2017: sim=0.1113  drift=0.8887  ████████████████████████████████████████████
#     2018: sim=0.0975  drift=0.9025  █████████████████████████████████████████████
#     2019: sim=0.1001  drift=0.8999  ████████████████████████████████████████████
#     2020: sim=0.0992  drift=0.9008  █████████████████████████████████████████████
#     2021: sim=0.0954  drift=0.9046  █████████████████████████████████████████████
#     2022: sim=0.1038  drift=0.8962  ████████████████████████████████████████████
#     2023: sim=0.1044  drift=0.8956  ████████████████████████████████████████████
#     2024: sim=0.1074  drift=0.8926  ████████████████████████████████████████████
#     2025: sim=0.1014  drift=0.8986  ████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: PHYSICS (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=0.6513  drift=0.3487  █████████████████
#     2001: sim=0.4003  drift=0.5997  █████████████████████████████
#     2002: sim=0.2982  drift=0.7018  ███████████████████████████████████
#     2003: sim=0.1846  drift=0.8154  ████████████████████████████████████████
#     2004: sim=0.1396  drift=0.8604  ███████████████████████████████████████████
#     2005: sim=0.1578  drift=0.8422  ██████████████████████████████████████████
#     2006: sim=0.1229  drift=0.8771  ███████████████████████████████████████████
#     2007: sim=0.1014  drift=0.8986  ████████████████████████████████████████████
#     2008: sim=0.0976  drift=0.9024  █████████████████████████████████████████████
#     2009: sim=0.0907  drift=0.9093  █████████████████████████████████████████████
#     2010: sim=0.0946  drift=0.9054  █████████████████████████████████████████████
#     2011: sim=0.1037  drift=0.8963  ████████████████████████████████████████████
#     2012: sim=0.1064  drift=0.8936  ████████████████████████████████████████████
#     2013: sim=0.1037  drift=0.8963  ████████████████████████████████████████████
#     2014: sim=0.1115  drift=0.8885  ████████████████████████████████████████████
#     2015: sim=0.1053  drift=0.8947  ████████████████████████████████████████████
#     2016: sim=0.1068  drift=0.8932  ████████████████████████████████████████████
#     2017: sim=0.1059  drift=0.8941  ████████████████████████████████████████████
#     2018: sim=0.1050  drift=0.8950  ████████████████████████████████████████████
#     2019: sim=0.1059  drift=0.8941  ████████████████████████████████████████████
#     2020: sim=0.1061  drift=0.8939  ████████████████████████████████████████████
#     2021: sim=0.0996  drift=0.9004  █████████████████████████████████████████████
#     2022: sim=0.1031  drift=0.8969  ████████████████████████████████████████████
#     2023: sim=0.1089  drift=0.8911  ████████████████████████████████████████████
#     2024: sim=0.1071  drift=0.8929  ████████████████████████████████████████████
#     2025: sim=0.1045  drift=0.8955  ████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv

# %% [markdown]
# ## 3. Year-over-Year Drift
# `cosine_sim(words_t, words_t+1)` — detects **sudden jumps** vs gradual evolution

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Year-over-Year Drift: {subject.upper()}")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row['year']), int(row['topic_id']))
        topic_words[key] = parse_words(row['top_words'])

    years = sorted(evo_df['year'].unique())


    yoy_rows = []

    # Iterate by CONSECUTIVE CALENDAR YEARS
    for i in range(len(years) - 1):
        t, t1 = int(years[i]), int(years[i + 1])

        # Find topics present in BOTH years
        topics_t = {tid for (y, tid) in topic_words if y == t}
        topics_t1 = {tid for (y, tid) in topic_words if y == t1}
        common_topics = sorted(topics_t & topics_t1)

        for tid in common_topics:
            words_t = topic_words[(t, tid)]
            words_t1 = topic_words[(t1, tid)]
            sim = rbo(words_t, words_t1, p=0.9)

            yoy_rows.append({
                'subject': subject, 'topic_id': tid,
                'year_from': t, 'year_to': t1,
                'cosine_sim': round(sim, 6),
                'drift': round(1.0 - sim, 6),
            })

    yoy_df = pd.DataFrame(yoy_rows)
    yoy_df.to_csv(RESULT_DIR / subject / "ttd_year_over_year.csv", index=False)

    # Per-topic summary
    topic_yoy = yoy_df.groupby('topic_id').agg(
        avg_yoy_sim=('cosine_sim', 'mean'),
        min_yoy_sim=('cosine_sim', 'min'),
        avg_yoy_drift=('drift', 'mean'),
        max_single_jump=('drift', 'max'),
    ).reset_index()
    topic_yoy.insert(0, 'subject', subject)
    topic_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_per_topic.csv", index=False)

    # Avg across all topics per year transition
    avg_yoy = yoy_df.groupby(['year_from', 'year_to']).agg(
        avg_sim=('cosine_sim', 'mean'),
        avg_drift=('drift', 'mean'),
        n_topics=('topic_id', 'count')
    ).reset_index()
    avg_yoy.insert(0, 'subject', subject)
    avg_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_avg.csv", index=False)

    print(f"  Avg year-over-year drift (consecutive calendar years):")
    for _, r in avg_yoy.iterrows():
        bar = chr(9608) * int(r['avg_drift'] * 50)
        print(f"    {int(r['year_from'])}→{int(r['year_to'])}: sim={r['avg_sim']:.4f}  "
              f"drift={r['avg_drift']:.4f}  ({int(r['n_topics'])} topics)  {bar}")

    # Top 5 biggest single-year jumps
    print(f"\n  Top 5 biggest single-year JUMPS:")
    for _, r in yoy_df.nlargest(5, 'drift').iterrows():
        print(f"    T{int(r['topic_id']):>3} | {int(r['year_from'])}→{int(r['year_to'])} | "
              f"drift={r['drift']:.4f}")

    overall_sim = yoy_df['cosine_sim'].mean()
    overall_drift = yoy_df['drift'].mean()
    print(f"\n  Overall: avg_yoy_sim={overall_sim:.4f}  avg_yoy_drift={overall_drift:.4f}")
    print(f"  Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv")
# Out:
# ======================================================================
# Year-over-Year Drift: CS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.3496  drift=0.6504  (18 topics)  ████████████████████████████████
#     2001→2002: sim=0.3044  drift=0.6956  (23 topics)  ██████████████████████████████████
#     2002→2003: sim=0.2883  drift=0.7117  (20 topics)  ███████████████████████████████████
#     2003→2004: sim=0.2349  drift=0.7651  (23 topics)  ██████████████████████████████████████
#     2004→2005: sim=0.2986  drift=0.7014  (29 topics)  ███████████████████████████████████
#     2005→2006: sim=0.3329  drift=0.6671  (28 topics)  █████████████████████████████████
#     2006→2007: sim=0.2407  drift=0.7593  (29 topics)  █████████████████████████████████████
#     2007→2008: sim=0.2840  drift=0.7160  (34 topics)  ███████████████████████████████████
#     2008→2009: sim=0.2701  drift=0.7299  (32 topics)  ████████████████████████████████████
#     2009→2010: sim=0.3026  drift=0.6974  (34 topics)  ██████████████████████████████████
#     2010→2011: sim=0.3392  drift=0.6608  (45 topics)  █████████████████████████████████
#     2011→2012: sim=0.3698  drift=0.6302  (52 topics)  ███████████████████████████████
#     2012→2013: sim=0.3270  drift=0.6730  (67 topics)  █████████████████████████████████
#     2013→2014: sim=0.3476  drift=0.6524  (78 topics)  ████████████████████████████████
#     2014→2015: sim=0.3655  drift=0.6345  (89 topics)  ███████████████████████████████
#     2015→2016: sim=0.3890  drift=0.6110  (112 topics)  ██████████████████████████████
#     2016→2017: sim=0.3982  drift=0.6018  (126 topics)  ██████████████████████████████
#     2017→2018: sim=0.4396  drift=0.5604  (135 topics)  ████████████████████████████
#     2018→2019: sim=0.4657  drift=0.5343  (137 topics)  ██████████████████████████
#     2019→2020: sim=0.4934  drift=0.5066  (137 topics)  █████████████████████████
#     2020→2021: sim=0.5083  drift=0.4917  (138 topics)  ████████████████████████
#     2021→2022: sim=0.5179  drift=0.4821  (138 topics)  ████████████████████████
#     2022→2023: sim=0.5140  drift=0.4860  (138 topics)  ████████████████████████
#     2023→2024: sim=0.5142  drift=0.4858  (138 topics)  ████████████████████████
#     2024→2025: sim=0.5327  drift=0.4673  (138 topics)  ███████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T  4 | 2003→2004 | drift=1.0000
#     T101 | 2003→2004 | drift=1.0000
#     T 13 | 2006→2007 | drift=1.0000
#     T 61 | 2006→2007 | drift=1.0000
#     T 61 | 2008→2009 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.4312  avg_yoy_drift=0.5688
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: MATH
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.3360  drift=0.6640  (46 topics)  █████████████████████████████████
#     2001→2002: sim=0.3277  drift=0.6723  (47 topics)  █████████████████████████████████
#     2002→2003: sim=0.3324  drift=0.6676  (49 topics)  █████████████████████████████████
#     2003→2004: sim=0.3250  drift=0.6750  (50 topics)  █████████████████████████████████
#     2004→2005: sim=0.3289  drift=0.6711  (54 topics)  █████████████████████████████████
#     2005→2006: sim=0.3487  drift=0.6513  (54 topics)  ████████████████████████████████
#     2006→2007: sim=0.3706  drift=0.6294  (56 topics)  ███████████████████████████████
#     2007→2008: sim=0.3606  drift=0.6394  (60 topics)  ███████████████████████████████
#     2008→2009: sim=0.3827  drift=0.6173  (59 topics)  ██████████████████████████████
#     2009→2010: sim=0.4031  drift=0.5969  (59 topics)  █████████████████████████████
#     2010→2011: sim=0.4007  drift=0.5993  (61 topics)  █████████████████████████████
#     2011→2012: sim=0.4165  drift=0.5835  (62 topics)  █████████████████████████████
#     2012→2013: sim=0.4561  drift=0.5439  (62 topics)  ███████████████████████████
#     2013→2014: sim=0.4499  drift=0.5501  (62 topics)  ███████████████████████████
#     2014→2015: sim=0.4587  drift=0.5413  (62 topics)  ███████████████████████████
#     2015→2016: sim=0.4544  drift=0.5456  (62 topics)  ███████████████████████████
#     2016→2017: sim=0.4628  drift=0.5372  (62 topics)  ██████████████████████████
#     2017→2018: sim=0.4733  drift=0.5267  (63 topics)  ██████████████████████████
#     2018→2019: sim=0.4862  drift=0.5138  (63 topics)  █████████████████████████
#     2019→2020: sim=0.4848  drift=0.5152  (63 topics)  █████████████████████████
#     2020→2021: sim=0.4854  drift=0.5146  (63 topics)  █████████████████████████
#     2021→2022: sim=0.5075  drift=0.4925  (63 topics)  ████████████████████████
#     2022→2023: sim=0.5087  drift=0.4913  (63 topics)  ████████████████████████
#     2023→2024: sim=0.5097  drift=0.4903  (63 topics)  ████████████████████████
#     2024→2025: sim=0.5325  drift=0.4675  (63 topics)  ███████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T  3 | 2003→2004 | drift=0.9961
#     T 31 | 2003→2004 | drift=0.9961
#     T 21 | 2001→2002 | drift=0.9913
#     T 21 | 2002→2003 | drift=0.9875
#     T 46 | 2005→2006 | drift=0.9854
#
#   Overall: avg_yoy_sim=0.4295  avg_yoy_drift=0.5705
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: PHYSICS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.3357  drift=0.6643  (35 topics)  █████████████████████████████████
#     2001→2002: sim=0.3027  drift=0.6973  (38 topics)  ██████████████████████████████████
#     2002→2003: sim=0.3198  drift=0.6802  (38 topics)  ██████████████████████████████████
#     2003→2004: sim=0.3366  drift=0.6634  (42 topics)  █████████████████████████████████
#     2004→2005: sim=0.3273  drift=0.6727  (45 topics)  █████████████████████████████████
#     2005→2006: sim=0.3443  drift=0.6557  (54 topics)  ████████████████████████████████
#     2006→2007: sim=0.3191  drift=0.6809  (61 topics)  ██████████████████████████████████
#     2007→2008: sim=0.3360  drift=0.6640  (65 topics)  █████████████████████████████████
#     2008→2009: sim=0.3455  drift=0.6545  (68 topics)  ████████████████████████████████
#     2009→2010: sim=0.3583  drift=0.6417  (71 topics)  ████████████████████████████████
#     2010→2011: sim=0.3939  drift=0.6061  (74 topics)  ██████████████████████████████
#     2011→2012: sim=0.4104  drift=0.5896  (73 topics)  █████████████████████████████
#     2012→2013: sim=0.4168  drift=0.5832  (73 topics)  █████████████████████████████
#     2013→2014: sim=0.4530  drift=0.5470  (74 topics)  ███████████████████████████
#     2014→2015: sim=0.4499  drift=0.5501  (74 topics)  ███████████████████████████
#     2015→2016: sim=0.4513  drift=0.5487  (74 topics)  ███████████████████████████
#     2016→2017: sim=0.4522  drift=0.5478  (74 topics)  ███████████████████████████
#     2017→2018: sim=0.4681  drift=0.5319  (74 topics)  ██████████████████████████
#     2018→2019: sim=0.4702  drift=0.5298  (74 topics)  ██████████████████████████
#     2019→2020: sim=0.4792  drift=0.5208  (74 topics)  ██████████████████████████
#     2020→2021: sim=0.4868  drift=0.5132  (74 topics)  █████████████████████████
#     2021→2022: sim=0.4890  drift=0.5110  (74 topics)  █████████████████████████
#     2022→2023: sim=0.4926  drift=0.5074  (74 topics)  █████████████████████████
#     2023→2024: sim=0.4967  drift=0.5033  (74 topics)  █████████████████████████
#     2024→2025: sim=0.5154  drift=0.4846  (74 topics)  ████████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T 25 | 2000→2001 | drift=1.0000
#     T  9 | 2004→2005 | drift=1.0000
#     T 47 | 2005→2006 | drift=1.0000
#     T  8 | 2007→2008 | drift=1.0000
#     T 16 | 2008→2009 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.4214  avg_yoy_drift=0.5786
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv

# %% [markdown]
# ## Inspect Individual Topics
# Two helper functions to drill into specific topics.

# %%
def show_topic_yoy(topic_id, subject):
    """
    Show year-over-year drift for a specific topic with drift labels.
    Labels: Stable (<0.3), Moderate (0.3-0.6), Aggressive (0.6-0.8), Extreme (>0.8)
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    for _, row in topic_evo.iterrows():
        tw[int(row["year"])] = parse_words(row["top_words"])

    topic_years = sorted(tw.keys())

    print(f"\n{'='*70}")
    print(f"YoY Drift: Topic {topic_id} — {subject.upper()}")
    print(f"Active: {topic_years[0]}–{topic_years[-1]} ({len(topic_years)} years)")
    print(f"{'='*70}")

    drifts = []
    for i in range(len(topic_years) - 1):
        t, t1 = topic_years[i], topic_years[i + 1]
        sim = rbo(tw[t], tw[t1], p=0.9)
        drift = 1.0 - sim
        drifts.append(drift)

        # Label
        if drift < 0.3:
            label = "🟢 Stable"
        elif drift < 0.6:
            label = "🟡 Moderate"
        elif drift < 0.8:
            label = "🟠 Aggressive"
        else:
            label = "🔴 Extreme"

        bar = chr(9608) * int(drift * 30)
        print(f"  {t}→{t1}: sim={sim:.4f}  drift={drift:.4f}  {bar}  {label}")

        # Show word changes
        added = set(tw[t1]) - set(tw[t])
        removed = set(tw[t]) - set(tw[t1])
        if added or removed:
            if removed:
                print(f"           − {', '.join(sorted(removed))}")
            if added:
                print(f"           + {', '.join(sorted(added))}")

    # Summary
    avg_d = np.mean(drifts)
    max_d = np.max(drifts)
    if avg_d < 0.3:
        verdict = "🟢 STABLE — vocabulary is consistent over time"
    elif avg_d < 0.5:
        verdict = "🟡 MODERATE — topic evolves gradually"
    elif avg_d < 0.7:
        verdict = "🟠 DRIFTING — significant vocabulary changes"
    else:
        verdict = "🔴 HIGHLY UNSTABLE — topic vocabulary reshuffles frequently"

    print(f"\n  Avg drift: {avg_d:.4f} | Max jump: {max_d:.4f}")
    print(f"  Verdict: {verdict}")


def show_topic_endpoint(topic_id, subject):
    """
    Show endpoint drift for a specific topic: first year vs last year.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    for _, row in topic_evo.iterrows():
        tw[int(row["year"])] = parse_words(row["top_words"])

    topic_years = sorted(tw.keys())
    t_first, t_last = topic_years[0], topic_years[-1]

    sim = rbo(tw[t_first], tw[t_last], p=0.9)
    ttd = 1.0 - sim

    # Words analysis
    w_first = set(tw[t_first])
    w_last = set(tw[t_last])
    kept = sorted(w_first & w_last)
    removed = sorted(w_first - w_last)
    added = sorted(w_last - w_first)

    if ttd < 0.3:
        verdict = "🟢 STABLE — topic maintained its core vocabulary"
    elif ttd < 0.5:
        verdict = "🟡 MODERATE — topic evolved but recognizable"
    elif ttd < 0.7:
        verdict = "🟠 SIGNIFICANT DRIFT — topic substantially changed"
    else:
        verdict = "🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced"

    print(f"\n{'='*70}")
    print(f"Endpoint Drift: Topic {topic_id} — {subject.upper()}")
    print(f"{'='*70}")
    print(f"  Active: {t_first}–{t_last} ({len(topic_years)} years)")
    print(f"  Cosine similarity: {sim:.4f}")
    print(f"  TTD (drift):       {ttd:.4f}")
    print(f"  Verdict: {verdict}")
    print(f"\n  First year ({t_first}): {', '.join(tw[t_first])}")
    print(f"  Last year  ({t_last}): {', '.join(tw[t_last])}")
    print(f"\n  🔒 Kept ({len(kept)}):    {', '.join(kept) if kept else '(none)'}")
    print(f"  ➖ Removed ({len(removed)}): {', '.join(removed) if removed else '(none)'}")
    print(f"  ➕ Added ({len(added)}):   {', '.join(added) if added else '(none)'}")


def show_topic_trajectory(topic_id, subject):
    """
    Show drift trajectory from baseline (first year) for a specific topic.
    cosine_sim(words_t0, words_t) per year — shows when drift accelerates.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    tw = {}
    for _, row in topic_evo.iterrows():
        tw[int(row["year"])] = parse_words(row["top_words"])

    topic_years = sorted(tw.keys())
    t0 = topic_years[0]
    words_baseline = tw[t0]

    print(f"\n{'='*70}")
    print(f"Drift Trajectory: Topic {topic_id} — {subject.upper()}")
    print(f"Baseline: {t0} → {', '.join(tw[t0])}")
    print(f"{'='*70}")

    prev_drift = 0.0
    for y in topic_years:
        words_y = tw[y]
        sim = rbo(words_baseline, words_y, p=0.9)
        drift = 1.0 - sim

        # Delta from previous year
        delta = drift - prev_drift
        if delta > 0.1:
            delta_label = f" ↑{delta:+.3f} ⚡"
        elif delta > 0.02:
            delta_label = f" ↑{delta:+.3f}"
        elif delta < -0.02:
            delta_label = f" ↓{delta:+.3f} 🔄"
        else:
            delta_label = f"  {delta:+.3f} —"
        prev_drift = drift

        # Shared words with baseline
        shared = sorted(set(tw[t0]) & set(tw[y]))
        n_shared = len(shared)
        n_total = len(tw[t0])

        bar = chr(9608) * int(drift * 30)
        print(f"  {y}: sim={sim:.4f}  drift={drift:.4f}  {bar}{delta_label}  "
              f"({n_shared}/{n_total} baseline words kept)")

    # Final summary
    final_sim = rbo(words_baseline, tw[topic_years[-1]], p=0.9)
    final_drift = 1.0 - final_sim
    kept = sorted(set(tw[t0]) & set(tw[topic_years[-1]]))
    lost = sorted(set(tw[t0]) - set(tw[topic_years[-1]]))

    print(f"\n  Total drift ({t0}→{topic_years[-1]}): {final_drift:.4f}")
    print(f"  Baseline words kept: {', '.join(kept) if kept else '(none)'}")
    print(f"  Baseline words lost: {', '.join(lost) if lost else '(none)'}")

# %% [markdown]
# ### Usage
# ```python
# show_topic_yoy(topic_id=5, subject="cs")
# show_topic_endpoint(topic_id=5, subject="cs")
# ```

# %%
# Example: inspect a specific topic
show_topic_yoy(topic_id=0, subject="cs")
show_topic_trajectory(topic_id=0, subject="cs")
show_topic_endpoint(topic_id=0, subject="cs")
# Out:
# ======================================================================
# YoY Drift: Topic 0 — CS
# Active: 2000–2025 (26 years)
# ======================================================================
#   2000→2001: sim=0.3764  drift=0.6236  ██████████████████  🟠 Aggressive
#            − categories, descriptions, mining, ontologies, research
#            + database, documents, pages, query, search
#   2001→2002: sim=0.2349  drift=0.7651  ██████████████████████  🟠 Aggressive
#            − apweb, database, databases, pages, query, talkmine
#            + c4, genex, keyphrase, keyphrases, learning, recommender
#   2002→2003: sim=0.5353  drift=0.4647  █████████████  🟡 Moderate
#            − c4, learning, recommender
#            + algorithm, document, recommendation
#   2003→2004: sim=0.2788  drift=0.7212  █████████████████████  🟠 Aggressive
#            − algorithm, genex, recommendation, search, text
#            + content, hierarchy, nrc, relevancy, semantic
#   2004→2005: sim=0.2129  drift=0.7871  ███████████████████████  🟠 Aggressive
#            − content, hierarchy, keyphrase, nrc, relevancy, semantic
#            + des, donn, es, requ, treillis, une
#   2005→2006: sim=0.3710  drift=0.6290  ██████████████████  🟠 Aggressive
#            − des, donn, es, keyphrases, requ, treillis, une
#            + approach, elps, gps, information, ontology, query, sources
#   2006→2007: sim=0.0146  drift=0.9854  █████████████████████████████  🔴 Extreme
#            − approach, document, elps, gps, information, ontology, query, sources, web
#            + bookmarking, citeulike, communities, content, del, icio, metadata, tagging, user
#   2007→2008: sim=0.0087  drift=0.9913  █████████████████████████████  🔴 Extreme
#            − bookmarking, citeulike, communities, content, del, documents, icio, metadata, tagging
#            + filtering, index, indexing, information, mails, profile, subcorpora, wiki, wikipedia
#   2008→2009: sim=0.5606  drift=0.4394  █████████████  🟡 Moderate
#            − filtering, index, mails, wiki
#            + bulletin, document, documents, scir
#   2009→2010: sim=0.2294  drift=0.7706  ███████████████████████  🟠 Aggressive
#            − bulletin, scir
#            + search, xml
#   2010→2011: sim=0.1806  drift=0.8194  ████████████████████████  🔴 Extreme
#            − document, indexing, profile, search, subcorpora, user, wikipedia, xml
#            + art1, biclustering, pages, query, reformulation, retrieval, users, web
#   2011→2012: sim=0.4666  drift=0.5334  ████████████████  🟡 Moderate
#            − art1, biclustering, query, reformulation
#            + articles, clustering, search, tags
#   2012→2013: sim=0.4400  drift=0.5600  ████████████████  🟡 Moderate
#            − articles, clustering, retrieval, tags
#            + browsing, engines, query, results
#   2013→2014: sim=0.3892  drift=0.6108  ██████████████████  🟠 Aggressive
#            − browsing, engines, information, pages, query, results, users
#            + albanian, clustering, document, relatedness, semantic, text, tomaco
#   2014→2015: sim=0.4886  drift=0.5114  ███████████████  🟡 Moderate
#            − albanian, clustering, semantic, tomaco
#            + information, keyword, rdf, user
#   2015→2016: sim=0.4905  drift=0.5095  ███████████████  🟡 Moderate
#            − information, keyword, rdf, relatedness, text
#            + classification, identifiers, job, namespaces, pages
#   2016→2017: sim=0.5064  drift=0.4936  ██████████████  🟡 Moderate
#            − classification, identifiers, job, namespaces, pages, user
#            + data, ontology, query, retrieval, semantic, text
#   2017→2018: sim=0.4573  drift=0.5427  ████████████████  🟡 Moderate
#            − data
#            + queries
#   2018→2019: sim=0.5261  drift=0.4739  ██████████████  🟡 Moderate
#            − ontology, queries, semantic, text
#            + based, data, information, keyword
#   2019→2020: sim=0.4350  drift=0.5650  ████████████████  🟡 Moderate
#            − based, data, keyword
#            + clarification, queries, text
#   2020→2021: sim=0.5288  drift=0.4712  ██████████████  🟡 Moderate
#            − clarification, document
#            + based, data
#   2021→2022: sim=0.3561  drift=0.6439  ███████████████████  🟠 Aggressive
#            − based, retrieval, web
#            + classification, document, topic
#   2022→2023: sim=0.4083  drift=0.5917  █████████████████  🟡 Moderate
#            − topic
#            + retrieval
#   2023→2024: sim=0.5119  drift=0.4881  ██████████████  🟡 Moderate
#            − data, document
#            + engines, web
#   2024→2025: sim=0.4351  drift=0.5649  ████████████████  🟡 Moderate
#            − classification, engines, information
#            + based, document, semantic
#
#   Avg drift: 0.6223 | Max jump: 0.9913
#   Verdict: 🟠 DRIFTING — significant vocabulary changes
#
# ======================================================================
# Drift Trajectory: Topic 0 — CS
# Baseline: 2000 → web, apweb, databases, talkmine, mining, text, research, categories, ontologies, descriptions
# ======================================================================
#   2000: sim=0.6513  drift=0.3487  ██████████ ↑+0.349 ⚡  (10/10 baseline words kept)
#   2001: sim=0.3764  drift=0.6236  ██████████████████ ↑+0.275 ⚡  (5/10 baseline words kept)
#   2002: sim=0.1675  drift=0.8325  ████████████████████████ ↑+0.209 ⚡  (2/10 baseline words kept)
#   2003: sim=0.1501  drift=0.8499  █████████████████████████  +0.017 —  (2/10 baseline words kept)
#   2004: sim=0.0904  drift=0.9096  ███████████████████████████ ↑+0.060  (1/10 baseline words kept)
#   2005: sim=0.0452  drift=0.9548  ████████████████████████████ ↑+0.045  (1/10 baseline words kept)
#   2006: sim=0.0634  drift=0.9366  ████████████████████████████  -0.018 —  (1/10 baseline words kept)
#   2007: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.063  (0/10 baseline words kept)
#   2008: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2009: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2010: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2011: sim=0.2354  drift=0.7646  ██████████████████████ ↓-0.235 🔄  (1/10 baseline words kept)
#   2012: sim=0.2354  drift=0.7646  ██████████████████████  +0.000 —  (1/10 baseline words kept)
#   2013: sim=0.2354  drift=0.7646  ██████████████████████  +0.000 —  (1/10 baseline words kept)
#   2014: sim=0.2675  drift=0.7325  █████████████████████ ↓-0.032 🔄  (2/10 baseline words kept)
#   2015: sim=0.2675  drift=0.7325  █████████████████████  +0.000 —  (2/10 baseline words kept)
#   2016: sim=0.2354  drift=0.7646  ██████████████████████ ↑+0.032  (1/10 baseline words kept)
#   2017: sim=0.2501  drift=0.7499  ██████████████████████  -0.015 —  (2/10 baseline words kept)
#   2018: sim=0.1576  drift=0.8424  █████████████████████████ ↑+0.092  (2/10 baseline words kept)
#   2019: sim=0.1354  drift=0.8646  █████████████████████████ ↑+0.022  (1/10 baseline words kept)
#   2020: sim=0.0943  drift=0.9057  ███████████████████████████ ↑+0.041  (2/10 baseline words kept)
#   2021: sim=0.0773  drift=0.9227  ███████████████████████████  +0.017 —  (2/10 baseline words kept)
#   2022: sim=0.0321  drift=0.9679  █████████████████████████████ ↑+0.045  (1/10 baseline words kept)
#   2023: sim=0.0321  drift=0.9679  █████████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2024: sim=0.0359  drift=0.9641  ████████████████████████████  -0.004 —  (2/10 baseline words kept)
#   2025: sim=0.0773  drift=0.9227  ███████████████████████████ ↓-0.041 🔄  (2/10 baseline words kept)
#
#   Total drift (2000→2025): 0.9227
#   Baseline words kept: text, web
#   Baseline words lost: apweb, categories, databases, descriptions, mining, ontologies, research, talkmine
#
# ======================================================================
# Endpoint Drift: Topic 0 — CS
# ======================================================================
#   Active: 2000–2025 (26 years)
#   Cosine similarity: 0.0773
#   TTD (drift):       0.9227
#   Verdict: 🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced
#
#   First year (2000): web, apweb, databases, talkmine, mining, text, research, categories, ontologies, descriptions
#   Last year  (2025): search, query, queries, text, web, document, documents, retrieval, based, semantic
#
#   🔒 Kept (2):    text, web
#   ➖ Removed (8): apweb, categories, databases, descriptions, mining, ontologies, research, talkmine
#   ➕ Added (8):   based, document, documents, queries, query, retrieval, search, semantic
