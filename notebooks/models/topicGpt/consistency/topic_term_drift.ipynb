# %% [markdown]
# # TopicGPT: Topic Term Drift (TTD)
#
# **Scenario 3a** — Three complementary drift metrics:
# 1. **Endpoint TTD**: cosine distance from first to last year (total drift)
# 2. **Trajectory from baseline**: cosine_sim(t₀, t) per year (when drift happens)
# 3. **Year-over-year drift**: cosine_sim(t, t+1) per year (smoothness of evolution)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/topicGpt/temporal")
RESULT_DIR = Path("../../../../results/topicGpt/consistency")

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Reading from: ../../../../results/topicGpt/temporal
# Saving to: ../../../../results/topicGpt/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def words_to_vector(words, vocab_index):
    vec = np.zeros(len(vocab_index))
    for w in words:
        if w in vocab_index:
            vec[vocab_index[w]] = 1.0
    return vec


def cos_sim(v1, v2):
    """Cosine similarity between two vectors."""
    return float(cosine_similarity(v1.reshape(1, -1), v2.reshape(1, -1))[0, 0])

# %% [markdown]
# ## 1. Endpoint TTD
# Total drift: `TTD = 1 - cosine_sim(words_first, words_last)`

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Endpoint TTD: {subject.upper()} (TopicGPT)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())

    # Build global vocabulary
    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t_first, t_last = topic_years[0], topic_years[-1]
        v_first = words_to_vector(topic_words[(t_first, tid)], vocab_index)
        v_last = words_to_vector(topic_words[(t_last, tid)], vocab_index)
        sim = cos_sim(v_first, v_last)

        rows.append({
            "subject": subject, "topic_id": tid,
            "first_year": t_first, "last_year": t_last,
            "n_years": len(topic_years),
            "cosine_sim": round(sim, 6),
            "ttd": round(1.0 - sim, 6),
            "words_first": ", ".join(topic_words[(t_first, tid)]),
            "words_last": ", ".join(topic_words[(t_last, tid)]),
        })

    df = pd.DataFrame(rows)
    df.to_csv(RESULT_DIR / subject / "topic_term_drift.csv", index=False)

    summary = {"subject": subject, "n_topics": len(df),
               "ttd_mean": round(df["ttd"].mean(), 6),
               "ttd_std": round(df["ttd"].std(), 6),
               "ttd_median": round(df["ttd"].median(), 6),
               "pct_stable": round((df["ttd"] < 0.5).mean() * 100, 2),
               "pct_drifted": round((df["ttd"] >= 0.5).mean() * 100, 2)}
    pd.DataFrame([summary]).to_csv(RESULT_DIR / subject / "ttd_summary.csv", index=False)

    print(f"  TTD: mean={summary['ttd_mean']:.4f} ± {summary['ttd_std']:.4f}, "
          f"median={summary['ttd_median']:.4f}")
    print(f"  Stable (TTD<0.5): {summary['pct_stable']:.1f}%  |  "
          f"Drifted (TTD≥0.5): {summary['pct_drifted']:.1f}%")

    print(f"\n  🔥 Top 5 most DRIFTED:")
    for _, r in df.nlargest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | "
              f"{r['words_first'][:40]}... → {r['words_last'][:40]}...")

    print(f"  🔒 Top 5 most STABLE:")
    for _, r in df.nsmallest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | {r['words_first'][:60]}")
# Out:
# ======================================================================
# Endpoint TTD: CS (TopicGPT)
# ======================================================================
#   TTD: mean=0.7913 ± 0.1353, median=0.8000
#   Stable (TTD<0.5): 0.7%  |  Drifted (TTD≥0.5): 99.3%
#
#   🔥 Top 5 most DRIFTED:
#     T  7 | TTD=1.0000 | lightest, derivation, abstractions, sear... → 3d, segmentation, point, document, cloud...
#     T 15 | TTD=1.0000 | stamping, service, keys, stamped, snapsh... → blockchain, byzantine, consensus, protoc...
#     T 19 | TTD=1.0000 | mining, data, scarce, pockets, sampling,... → cancer, medical, ct, imaging, lung, clin...
#     T 25 | TTD=1.0000 | catadioptric, panoramic, mirror, unwarpi... → 3d, reconstruction, view, rendering, ner...
#     T 45 | TTD=1.0000 | cooperative, safe, heirarchical, agv, ro... → agent, learning, reinforcement, agents, ...
#   🔒 Top 5 most STABLE:
#     T113 | TTD=0.4000 | salient, saliency, hypergraph, object, detection, image, reg
#     T  8 | TTD=0.5000 | calculus, rewriting, circularity, exptime, chr, rules, logic
#     T 10 | TTD=0.5000 | programs, language, grammar, program, slicing, alma, asf, so
#     T 18 | TTD=0.5000 | policy, reinforcement, rl, observable, grep, learning, parti
#     T 27 | TTD=0.5000 | lasco, policy, execution, security, policies, systems, crude
#
# ======================================================================
# Endpoint TTD: MATH (TopicGPT)
# ======================================================================
#   TTD: mean=0.6349 ± 0.1936, median=0.6000
#   Stable (TTD<0.5): 14.3%  |  Drifted (TTD≥0.5): 85.7%
#
#   🔥 Top 5 most DRIFTED:
#     T 30 | TTD=1.0000 | probability, chains, twice, sampled, mea... → branching, population, process, processe...
#     T 16 | TTD=0.9000 | widetilde, mirror, witten, curve, mm, gr... → mathcal, gauge, theories, mathbb, theory...
#     T 17 | TTD=0.9000 | modular, nieto, barth, meromorphic, genu... → modular, curves, mathbb, forms, selmer, ...
#     T 27 | TTD=0.9000 | kappa, popescu, gamma, eisenbud, spec, s... → modules, rr, rings, gorenstein, module, ...
#     T 31 | TTD=0.9000 | tinybbb, smallbbb, lescop, equivariant, ... → mirror, invariants, mathbb, equivariant,...
#   🔒 Top 5 most STABLE:
#     T 36 | TTD=0.2000 | symplectic, hamiltonian, group, manifolds, lie, action, mani
#     T 37 | TTD=0.2000 | hodge, manifolds, cohomology, rham, complex, differential, k
#     T 11 | TTD=0.3000 | algebra, superconformal, quantum, algebras, sl, schrodinger,
#     T 22 | TTD=0.3000 | einstein, curvature, kaehler, ricci, metrics, ew, dkp, metri
#     T 61 | TTD=0.3000 | neural, learning, networks, equations, data, informed, train
#
# ======================================================================
# Endpoint TTD: PHYSICS (TopicGPT)
# ======================================================================
#   TTD: mean=0.7338 ± 0.1633, median=0.8000
#   Stable (TTD<0.5): 5.4%  |  Drifted (TTD≥0.5): 94.6%
#
#   🔥 Top 5 most DRIFTED:
#     T 10 | TTD=1.0000 | deforming, inherit, energetic, automatic... → fluid, relativistic, hydrodynamics, sph,...
#     T 39 | TTD=1.0000 | ergodic, metric, walking, tempering, mon... → quantum, stochastic, sampling, dynamics,...
#     T 53 | TTD=1.0000 | mirabilis, bacteria, proteus, swarming, ... → cooperation, agents, collective, active,...
#     T 66 | TTD=1.0000 | condensate, bose, einstein, suggestions,... → cavity, quantum, optical, atoms, light, ...
#     T 72 | TTD=1.0000 | ge, omega, amorphous, liquid, initio, ab... → materials, learning, dft, crystal, funct...
#   🔒 Top 5 most STABLE:
#     T 15 | TTD=0.3000 | beam, linac, beams, accelerator, ion, high, colliders, laser
#     T 24 | TTD=0.4000 | single, photon, detectors, superconducting, 1300nm, apds, qu
#     T 44 | TTD=0.4000 | cities, urban, city, centrality, traffic, network, commuting
#     T 58 | TTD=0.4000 | opinion, political, opinions, voters, consensus, model, vote
#     T  0 | TTD=0.5000 | plasma, colliders, beam, gamma, electron, muon, laser, ions,

# %% [markdown]
# ## 2. Drift Trajectory from Baseline
# For each topic: `cosine_sim(words_t₀, words_t)` per year — shows **when** drift happens

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Drift Trajectory: {subject.upper()} (TopicGPT)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())

    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    traj_rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t0 = topic_years[0]
        v_baseline = words_to_vector(topic_words[(t0, tid)], vocab_index)

        for y in topic_years:
            v_y = words_to_vector(topic_words[(y, tid)], vocab_index)
            sim = cos_sim(v_baseline, v_y)
            traj_rows.append({
                "subject": subject, "topic_id": tid,
                "baseline_year": t0, "year": y,
                "years_elapsed": y - t0,
                "cosine_sim_to_baseline": round(sim, 6),
                "drift_from_baseline": round(1.0 - sim, 6),
            })

    traj_df = pd.DataFrame(traj_rows)
    traj_df.to_csv(RESULT_DIR / subject / "ttd_trajectory.csv", index=False)

    # Average drift trajectory across all topics per year
    avg_traj = traj_df.groupby("year").agg(
        avg_sim=("cosine_sim_to_baseline", "mean"),
        avg_drift=("drift_from_baseline", "mean"),
        n_topics=("topic_id", "count")
    ).reset_index()
    avg_traj.insert(0, "subject", subject)
    avg_traj.to_csv(RESULT_DIR / subject / "ttd_trajectory_avg.csv", index=False)

    print(f"  Avg drift from baseline per year:")
    for _, r in avg_traj.iterrows():
        bar = '█' * int(r['avg_drift'] * 50)
        print(f"    {int(r['year'])}: sim={r['avg_sim']:.4f}  drift={r['avg_drift']:.4f}  {bar}")
    print(f"  Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv")
# Out:
# ======================================================================
# Drift Trajectory: CS (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.7914  drift=0.2086  ██████████
#     2002: sim=0.6257  drift=0.3743  ██████████████████
#     2003: sim=0.4129  drift=0.5871  █████████████████████████████
#     2004: sim=0.3657  drift=0.6343  ███████████████████████████████
#     2005: sim=0.3128  drift=0.6872  ██████████████████████████████████
#     2006: sim=0.3605  drift=0.6395  ███████████████████████████████
#     2007: sim=0.2927  drift=0.7073  ███████████████████████████████████
#     2008: sim=0.3222  drift=0.6778  █████████████████████████████████
#     2009: sim=0.2675  drift=0.7325  ████████████████████████████████████
#     2010: sim=0.3118  drift=0.6882  ██████████████████████████████████
#     2011: sim=0.3226  drift=0.6774  █████████████████████████████████
#     2012: sim=0.3560  drift=0.6440  ████████████████████████████████
#     2013: sim=0.3326  drift=0.6674  █████████████████████████████████
#     2014: sim=0.2750  drift=0.7250  ████████████████████████████████████
#     2015: sim=0.2681  drift=0.7319  ████████████████████████████████████
#     2016: sim=0.2472  drift=0.7528  █████████████████████████████████████
#     2017: sim=0.2326  drift=0.7674  ██████████████████████████████████████
#     2018: sim=0.2355  drift=0.7645  ██████████████████████████████████████
#     2019: sim=0.2234  drift=0.7766  ██████████████████████████████████████
#     2020: sim=0.2246  drift=0.7754  ██████████████████████████████████████
#     2021: sim=0.2217  drift=0.7783  ██████████████████████████████████████
#     2022: sim=0.2196  drift=0.7804  ███████████████████████████████████████
#     2023: sim=0.2152  drift=0.7848  ███████████████████████████████████████
#     2024: sim=0.2138  drift=0.7862  ███████████████████████████████████████
#     2025: sim=0.2087  drift=0.7913  ███████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: MATH (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.6571  drift=0.3429  █████████████████
#     2002: sim=0.4925  drift=0.5075  █████████████████████████
#     2003: sim=0.4423  drift=0.5577  ███████████████████████████
#     2004: sim=0.3545  drift=0.6455  ████████████████████████████████
#     2005: sim=0.3614  drift=0.6386  ███████████████████████████████
#     2006: sim=0.3661  drift=0.6339  ███████████████████████████████
#     2007: sim=0.3600  drift=0.6400  ████████████████████████████████
#     2008: sim=0.3623  drift=0.6377  ███████████████████████████████
#     2009: sim=0.3576  drift=0.6424  ████████████████████████████████
#     2010: sim=0.3590  drift=0.6410  ████████████████████████████████
#     2011: sim=0.3677  drift=0.6323  ███████████████████████████████
#     2012: sim=0.3532  drift=0.6468  ████████████████████████████████
#     2013: sim=0.3452  drift=0.6548  ████████████████████████████████
#     2014: sim=0.3629  drift=0.6371  ███████████████████████████████
#     2015: sim=0.3710  drift=0.6290  ███████████████████████████████
#     2016: sim=0.3500  drift=0.6500  ████████████████████████████████
#     2017: sim=0.3667  drift=0.6333  ███████████████████████████████
#     2018: sim=0.3635  drift=0.6365  ███████████████████████████████
#     2019: sim=0.3571  drift=0.6429  ████████████████████████████████
#     2020: sim=0.3571  drift=0.6429  ████████████████████████████████
#     2021: sim=0.3635  drift=0.6365  ███████████████████████████████
#     2022: sim=0.3587  drift=0.6413  ████████████████████████████████
#     2023: sim=0.3587  drift=0.6413  ████████████████████████████████
#     2024: sim=0.3587  drift=0.6413  ████████████████████████████████
#     2025: sim=0.3651  drift=0.6349  ███████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: PHYSICS (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.6727  drift=0.3273  ████████████████
#     2002: sim=0.5137  drift=0.4863  ████████████████████████
#     2003: sim=0.3804  drift=0.6196  ██████████████████████████████
#     2004: sim=0.3000  drift=0.7000  ███████████████████████████████████
#     2005: sim=0.3310  drift=0.6690  █████████████████████████████████
#     2006: sim=0.2800  drift=0.7200  ████████████████████████████████████
#     2007: sim=0.2537  drift=0.7463  █████████████████████████████████████
#     2008: sim=0.2485  drift=0.7515  █████████████████████████████████████
#     2009: sim=0.2465  drift=0.7535  █████████████████████████████████████
#     2010: sim=0.2473  drift=0.7527  █████████████████████████████████████
#     2011: sim=0.2608  drift=0.7392  ████████████████████████████████████
#     2012: sim=0.2521  drift=0.7479  █████████████████████████████████████
#     2013: sim=0.2554  drift=0.7446  █████████████████████████████████████
#     2014: sim=0.2635  drift=0.7365  ████████████████████████████████████
#     2015: sim=0.2635  drift=0.7365  ████████████████████████████████████
#     2016: sim=0.2649  drift=0.7351  ████████████████████████████████████
#     2017: sim=0.2568  drift=0.7432  █████████████████████████████████████
#     2018: sim=0.2649  drift=0.7351  ████████████████████████████████████
#     2019: sim=0.2554  drift=0.7446  █████████████████████████████████████
#     2020: sim=0.2622  drift=0.7378  ████████████████████████████████████
#     2021: sim=0.2649  drift=0.7351  ████████████████████████████████████
#     2022: sim=0.2541  drift=0.7459  █████████████████████████████████████
#     2023: sim=0.2622  drift=0.7378  ████████████████████████████████████
#     2024: sim=0.2608  drift=0.7392  ████████████████████████████████████
#     2025: sim=0.2662  drift=0.7338  ████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv

# %% [markdown]
# ## 3. Year-over-Year Drift
# `cosine_sim(words_t, words_t+1)` — detects **sudden jumps** vs gradual evolution

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Year-over-Year Drift: {subject.upper()}")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row['year']), int(row['topic_id']))
        topic_words[key] = parse_words(row['top_words'])

    years = sorted(evo_df['year'].unique())

    # Build global vocabulary
    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    yoy_rows = []

    # Iterate by CONSECUTIVE CALENDAR YEARS
    for i in range(len(years) - 1):
        t, t1 = int(years[i]), int(years[i + 1])

        # Find topics present in BOTH years
        topics_t = {tid for (y, tid) in topic_words if y == t}
        topics_t1 = {tid for (y, tid) in topic_words if y == t1}
        common_topics = sorted(topics_t & topics_t1)

        for tid in common_topics:
            v_t = words_to_vector(topic_words[(t, tid)], vocab_index)
            v_t1 = words_to_vector(topic_words[(t1, tid)], vocab_index)
            sim = cos_sim(v_t, v_t1)

            yoy_rows.append({
                'subject': subject, 'topic_id': tid,
                'year_from': t, 'year_to': t1,
                'cosine_sim': round(sim, 6),
                'drift': round(1.0 - sim, 6),
            })

    yoy_df = pd.DataFrame(yoy_rows)
    yoy_df.to_csv(RESULT_DIR / subject / "ttd_year_over_year.csv", index=False)

    # Per-topic summary
    topic_yoy = yoy_df.groupby('topic_id').agg(
        avg_yoy_sim=('cosine_sim', 'mean'),
        min_yoy_sim=('cosine_sim', 'min'),
        avg_yoy_drift=('drift', 'mean'),
        max_single_jump=('drift', 'max'),
    ).reset_index()
    topic_yoy.insert(0, 'subject', subject)
    topic_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_per_topic.csv", index=False)

    # Avg across all topics per year transition
    avg_yoy = yoy_df.groupby(['year_from', 'year_to']).agg(
        avg_sim=('cosine_sim', 'mean'),
        avg_drift=('drift', 'mean'),
        n_topics=('topic_id', 'count')
    ).reset_index()
    avg_yoy.insert(0, 'subject', subject)
    avg_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_avg.csv", index=False)

    print(f"  Avg year-over-year drift (consecutive calendar years):")
    for _, r in avg_yoy.iterrows():
        bar = chr(9608) * int(r['avg_drift'] * 50)
        print(f"    {int(r['year_from'])}→{int(r['year_to'])}: sim={r['avg_sim']:.4f}  "
              f"drift={r['avg_drift']:.4f}  ({int(r['n_topics'])} topics)  {bar}")

    # Top 5 biggest single-year jumps
    print(f"\n  Top 5 biggest single-year JUMPS:")
    for _, r in yoy_df.nlargest(5, 'drift').iterrows():
        print(f"    T{int(r['topic_id']):>3} | {int(r['year_from'])}→{int(r['year_to'])} | "
              f"drift={r['drift']:.4f}")

    overall_sim = yoy_df['cosine_sim'].mean()
    overall_drift = yoy_df['drift'].mean()
    print(f"\n  Overall: avg_yoy_sim={overall_sim:.4f}  avg_yoy_drift={overall_drift:.4f}")
    print(f"  Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv")
# Out:
# ======================================================================
# Year-over-Year Drift: CS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.5944  drift=0.4056  (18 topics)  ████████████████████
#     2001→2002: sim=0.5870  drift=0.4130  (23 topics)  ████████████████████
#     2002→2003: sim=0.6100  drift=0.3900  (20 topics)  ███████████████████
#     2003→2004: sim=0.4826  drift=0.5174  (23 topics)  █████████████████████████
#     2004→2005: sim=0.5793  drift=0.4207  (29 topics)  █████████████████████
#     2005→2006: sim=0.6393  drift=0.3607  (28 topics)  ██████████████████
#     2006→2007: sim=0.5862  drift=0.4138  (29 topics)  ████████████████████
#     2007→2008: sim=0.5882  drift=0.4118  (34 topics)  ████████████████████
#     2008→2009: sim=0.5938  drift=0.4062  (32 topics)  ████████████████████
#     2009→2010: sim=0.6588  drift=0.3412  (34 topics)  █████████████████
#     2010→2011: sim=0.6644  drift=0.3356  (45 topics)  ████████████████
#     2011→2012: sim=0.6731  drift=0.3269  (52 topics)  ████████████████
#     2012→2013: sim=0.6164  drift=0.3836  (67 topics)  ███████████████████
#     2013→2014: sim=0.6462  drift=0.3538  (78 topics)  █████████████████
#     2014→2015: sim=0.6607  drift=0.3393  (89 topics)  ████████████████
#     2015→2016: sim=0.6893  drift=0.3107  (112 topics)  ███████████████
#     2016→2017: sim=0.7310  drift=0.2690  (126 topics)  █████████████
#     2017→2018: sim=0.7867  drift=0.2133  (135 topics)  ██████████
#     2018→2019: sim=0.8234  drift=0.1766  (137 topics)  ████████
#     2019→2020: sim=0.8416  drift=0.1584  (137 topics)  ███████
#     2020→2021: sim=0.8681  drift=0.1319  (138 topics)  ██████
#     2021→2022: sim=0.8935  drift=0.1065  (138 topics)  █████
#     2022→2023: sim=0.8841  drift=0.1159  (138 topics)  █████
#     2023→2024: sim=0.8942  drift=0.1058  (138 topics)  █████
#     2024→2025: sim=0.9130  drift=0.0870  (138 topics)  ████
#
#   Top 5 biggest single-year JUMPS:
#     T 13 | 2006→2007 | drift=1.0000
#     T  4 | 2003→2004 | drift=0.9000
#     T 13 | 2012→2013 | drift=0.9000
#     T 89 | 2012→2013 | drift=0.9000
#     T 64 | 2014→2015 | drift=0.9000
#
#   Overall: avg_yoy_sim=0.7709  avg_yoy_drift=0.2291
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: MATH
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.6348  drift=0.3652  (46 topics)  ██████████████████
#     2001→2002: sim=0.6532  drift=0.3468  (47 topics)  █████████████████
#     2002→2003: sim=0.6592  drift=0.3408  (49 topics)  █████████████████
#     2003→2004: sim=0.6600  drift=0.3400  (50 topics)  █████████████████
#     2004→2005: sim=0.6944  drift=0.3056  (54 topics)  ███████████████
#     2005→2006: sim=0.7167  drift=0.2833  (54 topics)  ██████████████
#     2006→2007: sim=0.7536  drift=0.2464  (56 topics)  ████████████
#     2007→2008: sim=0.7517  drift=0.2483  (60 topics)  ████████████
#     2008→2009: sim=0.7525  drift=0.2475  (59 topics)  ████████████
#     2009→2010: sim=0.7661  drift=0.2339  (59 topics)  ███████████
#     2010→2011: sim=0.7918  drift=0.2082  (61 topics)  ██████████
#     2011→2012: sim=0.8113  drift=0.1887  (62 topics)  █████████
#     2012→2013: sim=0.8194  drift=0.1806  (62 topics)  █████████
#     2013→2014: sim=0.8161  drift=0.1839  (62 topics)  █████████
#     2014→2015: sim=0.8565  drift=0.1435  (62 topics)  ███████
#     2015→2016: sim=0.8565  drift=0.1435  (62 topics)  ███████
#     2016→2017: sim=0.8597  drift=0.1403  (62 topics)  ███████
#     2017→2018: sim=0.8476  drift=0.1524  (63 topics)  ███████
#     2018→2019: sim=0.8667  drift=0.1333  (63 topics)  ██████
#     2019→2020: sim=0.8873  drift=0.1127  (63 topics)  █████
#     2020→2021: sim=0.8683  drift=0.1317  (63 topics)  ██████
#     2021→2022: sim=0.8714  drift=0.1286  (63 topics)  ██████
#     2022→2023: sim=0.8857  drift=0.1143  (63 topics)  █████
#     2023→2024: sim=0.8905  drift=0.1095  (63 topics)  █████
#     2024→2025: sim=0.9048  drift=0.0952  (63 topics)  ████
#
#   Top 5 biggest single-year JUMPS:
#     T 21 | 2001→2002 | drift=0.9000
#     T 50 | 2000→2001 | drift=0.8000
#     T 21 | 2002→2003 | drift=0.8000
#     T 31 | 2003→2004 | drift=0.8000
#     T  4 | 2000→2001 | drift=0.7000
#
#   Overall: avg_yoy_sim=0.8023  avg_yoy_drift=0.1977
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: PHYSICS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.5886  drift=0.4114  (35 topics)  ████████████████████
#     2001→2002: sim=0.5526  drift=0.4474  (38 topics)  ██████████████████████
#     2002→2003: sim=0.6053  drift=0.3947  (38 topics)  ███████████████████
#     2003→2004: sim=0.6167  drift=0.3833  (42 topics)  ███████████████████
#     2004→2005: sim=0.5933  drift=0.4067  (45 topics)  ████████████████████
#     2005→2006: sim=0.6407  drift=0.3593  (54 topics)  █████████████████
#     2006→2007: sim=0.6230  drift=0.3770  (61 topics)  ██████████████████
#     2007→2008: sim=0.6415  drift=0.3585  (65 topics)  █████████████████
#     2008→2009: sim=0.6485  drift=0.3515  (68 topics)  █████████████████
#     2009→2010: sim=0.6789  drift=0.3211  (71 topics)  ████████████████
#     2010→2011: sim=0.7189  drift=0.2811  (74 topics)  ██████████████
#     2011→2012: sim=0.7548  drift=0.2452  (73 topics)  ████████████
#     2012→2013: sim=0.7740  drift=0.2260  (73 topics)  ███████████
#     2013→2014: sim=0.7878  drift=0.2122  (74 topics)  ██████████
#     2014→2015: sim=0.8000  drift=0.2000  (74 topics)  ██████████
#     2015→2016: sim=0.8270  drift=0.1730  (74 topics)  ████████
#     2016→2017: sim=0.8257  drift=0.1743  (74 topics)  ████████
#     2017→2018: sim=0.8297  drift=0.1703  (74 topics)  ████████
#     2018→2019: sim=0.8324  drift=0.1676  (74 topics)  ████████
#     2019→2020: sim=0.8459  drift=0.1541  (74 topics)  ███████
#     2020→2021: sim=0.8514  drift=0.1486  (74 topics)  ███████
#     2021→2022: sim=0.8527  drift=0.1473  (74 topics)  ███████
#     2022→2023: sim=0.8703  drift=0.1297  (74 topics)  ██████
#     2023→2024: sim=0.8689  drift=0.1311  (74 topics)  ██████
#     2024→2025: sim=0.8811  drift=0.1189  (74 topics)  █████
#
#   Top 5 biggest single-year JUMPS:
#     T 25 | 2000→2001 | drift=1.0000
#     T  7 | 2003→2004 | drift=0.9000
#     T  9 | 2004→2005 | drift=0.9000
#     T 16 | 2004→2005 | drift=0.9000
#     T 13 | 2006→2007 | drift=0.9000
#
#   Overall: avg_yoy_sim=0.7594  avg_yoy_drift=0.2406
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv

# %% [markdown]
# ## Inspect Individual Topics
# Two helper functions to drill into specific topics.

# %%
def show_topic_yoy(topic_id, subject):
    """
    Show year-over-year drift for a specific topic with drift labels.
    Labels: Stable (<0.3), Moderate (0.3-0.6), Aggressive (0.6-0.8), Extreme (>0.8)
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    all_words_set = set()
    tw = {}
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())

    print(f"\n{'='*70}")
    print(f"YoY Drift: Topic {topic_id} — {subject.upper()}")
    print(f"Active: {topic_years[0]}–{topic_years[-1]} ({len(topic_years)} years)")
    print(f"{'='*70}")

    drifts = []
    for i in range(len(topic_years) - 1):
        t, t1 = topic_years[i], topic_years[i + 1]
        v_t = words_to_vector(tw[t], vi)
        v_t1 = words_to_vector(tw[t1], vi)
        sim = cos_sim(v_t, v_t1)
        drift = 1.0 - sim
        drifts.append(drift)

        # Label
        if drift < 0.3:
            label = "🟢 Stable"
        elif drift < 0.6:
            label = "🟡 Moderate"
        elif drift < 0.8:
            label = "🟠 Aggressive"
        else:
            label = "🔴 Extreme"

        bar = chr(9608) * int(drift * 30)
        print(f"  {t}→{t1}: sim={sim:.4f}  drift={drift:.4f}  {bar}  {label}")

        # Show word changes
        added = set(tw[t1]) - set(tw[t])
        removed = set(tw[t]) - set(tw[t1])
        if added or removed:
            if removed:
                print(f"           − {', '.join(sorted(removed))}")
            if added:
                print(f"           + {', '.join(sorted(added))}")

    # Summary
    avg_d = np.mean(drifts)
    max_d = np.max(drifts)
    if avg_d < 0.3:
        verdict = "🟢 STABLE — vocabulary is consistent over time"
    elif avg_d < 0.5:
        verdict = "🟡 MODERATE — topic evolves gradually"
    elif avg_d < 0.7:
        verdict = "🟠 DRIFTING — significant vocabulary changes"
    else:
        verdict = "🔴 HIGHLY UNSTABLE — topic vocabulary reshuffles frequently"

    print(f"\n  Avg drift: {avg_d:.4f} | Max jump: {max_d:.4f}")
    print(f"  Verdict: {verdict}")


def show_topic_endpoint(topic_id, subject):
    """
    Show endpoint drift for a specific topic: first year vs last year.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    all_words_set = set()
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())
    t_first, t_last = topic_years[0], topic_years[-1]

    v_first = words_to_vector(tw[t_first], vi)
    v_last = words_to_vector(tw[t_last], vi)
    sim = cos_sim(v_first, v_last)
    ttd = 1.0 - sim

    # Words analysis
    w_first = set(tw[t_first])
    w_last = set(tw[t_last])
    kept = sorted(w_first & w_last)
    removed = sorted(w_first - w_last)
    added = sorted(w_last - w_first)

    if ttd < 0.3:
        verdict = "🟢 STABLE — topic maintained its core vocabulary"
    elif ttd < 0.5:
        verdict = "🟡 MODERATE — topic evolved but recognizable"
    elif ttd < 0.7:
        verdict = "🟠 SIGNIFICANT DRIFT — topic substantially changed"
    else:
        verdict = "🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced"

    print(f"\n{'='*70}")
    print(f"Endpoint Drift: Topic {topic_id} — {subject.upper()}")
    print(f"{'='*70}")
    print(f"  Active: {t_first}–{t_last} ({len(topic_years)} years)")
    print(f"  Cosine similarity: {sim:.4f}")
    print(f"  TTD (drift):       {ttd:.4f}")
    print(f"  Verdict: {verdict}")
    print(f"\n  First year ({t_first}): {', '.join(tw[t_first])}")
    print(f"  Last year  ({t_last}): {', '.join(tw[t_last])}")
    print(f"\n  🔒 Kept ({len(kept)}):    {', '.join(kept) if kept else '(none)'}")
    print(f"  ➖ Removed ({len(removed)}): {', '.join(removed) if removed else '(none)'}")
    print(f"  ➕ Added ({len(added)}):   {', '.join(added) if added else '(none)'}")


def show_topic_trajectory(topic_id, subject):
    """
    Show drift trajectory from baseline (first year) for a specific topic.
    cosine_sim(words_t0, words_t) per year — shows when drift accelerates.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    tw = {}
    all_words_set = set()
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())
    t0 = topic_years[0]
    v_baseline = words_to_vector(tw[t0], vi)

    print(f"\n{'='*70}")
    print(f"Drift Trajectory: Topic {topic_id} — {subject.upper()}")
    print(f"Baseline: {t0} → {', '.join(tw[t0])}")
    print(f"{'='*70}")

    prev_drift = 0.0
    for y in topic_years:
        v_y = words_to_vector(tw[y], vi)
        sim = cos_sim(v_baseline, v_y)
        drift = 1.0 - sim

        # Delta from previous year
        delta = drift - prev_drift
        if delta > 0.1:
            delta_label = f" ↑{delta:+.3f} ⚡"
        elif delta > 0.02:
            delta_label = f" ↑{delta:+.3f}"
        elif delta < -0.02:
            delta_label = f" ↓{delta:+.3f} 🔄"
        else:
            delta_label = f"  {delta:+.3f} —"
        prev_drift = drift

        # Shared words with baseline
        shared = sorted(set(tw[t0]) & set(tw[y]))
        n_shared = len(shared)
        n_total = len(tw[t0])

        bar = chr(9608) * int(drift * 30)
        print(f"  {y}: sim={sim:.4f}  drift={drift:.4f}  {bar}{delta_label}  "
              f"({n_shared}/{n_total} baseline words kept)")

    # Final summary
    final_sim = cos_sim(v_baseline, words_to_vector(tw[topic_years[-1]], vi))
    final_drift = 1.0 - final_sim
    kept = sorted(set(tw[t0]) & set(tw[topic_years[-1]]))
    lost = sorted(set(tw[t0]) - set(tw[topic_years[-1]]))

    print(f"\n  Total drift ({t0}→{topic_years[-1]}): {final_drift:.4f}")
    print(f"  Baseline words kept: {', '.join(kept) if kept else '(none)'}")
    print(f"  Baseline words lost: {', '.join(lost) if lost else '(none)'}")

# %% [markdown]
# ### Usage
# ```python
# show_topic_yoy(topic_id=5, subject="cs")
# show_topic_endpoint(topic_id=5, subject="cs")
# ```

# %%
# Example: inspect a specific topic
show_topic_yoy(topic_id=0, subject="cs")
show_topic_trajectory(topic_id=0, subject="cs")
show_topic_endpoint(topic_id=0, subject="cs")
# Out:
# ======================================================================
# YoY Drift: Topic 0 — CS
# Active: 2000–2025 (26 years)
# ======================================================================
#   2000→2001: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − apweb, mining, research, talkmine
#            + content, database, pages, query
#   2001→2002: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − content, database, databases, pages
#            + document, genex, keyphrase, keyphrases
#   2002→2003: sim=0.9000  drift=0.1000  ██  🟢 Stable
#            − information
#            + algorithm
#   2003→2004: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − algorithm, genex, keyphrase, query
#            + based, content, information, semantic
#   2004→2005: sim=0.7000  drift=0.3000  ████████  🟢 Stable
#            − content, information, semantic
#            + des, donn, query
#   2005→2006: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − based, des, donn, keyphrases
#            + approach, gps, information, ontology
#   2006→2007: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − approach, gps, ontology, query, text
#            + communities, del, icio, tagging, user
#   2007→2008: sim=0.3000  drift=0.7000  █████████████████████  🟠 Aggressive
#            − communities, del, document, icio, search, tagging, web
#            + filtering, index, indexing, mails, profile, subcorpora, wikipedia
#   2008→2009: sim=0.7000  drift=0.3000  ████████  🟢 Stable
#            − filtering, index, mails
#            + bulletin, document, search
#   2009→2010: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − bulletin, indexing, profile, subcorpora
#            + classification, query, text, web
#   2010→2011: sim=0.7000  drift=0.3000  ████████  🟢 Stable
#            − classification, text, wikipedia
#            + pages, retrieval, users
#   2011→2012: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − pages, user
#            + data, text
#   2012→2013: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − data, retrieval
#            + engines, pages
#   2013→2014: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − engines, pages, query, users
#            + classification, clustering, relatedness, semantic
#   2014→2015: sim=0.7000  drift=0.3000  ████████  🟢 Stable
#            − classification, clustering, semantic
#            + data, query, user
#   2015→2016: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − data, relatedness
#            + classification, namespaces
#   2016→2017: sim=0.7000  drift=0.3000  ████████  🟢 Stable
#            − classification, namespaces, user
#            + data, retrieval, semantic
#   2017→2018: sim=0.9000  drift=0.1000  ██  🟢 Stable
#            − data
#            + queries
#   2018→2019: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − queries, semantic
#            + data, keyword
#   2019→2020: sim=0.9000  drift=0.1000  ██  🟢 Stable
#            − keyword
#            + queries
#   2020→2021: sim=1.0000  drift=0.0000    🟢 Stable
#   2021→2022: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − data, retrieval
#            + classification, topic
#   2022→2023: sim=0.9000  drift=0.1000  ██  🟢 Stable
#            − topic
#            + retrieval
#   2023→2024: sim=1.0000  drift=0.0000    🟢 Stable
#   2024→2025: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − classification, information
#            + based, semantic
#
#   Avg drift: 0.2680 | Max jump: 0.7000
#   Verdict: 🟢 STABLE — vocabulary is consistent over time
#
# ======================================================================
# Drift Trajectory: Topic 0 — CS
# Baseline: 2000 → web, databases, text, apweb, talkmine, documents, search, mining, information, research
# ======================================================================
#   2000: sim=1.0000  drift=-0.0000    -0.000 —  (10/10 baseline words kept)
#   2001: sim=0.6000  drift=0.4000  ████████████ ↑+0.400 ⚡  (6/10 baseline words kept)
#   2002: sim=0.5000  drift=0.5000  ███████████████ ↑+0.100  (5/10 baseline words kept)
#   2003: sim=0.4000  drift=0.6000  ██████████████████ ↑+0.100  (4/10 baseline words kept)
#   2004: sim=0.5000  drift=0.5000  ███████████████ ↓-0.100 🔄  (5/10 baseline words kept)
#   2005: sim=0.4000  drift=0.6000  ██████████████████ ↑+0.100  (4/10 baseline words kept)
#   2006: sim=0.5000  drift=0.5000  ███████████████ ↓-0.100 🔄  (5/10 baseline words kept)
#   2007: sim=0.4000  drift=0.6000  ██████████████████ ↑+0.100  (4/10 baseline words kept)
#   2008: sim=0.2000  drift=0.8000  ████████████████████████ ↑+0.200 ⚡  (2/10 baseline words kept)
#   2009: sim=0.3000  drift=0.7000  █████████████████████ ↓-0.100 🔄  (3/10 baseline words kept)
#   2010: sim=0.5000  drift=0.5000  ███████████████ ↓-0.200 🔄  (5/10 baseline words kept)
#   2011: sim=0.4000  drift=0.6000  ██████████████████ ↑+0.100  (4/10 baseline words kept)
#   2012: sim=0.5000  drift=0.5000  ███████████████ ↓-0.100 🔄  (5/10 baseline words kept)
#   2013: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2014: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2015: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2016: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2017: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2018: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2019: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2020: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2021: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2022: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2023: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2024: sim=0.5000  drift=0.5000  ███████████████  +0.000 —  (5/10 baseline words kept)
#   2025: sim=0.4000  drift=0.6000  ██████████████████ ↑+0.100  (4/10 baseline words kept)
#
#   Total drift (2000→2025): 0.6000
#   Baseline words kept: documents, search, text, web
#   Baseline words lost: apweb, databases, information, mining, research, talkmine
#
# ======================================================================
# Endpoint Drift: Topic 0 — CS
# ======================================================================
#   Active: 2000–2025 (26 years)
#   Cosine similarity: 0.4000
#   TTD (drift):       0.6000
#   Verdict: 🟠 SIGNIFICANT DRIFT — topic substantially changed
#
#   First year (2000): web, databases, text, apweb, talkmine, documents, search, mining, information, research
#   Last year  (2025): search, web, documents, query, text, document, queries, retrieval, based, semantic
#
#   🔒 Kept (4):    documents, search, text, web
#   ➖ Removed (6): apweb, databases, information, mining, research, talkmine
#   ➕ Added (6):   based, document, queries, query, retrieval, semantic
