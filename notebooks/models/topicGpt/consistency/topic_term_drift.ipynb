# %% [markdown]
# # TopicGPT: Topic Term Drift (TTD)
#
# **Scenario 3a** — Three complementary drift metrics:
# 1. **Endpoint TTD**: cosine distance from first to last year (total drift)
# 2. **Trajectory from baseline**: cosine_sim(t₀, t) per year (when drift happens)
# 3. **Year-over-year drift**: cosine_sim(t, t+1) per year (smoothness of evolution)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/topicGpt/temporal")
RESULT_DIR = Path("../../../../results/topicGpt/consistency")

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Reading from: ../../../../results/topicGpt/temporal
# Saving to: ../../../../results/topicGpt/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def words_to_vector(words, vocab_index):
    vec = np.zeros(len(vocab_index))
    for w in words:
        if w in vocab_index:
            vec[vocab_index[w]] = 1.0
    return vec


def cos_sim(v1, v2):
    """Cosine similarity between two vectors."""
    return float(cosine_similarity(v1.reshape(1, -1), v2.reshape(1, -1))[0, 0])

# %% [markdown]
# ## 1. Endpoint TTD
# Total drift: `TTD = 1 - cosine_sim(words_first, words_last)`

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Endpoint TTD: {subject.upper()} (TopicGPT)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())

    # Build global vocabulary
    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t_first, t_last = topic_years[0], topic_years[-1]
        v_first = words_to_vector(topic_words[(t_first, tid)], vocab_index)
        v_last = words_to_vector(topic_words[(t_last, tid)], vocab_index)
        sim = cos_sim(v_first, v_last)

        rows.append({
            "subject": subject, "topic_id": tid,
            "first_year": t_first, "last_year": t_last,
            "n_years": len(topic_years),
            "cosine_sim": round(sim, 6),
            "ttd": round(1.0 - sim, 6),
            "words_first": ", ".join(topic_words[(t_first, tid)]),
            "words_last": ", ".join(topic_words[(t_last, tid)]),
        })

    df = pd.DataFrame(rows)
    df.to_csv(RESULT_DIR / subject / "topic_term_drift.csv", index=False)

    summary = {"subject": subject, "n_topics": len(df),
               "ttd_mean": round(df["ttd"].mean(), 6),
               "ttd_std": round(df["ttd"].std(), 6),
               "ttd_median": round(df["ttd"].median(), 6),
               "pct_stable": round((df["ttd"] < 0.5).mean() * 100, 2),
               "pct_drifted": round((df["ttd"] >= 0.5).mean() * 100, 2)}
    pd.DataFrame([summary]).to_csv(RESULT_DIR / subject / "ttd_summary.csv", index=False)

    print(f"  TTD: mean={summary['ttd_mean']:.4f} ± {summary['ttd_std']:.4f}, "
          f"median={summary['ttd_median']:.4f}")
    print(f"  Stable (TTD<0.5): {summary['pct_stable']:.1f}%  |  "
          f"Drifted (TTD≥0.5): {summary['pct_drifted']:.1f}%")

    print(f"\n  🔥 Top 5 most DRIFTED:")
    for _, r in df.nlargest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | "
              f"{r['words_first'][:40]}... → {r['words_last'][:40]}...")

    print(f"  🔒 Top 5 most STABLE:")
    for _, r in df.nsmallest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | {r['words_first'][:60]}")
# Out:
# ======================================================================
# Endpoint TTD: CS (TopicGPT)
# ======================================================================
#   TTD: mean=0.8761 ± 0.1137, median=0.9000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   🔥 Top 5 most DRIFTED:
#     T  1 | TTD=1.0000 | story, understanding, 1970s, depth, 1990... → models, language, llms, dialogue, social...
#     T  3 | TTD=1.0000 | parsing, dop, ilp, semantic, tilde, indu... → reasoning, language, models, llms, logic...
#     T  5 | TTD=1.0000 | word, hypotheses, rate, words, recognize... → models, language, model, llms, generatio...
#     T  7 | TTD=1.0000 | lightest, derivation, abstractions, sear... → 3d, point, segmentation, document, cloud...
#     T 11 | TTD=1.0000 | object, multicomputers, server, semaphor... → memory, cxl, data, storage, performance,...
#   🔒 Top 5 most STABLE:
#     T 60 | TTD=0.5000 | 2d, 3d, hypothesis, shapes, image, object, reconstruction, p
#     T113 | TTD=0.5000 | salient, saliency, hypergraph, object, hyperedges, regions,
#     T  8 | TTD=0.6000 | calculus, rewriting, circularity, exptime, chr, rules, 2lr,
#     T 18 | TTD=0.6000 | policy, observable, grep, partially, reinforcement, market,
#     T 39 | TTD=0.6000 | strategic, power, wireless, energy, expenditure, optimizatio
#
# ======================================================================
# Endpoint TTD: MATH (TopicGPT)
# ======================================================================
#   TTD: mean=0.7984 ± 0.1338, median=0.8000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   🔥 Top 5 most DRIFTED:
#     T  9 | TTD=1.0000 | tree, continued, incidence, fraction, ca... → permutations, graphs, graph, trees, ex, ...
#     T 16 | TTD=1.0000 | widetilde, mirror, curve, witten, mm, di... → mathcal, gauge, theories, mathbb, cal, m...
#     T 27 | TTD=1.0000 | kappa, popescu, gamma, eisenbud, spec, s... → modules, rr, rings, module, gorenstein, ...
#     T 30 | TTD=1.0000 | probability, chains, twice, sampled, mea... → branching, population, process, processe...
#     T 34 | TTD=1.0000 | copositive, quadratic, l1, ball, bound, ... → optimization, convex, problems, method, ...
#   🔒 Top 5 most STABLE:
#     T  7 | TTD=0.5000 | braid, representations, group, quantum, krammer, algebra, te
#     T 36 | TTD=0.5000 | symplectic, hamiltonian, group, hyperkaehler, quasifolds, qu
#     T 10 | TTD=0.6000 | dinger, schr, quasiperiodic, spectral, titchmarsh, adjoint,
#     T 11 | TTD=0.6000 | superconformal, algebra, schrodinger, algebras, quantum, def
#     T 22 | TTD=0.6000 | kaehler, einstein, ew, dkp, curvature, metric, xd, mabuchi,
#
# ======================================================================
# Endpoint TTD: PHYSICS (TopicGPT)
# ======================================================================
#   TTD: mean=0.8297 ± 0.1268, median=0.8000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   🔥 Top 5 most DRIFTED:
#     T 10 | TTD=1.0000 | deforming, inherit, energetic, automatic... → fluid, relativistic, hydrodynamics, sph,...
#     T 11 | TTD=1.0000 | attractor, viscosity, inertial, eigenfre... → flow, vortex, reynolds, flows, fluid, in...
#     T 16 | TTD=1.0000 | rfq, charge, prestripper, lebt, cherenko... → muon, beam, energy, neutron, electron, m...
#     T 36 | TTD=1.0000 | pbpb, finder, cdf, tevatron, alice, mult... → detector, reconstruction, calorimeter, l...
#     T 39 | TTD=1.0000 | ergodic, metric, walking, tempering, mon... → quantum, sampling, dynamics, stochastic,...
#   🔒 Top 5 most STABLE:
#     T  4 | TTD=0.5000 | cooling, cesium, evaporative, trap, optical, sideband, 10muk
#     T  0 | TTD=0.6000 | colliders, gamma, plasma, beam, muon, converter, ions, elect
#     T  5 | TTD=0.6000 | photonic, crystal, terahertz, rectification, impedance, micr
#     T 24 | TTD=0.6000 | single, detectors, photon, 1300nm, apds, superconducting, ss
#     T 26 | TTD=0.6000 | relativity, transformations, tt, spacetime, qtr, true, speci

# %% [markdown]
# ## 2. Drift Trajectory from Baseline
# For each topic: `cosine_sim(words_t₀, words_t)` per year — shows **when** drift happens

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Drift Trajectory: {subject.upper()} (TopicGPT)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())

    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    traj_rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t0 = topic_years[0]
        v_baseline = words_to_vector(topic_words[(t0, tid)], vocab_index)

        for y in topic_years:
            v_y = words_to_vector(topic_words[(y, tid)], vocab_index)
            sim = cos_sim(v_baseline, v_y)
            traj_rows.append({
                "subject": subject, "topic_id": tid,
                "baseline_year": t0, "year": y,
                "years_elapsed": y - t0,
                "cosine_sim_to_baseline": round(sim, 6),
                "drift_from_baseline": round(1.0 - sim, 6),
            })

    traj_df = pd.DataFrame(traj_rows)
    traj_df.to_csv(RESULT_DIR / subject / "ttd_trajectory.csv", index=False)

    # Average drift trajectory across all topics per year
    avg_traj = traj_df.groupby("year").agg(
        avg_sim=("cosine_sim_to_baseline", "mean"),
        avg_drift=("drift_from_baseline", "mean"),
        n_topics=("topic_id", "count")
    ).reset_index()
    avg_traj.insert(0, "subject", subject)
    avg_traj.to_csv(RESULT_DIR / subject / "ttd_trajectory_avg.csv", index=False)

    print(f"  Avg drift from baseline per year:")
    for _, r in avg_traj.iterrows():
        bar = '█' * int(r['avg_drift'] * 50)
        print(f"    {int(r['year'])}: sim={r['avg_sim']:.4f}  drift={r['avg_drift']:.4f}  {bar}")
    print(f"  Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv")
# Out:
# ======================================================================
# Drift Trajectory: CS (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.7743  drift=0.2257  ███████████
#     2002: sim=0.5714  drift=0.4286  █████████████████████
#     2003: sim=0.3581  drift=0.6419  ████████████████████████████████
#     2004: sim=0.2829  drift=0.7171  ███████████████████████████████████
#     2005: sim=0.2256  drift=0.7744  ██████████████████████████████████████
#     2006: sim=0.2763  drift=0.7237  ████████████████████████████████████
#     2007: sim=0.2195  drift=0.7805  ███████████████████████████████████████
#     2008: sim=0.2489  drift=0.7511  █████████████████████████████████████
#     2009: sim=0.1600  drift=0.8400  ██████████████████████████████████████████
#     2010: sim=0.2098  drift=0.7902  ███████████████████████████████████████
#     2011: sim=0.2548  drift=0.7452  █████████████████████████████████████
#     2012: sim=0.2853  drift=0.7147  ███████████████████████████████████
#     2013: sim=0.2630  drift=0.7370  ████████████████████████████████████
#     2014: sim=0.2042  drift=0.7958  ███████████████████████████████████████
#     2015: sim=0.2043  drift=0.7957  ███████████████████████████████████████
#     2016: sim=0.1780  drift=0.8220  █████████████████████████████████████████
#     2017: sim=0.1630  drift=0.8370  █████████████████████████████████████████
#     2018: sim=0.1522  drift=0.8478  ██████████████████████████████████████████
#     2019: sim=0.1401  drift=0.8599  ██████████████████████████████████████████
#     2020: sim=0.1420  drift=0.8580  ██████████████████████████████████████████
#     2021: sim=0.1355  drift=0.8645  ███████████████████████████████████████████
#     2022: sim=0.1304  drift=0.8696  ███████████████████████████████████████████
#     2023: sim=0.1333  drift=0.8667  ███████████████████████████████████████████
#     2024: sim=0.1261  drift=0.8739  ███████████████████████████████████████████
#     2025: sim=0.1239  drift=0.8761  ███████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: MATH (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.5959  drift=0.4041  ████████████████████
#     2002: sim=0.4075  drift=0.5925  █████████████████████████████
#     2003: sim=0.2981  drift=0.7019  ███████████████████████████████████
#     2004: sim=0.2218  drift=0.7782  ██████████████████████████████████████
#     2005: sim=0.1982  drift=0.8018  ████████████████████████████████████████
#     2006: sim=0.2054  drift=0.7946  ███████████████████████████████████████
#     2007: sim=0.2083  drift=0.7917  ███████████████████████████████████████
#     2008: sim=0.2098  drift=0.7902  ███████████████████████████████████████
#     2009: sim=0.2034  drift=0.7966  ███████████████████████████████████████
#     2010: sim=0.2049  drift=0.7951  ███████████████████████████████████████
#     2011: sim=0.2097  drift=0.7903  ███████████████████████████████████████
#     2012: sim=0.2065  drift=0.7935  ███████████████████████████████████████
#     2013: sim=0.2032  drift=0.7968  ███████████████████████████████████████
#     2014: sim=0.2065  drift=0.7935  ███████████████████████████████████████
#     2015: sim=0.2129  drift=0.7871  ███████████████████████████████████████
#     2016: sim=0.1984  drift=0.8016  ████████████████████████████████████████
#     2017: sim=0.2127  drift=0.7873  ███████████████████████████████████████
#     2018: sim=0.2111  drift=0.7889  ███████████████████████████████████████
#     2019: sim=0.2127  drift=0.7873  ███████████████████████████████████████
#     2020: sim=0.2048  drift=0.7952  ███████████████████████████████████████
#     2021: sim=0.2000  drift=0.8000  ████████████████████████████████████████
#     2022: sim=0.2032  drift=0.7968  ███████████████████████████████████████
#     2023: sim=0.2048  drift=0.7952  ███████████████████████████████████████
#     2024: sim=0.1937  drift=0.8063  ████████████████████████████████████████
#     2025: sim=0.2016  drift=0.7984  ███████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: PHYSICS (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.6341  drift=0.3659  ██████████████████
#     2002: sim=0.4922  drift=0.5078  █████████████████████████
#     2003: sim=0.3118  drift=0.6882  ██████████████████████████████████
#     2004: sim=0.2111  drift=0.7889  ███████████████████████████████████████
#     2005: sim=0.2569  drift=0.7431  █████████████████████████████████████
#     2006: sim=0.1908  drift=0.8092  ████████████████████████████████████████
#     2007: sim=0.1567  drift=0.8433  ██████████████████████████████████████████
#     2008: sim=0.1574  drift=0.8426  ██████████████████████████████████████████
#     2009: sim=0.1493  drift=0.8507  ██████████████████████████████████████████
#     2010: sim=0.1486  drift=0.8514  ██████████████████████████████████████████
#     2011: sim=0.1662  drift=0.8338  █████████████████████████████████████████
#     2012: sim=0.1658  drift=0.8342  █████████████████████████████████████████
#     2013: sim=0.1514  drift=0.8486  ██████████████████████████████████████████
#     2014: sim=0.1622  drift=0.8378  █████████████████████████████████████████
#     2015: sim=0.1568  drift=0.8432  ██████████████████████████████████████████
#     2016: sim=0.1622  drift=0.8378  █████████████████████████████████████████
#     2017: sim=0.1568  drift=0.8432  ██████████████████████████████████████████
#     2018: sim=0.1649  drift=0.8351  █████████████████████████████████████████
#     2019: sim=0.1622  drift=0.8378  █████████████████████████████████████████
#     2020: sim=0.1635  drift=0.8365  █████████████████████████████████████████
#     2021: sim=0.1622  drift=0.8378  █████████████████████████████████████████
#     2022: sim=0.1608  drift=0.8392  █████████████████████████████████████████
#     2023: sim=0.1649  drift=0.8351  █████████████████████████████████████████
#     2024: sim=0.1689  drift=0.8311  █████████████████████████████████████████
#     2025: sim=0.1703  drift=0.8297  █████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv

# %% [markdown]
# ## 3. Year-over-Year Drift
# `cosine_sim(words_t, words_t+1)` — detects **sudden jumps** vs gradual evolution

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Year-over-Year Drift: {subject.upper()}")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row['year']), int(row['topic_id']))
        topic_words[key] = parse_words(row['top_words'])

    years = sorted(evo_df['year'].unique())

    # Build global vocabulary
    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    yoy_rows = []

    # Iterate by CONSECUTIVE CALENDAR YEARS
    for i in range(len(years) - 1):
        t, t1 = int(years[i]), int(years[i + 1])

        # Find topics present in BOTH years
        topics_t = {tid for (y, tid) in topic_words if y == t}
        topics_t1 = {tid for (y, tid) in topic_words if y == t1}
        common_topics = sorted(topics_t & topics_t1)

        for tid in common_topics:
            v_t = words_to_vector(topic_words[(t, tid)], vocab_index)
            v_t1 = words_to_vector(topic_words[(t1, tid)], vocab_index)
            sim = cos_sim(v_t, v_t1)

            yoy_rows.append({
                'subject': subject, 'topic_id': tid,
                'year_from': t, 'year_to': t1,
                'cosine_sim': round(sim, 6),
                'drift': round(1.0 - sim, 6),
            })

    yoy_df = pd.DataFrame(yoy_rows)
    yoy_df.to_csv(RESULT_DIR / subject / "ttd_year_over_year.csv", index=False)

    # Per-topic summary
    topic_yoy = yoy_df.groupby('topic_id').agg(
        avg_yoy_sim=('cosine_sim', 'mean'),
        min_yoy_sim=('cosine_sim', 'min'),
        avg_yoy_drift=('drift', 'mean'),
        max_single_jump=('drift', 'max'),
    ).reset_index()
    topic_yoy.insert(0, 'subject', subject)
    topic_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_per_topic.csv", index=False)

    # Avg across all topics per year transition
    avg_yoy = yoy_df.groupby(['year_from', 'year_to']).agg(
        avg_sim=('cosine_sim', 'mean'),
        avg_drift=('drift', 'mean'),
        n_topics=('topic_id', 'count')
    ).reset_index()
    avg_yoy.insert(0, 'subject', subject)
    avg_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_avg.csv", index=False)

    print(f"  Avg year-over-year drift (consecutive calendar years):")
    for _, r in avg_yoy.iterrows():
        bar = chr(9608) * int(r['avg_drift'] * 50)
        print(f"    {int(r['year_from'])}→{int(r['year_to'])}: sim={r['avg_sim']:.4f}  "
              f"drift={r['avg_drift']:.4f}  ({int(r['n_topics'])} topics)  {bar}")

    # Top 5 biggest single-year jumps
    print(f"\n  Top 5 biggest single-year JUMPS:")
    for _, r in yoy_df.nlargest(5, 'drift').iterrows():
        print(f"    T{int(r['topic_id']):>3} | {int(r['year_from'])}→{int(r['year_to'])} | "
              f"drift={r['drift']:.4f}")

    overall_sim = yoy_df['cosine_sim'].mean()
    overall_drift = yoy_df['drift'].mean()
    print(f"\n  Overall: avg_yoy_sim={overall_sim:.4f}  avg_yoy_drift={overall_drift:.4f}")
    print(f"  Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv")
# Out:
# ======================================================================
# Year-over-Year Drift: CS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.5611  drift=0.4389  (18 topics)  █████████████████████
#     2001→2002: sim=0.5348  drift=0.4652  (23 topics)  ███████████████████████
#     2002→2003: sim=0.5650  drift=0.4350  (20 topics)  █████████████████████
#     2003→2004: sim=0.3783  drift=0.6217  (23 topics)  ███████████████████████████████
#     2004→2005: sim=0.4793  drift=0.5207  (29 topics)  ██████████████████████████
#     2005→2006: sim=0.5464  drift=0.4536  (28 topics)  ██████████████████████
#     2006→2007: sim=0.4276  drift=0.5724  (29 topics)  ████████████████████████████
#     2007→2008: sim=0.4676  drift=0.5324  (34 topics)  ██████████████████████████
#     2008→2009: sim=0.4562  drift=0.5437  (32 topics)  ███████████████████████████
#     2009→2010: sim=0.5382  drift=0.4618  (34 topics)  ███████████████████████
#     2010→2011: sim=0.5356  drift=0.4644  (45 topics)  ███████████████████████
#     2011→2012: sim=0.6058  drift=0.3942  (52 topics)  ███████████████████
#     2012→2013: sim=0.5194  drift=0.4806  (67 topics)  ████████████████████████
#     2013→2014: sim=0.5397  drift=0.4603  (78 topics)  ███████████████████████
#     2014→2015: sim=0.5820  drift=0.4180  (89 topics)  ████████████████████
#     2015→2016: sim=0.6143  drift=0.3857  (112 topics)  ███████████████████
#     2016→2017: sim=0.6000  drift=0.4000  (126 topics)  ████████████████████
#     2017→2018: sim=0.6756  drift=0.3244  (135 topics)  ████████████████
#     2018→2019: sim=0.7073  drift=0.2927  (137 topics)  ██████████████
#     2019→2020: sim=0.7474  drift=0.2526  (137 topics)  ████████████
#     2020→2021: sim=0.7601  drift=0.2399  (138 topics)  ███████████
#     2021→2022: sim=0.7913  drift=0.2087  (138 topics)  ██████████
#     2022→2023: sim=0.7978  drift=0.2022  (138 topics)  ██████████
#     2023→2024: sim=0.8087  drift=0.1913  (138 topics)  █████████
#     2024→2025: sim=0.8304  drift=0.1696  (138 topics)  ████████
#
#   Top 5 biggest single-year JUMPS:
#     T  4 | 2003→2004 | drift=1.0000
#     T101 | 2003→2004 | drift=1.0000
#     T 13 | 2006→2007 | drift=1.0000
#     T 61 | 2006→2007 | drift=1.0000
#     T 61 | 2008→2009 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.6720  avg_yoy_drift=0.3280
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: MATH
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.5696  drift=0.4304  (46 topics)  █████████████████████
#     2001→2002: sim=0.5511  drift=0.4489  (47 topics)  ██████████████████████
#     2002→2003: sim=0.5224  drift=0.4776  (49 topics)  ███████████████████████
#     2003→2004: sim=0.5280  drift=0.4720  (50 topics)  ███████████████████████
#     2004→2005: sim=0.5130  drift=0.4870  (54 topics)  ████████████████████████
#     2005→2006: sim=0.5426  drift=0.4574  (54 topics)  ██████████████████████
#     2006→2007: sim=0.5661  drift=0.4339  (56 topics)  █████████████████████
#     2007→2008: sim=0.5833  drift=0.4167  (60 topics)  ████████████████████
#     2008→2009: sim=0.5831  drift=0.4169  (59 topics)  ████████████████████
#     2009→2010: sim=0.6085  drift=0.3915  (59 topics)  ███████████████████
#     2010→2011: sim=0.6279  drift=0.3721  (61 topics)  ██████████████████
#     2011→2012: sim=0.6468  drift=0.3532  (62 topics)  █████████████████
#     2012→2013: sim=0.6613  drift=0.3387  (62 topics)  ████████████████
#     2013→2014: sim=0.6484  drift=0.3516  (62 topics)  █████████████████
#     2014→2015: sim=0.7129  drift=0.2871  (62 topics)  ██████████████
#     2015→2016: sim=0.7145  drift=0.2855  (62 topics)  ██████████████
#     2016→2017: sim=0.7242  drift=0.2758  (62 topics)  █████████████
#     2017→2018: sim=0.7333  drift=0.2667  (63 topics)  █████████████
#     2018→2019: sim=0.7444  drift=0.2556  (63 topics)  ████████████
#     2019→2020: sim=0.7683  drift=0.2317  (63 topics)  ███████████
#     2020→2021: sim=0.7524  drift=0.2476  (63 topics)  ████████████
#     2021→2022: sim=0.7524  drift=0.2476  (63 topics)  ████████████
#     2022→2023: sim=0.7714  drift=0.2286  (63 topics)  ███████████
#     2023→2024: sim=0.7746  drift=0.2254  (63 topics)  ███████████
#     2024→2025: sim=0.7984  drift=0.2016  (63 topics)  ██████████
#
#   Top 5 biggest single-year JUMPS:
#     T 21 | 2001→2002 | drift=0.9000
#     T  3 | 2003→2004 | drift=0.9000
#     T 31 | 2003→2004 | drift=0.9000
#     T  3 | 2004→2005 | drift=0.9000
#     T  1 | 2005→2006 | drift=0.9000
#
#   Overall: avg_yoy_sim=0.6629  avg_yoy_drift=0.3371
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: PHYSICS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.5400  drift=0.4600  (35 topics)  ███████████████████████
#     2001→2002: sim=0.5079  drift=0.4921  (38 topics)  ████████████████████████
#     2002→2003: sim=0.4711  drift=0.5289  (38 topics)  ██████████████████████████
#     2003→2004: sim=0.5262  drift=0.4738  (42 topics)  ███████████████████████
#     2004→2005: sim=0.4978  drift=0.5022  (45 topics)  █████████████████████████
#     2005→2006: sim=0.5222  drift=0.4778  (54 topics)  ███████████████████████
#     2006→2007: sim=0.4902  drift=0.5098  (61 topics)  █████████████████████████
#     2007→2008: sim=0.4969  drift=0.5031  (65 topics)  █████████████████████████
#     2008→2009: sim=0.5206  drift=0.4794  (68 topics)  ███████████████████████
#     2009→2010: sim=0.5549  drift=0.4451  (71 topics)  ██████████████████████
#     2010→2011: sim=0.5919  drift=0.4081  (74 topics)  ████████████████████
#     2011→2012: sim=0.6247  drift=0.3753  (73 topics)  ██████████████████
#     2012→2013: sim=0.6274  drift=0.3726  (73 topics)  ██████████████████
#     2013→2014: sim=0.6595  drift=0.3405  (74 topics)  █████████████████
#     2014→2015: sim=0.6716  drift=0.3284  (74 topics)  ████████████████
#     2015→2016: sim=0.7054  drift=0.2946  (74 topics)  ██████████████
#     2016→2017: sim=0.6892  drift=0.3108  (74 topics)  ███████████████
#     2017→2018: sim=0.6919  drift=0.3081  (74 topics)  ███████████████
#     2018→2019: sim=0.7095  drift=0.2905  (74 topics)  ██████████████
#     2019→2020: sim=0.7000  drift=0.3000  (74 topics)  ███████████████
#     2020→2021: sim=0.7338  drift=0.2662  (74 topics)  █████████████
#     2021→2022: sim=0.7176  drift=0.2824  (74 topics)  ██████████████
#     2022→2023: sim=0.7311  drift=0.2689  (74 topics)  █████████████
#     2023→2024: sim=0.7446  drift=0.2554  (74 topics)  ████████████
#     2024→2025: sim=0.7527  drift=0.2473  (74 topics)  ████████████
#
#   Top 5 biggest single-year JUMPS:
#     T 25 | 2000→2001 | drift=1.0000
#     T  9 | 2004→2005 | drift=1.0000
#     T 47 | 2005→2006 | drift=1.0000
#     T  8 | 2007→2008 | drift=1.0000
#     T 16 | 2008→2009 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.6342  avg_yoy_drift=0.3658
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv

# %% [markdown]
# ## Inspect Individual Topics
# Two helper functions to drill into specific topics.

# %%
def show_topic_yoy(topic_id, subject):
    """
    Show year-over-year drift for a specific topic with drift labels.
    Labels: Stable (<0.3), Moderate (0.3-0.6), Aggressive (0.6-0.8), Extreme (>0.8)
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    all_words_set = set()
    tw = {}
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())

    print(f"\n{'='*70}")
    print(f"YoY Drift: Topic {topic_id} — {subject.upper()}")
    print(f"Active: {topic_years[0]}–{topic_years[-1]} ({len(topic_years)} years)")
    print(f"{'='*70}")

    drifts = []
    for i in range(len(topic_years) - 1):
        t, t1 = topic_years[i], topic_years[i + 1]
        v_t = words_to_vector(tw[t], vi)
        v_t1 = words_to_vector(tw[t1], vi)
        sim = cos_sim(v_t, v_t1)
        drift = 1.0 - sim
        drifts.append(drift)

        # Label
        if drift < 0.3:
            label = "🟢 Stable"
        elif drift < 0.6:
            label = "🟡 Moderate"
        elif drift < 0.8:
            label = "🟠 Aggressive"
        else:
            label = "🔴 Extreme"

        bar = chr(9608) * int(drift * 30)
        print(f"  {t}→{t1}: sim={sim:.4f}  drift={drift:.4f}  {bar}  {label}")

        # Show word changes
        added = set(tw[t1]) - set(tw[t])
        removed = set(tw[t]) - set(tw[t1])
        if added or removed:
            if removed:
                print(f"           − {', '.join(sorted(removed))}")
            if added:
                print(f"           + {', '.join(sorted(added))}")

    # Summary
    avg_d = np.mean(drifts)
    max_d = np.max(drifts)
    if avg_d < 0.3:
        verdict = "🟢 STABLE — vocabulary is consistent over time"
    elif avg_d < 0.5:
        verdict = "🟡 MODERATE — topic evolves gradually"
    elif avg_d < 0.7:
        verdict = "🟠 DRIFTING — significant vocabulary changes"
    else:
        verdict = "🔴 HIGHLY UNSTABLE — topic vocabulary reshuffles frequently"

    print(f"\n  Avg drift: {avg_d:.4f} | Max jump: {max_d:.4f}")
    print(f"  Verdict: {verdict}")


def show_topic_endpoint(topic_id, subject):
    """
    Show endpoint drift for a specific topic: first year vs last year.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    all_words_set = set()
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())
    t_first, t_last = topic_years[0], topic_years[-1]

    v_first = words_to_vector(tw[t_first], vi)
    v_last = words_to_vector(tw[t_last], vi)
    sim = cos_sim(v_first, v_last)
    ttd = 1.0 - sim

    # Words analysis
    w_first = set(tw[t_first])
    w_last = set(tw[t_last])
    kept = sorted(w_first & w_last)
    removed = sorted(w_first - w_last)
    added = sorted(w_last - w_first)

    if ttd < 0.3:
        verdict = "🟢 STABLE — topic maintained its core vocabulary"
    elif ttd < 0.5:
        verdict = "🟡 MODERATE — topic evolved but recognizable"
    elif ttd < 0.7:
        verdict = "🟠 SIGNIFICANT DRIFT — topic substantially changed"
    else:
        verdict = "🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced"

    print(f"\n{'='*70}")
    print(f"Endpoint Drift: Topic {topic_id} — {subject.upper()}")
    print(f"{'='*70}")
    print(f"  Active: {t_first}–{t_last} ({len(topic_years)} years)")
    print(f"  Cosine similarity: {sim:.4f}")
    print(f"  TTD (drift):       {ttd:.4f}")
    print(f"  Verdict: {verdict}")
    print(f"\n  First year ({t_first}): {', '.join(tw[t_first])}")
    print(f"  Last year  ({t_last}): {', '.join(tw[t_last])}")
    print(f"\n  🔒 Kept ({len(kept)}):    {', '.join(kept) if kept else '(none)'}")
    print(f"  ➖ Removed ({len(removed)}): {', '.join(removed) if removed else '(none)'}")
    print(f"  ➕ Added ({len(added)}):   {', '.join(added) if added else '(none)'}")


def show_topic_trajectory(topic_id, subject):
    """
    Show drift trajectory from baseline (first year) for a specific topic.
    cosine_sim(words_t0, words_t) per year — shows when drift accelerates.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    tw = {}
    all_words_set = set()
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())
    t0 = topic_years[0]
    v_baseline = words_to_vector(tw[t0], vi)

    print(f"\n{'='*70}")
    print(f"Drift Trajectory: Topic {topic_id} — {subject.upper()}")
    print(f"Baseline: {t0} → {', '.join(tw[t0])}")
    print(f"{'='*70}")

    prev_drift = 0.0
    for y in topic_years:
        v_y = words_to_vector(tw[y], vi)
        sim = cos_sim(v_baseline, v_y)
        drift = 1.0 - sim

        # Delta from previous year
        delta = drift - prev_drift
        if delta > 0.1:
            delta_label = f" ↑{delta:+.3f} ⚡"
        elif delta > 0.02:
            delta_label = f" ↑{delta:+.3f}"
        elif delta < -0.02:
            delta_label = f" ↓{delta:+.3f} 🔄"
        else:
            delta_label = f"  {delta:+.3f} —"
        prev_drift = drift

        # Shared words with baseline
        shared = sorted(set(tw[t0]) & set(tw[y]))
        n_shared = len(shared)
        n_total = len(tw[t0])

        bar = chr(9608) * int(drift * 30)
        print(f"  {y}: sim={sim:.4f}  drift={drift:.4f}  {bar}{delta_label}  "
              f"({n_shared}/{n_total} baseline words kept)")

    # Final summary
    final_sim = cos_sim(v_baseline, words_to_vector(tw[topic_years[-1]], vi))
    final_drift = 1.0 - final_sim
    kept = sorted(set(tw[t0]) & set(tw[topic_years[-1]]))
    lost = sorted(set(tw[t0]) - set(tw[topic_years[-1]]))

    print(f"\n  Total drift ({t0}→{topic_years[-1]}): {final_drift:.4f}")
    print(f"  Baseline words kept: {', '.join(kept) if kept else '(none)'}")
    print(f"  Baseline words lost: {', '.join(lost) if lost else '(none)'}")

# %% [markdown]
# ### Usage
# ```python
# show_topic_yoy(topic_id=5, subject="cs")
# show_topic_endpoint(topic_id=5, subject="cs")
# ```

# %%
# Example: inspect a specific topic
show_topic_yoy(topic_id=0, subject="cs")
show_topic_trajectory(topic_id=0, subject="cs")
show_topic_endpoint(topic_id=0, subject="cs")
# Out:
# ======================================================================
# YoY Drift: Topic 0 — CS
# Active: 2000–2025 (26 years)
# ======================================================================
#   2000→2001: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − categories, descriptions, mining, ontologies, research
#            + database, documents, pages, query, search
#   2001→2002: sim=0.4000  drift=0.6000  ██████████████████  🟠 Aggressive
#            − apweb, database, databases, pages, query, talkmine
#            + c4, genex, keyphrase, keyphrases, learning, recommender
#   2002→2003: sim=0.7000  drift=0.3000  ████████  🟢 Stable
#            − c4, learning, recommender
#            + algorithm, document, recommendation
#   2003→2004: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − algorithm, genex, recommendation, search, text
#            + content, hierarchy, nrc, relevancy, semantic
#   2004→2005: sim=0.4000  drift=0.6000  ██████████████████  🟠 Aggressive
#            − content, hierarchy, keyphrase, nrc, relevancy, semantic
#            + des, donn, es, requ, treillis, une
#   2005→2006: sim=0.3000  drift=0.7000  █████████████████████  🟠 Aggressive
#            − des, donn, es, keyphrases, requ, treillis, une
#            + approach, elps, gps, information, ontology, query, sources
#   2006→2007: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − approach, document, elps, gps, information, ontology, query, sources, web
#            + bookmarking, citeulike, communities, content, del, icio, metadata, tagging, user
#   2007→2008: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − bookmarking, citeulike, communities, content, del, documents, icio, metadata, tagging
#            + filtering, index, indexing, information, mails, profile, subcorpora, wiki, wikipedia
#   2008→2009: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − filtering, index, mails, wiki
#            + bulletin, document, documents, scir
#   2009→2010: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − bulletin, scir
#            + search, xml
#   2010→2011: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − document, indexing, profile, search, subcorpora, user, wikipedia, xml
#            + art1, biclustering, pages, query, reformulation, retrieval, users, web
#   2011→2012: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − art1, biclustering, query, reformulation
#            + articles, clustering, search, tags
#   2012→2013: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − articles, clustering, retrieval, tags
#            + browsing, engines, query, results
#   2013→2014: sim=0.3000  drift=0.7000  █████████████████████  🟠 Aggressive
#            − browsing, engines, information, pages, query, results, users
#            + albanian, clustering, document, relatedness, semantic, text, tomaco
#   2014→2015: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − albanian, clustering, semantic, tomaco
#            + information, keyword, rdf, user
#   2015→2016: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − information, keyword, rdf, relatedness, text
#            + classification, identifiers, job, namespaces, pages
#   2016→2017: sim=0.4000  drift=0.6000  ██████████████████  🟠 Aggressive
#            − classification, identifiers, job, namespaces, pages, user
#            + data, ontology, query, retrieval, semantic, text
#   2017→2018: sim=0.9000  drift=0.1000  ██  🟢 Stable
#            − data
#            + queries
#   2018→2019: sim=0.6000  drift=0.4000  ████████████  🟡 Moderate
#            − ontology, queries, semantic, text
#            + based, data, information, keyword
#   2019→2020: sim=0.7000  drift=0.3000  █████████  🟡 Moderate
#            − based, data, keyword
#            + clarification, queries, text
#   2020→2021: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − clarification, document
#            + based, data
#   2021→2022: sim=0.7000  drift=0.3000  ████████  🟢 Stable
#            − based, retrieval, web
#            + classification, document, topic
#   2022→2023: sim=0.9000  drift=0.1000  ██  🟢 Stable
#            − topic
#            + retrieval
#   2023→2024: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − data, document
#            + engines, web
#   2024→2025: sim=0.7000  drift=0.3000  ████████  🟢 Stable
#            − classification, engines, information
#            + based, document, semantic
#
#   Avg drift: 0.4520 | Max jump: 0.9000
#   Verdict: 🟡 MODERATE — topic evolves gradually
#
# ======================================================================
# Drift Trajectory: Topic 0 — CS
# Baseline: 2000 → web, apweb, databases, talkmine, mining, text, research, categories, ontologies, descriptions
# ======================================================================
#   2000: sim=1.0000  drift=0.0000    +0.000 —  (10/10 baseline words kept)
#   2001: sim=0.5000  drift=0.5000  ███████████████ ↑+0.500 ⚡  (5/10 baseline words kept)
#   2002: sim=0.2000  drift=0.8000  ████████████████████████ ↑+0.300 ⚡  (2/10 baseline words kept)
#   2003: sim=0.2000  drift=0.8000  ████████████████████████  +0.000 —  (2/10 baseline words kept)
#   2004: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2005: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2006: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2007: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2008: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2009: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2010: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2011: sim=0.1000  drift=0.9000  ███████████████████████████ ↓-0.100 🔄  (1/10 baseline words kept)
#   2012: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2013: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2014: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.100 🔄  (2/10 baseline words kept)
#   2015: sim=0.2000  drift=0.8000  ████████████████████████  +0.000 —  (2/10 baseline words kept)
#   2016: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2017: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.100 🔄  (2/10 baseline words kept)
#   2018: sim=0.2000  drift=0.8000  ████████████████████████  +0.000 —  (2/10 baseline words kept)
#   2019: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2020: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.100 🔄  (2/10 baseline words kept)
#   2021: sim=0.2000  drift=0.8000  ████████████████████████  +0.000 —  (2/10 baseline words kept)
#   2022: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2023: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2024: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.100 🔄  (2/10 baseline words kept)
#   2025: sim=0.2000  drift=0.8000  ████████████████████████  +0.000 —  (2/10 baseline words kept)
#
#   Total drift (2000→2025): 0.8000
#   Baseline words kept: text, web
#   Baseline words lost: apweb, categories, databases, descriptions, mining, ontologies, research, talkmine
#
# ======================================================================
# Endpoint Drift: Topic 0 — CS
# ======================================================================
#   Active: 2000–2025 (26 years)
#   Cosine similarity: 0.2000
#   TTD (drift):       0.8000
#   Verdict: 🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced
#
#   First year (2000): web, apweb, databases, talkmine, mining, text, research, categories, ontologies, descriptions
#   Last year  (2025): search, query, queries, text, web, document, documents, retrieval, based, semantic
#
#   🔒 Kept (2):    text, web
#   ➖ Removed (8): apweb, categories, databases, descriptions, mining, ontologies, research, talkmine
#   ➕ Added (8):   based, document, documents, queries, query, retrieval, search, semantic
