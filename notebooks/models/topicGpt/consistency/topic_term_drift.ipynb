# %% [markdown]
# # TopicGPT: Topic Term Drift (TTD)
#
# **Scenario 3a** — Three complementary drift metrics:
# 1. **Endpoint TTD**: cosine distance from first to last year (total drift)
# 2. **Trajectory from baseline**: cosine_sim(t₀, t) per year (when drift happens)
# 3. **Year-over-year drift**: cosine_sim(t, t+1) per year (smoothness of evolution)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/topicGpt/temporal")
RESULT_DIR = Path("../../../../results/topicGpt/consistency")

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Reading from: ../../../../results/topicGpt/temporal
# Saving to: ../../../../results/topicGpt/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## 1. Endpoint TTD
# Total drift: `TTD = 1 - cosine_sim(words_first, words_last)`

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Endpoint TTD: {subject.upper()} (TopicGPT)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())


    rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t_first, t_last = topic_years[0], topic_years[-1]
        sim = rbo(topic_words[(t_first, tid)], topic_words[(t_last, tid)], p=0.9)

        rows.append({
            "subject": subject, "topic_id": tid,
            "first_year": t_first, "last_year": t_last,
            "n_years": len(topic_years),
            "cosine_sim": round(sim, 6),
            "ttd": round(1.0 - sim, 6),
            "words_first": ", ".join(topic_words[(t_first, tid)]),
            "words_last": ", ".join(topic_words[(t_last, tid)]),
        })

    df = pd.DataFrame(rows)
    df.to_csv(RESULT_DIR / subject / "topic_term_drift.csv", index=False)

    summary = {"subject": subject, "n_topics": len(df),
               "ttd_mean": round(df["ttd"].mean(), 6),
               "ttd_std": round(df["ttd"].std(), 6),
               "ttd_median": round(df["ttd"].median(), 6),
               "pct_stable": round((df["ttd"] < 0.5).mean() * 100, 2),
               "pct_drifted": round((df["ttd"] >= 0.5).mean() * 100, 2)}
    pd.DataFrame([summary]).to_csv(RESULT_DIR / subject / "ttd_summary.csv", index=False)

    print(f"  TTD: mean={summary['ttd_mean']:.4f} ± {summary['ttd_std']:.4f}, "
          f"median={summary['ttd_median']:.4f}")
    print(f"  Stable (TTD<0.5): {summary['pct_stable']:.1f}%  |  "
          f"Drifted (TTD≥0.5): {summary['pct_drifted']:.1f}%")

    print(f"\n  🔥 Top 5 most DRIFTED:")
    for _, r in df.nlargest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | "
              f"{r['words_first'][:40]}... → {r['words_last'][:40]}...")

    print(f"  🔒 Top 5 most STABLE:")
    for _, r in df.nsmallest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | {r['words_first'][:60]}")
# Out:
# ======================================================================
# Endpoint TTD: CS (TopicGPT)
# ======================================================================
#   TTD: mean=0.8935 ± 0.1098, median=0.9331
#   Stable (TTD<0.5): 0.7%  |  Drifted (TTD≥0.5): 99.3%
#
#   🔥 Top 5 most DRIFTED:
#     T  1 | TTD=1.0000 | story, understanding, 1970s, depth, 1990... → models, language, llms, dialogue, social...
#     T  3 | TTD=1.0000 | parsing, dop, ilp, semantic, tilde, indu... → reasoning, language, models, llms, logic...
#     T  5 | TTD=1.0000 | word, hypotheses, rate, words, recognize... → models, language, model, llms, generatio...
#     T  7 | TTD=1.0000 | lightest, derivation, abstractions, sear... → 3d, point, segmentation, document, cloud...
#     T 11 | TTD=1.0000 | object, multicomputers, server, semaphor... → memory, cxl, data, storage, performance,...
#   🔒 Top 5 most STABLE:
#     T114 | TTD=0.4749 | privacy, private, kanonymity, inferencebased, data, differen
#     T 60 | TTD=0.5761 | 2d, 3d, hypothesis, shapes, image, object, reconstruction, p
#     T113 | TTD=0.5889 | salient, saliency, hypergraph, object, hyperedges, regions,
#     T 38 | TTD=0.6415 | manifold, tangent, unorganized, nonlinear, spaces, eigendeco
#     T127 | TTD=0.6539 | policy, learning, tasks, task, policies, generalizes, reinfo
#
# ======================================================================
# Endpoint TTD: MATH (TopicGPT)
# ======================================================================
#   TTD: mean=0.8283 ± 0.1325, median=0.8363
#   Stable (TTD<0.5): 3.2%  |  Drifted (TTD≥0.5): 96.8%
#
#   🔥 Top 5 most DRIFTED:
#     T  9 | TTD=1.0000 | tree, continued, incidence, fraction, ca... → permutations, graphs, graph, trees, ex, ...
#     T 16 | TTD=1.0000 | widetilde, mirror, curve, witten, mm, di... → mathcal, gauge, theories, mathbb, cal, m...
#     T 27 | TTD=1.0000 | kappa, popescu, gamma, eisenbud, spec, s... → modules, rr, rings, module, gorenstein, ...
#     T 30 | TTD=1.0000 | probability, chains, twice, sampled, mea... → branching, population, process, processe...
#     T 34 | TTD=1.0000 | copositive, quadratic, l1, ball, bound, ... → optimization, convex, problems, method, ...
#   🔒 Top 5 most STABLE:
#     T 36 | TTD=0.3967 | symplectic, hamiltonian, group, hyperkaehler, quasifolds, qu
#     T 37 | TTD=0.4566 | hodge, cohomology, manifolds, kahler, rham, gelfand, lielie,
#     T 13 | TTD=0.5819 | knots, legendrian, vassiliev, knot, moves, invariants, linki
#     T 35 | TTD=0.5836 | galois, group, wf, groups, arithmetically, field, ring, coho
#     T 61 | TTD=0.6207 | learning, neural, data, chemical, equations, differential, n
#
# ======================================================================
# Endpoint TTD: PHYSICS (TopicGPT)
# ======================================================================
#   TTD: mean=0.8287 ± 0.1445, median=0.8360
#   Stable (TTD<0.5): 4.9%  |  Drifted (TTD≥0.5): 95.1%
#
#   🔥 Top 5 most DRIFTED:
#     T  6 | TTD=1.0000 | deforming, inherit, energetic, automatic... → fluid, relativistic, hydrodynamics, sph,...
#     T  7 | TTD=1.0000 | attractor, viscosity, inertial, eigenfre... → flow, vortex, reynolds, flows, fluid, in...
#     T 20 | TTD=1.0000 | pbpb, finder, cdf, tevatron, multiplicit... → detector, reconstruction, calorimeter, d...
#     T 28 | TTD=1.0000 | music, genres, listeners, listening, hab... → social, news, online, media, users, netw...
#     T 29 | TTD=1.0000 | mirabilis, proteus, bacteria, swarming, ... → agents, cooperation, active, collective,...
#   🔒 Top 5 most STABLE:
#     T  3 | TTD=0.4421 | cooling, cesium, trap, evaporative, optical, sideband, 10muk
#     T 33 | TTD=0.4794 | solitons, soliton, media, bullets, nonlinear, modulational,
#     T 16 | TTD=0.6330 | single, detectors, photon, 1300nm, apds, superconducting, ss
#     T 30 | TTD=0.6339 | opinion, political, vote, sm, voters, decision, rating, szna
#     T 37 | TTD=0.6862 | rydberg, cold, 30ms, zeke, gases, ionize, trap, lasting, ato

# %% [markdown]
# ## 2. Drift Trajectory from Baseline
# For each topic: `cosine_sim(words_t₀, words_t)` per year — shows **when** drift happens

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Drift Trajectory: {subject.upper()} (TopicGPT)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())


    traj_rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t0 = topic_years[0]
        words_baseline = topic_words[(t0, tid)]

        for y in topic_years:
            words_y = topic_words[(y, tid)]
            sim = rbo(words_baseline, words_y, p=0.9)
            traj_rows.append({
                "subject": subject, "topic_id": tid,
                "baseline_year": t0, "year": y,
                "years_elapsed": y - t0,
                "cosine_sim_to_baseline": round(sim, 6),
                "drift_from_baseline": round(1.0 - sim, 6),
            })

    traj_df = pd.DataFrame(traj_rows)
    traj_df.to_csv(RESULT_DIR / subject / "ttd_trajectory.csv", index=False)

    # Average drift trajectory across all topics per year
    avg_traj = traj_df.groupby("year").agg(
        avg_sim=("cosine_sim_to_baseline", "mean"),
        avg_drift=("drift_from_baseline", "mean"),
        n_topics=("topic_id", "count")
    ).reset_index()
    avg_traj.insert(0, "subject", subject)
    avg_traj.to_csv(RESULT_DIR / subject / "ttd_trajectory_avg.csv", index=False)

    print(f"  Avg drift from baseline per year:")
    for _, r in avg_traj.iterrows():
        bar = '█' * int(r['avg_drift'] * 50)
        print(f"    {int(r['year'])}: sim={r['avg_sim']:.4f}  drift={r['avg_drift']:.4f}  {bar}")
    print(f"  Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv")
# Out:
# ======================================================================
# Drift Trajectory: CS (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.7661  drift=0.2339  ███████████
#     2002: sim=0.5552  drift=0.4448  ██████████████████████
#     2003: sim=0.3162  drift=0.6838  ██████████████████████████████████
#     2004: sim=0.2602  drift=0.7398  ████████████████████████████████████
#     2005: sim=0.2188  drift=0.7812  ███████████████████████████████████████
#     2006: sim=0.2459  drift=0.7541  █████████████████████████████████████
#     2007: sim=0.1919  drift=0.8081  ████████████████████████████████████████
#     2008: sim=0.2288  drift=0.7712  ██████████████████████████████████████
#     2009: sim=0.1372  drift=0.8628  ███████████████████████████████████████████
#     2010: sim=0.1902  drift=0.8098  ████████████████████████████████████████
#     2011: sim=0.2369  drift=0.7631  ██████████████████████████████████████
#     2012: sim=0.2726  drift=0.7274  ████████████████████████████████████
#     2013: sim=0.2547  drift=0.7453  █████████████████████████████████████
#     2014: sim=0.1907  drift=0.8093  ████████████████████████████████████████
#     2015: sim=0.1875  drift=0.8125  ████████████████████████████████████████
#     2016: sim=0.1715  drift=0.8285  █████████████████████████████████████████
#     2017: sim=0.1558  drift=0.8442  ██████████████████████████████████████████
#     2018: sim=0.1430  drift=0.8570  ██████████████████████████████████████████
#     2019: sim=0.1280  drift=0.8720  ███████████████████████████████████████████
#     2020: sim=0.1295  drift=0.8705  ███████████████████████████████████████████
#     2021: sim=0.1223  drift=0.8777  ███████████████████████████████████████████
#     2022: sim=0.1188  drift=0.8812  ████████████████████████████████████████████
#     2023: sim=0.1157  drift=0.8843  ████████████████████████████████████████████
#     2024: sim=0.1068  drift=0.8932  ████████████████████████████████████████████
#     2025: sim=0.1065  drift=0.8935  ████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: MATH (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.5631  drift=0.4369  █████████████████████
#     2002: sim=0.3551  drift=0.6449  ████████████████████████████████
#     2003: sim=0.2775  drift=0.7225  ████████████████████████████████████
#     2004: sim=0.1886  drift=0.8114  ████████████████████████████████████████
#     2005: sim=0.1625  drift=0.8375  █████████████████████████████████████████
#     2006: sim=0.1810  drift=0.8190  ████████████████████████████████████████
#     2007: sim=0.1789  drift=0.8211  █████████████████████████████████████████
#     2008: sim=0.1781  drift=0.8219  █████████████████████████████████████████
#     2009: sim=0.1692  drift=0.8308  █████████████████████████████████████████
#     2010: sim=0.1772  drift=0.8228  █████████████████████████████████████████
#     2011: sim=0.1809  drift=0.8191  ████████████████████████████████████████
#     2012: sim=0.1721  drift=0.8279  █████████████████████████████████████████
#     2013: sim=0.1707  drift=0.8293  █████████████████████████████████████████
#     2014: sim=0.1710  drift=0.8290  █████████████████████████████████████████
#     2015: sim=0.1733  drift=0.8267  █████████████████████████████████████████
#     2016: sim=0.1712  drift=0.8288  █████████████████████████████████████████
#     2017: sim=0.1854  drift=0.8146  ████████████████████████████████████████
#     2018: sim=0.1711  drift=0.8289  █████████████████████████████████████████
#     2019: sim=0.1743  drift=0.8257  █████████████████████████████████████████
#     2020: sim=0.1706  drift=0.8294  █████████████████████████████████████████
#     2021: sim=0.1652  drift=0.8348  █████████████████████████████████████████
#     2022: sim=0.1747  drift=0.8253  █████████████████████████████████████████
#     2023: sim=0.1758  drift=0.8242  █████████████████████████████████████████
#     2024: sim=0.1749  drift=0.8251  █████████████████████████████████████████
#     2025: sim=0.1717  drift=0.8283  █████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: PHYSICS (TopicGPT)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.6489  drift=0.3511  █████████████████
#     2002: sim=0.4906  drift=0.5094  █████████████████████████
#     2003: sim=0.2902  drift=0.7098  ███████████████████████████████████
#     2004: sim=0.2186  drift=0.7814  ███████████████████████████████████████
#     2005: sim=0.2442  drift=0.7558  █████████████████████████████████████
#     2006: sim=0.2265  drift=0.7735  ██████████████████████████████████████
#     2007: sim=0.1833  drift=0.8167  ████████████████████████████████████████
#     2008: sim=0.1688  drift=0.8312  █████████████████████████████████████████
#     2009: sim=0.1618  drift=0.8382  █████████████████████████████████████████
#     2010: sim=0.1601  drift=0.8399  █████████████████████████████████████████
#     2011: sim=0.1634  drift=0.8366  █████████████████████████████████████████
#     2012: sim=0.1701  drift=0.8299  █████████████████████████████████████████
#     2013: sim=0.1617  drift=0.8383  █████████████████████████████████████████
#     2014: sim=0.1725  drift=0.8275  █████████████████████████████████████████
#     2015: sim=0.1639  drift=0.8361  █████████████████████████████████████████
#     2016: sim=0.1658  drift=0.8342  █████████████████████████████████████████
#     2017: sim=0.1688  drift=0.8312  █████████████████████████████████████████
#     2018: sim=0.1682  drift=0.8318  █████████████████████████████████████████
#     2019: sim=0.1686  drift=0.8314  █████████████████████████████████████████
#     2020: sim=0.1719  drift=0.8281  █████████████████████████████████████████
#     2021: sim=0.1626  drift=0.8374  █████████████████████████████████████████
#     2022: sim=0.1662  drift=0.8338  █████████████████████████████████████████
#     2023: sim=0.1722  drift=0.8278  █████████████████████████████████████████
#     2024: sim=0.1697  drift=0.8303  █████████████████████████████████████████
#     2025: sim=0.1713  drift=0.8287  █████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv

# %% [markdown]
# ## 3. Year-over-Year Drift
# `cosine_sim(words_t, words_t+1)` — detects **sudden jumps** vs gradual evolution

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Year-over-Year Drift: {subject.upper()}")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row['year']), int(row['topic_id']))
        topic_words[key] = parse_words(row['top_words'])

    years = sorted(evo_df['year'].unique())


    yoy_rows = []

    # Iterate by CONSECUTIVE CALENDAR YEARS
    for i in range(len(years) - 1):
        t, t1 = int(years[i]), int(years[i + 1])

        # Find topics present in BOTH years
        topics_t = {tid for (y, tid) in topic_words if y == t}
        topics_t1 = {tid for (y, tid) in topic_words if y == t1}
        common_topics = sorted(topics_t & topics_t1)

        for tid in common_topics:
            words_t = topic_words[(t, tid)]
            words_t1 = topic_words[(t1, tid)]
            sim = rbo(words_t, words_t1, p=0.9)

            yoy_rows.append({
                'subject': subject, 'topic_id': tid,
                'year_from': t, 'year_to': t1,
                'cosine_sim': round(sim, 6),
                'drift': round(1.0 - sim, 6),
            })

    yoy_df = pd.DataFrame(yoy_rows)
    yoy_df.to_csv(RESULT_DIR / subject / "ttd_year_over_year.csv", index=False)

    # Per-topic summary
    topic_yoy = yoy_df.groupby('topic_id').agg(
        avg_yoy_sim=('cosine_sim', 'mean'),
        min_yoy_sim=('cosine_sim', 'min'),
        avg_yoy_drift=('drift', 'mean'),
        max_single_jump=('drift', 'max'),
    ).reset_index()
    topic_yoy.insert(0, 'subject', subject)
    topic_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_per_topic.csv", index=False)

    # Avg across all topics per year transition
    avg_yoy = yoy_df.groupby(['year_from', 'year_to']).agg(
        avg_sim=('cosine_sim', 'mean'),
        avg_drift=('drift', 'mean'),
        n_topics=('topic_id', 'count')
    ).reset_index()
    avg_yoy.insert(0, 'subject', subject)
    avg_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_avg.csv", index=False)

    print(f"  Avg year-over-year drift (consecutive calendar years):")
    for _, r in avg_yoy.iterrows():
        bar = chr(9608) * int(r['avg_drift'] * 50)
        print(f"    {int(r['year_from'])}→{int(r['year_to'])}: sim={r['avg_sim']:.4f}  "
              f"drift={r['avg_drift']:.4f}  ({int(r['n_topics'])} topics)  {bar}")

    # Top 5 biggest single-year jumps
    print(f"\n  Top 5 biggest single-year JUMPS:")
    for _, r in yoy_df.nlargest(5, 'drift').iterrows():
        print(f"    T{int(r['topic_id']):>3} | {int(r['year_from'])}→{int(r['year_to'])} | "
              f"drift={r['drift']:.4f}")

    overall_sim = yoy_df['cosine_sim'].mean()
    overall_drift = yoy_df['drift'].mean()
    print(f"\n  Overall: avg_yoy_sim={overall_sim:.4f}  avg_yoy_drift={overall_drift:.4f}")
    print(f"  Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv")
# Out:
# ======================================================================
# Year-over-Year Drift: CS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.5452  drift=0.4548  (18 topics)  ██████████████████████
#     2001→2002: sim=0.4909  drift=0.5091  (23 topics)  █████████████████████████
#     2002→2003: sim=0.4853  drift=0.5147  (20 topics)  █████████████████████████
#     2003→2004: sim=0.3668  drift=0.6332  (23 topics)  ███████████████████████████████
#     2004→2005: sim=0.4657  drift=0.5343  (29 topics)  ██████████████████████████
#     2005→2006: sim=0.5234  drift=0.4766  (28 topics)  ███████████████████████
#     2006→2007: sim=0.3898  drift=0.6102  (29 topics)  ██████████████████████████████
#     2007→2008: sim=0.4470  drift=0.5530  (34 topics)  ███████████████████████████
#     2008→2009: sim=0.4292  drift=0.5708  (32 topics)  ████████████████████████████
#     2009→2010: sim=0.4903  drift=0.5097  (34 topics)  █████████████████████████
#     2010→2011: sim=0.5259  drift=0.4741  (45 topics)  ███████████████████████
#     2011→2012: sim=0.5810  drift=0.4190  (52 topics)  ████████████████████
#     2012→2013: sim=0.5081  drift=0.4919  (67 topics)  ████████████████████████
#     2013→2014: sim=0.5358  drift=0.4642  (78 topics)  ███████████████████████
#     2014→2015: sim=0.5685  drift=0.4315  (89 topics)  █████████████████████
#     2015→2016: sim=0.6032  drift=0.3968  (112 topics)  ███████████████████
#     2016→2017: sim=0.6074  drift=0.3926  (126 topics)  ███████████████████
#     2017→2018: sim=0.6752  drift=0.3248  (135 topics)  ████████████████
#     2018→2019: sim=0.7123  drift=0.2877  (137 topics)  ██████████████
#     2019→2020: sim=0.7540  drift=0.2460  (137 topics)  ████████████
#     2020→2021: sim=0.7734  drift=0.2266  (138 topics)  ███████████
#     2021→2022: sim=0.7938  drift=0.2062  (138 topics)  ██████████
#     2022→2023: sim=0.7922  drift=0.2078  (138 topics)  ██████████
#     2023→2024: sim=0.7962  drift=0.2038  (138 topics)  ██████████
#     2024→2025: sim=0.8223  drift=0.1777  (138 topics)  ████████
#
#   Top 5 biggest single-year JUMPS:
#     T  4 | 2003→2004 | drift=1.0000
#     T101 | 2003→2004 | drift=1.0000
#     T 13 | 2006→2007 | drift=1.0000
#     T 61 | 2006→2007 | drift=1.0000
#     T 61 | 2008→2009 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.6655  avg_yoy_drift=0.3345
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: MATH
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.5346  drift=0.4654  (46 topics)  ███████████████████████
#     2001→2002: sim=0.5198  drift=0.4802  (47 topics)  ████████████████████████
#     2002→2003: sim=0.5146  drift=0.4854  (49 topics)  ████████████████████████
#     2003→2004: sim=0.5092  drift=0.4908  (50 topics)  ████████████████████████
#     2004→2005: sim=0.5078  drift=0.4922  (54 topics)  ████████████████████████
#     2005→2006: sim=0.5378  drift=0.4622  (54 topics)  ███████████████████████
#     2006→2007: sim=0.5680  drift=0.4320  (56 topics)  █████████████████████
#     2007→2008: sim=0.5640  drift=0.4360  (60 topics)  █████████████████████
#     2008→2009: sim=0.5860  drift=0.4140  (59 topics)  ████████████████████
#     2009→2010: sim=0.6152  drift=0.3848  (59 topics)  ███████████████████
#     2010→2011: sim=0.6197  drift=0.3803  (61 topics)  ███████████████████
#     2011→2012: sim=0.6420  drift=0.3580  (62 topics)  █████████████████
#     2012→2013: sim=0.6867  drift=0.3133  (62 topics)  ███████████████
#     2013→2014: sim=0.6760  drift=0.3240  (62 topics)  ████████████████
#     2014→2015: sim=0.7073  drift=0.2927  (62 topics)  ██████████████
#     2015→2016: sim=0.7035  drift=0.2965  (62 topics)  ██████████████
#     2016→2017: sim=0.7153  drift=0.2847  (62 topics)  ██████████████
#     2017→2018: sim=0.7290  drift=0.2710  (63 topics)  █████████████
#     2018→2019: sim=0.7458  drift=0.2542  (63 topics)  ████████████
#     2019→2020: sim=0.7527  drift=0.2473  (63 topics)  ████████████
#     2020→2021: sim=0.7477  drift=0.2523  (63 topics)  ████████████
#     2021→2022: sim=0.7698  drift=0.2302  (63 topics)  ███████████
#     2022→2023: sim=0.7777  drift=0.2223  (63 topics)  ███████████
#     2023→2024: sim=0.7797  drift=0.2203  (63 topics)  ███████████
#     2024→2025: sim=0.8109  drift=0.1891  (63 topics)  █████████
#
#   Top 5 biggest single-year JUMPS:
#     T  3 | 2003→2004 | drift=0.9613
#     T 31 | 2003→2004 | drift=0.9613
#     T 21 | 2001→2002 | drift=0.9565
#     T 46 | 2005→2006 | drift=0.9505
#     T  1 | 2005→2006 | drift=0.9331
#
#   Overall: avg_yoy_sim=0.6606  avg_yoy_drift=0.3394
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: PHYSICS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.5435  drift=0.4565  (20 topics)  ██████████████████████
#     2001→2002: sim=0.4879  drift=0.5121  (23 topics)  █████████████████████████
#     2002→2003: sim=0.4662  drift=0.5338  (24 topics)  ██████████████████████████
#     2003→2004: sim=0.4888  drift=0.5112  (24 topics)  █████████████████████████
#     2004→2005: sim=0.5552  drift=0.4448  (27 topics)  ██████████████████████
#     2005→2006: sim=0.5500  drift=0.4500  (34 topics)  ██████████████████████
#     2006→2007: sim=0.5236  drift=0.4764  (38 topics)  ███████████████████████
#     2007→2008: sim=0.5476  drift=0.4524  (39 topics)  ██████████████████████
#     2008→2009: sim=0.5909  drift=0.4091  (39 topics)  ████████████████████
#     2009→2010: sim=0.6162  drift=0.3838  (41 topics)  ███████████████████
#     2010→2011: sim=0.6618  drift=0.3382  (41 topics)  ████████████████
#     2011→2012: sim=0.6887  drift=0.3113  (41 topics)  ███████████████
#     2012→2013: sim=0.7137  drift=0.2863  (41 topics)  ██████████████
#     2013→2014: sim=0.7580  drift=0.2420  (41 topics)  ████████████
#     2014→2015: sim=0.7650  drift=0.2350  (41 topics)  ███████████
#     2015→2016: sim=0.7765  drift=0.2235  (41 topics)  ███████████
#     2016→2017: sim=0.7680  drift=0.2320  (41 topics)  ███████████
#     2017→2018: sim=0.7793  drift=0.2207  (41 topics)  ███████████
#     2018→2019: sim=0.7920  drift=0.2080  (41 topics)  ██████████
#     2019→2020: sim=0.7898  drift=0.2102  (41 topics)  ██████████
#     2020→2021: sim=0.7999  drift=0.2001  (41 topics)  ██████████
#     2021→2022: sim=0.7967  drift=0.2033  (41 topics)  ██████████
#     2022→2023: sim=0.8102  drift=0.1898  (41 topics)  █████████
#     2023→2024: sim=0.7909  drift=0.2091  (41 topics)  ██████████
#     2024→2025: sim=0.8303  drift=0.1697  (41 topics)  ████████
#
#   Top 5 biggest single-year JUMPS:
#     T 26 | 2005→2006 | drift=1.0000
#     T  9 | 2006→2007 | drift=1.0000
#     T 31 | 2009→2010 | drift=1.0000
#     T 36 | 2008→2009 | drift=0.9613
#     T  7 | 2003→2004 | drift=0.9565
#
#   Overall: avg_yoy_sim=0.6933  avg_yoy_drift=0.3067
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv

# %% [markdown]
# ## Inspect Individual Topics
# Two helper functions to drill into specific topics.

# %%
def show_topic_yoy(topic_id, subject):
    """
    Show year-over-year drift for a specific topic with drift labels.
    Labels: Stable (<0.3), Moderate (0.3-0.6), Aggressive (0.6-0.8), Extreme (>0.8)
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    for _, row in topic_evo.iterrows():
        tw[int(row["year"])] = parse_words(row["top_words"])

    topic_years = sorted(tw.keys())

    print(f"\n{'='*70}")
    print(f"YoY Drift: Topic {topic_id} — {subject.upper()}")
    print(f"Active: {topic_years[0]}–{topic_years[-1]} ({len(topic_years)} years)")
    print(f"{'='*70}")

    drifts = []
    for i in range(len(topic_years) - 1):
        t, t1 = topic_years[i], topic_years[i + 1]
        sim = rbo(tw[t], tw[t1], p=0.9)
        drift = 1.0 - sim
        drifts.append(drift)

        # Label
        if drift < 0.3:
            label = "🟢 Stable"
        elif drift < 0.6:
            label = "🟡 Moderate"
        elif drift < 0.8:
            label = "🟠 Aggressive"
        else:
            label = "🔴 Extreme"

        bar = chr(9608) * int(drift * 30)
        print(f"  {t}→{t1}: sim={sim:.4f}  drift={drift:.4f}  {bar}  {label}")

        # Show word changes
        added = set(tw[t1]) - set(tw[t])
        removed = set(tw[t]) - set(tw[t1])
        if added or removed:
            if removed:
                print(f"           − {', '.join(sorted(removed))}")
            if added:
                print(f"           + {', '.join(sorted(added))}")

    # Summary
    avg_d = np.mean(drifts)
    max_d = np.max(drifts)
    if avg_d < 0.3:
        verdict = "🟢 STABLE — vocabulary is consistent over time"
    elif avg_d < 0.5:
        verdict = "🟡 MODERATE — topic evolves gradually"
    elif avg_d < 0.7:
        verdict = "🟠 DRIFTING — significant vocabulary changes"
    else:
        verdict = "🔴 HIGHLY UNSTABLE — topic vocabulary reshuffles frequently"

    print(f"\n  Avg drift: {avg_d:.4f} | Max jump: {max_d:.4f}")
    print(f"  Verdict: {verdict}")


def show_topic_endpoint(topic_id, subject):
    """
    Show endpoint drift for a specific topic: first year vs last year.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    for _, row in topic_evo.iterrows():
        tw[int(row["year"])] = parse_words(row["top_words"])

    topic_years = sorted(tw.keys())
    t_first, t_last = topic_years[0], topic_years[-1]

    sim = rbo(tw[t_first], tw[t_last], p=0.9)
    ttd = 1.0 - sim

    # Words analysis
    w_first = set(tw[t_first])
    w_last = set(tw[t_last])
    kept = sorted(w_first & w_last)
    removed = sorted(w_first - w_last)
    added = sorted(w_last - w_first)

    if ttd < 0.3:
        verdict = "🟢 STABLE — topic maintained its core vocabulary"
    elif ttd < 0.5:
        verdict = "🟡 MODERATE — topic evolved but recognizable"
    elif ttd < 0.7:
        verdict = "🟠 SIGNIFICANT DRIFT — topic substantially changed"
    else:
        verdict = "🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced"

    print(f"\n{'='*70}")
    print(f"Endpoint Drift: Topic {topic_id} — {subject.upper()}")
    print(f"{'='*70}")
    print(f"  Active: {t_first}–{t_last} ({len(topic_years)} years)")
    print(f"  Cosine similarity: {sim:.4f}")
    print(f"  TTD (drift):       {ttd:.4f}")
    print(f"  Verdict: {verdict}")
    print(f"\n  First year ({t_first}): {', '.join(tw[t_first])}")
    print(f"  Last year  ({t_last}): {', '.join(tw[t_last])}")
    print(f"\n  🔒 Kept ({len(kept)}):    {', '.join(kept) if kept else '(none)'}")
    print(f"  ➖ Removed ({len(removed)}): {', '.join(removed) if removed else '(none)'}")
    print(f"  ➕ Added ({len(added)}):   {', '.join(added) if added else '(none)'}")


def show_topic_trajectory(topic_id, subject):
    """
    Show drift trajectory from baseline (first year) for a specific topic.
    cosine_sim(words_t0, words_t) per year — shows when drift accelerates.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    tw = {}
    for _, row in topic_evo.iterrows():
        tw[int(row["year"])] = parse_words(row["top_words"])

    topic_years = sorted(tw.keys())
    t0 = topic_years[0]
    words_baseline = tw[t0]

    print(f"\n{'='*70}")
    print(f"Drift Trajectory: Topic {topic_id} — {subject.upper()}")
    print(f"Baseline: {t0} → {', '.join(tw[t0])}")
    print(f"{'='*70}")

    prev_drift = 0.0
    for y in topic_years:
        words_y = tw[y]
        sim = rbo(words_baseline, words_y, p=0.9)
        drift = 1.0 - sim

        # Delta from previous year
        delta = drift - prev_drift
        if delta > 0.1:
            delta_label = f" ↑{delta:+.3f} ⚡"
        elif delta > 0.02:
            delta_label = f" ↑{delta:+.3f}"
        elif delta < -0.02:
            delta_label = f" ↓{delta:+.3f} 🔄"
        else:
            delta_label = f"  {delta:+.3f} —"
        prev_drift = drift

        # Shared words with baseline
        shared = sorted(set(tw[t0]) & set(tw[y]))
        n_shared = len(shared)
        n_total = len(tw[t0])

        bar = chr(9608) * int(drift * 30)
        print(f"  {y}: sim={sim:.4f}  drift={drift:.4f}  {bar}{delta_label}  "
              f"({n_shared}/{n_total} baseline words kept)")

    # Final summary
    final_sim = rbo(words_baseline, tw[topic_years[-1]], p=0.9)
    final_drift = 1.0 - final_sim
    kept = sorted(set(tw[t0]) & set(tw[topic_years[-1]]))
    lost = sorted(set(tw[t0]) - set(tw[topic_years[-1]]))

    print(f"\n  Total drift ({t0}→{topic_years[-1]}): {final_drift:.4f}")
    print(f"  Baseline words kept: {', '.join(kept) if kept else '(none)'}")
    print(f"  Baseline words lost: {', '.join(lost) if lost else '(none)'}")

# %% [markdown]
# ### Usage
# ```python
# show_topic_yoy(topic_id=5, subject="cs")
# show_topic_endpoint(topic_id=5, subject="cs")
# ```

# %%
# Example: inspect a specific topic
show_topic_yoy(topic_id=0, subject="cs")
show_topic_trajectory(topic_id=0, subject="cs")
show_topic_endpoint(topic_id=0, subject="cs")
# Out:
# ======================================================================
# YoY Drift: Topic 0 — CS
# Active: 2000–2025 (26 years)
# ======================================================================
#   2000→2001: sim=0.5508  drift=0.4492  █████████████  🟡 Moderate
#            − categories, descriptions, mining, ontologies, research
#            + database, documents, pages, query, search
#   2001→2002: sim=0.3744  drift=0.6256  ██████████████████  🟠 Aggressive
#            − apweb, database, databases, pages, query, talkmine
#            + c4, genex, keyphrase, keyphrases, learning, recommender
#   2002→2003: sim=0.7793  drift=0.2207  ██████  🟢 Stable
#            − c4, learning, recommender
#            + algorithm, document, recommendation
#   2003→2004: sim=0.4531  drift=0.5469  ████████████████  🟡 Moderate
#            − algorithm, genex, recommendation, search, text
#            + content, hierarchy, nrc, relevancy, semantic
#   2004→2005: sim=0.3523  drift=0.6477  ███████████████████  🟠 Aggressive
#            − content, hierarchy, keyphrase, nrc, relevancy, semantic
#            + des, donn, es, requ, treillis, une
#   2005→2006: sim=0.4756  drift=0.5244  ███████████████  🟡 Moderate
#            − des, donn, es, keyphrases, requ, treillis, une
#            + approach, elps, gps, information, ontology, query, sources
#   2006→2007: sim=0.0495  drift=0.9505  ████████████████████████████  🔴 Extreme
#            − approach, document, elps, gps, information, ontology, query, sources, web
#            + bookmarking, citeulike, communities, content, del, icio, metadata, tagging, user
#   2007→2008: sim=0.0435  drift=0.9565  ████████████████████████████  🔴 Extreme
#            − bookmarking, citeulike, communities, content, del, documents, icio, metadata, tagging
#            + filtering, index, indexing, information, mails, profile, subcorpora, wiki, wikipedia
#   2008→2009: sim=0.7698  drift=0.2302  ██████  🟢 Stable
#            − filtering, index, mails, wiki
#            + bulletin, document, documents, scir
#   2009→2010: sim=0.5084  drift=0.4916  ██████████████  🟡 Moderate
#            − bulletin, scir
#            + search, xml
#   2010→2011: sim=0.2503  drift=0.7497  ██████████████████████  🟠 Aggressive
#            − document, indexing, profile, search, subcorpora, user, wikipedia, xml
#            + art1, biclustering, pages, query, reformulation, retrieval, users, web
#   2011→2012: sim=0.6758  drift=0.3242  █████████  🟡 Moderate
#            − art1, biclustering, query, reformulation
#            + articles, clustering, search, tags
#   2012→2013: sim=0.6492  drift=0.3508  ██████████  🟡 Moderate
#            − articles, clustering, retrieval, tags
#            + browsing, engines, query, results
#   2013→2014: sim=0.4939  drift=0.5061  ███████████████  🟡 Moderate
#            − browsing, engines, information, pages, query, results, users
#            + albanian, clustering, document, relatedness, semantic, text, tomaco
#   2014→2015: sim=0.6978  drift=0.3022  █████████  🟡 Moderate
#            − albanian, clustering, semantic, tomaco
#            + information, keyword, rdf, user
#   2015→2016: sim=0.6649  drift=0.3351  ██████████  🟡 Moderate
#            − information, keyword, rdf, relatedness, text
#            + classification, identifiers, job, namespaces, pages
#   2016→2017: sim=0.6459  drift=0.3541  ██████████  🟡 Moderate
#            − classification, identifiers, job, namespaces, pages, user
#            + data, ontology, query, retrieval, semantic, text
#   2017→2018: sim=0.7711  drift=0.2289  ██████  🟢 Stable
#            − data
#            + queries
#   2018→2019: sim=0.7354  drift=0.2646  ███████  🟢 Stable
#            − ontology, queries, semantic, text
#            + based, data, information, keyword
#   2019→2020: sim=0.6791  drift=0.3209  █████████  🟡 Moderate
#            − based, data, keyword
#            + clarification, queries, text
#   2020→2021: sim=0.8078  drift=0.1922  █████  🟢 Stable
#            − clarification, document
#            + based, data
#   2021→2022: sim=0.6002  drift=0.3998  ███████████  🟡 Moderate
#            − based, retrieval, web
#            + classification, document, topic
#   2022→2023: sim=0.7221  drift=0.2779  ████████  🟢 Stable
#            − topic
#            + retrieval
#   2023→2024: sim=0.7908  drift=0.2092  ██████  🟢 Stable
#            − data, document
#            + engines, web
#   2024→2025: sim=0.6791  drift=0.3209  █████████  🟡 Moderate
#            − classification, engines, information
#            + based, document, semantic
#
#   Avg drift: 0.4312 | Max jump: 0.9565
#   Verdict: 🟡 MODERATE — topic evolves gradually
#
# ======================================================================
# Drift Trajectory: Topic 0 — CS
# Baseline: 2000 → web, apweb, databases, talkmine, mining, text, research, categories, ontologies, descriptions
# ======================================================================
#   2000: sim=1.0000  drift=0.0000    +0.000 —  (10/10 baseline words kept)
#   2001: sim=0.5508  drift=0.4492  █████████████ ↑+0.449 ⚡  (5/10 baseline words kept)
#   2002: sim=0.2372  drift=0.7628  ██████████████████████ ↑+0.314 ⚡  (2/10 baseline words kept)
#   2003: sim=0.2198  drift=0.7802  ███████████████████████  +0.017 —  (2/10 baseline words kept)
#   2004: sim=0.1253  drift=0.8747  ██████████████████████████ ↑+0.095  (1/10 baseline words kept)
#   2005: sim=0.0801  drift=0.9199  ███████████████████████████ ↑+0.045  (1/10 baseline words kept)
#   2006: sim=0.0983  drift=0.9017  ███████████████████████████  -0.018 —  (1/10 baseline words kept)
#   2007: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.098  (0/10 baseline words kept)
#   2008: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2009: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2010: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2011: sim=0.2703  drift=0.7297  █████████████████████ ↓-0.270 🔄  (1/10 baseline words kept)
#   2012: sim=0.2703  drift=0.7297  █████████████████████  +0.000 —  (1/10 baseline words kept)
#   2013: sim=0.2703  drift=0.7297  █████████████████████  +0.000 —  (1/10 baseline words kept)
#   2014: sim=0.3372  drift=0.6628  ███████████████████ ↓-0.067 🔄  (2/10 baseline words kept)
#   2015: sim=0.3372  drift=0.6628  ███████████████████  +0.000 —  (2/10 baseline words kept)
#   2016: sim=0.2703  drift=0.7297  █████████████████████ ↑+0.067  (1/10 baseline words kept)
#   2017: sim=0.3198  drift=0.6802  ████████████████████ ↓-0.050 🔄  (2/10 baseline words kept)
#   2018: sim=0.2274  drift=0.7726  ███████████████████████ ↑+0.092  (2/10 baseline words kept)
#   2019: sim=0.1703  drift=0.8297  ████████████████████████ ↑+0.057  (1/10 baseline words kept)
#   2020: sim=0.1640  drift=0.8360  █████████████████████████  +0.006 —  (2/10 baseline words kept)
#   2021: sim=0.1470  drift=0.8530  █████████████████████████  +0.017 —  (2/10 baseline words kept)
#   2022: sim=0.0669  drift=0.9331  ███████████████████████████ ↑+0.080  (1/10 baseline words kept)
#   2023: sim=0.0669  drift=0.9331  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2024: sim=0.1057  drift=0.8943  ██████████████████████████ ↓-0.039 🔄  (2/10 baseline words kept)
#   2025: sim=0.1470  drift=0.8530  █████████████████████████ ↓-0.041 🔄  (2/10 baseline words kept)
#
#   Total drift (2000→2025): 0.8530
#   Baseline words kept: text, web
#   Baseline words lost: apweb, categories, databases, descriptions, mining, ontologies, research, talkmine
#
# ======================================================================
# Endpoint Drift: Topic 0 — CS
# ======================================================================
#   Active: 2000–2025 (26 years)
#   Cosine similarity: 0.1470
#   TTD (drift):       0.8530
#   Verdict: 🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced
#
#   First year (2000): web, apweb, databases, talkmine, mining, text, research, categories, ontologies, descriptions
#   Last year  (2025): search, query, queries, text, web, document, documents, retrieval, based, semantic
#
#   🔒 Kept (2):    text, web
#   ➖ Removed (8): apweb, categories, databases, descriptions, mining, ontologies, research, talkmine
#   ➕ Added (8):   based, document, documents, queries, query, retrieval, search, semantic
