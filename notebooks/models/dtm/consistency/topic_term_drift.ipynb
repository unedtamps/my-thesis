# %% [markdown]
# # DTM: Topic Term Drift (TTD)
#
# **Scenario 3a** — Three complementary drift metrics:
# 1. **Endpoint TTD**: cosine distance from first to last year (total drift)
# 2. **Trajectory from baseline**: cosine_sim(t₀, t) per year (when drift happens)
# 3. **Year-over-year drift**: cosine_sim(t, t+1) per year (smoothness of evolution)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/dtm/temporal")
RESULT_DIR = Path("../../../../results/dtm/consistency")

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Reading from: ../../../../results/dtm/temporal
# Saving to: ../../../../results/dtm/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def words_to_vector(words, vocab_index):
    vec = np.zeros(len(vocab_index))
    for w in words:
        if w in vocab_index:
            vec[vocab_index[w]] = 1.0
    return vec


def cos_sim(v1, v2):
    """Cosine similarity between two vectors."""
    return float(cosine_similarity(v1.reshape(1, -1), v2.reshape(1, -1))[0, 0])

# %% [markdown]
# ## 1. Endpoint TTD
# Total drift: `TTD = 1 - cosine_sim(words_first, words_last)`

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Endpoint TTD: {subject.upper()} (DTM)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())

    # Build global vocabulary
    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t_first, t_last = topic_years[0], topic_years[-1]
        v_first = words_to_vector(topic_words[(t_first, tid)], vocab_index)
        v_last = words_to_vector(topic_words[(t_last, tid)], vocab_index)
        sim = cos_sim(v_first, v_last)

        rows.append({
            "subject": subject, "topic_id": tid,
            "first_year": t_first, "last_year": t_last,
            "n_years": len(topic_years),
            "cosine_sim": round(sim, 6),
            "ttd": round(1.0 - sim, 6),
            "words_first": ", ".join(topic_words[(t_first, tid)]),
            "words_last": ", ".join(topic_words[(t_last, tid)]),
        })

    df = pd.DataFrame(rows)
    df.to_csv(RESULT_DIR / subject / "topic_term_drift.csv", index=False)

    summary = {"subject": subject, "n_topics": len(df),
               "ttd_mean": round(df["ttd"].mean(), 6),
               "ttd_std": round(df["ttd"].std(), 6),
               "ttd_median": round(df["ttd"].median(), 6),
               "pct_stable": round((df["ttd"] < 0.5).mean() * 100, 2),
               "pct_drifted": round((df["ttd"] >= 0.5).mean() * 100, 2)}
    pd.DataFrame([summary]).to_csv(RESULT_DIR / subject / "ttd_summary.csv", index=False)

    print(f"  TTD: mean={summary['ttd_mean']:.4f} ± {summary['ttd_std']:.4f}, "
          f"median={summary['ttd_median']:.4f}")
    print(f"  Stable (TTD<0.5): {summary['pct_stable']:.1f}%  |  "
          f"Drifted (TTD≥0.5): {summary['pct_drifted']:.1f}%")

    print(f"\n  �� Top 5 most DRIFTED:")
    for _, r in df.nlargest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | "
              f"{r['words_first'][:40]}... → {r['words_last'][:40]}...")

    print(f"  🔒 Top 5 most STABLE:")
    for _, r in df.nsmallest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | {r['words_first'][:60]}")
# Out:
# ======================================================================
# Endpoint TTD: CS (DTM)
# ======================================================================
#   TTD: mean=0.9700 ± 0.0505, median=1.0000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   �� Top 5 most DRIFTED:
#     T  0 | TTD=1.0000 | algorithm, rule, theory, program, datum,... → policy, modeling, linear, local, consist...
#     T  3 | TTD=1.0000 | logic, information, algorithm, non, lang... → control, global, development, limited, t...
#     T  4 | TTD=1.0000 | algorithm, logic, datum, set, domain, te... → benchmark, distribution, interaction, mu...
#     T  8 | TTD=1.0000 | algorithm, rule, logic, program, theory,... → multi, robust, potential, accurate, flow...
#     T 11 | TTD=1.0000 | logic, algorithm, program, order, tool, ... → code, network, planning, computation, sh...
#   🔒 Top 5 most STABLE:
#     T 35 | TTD=0.8000 | algorithm, language, program, agent, logic, set, semantic, t
#     T  1 | TTD=0.9000 | set, algorithm, program, datum, language, rule, pattern, log
#     T  2 | TTD=0.9000 | logic, algorithm, program, language, information, datum, set
#     T  5 | TTD=0.9000 | algorithm, program, function, theory, rule, word, language,
#     T  6 | TTD=0.9000 | datum, order, language, set, complexity, algorithm, logic, i
#
# ======================================================================
# Endpoint TTD: MATH (DTM)
# ======================================================================
#   TTD: mean=0.9560 ± 0.0611, median=1.0000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   �� Top 5 most DRIFTED:
#     T  2 | TTD=1.0000 | space, algebra, group, manifold, class, ... → wave, classification, exponential, sampl...
#     T  3 | TTD=1.0000 | manifold, space, non, group, algebra, fu... → inequality, integer, assumption, structu...
#     T  4 | TTD=1.0000 | space, theory, group, quantum, function,... → mathbb_mathbb, order, finite, scheme, no...
#     T  5 | TTD=1.0000 | group, algebra, class, theory, function,... → edge, vertex, periodic, lattice, log, lo...
#     T  7 | TTD=1.0000 | algebra, operator, theory, invariant, gr... → domain, constant, prime, independent, op...
#   🔒 Top 5 most STABLE:
#     T  6 | TTD=0.8000 | group, operator, vector, space, invariant, manifold, structu
#     T 25 | TTD=0.8000 | group, function, theory, manifold, algebra, operator, field,
#     T 48 | TTD=0.8000 | theory, algebra, operator, invariant, group, function, manif
#     T  0 | TTD=0.9000 | algebra, group, space, theory, operator, quantum, representa
#     T  1 | TTD=0.9000 | group, manifold, space, dimension, algebra, representation,
#
# ======================================================================
# Endpoint TTD: PHYSICS (DTM)
# ======================================================================
#   TTD: mean=0.9550 ± 0.0622, median=1.0000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   �� Top 5 most DRIFTED:
#     T  0 | TTD=1.0000 | electron, beam, structure, energy, effec... → datum, prediction, optimization, domain,...
#     T  1 | TTD=1.0000 | beam, energy, theory, measurement, sourc... → size, order, gas, event, network, cohere...
#     T  2 | TTD=1.0000 | energy, field, beam, effect, transition,... → dimensional, liquid, standard, formation...
#     T  3 | TTD=1.0000 | beam, energy, field, particle, phase, ef... → frequency, regime, tool, spectral, point...
#     T  5 | TTD=1.0000 | beam, energy, dynamic, nonlinear, freque... → control, interface, charge, traditional,...
#   🔒 Top 5 most STABLE:
#     T 21 | TTD=0.8000 | beam, field, energy, wave, quantum, surface, space, ion, mod
#     T 36 | TTD=0.8000 | field, beam, rate, dimensional, theory, effect, dynamic, ato
#     T 44 | TTD=0.8000 | beam, space, energy, field, structure, atom, function, magne
#     T 54 | TTD=0.8000 | energy, field, distribution, beam, structure, electron, line
#     T  4 | TTD=0.9000 | beam, quantum, energy, mode, electron, effect, term, field,

# %% [markdown]
# ## 2. Drift Trajectory from Baseline
# For each topic: `cosine_sim(words_t₀, words_t)` per year — shows **when** drift happens

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Drift Trajectory: {subject.upper()} (DTM)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())

    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    traj_rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t0 = topic_years[0]
        v_baseline = words_to_vector(topic_words[(t0, tid)], vocab_index)

        for y in topic_years:
            v_y = words_to_vector(topic_words[(y, tid)], vocab_index)
            sim = cos_sim(v_baseline, v_y)
            traj_rows.append({
                "subject": subject, "topic_id": tid,
                "baseline_year": t0, "year": y,
                "years_elapsed": y - t0,
                "cosine_sim_to_baseline": round(sim, 6),
                "drift_from_baseline": round(1.0 - sim, 6),
            })

    traj_df = pd.DataFrame(traj_rows)
    traj_df.to_csv(RESULT_DIR / subject / "ttd_trajectory.csv", index=False)

    # Average drift trajectory across all topics per year
    avg_traj = traj_df.groupby("year").agg(
        avg_sim=("cosine_sim_to_baseline", "mean"),
        avg_drift=("drift_from_baseline", "mean"),
        n_topics=("topic_id", "count")
    ).reset_index()
    avg_traj.insert(0, "subject", subject)
    avg_traj.to_csv(RESULT_DIR / subject / "ttd_trajectory_avg.csv", index=False)

    print(f"  Avg drift from baseline per year:")
    for _, r in avg_traj.iterrows():
        bar = '█' * int(r['avg_drift'] * 50)
        print(f"    {int(r['year'])}: sim={r['avg_sim']:.4f}  drift={r['avg_drift']:.4f}  {bar}")
    print(f"  Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv")
# Out:
# ======================================================================
# Drift Trajectory: CS (DTM)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.3640  drift=0.6360  ███████████████████████████████
#     2002: sim=0.4060  drift=0.5940  █████████████████████████████
#     2003: sim=0.3560  drift=0.6440  ████████████████████████████████
#     2004: sim=0.3600  drift=0.6400  ████████████████████████████████
#     2005: sim=0.2900  drift=0.7100  ███████████████████████████████████
#     2006: sim=0.2780  drift=0.7220  ████████████████████████████████████
#     2007: sim=0.2240  drift=0.7760  ██████████████████████████████████████
#     2008: sim=0.1560  drift=0.8440  ██████████████████████████████████████████
#     2009: sim=0.1600  drift=0.8400  ██████████████████████████████████████████
#     2010: sim=0.1380  drift=0.8620  ███████████████████████████████████████████
#     2011: sim=0.1200  drift=0.8800  ████████████████████████████████████████████
#     2012: sim=0.1260  drift=0.8740  ███████████████████████████████████████████
#     2013: sim=0.0980  drift=0.9020  █████████████████████████████████████████████
#     2014: sim=0.0440  drift=0.9560  ███████████████████████████████████████████████
#     2015: sim=0.0660  drift=0.9340  ██████████████████████████████████████████████
#     2016: sim=0.0620  drift=0.9380  ██████████████████████████████████████████████
#     2017: sim=0.0700  drift=0.9300  ██████████████████████████████████████████████
#     2018: sim=0.0680  drift=0.9320  ██████████████████████████████████████████████
#     2019: sim=0.0600  drift=0.9400  ███████████████████████████████████████████████
#     2020: sim=0.0720  drift=0.9280  ██████████████████████████████████████████████
#     2021: sim=0.0480  drift=0.9520  ███████████████████████████████████████████████
#     2022: sim=0.0460  drift=0.9540  ███████████████████████████████████████████████
#     2023: sim=0.0420  drift=0.9580  ███████████████████████████████████████████████
#     2024: sim=0.0360  drift=0.9640  ████████████████████████████████████████████████
#     2025: sim=0.0300  drift=0.9700  ████████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: MATH (DTM)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.4760  drift=0.5240  ██████████████████████████
#     2002: sim=0.5240  drift=0.4760  ███████████████████████
#     2003: sim=0.4160  drift=0.5840  █████████████████████████████
#     2004: sim=0.4000  drift=0.6000  ██████████████████████████████
#     2005: sim=0.4340  drift=0.5660  ████████████████████████████
#     2006: sim=0.3160  drift=0.6840  ██████████████████████████████████
#     2007: sim=0.3020  drift=0.6980  ██████████████████████████████████
#     2008: sim=0.2780  drift=0.7220  ████████████████████████████████████
#     2009: sim=0.2220  drift=0.7780  ██████████████████████████████████████
#     2010: sim=0.1980  drift=0.8020  ████████████████████████████████████████
#     2011: sim=0.1500  drift=0.8500  ██████████████████████████████████████████
#     2012: sim=0.1460  drift=0.8540  ██████████████████████████████████████████
#     2013: sim=0.1340  drift=0.8660  ███████████████████████████████████████████
#     2014: sim=0.1180  drift=0.8820  ████████████████████████████████████████████
#     2015: sim=0.0760  drift=0.9240  ██████████████████████████████████████████████
#     2016: sim=0.0640  drift=0.9360  ██████████████████████████████████████████████
#     2017: sim=0.0600  drift=0.9400  ███████████████████████████████████████████████
#     2018: sim=0.0820  drift=0.9180  █████████████████████████████████████████████
#     2019: sim=0.0800  drift=0.9200  ██████████████████████████████████████████████
#     2020: sim=0.0800  drift=0.9200  ██████████████████████████████████████████████
#     2021: sim=0.0680  drift=0.9320  ██████████████████████████████████████████████
#     2022: sim=0.0800  drift=0.9200  ██████████████████████████████████████████████
#     2023: sim=0.0740  drift=0.9260  ██████████████████████████████████████████████
#     2024: sim=0.0540  drift=0.9460  ███████████████████████████████████████████████
#     2025: sim=0.0440  drift=0.9560  ███████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: PHYSICS (DTM)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.3933  drift=0.6067  ██████████████████████████████
#     2002: sim=0.3667  drift=0.6333  ███████████████████████████████
#     2003: sim=0.3450  drift=0.6550  ████████████████████████████████
#     2004: sim=0.3700  drift=0.6300  ███████████████████████████████
#     2005: sim=0.3783  drift=0.6217  ███████████████████████████████
#     2006: sim=0.3867  drift=0.6133  ██████████████████████████████
#     2007: sim=0.2917  drift=0.7083  ███████████████████████████████████
#     2008: sim=0.3100  drift=0.6900  ██████████████████████████████████
#     2009: sim=0.2017  drift=0.7983  ███████████████████████████████████████
#     2010: sim=0.1567  drift=0.8433  ██████████████████████████████████████████
#     2011: sim=0.1000  drift=0.9000  █████████████████████████████████████████████
#     2012: sim=0.0917  drift=0.9083  █████████████████████████████████████████████
#     2013: sim=0.0783  drift=0.9217  ██████████████████████████████████████████████
#     2014: sim=0.0933  drift=0.9067  █████████████████████████████████████████████
#     2015: sim=0.0883  drift=0.9117  █████████████████████████████████████████████
#     2016: sim=0.0817  drift=0.9183  █████████████████████████████████████████████
#     2017: sim=0.0700  drift=0.9300  ██████████████████████████████████████████████
#     2018: sim=0.0700  drift=0.9300  ██████████████████████████████████████████████
#     2019: sim=0.0600  drift=0.9400  ███████████████████████████████████████████████
#     2020: sim=0.0633  drift=0.9367  ██████████████████████████████████████████████
#     2021: sim=0.0617  drift=0.9383  ██████████████████████████████████████████████
#     2022: sim=0.0683  drift=0.9317  ██████████████████████████████████████████████
#     2023: sim=0.0567  drift=0.9433  ███████████████████████████████████████████████
#     2024: sim=0.0483  drift=0.9517  ███████████████████████████████████████████████
#     2025: sim=0.0450  drift=0.9550  ███████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv

# %% [markdown]
# ## 3. Year-over-Year Drift
# `cosine_sim(words_t, words_t+1)` — detects **sudden jumps** vs gradual evolution

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Year-over-Year Drift: {subject.upper()}")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row['year']), int(row['topic_id']))
        topic_words[key] = parse_words(row['top_words'])

    years = sorted(evo_df['year'].unique())

    # Build global vocabulary
    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    yoy_rows = []

    # Iterate by CONSECUTIVE CALENDAR YEARS
    for i in range(len(years) - 1):
        t, t1 = int(years[i]), int(years[i + 1])

        # Find topics present in BOTH years
        topics_t = {tid for (y, tid) in topic_words if y == t}
        topics_t1 = {tid for (y, tid) in topic_words if y == t1}
        common_topics = sorted(topics_t & topics_t1)

        for tid in common_topics:
            v_t = words_to_vector(topic_words[(t, tid)], vocab_index)
            v_t1 = words_to_vector(topic_words[(t1, tid)], vocab_index)
            sim = cos_sim(v_t, v_t1)

            yoy_rows.append({
                'subject': subject, 'topic_id': tid,
                'year_from': t, 'year_to': t1,
                'cosine_sim': round(sim, 6),
                'drift': round(1.0 - sim, 6),
            })

    yoy_df = pd.DataFrame(yoy_rows)
    yoy_df.to_csv(RESULT_DIR / subject / "ttd_year_over_year.csv", index=False)

    # Per-topic summary
    topic_yoy = yoy_df.groupby('topic_id').agg(
        avg_yoy_sim=('cosine_sim', 'mean'),
        min_yoy_sim=('cosine_sim', 'min'),
        avg_yoy_drift=('drift', 'mean'),
        max_single_jump=('drift', 'max'),
    ).reset_index()
    topic_yoy.insert(0, 'subject', subject)
    topic_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_per_topic.csv", index=False)

    # Avg across all topics per year transition
    avg_yoy = yoy_df.groupby(['year_from', 'year_to']).agg(
        avg_sim=('cosine_sim', 'mean'),
        avg_drift=('drift', 'mean'),
        n_topics=('topic_id', 'count')
    ).reset_index()
    avg_yoy.insert(0, 'subject', subject)
    avg_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_avg.csv", index=False)

    print(f"  Avg year-over-year drift (consecutive calendar years):")
    for _, r in avg_yoy.iterrows():
        bar = chr(9608) * int(r['avg_drift'] * 50)
        print(f"    {int(r['year_from'])}→{int(r['year_to'])}: sim={r['avg_sim']:.4f}  "
              f"drift={r['avg_drift']:.4f}  ({int(r['n_topics'])} topics)  {bar}")

    # Top 5 biggest single-year jumps
    print(f"\n  Top 5 biggest single-year JUMPS:")
    for _, r in yoy_df.nlargest(5, 'drift').iterrows():
        print(f"    T{int(r['topic_id']):>3} | {int(r['year_from'])}→{int(r['year_to'])} | "
              f"drift={r['drift']:.4f}")

    overall_sim = yoy_df['cosine_sim'].mean()
    overall_drift = yoy_df['drift'].mean()
    print(f"\n  Overall: avg_yoy_sim={overall_sim:.4f}  avg_yoy_drift={overall_drift:.4f}")
    print(f"  Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv")
# Out:
# ======================================================================
# Year-over-Year Drift: CS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.3640  drift=0.6360  (50 topics)  ███████████████████████████████
#     2001→2002: sim=0.3340  drift=0.6660  (50 topics)  █████████████████████████████████
#     2002→2003: sim=0.3880  drift=0.6120  (50 topics)  ██████████████████████████████
#     2003→2004: sim=0.4280  drift=0.5720  (50 topics)  ████████████████████████████
#     2004→2005: sim=0.4200  drift=0.5800  (50 topics)  ████████████████████████████
#     2005→2006: sim=0.5180  drift=0.4820  (50 topics)  ████████████████████████
#     2006→2007: sim=0.4800  drift=0.5200  (50 topics)  ██████████████████████████
#     2007→2008: sim=0.3540  drift=0.6460  (50 topics)  ████████████████████████████████
#     2008→2009: sim=0.3760  drift=0.6240  (50 topics)  ███████████████████████████████
#     2009→2010: sim=0.3440  drift=0.6560  (50 topics)  ████████████████████████████████
#     2010→2011: sim=0.2980  drift=0.7020  (50 topics)  ███████████████████████████████████
#     2011→2012: sim=0.3680  drift=0.6320  (50 topics)  ███████████████████████████████
#     2012→2013: sim=0.3820  drift=0.6180  (50 topics)  ██████████████████████████████
#     2013→2014: sim=0.3480  drift=0.6520  (50 topics)  ████████████████████████████████
#     2014→2015: sim=0.3420  drift=0.6580  (50 topics)  ████████████████████████████████
#     2015→2016: sim=0.3900  drift=0.6100  (50 topics)  ██████████████████████████████
#     2016→2017: sim=0.4040  drift=0.5960  (50 topics)  █████████████████████████████
#     2017→2018: sim=0.4780  drift=0.5220  (50 topics)  ██████████████████████████
#     2018→2019: sim=0.6140  drift=0.3860  (50 topics)  ███████████████████
#     2019→2020: sim=0.7260  drift=0.2740  (50 topics)  █████████████
#     2020→2021: sim=0.7660  drift=0.2340  (50 topics)  ███████████
#     2021→2022: sim=0.7780  drift=0.2220  (50 topics)  ███████████
#     2022→2023: sim=0.7980  drift=0.2020  (50 topics)  ██████████
#     2023→2024: sim=0.8380  drift=0.1620  (50 topics)  ████████
#     2024→2025: sim=0.8740  drift=0.1260  (50 topics)  ██████
#
#   Top 5 biggest single-year JUMPS:
#     T  4 | 2014→2015 | drift=1.0000
#     T 32 | 2015→2016 | drift=1.0000
#     T 11 | 2016→2017 | drift=1.0000
#     T 23 | 2001→2002 | drift=0.9000
#     T 28 | 2001→2002 | drift=0.9000
#
#   Overall: avg_yoy_sim=0.4964  avg_yoy_drift=0.5036
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: MATH
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.4760  drift=0.5240  (50 topics)  ██████████████████████████
#     2001→2002: sim=0.4460  drift=0.5540  (50 topics)  ███████████████████████████
#     2002→2003: sim=0.4560  drift=0.5440  (50 topics)  ███████████████████████████
#     2003→2004: sim=0.4420  drift=0.5580  (50 topics)  ███████████████████████████
#     2004→2005: sim=0.4340  drift=0.5660  (50 topics)  ████████████████████████████
#     2005→2006: sim=0.3940  drift=0.6060  (50 topics)  ██████████████████████████████
#     2006→2007: sim=0.4320  drift=0.5680  (50 topics)  ████████████████████████████
#     2007→2008: sim=0.4940  drift=0.5060  (50 topics)  █████████████████████████
#     2008→2009: sim=0.4280  drift=0.5720  (50 topics)  ████████████████████████████
#     2009→2010: sim=0.4120  drift=0.5880  (50 topics)  █████████████████████████████
#     2010→2011: sim=0.4000  drift=0.6000  (50 topics)  ██████████████████████████████
#     2011→2012: sim=0.4700  drift=0.5300  (50 topics)  ██████████████████████████
#     2012→2013: sim=0.4860  drift=0.5140  (50 topics)  █████████████████████████
#     2013→2014: sim=0.5300  drift=0.4700  (50 topics)  ███████████████████████
#     2014→2015: sim=0.5460  drift=0.4540  (50 topics)  ██████████████████████
#     2015→2016: sim=0.5640  drift=0.4360  (50 topics)  █████████████████████
#     2016→2017: sim=0.5900  drift=0.4100  (50 topics)  ████████████████████
#     2017→2018: sim=0.5820  drift=0.4180  (50 topics)  ████████████████████
#     2018→2019: sim=0.6360  drift=0.3640  (50 topics)  ██████████████████
#     2019→2020: sim=0.6420  drift=0.3580  (50 topics)  █████████████████
#     2020→2021: sim=0.6360  drift=0.3640  (50 topics)  ██████████████████
#     2021→2022: sim=0.6300  drift=0.3700  (50 topics)  ██████████████████
#     2022→2023: sim=0.6100  drift=0.3900  (50 topics)  ███████████████████
#     2023→2024: sim=0.6680  drift=0.3320  (50 topics)  ████████████████
#     2024→2025: sim=0.7940  drift=0.2060  (50 topics)  ██████████
#
#   Top 5 biggest single-year JUMPS:
#     T 47 | 2004→2005 | drift=0.9000
#     T  4 | 2005→2006 | drift=0.9000
#     T  2 | 2010→2011 | drift=0.9000
#     T 38 | 2010→2011 | drift=0.9000
#     T 23 | 2011→2012 | drift=0.9000
#
#   Overall: avg_yoy_sim=0.5279  avg_yoy_drift=0.4721
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: PHYSICS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.3933  drift=0.6067  (60 topics)  ██████████████████████████████
#     2001→2002: sim=0.3700  drift=0.6300  (60 topics)  ███████████████████████████████
#     2002→2003: sim=0.3717  drift=0.6283  (60 topics)  ███████████████████████████████
#     2003→2004: sim=0.3483  drift=0.6517  (60 topics)  ████████████████████████████████
#     2004→2005: sim=0.3783  drift=0.6217  (60 topics)  ███████████████████████████████
#     2005→2006: sim=0.4367  drift=0.5633  (60 topics)  ████████████████████████████
#     2006→2007: sim=0.3833  drift=0.6167  (60 topics)  ██████████████████████████████
#     2007→2008: sim=0.3583  drift=0.6417  (60 topics)  ████████████████████████████████
#     2008→2009: sim=0.3233  drift=0.6767  (60 topics)  █████████████████████████████████
#     2009→2010: sim=0.3783  drift=0.6217  (60 topics)  ███████████████████████████████
#     2010→2011: sim=0.3650  drift=0.6350  (60 topics)  ███████████████████████████████
#     2011→2012: sim=0.4133  drift=0.5867  (60 topics)  █████████████████████████████
#     2012→2013: sim=0.4967  drift=0.5033  (60 topics)  █████████████████████████
#     2013→2014: sim=0.4817  drift=0.5183  (60 topics)  █████████████████████████
#     2014→2015: sim=0.4350  drift=0.5650  (60 topics)  ████████████████████████████
#     2015→2016: sim=0.4383  drift=0.5617  (60 topics)  ████████████████████████████
#     2016→2017: sim=0.4633  drift=0.5367  (60 topics)  ██████████████████████████
#     2017→2018: sim=0.5567  drift=0.4433  (60 topics)  ██████████████████████
#     2018→2019: sim=0.5817  drift=0.4183  (60 topics)  ████████████████████
#     2019→2020: sim=0.6650  drift=0.3350  (60 topics)  ████████████████
#     2020→2021: sim=0.6433  drift=0.3567  (60 topics)  █████████████████
#     2021→2022: sim=0.6433  drift=0.3567  (60 topics)  █████████████████
#     2022→2023: sim=0.6400  drift=0.3600  (60 topics)  ██████████████████
#     2023→2024: sim=0.6633  drift=0.3367  (60 topics)  ████████████████
#     2024→2025: sim=0.8017  drift=0.1983  (60 topics)  █████████
#
#   Top 5 biggest single-year JUMPS:
#     T 58 | 2007→2008 | drift=1.0000
#     T 20 | 2010→2011 | drift=1.0000
#     T 22 | 2000→2001 | drift=0.9000
#     T  9 | 2001→2002 | drift=0.9000
#     T 20 | 2001→2002 | drift=0.9000
#
#   Overall: avg_yoy_sim=0.4812  avg_yoy_drift=0.5188
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv

# %% [markdown]
# ## Inspect Individual Topics
# Two helper functions to drill into specific topics.

# %%
def show_topic_yoy(topic_id, subject):
    """
    Show year-over-year drift for a specific topic with drift labels.
    Labels: Stable (<0.3), Moderate (0.3-0.6), Aggressive (0.6-0.8), Extreme (>0.8)
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    all_words_set = set()
    tw = {}
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())

    print(f"\n{'='*70}")
    print(f"YoY Drift: Topic {topic_id} — {subject.upper()}")
    print(f"Active: {topic_years[0]}–{topic_years[-1]} ({len(topic_years)} years)")
    print(f"{'='*70}")

    drifts = []
    for i in range(len(topic_years) - 1):
        t, t1 = topic_years[i], topic_years[i + 1]
        v_t = words_to_vector(tw[t], vi)
        v_t1 = words_to_vector(tw[t1], vi)
        sim = cos_sim(v_t, v_t1)
        drift = 1.0 - sim
        drifts.append(drift)

        # Label
        if drift < 0.3:
            label = "🟢 Stable"
        elif drift < 0.6:
            label = "🟡 Moderate"
        elif drift < 0.8:
            label = "�� Aggressive"
        else:
            label = "🔴 Extreme"

        bar = chr(9608) * int(drift * 30)
        print(f"  {t}→{t1}: sim={sim:.4f}  drift={drift:.4f}  {bar}  {label}")

        # Show word changes
        added = set(tw[t1]) - set(tw[t])
        removed = set(tw[t]) - set(tw[t1])
        if added or removed:
            if removed:
                print(f"           − {', '.join(sorted(removed))}")
            if added:
                print(f"           + {', '.join(sorted(added))}")

    # Summary
    avg_d = np.mean(drifts)
    max_d = np.max(drifts)
    if avg_d < 0.3:
        verdict = "🟢 STABLE — vocabulary is consistent over time"
    elif avg_d < 0.5:
        verdict = "🟡 MODERATE — topic evolves gradually"
    elif avg_d < 0.7:
        verdict = "🟠 DRIFTING — significant vocabulary changes"
    else:
        verdict = "🔴 HIGHLY UNSTABLE — topic vocabulary reshuffles frequently"

    print(f"\n  Avg drift: {avg_d:.4f} | Max jump: {max_d:.4f}")
    print(f"  Verdict: {verdict}")


def show_topic_endpoint(topic_id, subject):
    """
    Show endpoint drift for a specific topic: first year vs last year.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    all_words_set = set()
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())
    t_first, t_last = topic_years[0], topic_years[-1]

    v_first = words_to_vector(tw[t_first], vi)
    v_last = words_to_vector(tw[t_last], vi)
    sim = cos_sim(v_first, v_last)
    ttd = 1.0 - sim

    # Words analysis
    w_first = set(tw[t_first])
    w_last = set(tw[t_last])
    kept = sorted(w_first & w_last)
    removed = sorted(w_first - w_last)
    added = sorted(w_last - w_first)

    if ttd < 0.3:
        verdict = "🟢 STABLE — topic maintained its core vocabulary"
    elif ttd < 0.5:
        verdict = "🟡 MODERATE — topic evolved but recognizable"
    elif ttd < 0.7:
        verdict = "🟠 SIGNIFICANT DRIFT — topic substantially changed"
    else:
        verdict = "🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced"

    print(f"\n{'='*70}")
    print(f"Endpoint Drift: Topic {topic_id} — {subject.upper()}")
    print(f"{'='*70}")
    print(f"  Active: {t_first}–{t_last} ({len(topic_years)} years)")
    print(f"  Cosine similarity: {sim:.4f}")
    print(f"  TTD (drift):       {ttd:.4f}")
    print(f"  Verdict: {verdict}")
    print(f"\n  First year ({t_first}): {', '.join(tw[t_first])}")
    print(f"  Last year  ({t_last}): {', '.join(tw[t_last])}")
    print(f"\n  🔒 Kept ({len(kept)}):    {', '.join(kept) if kept else '(none)'}")
    print(f"  ➖ Removed ({len(removed)}): {', '.join(removed) if removed else '(none)'}")
    print(f"  ➕ Added ({len(added)}):   {', '.join(added) if added else '(none)'}")


def show_topic_trajectory(topic_id, subject):
    """
    Show drift trajectory from baseline (first year) for a specific topic.
    cosine_sim(words_t0, words_t) per year — shows when drift accelerates.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    tw = {}
    all_words_set = set()
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())
    t0 = topic_years[0]
    v_baseline = words_to_vector(tw[t0], vi)

    print(f"\n{'='*70}")
    print(f"Drift Trajectory: Topic {topic_id} — {subject.upper()}")
    print(f"Baseline: {t0} → {', '.join(tw[t0])}")
    print(f"{'='*70}")

    prev_drift = 0.0
    for y in topic_years:
        v_y = words_to_vector(tw[y], vi)
        sim = cos_sim(v_baseline, v_y)
        drift = 1.0 - sim

        # Delta from previous year
        delta = drift - prev_drift
        if delta > 0.1:
            delta_label = f" ↑{delta:+.3f} ⚡"
        elif delta > 0.02:
            delta_label = f" ↑{delta:+.3f}"
        elif delta < -0.02:
            delta_label = f" ↓{delta:+.3f} 🔄"
        else:
            delta_label = f"  {delta:+.3f} —"
        prev_drift = drift

        # Shared words with baseline
        shared = sorted(set(tw[t0]) & set(tw[y]))
        n_shared = len(shared)
        n_total = len(tw[t0])

        bar = chr(9608) * int(drift * 30)
        print(f"  {y}: sim={sim:.4f}  drift={drift:.4f}  {bar}{delta_label}  "
              f"({n_shared}/{n_total} baseline words kept)")

    # Final summary
    final_sim = cos_sim(v_baseline, words_to_vector(tw[topic_years[-1]], vi))
    final_drift = 1.0 - final_sim
    kept = sorted(set(tw[t0]) & set(tw[topic_years[-1]]))
    lost = sorted(set(tw[t0]) - set(tw[topic_years[-1]]))

    print(f"\n  Total drift ({t0}→{topic_years[-1]}): {final_drift:.4f}")
    print(f"  Baseline words kept: {', '.join(kept) if kept else '(none)'}")
    print(f"  Baseline words lost: {', '.join(lost) if lost else '(none)'}")

# %% [markdown]
# ### Usage
# ```python
# show_topic_yoy(topic_id=5, subject="cs")
# show_topic_endpoint(topic_id=5, subject="cs")
# ```

# %%
# Example: inspect a specific topic
show_topic_yoy(topic_id=0, subject="cs")
show_topic_trajectory(topic_id=0, subject="cs")
show_topic_endpoint(topic_id=0, subject="cs")
# Out:
# ======================================================================
# YoY Drift: Topic 0 — CS
# Active: 2000–2025 (26 years)
# ======================================================================
#   2000→2001: sim=0.3000  drift=0.7000  █████████████████████  �� Aggressive
#            − belief_revision, datum, function, programming, rule, set, theory
#            + code, communication, constraint, finite, graph, information, interface
#   2001→2002: sim=0.3000  drift=0.7000  █████████████████████  �� Aggressive
#            − code, communication, constraint, finite, graph, interface, language
#            + datum, logic, network, semantic, service, set, space
#   2002→2003: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − logic, semantic, service, set, space
#            + code, grid, polynomial, resource, theory
#   2003→2004: sim=0.4000  drift=0.6000  ██████████████████  �� Aggressive
#            − code, grid, polynomial, program, resource, theory
#            + decision, order, quantum, region, set, standard
#   2004→2005: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − decision, order, quantum, region, standard
#            + communication, complexity, logic, power, scheme
#   2005→2006: sim=0.4000  drift=0.6000  ██████████████████  �� Aggressive
#            − communication, datum, information, logic, power, scheme
#            + channel, function, linear, random, space, theory
#   2006→2007: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − channel, linear, random, space, theory
#            + code, communication, datum, design, level
#   2007→2008: sim=0.3000  drift=0.7000  █████████████████████  �� Aggressive
#            − algorithm, communication, design, function, level, network, set
#            + capacity, channel, class, error, linear, rate, scheme
#   2008→2009: sim=0.4000  drift=0.6000  ██████████████████  �� Aggressive
#            − capacity, class, code, complexity, error, rate
#            + finite, image, information, optimal, optimization, source
#   2009→2010: sim=0.3000  drift=0.7000  █████████████████████  �� Aggressive
#            − datum, finite, image, linear, optimization, scheme, source
#            + constraint, distribution, graph, node, set, structure, tree
#   2010→2011: sim=0.3000  drift=0.7000  █████████████████████  �� Aggressive
#            − channel, constraint, distribution, graph, information, optimal, tree
#            + class, code, function, linear, probability, property, scheme
#   2011→2012: sim=0.3000  drift=0.7000  █████████████████████  �� Aggressive
#            − class, code, linear, node, probability, property, scheme
#            + channel, game, language, non, optimal, order, rate
#   2012→2013: sim=0.4000  drift=0.6000  ██████████████████  �� Aggressive
#            − channel, game, language, non, set, structure
#            + code, complexity, linear, node, scheme, way
#   2013→2014: sim=0.4000  drift=0.6000  ██████████████████  �� Aggressive
#            − function, linear, node, order, rate, way
#            + channel, energy, multi, processing, property, structure
#   2014→2015: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − channel, code, energy, multi, optimal, processing, scheme, structure
#            + computation, constraint, non, point, program, random, rate, transmission
#   2015→2016: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − computation, constraint, non, point, program, random, rate, transmission
#            + conventional, link, machine, matrix, node, pattern, signal, tool
#   2016→2017: sim=0.4000  drift=0.6000  ██████████████████  �� Aggressive
#            − conventional, link, node, pattern, signal, tool
#            + action, constraint, cost, edge, game, recognition
#   2017→2018: sim=0.6000  drift=0.4000  ███████████  🟡 Moderate
#            − complexity, constraint, cost, edge
#            + approximation, detection, distance, software
#   2018→2019: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − distance, property
#            + energy, modeling
#   2019→2020: sim=0.7000  drift=0.3000  ████████  🟢 Stable
#            − action, detection, energy
#            + datum, policy, representation
#   2020→2021: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − matrix, software
#            + consistency, multi
#   2021→2022: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − machine, recognition
#            + adversarial, linear
#   2022→2023: sim=0.9000  drift=0.1000  ██  🟢 Stable
#            − datum
#            + local
#   2023→2024: sim=1.0000  drift=0.0000    🟢 Stable
#   2024→2025: sim=0.9000  drift=0.1000  ███  🟢 Stable
#            − multi
#            + transformation
#
#   Avg drift: 0.4960 | Max jump: 0.8000
#   Verdict: 🟡 MODERATE — topic evolves gradually
#
# ======================================================================
# Drift Trajectory: Topic 0 — CS
# Baseline: 2000 → algorithm, rule, theory, program, datum, language, set, belief_revision, function, programming
# ======================================================================
#   2000: sim=1.0000  drift=0.0000    +0.000 —  (10/10 baseline words kept)
#   2001: sim=0.3000  drift=0.7000  █████████████████████ ↑+0.700 ⚡  (3/10 baseline words kept)
#   2002: sim=0.4000  drift=0.6000  ██████████████████ ↓-0.100 🔄  (4/10 baseline words kept)
#   2003: sim=0.4000  drift=0.6000  ██████████████████  +0.000 —  (4/10 baseline words kept)
#   2004: sim=0.3000  drift=0.7000  █████████████████████ ↑+0.100  (3/10 baseline words kept)
#   2005: sim=0.3000  drift=0.7000  █████████████████████  +0.000 —  (3/10 baseline words kept)
#   2006: sim=0.4000  drift=0.6000  ██████████████████ ↓-0.100 🔄  (4/10 baseline words kept)
#   2007: sim=0.4000  drift=0.6000  ██████████████████  +0.000 —  (4/10 baseline words kept)
#   2008: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.300 ⚡  (1/10 baseline words kept)
#   2009: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2010: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2011: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.100 🔄  (2/10 baseline words kept)
#   2012: sim=0.3000  drift=0.7000  █████████████████████ ↓-0.100 🔄  (3/10 baseline words kept)
#   2013: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.200 ⚡  (1/10 baseline words kept)
#   2014: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2015: sim=0.1000  drift=0.9000  ███████████████████████████ ↓-0.100 🔄  (1/10 baseline words kept)
#   2016: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2017: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2018: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2019: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2020: sim=0.1000  drift=0.9000  ███████████████████████████ ↓-0.100 🔄  (1/10 baseline words kept)
#   2021: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2022: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2023: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2024: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2025: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#
#   Total drift (2000→2025): 1.0000
#   Baseline words kept: (none)
#   Baseline words lost: algorithm, belief_revision, datum, function, language, program, programming, rule, set, theory
#
# ======================================================================
# Endpoint Drift: Topic 0 — CS
# ======================================================================
#   Active: 2000–2025 (26 years)
#   Cosine similarity: 0.0000
#   TTD (drift):       1.0000
#   Verdict: 🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced
#
#   First year (2000): algorithm, rule, theory, program, datum, language, set, belief_revision, function, programming
#   Last year  (2025): policy, modeling, linear, local, consistency, adversarial, approximation, game, representation, transformation
#
#   🔒 Kept (0):    (none)
#   ➖ Removed (10): algorithm, belief_revision, datum, function, language, program, programming, rule, set, theory
#   ➕ Added (10):   adversarial, approximation, consistency, game, linear, local, modeling, policy, representation, transformation
