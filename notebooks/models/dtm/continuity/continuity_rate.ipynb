# %% [markdown]
# # DTM: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment with DTM-specific classification.
#
# Since DTM maintains **consistent topic IDs across years**, a topic at t is expected
# to map to the **same topic ID** at t+1.
#
# | Priority | Category | Condition |
# |----------|----------|-----------|
# | 1 | **Merge** | sim > THRESHOLD, and the t+1-topic has >1 source |
# | 2 | **Disappear** | sim == 0 |
# | 3 | **Evolve** | 0 < sim ≤ THRESHOLD |
# | 4 | **Mismatch** | sim > THRESHOLD, single source, best-match ID ≠ own topic ID |
# | 5 | **Stable** | sim > THRESHOLD, best-match ID = own topic ID |
# | — | **New** | t+1-topic has no incoming source with sim > 0 |
#
# From t-side: Disappear + Merge + Mismatch + Stable + Evolve = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/dtm/temporal")
RESULT_DIR = Path("../../../../results/dtm/continuity")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold Disappear : sim == 0")
print(f"Threshold Evolve    : 0 < sim <= {THRESHOLD}")
print(f"Threshold Stable    : sim > {THRESHOLD}")
print(f"Merge requires all sources to have sim > {THRESHOLD}")
print(f"New topic : no incoming source with sim > 0")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold Disappear : sim == 0
# Threshold Evolve    : 0 < sim <= 0.5
# Threshold Stable    : sim > 0.5
# Merge requires all sources to have sim > 0.5
# New topic : no incoming source with sim > 0
# Reading from: ../../../../results/dtm/temporal
# Saving to: ../../../../results/dtm/continuity

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n'======================================================================'")
    print(f"Continuity Rate: {subject.upper()} (DTM)")
    print(f"'======================================================================'")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t  = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        # Build full RBO similarity matrix (t → t+1)
        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for ii, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for jj, tid_t1 in enumerate(topics_t1):
                words_t1_tmp = topic_words.get((t_next, tid_t1), [])
                sim_matrix[ii, jj] = rbo(words_t, words_t1_tmp, p=0.9)

        # ── Step 1: Each t-topic → its best t+1-topic ────────────────────────
        best_match_idx = np.argmax(sim_matrix, axis=1)
        best_match_sim = np.max(sim_matrix, axis=1)

        # ── Step 2: Count sources (sim > 0.2) per t+1-topic ──────────────────
        target_counts = Counter()
        for idx in range(len(topics_t)):
            if float(best_match_sim[idx]) > THRESHOLD:
                target_counts[topics_t1[best_match_idx[idx]]] += 1

        # merge_targets: t+1-topics claimed by >1 source with sim > 0.2
        merge_targets = {tgt for tgt, cnt in target_counts.items() if cnt > 1}

        # ── Step 3: Classify each t-topic ─────────────────────────────────────
        n_stable = n_evolve = n_merge = n_disappear = n_mismatch = 0

        for idx, tid in enumerate(topics_t):
            sim_val    = float(best_match_sim[idx])
            target_tid = topics_t1[best_match_idx[idx]]
            words_t    = ", ".join(topic_words.get((t, tid), []))

            # ── 1. MERGE: target has >1 source ───────────────────────────────
            if tid in merge_targets:
                category = "merge"
                n_merge += 1

            # ── 2. DISAPPEAR: sim == 0 ────────────────────────────────────────
            elif sim_val == 0:
                category = "disappear"
                n_disappear += 1

            # ── 3. EVOLVE: 0 < sim <= 0.5 ─────────────────────────────────────
            elif sim_val > 0 and sim_val <= THRESHOLD:
                category = "evolve"
                n_evolve += 1

            # ── 4. MISMATCH: sim > 0.5, single source, target ID ≠ own ID ────
            elif target_tid != tid and sim_val > THRESHOLD:
                category   = "mismatch"
                n_mismatch += 1

            # ── 5. STABLE: sim > 0.5, target ID = own ID ─────────────────────
            else:
                category = "stable"
                n_stable += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target_tid,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # ── Step 4: Record merge groups ────────────────────────────────────────
        for target_tid in merge_targets:
            sources = [tid for idx, tid in enumerate(topics_t)
                       if topics_t1[best_match_idx[idx]] == target_tid
                       and float(best_match_sim[idx]) > THRESHOLD]
            source_sims = [round(float(sim_matrix[topics_t.index(s),
                                                   topics_t1.index(target_tid)]), 4)
                           for s in sources]
            words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
            all_merge_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "target_topic": target_tid,
                "n_sources": len(sources),
                "source_topics": str(sources),
                "source_sims": str(source_sims),
                "target_words": words_t1,
            })

        # ── Step 5: New topics — no incoming source with sim > 0 ────────────
        new_topics = []
        for jj, tid in enumerate(topics_t1):
            if np.max(sim_matrix[:, jj]) == 0:
                new_topics.append(tid)
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t        = len(topics_t)
        n_new          = len(new_topics)
        n_merge_groups = len(merge_targets)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_evolve": n_evolve, "n_merge": n_merge,
            "n_mismatch": n_mismatch, "n_disappear": n_disappear,
            "n_merge_groups": n_merge_groups, "n_new": n_new,
            "pct_stable":    round(n_stable    / total_t * 100, 2),
            "pct_evolve":    round(n_evolve    / total_t * 100, 2),
            "pct_merge":     round(n_merge     / total_t * 100, 2),
            "pct_mismatch":  round(n_mismatch  / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Evolve={n_evolve} ({n_evolve/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Mismatch={n_mismatch} ({n_mismatch/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject,
        "threshold_stable":    THRESHOLD,
        "avg_pct_stable":    round(subj_sum["pct_stable"].mean(),    2),
        "avg_pct_evolve":    round(subj_sum["pct_evolve"].mean(),    2),
        "avg_pct_merge":     round(subj_sum["pct_merge"].mean(),     2),
        "avg_pct_mismatch":  round(subj_sum["pct_mismatch"].mean(),  2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new":          int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Evolve={overall['avg_pct_evolve']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Mismatch={overall['avg_pct_mismatch']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# '======================================================================'
# Continuity Rate: CS (DTM)
# '======================================================================'
#   2000→2001: Stable=2 (4%)  Evolve=28 (56%)  Merge=4 (8%)  Mismatch=16 (32%)  Disappear=0 (0%)  New=0
#   2001→2002: Stable=2 (4%)  Evolve=36 (72%)  Merge=1 (2%)  Mismatch=11 (22%)  Disappear=0 (0%)  New=0
#   2002→2003: Stable=1 (2%)  Evolve=37 (74%)  Merge=3 (6%)  Mismatch=9 (18%)  Disappear=0 (0%)  New=0
#   2003→2004: Stable=1 (2%)  Evolve=40 (80%)  Merge=2 (4%)  Mismatch=7 (14%)  Disappear=0 (0%)  New=0
#   2004→2005: Stable=2 (4%)  Evolve=47 (94%)  Merge=0 (0%)  Mismatch=1 (2%)  Disappear=0 (0%)  New=0
#   2005→2006: Stable=11 (22%)  Evolve=29 (58%)  Merge=2 (4%)  Mismatch=8 (16%)  Disappear=0 (0%)  New=0
#   2006→2007: Stable=16 (32%)  Evolve=29 (58%)  Merge=0 (0%)  Mismatch=5 (10%)  Disappear=0 (0%)  New=0
#   2007→2008: Stable=14 (28%)  Evolve=27 (54%)  Merge=1 (2%)  Mismatch=8 (16%)  Disappear=0 (0%)  New=0
#   2008→2009: Stable=23 (46%)  Evolve=21 (42%)  Merge=1 (2%)  Mismatch=5 (10%)  Disappear=0 (0%)  New=0
#   2009→2010: Stable=26 (52%)  Evolve=19 (38%)  Merge=1 (2%)  Mismatch=4 (8%)  Disappear=0 (0%)  New=0
#   2010→2011: Stable=25 (50%)  Evolve=24 (48%)  Merge=0 (0%)  Mismatch=1 (2%)  Disappear=0 (0%)  New=0
#   2011→2012: Stable=31 (62%)  Evolve=19 (38%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2012→2013: Stable=37 (74%)  Evolve=13 (26%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2013→2014: Stable=36 (72%)  Evolve=14 (28%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2014→2015: Stable=43 (86%)  Evolve=7 (14%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2015→2016: Stable=46 (92%)  Evolve=4 (8%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2016→2017: Stable=47 (94%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2017→2018: Stable=46 (92%)  Evolve=4 (8%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2018→2019: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=60.5%  Evolve=32.3%  Merge=1.2%  Mismatch=6.0%  Disappear=0.0%  New=0
#   Saved: ../../../../results/dtm/continuity/cs
#
# '======================================================================'
# Continuity Rate: MATH (DTM)
# '======================================================================'
#   2000→2001: Stable=1 (2%)  Evolve=1 (2%)  Merge=11 (22%)  Mismatch=37 (74%)  Disappear=0 (0%)  New=0
#   2001→2002: Stable=0 (0%)  Evolve=0 (0%)  Merge=13 (26%)  Mismatch=37 (74%)  Disappear=0 (0%)  New=0
#   2002→2003: Stable=2 (4%)  Evolve=4 (8%)  Merge=5 (10%)  Mismatch=39 (78%)  Disappear=0 (0%)  New=0
#   2003→2004: Stable=1 (2%)  Evolve=6 (12%)  Merge=11 (22%)  Mismatch=32 (64%)  Disappear=0 (0%)  New=0
#   2004→2005: Stable=0 (0%)  Evolve=13 (26%)  Merge=8 (16%)  Mismatch=29 (58%)  Disappear=0 (0%)  New=0
#   2005→2006: Stable=3 (6%)  Evolve=14 (28%)  Merge=10 (20%)  Mismatch=23 (46%)  Disappear=0 (0%)  New=0
#   2006→2007: Stable=4 (8%)  Evolve=3 (6%)  Merge=14 (28%)  Mismatch=29 (58%)  Disappear=0 (0%)  New=0
#   2007→2008: Stable=4 (8%)  Evolve=3 (6%)  Merge=12 (24%)  Mismatch=31 (62%)  Disappear=0 (0%)  New=0
#   2008→2009: Stable=5 (10%)  Evolve=17 (34%)  Merge=8 (16%)  Mismatch=20 (40%)  Disappear=0 (0%)  New=0
#   2009→2010: Stable=17 (34%)  Evolve=21 (42%)  Merge=2 (4%)  Mismatch=10 (20%)  Disappear=0 (0%)  New=0
#   2010→2011: Stable=9 (18%)  Evolve=26 (52%)  Merge=7 (14%)  Mismatch=8 (16%)  Disappear=0 (0%)  New=0
#   2011→2012: Stable=22 (44%)  Evolve=21 (42%)  Merge=2 (4%)  Mismatch=5 (10%)  Disappear=0 (0%)  New=0
#   2012→2013: Stable=25 (50%)  Evolve=17 (34%)  Merge=3 (6%)  Mismatch=5 (10%)  Disappear=0 (0%)  New=0
#   2013→2014: Stable=38 (76%)  Evolve=12 (24%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2014→2015: Stable=37 (74%)  Evolve=11 (22%)  Merge=1 (2%)  Mismatch=1 (2%)  Disappear=0 (0%)  New=0
#   2015→2016: Stable=38 (76%)  Evolve=12 (24%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2016→2017: Stable=40 (80%)  Evolve=10 (20%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2017→2018: Stable=45 (90%)  Evolve=5 (10%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2018→2019: Stable=45 (90%)  Evolve=5 (10%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=45 (90%)  Evolve=4 (8%)  Merge=0 (0%)  Mismatch=1 (2%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=47 (94%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=49.9%  Evolve=17.0%  Merge=8.6%  Mismatch=24.6%  Disappear=0.0%  New=0
#   Saved: ../../../../results/dtm/continuity/math
#
# '======================================================================'
# Continuity Rate: PHYSICS (DTM)
# '======================================================================'
#   2000→2001: Stable=0 (0%)  Evolve=6 (12%)  Merge=7 (14%)  Mismatch=37 (74%)  Disappear=0 (0%)  New=0
#   2001→2002: Stable=0 (0%)  Evolve=14 (28%)  Merge=9 (18%)  Mismatch=27 (54%)  Disappear=0 (0%)  New=0
#   2002→2003: Stable=0 (0%)  Evolve=9 (18%)  Merge=11 (22%)  Mismatch=30 (60%)  Disappear=0 (0%)  New=0
#   2003→2004: Stable=0 (0%)  Evolve=11 (22%)  Merge=9 (18%)  Mismatch=30 (60%)  Disappear=0 (0%)  New=0
#   2004→2005: Stable=0 (0%)  Evolve=11 (22%)  Merge=9 (18%)  Mismatch=30 (60%)  Disappear=0 (0%)  New=0
#   2005→2006: Stable=0 (0%)  Evolve=4 (8%)  Merge=13 (26%)  Mismatch=33 (66%)  Disappear=0 (0%)  New=0
#   2006→2007: Stable=1 (2%)  Evolve=3 (6%)  Merge=9 (18%)  Mismatch=37 (74%)  Disappear=0 (0%)  New=0
#   2007→2008: Stable=1 (2%)  Evolve=14 (28%)  Merge=8 (16%)  Mismatch=27 (54%)  Disappear=0 (0%)  New=0
#   2008→2009: Stable=5 (10%)  Evolve=30 (60%)  Merge=4 (8%)  Mismatch=11 (22%)  Disappear=0 (0%)  New=0
#   2009→2010: Stable=7 (14%)  Evolve=35 (70%)  Merge=2 (4%)  Mismatch=6 (12%)  Disappear=0 (0%)  New=0
#   2010→2011: Stable=15 (30%)  Evolve=24 (48%)  Merge=4 (8%)  Mismatch=7 (14%)  Disappear=0 (0%)  New=0
#   2011→2012: Stable=23 (46%)  Evolve=22 (44%)  Merge=2 (4%)  Mismatch=3 (6%)  Disappear=0 (0%)  New=0
#   2012→2013: Stable=28 (56%)  Evolve=19 (38%)  Merge=1 (2%)  Mismatch=2 (4%)  Disappear=0 (0%)  New=0
#   2013→2014: Stable=32 (64%)  Evolve=18 (36%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2014→2015: Stable=38 (76%)  Evolve=12 (24%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2015→2016: Stable=33 (66%)  Evolve=17 (34%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2016→2017: Stable=36 (72%)  Evolve=14 (28%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2017→2018: Stable=46 (92%)  Evolve=4 (8%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2018→2019: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=46 (92%)  Evolve=4 (8%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=45 (90%)  Evolve=5 (10%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=41 (82%)  Evolve=9 (18%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=41 (82%)  Evolve=9 (18%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=46.7%  Evolve=23.8%  Merge=7.0%  Mismatch=22.4%  Disappear=0.0%  New=0
#   Saved: ../../../../results/dtm/continuity/physics

# %% [markdown]
# ## Analysis Review

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/dtm/temporal")
RESULT_DIR = Path("../../../../results/dtm/continuity")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold Disappear : sim == 0")
print(f"Threshold Evolve    : 0 < sim <= {THRESHOLD}")
print(f"Threshold Stable    : sim > {THRESHOLD}")
print(f"Merge requires all sources to have sim > {THRESHOLD}")
print(f"New topic : no incoming source with sim > 0")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold Disappear : sim == 0
# Threshold Evolve    : 0 < sim <= 0.5
# Threshold Stable    : sim > 0.5
# Merge requires all sources to have sim > 0.5
# New topic : no incoming source with sim > 0
# Reading from: ../../../../results/dtm/temporal
# Saving to: ../../../../results/dtm/continuity
