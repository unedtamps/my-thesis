# %% [markdown]
# # LDA: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/lda/temporal")
RESULT_DIR = Path("../../../../results/lda/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/lda/temporal
# Saving to: ../../../../results/lda/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def build_word_matrix(topic_ids, topic_words_dict, year, vocab_index):
    matrix = np.zeros((len(topic_ids), len(vocab_index)))
    for i, tid in enumerate(topic_ids):
        words = topic_words_dict.get((year, tid), [])
        for w in words:
            if w in vocab_index:
                matrix[i, vocab_index[w]] = 1.0
    return matrix

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_words = set()
    for words in topic_words.values():
        all_words.update(words)
    vocab_index = {w: i for i, w in enumerate(sorted(all_words))}

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        mat_t = build_word_matrix(topics_t, topic_words, t, vocab_index)
        mat_t1 = build_word_matrix(topics_t1, topic_words, t_next, vocab_index)
        sim_matrix = cosine_similarity(mat_t, mat_t1)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (LDA)
# ======================================================================
#   2000→2001: Stable=36 (63%)  Merge=0 (0%)  Disappear=21 (37%)  New=25
#   2001→2002: Stable=29 (48%)  Merge=0 (0%)  Disappear=32 (52%)  New=29
#   2002→2003: Stable=30 (52%)  Merge=0 (0%)  Disappear=28 (48%)  New=29
#   2003→2004: Stable=39 (66%)  Merge=0 (0%)  Disappear=20 (34%)  New=29
#   2004→2005: Stable=33 (49%)  Merge=0 (0%)  Disappear=35 (51%)  New=34
#   2005→2006: Stable=35 (52%)  Merge=0 (0%)  Disappear=32 (48%)  New=34
#   2006→2007: Stable=38 (55%)  Merge=0 (0%)  Disappear=31 (45%)  New=28
#   2007→2008: Stable=38 (58%)  Merge=0 (0%)  Disappear=28 (42%)  New=27
#   2008→2009: Stable=27 (42%)  Merge=0 (0%)  Disappear=38 (58%)  New=39
#   2009→2010: Stable=41 (62%)  Merge=0 (0%)  Disappear=25 (38%)  New=29
#   2010→2011: Stable=52 (74%)  Merge=0 (0%)  Disappear=18 (26%)  New=19
#   2011→2012: Stable=56 (79%)  Merge=0 (0%)  Disappear=15 (21%)  New=18
#   2012→2013: Stable=53 (72%)  Merge=0 (0%)  Disappear=21 (28%)  New=19
#   2013→2014: Stable=54 (75%)  Merge=0 (0%)  Disappear=18 (25%)  New=19
#   2014→2015: Stable=57 (78%)  Merge=0 (0%)  Disappear=16 (22%)  New=16
#   2015→2016: Stable=59 (81%)  Merge=0 (0%)  Disappear=14 (19%)  New=13
#   2016→2017: Stable=63 (88%)  Merge=0 (0%)  Disappear=9 (12%)  New=9
#   2017→2018: Stable=66 (92%)  Merge=0 (0%)  Disappear=6 (8%)  New=8
#   2018→2019: Stable=69 (93%)  Merge=0 (0%)  Disappear=5 (7%)  New=5
#   2019→2020: Stable=70 (95%)  Merge=0 (0%)  Disappear=4 (5%)  New=5
#   2020→2021: Stable=69 (92%)  Merge=0 (0%)  Disappear=6 (8%)  New=6
#   2021→2022: Stable=72 (96%)  Merge=0 (0%)  Disappear=3 (4%)  New=3
#   2022→2023: Stable=71 (95%)  Merge=0 (0%)  Disappear=4 (5%)  New=4
#   2023→2024: Stable=74 (99%)  Merge=0 (0%)  Disappear=1 (1%)  New=1
#   2024→2025: Stable=73 (97%)  Merge=0 (0%)  Disappear=2 (3%)  New=2
#
#   Overall: Stable=74.0%  Merge=0.0%  Disappear=26.0%  New=450
#   Saved: ../../../../results/lda/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (LDA)
# ======================================================================
#   2000→2001: Stable=27 (71%)  Merge=0 (0%)  Disappear=11 (29%)  New=12
#   2001→2002: Stable=26 (67%)  Merge=0 (0%)  Disappear=13 (33%)  New=15
#   2002→2003: Stable=30 (73%)  Merge=0 (0%)  Disappear=11 (27%)  New=10
#   2003→2004: Stable=31 (78%)  Merge=0 (0%)  Disappear=9 (22%)  New=12
#   2004→2005: Stable=34 (79%)  Merge=0 (0%)  Disappear=9 (21%)  New=9
#   2005→2006: Stable=37 (86%)  Merge=0 (0%)  Disappear=6 (14%)  New=7
#   2006→2007: Stable=35 (80%)  Merge=0 (0%)  Disappear=9 (20%)  New=10
#   2007→2008: Stable=39 (87%)  Merge=0 (0%)  Disappear=6 (13%)  New=7
#   2008→2009: Stable=38 (83%)  Merge=0 (0%)  Disappear=8 (17%)  New=8
#   2009→2010: Stable=34 (74%)  Merge=0 (0%)  Disappear=12 (26%)  New=11
#   2010→2011: Stable=41 (91%)  Merge=0 (0%)  Disappear=4 (9%)  New=7
#   2011→2012: Stable=42 (88%)  Merge=0 (0%)  Disappear=6 (12%)  New=5
#   2012→2013: Stable=42 (89%)  Merge=0 (0%)  Disappear=5 (11%)  New=6
#   2013→2014: Stable=43 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=4
#   2014→2015: Stable=43 (91%)  Merge=0 (0%)  Disappear=4 (9%)  New=7
#   2015→2016: Stable=45 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=3
#   2016→2017: Stable=43 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=6
#   2017→2018: Stable=45 (92%)  Merge=0 (0%)  Disappear=4 (8%)  New=4
#   2018→2019: Stable=47 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=3
#   2019→2020: Stable=45 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=3
#   2020→2021: Stable=45 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=3
#   2021→2022: Stable=44 (92%)  Merge=0 (0%)  Disappear=4 (8%)  New=6
#   2022→2023: Stable=45 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=5
#   2023→2024: Stable=48 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=2
#   2024→2025: Stable=45 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=4
#
#   Overall: Stable=85.8%  Merge=0.0%  Disappear=14.2%  New=169
#   Saved: ../../../../results/lda/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (LDA)
# ======================================================================
#   2000→2001: Stable=34 (76%)  Merge=0 (0%)  Disappear=11 (24%)  New=15
#   2001→2002: Stable=32 (65%)  Merge=0 (0%)  Disappear=17 (35%)  New=16
#   2002→2003: Stable=30 (62%)  Merge=0 (0%)  Disappear=18 (38%)  New=19
#   2003→2004: Stable=30 (61%)  Merge=0 (0%)  Disappear=19 (39%)  New=18
#   2004→2005: Stable=28 (58%)  Merge=0 (0%)  Disappear=20 (42%)  New=20
#   2005→2006: Stable=37 (77%)  Merge=0 (0%)  Disappear=11 (23%)  New=11
#   2006→2007: Stable=40 (83%)  Merge=0 (0%)  Disappear=8 (17%)  New=8
#   2007→2008: Stable=40 (83%)  Merge=0 (0%)  Disappear=8 (17%)  New=10
#   2008→2009: Stable=39 (78%)  Merge=0 (0%)  Disappear=11 (22%)  New=11
#   2009→2010: Stable=45 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=5
#   2010→2011: Stable=45 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=5
#   2011→2012: Stable=43 (86%)  Merge=0 (0%)  Disappear=7 (14%)  New=6
#   2012→2013: Stable=44 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=5
#   2013→2014: Stable=46 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=4
#   2014→2015: Stable=46 (92%)  Merge=0 (0%)  Disappear=4 (8%)  New=3
#   2015→2016: Stable=47 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=3
#   2016→2017: Stable=47 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=3
#   2017→2018: Stable=49 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=0
#   2018→2019: Stable=47 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=2
#   2019→2020: Stable=47 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=2
#   2020→2021: Stable=47 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=3
#   2021→2022: Stable=49 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2022→2023: Stable=48 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=1
#   2023→2024: Stable=48 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2024→2025: Stable=48 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#
#   Overall: Stable=86.1%  Merge=0.0%  Disappear=13.9%  New=173
#   Saved: ../../../../results/lda/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 432 events
#   Per year:
#     2000: 21 topics
#     2001: 32 topics
#     2002: 28 topics
#     2003: 20 topics
#     2004: 35 topics
#     2005: 32 topics
#     2006: 31 topics
#     2007: 28 topics
#     2008: 38 topics
#     2009: 25 topics
#     2010: 18 topics
#     2011: 15 topics
#     2012: 21 topics
#     2013: 18 topics
#     2014: 16 topics
#     2015: 14 topics
#     2016: 9 topics
#     2017: 6 topics
#     2018: 5 topics
#     2019: 4 topics
#     2020: 6 topics
#     2021: 3 topics
#     2022: 4 topics
#     2023: 1 topics
#     2024: 2 topics
#
#   Permanently gone: 2
#     T 16 last @ 2024 (sim=0.300) | rho, chess, fiber, lineage, invariant, makeup, inv
#     T 69 last @ 2024 (sim=0.400) | topological, tape, homology, simplicial, tda, cata
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 450 events
#   Per year:
#     2001: 25 new topics
#     2002: 29 new topics
#     2003: 29 new topics
#     2004: 29 new topics
#     2005: 34 new topics
#     2006: 34 new topics
#     2007: 28 new topics
#     2008: 27 new topics
#     2009: 39 new topics
#     2010: 29 new topics
#     2011: 19 new topics
#     2012: 18 new topics
#     2013: 19 new topics
#     2014: 19 new topics
#     2015: 16 new topics
#     2016: 13 new topics
#     2017: 9 new topics
#     2018: 8 new topics
#     2019: 5 new topics
#     2020: 5 new topics
#     2021: 6 new topics
#     2022: 3 new topics
#     2023: 4 new topics
#     2024: 1 new topics
#     2025: 2 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  7 | 100% stable (25S 0M 0D)
#     T  4 | 100% stable (25S 0M 0D)
#     T  3 | 100% stable (25S 0M 0D)
#     T 44 | 100% stable (25S 0M 0D)
#     T 74 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 69 | 44% stable (7S 0M 9D)
#     T 62 | 42% stable (10S 0M 14D)
#     T 17 | 38% stable (3S 0M 5D)
#     T 16 | 33% stable (7S 0M 14D)
#     T 24 | 33% stable (6S 0M 12D)
#
#
# ======================================================================
# Analysis Review: MATH (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 158 events
#   Per year:
#     2000: 11 topics
#     2001: 13 topics
#     2002: 11 topics
#     2003: 9 topics
#     2004: 9 topics
#     2005: 6 topics
#     2006: 9 topics
#     2007: 6 topics
#     2008: 8 topics
#     2009: 12 topics
#     2010: 4 topics
#     2011: 6 topics
#     2012: 5 topics
#     2013: 5 topics
#     2014: 4 topics
#     2015: 5 topics
#     2016: 5 topics
#     2017: 4 topics
#     2018: 2 topics
#     2019: 5 topics
#     2020: 3 topics
#     2021: 4 topics
#     2022: 5 topics
#     2023: 2 topics
#     2024: 5 topics
#
#   Permanently gone: 5
#     T 23 last @ 2024 (sim=0.300) | hilb, geq, mathbb, func, shnirelman, closeness, da
#     T 25 last @ 2024 (sim=0.300) | mathrm, adj, dim, mathbb, gobs, cat, supp, privacy
#     T 30 last @ 2024 (sim=0.000) | semifield, vee, ker, tough, cup, lowercase, spectr
#     T 37 last @ 2024 (sim=0.300) | infty, mathcal, leq, operatorname_gal, mathbb_math
#     T 46 last @ 2024 (sim=0.400) | forall, inftycd, iff, ldots, mathbb, cdot, pseudop
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 169 events
#   Per year:
#     2001: 12 new topics
#     2002: 15 new topics
#     2003: 10 new topics
#     2004: 12 new topics
#     2005: 9 new topics
#     2006: 7 new topics
#     2007: 10 new topics
#     2008: 7 new topics
#     2009: 8 new topics
#     2010: 11 new topics
#     2011: 7 new topics
#     2012: 5 new topics
#     2013: 6 new topics
#     2014: 4 new topics
#     2015: 7 new topics
#     2016: 3 new topics
#     2017: 6 new topics
#     2018: 4 new topics
#     2019: 3 new topics
#     2020: 3 new topics
#     2021: 3 new topics
#     2022: 6 new topics
#     2023: 5 new topics
#     2024: 2 new topics
#     2025: 4 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0M 0D)
#     T  1 | 100% stable (25S 0M 0D)
#     T  4 | 100% stable (25S 0M 0D)
#     T  8 | 100% stable (25S 0M 0D)
#     T  7 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 23 | 46% stable (6S 0M 7D)
#     T 25 | 46% stable (6S 0M 7D)
#     T 30 | 33% stable (5S 0M 10D)
#     T 46 | 20% stable (2S 0M 8D)
#     T 37 | 11% stable (2S 0M 16D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 169 events
#   Per year:
#     2000: 11 topics
#     2001: 17 topics
#     2002: 18 topics
#     2003: 19 topics
#     2004: 20 topics
#     2005: 11 topics
#     2006: 8 topics
#     2007: 8 topics
#     2008: 11 topics
#     2009: 5 topics
#     2010: 5 topics
#     2011: 7 topics
#     2012: 5 topics
#     2013: 3 topics
#     2014: 4 topics
#     2015: 2 topics
#     2016: 3 topics
#     2017: 1 topics
#     2018: 2 topics
#     2019: 2 topics
#     2020: 2 topics
#     2021: 1 topics
#     2022: 2 topics
#     2023: 1 topics
#     2024: 1 topics
#
#   Permanently gone: 2
#     T 21 last @ 2022 (sim=0.000) | prl, comment, arxiv, dot_obs, 15242v1, minguzzi, d
#     T 24 last @ 2024 (sim=0.400) | experimental, diffusion, maple, dmd, dynamic, datu
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 173 events
#   Per year:
#     2001: 15 new topics
#     2002: 16 new topics
#     2003: 19 new topics
#     2004: 18 new topics
#     2005: 20 new topics
#     2006: 11 new topics
#     2007: 8 new topics
#     2008: 10 new topics
#     2009: 11 new topics
#     2010: 5 new topics
#     2011: 5 new topics
#     2012: 6 new topics
#     2013: 5 new topics
#     2014: 4 new topics
#     2015: 3 new topics
#     2016: 3 new topics
#     2017: 3 new topics
#     2019: 2 new topics
#     2020: 2 new topics
#     2021: 3 new topics
#     2022: 1 new topics
#     2023: 1 new topics
#     2024: 1 new topics
#     2025: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  8 | 100% stable (25S 0M 0D)
#     T  3 | 100% stable (25S 0M 0D)
#     T 16 | 100% stable (25S 0M 0D)
#     T 10 | 100% stable (25S 0M 0D)
#     T 43 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 32 | 58% stable (14S 0M 10D)
#     T 21 | 54% stable (7S 0M 6D)
#     T 29 | 52% stable (11S 0M 10D)
#     T 24 | 30% stable (7S 0M 16D)
#     T 41 | 30% stable (6S 0M 14D)
