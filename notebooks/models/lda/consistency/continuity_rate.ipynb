# %% [markdown]
# # LDA: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/lda/temporal")
RESULT_DIR = Path("../../../../results/lda/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/lda/temporal
# Saving to: ../../../../results/lda/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]

def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for i, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for j, tid_t1 in enumerate(topics_t1):
                words_t1 = topic_words.get((t_next, tid_t1), [])
                sim_matrix[i, j] = rbo(words_t, words_t1, p=0.9)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (LDA)
# ======================================================================
#   2000→2001: Stable=31 (54%)  Merge=0 (0%)  Disappear=26 (46%)  New=30
#   2001→2002: Stable=26 (43%)  Merge=0 (0%)  Disappear=35 (57%)  New=32
#   2002→2003: Stable=27 (47%)  Merge=0 (0%)  Disappear=31 (53%)  New=32
#   2003→2004: Stable=35 (59%)  Merge=0 (0%)  Disappear=24 (41%)  New=33
#   2004→2005: Stable=27 (40%)  Merge=2 (3%)  Disappear=39 (57%)  New=39
#   2005→2006: Stable=28 (42%)  Merge=0 (0%)  Disappear=39 (58%)  New=41
#   2006→2007: Stable=29 (42%)  Merge=0 (0%)  Disappear=40 (58%)  New=37
#   2007→2008: Stable=35 (53%)  Merge=0 (0%)  Disappear=31 (47%)  New=30
#   2008→2009: Stable=29 (45%)  Merge=0 (0%)  Disappear=36 (55%)  New=37
#   2009→2010: Stable=41 (62%)  Merge=0 (0%)  Disappear=25 (38%)  New=29
#   2010→2011: Stable=48 (69%)  Merge=0 (0%)  Disappear=22 (31%)  New=23
#   2011→2012: Stable=54 (76%)  Merge=0 (0%)  Disappear=17 (24%)  New=20
#   2012→2013: Stable=48 (65%)  Merge=0 (0%)  Disappear=26 (35%)  New=24
#   2013→2014: Stable=51 (71%)  Merge=0 (0%)  Disappear=21 (29%)  New=22
#   2014→2015: Stable=56 (77%)  Merge=0 (0%)  Disappear=17 (23%)  New=17
#   2015→2016: Stable=59 (81%)  Merge=0 (0%)  Disappear=14 (19%)  New=13
#   2016→2017: Stable=64 (89%)  Merge=0 (0%)  Disappear=8 (11%)  New=8
#   2017→2018: Stable=64 (89%)  Merge=0 (0%)  Disappear=8 (11%)  New=10
#   2018→2019: Stable=70 (95%)  Merge=0 (0%)  Disappear=4 (5%)  New=4
#   2019→2020: Stable=70 (95%)  Merge=0 (0%)  Disappear=4 (5%)  New=5
#   2020→2021: Stable=70 (93%)  Merge=0 (0%)  Disappear=5 (7%)  New=5
#   2021→2022: Stable=71 (95%)  Merge=0 (0%)  Disappear=4 (5%)  New=4
#   2022→2023: Stable=70 (93%)  Merge=0 (0%)  Disappear=5 (7%)  New=5
#   2023→2024: Stable=69 (92%)  Merge=0 (0%)  Disappear=6 (8%)  New=6
#   2024→2025: Stable=72 (96%)  Merge=0 (0%)  Disappear=3 (4%)  New=3
#
#   Overall: Stable=70.4%  Merge=0.1%  Disappear=29.5%  New=509
#   Saved: ../../../../results/lda/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (LDA)
# ======================================================================
#   2000→2001: Stable=25 (66%)  Merge=0 (0%)  Disappear=13 (34%)  New=14
#   2001→2002: Stable=20 (51%)  Merge=0 (0%)  Disappear=19 (49%)  New=21
#   2002→2003: Stable=26 (63%)  Merge=0 (0%)  Disappear=15 (37%)  New=14
#   2003→2004: Stable=28 (70%)  Merge=0 (0%)  Disappear=12 (30%)  New=15
#   2004→2005: Stable=31 (72%)  Merge=0 (0%)  Disappear=12 (28%)  New=12
#   2005→2006: Stable=30 (70%)  Merge=0 (0%)  Disappear=13 (30%)  New=14
#   2006→2007: Stable=32 (73%)  Merge=0 (0%)  Disappear=12 (27%)  New=13
#   2007→2008: Stable=38 (84%)  Merge=0 (0%)  Disappear=7 (16%)  New=8
#   2008→2009: Stable=36 (78%)  Merge=0 (0%)  Disappear=10 (22%)  New=10
#   2009→2010: Stable=37 (80%)  Merge=0 (0%)  Disappear=9 (20%)  New=8
#   2010→2011: Stable=41 (91%)  Merge=0 (0%)  Disappear=4 (9%)  New=7
#   2011→2012: Stable=39 (81%)  Merge=0 (0%)  Disappear=9 (19%)  New=8
#   2012→2013: Stable=39 (83%)  Merge=0 (0%)  Disappear=8 (17%)  New=9
#   2013→2014: Stable=43 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=4
#   2014→2015: Stable=39 (83%)  Merge=0 (0%)  Disappear=8 (17%)  New=11
#   2015→2016: Stable=44 (88%)  Merge=0 (0%)  Disappear=6 (12%)  New=4
#   2016→2017: Stable=43 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=6
#   2017→2018: Stable=44 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=5
#   2018→2019: Stable=46 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=4
#   2019→2020: Stable=44 (88%)  Merge=0 (0%)  Disappear=6 (12%)  New=4
#   2020→2021: Stable=45 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=3
#   2021→2022: Stable=45 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=5
#   2022→2023: Stable=43 (86%)  Merge=0 (0%)  Disappear=7 (14%)  New=7
#   2023→2024: Stable=48 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=2
#   2024→2025: Stable=45 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=4
#
#   Overall: Stable=81.8%  Merge=0.0%  Disappear=18.2%  New=212
#   Saved: ../../../../results/lda/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (LDA)
# ======================================================================
#   2000→2001: Stable=30 (67%)  Merge=0 (0%)  Disappear=15 (33%)  New=19
#   2001→2002: Stable=29 (59%)  Merge=0 (0%)  Disappear=20 (41%)  New=19
#   2002→2003: Stable=28 (58%)  Merge=0 (0%)  Disappear=20 (42%)  New=21
#   2003→2004: Stable=30 (61%)  Merge=0 (0%)  Disappear=19 (39%)  New=18
#   2004→2005: Stable=26 (54%)  Merge=0 (0%)  Disappear=22 (46%)  New=22
#   2005→2006: Stable=38 (79%)  Merge=0 (0%)  Disappear=10 (21%)  New=10
#   2006→2007: Stable=38 (79%)  Merge=0 (0%)  Disappear=10 (21%)  New=10
#   2007→2008: Stable=38 (79%)  Merge=0 (0%)  Disappear=10 (21%)  New=12
#   2008→2009: Stable=36 (72%)  Merge=0 (0%)  Disappear=14 (28%)  New=14
#   2009→2010: Stable=45 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=5
#   2010→2011: Stable=42 (84%)  Merge=0 (0%)  Disappear=8 (16%)  New=8
#   2011→2012: Stable=43 (86%)  Merge=0 (0%)  Disappear=7 (14%)  New=6
#   2012→2013: Stable=42 (86%)  Merge=0 (0%)  Disappear=7 (14%)  New=7
#   2013→2014: Stable=45 (92%)  Merge=0 (0%)  Disappear=4 (8%)  New=5
#   2014→2015: Stable=46 (92%)  Merge=0 (0%)  Disappear=4 (8%)  New=3
#   2015→2016: Stable=46 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=4
#   2016→2017: Stable=47 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=3
#   2017→2018: Stable=48 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=1
#   2018→2019: Stable=47 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=2
#   2019→2020: Stable=48 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2020→2021: Stable=47 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=3
#   2021→2022: Stable=47 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=3
#   2022→2023: Stable=47 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=2
#   2023→2024: Stable=47 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=2
#   2024→2025: Stable=48 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#
#   Overall: Stable=83.8%  Merge=0.0%  Disappear=16.2%  New=201
#   Saved: ../../../../results/lda/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 490 events
#   Per year:
#     2000: 26 topics
#     2001: 35 topics
#     2002: 31 topics
#     2003: 24 topics
#     2004: 39 topics
#     2005: 39 topics
#     2006: 40 topics
#     2007: 31 topics
#     2008: 36 topics
#     2009: 25 topics
#     2010: 22 topics
#     2011: 17 topics
#     2012: 26 topics
#     2013: 21 topics
#     2014: 17 topics
#     2015: 14 topics
#     2016: 8 topics
#     2017: 8 topics
#     2018: 4 topics
#     2019: 4 topics
#     2020: 5 topics
#     2021: 4 topics
#     2022: 5 topics
#     2023: 6 topics
#     2024: 3 topics
#
#   Permanently gone: 3
#     T 16 last @ 2024 (sim=0.164) | rho, chess, fiber, lineage, invariant, makeup, inv
#     T 24 last @ 2024 (sim=0.342) | applicant, preorder, poem, psmd, idea, gpt, erc, e
#     T 69 last @ 2024 (sim=0.357) | topological, tape, homology, simplicial, tda, cata
#
#   🔗 MERGE GROUPS: 1 events
#   Top 10 merges (most sources):
#     T  7 @ 2005 ← [7, 56] (sims=[0.8351, 0.5434]) | logic, program, semantic, rule, programm
#
#   🆕 NEW TOPICS: 509 events
#   Per year:
#     2001: 30 new topics
#     2002: 32 new topics
#     2003: 32 new topics
#     2004: 33 new topics
#     2005: 39 new topics
#     2006: 41 new topics
#     2007: 37 new topics
#     2008: 30 new topics
#     2009: 37 new topics
#     2010: 29 new topics
#     2011: 23 new topics
#     2012: 20 new topics
#     2013: 24 new topics
#     2014: 22 new topics
#     2015: 17 new topics
#     2016: 13 new topics
#     2017: 8 new topics
#     2018: 10 new topics
#     2019: 4 new topics
#     2020: 5 new topics
#     2021: 5 new topics
#     2022: 4 new topics
#     2023: 5 new topics
#     2024: 6 new topics
#     2025: 3 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  4 | 100% stable (25S 0M 0D)
#     T 28 | 100% stable (25S 0M 0D)
#     T 33 | 100% stable (25S 0M 0D)
#     T 50 | 100% stable (24S 0M 0D)
#     T 71 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 69 | 31% stable (5S 0M 11D)
#     T 54 | 31% stable (4S 0M 9D)
#     T 17 | 25% stable (2S 0M 6D)
#     T 16 | 24% stable (5S 0M 16D)
#     T 24 | 6% stable (1S 0M 17D)
#
#
# ======================================================================
# Analysis Review: MATH (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 201 events
#   Per year:
#     2000: 13 topics
#     2001: 19 topics
#     2002: 15 topics
#     2003: 12 topics
#     2004: 12 topics
#     2005: 13 topics
#     2006: 12 topics
#     2007: 7 topics
#     2008: 10 topics
#     2009: 9 topics
#     2010: 4 topics
#     2011: 9 topics
#     2012: 8 topics
#     2013: 5 topics
#     2014: 8 topics
#     2015: 6 topics
#     2016: 5 topics
#     2017: 5 topics
#     2018: 3 topics
#     2019: 6 topics
#     2020: 3 topics
#     2021: 3 topics
#     2022: 7 topics
#     2023: 2 topics
#     2024: 5 topics
#
#   Permanently gone: 6
#     T 30 last @ 2023 (sim=0.365) | ker, lowercase, end_bmatrix, bmatrix, semifield, t
#     T 23 last @ 2024 (sim=0.287) | hilb, geq, mathbb, func, shnirelman, closeness, da
#     T 25 last @ 2024 (sim=0.407) | mathrm, adj, dim, mathbb, gobs, cat, supp, privacy
#     T 30 last @ 2024 (sim=0.000) | semifield, vee, ker, tough, cup, lowercase, spectr
#     T 37 last @ 2024 (sim=0.363) | infty, mathcal, leq, operatorname_gal, mathbb_math
#     T 46 last @ 2024 (sim=0.238) | forall, inftycd, iff, ldots, mathbb, cdot, pseudop
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 212 events
#   Per year:
#     2001: 14 new topics
#     2002: 21 new topics
#     2003: 14 new topics
#     2004: 15 new topics
#     2005: 12 new topics
#     2006: 14 new topics
#     2007: 13 new topics
#     2008: 8 new topics
#     2009: 10 new topics
#     2010: 8 new topics
#     2011: 7 new topics
#     2012: 8 new topics
#     2013: 9 new topics
#     2014: 4 new topics
#     2015: 11 new topics
#     2016: 4 new topics
#     2017: 6 new topics
#     2018: 5 new topics
#     2019: 4 new topics
#     2020: 4 new topics
#     2021: 3 new topics
#     2022: 5 new topics
#     2023: 7 new topics
#     2024: 2 new topics
#     2025: 4 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0M 0D)
#     T  4 | 100% stable (25S 0M 0D)
#     T 14 | 100% stable (25S 0M 0D)
#     T  8 | 100% stable (25S 0M 0D)
#     T  7 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 25 | 38% stable (5S 0M 8D)
#     T 23 | 23% stable (3S 0M 10D)
#     T 37 | 22% stable (4S 0M 14D)
#     T 46 | 20% stable (2S 0M 8D)
#     T 30 | 0% stable (0S 0M 15D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 197 events
#   Per year:
#     2000: 15 topics
#     2001: 20 topics
#     2002: 20 topics
#     2003: 19 topics
#     2004: 22 topics
#     2005: 10 topics
#     2006: 10 topics
#     2007: 10 topics
#     2008: 14 topics
#     2009: 5 topics
#     2010: 8 topics
#     2011: 7 topics
#     2012: 7 topics
#     2013: 4 topics
#     2014: 4 topics
#     2015: 3 topics
#     2016: 3 topics
#     2017: 2 topics
#     2018: 2 topics
#     2019: 1 topics
#     2020: 2 topics
#     2021: 3 topics
#     2022: 3 topics
#     2023: 2 topics
#     2024: 1 topics
#
#   Permanently gone: 3
#     T 21 last @ 2021 (sim=0.287) | dot_obs, dot_dot, mathrm, dot, boldsymbol_boldsymb
#     T 21 last @ 2022 (sim=0.000) | prl, comment, arxiv, dot_obs, 15242v1, minguzzi, d
#     T 24 last @ 2024 (sim=0.371) | experimental, diffusion, maple, dmd, dynamic, datu
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 201 events
#   Per year:
#     2001: 19 new topics
#     2002: 19 new topics
#     2003: 21 new topics
#     2004: 18 new topics
#     2005: 22 new topics
#     2006: 10 new topics
#     2007: 10 new topics
#     2008: 12 new topics
#     2009: 14 new topics
#     2010: 5 new topics
#     2011: 8 new topics
#     2012: 6 new topics
#     2013: 7 new topics
#     2014: 5 new topics
#     2015: 3 new topics
#     2016: 4 new topics
#     2017: 3 new topics
#     2018: 1 new topics
#     2019: 2 new topics
#     2020: 1 new topics
#     2021: 3 new topics
#     2022: 3 new topics
#     2023: 2 new topics
#     2024: 2 new topics
#     2025: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  8 | 100% stable (25S 0M 0D)
#     T  3 | 100% stable (25S 0M 0D)
#     T 16 | 100% stable (25S 0M 0D)
#     T 10 | 100% stable (25S 0M 0D)
#     T 17 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 21 | 46% stable (6S 0M 7D)
#     T 49 | 40% stable (10S 0M 15D)
#     T 32 | 38% stable (9S 0M 15D)
#     T 24 | 17% stable (4S 0M 19D)
#     T 41 | 15% stable (3S 0M 17D)
