# %% [markdown]
# # LDA: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/lda/temporal")
RESULT_DIR = Path("../../../../results/lda/consistency")
THRESHOLD_LOW = 0.2   
THRESHOLD_HIGH = 0.5 

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold Low  (disappear): {THRESHOLD_LOW}")
print(f"Threshold High (stable)   : {THRESHOLD_HIGH}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold Low  (disappear): 0.2
# Threshold High (stable)   : 0.5
# Reading from: ../../../../results/lda/temporal
# Saving to: ../../../../results/lda/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]

def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for i, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for j, tid_t1 in enumerate(topics_t1):
                words_t1 = topic_words.get((t_next, tid_t1), [])
                sim_matrix[i, j] = rbo(words_t, words_t1, p=0.9)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map
        # Disappear : sim < THRESHOLD_LOW
        # Qualify   : sim >= THRESHOLD_LOW  (evolve or stable — further split by THRESHOLD_HIGH)
        # Merge     : qualified AND target_counts > 1
        assignment = {}     # topic_t → best topic_t1 (or None if disappeared)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD_LOW:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_evolve, n_merge, n_disappear = 0, 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] > 1:
                # Multiple t-topics map to the same t+1-topic → merge
                category = "merge"
                n_merge += 1
            elif sim_val >= THRESHOLD_HIGH:
                category = "stable"
                n_stable += 1
            else:
                # THRESHOLD_LOW <= sim < THRESHOLD_HIGH
                category = "evolve"
                n_evolve += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_evolve": n_evolve, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_evolve": round(n_evolve / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Evolve={n_evolve} ({n_evolve/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold_low": THRESHOLD_LOW, "threshold_high": THRESHOLD_HIGH,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_evolve": round(subj_sum["pct_evolve"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Evolve={overall['avg_pct_evolve']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (LDA)
# ======================================================================
#   2000→2001: Stable=26 (57%)  Evolve=11 (24%)  Merge=0 (0%)  Disappear=9 (20%)  New=4
#   2001→2002: Stable=19 (46%)  Evolve=20 (49%)  Merge=0 (0%)  Disappear=2 (5%)  New=4
#   2002→2003: Stable=24 (56%)  Evolve=17 (40%)  Merge=2 (5%)  Disappear=0 (0%)  New=8
#   2003→2004: Stable=32 (64%)  Evolve=11 (22%)  Merge=0 (0%)  Disappear=7 (14%)  New=4
#   2004→2005: Stable=26 (55%)  Evolve=17 (36%)  Merge=0 (0%)  Disappear=4 (9%)  New=7
#   2005→2006: Stable=24 (48%)  Evolve=18 (36%)  Merge=4 (8%)  Disappear=4 (8%)  New=4
#   2006→2007: Stable=24 (50%)  Evolve=14 (29%)  Merge=0 (0%)  Disappear=10 (21%)  New=10
#   2007→2008: Stable=26 (54%)  Evolve=18 (38%)  Merge=0 (0%)  Disappear=4 (8%)  New=5
#   2008→2009: Stable=27 (55%)  Evolve=17 (35%)  Merge=0 (0%)  Disappear=5 (10%)  New=4
#   2009→2010: Stable=35 (73%)  Evolve=8 (17%)  Merge=0 (0%)  Disappear=5 (10%)  New=7
#   2010→2011: Stable=35 (70%)  Evolve=12 (24%)  Merge=0 (0%)  Disappear=3 (6%)  New=1
#   2011→2012: Stable=38 (79%)  Evolve=7 (15%)  Merge=0 (0%)  Disappear=3 (6%)  New=4
#   2012→2013: Stable=42 (86%)  Evolve=7 (14%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2013→2014: Stable=41 (82%)  Evolve=9 (18%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2014→2015: Stable=45 (90%)  Evolve=4 (8%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2015→2016: Stable=46 (92%)  Evolve=3 (6%)  Merge=0 (0%)  Disappear=1 (2%)  New=0
#   2016→2017: Stable=48 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2017→2018: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2018→2019: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=78.0%  Evolve=16.7%  Merge=0.5%  Disappear=4.8%  New=65
#   Saved: ../../../../results/lda/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (LDA)
# ======================================================================
#   2000→2001: Stable=30 (62%)  Evolve=15 (31%)  Merge=0 (0%)  Disappear=3 (6%)  New=3
#   2001→2002: Stable=26 (54%)  Evolve=16 (33%)  Merge=0 (0%)  Disappear=6 (12%)  New=5
#   2002→2003: Stable=32 (68%)  Evolve=9 (19%)  Merge=0 (0%)  Disappear=6 (13%)  New=8
#   2003→2004: Stable=37 (76%)  Evolve=8 (16%)  Merge=0 (0%)  Disappear=4 (8%)  New=3
#   2004→2005: Stable=36 (75%)  Evolve=10 (21%)  Merge=0 (0%)  Disappear=2 (4%)  New=3
#   2005→2006: Stable=44 (90%)  Evolve=5 (10%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2006→2007: Stable=39 (78%)  Evolve=8 (16%)  Merge=0 (0%)  Disappear=3 (6%)  New=3
#   2007→2008: Stable=39 (78%)  Evolve=10 (20%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2008→2009: Stable=41 (82%)  Evolve=8 (16%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2009→2010: Stable=43 (86%)  Evolve=7 (14%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2010→2011: Stable=42 (84%)  Evolve=8 (16%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2011→2012: Stable=44 (88%)  Evolve=6 (12%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2012→2013: Stable=46 (92%)  Evolve=3 (6%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2013→2014: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2014→2015: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2015→2016: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2016→2017: Stable=48 (96%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2017→2018: Stable=47 (94%)  Evolve=2 (4%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2018→2019: Stable=47 (94%)  Evolve=2 (4%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2019→2020: Stable=47 (94%)  Evolve=2 (4%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2020→2021: Stable=47 (94%)  Evolve=3 (6%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=47 (94%)  Evolve=3 (6%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=47 (94%)  Evolve=2 (4%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2023→2024: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=86.5%  Evolve=10.8%  Merge=0.0%  Disappear=2.6%  New=34
#   Saved: ../../../../results/lda/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (LDA)
# ======================================================================
#   2000→2001: Stable=31 (69%)  Evolve=14 (31%)  Merge=0 (0%)  Disappear=0 (0%)  New=4
#   2001→2002: Stable=34 (69%)  Evolve=14 (29%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2002→2003: Stable=30 (61%)  Evolve=16 (33%)  Merge=0 (0%)  Disappear=3 (6%)  New=2
#   2003→2004: Stable=39 (81%)  Evolve=6 (12%)  Merge=0 (0%)  Disappear=3 (6%)  New=5
#   2004→2005: Stable=36 (72%)  Evolve=11 (22%)  Merge=0 (0%)  Disappear=3 (6%)  New=2
#   2005→2006: Stable=34 (69%)  Evolve=14 (29%)  Merge=0 (0%)  Disappear=1 (2%)  New=2
#   2006→2007: Stable=42 (84%)  Evolve=7 (14%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2007→2008: Stable=39 (78%)  Evolve=9 (18%)  Merge=0 (0%)  Disappear=2 (4%)  New=1
#   2008→2009: Stable=40 (82%)  Evolve=8 (16%)  Merge=0 (0%)  Disappear=1 (2%)  New=2
#   2009→2010: Stable=46 (92%)  Evolve=3 (6%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2010→2011: Stable=45 (90%)  Evolve=3 (6%)  Merge=0 (0%)  Disappear=2 (4%)  New=2
#   2011→2012: Stable=47 (94%)  Evolve=2 (4%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2012→2013: Stable=45 (90%)  Evolve=3 (6%)  Merge=0 (0%)  Disappear=2 (4%)  New=1
#   2013→2014: Stable=46 (94%)  Evolve=2 (4%)  Merge=0 (0%)  Disappear=1 (2%)  New=2
#   2014→2015: Stable=47 (94%)  Evolve=3 (6%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2015→2016: Stable=48 (96%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2016→2017: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2017→2018: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2018→2019: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=49 (98%)  Evolve=0 (0%)  Merge=0 (0%)  Disappear=1 (2%)  New=0
#   2020→2021: Stable=49 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2021→2022: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=87.8%  Evolve=10.3%  Merge=0.0%  Disappear=1.9%  New=29
#   Saved: ../../../../results/lda/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED (sim < THRESHOLD_LOW) ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED (sim < {THRESHOLD_LOW}): {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- EVOLVE (THRESHOLD_LOW <= sim < THRESHOLD_HIGH, single source) ---
    evolved = trans_df[trans_df["category"] == "evolve"]
    print(f"\n  🔄 EVOLVE ({THRESHOLD_LOW} <= sim < {THRESHOLD_HIGH}): {len(evolved)} events")
    if len(evolved) > 0:
        per_year = evolved.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

    # --- MERGE GROUPS (>1 source, sim >= THRESHOLD_LOW) ---
    print(f"\n  🔗 MERGE GROUPS (sim >= {THRESHOLD_LOW}, >1 source): {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "evolve", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED (sim < 0.2): 58 events
#   Per year:
#     2000: 9 topics
#     2001: 2 topics
#     2003: 7 topics
#     2004: 4 topics
#     2005: 4 topics
#     2006: 10 topics
#     2007: 4 topics
#     2008: 5 topics
#     2009: 5 topics
#     2010: 3 topics
#     2011: 3 topics
#     2014: 1 topics
#     2015: 1 topics
#
#   Permanently gone: 0
#
#   🔄 EVOLVE (0.2 <= sim < 0.5): 197 events
#   Per year:
#     2000: 11 topics
#     2001: 20 topics
#     2002: 17 topics
#     2003: 11 topics
#     2004: 17 topics
#     2005: 18 topics
#     2006: 14 topics
#     2007: 18 topics
#     2008: 17 topics
#     2009: 8 topics
#     2010: 12 topics
#     2011: 7 topics
#     2012: 7 topics
#     2013: 9 topics
#     2014: 4 topics
#     2015: 3 topics
#     2016: 1 topics
#     2017: 1 topics
#     2018: 1 topics
#     2022: 1 topics
#
#   🔗 MERGE GROUPS (sim >= 0.2, >1 source): 3 events
#   Top 10 merges (most sources):
#     T 42 @ 2003 ← [31, 42] (sims=[0.2703, 0.6828]) | rbf, rbfns, matrix, frame, grassmannian,
#     T 34 @ 2006 ← [2, 34] (sims=[0.2703, 0.3434]) | robot, rotation, arm, quaternion, rollin
#     T 49 @ 2006 ← [35, 49] (sims=[0.2703, 0.6961]) | grid, resource, computing, network, sche
#
#   🆕 NEW TOPICS: 65 events
#   Per year:
#     2001: 4 new topics
#     2002: 4 new topics
#     2003: 8 new topics
#     2004: 4 new topics
#     2005: 7 new topics
#     2006: 4 new topics
#     2007: 10 new topics
#     2008: 5 new topics
#     2009: 4 new topics
#     2010: 7 new topics
#     2011: 1 new topics
#     2012: 4 new topics
#     2013: 1 new topics
#     2015: 1 new topics
#     2017: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  1 | 100% stable (25S 0Ev 0M 0D)
#     T  6 | 100% stable (25S 0Ev 0M 0D)
#     T 15 | 100% stable (25S 0Ev 0M 0D)
#     T 26 | 100% stable (25S 0Ev 0M 0D)
#     T 48 | 96% stable (24S 1Ev 0M 0D)
#   Top 5 most unstable:
#     T 41 | 56% stable (13S 7Ev 0M 3D)
#     T 24 | 50% stable (10S 6Ev 0M 4D)
#     T 25 | 48% stable (10S 8Ev 0M 3D)
#     T 21 | 46% stable (11S 8Ev 0M 5D)
#     T 31 | 44% stable (11S 9Ev 1M 4D)
#
#
# ======================================================================
# Analysis Review: MATH (LDA)
# ======================================================================
#
#   📉 DISAPPEARED (sim < 0.2): 32 events
#   Per year:
#     2000: 3 topics
#     2001: 6 topics
#     2002: 6 topics
#     2003: 4 topics
#     2004: 2 topics
#     2006: 3 topics
#     2007: 1 topics
#     2008: 1 topics
#     2012: 1 topics
#     2016: 1 topics
#     2017: 1 topics
#     2018: 1 topics
#     2019: 1 topics
#     2022: 1 topics
#
#   Permanently gone: 0
#
#   🔄 EVOLVE (0.2 <= sim < 0.5): 133 events
#   Per year:
#     2000: 15 topics
#     2001: 16 topics
#     2002: 9 topics
#     2003: 8 topics
#     2004: 10 topics
#     2005: 5 topics
#     2006: 8 topics
#     2007: 10 topics
#     2008: 8 topics
#     2009: 7 topics
#     2010: 8 topics
#     2011: 6 topics
#     2012: 3 topics
#     2013: 1 topics
#     2014: 1 topics
#     2015: 1 topics
#     2016: 1 topics
#     2017: 2 topics
#     2018: 2 topics
#     2019: 2 topics
#     2020: 3 topics
#     2021: 3 topics
#     2022: 2 topics
#     2024: 2 topics
#
#   🔗 MERGE GROUPS (sim >= 0.2, >1 source): 0 events
#
#   🆕 NEW TOPICS: 34 events
#   Per year:
#     2001: 3 new topics
#     2002: 5 new topics
#     2003: 8 new topics
#     2004: 3 new topics
#     2005: 3 new topics
#     2006: 1 new topics
#     2007: 3 new topics
#     2008: 1 new topics
#     2009: 1 new topics
#     2013: 1 new topics
#     2017: 1 new topics
#     2018: 1 new topics
#     2019: 1 new topics
#     2020: 1 new topics
#     2023: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0Ev 0M 0D)
#     T  2 | 100% stable (25S 0Ev 0M 0D)
#     T  9 | 100% stable (25S 0Ev 0M 0D)
#     T  4 | 100% stable (25S 0Ev 0M 0D)
#     T  5 | 100% stable (25S 0Ev 0M 0D)
#   Top 5 most unstable:
#     T 41 | 56% stable (14S 11Ev 0M 0D)
#     T  3 | 52% stable (13S 11Ev 0M 1D)
#     T 28 | 36% stable (9S 14Ev 0M 2D)
#     T 49 | 27% stable (6S 10Ev 0M 6D)
#     T 10 | 26% stable (6S 12Ev 0M 5D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED (sim < 0.2): 24 events
#   Per year:
#     2001: 1 topics
#     2002: 3 topics
#     2003: 3 topics
#     2004: 3 topics
#     2005: 1 topics
#     2006: 1 topics
#     2007: 2 topics
#     2008: 1 topics
#     2009: 1 topics
#     2010: 2 topics
#     2011: 1 topics
#     2012: 2 topics
#     2013: 1 topics
#     2015: 1 topics
#     2019: 1 topics
#
#   Permanently gone: 0
#
#   🔄 EVOLVE (0.2 <= sim < 0.5): 126 events
#   Per year:
#     2000: 14 topics
#     2001: 14 topics
#     2002: 16 topics
#     2003: 6 topics
#     2004: 11 topics
#     2005: 14 topics
#     2006: 7 topics
#     2007: 9 topics
#     2008: 8 topics
#     2009: 3 topics
#     2010: 3 topics
#     2011: 2 topics
#     2012: 3 topics
#     2013: 2 topics
#     2014: 3 topics
#     2015: 1 topics
#     2016: 1 topics
#     2017: 2 topics
#     2018: 2 topics
#     2021: 1 topics
#     2022: 2 topics
#     2023: 1 topics
#     2024: 1 topics
#
#   🔗 MERGE GROUPS (sim >= 0.2, >1 source): 0 events
#
#   🆕 NEW TOPICS: 29 events
#   Per year:
#     2001: 4 new topics
#     2002: 1 new topics
#     2003: 2 new topics
#     2004: 5 new topics
#     2005: 2 new topics
#     2006: 2 new topics
#     2007: 1 new topics
#     2008: 1 new topics
#     2009: 2 new topics
#     2010: 1 new topics
#     2011: 2 new topics
#     2012: 1 new topics
#     2013: 1 new topics
#     2014: 2 new topics
#     2016: 1 new topics
#     2021: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  6 | 100% stable (25S 0Ev 0M 0D)
#     T  4 | 100% stable (25S 0Ev 0M 0D)
#     T 12 | 100% stable (25S 0Ev 0M 0D)
#     T 10 | 100% stable (25S 0Ev 0M 0D)
#     T 39 | 100% stable (25S 0Ev 0M 0D)
#   Top 5 most unstable:
#     T 32 | 68% stable (17S 7Ev 0M 1D)
#     T 25 | 61% stable (14S 8Ev 0M 1D)
#     T 20 | 48% stable (12S 7Ev 0M 6D)
#     T  5 | 41% stable (9S 7Ev 0M 6D)
#     T 42 | 32% stable (6S 8Ev 0M 5D)
