# %% [markdown]
# # LDA: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/lda/temporal")
RESULT_DIR = Path("../../../../results/lda/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/lda/temporal
# Saving to: ../../../../results/lda/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def build_word_matrix(topic_ids, topic_words_dict, year, vocab_index):
    matrix = np.zeros((len(topic_ids), len(vocab_index)))
    for i, tid in enumerate(topic_ids):
        words = topic_words_dict.get((year, tid), [])
        for w in words:
            if w in vocab_index:
                matrix[i, vocab_index[w]] = 1.0
    return matrix

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_words = set()
    for words in topic_words.values():
        all_words.update(words)
    vocab_index = {w: i for i, w in enumerate(sorted(all_words))}

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        mat_t = build_word_matrix(topics_t, topic_words, t, vocab_index)
        mat_t1 = build_word_matrix(topics_t1, topic_words, t_next, vocab_index)
        sim_matrix = cosine_similarity(mat_t, mat_t1)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (LDA)
# ======================================================================
#   2000→2001: Stable=39 (68%)  Merge=0 (0%)  Disappear=18 (32%)  New=22
#   2001→2002: Stable=38 (62%)  Merge=0 (0%)  Disappear=23 (38%)  New=20
#   2002→2003: Stable=39 (67%)  Merge=0 (0%)  Disappear=19 (33%)  New=20
#   2003→2004: Stable=48 (81%)  Merge=0 (0%)  Disappear=11 (19%)  New=20
#   2004→2005: Stable=46 (68%)  Merge=0 (0%)  Disappear=22 (32%)  New=21
#   2005→2006: Stable=48 (72%)  Merge=0 (0%)  Disappear=19 (28%)  New=21
#   2006→2007: Stable=47 (68%)  Merge=0 (0%)  Disappear=22 (32%)  New=19
#   2007→2008: Stable=52 (79%)  Merge=0 (0%)  Disappear=14 (21%)  New=13
#   2008→2009: Stable=46 (71%)  Merge=0 (0%)  Disappear=19 (29%)  New=20
#   2009→2010: Stable=54 (82%)  Merge=0 (0%)  Disappear=12 (18%)  New=16
#   2010→2011: Stable=61 (87%)  Merge=0 (0%)  Disappear=9 (13%)  New=10
#   2011→2012: Stable=65 (92%)  Merge=0 (0%)  Disappear=6 (8%)  New=9
#   2012→2013: Stable=68 (92%)  Merge=0 (0%)  Disappear=6 (8%)  New=4
#   2013→2014: Stable=65 (90%)  Merge=0 (0%)  Disappear=7 (10%)  New=8
#   2014→2015: Stable=68 (93%)  Merge=0 (0%)  Disappear=5 (7%)  New=5
#   2015→2016: Stable=67 (92%)  Merge=0 (0%)  Disappear=6 (8%)  New=5
#   2016→2017: Stable=68 (94%)  Merge=0 (0%)  Disappear=4 (6%)  New=4
#   2017→2018: Stable=70 (97%)  Merge=0 (0%)  Disappear=2 (3%)  New=4
#   2018→2019: Stable=73 (99%)  Merge=0 (0%)  Disappear=1 (1%)  New=1
#   2019→2020: Stable=74 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2020→2021: Stable=73 (97%)  Merge=0 (0%)  Disappear=2 (3%)  New=2
#   2021→2022: Stable=72 (96%)  Merge=0 (0%)  Disappear=3 (4%)  New=3
#   2022→2023: Stable=74 (99%)  Merge=0 (0%)  Disappear=1 (1%)  New=1
#   2023→2024: Stable=75 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=75 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=85.8%  Merge=0.0%  Disappear=14.2%  New=249
#   Saved: ../../../../results/lda/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (LDA)
# ======================================================================
#   2000→2001: Stable=30 (79%)  Merge=0 (0%)  Disappear=8 (21%)  New=9
#   2001→2002: Stable=30 (77%)  Merge=0 (0%)  Disappear=9 (23%)  New=11
#   2002→2003: Stable=34 (83%)  Merge=0 (0%)  Disappear=7 (17%)  New=6
#   2003→2004: Stable=37 (92%)  Merge=0 (0%)  Disappear=3 (8%)  New=6
#   2004→2005: Stable=38 (88%)  Merge=0 (0%)  Disappear=5 (12%)  New=5
#   2005→2006: Stable=42 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=2
#   2006→2007: Stable=40 (91%)  Merge=0 (0%)  Disappear=4 (9%)  New=5
#   2007→2008: Stable=42 (93%)  Merge=0 (0%)  Disappear=3 (7%)  New=4
#   2008→2009: Stable=44 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=2
#   2009→2010: Stable=41 (89%)  Merge=0 (0%)  Disappear=5 (11%)  New=4
#   2010→2011: Stable=45 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=3
#   2011→2012: Stable=44 (92%)  Merge=0 (0%)  Disappear=4 (8%)  New=3
#   2012→2013: Stable=44 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=4
#   2013→2014: Stable=45 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=2
#   2014→2015: Stable=46 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=4
#   2015→2016: Stable=48 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=0
#   2016→2017: Stable=46 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=3
#   2017→2018: Stable=47 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=2
#   2018→2019: Stable=48 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=2
#   2019→2020: Stable=47 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=1
#   2020→2021: Stable=47 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2021→2022: Stable=48 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=2
#   2022→2023: Stable=50 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=50 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=48 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=1
#
#   Overall: Stable=93.5%  Merge=0.0%  Disappear=6.5%  New=82
#   Saved: ../../../../results/lda/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (LDA)
# ======================================================================
#   2000→2001: Stable=42 (93%)  Merge=0 (0%)  Disappear=3 (7%)  New=7
#   2001→2002: Stable=41 (84%)  Merge=0 (0%)  Disappear=8 (16%)  New=7
#   2002→2003: Stable=39 (81%)  Merge=0 (0%)  Disappear=9 (19%)  New=10
#   2003→2004: Stable=41 (84%)  Merge=0 (0%)  Disappear=8 (16%)  New=7
#   2004→2005: Stable=43 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=5
#   2005→2006: Stable=43 (90%)  Merge=0 (0%)  Disappear=5 (10%)  New=5
#   2006→2007: Stable=46 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=2
#   2007→2008: Stable=47 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=3
#   2008→2009: Stable=47 (94%)  Merge=0 (0%)  Disappear=3 (6%)  New=3
#   2009→2010: Stable=49 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2010→2011: Stable=49 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2011→2012: Stable=48 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=1
#   2012→2013: Stable=48 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=1
#   2013→2014: Stable=49 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2014→2015: Stable=48 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=1
#   2015→2016: Stable=49 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2016→2017: Stable=50 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2017→2018: Stable=49 (98%)  Merge=0 (0%)  Disappear=1 (2%)  New=0
#   2018→2019: Stable=49 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=49 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=49 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=1
#   2021→2022: Stable=50 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=48 (96%)  Merge=0 (0%)  Disappear=2 (4%)  New=1
#   2023→2024: Stable=49 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=49 (100%)  Merge=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=95.5%  Merge=0.0%  Disappear=4.5%  New=58
#   Saved: ../../../../results/lda/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 231 events
#   Per year:
#     2000: 18 topics
#     2001: 23 topics
#     2002: 19 topics
#     2003: 11 topics
#     2004: 22 topics
#     2005: 19 topics
#     2006: 22 topics
#     2007: 14 topics
#     2008: 19 topics
#     2009: 12 topics
#     2010: 9 topics
#     2011: 6 topics
#     2012: 6 topics
#     2013: 7 topics
#     2014: 5 topics
#     2015: 6 topics
#     2016: 4 topics
#     2017: 2 topics
#     2018: 1 topics
#     2020: 2 topics
#     2021: 3 topics
#     2022: 1 topics
#
#   Permanently gone: 0
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 249 events
#   Per year:
#     2001: 22 new topics
#     2002: 20 new topics
#     2003: 20 new topics
#     2004: 20 new topics
#     2005: 21 new topics
#     2006: 21 new topics
#     2007: 19 new topics
#     2008: 13 new topics
#     2009: 20 new topics
#     2010: 16 new topics
#     2011: 10 new topics
#     2012: 9 new topics
#     2013: 4 new topics
#     2014: 8 new topics
#     2015: 5 new topics
#     2016: 5 new topics
#     2017: 4 new topics
#     2018: 4 new topics
#     2019: 1 new topics
#     2020: 1 new topics
#     2021: 2 new topics
#     2022: 3 new topics
#     2023: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  8 | 100% stable (25S 0M 0D)
#     T  4 | 100% stable (25S 0M 0D)
#     T  3 | 100% stable (25S 0M 0D)
#     T  7 | 100% stable (25S 0M 0D)
#     T 71 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 16 | 62% stable (13S 0M 8D)
#     T 64 | 62% stable (13S 0M 8D)
#     T 17 | 50% stable (4S 0M 4D)
#     T 54 | 46% stable (6S 0M 7D)
#     T 24 | 33% stable (6S 0M 12D)
#
#
# ======================================================================
# Analysis Review: MATH (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 71 events
#   Per year:
#     2000: 8 topics
#     2001: 9 topics
#     2002: 7 topics
#     2003: 3 topics
#     2004: 5 topics
#     2005: 1 topics
#     2006: 4 topics
#     2007: 3 topics
#     2008: 2 topics
#     2009: 5 topics
#     2011: 4 topics
#     2012: 3 topics
#     2013: 3 topics
#     2014: 1 topics
#     2015: 2 topics
#     2016: 2 topics
#     2017: 2 topics
#     2018: 1 topics
#     2019: 3 topics
#     2020: 1 topics
#     2024: 2 topics
#
#   Permanently gone: 2
#     T 30 last @ 2024 (sim=0.000) | semifield, ker, vee, cup, hat, tough, lowercase, e
#     T 37 last @ 2024 (sim=0.400) | infty, mathcal, leq, mathbb_mathbb, operatorname_g
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 82 events
#   Per year:
#     2001: 9 new topics
#     2002: 11 new topics
#     2003: 6 new topics
#     2004: 6 new topics
#     2005: 5 new topics
#     2006: 2 new topics
#     2007: 5 new topics
#     2008: 4 new topics
#     2009: 2 new topics
#     2010: 4 new topics
#     2011: 3 new topics
#     2012: 3 new topics
#     2013: 4 new topics
#     2014: 2 new topics
#     2015: 4 new topics
#     2017: 3 new topics
#     2018: 2 new topics
#     2019: 2 new topics
#     2020: 1 new topics
#     2021: 1 new topics
#     2022: 2 new topics
#     2025: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 100% stable (25S 0M 0D)
#     T  1 | 100% stable (25S 0M 0D)
#     T  3 | 100% stable (25S 0M 0D)
#     T  4 | 100% stable (25S 0M 0D)
#     T  7 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 25 | 69% stable (9S 0M 4D)
#     T 27 | 67% stable (10S 0M 5D)
#     T 30 | 60% stable (9S 0M 6D)
#     T 37 | 56% stable (10S 0M 8D)
#     T 46 | 40% stable (4S 0M 6D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 54 events
#   Per year:
#     2000: 3 topics
#     2001: 8 topics
#     2002: 9 topics
#     2003: 8 topics
#     2004: 5 topics
#     2005: 5 topics
#     2006: 2 topics
#     2007: 1 topics
#     2008: 3 topics
#     2009: 1 topics
#     2010: 1 topics
#     2011: 2 topics
#     2012: 1 topics
#     2014: 2 topics
#     2017: 1 topics
#     2022: 2 topics
#
#   Permanently gone: 1
#     T 21 last @ 2022 (sim=0.000) | prl, comment, arxiv, dot_obs, dot_dot, mathrm, dot
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 58 events
#   Per year:
#     2001: 7 new topics
#     2002: 7 new topics
#     2003: 10 new topics
#     2004: 7 new topics
#     2005: 5 new topics
#     2006: 5 new topics
#     2007: 2 new topics
#     2008: 3 new topics
#     2009: 3 new topics
#     2010: 1 new topics
#     2011: 1 new topics
#     2012: 1 new topics
#     2013: 1 new topics
#     2014: 1 new topics
#     2015: 1 new topics
#     2016: 1 new topics
#     2021: 1 new topics
#     2023: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  1 | 100% stable (25S 0M 0D)
#     T  2 | 100% stable (25S 0M 0D)
#     T 17 | 100% stable (25S 0M 0D)
#     T  3 | 100% stable (25S 0M 0D)
#     T  4 | 100% stable (25S 0M 0D)
#   Top 5 most unstable:
#     T 24 | 83% stable (19S 0M 4D)
#     T 29 | 81% stable (17S 0M 4D)
#     T 32 | 75% stable (18S 0M 6D)
#     T 41 | 65% stable (13S 0M 7D)
#     T 21 | 54% stable (7S 0M 6D)
