# %% [markdown]
# # LDA: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/lda/temporal")
RESULT_DIR = Path("../../../../results/lda/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/lda/temporal
# Saving to: ../../../../results/lda/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list_1, list_2, p=0.9):
    k = min(len(list_1), len(list_2))
    if k == 0:
        return 0.0
    score = 0.0
    for d in range(1, k + 1):
        agreement = len(set(list_1[:d]) & set(list_2[:d])) / d
        score += (p ** (d - 1)) * agreement
    return score * (1 - p)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for i, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for j, tid_t1 in enumerate(topics_t1):
                words_t1 = topic_words.get((t_next, tid_t1), [])
                sim_matrix[i, j] = rbo(words_t, words_t1, p=0.9)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (LDA)
# ======================================================================
#   2000→2001: Stable=17 (30%)  Merge=0 (0%)  Disappear=40 (70%)  New=44
#   2001→2002: Stable=4 (7%)  Merge=0 (0%)  Disappear=57 (93%)  New=54
#   2002→2003: Stable=7 (12%)  Merge=0 (0%)  Disappear=51 (88%)  New=52
#   2003→2004: Stable=12 (20%)  Merge=0 (0%)  Disappear=47 (80%)  New=56
#   2004→2005: Stable=8 (12%)  Merge=0 (0%)  Disappear=60 (88%)  New=59
#   2005→2006: Stable=7 (10%)  Merge=0 (0%)  Disappear=60 (90%)  New=62
#   2006→2007: Stable=8 (12%)  Merge=0 (0%)  Disappear=61 (88%)  New=58
#   2007→2008: Stable=15 (23%)  Merge=0 (0%)  Disappear=51 (77%)  New=50
#   2008→2009: Stable=10 (15%)  Merge=0 (0%)  Disappear=55 (85%)  New=56
#   2009→2010: Stable=13 (20%)  Merge=0 (0%)  Disappear=53 (80%)  New=57
#   2010→2011: Stable=18 (26%)  Merge=0 (0%)  Disappear=52 (74%)  New=53
#   2011→2012: Stable=29 (41%)  Merge=0 (0%)  Disappear=42 (59%)  New=45
#   2012→2013: Stable=22 (30%)  Merge=0 (0%)  Disappear=52 (70%)  New=50
#   2013→2014: Stable=23 (32%)  Merge=0 (0%)  Disappear=49 (68%)  New=50
#   2014→2015: Stable=26 (36%)  Merge=0 (0%)  Disappear=47 (64%)  New=47
#   2015→2016: Stable=33 (45%)  Merge=0 (0%)  Disappear=40 (55%)  New=39
#   2016→2017: Stable=42 (58%)  Merge=0 (0%)  Disappear=30 (42%)  New=30
#   2017→2018: Stable=49 (68%)  Merge=0 (0%)  Disappear=23 (32%)  New=25
#   2018→2019: Stable=51 (69%)  Merge=0 (0%)  Disappear=23 (31%)  New=23
#   2019→2020: Stable=61 (82%)  Merge=0 (0%)  Disappear=13 (18%)  New=14
#   2020→2021: Stable=57 (76%)  Merge=0 (0%)  Disappear=18 (24%)  New=18
#   2021→2022: Stable=56 (75%)  Merge=0 (0%)  Disappear=19 (25%)  New=19
#   2022→2023: Stable=53 (71%)  Merge=0 (0%)  Disappear=22 (29%)  New=22
#   2023→2024: Stable=55 (73%)  Merge=0 (0%)  Disappear=20 (27%)  New=20
#   2024→2025: Stable=57 (76%)  Merge=0 (0%)  Disappear=18 (24%)  New=18
#
#   Overall: Stable=40.7%  Merge=0.0%  Disappear=59.3%  New=1021
#   Saved: ../../../../results/lda/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (LDA)
# ======================================================================
#   2000→2001: Stable=10 (26%)  Merge=0 (0%)  Disappear=28 (74%)  New=29
#   2001→2002: Stable=8 (21%)  Merge=0 (0%)  Disappear=31 (79%)  New=33
#   2002→2003: Stable=15 (37%)  Merge=0 (0%)  Disappear=26 (63%)  New=25
#   2003→2004: Stable=13 (32%)  Merge=0 (0%)  Disappear=27 (68%)  New=30
#   2004→2005: Stable=13 (30%)  Merge=0 (0%)  Disappear=30 (70%)  New=30
#   2005→2006: Stable=21 (49%)  Merge=0 (0%)  Disappear=22 (51%)  New=23
#   2006→2007: Stable=19 (43%)  Merge=0 (0%)  Disappear=25 (57%)  New=26
#   2007→2008: Stable=20 (44%)  Merge=0 (0%)  Disappear=25 (56%)  New=26
#   2008→2009: Stable=22 (48%)  Merge=0 (0%)  Disappear=24 (52%)  New=24
#   2009→2010: Stable=24 (52%)  Merge=0 (0%)  Disappear=22 (48%)  New=21
#   2010→2011: Stable=24 (53%)  Merge=0 (0%)  Disappear=21 (47%)  New=24
#   2011→2012: Stable=29 (60%)  Merge=0 (0%)  Disappear=19 (40%)  New=18
#   2012→2013: Stable=27 (57%)  Merge=0 (0%)  Disappear=20 (43%)  New=21
#   2013→2014: Stable=31 (65%)  Merge=0 (0%)  Disappear=17 (35%)  New=16
#   2014→2015: Stable=30 (64%)  Merge=0 (0%)  Disappear=17 (36%)  New=20
#   2015→2016: Stable=33 (66%)  Merge=0 (0%)  Disappear=17 (34%)  New=15
#   2016→2017: Stable=33 (69%)  Merge=0 (0%)  Disappear=15 (31%)  New=16
#   2017→2018: Stable=35 (71%)  Merge=0 (0%)  Disappear=14 (29%)  New=14
#   2018→2019: Stable=34 (69%)  Merge=0 (0%)  Disappear=15 (31%)  New=16
#   2019→2020: Stable=36 (72%)  Merge=0 (0%)  Disappear=14 (28%)  New=12
#   2020→2021: Stable=33 (69%)  Merge=0 (0%)  Disappear=15 (31%)  New=15
#   2021→2022: Stable=34 (71%)  Merge=0 (0%)  Disappear=14 (29%)  New=16
#   2022→2023: Stable=35 (70%)  Merge=0 (0%)  Disappear=15 (30%)  New=15
#   2023→2024: Stable=35 (70%)  Merge=0 (0%)  Disappear=15 (30%)  New=15
#   2024→2025: Stable=34 (68%)  Merge=0 (0%)  Disappear=16 (32%)  New=15
#
#   Overall: Stable=55.1%  Merge=0.0%  Disappear=44.9%  New=515
#   Saved: ../../../../results/lda/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (LDA)
# ======================================================================
#   2000→2001: Stable=11 (24%)  Merge=0 (0%)  Disappear=34 (76%)  New=38
#   2001→2002: Stable=9 (18%)  Merge=0 (0%)  Disappear=40 (82%)  New=39
#   2002→2003: Stable=9 (19%)  Merge=0 (0%)  Disappear=39 (81%)  New=40
#   2003→2004: Stable=11 (22%)  Merge=0 (0%)  Disappear=38 (78%)  New=37
#   2004→2005: Stable=12 (25%)  Merge=0 (0%)  Disappear=36 (75%)  New=36
#   2005→2006: Stable=18 (38%)  Merge=0 (0%)  Disappear=30 (62%)  New=30
#   2006→2007: Stable=19 (40%)  Merge=0 (0%)  Disappear=29 (60%)  New=29
#   2007→2008: Stable=23 (48%)  Merge=0 (0%)  Disappear=25 (52%)  New=27
#   2008→2009: Stable=19 (38%)  Merge=0 (0%)  Disappear=31 (62%)  New=31
#   2009→2010: Stable=26 (52%)  Merge=0 (0%)  Disappear=24 (48%)  New=24
#   2010→2011: Stable=30 (60%)  Merge=0 (0%)  Disappear=20 (40%)  New=20
#   2011→2012: Stable=34 (68%)  Merge=0 (0%)  Disappear=16 (32%)  New=15
#   2012→2013: Stable=33 (67%)  Merge=0 (0%)  Disappear=16 (33%)  New=16
#   2013→2014: Stable=31 (63%)  Merge=0 (0%)  Disappear=18 (37%)  New=19
#   2014→2015: Stable=37 (74%)  Merge=0 (0%)  Disappear=13 (26%)  New=12
#   2015→2016: Stable=36 (73%)  Merge=0 (0%)  Disappear=13 (27%)  New=14
#   2016→2017: Stable=33 (66%)  Merge=0 (0%)  Disappear=17 (34%)  New=17
#   2017→2018: Stable=38 (76%)  Merge=0 (0%)  Disappear=12 (24%)  New=11
#   2018→2019: Stable=38 (78%)  Merge=0 (0%)  Disappear=11 (22%)  New=11
#   2019→2020: Stable=37 (76%)  Merge=0 (0%)  Disappear=12 (24%)  New=12
#   2020→2021: Stable=42 (86%)  Merge=0 (0%)  Disappear=7 (14%)  New=8
#   2021→2022: Stable=42 (84%)  Merge=0 (0%)  Disappear=8 (16%)  New=8
#   2022→2023: Stable=42 (84%)  Merge=0 (0%)  Disappear=8 (16%)  New=7
#   2023→2024: Stable=40 (82%)  Merge=0 (0%)  Disappear=9 (18%)  New=9
#   2024→2025: Stable=43 (88%)  Merge=0 (0%)  Disappear=6 (12%)  New=6
#
#   Overall: Stable=57.9%  Merge=0.0%  Disappear=42.1%  New=516
#   Saved: ../../../../results/lda/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 1003 events
#   Per year:
#     2000: 40 topics
#     2001: 57 topics
#     2002: 51 topics
#     2003: 47 topics
#     2004: 60 topics
#     2005: 60 topics
#     2006: 61 topics
#     2007: 51 topics
#     2008: 55 topics
#     2009: 53 topics
#     2010: 52 topics
#     2011: 42 topics
#     2012: 52 topics
#     2013: 49 topics
#     2014: 47 topics
#     2015: 40 topics
#     2016: 30 topics
#     2017: 23 topics
#     2018: 23 topics
#     2019: 13 topics
#     2020: 18 topics
#     2021: 19 topics
#     2022: 22 topics
#     2023: 20 topics
#     2024: 18 topics
#
#   Permanently gone: 18
#     T  7 last @ 2024 (sim=0.388) | concept, language, reasoning, logic, type, program
#     T  9 last @ 2024 (sim=0.474) | claim, news, fact, meme, fake_news, dataset, evide
#     T 10 last @ 2024 (sim=0.487) | image, clinical, mri, patient, medical, brain, seg
#     T 13 last @ 2024 (sim=0.490) | voter, voting, election, llm, story, character, te
#     T 16 last @ 2024 (sim=0.059) | rho, chess, fiber, lineage, invariant, makeup, inv
#     T 17 last @ 2024 (sim=0.372) | patent, layout, footstep, dispat, furniture, arran
#     T 24 last @ 2024 (sim=0.168) | applicant, preorder, poem, psmd, idea, gpt, erc, e
#     T 25 last @ 2024 (sim=0.457) | mathcal, mathrm, mathcal_mathcal, spanner, frac, v
#     T 26 last @ 2024 (sim=0.484) | tree, group, draft, phylogeny, splay, nucleus, lea
#     T 29 last @ 2024 (sim=0.462) | iot, datum, device, network, technology, security,
#     ... +8 more
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 1021 events
#   Per year:
#     2001: 44 new topics
#     2002: 54 new topics
#     2003: 52 new topics
#     2004: 56 new topics
#     2005: 59 new topics
#     2006: 62 new topics
#     2007: 58 new topics
#     2008: 50 new topics
#     2009: 56 new topics
#     2010: 57 new topics
#     2011: 53 new topics
#     2012: 45 new topics
#     2013: 50 new topics
#     2014: 50 new topics
#     2015: 47 new topics
#     2016: 39 new topics
#     2017: 30 new topics
#     2018: 25 new topics
#     2019: 23 new topics
#     2020: 14 new topics
#     2021: 18 new topics
#     2022: 19 new topics
#     2023: 22 new topics
#     2024: 20 new topics
#     2025: 18 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  7 | 84% stable (21S 0M 4D)
#     T 61 | 84% stable (21S 0M 4D)
#     T 28 | 84% stable (21S 0M 4D)
#     T 50 | 79% stable (19S 0M 5D)
#     T 33 | 76% stable (19S 0M 6D)
#   Top 5 most unstable:
#     T 42 | 10% stable (2S 0M 19D)
#     T 25 | 9% stable (2S 0M 20D)
#     T 16 | 5% stable (1S 0M 20D)
#     T 17 | 0% stable (0S 0M 8D)
#     T 24 | 0% stable (0S 0M 18D)
#
#
# ======================================================================
# Analysis Review: MATH (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 504 events
#   Per year:
#     2000: 28 topics
#     2001: 31 topics
#     2002: 26 topics
#     2003: 27 topics
#     2004: 30 topics
#     2005: 22 topics
#     2006: 25 topics
#     2007: 25 topics
#     2008: 24 topics
#     2009: 22 topics
#     2010: 21 topics
#     2011: 19 topics
#     2012: 20 topics
#     2013: 17 topics
#     2014: 17 topics
#     2015: 17 topics
#     2016: 15 topics
#     2017: 14 topics
#     2018: 15 topics
#     2019: 14 topics
#     2020: 15 topics
#     2021: 14 topics
#     2022: 15 topics
#     2023: 15 topics
#     2024: 16 topics
#
#   Permanently gone: 17
#     T 30 last @ 2023 (sim=0.191) | ker, lowercase, end_bmatrix, bmatrix, semifield, t
#     T  5 last @ 2024 (sim=0.389) | word, texttt_texttt, varphi, circ, psh, fibonacci,
#     T 10 last @ 2024 (sim=0.458) | varepsilon, bullet, varepsilon_varepsilon, mathbb,
#     T 16 last @ 2024 (sim=0.411) | dynamical, entropy, subshift, right, logic, topolo
#     T 22 last @ 2024 (sim=0.407) | code, prime, permutation, frac, integer, log, sum,
#     T 23 last @ 2024 (sim=0.182) | hilb, geq, mathbb, func, shnirelman, closeness, da
#     T 25 last @ 2024 (sim=0.303) | mathrm, adj, dim, mathbb, gobs, cat, supp, privacy
#     T 26 last @ 2024 (sim=0.492) | tensor, rank, decomposition, product, free, matrix
#     T 27 last @ 2024 (sim=0.488) | mathcal, mathcal_mathcal, mathbb, subset, ovr, mat
#     T 30 last @ 2024 (sim=0.000) | semifield, vee, ker, tough, cup, lowercase, spectr
#     ... +7 more
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 515 events
#   Per year:
#     2001: 29 new topics
#     2002: 33 new topics
#     2003: 25 new topics
#     2004: 30 new topics
#     2005: 30 new topics
#     2006: 23 new topics
#     2007: 26 new topics
#     2008: 26 new topics
#     2009: 24 new topics
#     2010: 21 new topics
#     2011: 24 new topics
#     2012: 18 new topics
#     2013: 21 new topics
#     2014: 16 new topics
#     2015: 20 new topics
#     2016: 15 new topics
#     2017: 16 new topics
#     2018: 14 new topics
#     2019: 16 new topics
#     2020: 12 new topics
#     2021: 15 new topics
#     2022: 16 new topics
#     2023: 15 new topics
#     2024: 15 new topics
#     2025: 15 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  7 | 100% stable (25S 0M 0D)
#     T  4 | 100% stable (25S 0M 0D)
#     T 12 | 100% stable (25S 0M 0D)
#     T  6 | 96% stable (24S 0M 1D)
#     T  8 | 96% stable (24S 0M 1D)
#   Top 5 most unstable:
#     T 25 | 0% stable (0S 0M 13D)
#     T 30 | 0% stable (0S 0M 15D)
#     T 31 | 0% stable (0S 0M 19D)
#     T 37 | 0% stable (0S 0M 18D)
#     T 46 | 0% stable (0S 0M 10D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 512 events
#   Per year:
#     2000: 34 topics
#     2001: 40 topics
#     2002: 39 topics
#     2003: 38 topics
#     2004: 36 topics
#     2005: 30 topics
#     2006: 29 topics
#     2007: 25 topics
#     2008: 31 topics
#     2009: 24 topics
#     2010: 20 topics
#     2011: 16 topics
#     2012: 16 topics
#     2013: 18 topics
#     2014: 13 topics
#     2015: 13 topics
#     2016: 17 topics
#     2017: 12 topics
#     2018: 11 topics
#     2019: 12 topics
#     2020: 7 topics
#     2021: 8 topics
#     2022: 8 topics
#     2023: 9 topics
#     2024: 6 topics
#
#   Permanently gone: 8
#     T 21 last @ 2021 (sim=0.113) | dot_obs, dot_dot, mathrm, dot, boldsymbol_boldsymb
#     T 21 last @ 2022 (sim=0.000) | prl, comment, arxiv, dot_obs, 15242v1, minguzzi, d
#     T 11 last @ 2024 (sim=0.459) | solar, earth, planet, satellite, mission, atmosphe
#     T 13 last @ 2024 (sim=0.459) | measurement, frequency, optical, noise, sensor, si
#     T 15 last @ 2024 (sim=0.466) | spin, tensor, space, field, vector, momentum, vort
#     T 18 last @ 2024 (sim=0.464) | function, operator, numerical, hamiltonian, field,
#     T 24 last @ 2024 (sim=0.231) | experimental, diffusion, maple, dmd, dynamic, datu
#     T 41 last @ 2024 (sim=0.338) | frac, text, textit, leq, pm0_times10, sim, ell, tw
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 516 events
#   Per year:
#     2001: 38 new topics
#     2002: 39 new topics
#     2003: 40 new topics
#     2004: 37 new topics
#     2005: 36 new topics
#     2006: 30 new topics
#     2007: 29 new topics
#     2008: 27 new topics
#     2009: 31 new topics
#     2010: 24 new topics
#     2011: 20 new topics
#     2012: 15 new topics
#     2013: 16 new topics
#     2014: 19 new topics
#     2015: 12 new topics
#     2016: 14 new topics
#     2017: 17 new topics
#     2018: 11 new topics
#     2019: 11 new topics
#     2020: 12 new topics
#     2021: 8 new topics
#     2022: 8 new topics
#     2023: 7 new topics
#     2024: 9 new topics
#     2025: 6 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 16 | 100% stable (25S 0M 0D)
#     T 35 | 100% stable (25S 0M 0D)
#     T 44 | 92% stable (23S 0M 2D)
#     T 23 | 88% stable (22S 0M 3D)
#     T 26 | 88% stable (22S 0M 3D)
#   Top 5 most unstable:
#     T 29 | 19% stable (4S 0M 17D)
#     T 24 | 9% stable (2S 0M 21D)
#     T 15 | 8% stable (2S 0M 23D)
#     T 49 | 8% stable (2S 0M 23D)
#     T 41 | 0% stable (0S 0M 20D)
