# %% [markdown]
# # LDA: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment with mismatch detection.
#
# | Priority | Category | Condition |
# |----------|----------|-----------|
# | 1 | **Disappear** | sim ≤ 0.2 |
# | 2 | **Merge** | sim > 0.2, and the t+1-topic has >1 source |
# | 3 | **Mismatch** | sim > 0.2, single source, best-match ID ≠ own topic ID |
# | 4 | **Stable** | sim > 0.6, best-match ID = own topic ID |
# | 5 | **Evolve** | 0.2 < sim ≤ 0.6, best-match ID = own topic ID |
# | — | **New** | t+1-topic has no incoming source with sim > 0.2 |
#
# From t-side: Disappear + Merge + Mismatch + Stable + Evolve = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/lda/temporal")
RESULT_DIR = Path("../../../../results/lda/consistency")
THRESHOLD_DISAPPEAR = 0.2  # sim <= 0.2 → disappear
THRESHOLD_STABLE    = 0.6  # sim > 0.5  → stable (if same ID)

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold Disappear : sim <= {THRESHOLD_DISAPPEAR}")
print(f"Threshold Stable    : sim > {THRESHOLD_STABLE}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold Disappear : sim <= 0.2
# Threshold Stable    : sim > 0.6
# Reading from: ../../../../results/lda/temporal
# Saving to: ../../../../results/lda/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]

def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n'======================================================================'")
    print(f"Continuity Rate: {subject.upper()} (LDA)")
    print(f"'======================================================================'")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t  = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        # Build full RBO similarity matrix (t → t+1)
        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for ii, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for jj, tid_t1 in enumerate(topics_t1):
                words_t1_tmp = topic_words.get((t_next, tid_t1), [])
                sim_matrix[ii, jj] = rbo(words_t, words_t1_tmp, p=0.9)

        # ── Step 1: Each t-topic → its best t+1-topic ────────────────────────
        best_match_idx = np.argmax(sim_matrix, axis=1)
        best_match_sim = np.max(sim_matrix, axis=1)

        # ── Step 2: Count sources (sim > 0.2) per t+1-topic ──────────────────
        target_counts = Counter()
        for idx in range(len(topics_t)):
            if float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR:
                target_counts[topics_t1[best_match_idx[idx]]] += 1

        # merge_targets: t+1-topics claimed by >1 source with sim > 0.2
        merge_targets = {tgt for tgt, cnt in target_counts.items() if cnt > 1}

        # ── Step 3: Classify each t-topic ─────────────────────────────────────
        n_stable = n_evolve = n_merge = n_disappear = n_mismatch = 0

        for idx, tid in enumerate(topics_t):
            sim_val    = float(best_match_sim[idx])
            target_tid = topics_t1[best_match_idx[idx]]
            words_t    = ", ".join(topic_words.get((t, tid), []))

            # ── 1. DISAPPEAR: sim <= 0.2 ──────────────────────────────────────
            if sim_val <= THRESHOLD_DISAPPEAR:
                category = "disappear"
                n_disappear += 1

            # ── 2. MERGE: sim > 0.2 AND target has >1 source ─────────────────
            elif tid in merge_targets:
                tar_id = tid
                sources = [tid for idx, tid in enumerate(topics_t)
                       if topics_t1[best_match_idx[idx]] == tar_id
                       and float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR]
                if tid in sources:
                    category = "merge"
                    n_merge += 1
                else:
                    category = "mismatch"
                    n_merge += 1

            # ── 3. MISMATCH: sim > 0.2, single source, target ID ≠ own ID ────
            elif target_tid != tid:
                category   = "mismatch"
                n_mismatch += 1

            # ── 4. STABLE: sim > 0.5, target ID = own ID ─────────────────────
            elif sim_val > THRESHOLD_STABLE:
                category = "stable"
                n_stable += 1

            # ── 5. EVOLVE: 0.2 < sim <= 0.5, target ID = own ID ─────────────
            else:
                category = "evolve"
                n_evolve += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target_tid,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # ── Step 4: Record merge groups ────────────────────────────────────────
        for target_tid in merge_targets:
            sources = [tid for idx, tid in enumerate(topics_t)
                       if topics_t1[best_match_idx[idx]] == target_tid
                       and float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR]
            source_sims = [round(float(sim_matrix[topics_t.index(s),
                                                   topics_t1.index(target_tid)]), 4)
                           for s in sources]
            words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
            all_merge_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "target_topic": target_tid,
                "n_sources": len(sources),
                "source_topics": str(sources),
                "source_sims": str(source_sims),
                "target_words": words_t1,
            })

        # ── Step 5: New topics — no incoming source with sim > 0.2 ────────────
        matched_t1 = set(topics_t[idx]
                         for idx in range(len(topics_t))
                         if float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR)
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t        = len(topics_t)
        n_new          = len(new_topics)
        n_merge_groups = len(merge_targets)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_evolve": n_evolve, "n_merge": n_merge,
            "n_mismatch": n_mismatch, "n_disappear": n_disappear,
            "n_merge_groups": n_merge_groups, "n_new": n_new,
            "pct_stable":    round(n_stable    / total_t * 100, 2),
            "pct_evolve":    round(n_evolve    / total_t * 100, 2),
            "pct_merge":     round(n_merge     / total_t * 100, 2),
            "pct_mismatch":  round(n_mismatch  / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Evolve={n_evolve} ({n_evolve/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Mismatch={n_mismatch} ({n_mismatch/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject,
        "threshold_disappear": THRESHOLD_DISAPPEAR,
        "threshold_stable":    THRESHOLD_STABLE,
        "avg_pct_stable":    round(subj_sum["pct_stable"].mean(),    2),
        "avg_pct_evolve":    round(subj_sum["pct_evolve"].mean(),    2),
        "avg_pct_merge":     round(subj_sum["pct_merge"].mean(),     2),
        "avg_pct_mismatch":  round(subj_sum["pct_mismatch"].mean(),  2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new":          int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Evolve={overall['avg_pct_evolve']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Mismatch={overall['avg_pct_mismatch']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# '======================================================================'
# Continuity Rate: CS (LDA)
# '======================================================================'
#   2000→2001: Stable=18 (39%)  Evolve=19 (41%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=9 (20%)  New=4
#   2001→2002: Stable=15 (37%)  Evolve=24 (59%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=2 (5%)  New=4
#   2002→2003: Stable=14 (33%)  Evolve=27 (63%)  Merge=1 (2%)  Mismatch=1 (2%)  Disappear=0 (0%)  New=7
#   2003→2004: Stable=21 (42%)  Evolve=22 (44%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=7 (14%)  New=4
#   2004→2005: Stable=17 (36%)  Evolve=26 (55%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=4 (9%)  New=7
#   2005→2006: Stable=14 (28%)  Evolve=28 (56%)  Merge=2 (4%)  Mismatch=2 (4%)  Disappear=4 (8%)  New=2
#   2006→2007: Stable=20 (42%)  Evolve=18 (38%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=10 (21%)  New=10
#   2007→2008: Stable=19 (40%)  Evolve=25 (52%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=4 (8%)  New=5
#   2008→2009: Stable=17 (35%)  Evolve=27 (55%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=5 (10%)  New=4
#   2009→2010: Stable=23 (48%)  Evolve=20 (42%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=5 (10%)  New=7
#   2010→2011: Stable=31 (62%)  Evolve=16 (32%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=3 (6%)  New=1
#   2011→2012: Stable=33 (69%)  Evolve=12 (25%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=3 (6%)  New=4
#   2012→2013: Stable=29 (59%)  Evolve=20 (41%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=1
#   2013→2014: Stable=35 (70%)  Evolve=15 (30%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2014→2015: Stable=36 (72%)  Evolve=13 (26%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2015→2016: Stable=43 (86%)  Evolve=6 (12%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=0
#   2016→2017: Stable=44 (90%)  Evolve=5 (10%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=1
#   2017→2018: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2018→2019: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2020→2021: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=50 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=66.9%  Evolve=27.8%  Merge=0.2%  Mismatch=0.2%  Disappear=4.8%  New=62
#   Saved: ../../../../results/lda/consistency/cs
#
# '======================================================================'
# Continuity Rate: MATH (LDA)
# '======================================================================'
#   2000→2001: Stable=24 (50%)  Evolve=21 (44%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=3 (6%)  New=3
#   2001→2002: Stable=21 (44%)  Evolve=21 (44%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=6 (12%)  New=5
#   2002→2003: Stable=26 (55%)  Evolve=15 (32%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=6 (13%)  New=8
#   2003→2004: Stable=31 (63%)  Evolve=14 (29%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=4 (8%)  New=3
#   2004→2005: Stable=32 (67%)  Evolve=14 (29%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=2 (4%)  New=3
#   2005→2006: Stable=33 (67%)  Evolve=16 (33%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=1
#   2006→2007: Stable=36 (72%)  Evolve=11 (22%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=3 (6%)  New=3
#   2007→2008: Stable=34 (68%)  Evolve=15 (30%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2008→2009: Stable=34 (68%)  Evolve=15 (30%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2009→2010: Stable=37 (74%)  Evolve=13 (26%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2010→2011: Stable=37 (74%)  Evolve=13 (26%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2011→2012: Stable=41 (82%)  Evolve=9 (18%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2012→2013: Stable=42 (84%)  Evolve=7 (14%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2013→2014: Stable=45 (90%)  Evolve=5 (10%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2014→2015: Stable=47 (94%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2015→2016: Stable=45 (90%)  Evolve=5 (10%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2016→2017: Stable=43 (86%)  Evolve=6 (12%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2017→2018: Stable=46 (92%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2018→2019: Stable=46 (92%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2019→2020: Stable=45 (90%)  Evolve=4 (8%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2020→2021: Stable=47 (94%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2021→2022: Stable=45 (90%)  Evolve=5 (10%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=46 (92%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2023→2024: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=78.8%  Evolve=18.6%  Merge=0.0%  Mismatch=0.0%  Disappear=2.6%  New=34
#   Saved: ../../../../results/lda/consistency/math
#
# '======================================================================'
# Continuity Rate: PHYSICS (LDA)
# '======================================================================'
#   2000→2001: Stable=24 (53%)  Evolve=21 (47%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=4
#   2001→2002: Stable=20 (41%)  Evolve=28 (57%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2002→2003: Stable=17 (35%)  Evolve=29 (59%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=3 (6%)  New=2
#   2003→2004: Stable=26 (54%)  Evolve=19 (40%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=3 (6%)  New=5
#   2004→2005: Stable=25 (50%)  Evolve=22 (44%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=3 (6%)  New=2
#   2005→2006: Stable=28 (57%)  Evolve=20 (41%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=2
#   2006→2007: Stable=36 (72%)  Evolve=13 (26%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2007→2008: Stable=35 (70%)  Evolve=13 (26%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=2 (4%)  New=1
#   2008→2009: Stable=34 (69%)  Evolve=14 (29%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=2
#   2009→2010: Stable=42 (84%)  Evolve=7 (14%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2010→2011: Stable=41 (82%)  Evolve=7 (14%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=2 (4%)  New=2
#   2011→2012: Stable=43 (86%)  Evolve=6 (12%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2012→2013: Stable=45 (90%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=2 (4%)  New=1
#   2013→2014: Stable=43 (88%)  Evolve=5 (10%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=2
#   2014→2015: Stable=46 (92%)  Evolve=4 (8%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2015→2016: Stable=46 (92%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=1
#   2016→2017: Stable=47 (94%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2017→2018: Stable=46 (92%)  Evolve=4 (8%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2018→2019: Stable=47 (94%)  Evolve=3 (6%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2019→2020: Stable=47 (94%)  Evolve=2 (4%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=1 (2%)  New=0
#   2020→2021: Stable=49 (100%)  Evolve=0 (0%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=1
#   2021→2022: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2022→2023: Stable=48 (96%)  Evolve=2 (4%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2023→2024: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#   2024→2025: Stable=49 (98%)  Evolve=1 (2%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=0 (0%)  New=0
#
#   Overall: Stable=79.1%  Evolve=19.0%  Merge=0.0%  Mismatch=0.0%  Disappear=1.9%  New=29
#   Saved: ../../../../results/lda/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n'======================================================================'")
    print(f"Analysis Review: {subject.upper()} (LDA)")
    print(f"'======================================================================'")

    trans_df   = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df   = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path   = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df     = pd.read_csv(new_path)   if new_path.stat().st_size   > 10 else pd.DataFrame()
    evo_df     = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- MERGE ---
    merged = trans_df[trans_df["category"] == "merge"]
    print(f"\n  🔗 MERGE (sim > {THRESHOLD_DISAPPEAR}, >1 source): {len(merged)} events")
    if len(merge_df) > 0:
        print("  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(min(10, len(merge_df)), "n_sources").iterrows():
            w = str(r["target_words"])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- MISMATCH ---
    mismatch = trans_df[trans_df["category"] == "mismatch"]
    print(f"\n  ⚠️  MISMATCH (sim > {THRESHOLD_DISAPPEAR}, target ID ≠ own ID): {len(mismatch)} events")
    if len(mismatch) > 0:
        per_year = mismatch.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")
        print("  Sample (up to 5):")
        for _, r in mismatch.head(5).iterrows():
            print(f"    T{int(r['topic_id']):>3} @ {int(r['year_from'])}→{int(r['year_to'])} "
                  f"best→T{int(r['best_match_topic'])} (sim={r['best_match_sim']:.3f}) | {str(r['words'])[:50]}")

    # --- STABLE ---
    stable = trans_df[trans_df["category"] == "stable"]
    print(f"\n  🟢 STABLE (sim > {THRESHOLD_STABLE}, same ID): {len(stable)} events")
    if len(stable) > 0:
        per_year = stable.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

    # --- EVOLVE ---
    evolved = trans_df[trans_df["category"] == "evolve"]
    print(f"\n  🔄 EVOLVE ({THRESHOLD_DISAPPEAR} < sim <= {THRESHOLD_STABLE}, same ID): {len(evolved)} events")
    if len(evolved) > 0:
        per_year = evolved.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

    # --- DISAPPEAR ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED (sim <= {THRESHOLD_DISAPPEAR}): {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")
        perm = []
        for _, r in disappeared.iterrows():
            tid   = int(r["topic_id"])
            later = evo_df[(evo_df["topic_id"] == tid) & (evo_df["year"] > int(r["year_to"]))]
            if len(later) == 0:
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {str(r['words'])[:50]}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS (no incoming sim > {THRESHOLD_DISAPPEAR}): {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print("\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "evolve", "merge", "mismatch", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)
    print("  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev "
              f"{int(r.get('merge',0))}M {int(r.get('mismatch',0))}Mm {int(r.get('disappear',0))}D)")
    print("  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev "
              f"{int(r.get('merge',0))}M {int(r.get('mismatch',0))}Mm {int(r.get('disappear',0))}D)")
    print()
# Out:
# '======================================================================'
# Analysis Review: CS (LDA)
# '======================================================================'
#
#   🔗 MERGE (sim > 0.2, >1 source): 3 events
#   Top 10 merges (most sources):
#     T 42 @ 2003 ← [31, 42] (sims=[0.2703, 0.6828]) | rbf, rbfns, matrix, frame, grassmannian,
#     T 49 @ 2006 ← [35, 49] (sims=[0.2703, 0.6961]) | grid, resource, computing, network, sche
#     T 34 @ 2006 ← [2, 34] (sims=[0.2703, 0.3434]) | robot, rotation, arm, quaternion, rollin
#
#   ⚠️  MISMATCH (sim > 0.2, target ID ≠ own ID): 3 events
#   Per year:
#     2002: 1 topics
#     2005: 2 topics
#   Sample (up to 5):
#     T 31 @ 2002→2003 best→T42 (sim=0.270) | rbf, bkm, boundary, cache_miss, mesh, reciprocity,
#     T  2 @ 2005→2006 best→T34 (sim=0.270) | robot, human, interaction, gesture, recognition, m
#     T 35 @ 2005→2006 best→T49 (sim=0.270) | grid, self, reworking, semantic, scaleable, freewa
#
#   🟢 STABLE (sim > 0.6, same ID): 822 events
#   Per year:
#     2000: 18 topics
#     2001: 15 topics
#     2002: 14 topics
#     2003: 21 topics
#     2004: 17 topics
#     2005: 14 topics
#     2006: 20 topics
#     2007: 19 topics
#     2008: 17 topics
#     2009: 23 topics
#     2010: 31 topics
#     2011: 33 topics
#     2012: 29 topics
#     2013: 35 topics
#     2014: 36 topics
#     2015: 43 topics
#     2016: 44 topics
#     2017: 48 topics
#     2018: 49 topics
#     2019: 50 topics
#     2020: 49 topics
#     2021: 49 topics
#     2022: 49 topics
#     2023: 49 topics
#     2024: 50 topics
#
#   🔄 EVOLVE (0.2 < sim <= 0.6, same ID): 330 events
#   Per year:
#     2000: 19 topics
#     2001: 24 topics
#     2002: 27 topics
#     2003: 22 topics
#     2004: 26 topics
#     2005: 28 topics
#     2006: 18 topics
#     2007: 25 topics
#     2008: 27 topics
#     2009: 20 topics
#     2010: 16 topics
#     2011: 12 topics
#     2012: 20 topics
#     2013: 15 topics
#     2014: 13 topics
#     2015: 6 topics
#     2016: 5 topics
#     2017: 2 topics
#     2018: 1 topics
#     2020: 1 topics
#     2021: 1 topics
#     2022: 1 topics
#     2023: 1 topics
#
#   📉 DISAPPEARED (sim <= 0.2): 58 events
#   Per year:
#     2000: 9 topics
#     2001: 2 topics
#     2003: 7 topics
#     2004: 4 topics
#     2005: 4 topics
#     2006: 10 topics
#     2007: 4 topics
#     2008: 5 topics
#     2009: 5 topics
#     2010: 3 topics
#     2011: 3 topics
#     2014: 1 topics
#     2015: 1 topics
#
#   Permanently gone: 0
#
#   🆕 NEW TOPICS (no incoming sim > 0.2): 62 events
#   Per year:
#     2001: 4 new topics
#     2002: 4 new topics
#     2003: 7 new topics
#     2004: 4 new topics
#     2005: 7 new topics
#     2006: 2 new topics
#     2007: 10 new topics
#     2008: 5 new topics
#     2009: 4 new topics
#     2010: 7 new topics
#     2011: 1 new topics
#     2012: 4 new topics
#     2013: 1 new topics
#     2015: 1 new topics
#     2017: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 15 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T 26 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T 20 | 96% stable (24S 1Ev 0M 0Mm 0D)
#     T 38 | 96% stable (24S 1Ev 0M 0Mm 0D)
#     T  1 | 96% stable (24S 1Ev 0M 0Mm 0D)
#   Top 5 most unstable:
#     T  4 | 42% stable (10S 12Ev 0M 0Mm 2D)
#     T 31 | 40% stable (10S 10Ev 0M 1Mm 4D)
#     T 25 | 38% stable (8S 10Ev 0M 0Mm 3D)
#     T 21 | 38% stable (9S 10Ev 0M 0Mm 5D)
#     T 24 | 30% stable (6S 10Ev 0M 0Mm 4D)
#
#
# '======================================================================'
# Analysis Review: MATH (LDA)
# '======================================================================'
#
#   🔗 MERGE (sim > 0.2, >1 source): 0 events
#
#   ⚠️  MISMATCH (sim > 0.2, target ID ≠ own ID): 0 events
#
#   🟢 STABLE (sim > 0.6, same ID): 979 events
#   Per year:
#     2000: 24 topics
#     2001: 21 topics
#     2002: 26 topics
#     2003: 31 topics
#     2004: 32 topics
#     2005: 33 topics
#     2006: 36 topics
#     2007: 34 topics
#     2008: 34 topics
#     2009: 37 topics
#     2010: 37 topics
#     2011: 41 topics
#     2012: 42 topics
#     2013: 45 topics
#     2014: 47 topics
#     2015: 45 topics
#     2016: 43 topics
#     2017: 46 topics
#     2018: 46 topics
#     2019: 45 topics
#     2020: 47 topics
#     2021: 45 topics
#     2022: 46 topics
#     2023: 48 topics
#     2024: 48 topics
#
#   🔄 EVOLVE (0.2 < sim <= 0.6, same ID): 228 events
#   Per year:
#     2000: 21 topics
#     2001: 21 topics
#     2002: 15 topics
#     2003: 14 topics
#     2004: 14 topics
#     2005: 16 topics
#     2006: 11 topics
#     2007: 15 topics
#     2008: 15 topics
#     2009: 13 topics
#     2010: 13 topics
#     2011: 9 topics
#     2012: 7 topics
#     2013: 5 topics
#     2014: 3 topics
#     2015: 5 topics
#     2016: 6 topics
#     2017: 3 topics
#     2018: 3 topics
#     2019: 4 topics
#     2020: 3 topics
#     2021: 5 topics
#     2022: 3 topics
#     2023: 2 topics
#     2024: 2 topics
#
#   📉 DISAPPEARED (sim <= 0.2): 32 events
#   Per year:
#     2000: 3 topics
#     2001: 6 topics
#     2002: 6 topics
#     2003: 4 topics
#     2004: 2 topics
#     2006: 3 topics
#     2007: 1 topics
#     2008: 1 topics
#     2012: 1 topics
#     2016: 1 topics
#     2017: 1 topics
#     2018: 1 topics
#     2019: 1 topics
#     2022: 1 topics
#
#   Permanently gone: 0
#
#   🆕 NEW TOPICS (no incoming sim > 0.2): 34 events
#   Per year:
#     2001: 3 new topics
#     2002: 5 new topics
#     2003: 8 new topics
#     2004: 3 new topics
#     2005: 3 new topics
#     2006: 1 new topics
#     2007: 3 new topics
#     2008: 1 new topics
#     2009: 1 new topics
#     2013: 1 new topics
#     2017: 1 new topics
#     2018: 1 new topics
#     2019: 1 new topics
#     2020: 1 new topics
#     2023: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  4 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T  2 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T  8 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T  9 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T  5 | 100% stable (25S 0Ev 0M 0Mm 0D)
#   Top 5 most unstable:
#     T 16 | 52% stable (13S 12Ev 0M 0Mm 0D)
#     T 41 | 32% stable (8S 17Ev 0M 0Mm 0D)
#     T 28 | 20% stable (5S 18Ev 0M 0Mm 2D)
#     T 10 | 17% stable (4S 14Ev 0M 0Mm 5D)
#     T 49 | 4% stable (1S 15Ev 0M 0Mm 6D)
#
#
# '======================================================================'
# Analysis Review: PHYSICS (LDA)
# '======================================================================'
#
#   🔗 MERGE (sim > 0.2, >1 source): 0 events
#
#   ⚠️  MISMATCH (sim > 0.2, target ID ≠ own ID): 0 events
#
#   🟢 STABLE (sim > 0.6, same ID): 981 events
#   Per year:
#     2000: 24 topics
#     2001: 20 topics
#     2002: 17 topics
#     2003: 26 topics
#     2004: 25 topics
#     2005: 28 topics
#     2006: 36 topics
#     2007: 35 topics
#     2008: 34 topics
#     2009: 42 topics
#     2010: 41 topics
#     2011: 43 topics
#     2012: 45 topics
#     2013: 43 topics
#     2014: 46 topics
#     2015: 46 topics
#     2016: 47 topics
#     2017: 46 topics
#     2018: 47 topics
#     2019: 47 topics
#     2020: 49 topics
#     2021: 48 topics
#     2022: 48 topics
#     2023: 49 topics
#     2024: 49 topics
#
#   🔄 EVOLVE (0.2 < sim <= 0.6, same ID): 232 events
#   Per year:
#     2000: 21 topics
#     2001: 28 topics
#     2002: 29 topics
#     2003: 19 topics
#     2004: 22 topics
#     2005: 20 topics
#     2006: 13 topics
#     2007: 13 topics
#     2008: 14 topics
#     2009: 7 topics
#     2010: 7 topics
#     2011: 6 topics
#     2012: 3 topics
#     2013: 5 topics
#     2014: 4 topics
#     2015: 3 topics
#     2016: 3 topics
#     2017: 4 topics
#     2018: 3 topics
#     2019: 2 topics
#     2021: 2 topics
#     2022: 2 topics
#     2023: 1 topics
#     2024: 1 topics
#
#   📉 DISAPPEARED (sim <= 0.2): 24 events
#   Per year:
#     2001: 1 topics
#     2002: 3 topics
#     2003: 3 topics
#     2004: 3 topics
#     2005: 1 topics
#     2006: 1 topics
#     2007: 2 topics
#     2008: 1 topics
#     2009: 1 topics
#     2010: 2 topics
#     2011: 1 topics
#     2012: 2 topics
#     2013: 1 topics
#     2015: 1 topics
#     2019: 1 topics
#   Permanently gone: 0
#
#   🆕 NEW TOPICS (no incoming sim > 0.2): 29 events
#   Per year:
#     2001: 4 new topics
#     2002: 1 new topics
#     2003: 2 new topics
#     2004: 5 new topics
#     2005: 2 new topics
#     2006: 2 new topics
#     2007: 1 new topics
#     2008: 1 new topics
#     2009: 2 new topics
#     2010: 1 new topics
#     2011: 2 new topics
#     2012: 1 new topics
#     2013: 1 new topics
#     2014: 2 new topics
#     2016: 1 new topics
#     2021: 1 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 10 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T  6 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T 41 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T 38 | 100% stable (25S 0Ev 0M 0Mm 0D)
#     T 48 | 100% stable (25S 0Ev 0M 0Mm 0D)
#   Top 5 most unstable:
#     T 32 | 52% stable (13S 11Ev 0M 0Mm 1D)
#     T 16 | 44% stable (11S 14Ev 0M 0Mm 0D)
#     T 20 | 36% stable (9S 10Ev 0M 0Mm 6D)
#     T 42 | 21% stable (4S 10Ev 0M 0Mm 5D)
#     T  5 | 18% stable (4S 12Ev 0M 0Mm 6D)
