# %% [markdown]
# # LDA: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/lda/temporal")
RESULT_DIR = Path("../../../../results/lda/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/lda/temporal
# Saving to: ../../../../results/lda/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def build_word_matrix(topic_ids, topic_words_dict, year, vocab_index):
    matrix = np.zeros((len(topic_ids), len(vocab_index)))
    for i, tid in enumerate(topic_ids):
        words = topic_words_dict.get((year, tid), [])
        for w in words:
            if w in vocab_index:
                matrix[i, vocab_index[w]] = 1.0
    return matrix

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_words = set()
    for words in topic_words.values():
        all_words.update(words)
    vocab_index = {w: i for i, w in enumerate(sorted(all_words))}

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        mat_t = build_word_matrix(topics_t, topic_words, t, vocab_index)
        mat_t1 = build_word_matrix(topics_t1, topic_words, t_next, vocab_index)
        sim_matrix = cosine_similarity(mat_t, mat_t1)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (LDA)
# ======================================================================
#   2000→2001: Stable=2 (4%)  Merge=0 (0%)  Disappear=43 (96%)  New=49
#   2001→2002: Stable=1 (2%)  Merge=0 (0%)  Disappear=50 (98%)  New=55
#   2002→2003: Stable=2 (4%)  Merge=0 (0%)  Disappear=54 (96%)  New=52
#   2003→2004: Stable=1 (2%)  Merge=0 (0%)  Disappear=53 (98%)  New=61
#   2004→2005: Stable=4 (6%)  Merge=0 (0%)  Disappear=58 (94%)  New=50
#   2005→2006: Stable=6 (11%)  Merge=0 (0%)  Disappear=48 (89%)  New=57
#   2006→2007: Stable=5 (8%)  Merge=0 (0%)  Disappear=58 (92%)  New=53
#   2007→2008: Stable=5 (9%)  Merge=0 (0%)  Disappear=53 (91%)  New=57
#   2008→2009: Stable=3 (5%)  Merge=0 (0%)  Disappear=59 (95%)  New=55
#   2009→2010: Stable=7 (12%)  Merge=0 (0%)  Disappear=51 (88%)  New=56
#   2010→2011: Stable=11 (17%)  Merge=2 (3%)  Disappear=50 (79%)  New=56
#   2011→2012: Stable=14 (21%)  Merge=0 (0%)  Disappear=54 (79%)  New=52
#   2012→2013: Stable=15 (23%)  Merge=0 (0%)  Disappear=51 (77%)  New=53
#   2013→2014: Stable=21 (31%)  Merge=0 (0%)  Disappear=47 (69%)  New=49
#   2014→2015: Stable=27 (39%)  Merge=0 (0%)  Disappear=43 (61%)  New=40
#   2015→2016: Stable=31 (46%)  Merge=0 (0%)  Disappear=36 (54%)  New=37
#   2016→2017: Stable=36 (53%)  Merge=0 (0%)  Disappear=32 (47%)  New=35
#   2017→2018: Stable=46 (65%)  Merge=0 (0%)  Disappear=25 (35%)  New=26
#   2018→2019: Stable=51 (71%)  Merge=0 (0%)  Disappear=21 (29%)  New=21
#   2019→2020: Stable=51 (71%)  Merge=0 (0%)  Disappear=21 (29%)  New=20
#   2020→2021: Stable=56 (79%)  Merge=0 (0%)  Disappear=15 (21%)  New=16
#   2021→2022: Stable=57 (79%)  Merge=0 (0%)  Disappear=15 (21%)  New=15
#   2022→2023: Stable=56 (78%)  Merge=0 (0%)  Disappear=16 (22%)  New=18
#   2023→2024: Stable=55 (74%)  Merge=0 (0%)  Disappear=19 (26%)  New=15
#   2024→2025: Stable=56 (80%)  Merge=2 (3%)  Disappear=12 (17%)  New=12
#
#   Overall: Stable=35.6%  Merge=0.2%  Disappear=64.2%  New=1010
#   Saved: ../../../../results/lda/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (LDA)
# ======================================================================
#   2000→2001: Stable=3 (6%)  Merge=0 (0%)  Disappear=44 (94%)  New=47
#   2001→2002: Stable=3 (6%)  Merge=0 (0%)  Disappear=47 (94%)  New=47
#   2002→2003: Stable=3 (6%)  Merge=0 (0%)  Disappear=47 (94%)  New=44
#   2003→2004: Stable=9 (19%)  Merge=0 (0%)  Disappear=38 (81%)  New=40
#   2004→2005: Stable=14 (29%)  Merge=0 (0%)  Disappear=35 (71%)  New=36
#   2005→2006: Stable=17 (34%)  Merge=0 (0%)  Disappear=33 (66%)  New=32
#   2006→2007: Stable=17 (35%)  Merge=0 (0%)  Disappear=32 (65%)  New=33
#   2007→2008: Stable=19 (38%)  Merge=0 (0%)  Disappear=31 (62%)  New=31
#   2008→2009: Stable=16 (32%)  Merge=0 (0%)  Disappear=34 (68%)  New=32
#   2009→2010: Stable=20 (42%)  Merge=0 (0%)  Disappear=28 (58%)  New=29
#   2010→2011: Stable=25 (51%)  Merge=0 (0%)  Disappear=24 (49%)  New=25
#   2011→2012: Stable=26 (52%)  Merge=0 (0%)  Disappear=24 (48%)  New=23
#   2012→2013: Stable=29 (59%)  Merge=0 (0%)  Disappear=20 (41%)  New=21
#   2013→2014: Stable=31 (62%)  Merge=0 (0%)  Disappear=19 (38%)  New=18
#   2014→2015: Stable=32 (65%)  Merge=0 (0%)  Disappear=17 (35%)  New=17
#   2015→2016: Stable=35 (71%)  Merge=0 (0%)  Disappear=14 (29%)  New=15
#   2016→2017: Stable=37 (74%)  Merge=0 (0%)  Disappear=13 (26%)  New=13
#   2017→2018: Stable=33 (66%)  Merge=3 (6%)  Disappear=14 (28%)  New=16
#   2018→2019: Stable=39 (78%)  Merge=0 (0%)  Disappear=11 (22%)  New=11
#   2019→2020: Stable=35 (70%)  Merge=4 (8%)  Disappear=11 (22%)  New=14
#   2020→2021: Stable=36 (72%)  Merge=3 (6%)  Disappear=11 (22%)  New=13
#   2021→2022: Stable=37 (74%)  Merge=2 (4%)  Disappear=11 (22%)  New=12
#   2022→2023: Stable=40 (80%)  Merge=0 (0%)  Disappear=10 (20%)  New=10
#   2023→2024: Stable=39 (78%)  Merge=2 (4%)  Disappear=9 (18%)  New=10
#   2024→2025: Stable=42 (84%)  Merge=0 (0%)  Disappear=8 (16%)  New=8
#
#   Overall: Stable=51.3%  Merge=1.1%  Disappear=47.5%  New=597
#   Saved: ../../../../results/lda/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (LDA)
# ======================================================================
#   2000→2001: Stable=1 (2%)  Merge=0 (0%)  Disappear=47 (98%)  New=49
#   2001→2002: Stable=2 (4%)  Merge=0 (0%)  Disappear=48 (96%)  New=47
#   2002→2003: Stable=1 (2%)  Merge=0 (0%)  Disappear=48 (98%)  New=49
#   2003→2004: Stable=5 (10%)  Merge=0 (0%)  Disappear=45 (90%)  New=44
#   2004→2005: Stable=7 (14%)  Merge=0 (0%)  Disappear=42 (86%)  New=42
#   2005→2006: Stable=14 (29%)  Merge=0 (0%)  Disappear=35 (71%)  New=35
#   2006→2007: Stable=12 (24%)  Merge=0 (0%)  Disappear=37 (76%)  New=37
#   2007→2008: Stable=16 (33%)  Merge=0 (0%)  Disappear=33 (67%)  New=34
#   2008→2009: Stable=15 (30%)  Merge=0 (0%)  Disappear=35 (70%)  New=35
#   2009→2010: Stable=18 (36%)  Merge=0 (0%)  Disappear=32 (64%)  New=32
#   2010→2011: Stable=22 (44%)  Merge=0 (0%)  Disappear=28 (56%)  New=28
#   2011→2012: Stable=31 (62%)  Merge=0 (0%)  Disappear=19 (38%)  New=19
#   2012→2013: Stable=31 (62%)  Merge=0 (0%)  Disappear=19 (38%)  New=19
#   2013→2014: Stable=31 (62%)  Merge=0 (0%)  Disappear=19 (38%)  New=19
#   2014→2015: Stable=33 (66%)  Merge=0 (0%)  Disappear=17 (34%)  New=17
#   2015→2016: Stable=33 (66%)  Merge=0 (0%)  Disappear=17 (34%)  New=17
#   2016→2017: Stable=39 (78%)  Merge=0 (0%)  Disappear=11 (22%)  New=11
#   2017→2018: Stable=40 (80%)  Merge=0 (0%)  Disappear=10 (20%)  New=10
#   2018→2019: Stable=40 (80%)  Merge=0 (0%)  Disappear=10 (20%)  New=10
#   2019→2020: Stable=40 (80%)  Merge=0 (0%)  Disappear=10 (20%)  New=10
#   2020→2021: Stable=42 (84%)  Merge=0 (0%)  Disappear=8 (16%)  New=8
#   2021→2022: Stable=44 (88%)  Merge=0 (0%)  Disappear=6 (12%)  New=6
#   2022→2023: Stable=39 (78%)  Merge=0 (0%)  Disappear=11 (22%)  New=11
#   2023→2024: Stable=42 (84%)  Merge=0 (0%)  Disappear=8 (16%)  New=8
#   2024→2025: Stable=39 (78%)  Merge=0 (0%)  Disappear=11 (22%)  New=11
#
#   Overall: Stable=51.0%  Merge=0.0%  Disappear=49.0%  New=608
#   Saved: ../../../../results/lda/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (LDA)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 984 events
#   Per year:
#     2000: 43 topics
#     2001: 50 topics
#     2002: 54 topics
#     2003: 53 topics
#     2004: 58 topics
#     2005: 48 topics
#     2006: 58 topics
#     2007: 53 topics
#     2008: 59 topics
#     2009: 51 topics
#     2010: 50 topics
#     2011: 54 topics
#     2012: 51 topics
#     2013: 47 topics
#     2014: 43 topics
#     2015: 36 topics
#     2016: 32 topics
#     2017: 25 topics
#     2018: 21 topics
#     2019: 21 topics
#     2020: 15 topics
#     2021: 15 topics
#     2022: 16 topics
#     2023: 19 topics
#     2024: 12 topics
#
#   Permanently gone: 19
#     T 45 last @ 2022 (sim=0.100) | color, palette, graphic, recommendation, documents
#     T 57 last @ 2022 (sim=0.200) | alarms, cyclegan, nit, se, clean, alarm, noisy, co
#     T 16 last @ 2023 (sim=0.200) | mathbf, tr, frac, manova, mathrm, times, eigenvalu
#     T 45 last @ 2023 (sim=0.000) | trpca, tensor, rank, rtcur, cur, component, brtf,
#     T 57 last @ 2023 (sim=0.100) | se, noise, gpc, nadiffuse, blind2sound, noisy, sig
#     T 69 last @ 2023 (sim=0.100) | simplicial, complexes, nayyeri, laplacians, shaped
#     T 73 last @ 2023 (sim=0.100) | geud, radiation, plans, therapy, modulated, planni
#     T  6 last @ 2024 (sim=0.100) | coding, moac, mopc, mc, molecular, source, moapc,
#     T  9 last @ 2024 (sim=0.200) | news, fake, elites, statements, checked, fact, ver
#     T 13 last @ 2024 (sim=0.000) | decoders, records, vote, cast, ballots, mlnn, slnn
#     ... +9 more
#
#   🔗 MERGE GROUPS: 2 events
#   Top 10 merges (most sources):
#     T 24 @ 2011 ← [24, 29] (sims=[0.6, 0.5]) | information, data, mb, model, paper, net
#     T 36 @ 2025 ← [36, 48] (sims=[0.9, 0.7]) | neural, networks, network, learning, dee
#
#   🆕 NEW TOPICS: 1010 events
#   Per year:
#     2001: 49 new topics
#     2002: 55 new topics
#     2003: 52 new topics
#     2004: 61 new topics
#     2005: 50 new topics
#     2006: 57 new topics
#     2007: 53 new topics
#     2008: 57 new topics
#     2009: 55 new topics
#     2010: 56 new topics
#     2011: 56 new topics
#     2012: 52 new topics
#     2013: 53 new topics
#     2014: 49 new topics
#     2015: 40 new topics
#     2016: 37 new topics
#     2017: 35 new topics
#     2018: 26 new topics
#     2019: 21 new topics
#     2020: 20 new topics
#     2021: 16 new topics
#     2022: 15 new topics
#     2023: 18 new topics
#     2024: 15 new topics
#     2025: 12 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 61 | 96% stable (24S 0M 1D)
#     T 66 | 83% stable (20S 0M 4D)
#     T  7 | 68% stable (17S 0M 8D)
#     T 37 | 68% stable (17S 0M 8D)
#     T 60 | 67% stable (16S 0M 8D)
#   Top 5 most unstable:
#     T 26 | 0% stable (0S 0M 8D)
#     T 57 | 0% stable (0S 0M 7D)
#     T 43 | 0% stable (0S 0M 24D)
#     T 45 | 0% stable (0S 0M 13D)
#     T 73 | 0% stable (0S 0M 8D)
#
#
# ======================================================================
# Analysis Review: MATH (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 585 events
#   Per year:
#     2000: 44 topics
#     2001: 47 topics
#     2002: 47 topics
#     2003: 38 topics
#     2004: 35 topics
#     2005: 33 topics
#     2006: 32 topics
#     2007: 31 topics
#     2008: 34 topics
#     2009: 28 topics
#     2010: 24 topics
#     2011: 24 topics
#     2012: 20 topics
#     2013: 19 topics
#     2014: 17 topics
#     2015: 14 topics
#     2016: 13 topics
#     2017: 14 topics
#     2018: 11 topics
#     2019: 11 topics
#     2020: 11 topics
#     2021: 11 topics
#     2022: 10 topics
#     2023: 9 topics
#     2024: 8 topics
#
#   Permanently gone: 8
#     T  3 last @ 2024 (sim=0.400) | logic, semantics, modal, fuzzy, intuitionistic, th
#     T  5 last @ 2024 (sim=0.100) | varphi, texttt, palindromes, geshkovski, mapsto, s
#     T 25 last @ 2024 (sim=0.300) | mathrm, mathbb, ast, ldots, ham, mathsf, rm, mm, f
#     T 26 last @ 2024 (sim=0.300) | tensor, kronecker, mathscr, product, rank, diverge
#     T 27 last @ 2024 (sim=0.400) | mathcal, mathbb, mathrm, operatorname, cc, governo
#     T 39 last @ 2024 (sim=0.000) | resetting, service, ashkin, xs, teller, slowdown,
#     T 43 last @ 2024 (sim=0.000) | domino, aztec, shin, tilings, diagonally, schur, n
#     T 46 last @ 2024 (sim=0.400) | mathbb, overline, mathcal, ldots, underline, li, x
#
#   🔗 MERGE GROUPS: 5 events
#   Top 10 merges (most sources):
#     T 31 @ 2020 ← [31, 34, 37, 46] (sims=[0.7, 0.5, 0.5, 0.5]) | mathbb, frac, infty, leq, mathcal, ldots
#     T 31 @ 2018 ← [31, 37, 46] (sims=[0.7, 0.5, 0.5]) | mathbb, mathcal, frac, leq, geq, infty,
#     T 31 @ 2021 ← [23, 31, 46] (sims=[0.5, 0.7, 0.5]) | mathbb, frac, geq, leq, dots, ldots, inf
#     T 31 @ 2022 ← [31, 37] (sims=[0.8, 0.5]) | mathbb, frac, mathcal, leq, text, dots,
#     T 34 @ 2024 ← [31, 34] (sims=[0.7, 0.6]) | mathbb, frac, vert, mathcal, langle, leq
#
#   🆕 NEW TOPICS: 597 events
#   Per year:
#     2001: 47 new topics
#     2002: 47 new topics
#     2003: 44 new topics
#     2004: 40 new topics
#     2005: 36 new topics
#     2006: 32 new topics
#     2007: 33 new topics
#     2008: 31 new topics
#     2009: 32 new topics
#     2010: 29 new topics
#     2011: 25 new topics
#     2012: 23 new topics
#     2013: 21 new topics
#     2014: 18 new topics
#     2015: 17 new topics
#     2016: 15 new topics
#     2017: 13 new topics
#     2018: 16 new topics
#     2019: 11 new topics
#     2020: 14 new topics
#     2021: 13 new topics
#     2022: 12 new topics
#     2023: 10 new topics
#     2024: 10 new topics
#     2025: 8 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 12 | 100% stable (25S 0M 0D)
#     T  0 | 92% stable (23S 0M 2D)
#     T  4 | 92% stable (23S 0M 2D)
#     T  7 | 88% stable (22S 0M 3D)
#     T  6 | 88% stable (22S 0M 3D)
#   Top 5 most unstable:
#     T 25 | 0% stable (0S 0M 25D)
#     T 27 | 0% stable (0S 0M 23D)
#     T 26 | 0% stable (0S 0M 21D)
#     T 39 | 0% stable (0S 0M 25D)
#     T 43 | 0% stable (0S 0M 25D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (LDA)
# ======================================================================
#
#   📉 DISAPPEARED: 606 events
#   Per year:
#     2000: 47 topics
#     2001: 48 topics
#     2002: 48 topics
#     2003: 45 topics
#     2004: 42 topics
#     2005: 35 topics
#     2006: 37 topics
#     2007: 33 topics
#     2008: 35 topics
#     2009: 32 topics
#     2010: 28 topics
#     2011: 19 topics
#     2012: 19 topics
#     2013: 19 topics
#     2014: 17 topics
#     2015: 17 topics
#     2016: 11 topics
#     2017: 10 topics
#     2018: 10 topics
#     2019: 10 topics
#     2020: 8 topics
#     2021: 6 topics
#     2022: 11 topics
#     2023: 8 topics
#     2024: 11 topics
#
#   Permanently gone: 11
#     T  4 last @ 2024 (sim=0.400) | text, mixtures, temperature, liquid, alkanone, ami
#     T 11 last @ 2024 (sim=0.300) | solar, earth, mars, satellite, wind, data, planets
#     T 15 last @ 2024 (sim=0.300) | spin, momentum, orbital, cfb, angular, zr, algebra
#     T 17 last @ 2024 (sim=0.200) | phase, transition, order, quantum, transitions, ca
#     T 20 last @ 2024 (sim=0.300) | dna, protein, proteins, rna, amino, molecular, dyn
#     T 21 last @ 2024 (sim=0.100) | na, 300k, rm, langle, rangle, lectromagn, ondes, d
#     T 22 last @ 2024 (sim=0.200) | polymer, dynamics, chains, translocation, friction
#     T 37 last @ 2024 (sim=0.300) | urban, traffic, cities, resilience, pavements, dat
#     T 41 last @ 2024 (sim=0.400) | text, mathcal, mathrm, vec, frac, le, mathit, vert
#     T 43 last @ 2024 (sim=0.400) | field, acceleration, momentum, relativistic, relat
#     ... +1 more
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 608 events
#   Per year:
#     2001: 49 new topics
#     2002: 47 new topics
#     2003: 49 new topics
#     2004: 44 new topics
#     2005: 42 new topics
#     2006: 35 new topics
#     2007: 37 new topics
#     2008: 34 new topics
#     2009: 35 new topics
#     2010: 32 new topics
#     2011: 28 new topics
#     2012: 19 new topics
#     2013: 19 new topics
#     2014: 19 new topics
#     2015: 17 new topics
#     2016: 17 new topics
#     2017: 11 new topics
#     2018: 10 new topics
#     2019: 10 new topics
#     2020: 10 new topics
#     2021: 8 new topics
#     2022: 6 new topics
#     2023: 11 new topics
#     2024: 8 new topics
#     2025: 11 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  8 | 96% stable (24S 0M 1D)
#     T 10 | 88% stable (22S 0M 3D)
#     T 28 | 88% stable (22S 0M 3D)
#     T 18 | 84% stable (21S 0M 4D)
#     T 19 | 84% stable (21S 0M 4D)
#   Top 5 most unstable:
#     T 41 | 12% stable (3S 0M 22D)
#     T  4 | 0% stable (0S 0M 25D)
#     T 22 | 0% stable (0S 0M 25D)
#     T 21 | 0% stable (0S 0M 23D)
#     T 49 | 0% stable (0S 0M 25D)
