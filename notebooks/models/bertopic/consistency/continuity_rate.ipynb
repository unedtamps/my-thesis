# %% [markdown]
# # BERTopic: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/bertopic/temporal")
RESULT_DIR = Path("../../../../results/bertopic/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/bertopic/temporal
# Saving to: ../../../../results/bertopic/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for i, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for j, tid_t1 in enumerate(topics_t1):
                words_t1 = topic_words.get((t_next, tid_t1), [])
                sim_matrix[i, j] = rbo(words_t, words_t1, p=0.9)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (BERTopic)
# ======================================================================
#   2000→2001: Stable=2 (4%)  Merge=0 (0%)  Disappear=45 (96%)  New=61
#   2001→2002: Stable=3 (5%)  Merge=0 (0%)  Disappear=60 (95%)  New=62
#   2002→2003: Stable=2 (3%)  Merge=0 (0%)  Disappear=63 (97%)  New=72
#   2003→2004: Stable=1 (1%)  Merge=0 (0%)  Disappear=73 (99%)  New=94
#   2004→2005: Stable=0 (0%)  Merge=0 (0%)  Disappear=95 (100%)  New=87
#   2005→2006: Stable=2 (2%)  Merge=0 (0%)  Disappear=85 (98%)  New=86
#   2006→2007: Stable=4 (5%)  Merge=0 (0%)  Disappear=84 (95%)  New=78
#   2007→2008: Stable=4 (5%)  Merge=0 (0%)  Disappear=78 (95%)  New=96
#   2008→2009: Stable=2 (2%)  Merge=0 (0%)  Disappear=98 (98%)  New=106
#   2009→2010: Stable=2 (2%)  Merge=0 (0%)  Disappear=106 (98%)  New=124
#   2010→2011: Stable=3 (2%)  Merge=0 (0%)  Disappear=123 (98%)  New=141
#   2011→2012: Stable=10 (7%)  Merge=0 (0%)  Disappear=134 (93%)  New=151
#   2012→2013: Stable=13 (8%)  Merge=0 (0%)  Disappear=148 (92%)  New=165
#   2013→2014: Stable=15 (8%)  Merge=0 (0%)  Disappear=163 (92%)  New=170
#   2014→2015: Stable=16 (9%)  Merge=0 (0%)  Disappear=169 (91%)  New=182
#   2015→2016: Stable=23 (12%)  Merge=0 (0%)  Disappear=175 (88%)  New=202
#   2016→2017: Stable=27 (12%)  Merge=0 (0%)  Disappear=198 (88%)  New=212
#   2017→2018: Stable=51 (21%)  Merge=0 (0%)  Disappear=188 (79%)  New=200
#   2018→2019: Stable=72 (29%)  Merge=0 (0%)  Disappear=179 (71%)  New=183
#   2019→2020: Stable=101 (40%)  Merge=0 (0%)  Disappear=154 (60%)  New=156
#   2020→2021: Stable=135 (53%)  Merge=2 (1%)  Disappear=120 (47%)  New=122
#   2021→2022: Stable=138 (53%)  Merge=4 (2%)  Disappear=116 (45%)  New=120
#   2022→2023: Stable=139 (53%)  Merge=2 (1%)  Disappear=119 (46%)  New=121
#   2023→2024: Stable=166 (64%)  Merge=2 (1%)  Disappear=93 (36%)  New=94
#   2024→2025: Stable=183 (70%)  Merge=4 (2%)  Disappear=74 (28%)  New=75
#
#   Overall: Stable=18.8%  Merge=0.2%  Disappear=81.0%  New=3160
#   Saved: ../../../../results/bertopic/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (BERTopic)
# ======================================================================
#   2000→2001: Stable=3 (3%)  Merge=0 (0%)  Disappear=89 (97%)  New=98
#   2001→2002: Stable=0 (0%)  Merge=0 (0%)  Disappear=101 (100%)  New=90
#   2002→2003: Stable=3 (3%)  Merge=0 (0%)  Disappear=87 (97%)  New=112
#   2003→2004: Stable=1 (1%)  Merge=0 (0%)  Disappear=114 (99%)  New=117
#   2004→2005: Stable=4 (3%)  Merge=0 (0%)  Disappear=114 (97%)  New=117
#   2005→2006: Stable=6 (5%)  Merge=0 (0%)  Disappear=115 (95%)  New=127
#   2006→2007: Stable=12 (9%)  Merge=0 (0%)  Disappear=121 (91%)  New=126
#   2007→2008: Stable=12 (9%)  Merge=0 (0%)  Disappear=126 (91%)  New=129
#   2008→2009: Stable=14 (10%)  Merge=0 (0%)  Disappear=127 (90%)  New=125
#   2009→2010: Stable=17 (12%)  Merge=0 (0%)  Disappear=122 (88%)  New=124
#   2010→2011: Stable=17 (12%)  Merge=0 (0%)  Disappear=124 (88%)  New=129
#   2011→2012: Stable=26 (18%)  Merge=0 (0%)  Disappear=120 (82%)  New=122
#   2012→2013: Stable=31 (21%)  Merge=0 (0%)  Disappear=117 (79%)  New=119
#   2013→2014: Stable=35 (23%)  Merge=0 (0%)  Disappear=115 (77%)  New=115
#   2014→2015: Stable=32 (21%)  Merge=2 (1%)  Disappear=116 (77%)  New=116
#   2015→2016: Stable=39 (26%)  Merge=2 (1%)  Disappear=108 (72%)  New=110
#   2016→2017: Stable=41 (27%)  Merge=0 (0%)  Disappear=109 (73%)  New=109
#   2017→2018: Stable=51 (34%)  Merge=0 (0%)  Disappear=99 (66%)  New=99
#   2018→2019: Stable=66 (44%)  Merge=0 (0%)  Disappear=84 (56%)  New=84
#   2019→2020: Stable=64 (43%)  Merge=0 (0%)  Disappear=86 (57%)  New=86
#   2020→2021: Stable=65 (43%)  Merge=0 (0%)  Disappear=85 (57%)  New=85
#   2021→2022: Stable=84 (56%)  Merge=0 (0%)  Disappear=66 (44%)  New=66
#   2022→2023: Stable=64 (43%)  Merge=0 (0%)  Disappear=86 (57%)  New=86
#   2023→2024: Stable=61 (41%)  Merge=0 (0%)  Disappear=89 (59%)  New=89
#   2024→2025: Stable=85 (57%)  Merge=0 (0%)  Disappear=65 (43%)  New=65
#
#   Overall: Stable=22.6%  Merge=0.1%  Disappear=77.3%  New=2645
#   Saved: ../../../../results/bertopic/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (BERTopic)
# ======================================================================
#   2000→2001: Stable=0 (0%)  Merge=0 (0%)  Disappear=108 (100%)  New=114
#   2001→2002: Stable=3 (3%)  Merge=0 (0%)  Disappear=111 (97%)  New=125
#   2002→2003: Stable=0 (0%)  Merge=0 (0%)  Disappear=128 (100%)  New=125
#   2003→2004: Stable=4 (3%)  Merge=0 (0%)  Disappear=121 (97%)  New=154
#   2004→2005: Stable=0 (0%)  Merge=0 (0%)  Disappear=158 (100%)  New=157
#   2005→2006: Stable=7 (4%)  Merge=0 (0%)  Disappear=150 (96%)  New=167
#   2006→2007: Stable=7 (4%)  Merge=0 (0%)  Disappear=167 (96%)  New=175
#   2007→2008: Stable=10 (5%)  Merge=0 (0%)  Disappear=172 (95%)  New=181
#   2008→2009: Stable=11 (6%)  Merge=0 (0%)  Disappear=180 (94%)  New=185
#   2009→2010: Stable=14 (7%)  Merge=0 (0%)  Disappear=182 (93%)  New=195
#   2010→2011: Stable=23 (11%)  Merge=0 (0%)  Disappear=186 (89%)  New=196
#   2011→2012: Stable=22 (10%)  Merge=0 (0%)  Disappear=197 (90%)  New=201
#   2012→2013: Stable=41 (18%)  Merge=0 (0%)  Disappear=182 (82%)  New=181
#   2013→2014: Stable=46 (21%)  Merge=0 (0%)  Disappear=176 (79%)  New=175
#   2014→2015: Stable=49 (22%)  Merge=0 (0%)  Disappear=172 (78%)  New=175
#   2015→2016: Stable=52 (23%)  Merge=0 (0%)  Disappear=172 (77%)  New=176
#   2016→2017: Stable=56 (25%)  Merge=0 (0%)  Disappear=172 (75%)  New=175
#   2017→2018: Stable=59 (26%)  Merge=0 (0%)  Disappear=172 (74%)  New=172
#   2018→2019: Stable=60 (26%)  Merge=0 (0%)  Disappear=171 (74%)  New=172
#   2019→2020: Stable=65 (28%)  Merge=0 (0%)  Disappear=167 (72%)  New=166
#   2020→2021: Stable=83 (36%)  Merge=2 (1%)  Disappear=146 (63%)  New=148
#   2021→2022: Stable=74 (32%)  Merge=0 (0%)  Disappear=158 (68%)  New=158
#   2022→2023: Stable=72 (31%)  Merge=0 (0%)  Disappear=160 (69%)  New=159
#   2023→2024: Stable=78 (34%)  Merge=0 (0%)  Disappear=153 (66%)  New=153
#   2024→2025: Stable=87 (38%)  Merge=0 (0%)  Disappear=144 (62%)  New=145
#
#   Overall: Stable=16.5%  Merge=0.0%  Disappear=83.5%  New=4130
#   Saved: ../../../../results/bertopic/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 2940 events
#   Per year:
#     2000: 45 topics
#     2001: 60 topics
#     2002: 63 topics
#     2003: 73 topics
#     2004: 95 topics
#     2005: 85 topics
#     2006: 84 topics
#     2007: 78 topics
#     2008: 98 topics
#     2009: 106 topics
#     2010: 123 topics
#     2011: 134 topics
#     2012: 148 topics
#     2013: 163 topics
#     2014: 169 topics
#     2015: 175 topics
#     2016: 198 topics
#     2017: 188 topics
#     2018: 179 topics
#     2019: 154 topics
#     2020: 120 topics
#     2021: 116 topics
#     2022: 119 topics
#     2023: 93 topics
#     2024: 74 topics
#
#   Permanently gone: 75
#     T218 last @ 2023 (sim=0.182) | relays, coherence, channel, superposition, relay,
#     T  4 last @ 2024 (sim=0.422) | type, calculus, logics, logic, proof, sequent, sem
#     T 16 last @ 2024 (sim=0.448) | sar, species, remote, underwater, sensing, images,
#     T 35 last @ 2024 (sim=0.475) | scientific, papers, citation, journals, retracted,
#     T 36 last @ 2024 (sim=0.421) | polynomial, algebraic, bbb, functions, mathbb, ben
#     T 55 last @ 2024 (sim=0.438) | converse, coding, distortion, channel, rate, chann
#     T 56 last @ 2024 (sim=0.101) | octonion, sgm, qcs, sparse, amp, passing, signal,
#     T 71 last @ 2024 (sim=0.044) | fog, queue, p4, service, ndn, jsq, networking, flo
#     T 79 last @ 2024 (sim=0.448) | quadrotor, flight, aerial, control, quadrotors, pe
#     T 81 last @ 2024 (sim=0.461) | security, hardware, attacks, dram, ht, microarchit
#     ... +65 more
#
#   🔗 MERGE GROUPS: 7 events
#   Top 10 merges (most sources):
#     T 67 @ 2021 ← [67, 257] (sims=[0.8003, 0.5978]) | games, game, player, equilibria, nash, p
#     T  8 @ 2022 ← [8, 18] (sims=[0.9007, 0.6103]) | adversarial, robustness, attacks, attack
#     T 41 @ 2022 ← [41, 227] (sims=[0.6975, 0.5492]) | privacy, dp, private, differentially, di
#     T 10 @ 2023 ← [10, 149] (sims=[0.8352, 0.5608]) | speech, audio, speaker, sound, acoustic,
#     T  8 @ 2024 ← [8, 18] (sims=[0.7645, 0.6058]) | adversarial, attacks, robustness, attack
#     T 48 @ 2025 ← [48, 246] (sims=[0.7767, 0.5075]) | anomaly, detection, anomalies, ad, vad,
#     T 67 @ 2025 ← [67, 257] (sims=[0.7161, 0.5543]) | games, game, bf, nash, player, equilibri
#
#   🆕 NEW TOPICS: 3160 events
#   Per year:
#     2001: 61 new topics
#     2002: 62 new topics
#     2003: 72 new topics
#     2004: 94 new topics
#     2005: 87 new topics
#     2006: 86 new topics
#     2007: 78 new topics
#     2008: 96 new topics
#     2009: 106 new topics
#     2010: 124 new topics
#     2011: 141 new topics
#     2012: 151 new topics
#     2013: 165 new topics
#     2014: 170 new topics
#     2015: 182 new topics
#     2016: 202 new topics
#     2017: 212 new topics
#     2018: 200 new topics
#     2019: 183 new topics
#     2020: 156 new topics
#     2021: 122 new topics
#     2022: 120 new topics
#     2023: 121 new topics
#     2024: 94 new topics
#     2025: 75 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 74 | 100% stable (9S 0M 0D)
#     T182 | 86% stable (6S 0M 1D)
#     T 73 | 80% stable (8S 0M 2D)
#     T181 | 78% stable (7S 0M 2D)
#     T 70 | 75% stable (6S 0M 2D)
#   Top 5 most unstable:
#     T232 | 0% stable (0S 0M 21D)
#     T233 | 0% stable (0S 0M 23D)
#     T234 | 0% stable (0S 0M 9D)
#     T237 | 0% stable (0S 0M 13D)
#     T259 | 0% stable (0S 0M 18D)
#
#
# ======================================================================
# Analysis Review: MATH (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 2585 events
#   Per year:
#     2000: 89 topics
#     2001: 101 topics
#     2002: 87 topics
#     2003: 114 topics
#     2004: 114 topics
#     2005: 115 topics
#     2006: 121 topics
#     2007: 126 topics
#     2008: 127 topics
#     2009: 122 topics
#     2010: 124 topics
#     2011: 120 topics
#     2012: 117 topics
#     2013: 115 topics
#     2014: 116 topics
#     2015: 108 topics
#     2016: 109 topics
#     2017: 99 topics
#     2018: 84 topics
#     2019: 86 topics
#     2020: 85 topics
#     2021: 66 topics
#     2022: 86 topics
#     2023: 89 topics
#     2024: 65 topics
#
#   Permanently gone: 65
#     T  8 last @ 2024 (sim=0.473) | nabla, solutions, equation, regularity, begin, ell
#     T 15 last @ 2024 (sim=0.498) | operators, resolvent, operator, dinger, schr, spec
#     T 26 last @ 2024 (sim=0.409) | traffic, vehicle, charging, routing, demand, vehic
#     T 27 last @ 2024 (sim=0.479) | textsf, cluster, categories, algebras, mathcal, tr
#     T 28 last @ 2024 (sim=0.484) | codes, code, reed, varepsilon, list, bbb, decodabl
#     T 38 last @ 2024 (sim=0.267) | periodic, systems, bifurcation, differential, ddot
#     T 41 last @ 2024 (sim=0.303) | bmatrix, ij, rm, inequalities, leq, vdots, radius,
#     T 44 last @ 2024 (sim=0.366) | calabi, invariants, yau, mirror, vafa, superpotent
#     T 46 last @ 2024 (sim=0.301) | service, queueing, resetting, queues, server, netw
#     T 52 last @ 2024 (sim=0.453) | image, regularization, reconstruction, imaging, in
#     ... +55 more
#
#   🔗 MERGE GROUPS: 2 events
#   Top 10 merges (most sources):
#     T  4 @ 2015 ← [4, 72] (sims=[0.8415, 0.5075]) | groups, group, subgroups, subgroup, fini
#     T 62 @ 2016 ← [62, 94] (sims=[0.5462, 0.5364]) | game, games, pebble, tg, number, player,
#
#   🆕 NEW TOPICS: 2645 events
#   Per year:
#     2001: 98 new topics
#     2002: 90 new topics
#     2003: 112 new topics
#     2004: 117 new topics
#     2005: 117 new topics
#     2006: 127 new topics
#     2007: 126 new topics
#     2008: 129 new topics
#     2009: 125 new topics
#     2010: 124 new topics
#     2011: 129 new topics
#     2012: 122 new topics
#     2013: 119 new topics
#     2014: 115 new topics
#     2015: 116 new topics
#     2016: 110 new topics
#     2017: 109 new topics
#     2018: 99 new topics
#     2019: 84 new topics
#     2020: 86 new topics
#     2021: 85 new topics
#     2022: 66 new topics
#     2023: 86 new topics
#     2024: 89 new topics
#     2025: 65 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 18 | 77% stable (17S 0M 5D)
#     T  4 | 76% stable (19S 1M 5D)
#     T 10 | 76% stable (19S 0M 6D)
#     T  3 | 76% stable (19S 0M 6D)
#     T  0 | 72% stable (18S 0M 7D)
#   Top 5 most unstable:
#     T137 | 0% stable (0S 0M 25D)
#     T138 | 0% stable (0S 0M 25D)
#     T142 | 0% stable (0S 0M 25D)
#     T144 | 0% stable (0S 0M 25D)
#     T146 | 0% stable (0S 0M 25D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 4005 events
#   Per year:
#     2000: 108 topics
#     2001: 111 topics
#     2002: 128 topics
#     2003: 121 topics
#     2004: 158 topics
#     2005: 150 topics
#     2006: 167 topics
#     2007: 172 topics
#     2008: 180 topics
#     2009: 182 topics
#     2010: 186 topics
#     2011: 197 topics
#     2012: 182 topics
#     2013: 176 topics
#     2014: 172 topics
#     2015: 172 topics
#     2016: 172 topics
#     2017: 172 topics
#     2018: 171 topics
#     2019: 167 topics
#     2020: 146 topics
#     2021: 158 topics
#     2022: 160 topics
#     2023: 153 topics
#     2024: 144 topics
#
#   Permanently gone: 144
#     T  6 last @ 2024 (sim=0.413) | crack, fracture, fatigue, materials, stress, pore,
#     T  8 last @ 2024 (sim=0.417) | beam, emittance, luminosity, csr, collider, synchr
#     T 10 last @ 2024 (sim=0.266) | trade, economic, financial, countries, firms, regi
#     T 14 last @ 2024 (sim=0.496) | plasma, dust, ion, plasmas, waves, magnetized, cnl
#     T 15 last @ 2024 (sim=0.433) | dark, universe, matter, inflation, cosmological, o
#     T 19 last @ 2024 (sim=0.400) | scientific, scientists, ai, research, authorship,
#     T 21 last @ 2024 (sim=0.262) | hyperfine, 2s, e1, fm, nuclear, mathrm, isotope, 2
#     T 26 last @ 2024 (sim=0.267) | vec, four, electromagnetic, momentum, vector, maxw
#     T 28 last @ 2024 (sim=0.485) | reaction, stochastic, autocatalytic, diffusion, re
#     T 29 last @ 2024 (sim=0.433) | mhd, magnetic, dynamo, magnetohydrodynamics, turbu
#     ... +134 more
#
#   🔗 MERGE GROUPS: 1 events
#   Top 10 merges (most sources):
#     T159 @ 2021 ← [159, 173] (sims=[0.5079, 0.5374]) | ct, reconstruction, image, breast, atten
#
#   🆕 NEW TOPICS: 4130 events
#   Per year:
#     2001: 114 new topics
#     2002: 125 new topics
#     2003: 125 new topics
#     2004: 154 new topics
#     2005: 157 new topics
#     2006: 167 new topics
#     2007: 175 new topics
#     2008: 181 new topics
#     2009: 185 new topics
#     2010: 195 new topics
#     2011: 196 new topics
#     2012: 201 new topics
#     2013: 181 new topics
#     2014: 175 new topics
#     2015: 175 new topics
#     2016: 176 new topics
#     2017: 175 new topics
#     2018: 172 new topics
#     2019: 172 new topics
#     2020: 166 new topics
#     2021: 148 new topics
#     2022: 158 new topics
#     2023: 159 new topics
#     2024: 153 new topics
#     2025: 145 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 35 | 82% stable (14S 0M 3D)
#     T170 | 75% stable (6S 0M 2D)
#     T131 | 73% stable (11S 0M 4D)
#     T 14 | 72% stable (18S 0M 7D)
#     T 32 | 70% stable (16S 0M 7D)
#   Top 5 most unstable:
#     T224 | 0% stable (0S 0M 15D)
#     T226 | 0% stable (0S 0M 20D)
#     T229 | 0% stable (0S 0M 20D)
#     T230 | 0% stable (0S 0M 20D)
#     T231 | 0% stable (0S 0M 17D)
