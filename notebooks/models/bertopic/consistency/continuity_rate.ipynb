# %% [markdown]
# # BERTopic: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment with mismatch detection.
#
# | Priority | Category | Condition |
# |----------|----------|-----------|
# | 1 | **Disappear** | sim ≤ 0.2 |
# | 2 | **Merge** | sim > 0.2, and the t+1-topic has >1 source |
# | 3 | **Mismatch** | sim > 0.2, single source, best-match ID ≠ own topic ID |
# | 4 | **Stable** | sim > 0.6, best-match ID = own topic ID |
# | 5 | **Evolve** | 0.2 < sim ≤ 0.6, best-match ID = own topic ID |
# | — | **New** | t+1-topic has no incoming source with sim > 0.2 |
#
#
# From t-side: Disappear + Merge + Mismatch + Stable + Evolve = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/bertopic/temporal")
RESULT_DIR = Path("../../../../results/bertopic/consistency")
THRESHOLD_DISAPPEAR = 0.2  # sim <= 0.2 → disappear
THRESHOLD_STABLE    = 0.6  # sim > 0.5  → stable (if same ID)

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold Disappear : sim <= {THRESHOLD_DISAPPEAR}")
print(f"Threshold Stable    : sim > {THRESHOLD_STABLE}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold Disappear : sim <= 0.2
# Threshold Stable    : sim > 0.6
# Reading from: ../../../../results/bertopic/temporal
# Saving to: ../../../../results/bertopic/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n'======================================================================'")
    print(f"Continuity Rate: {subject.upper()} (BERTopic)")
    print(f"'======================================================================'")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t  = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        # Build full RBO similarity matrix (t → t+1)
        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for ii, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for jj, tid_t1 in enumerate(topics_t1):
                words_t1_tmp = topic_words.get((t_next, tid_t1), [])
                sim_matrix[ii, jj] = rbo(words_t, words_t1_tmp, p=0.9)

        # ── Step 1: Each t-topic → its best t+1-topic ────────────────────────
        best_match_idx = np.argmax(sim_matrix, axis=1)
        best_match_sim = np.max(sim_matrix, axis=1)

        # ── Step 2: Count sources (sim > 0.2) per t+1-topic ──────────────────
        target_counts = Counter()
        for idx in range(len(topics_t)):
            if float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR:
                target_counts[topics_t1[best_match_idx[idx]]] += 1

        # merge_targets: t+1-topics claimed by >1 source with sim > 0.2
        merge_targets = {tgt for tgt, cnt in target_counts.items() if cnt > 1}

        # ── Step 3: Classify each t-topic ─────────────────────────────────────
        n_stable = n_evolve = n_merge = n_disappear = n_mismatch = 0

        for idx, tid in enumerate(topics_t):
            sim_val    = float(best_match_sim[idx])
            target_tid = topics_t1[best_match_idx[idx]]
            words_t    = ", ".join(topic_words.get((t, tid), []))

            # ── 1. DISAPPEAR: sim <= 0.2 ──────────────────────────────────────
            if sim_val <= THRESHOLD_DISAPPEAR:
                category = "disappear"
                n_disappear += 1

            # ── 2. MERGE: sim > 0.2 AND target has >1 source ─────────────────
            elif tid in merge_targets:
                tar_id = tid
                sources = [tid for idx, tid in enumerate(topics_t)
                       if topics_t1[best_match_idx[idx]] == tar_id
                       and float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR]
                if tid in sources:
                    category = "merge"
                    n_merge += 1
                else:
                    category = "mismatch"
                    n_merge += 1

            # ── 3. MISMATCH: sim > 0.2, single source, target ID ≠ own ID ────
            elif target_tid != tid:
                category   = "mismatch"
                n_mismatch += 1

            # ── 4. STABLE: sim > 0.5, target ID = own ID ─────────────────────
            elif sim_val > THRESHOLD_STABLE:
                category = "stable"
                n_stable += 1

            # ── 5. EVOLVE: 0.2 < sim <= 0.5, target ID = own ID ─────────────
            else:
                category = "evolve"
                n_evolve += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target_tid,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # ── Step 4: Record merge groups ────────────────────────────────────────
        for target_tid in merge_targets:
            sources = [tid for idx, tid in enumerate(topics_t)
                       if topics_t1[best_match_idx[idx]] == target_tid
                       and float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR]
            source_sims = [round(float(sim_matrix[topics_t.index(s),
                                                   topics_t1.index(target_tid)]), 4)
                           for s in sources]
            words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
            all_merge_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "target_topic": target_tid,
                "n_sources": len(sources),
                "source_topics": str(sources),
                "source_sims": str(source_sims),
                "target_words": words_t1,
            })

        # ── Step 5: New topics — no incoming source with sim > 0.2 ────────────
        matched_t1 = set(topics_t[idx]
                         for idx in range(len(topics_t))
                         if float(best_match_sim[idx]) > THRESHOLD_DISAPPEAR)
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t        = len(topics_t)
        n_new          = len(new_topics)
        n_merge_groups = len(merge_targets)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_evolve": n_evolve, "n_merge": n_merge,
            "n_mismatch": n_mismatch, "n_disappear": n_disappear,
            "n_merge_groups": n_merge_groups, "n_new": n_new,
            "pct_stable":    round(n_stable    / total_t * 100, 2),
            "pct_evolve":    round(n_evolve    / total_t * 100, 2),
            "pct_merge":     round(n_merge     / total_t * 100, 2),
            "pct_mismatch":  round(n_mismatch  / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Evolve={n_evolve} ({n_evolve/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Mismatch={n_mismatch} ({n_mismatch/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject,
        "threshold_disappear": THRESHOLD_DISAPPEAR,
        "threshold_stable":    THRESHOLD_STABLE,
        "avg_pct_stable":    round(subj_sum["pct_stable"].mean(),    2),
        "avg_pct_evolve":    round(subj_sum["pct_evolve"].mean(),    2),
        "avg_pct_merge":     round(subj_sum["pct_merge"].mean(),     2),
        "avg_pct_mismatch":  round(subj_sum["pct_mismatch"].mean(),  2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new":          int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Evolve={overall['avg_pct_evolve']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Mismatch={overall['avg_pct_mismatch']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# '======================================================================'
# Continuity Rate: CS (BERTopic)
# '======================================================================'
#   2000→2001: Stable=1 (2%)  Evolve=7 (15%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear=39 (83%)  New=55
#   2001→2002: Stable=0 (0%)  Evolve=11 (17%)  Merge=0 (0%)  Mismatch=0 (0%)  Disappear
#   2016→2017: Stable=26 (11%)  Evolve=126 (55%)  Merge=8 (4%)  Mismatch=8 (4%)  Disappear=60 (26%)  New=63
#   2017→2018: Stable=29 (13%)  Evolve=120 (52%)  Merge=7 (3%)  Mismatch=9 (4%)  Disappear=66 (29%)  New=66
#   2018→2019: Stable=36 (16%)  Evolve=119 (52%)  Merge=10 (4%)  Mismatch=11 (5%)  Disappear=55 (24%)  New=56
#   2019→2020: Stable=39 (17%)  Evolve=128 (55%)  Merge=9 (4%)  Mismatch=10 (4%)  Disappear=46 (20%)  New=45
#   2020→2021: Stable=36 (16%)  Evolve=131 (57%)  Merge=11 (5%)  Mismatch=12 (5%)  Disappear=41 (18%)  New=42
#   2021→2022: Stable=38 (16%)  Evolve=124 (53%)  Merge=10 (4%)  Mismatch=12 (5%)  Disappear=48 (21%)  New=48
#   2022→2023: Stable=41 (18%)  Evolve=121 (52%)  Merge=10 (4%)  Mismatch=10 (4%)  Disappear=50 (22%)  New=49
#   2023→2024: Stable=43 (19%)  Evolve=126 (55%)  Merge=8 (3%)  Mismatch=10 (4%)  Disappear=44 (19%)  New=44
#   2024→2025: Stable=54 (23%)  Evolve=127 (55%)  Merge=8 (3%)  Mismatch=10 (4%)  Disappear=32 (14%)  New=33
#
#   Overall: Stable=7.9%  Evolve=40.9%  Merge=2.6%  Mismatch=3.8%  Disappear=44.8%  New=2136
#   Saved: ../../../../results/bertopic/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n'======================================================================'")
    print(f"Analysis Review: {subject.upper()} (BERTopic)")
    print(f"'======================================================================'")

    trans_df   = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df   = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path   = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df     = pd.read_csv(new_path)   if new_path.stat().st_size   > 10 else pd.DataFrame()
    evo_df     = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- MERGE ---
    merged = trans_df[trans_df["category"] == "merge"]
    print(f"\n  🔗 MERGE (sim > {THRESHOLD_DISAPPEAR}, >1 source): {len(merged)} events")
    if len(merge_df) > 0:
        print("  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(min(10, len(merge_df)), "n_sources").iterrows():
            w = str(r["target_words"])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- MISMATCH ---
    mismatch = trans_df[trans_df["category"] == "mismatch"]
    print(f"\n  ⚠️  MISMATCH (sim > {THRESHOLD_DISAPPEAR}, target ID ≠ own ID): {len(mismatch)} events")
    if len(mismatch) > 0:
        per_year = mismatch.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")
        print("  Sample (up to 5):")
        for _, r in mismatch.head(5).iterrows():
            print(f"    T{int(r['topic_id']):>3} @ {int(r['year_from'])}→{int(r['year_to'])} "
                  f"best→T{int(r['best_match_topic'])} (sim={r['best_match_sim']:.3f}) | {str(r['words'])[:50]}")

    # --- STABLE ---
    stable = trans_df[trans_df["category"] == "stable"]
    print(f"\n  🟢 STABLE (sim > {THRESHOLD_STABLE}, same ID): {len(stable)} events")
    if len(stable) > 0:
        per_year = stable.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

    # --- EVOLVE ---
    evolved = trans_df[trans_df["category"] == "evolve"]
    print(f"\n  🔄 EVOLVE ({THRESHOLD_DISAPPEAR} < sim <= {THRESHOLD_STABLE}, same ID): {len(evolved)} events")
    if len(evolved) > 0:
        per_year = evolved.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

    # --- DISAPPEAR ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED (sim <= {THRESHOLD_DISAPPEAR}): {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")
        perm = []
        for _, r in disappeared.iterrows():
            tid   = int(r["topic_id"])
            later = evo_df[(evo_df["topic_id"] == tid) & (evo_df["year"] > int(r["year_to"]))]
            if len(later) == 0:
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {str(r['words'])[:50]}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS (no incoming sim > {THRESHOLD_DISAPPEAR}): {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print("\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "evolve", "merge", "mismatch", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)
    print("  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev "
              f"{int(r.get('merge',0))}M {int(r.get('mismatch',0))}Mm {int(r.get('disappear',0))}D)")
    print("  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev "
              f"{int(r.get('merge',0))}M {int(r.get('mismatch',0))}Mm {int(r.get('disappear',0))}D)")
    print()
# Out:
# '======================================================================'
# Analysis Review: CS (BERTopic)
# '======================================================================'
#
#   🔗 MERGE (sim > 0.2, >1 source): 97 events
#   Top 10 merges (most sources):
#     T 25 @ 2008 ← [25, 109, 243] (sims=[0.4568, 0.3686, 0.309]) | codes, trapping, kloosterman, decoding,
#     T 41 @ 2019 ← [41, 226, 227] (sims=[0.6191, 0.2703, 0.4196]) | privacy, differential, private, differen
#     T170 @ 2020 ← [145, 170, 237] (sims=[0.2686, 0.5005, 0.2461]) | v2x, vehicle, vehicular, vehicles, dsrc,
#     T 41 @ 2022 ← [41, 226, 227] (sims=[0.6975, 0.2703, 0.5492]) | privacy, dp, private, differentially, di
#     T 67 @ 2023 ← [67, 102, 257] (sims=[0.7013, 0.4659, 0.451]) | games, game, player, nash, equilibria, e
#     T 41 @ 2024 ← [41, 226, 227] (sims=[0.8651, 0.2703, 0.4625]) | privacy, dp, private, differential, diff
#     T109 @ 2006 ← [25, 109] (sims=[0.4438, 0.7258]) | codes, ldpc, decoding, turbo, bounds, st
#     T103 @ 2009 ← [103, 209] (sims=[0.3198, 0.2049]) | routing, hoc, ad, sensor, olsr, energy,
#     T 56 @ 2012 ← [56, 201] (sims=[0.3821, 0.2703]) | recovery, dbf, ell, omp, sparse, fbf, is
#     T150 @ 2012 ← [150, 245] (sims=[0.3633, 0.2703]) | scheduling, jobs, makespan, energy, spee
#
#   ⚠️  MISMATCH (sim > 0.2, target ID ≠ own ID): 133 events
#   Per year:
#     2002: 2 topics
#     2004: 2 topics
#     2005: 1 topics
#     2007: 3 topics
#     2008: 1 topics
#     2010: 1 topics
#     2011: 6 topics
#     2012: 5 topics
#     2013: 7 topics
#     2014: 8 topics
#     2015: 12 topics
#     2016: 9 topics
#     2017: 9 topics
#     2018: 10 topics
#     2019: 10 topics
#     2020: 15 topics
#     2021: 12 topics
#     2022: 8 topics
#     2023: 8 topics
#     2024: 4 topics
#   Sample (up to 5):
#     T 67 @ 2002→2003 best→T102 (sim=0.224) | game, nash, player, valuation, equilibrium, equili
#     T212 @ 2002→2003 best→T83 (sim=0.209) | finitely, word, gg, group, braid, case, average, c
#     T 34 @ 2004→2005 best→T174 (sim=0.270) | engagement, hmm, emotional, callfriend, svm, state
#     T 67 @ 2004→2005 best→T257 (sim=0.205) | chaotic, parrondo, 2x2, switching, games, proofs,
#     T 25 @ 2005→2006 best→T109 (sim=0.444) | codes, stopping, redundancy, parity, mds, check, r
#
#   🟢 STABLE (sim > 0.6, same ID): 669 events
#   Per year:
#     2000: 1 topics
#     2002: 2 topics
#     2006: 1 topics
#     2011: 3 topics
#     2012: 4 topics
#     2013: 3 topics
#     2014: 8 topics
#     2015: 8 topics
#     2016: 12 topics
#     2017: 27 topics
#     2018: 44 topics
#     2019: 57 topics
#     2020: 78 topics
#     2021: 83 topics
#     2022: 95 topics
#     2023: 111 topics
#     2024: 132 topics
#
#   🔄 EVOLVE (0.2 < sim <= 0.6, same ID): 1607 events
#   Per year:
#     2000: 7 topics
#     2001: 11 topics
#     2002: 7 topics
#     2003: 12 topics
#     2004: 18 topics
#     2005: 14 topics
#     2006: 15 topics
#     2007: 19 topics
#     2008: 19 topics
#     2009: 33 topics
#     2010: 32 topics
#     2011: 43 topics
#     2012: 57 topics
#     2013: 66 topics
#     2014: 65 topics
#     2015: 72 topics
#     2016: 99 topics
#     2017: 119 topics
#     2018: 131 topics
#     2019: 149 topics
#     2020: 127 topics
#     2021: 135 topics
#     2022: 129 topics
#     2023: 120 topics
#     2024: 108 topics
#
#   📉 DISAPPEARED (sim <= 0.2): 1562 events
#   Per year:
#     2000: 39 topics
#     2001: 52 topics
#     2002: 54 topics
#     2003: 62 topics
#     2004: 75 topics
#     2005: 71 topics
#     2006: 72 topics
#     2007: 59 topics
#     2008: 79 topics
#     2009: 75 topics
#     2010: 93 topics
#     2011: 90 topics
#     2012: 92 topics
#     2013: 98 topics
#     2014: 100 topics
#     2015: 99 topics
#     2016: 98 topics
#     2017: 76 topics
#     2018: 58 topics
#     2019: 30 topics
#     2020: 22 topics
#     2021: 19 topics
#     2022: 21 topics
#     2023: 15 topics
#     2024: 13 topics
#
#   Permanently gone: 14
#     T218 last @ 2023 (sim=0.182) | relays, coherence, channel, superposition, relay,
#     T 56 last @ 2024 (sim=0.101) | octonion, sgm, qcs, sparse, amp, passing, signal,
#     T 71 last @ 2024 (sim=0.044) | fog, queue, p4, service, ndn, jsq, networking, flo
#     T103 last @ 2024 (sim=0.067) | synchronization, wireless, gateway, aco, adhoc, se
#     T106 last @ 2024 (sim=0.147) | perp, 10mu, mkern, mathrel, entropy, information,
#     T135 last @ 2024 (sim=0.125) | shootings, pandemic, disease, school, outbreaks, e
#     T204 last @ 2024 (sim=0.125) | dapp, incumbent, coverage, emfe, cellular, spectru
#     T212 last @ 2024 (sim=0.088) | lyndon, aperiodic, ww, icfl, parikh, factorization
#     T217 last @ 2024 (sim=0.098) | wpts, coils, coil, power, meter, litz, transfer, m
#     T218 last @ 2024 (sim=0.080) | sf, relaying, cooperative, communications, 6g, for
#     ... +4 more
#
#   🆕 NEW TOPICS (no incoming sim > 0.2): 1787 events
#   Per year:
#     2001: 55 new topics
#     2002: 54 new topics
#     2003: 63 new topics
#     2004: 83 new topics
#     2005: 68 new topics
#     2006: 72 new topics
#     2007: 66 new topics
#     2008: 78 new topics
#     2009: 87 new topics
#     2010: 93 new topics
#     2011: 111 new topics
#     2012: 109 new topics
#     2013: 112 new topics
#     2014: 106 new topics
#     2015: 114 new topics
#     2016: 126 new topics
#     2017: 114 new topics
#     2018: 88 new topics
#     2019: 62 new topics
#     2020: 32 new topics
#     2021: 24 new topics
#     2022: 21 new topics
#     2023: 22 new topics
#     2024: 15 new topics
#     2025: 12 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T182 | 86% stable (6S 0Ev 0M 0Mm 1D)
#     T 73 | 80% stable (8S 2Ev 0M 0Mm 0D)
#     T 74 | 78% stable (7S 1Ev 1M 0Mm 0D)
#     T 70 | 75% stable (6S 0Ev 0M 0Mm 2D)
#     T115 | 75% stable (6S 1Ev 0M 0Mm 1D)
#   Top 5 most unstable:
#     T232 | 0% stable (0S 6Ev 0M 0Mm 15D)
#     T256 | 0% stable (0S 7Ev 0M 2Mm 2D)
#     T239 | 0% stable (0S 6Ev 0M 0Mm 3D)
#     T237 | 0% stable (0S 3Ev 0M 4Mm 6D)
#     T259 | 0% stable (0S 1Ev 0M 0Mm 17D)
#
#
# '======================================================================'
# Analysis Review: MATH (BERTopic)
# '======================================================================'
#
#   🔗 MERGE (sim > 0.2, >1 source): 82 events
#   Top 10 merges (most sources):
#     T 40 @ 2008 ← [40, 112, 119, 130] (sims=[0.5579, 0.2703, 0.3198, 0.376]) | lie, subalgebras, algebras, filiform, le
#     T  6 @ 2004 ← [6, 27, 40] (sims=[0.3914, 0.2703, 0.3956]) | algebras, unital, algebra, pi, tracial,
#     T 40 @ 2003 ← [6, 40] (sims=[0.3686, 0.3001]) | algebras, algebra, lie, xu, dynkin, cent
#     T 20 @ 2003 ← [9, 117] (sims=[0.2703, 0.2372]) | surfaces, umbilic, curvature, mean, line
#     T 20 @ 2004 ← [20, 117] (sims=[0.3924, 0.2703]) | curvature, minimal, surfaces, mean, surf
#     T  9 @ 2005 ← [9, 44] (sims=[0.4258, 0.2703]) | hilb, k3, bundles, moduli, curves, surfa
#     T 64 @ 2006 ← [64, 92] (sims=[0.3686, 0.2703]) | polynomials, orthogonal, 2n, circle, mat
#     T 33 @ 2006 ← [33, 127] (sims=[0.3527, 0.2211]) | category, operads, categories, operad, r
#     T 11 @ 2006 ← [11, 117] (sims=[0.412, 0.2731]) | ricci, manifolds, hler, manifold, hm, cu
#     T 80 @ 2007 ← [20, 80] (sims=[0.2053, 0.5374]) | flow, curvature, mean, hypersurface, evo
#
#   ⚠️  MISMATCH (sim > 0.2, target ID ≠ own ID): 109 events
#   Per year:
#     2000: 2 topics
#     2002: 4 topics
#     2003: 3 topics
#     2004: 2 topics
#     2005: 4 topics
#     2006: 4 topics
#     2007: 12 topics
#     2008: 4 topics
#     2009: 4 topics
#     2010: 4 topics
#     2011: 5 topics
#     2012: 7 topics
#     2013: 4 topics
#     2014: 8 topics
#     2015: 6 topics
#     2016: 4 topics
#     2017: 7 topics
#     2018: 3 topics
#     2019: 2 topics
#     2020: 3 topics
#     2021: 4 topics
#     2022: 3 topics
#     2023: 5 topics
#     2024: 5 topics
#   Sample (up to 5):
#     T 20 @ 2000→2001 best→T9 (sim=0.270) | surfaces, willmore, sphere, conformal, quaternioni
#     T140 @ 2000→2001 best→T75 (sim=0.363) | steady, energy, states, state, droplet, periodic,
#     T  6 @ 2002→2003 best→T40 (sim=0.369) | algebras, ast, crossed, algebra, automorphisms, ba
#     T  9 @ 2002→2003 best→T20 (sim=0.270) | surfaces, birational, degree, kodaira, fibration,
#     T 13 @ 2002→2003 best→T111 (sim=0.220) | dispersive, devries, equations, representation, ev
#
#   🟢 STABLE (sim > 0.6, same ID): 401 events
#   Per year:
#     2004: 1 topics
#     2005: 1 topics
#     2006: 4 topics
#     2007: 5 topics
#     2008: 3 topics
#     2009: 8 topics
#     2010: 7 topics
#     2011: 14 topics
#     2012: 15 topics
#     2013: 11 topics
#     2014: 15 topics
#     2015: 16 topics
#     2016: 24 topics
#     2017: 26 topics
#     2018: 25 topics
#     2019: 35 topics
#     2020: 31 topics
#     2021: 39 topics
#     2022: 33 topics
#     2023: 40 topics
#     2024: 48 topics
#
#   🔄 EVOLVE (0.2 < sim <= 0.6, same ID): 1763 events
#   Per year:
#     2000: 20 topics
#     2001: 27 topics
#     2002: 23 topics
#     2003: 30 topics
#     2004: 39 topics
#     2005: 53 topics
#     2006: 49 topics
#     2007: 51 topics
#     2008: 62 topics
#     2009: 54 topics
#     2010: 75 topics
#     2011: 67 topics
#     2012: 77 topics
#     2013: 96 topics
#     2014: 95 topics
#     2015: 98 topics
#     2016: 99 topics
#     2017: 94 topics
#     2018: 101 topics
#     2019: 95 topics
#     2020: 93 topics
#     2021: 94 topics
#     2022: 97 topics
#     2023: 87 topics
#     2024: 87 topics
#
#   📉 DISAPPEARED (sim <= 0.2): 1067 events
#   Per year:
#     2000: 70 topics
#     2001: 74 topics
#     2002: 62 topics
#     2003: 80 topics
#     2004: 75 topics
#     2005: 60 topics
#     2006: 73 topics
#     2007: 64 topics
#     2008: 68 topics
#     2009: 71 topics
#     2010: 52 topics
#     2011: 56 topics
#     2012: 44 topics
#     2013: 35 topics
#     2014: 25 topics
#     2015: 25 topics
#     2016: 20 topics
#     2017: 17 topics
#     2018: 18 topics
#     2019: 16 topics
#     2020: 20 topics
#     2021: 10 topics
#     2022: 14 topics
#     2023: 13 topics
#     2024: 5 topics
#
#   Permanently gone: 5
#     T 97 last @ 2024 (sim=0.155) | smectic, thin, defects, liquid, ericksen, leslie,
#     T127 last @ 2024 (sim=0.191) | reflexive, tdd, monadicity, categorical, categorie
#     T133 last @ 2024 (sim=0.170) | nonholonomic, hamilton, lepage, bracket, lagrangia
#     T137 last @ 2024 (sim=0.098) | rm, nijenhuis, inftya, hochschild, homotopy, algeb
#     T144 last @ 2024 (sim=0.170) | spin, baxterization, parametrising, graphical, dyn
#
#   🆕 NEW TOPICS (no incoming sim > 0.2): 1127 events
#   Per year:
#     2001: 79 new topics
#     2002: 63 new topics
#     2003: 87 new topics
#     2004: 83 new topics
#     2005: 78 new topics
#     2006: 73 new topics
#     2007: 79 new topics
#     2008: 67 new topics
#     2009: 66 new topics
#     2010: 73 new topics
#     2011: 57 new topics
#     2012: 58 new topics
#     2013: 46 new topics
#     2014: 35 new topics
#     2015: 24 new topics
#     2016: 26 new topics
#     2017: 20 new topics
#     2018: 17 new topics
#     2019: 18 new topics
#     2020: 16 new topics
#     2021: 20 new topics
#     2022: 10 new topics
#     2023: 14 new topics
#     2024: 13 new topics
#     2025: 5 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  0 | 60% stable (15S 7Ev 0M 0Mm 3D)
#     T 10 | 60% stable (15S 8Ev 0M 0Mm 2D)
#     T 19 | 58% stable (11S 3Ev 1M 0Mm 4D)
#     T 25 | 56% stable (14S 7Ev 0M 0Mm 4D)
#     T  1 | 52% stable (13S 7Ev 2M 0Mm 3D)
#   Top 5 most unstable:
#     T142 | 0% stable (0S 13Ev 1M 1Mm 10D)
#     T145 | 0% stable (0S 16Ev 0M 0Mm 9D)
#     T144 | 0% stable (0S 7Ev 0M 2Mm 16D)
#     T146 | 0% stable (0S 17Ev 0M 0Mm 8D)
#     T148 | 0% stable (0S 18Ev 2M 0Mm 4D)
#
#
# '======================================================================'
# Analysis Review: PHYSICS (BERTopic)
# '======================================================================'
#
#   🔗 MERGE (sim > 0.2, >1 source): 138 events
#   Top 10 merges (most sources):
#     T121 @ 2025 ← [121, 180, 187, 197] (sims=[0.3372, 0.2703, 0.2198, 0.2703]) | text, positron, ps, annihilation, antihy
#     T 34 @ 2012 ← [34, 81, 225] (sims=[0.2703, 0.3372, 0.2703]) | graphene, edge, plasmon, bearded, plasmo
#     T 42 @ 2012 ← [42, 158, 220] (sims=[0.6725, 0.2703, 0.2703]) | solitons, soliton, nonlinear, lattices,
#     T 14 @ 2012 ← [14, 33, 209] (sims=[0.7246, 0.2703, 0.2053]) | plasma, dust, dusty, waves, plasmas, wav
#     T158 @ 2020 ← [158, 176, 184] (sims=[0.4841, 0.2703, 0.2703]) | fiber, supercontinuum, saturable, sweepi
#     T  9 @ 2021 ← [9, 149, 172] (sims=[0.6163, 0.276, 0.2703]) | students, physics, graduate, student, ed
#     T  0 @ 2022 ← [0, 125, 172] (sims=[0.8671, 0.2703, 0.2703]) | quantum, functional, density, orbitals,
#     T 72 @ 2001 ← [72, 82] (sims=[0.3769, 0.2703]) | relativity, morley, michelson, lorentz,
#     T 82 @ 2001 ← [64, 151] (sims=[0.2703, 0.2703]) | gravitational, zero, instantaneous, rela
#     T 99 @ 2001 ← [57, 99] (sims=[0.2198, 0.3138]) | dna, unzipping, sequence, rna, folding,
#
#   ⚠️  MISMATCH (sim > 0.2, target ID ≠ own ID): 194 events
#   Per year:
#     2000: 5 topics
#     2001: 4 topics
#     2002: 3 topics
#     2003: 4 topics
#     2004: 7 topics
#     2005: 3 topics
#     2006: 3 topics
#     2007: 8 topics
#     2008: 5 topics
#     2009: 3 topics
#     2010: 13 topics
#     2011: 11 topics
#     2012: 4 topics
#     2013: 10 topics
#     2014: 9 topics
#     2015: 10 topics
#     2016: 8 topics
#     2017: 9 topics
#     2018: 11 topics
#     2019: 10 topics
#     2020: 12 topics
#     2021: 12 topics
#     2022: 10 topics
#     2023: 10 topics
#     2024: 10 topics
#   Sample (up to 5):
#     T  0 @ 2000→2001 best→T212 (sim=0.296) | hcth, monte, carlo, mpw1k, methods, correlated, ce
#     T 57 @ 2000→2001 best→T99 (sim=0.220) | breaks, dna, strand, compound, dsbs, dsb, poisson,
#     T 64 @ 2000→2001 best→T82 (sim=0.270) | gravitational, concavo, bispherical, homogeneous,
#     T 82 @ 2000→2001 best→T72 (sim=0.270) | relativity, space, fractal, heckmann, quantized, n
#     T151 @ 2000→2001 best→T82 (sim=0.270) | gravitational, alfven, waves, bayesan, radiation,
#
#   🟢 STABLE (sim > 0.6, same ID): 448 events
#   Per year:
#     2001: 1 topics
#     2005: 2 topics
#     2006: 3 topics
#     2007: 5 topics
#     2008: 4 topics
#     2009: 7 topics
#     2010: 8 topics
#     2011: 10 topics
#     2012: 13 topics
#     2013: 20 topics
#     2014: 17 topics
#     2015: 16 topics
#     2016: 26 topics
#     2017: 29 topics
#     2018: 36 topics
#     2019: 39 topics
#     2020: 36 topics
#     2021: 38 topics
#     2022: 41 topics
#     2023: 43 topics
#     2024: 54 topics
#
#   🔄 EVOLVE (0.2 < sim <= 0.6, same ID): 2148 events
#   Per year:
#     2000: 23 topics
#     2001: 22 topics
#     2002: 20 topics
#     2003: 28 topics
#     2004: 30 topics
#     2005: 44 topics
#     2006: 56 topics
#     2007: 54 topics
#     2008: 57 topics
#     2009: 74 topics
#     2010: 80 topics
#     2011: 107 topics
#     2012: 107 topics
#     2013: 97 topics
#     2014: 112 topics
#     2015: 115 topics
#     2016: 126 topics
#     2017: 120 topics
#     2018: 119 topics
#     2019: 128 topics
#     2020: 131 topics
#     2021: 124 topics
#     2022: 121 topics
#     2023: 126 topics
#     2024: 127 topics
#
#   📉 DISAPPEARED (sim <= 0.2): 2002 events
#   Per year:
#     2000: 78 topics
#     2001: 87 topics
#     2002: 104 topics
#     2003: 93 topics
#     2004: 120 topics
#     2005: 106 topics
#     2006: 111 topics
#     2007: 112 topics
#     2008: 121 topics
#     2009: 112 topics
#     2010: 100 topics
#     2011: 84 topics
#     2012: 96 topics
#     2013: 86 topics
#     2014: 75 topics
#     2015: 75 topics
#     2016: 60 topics
#     2017: 66 topics
#     2018: 55 topics
#     2019: 46 topics
#     2020: 41 topics
#     2021: 48 topics
#     2022: 50 topics
#     2023: 44 topics
#     2024: 32 topics
#
#   Permanently gone: 32
#     T 39 last @ 2024 (sim=0.182) | community, networks, communities, membership, bipa
#     T 56 last @ 2024 (sim=0.080) | negative, brewster, refraction, veps, metamaterial
#     T 68 last @ 2024 (sim=0.125) | calendar, astronomical, eclipse, hipparchus, catal
#     T 70 last @ 2024 (sim=0.080) | rtimes, neq, action, mathcal, relativity, mechanic
#     T 72 last @ 2024 (sim=0.137) | relativity, bob, alice, morley, sitter, michelson,
#     T 77 last @ 2024 (sim=0.124) | su, mathbb, higgs, symmetry, group, boson, supersy
#     T 89 last @ 2024 (sim=0.099) | prey, predator, mbox, allee, population, alleles,
#     T106 last @ 2024 (sim=0.181) | lines, fe, sc, ii, transitions, xvii, levels, spec
#     T113 last @ 2024 (sim=0.165) | debris, trajectory, mission, vlbi, thrust, mars, c
#     T120 last @ 2024 (sim=0.057) | ski, resistance, roughness, snow, deer, bicycle, p
#     ... +22 more
#
#   🆕 NEW TOPICS (no incoming sim > 0.2): 2136 events
#   Per year:
#     2001: 85 new topics
#     2002: 103 new topics
#     2003: 101 new topics
#     2004: 126 new topics
#     2005: 120 new topics
#     2006: 124 new topics
#     2007: 120 new topics
#     2008: 121 new topics
#     2009: 127 new topics
#     2010: 125 new topics
#     2011: 111 new topics
#     2012: 90 new topics
#     2013: 95 new topics
#     2014: 85 new topics
#     2015: 78 new topics
#     2016: 79 new topics
#     2017: 63 new topics
#     2018: 66 new topics
#     2019: 56 new topics
#     2020: 45 new topics
#     2021: 42 new topics
#     2022: 48 new topics
#     2023: 49 new topics
#     2024: 44 new topics
#     2025: 33 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 35 | 71% stable (12S 4Ev 0M 0Mm 1D)
#     T 13 | 55% stable (11S 3Ev 0M 0Mm 6D)
#     T 44 | 52% stable (12S 5Ev 1M 0Mm 5D)
#     T170 | 50% stable (4S 3Ev 0M 0Mm 1D)
#     T 15 | 48% stable (12S 13Ev 0M 0Mm 0D)
#   Top 5 most unstable:
#     T227 | 0% stable (0S 5Ev 0M 0Mm 12D)
#     T228 | 0% stable (0S 13Ev 0M 0Mm 8D)
#     T229 | 0% stable (0S 9Ev 0M 0Mm 11D)
#     T230 | 0% stable (0S 10Ev 0M 2Mm 8D)
#     T231 | 0% stable (0S 4Ev 0M 0Mm 13D)
