# %% [markdown]
# # BERTopic: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/bertopic/temporal")
RESULT_DIR = Path("../../../../results/bertopic/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/bertopic/temporal
# Saving to: ../../../../results/bertopic/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def build_word_matrix(topic_ids, topic_words_dict, year, vocab_index):
    matrix = np.zeros((len(topic_ids), len(vocab_index)))
    for i, tid in enumerate(topic_ids):
        words = topic_words_dict.get((year, tid), [])
        for w in words:
            if w in vocab_index:
                matrix[i, vocab_index[w]] = 1.0
    return matrix

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_words = set()
    for words in topic_words.values():
        all_words.update(words)
    vocab_index = {w: i for i, w in enumerate(sorted(all_words))}

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        mat_t = build_word_matrix(topics_t, topic_words, t, vocab_index)
        mat_t1 = build_word_matrix(topics_t1, topic_words, t_next, vocab_index)
        sim_matrix = cosine_similarity(mat_t, mat_t1)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (BERTopic)
# ======================================================================
#   2000→2001: Stable=1 (2%)  Merge=0 (0%)  Disappear=46 (98%)  New=62
#   2001→2002: Stable=0 (0%)  Merge=0 (0%)  Disappear=63 (100%)  New=65
#   2002→2003: Stable=2 (3%)  Merge=0 (0%)  Disappear=63 (97%)  New=72
#   2003→2004: Stable=1 (1%)  Merge=0 (0%)  Disappear=73 (99%)  New=94
#   2004→2005: Stable=0 (0%)  Merge=0 (0%)  Disappear=95 (100%)  New=87
#   2005→2006: Stable=3 (3%)  Merge=0 (0%)  Disappear=84 (97%)  New=85
#   2006→2007: Stable=5 (6%)  Merge=0 (0%)  Disappear=83 (94%)  New=77
#   2007→2008: Stable=6 (7%)  Merge=0 (0%)  Disappear=76 (93%)  New=94
#   2008→2009: Stable=2 (2%)  Merge=0 (0%)  Disappear=98 (98%)  New=106
#   2009→2010: Stable=7 (6%)  Merge=0 (0%)  Disappear=101 (94%)  New=119
#   2010→2011: Stable=7 (6%)  Merge=0 (0%)  Disappear=119 (94%)  New=137
#   2011→2012: Stable=7 (5%)  Merge=2 (1%)  Disappear=135 (94%)  New=153
#   2012→2013: Stable=12 (7%)  Merge=2 (1%)  Disappear=147 (91%)  New=165
#   2013→2014: Stable=11 (6%)  Merge=0 (0%)  Disappear=167 (94%)  New=174
#   2014→2015: Stable=14 (8%)  Merge=0 (0%)  Disappear=171 (92%)  New=184
#   2015→2016: Stable=24 (12%)  Merge=0 (0%)  Disappear=174 (88%)  New=201
#   2016→2017: Stable=32 (14%)  Merge=0 (0%)  Disappear=193 (86%)  New=207
#   2017→2018: Stable=51 (21%)  Merge=0 (0%)  Disappear=188 (79%)  New=200
#   2018→2019: Stable=73 (29%)  Merge=0 (0%)  Disappear=178 (71%)  New=182
#   2019→2020: Stable=107 (42%)  Merge=2 (1%)  Disappear=146 (57%)  New=149
#   2020→2021: Stable=123 (48%)  Merge=2 (1%)  Disappear=132 (51%)  New=134
#   2021→2022: Stable=134 (52%)  Merge=4 (2%)  Disappear=120 (47%)  New=124
#   2022→2023: Stable=141 (54%)  Merge=0 (0%)  Disappear=119 (46%)  New=120
#   2023→2024: Stable=162 (62%)  Merge=2 (1%)  Disappear=97 (37%)  New=98
#   2024→2025: Stable=185 (71%)  Merge=4 (2%)  Disappear=72 (28%)  New=73
#
#   Overall: Stable=18.8%  Merge=0.3%  Disappear=80.9%  New=3162
#   Saved: ../../../../results/bertopic/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (BERTopic)
# ======================================================================
#   2000→2001: Stable=2 (2%)  Merge=0 (0%)  Disappear=90 (98%)  New=99
#   2001→2002: Stable=1 (1%)  Merge=0 (0%)  Disappear=100 (99%)  New=89
#   2002→2003: Stable=0 (0%)  Merge=0 (0%)  Disappear=90 (100%)  New=115
#   2003→2004: Stable=4 (3%)  Merge=0 (0%)  Disappear=111 (97%)  New=114
#   2004→2005: Stable=5 (4%)  Merge=0 (0%)  Disappear=113 (96%)  New=116
#   2005→2006: Stable=8 (7%)  Merge=0 (0%)  Disappear=113 (93%)  New=125
#   2006→2007: Stable=12 (9%)  Merge=0 (0%)  Disappear=121 (91%)  New=126
#   2007→2008: Stable=14 (10%)  Merge=0 (0%)  Disappear=124 (90%)  New=127
#   2008→2009: Stable=15 (11%)  Merge=0 (0%)  Disappear=126 (89%)  New=124
#   2009→2010: Stable=22 (16%)  Merge=0 (0%)  Disappear=117 (84%)  New=119
#   2010→2011: Stable=20 (14%)  Merge=0 (0%)  Disappear=121 (86%)  New=126
#   2011→2012: Stable=33 (23%)  Merge=0 (0%)  Disappear=113 (77%)  New=115
#   2012→2013: Stable=29 (20%)  Merge=0 (0%)  Disappear=119 (80%)  New=121
#   2013→2014: Stable=31 (21%)  Merge=0 (0%)  Disappear=119 (79%)  New=119
#   2014→2015: Stable=40 (27%)  Merge=0 (0%)  Disappear=110 (73%)  New=109
#   2015→2016: Stable=42 (28%)  Merge=0 (0%)  Disappear=107 (72%)  New=108
#   2016→2017: Stable=49 (33%)  Merge=0 (0%)  Disappear=101 (67%)  New=101
#   2017→2018: Stable=59 (39%)  Merge=0 (0%)  Disappear=91 (61%)  New=91
#   2018→2019: Stable=61 (41%)  Merge=0 (0%)  Disappear=89 (59%)  New=89
#   2019→2020: Stable=70 (47%)  Merge=0 (0%)  Disappear=80 (53%)  New=80
#   2020→2021: Stable=66 (44%)  Merge=0 (0%)  Disappear=84 (56%)  New=84
#   2021→2022: Stable=78 (52%)  Merge=2 (1%)  Disappear=70 (47%)  New=71
#   2022→2023: Stable=58 (39%)  Merge=0 (0%)  Disappear=92 (61%)  New=92
#   2023→2024: Stable=73 (49%)  Merge=0 (0%)  Disappear=77 (51%)  New=77
#   2024→2025: Stable=90 (60%)  Merge=0 (0%)  Disappear=60 (40%)  New=60
#
#   Overall: Stable=23.9%  Merge=0.1%  Disappear=76.0%  New=2597
#   Saved: ../../../../results/bertopic/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (BERTopic)
# ======================================================================
#   2000→2001: Stable=0 (0%)  Merge=0 (0%)  Disappear=108 (100%)  New=114
#   2001→2002: Stable=2 (2%)  Merge=0 (0%)  Disappear=112 (98%)  New=126
#   2002→2003: Stable=3 (2%)  Merge=0 (0%)  Disappear=125 (98%)  New=122
#   2003→2004: Stable=3 (2%)  Merge=0 (0%)  Disappear=122 (98%)  New=155
#   2004→2005: Stable=1 (1%)  Merge=0 (0%)  Disappear=157 (99%)  New=156
#   2005→2006: Stable=8 (5%)  Merge=0 (0%)  Disappear=149 (95%)  New=166
#   2006→2007: Stable=5 (3%)  Merge=0 (0%)  Disappear=169 (97%)  New=177
#   2007→2008: Stable=7 (4%)  Merge=0 (0%)  Disappear=175 (96%)  New=184
#   2008→2009: Stable=12 (6%)  Merge=0 (0%)  Disappear=179 (94%)  New=184
#   2009→2010: Stable=14 (7%)  Merge=0 (0%)  Disappear=182 (93%)  New=195
#   2010→2011: Stable=22 (11%)  Merge=0 (0%)  Disappear=187 (89%)  New=197
#   2011→2012: Stable=28 (13%)  Merge=0 (0%)  Disappear=191 (87%)  New=195
#   2012→2013: Stable=41 (18%)  Merge=0 (0%)  Disappear=182 (82%)  New=181
#   2013→2014: Stable=46 (21%)  Merge=0 (0%)  Disappear=176 (79%)  New=175
#   2014→2015: Stable=47 (21%)  Merge=0 (0%)  Disappear=174 (79%)  New=177
#   2015→2016: Stable=47 (21%)  Merge=2 (1%)  Disappear=175 (78%)  New=180
#   2016→2017: Stable=54 (24%)  Merge=2 (1%)  Disappear=172 (75%)  New=176
#   2017→2018: Stable=58 (25%)  Merge=0 (0%)  Disappear=173 (75%)  New=173
#   2018→2019: Stable=66 (29%)  Merge=0 (0%)  Disappear=165 (71%)  New=166
#   2019→2020: Stable=81 (35%)  Merge=3 (1%)  Disappear=148 (64%)  New=149
#   2020→2021: Stable=82 (35%)  Merge=0 (0%)  Disappear=149 (65%)  New=150
#   2021→2022: Stable=87 (38%)  Merge=0 (0%)  Disappear=145 (62%)  New=145
#   2022→2023: Stable=75 (32%)  Merge=0 (0%)  Disappear=157 (68%)  New=156
#   2023→2024: Stable=80 (35%)  Merge=0 (0%)  Disappear=151 (65%)  New=151
#   2024→2025: Stable=93 (40%)  Merge=2 (1%)  Disappear=136 (59%)  New=138
#
#   Overall: Stable=17.2%  Merge=0.2%  Disappear=82.7%  New=4088
#   Saved: ../../../../results/bertopic/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 2940 events
#   Per year:
#     2000: 46 topics
#     2001: 63 topics
#     2002: 63 topics
#     2003: 73 topics
#     2004: 95 topics
#     2005: 84 topics
#     2006: 83 topics
#     2007: 76 topics
#     2008: 98 topics
#     2009: 101 topics
#     2010: 119 topics
#     2011: 135 topics
#     2012: 147 topics
#     2013: 167 topics
#     2014: 171 topics
#     2015: 174 topics
#     2016: 193 topics
#     2017: 188 topics
#     2018: 178 topics
#     2019: 146 topics
#     2020: 132 topics
#     2021: 120 topics
#     2022: 119 topics
#     2023: 97 topics
#     2024: 72 topics
#
#   Permanently gone: 73
#     T218 last @ 2023 (sim=0.200) | relays, coherence, channel, superposition, relay,
#     T 13 last @ 2024 (sim=0.400) | mimo, channel, oam, afdm, otfs, downlink, massive,
#     T 56 last @ 2024 (sim=0.200) | octonion, sgm, qcs, sparse, amp, passing, signal,
#     T 71 last @ 2024 (sim=0.100) | fog, queue, p4, service, ndn, jsq, networking, flo
#     T 73 last @ 2024 (sim=0.400) | gans, gan, generative, adversarial, image, pcf, im
#     T 81 last @ 2024 (sim=0.400) | security, hardware, attacks, dram, ht, microarchit
#     T 82 last @ 2024 (sim=0.100) | kernel, tsvm, poly, varepsilon, cdot, bounds, svm,
#     T 83 last @ 2024 (sim=0.300) | automata, automaton, deterministic, ocns, pda, sst
#     T 84 last @ 2024 (sim=0.200) | encryption, cipher, cryptanalysis, longa, elliptic
#     T 91 last @ 2024 (sim=0.400) | depth, monocular, stereo, estimation, mvs, view, m
#     ... +63 more
#
#   🔗 MERGE GROUPS: 9 events
#   Top 10 merges (most sources):
#     T103 @ 2012 ← [103, 170] (sims=[0.5, 0.5]) | routing, sensor, energy, wireless, wsns,
#     T170 @ 2013 ← [170, 237] (sims=[0.5, 0.5]) | vehicular, vanet, aomdv, hoc, mobility,
#     T 12 @ 2020 ← [12, 187] (sims=[0.7, 0.6]) | driving, autonomous, traffic, vehicles,
#     T 67 @ 2021 ← [67, 257] (sims=[0.7, 0.6]) | games, game, player, equilibria, nash, p
#     T  8 @ 2022 ← [8, 18] (sims=[0.9, 0.5]) | adversarial, robustness, attacks, attack
#     T 41 @ 2022 ← [41, 227] (sims=[0.6, 0.5]) | privacy, dp, private, differentially, di
#     T 67 @ 2024 ← [67, 257] (sims=[0.7, 0.6]) | games, players, game, player, equilibriu
#     T 14 @ 2025 ← [14, 117] (sims=[0.7, 0.5]) | federated, fl, clients, client, heteroge
#     T 67 @ 2025 ← [67, 257] (sims=[0.7, 0.5]) | games, game, bf, nash, player, equilibri
#
#   🆕 NEW TOPICS: 3162 events
#   Per year:
#     2001: 62 new topics
#     2002: 65 new topics
#     2003: 72 new topics
#     2004: 94 new topics
#     2005: 87 new topics
#     2006: 85 new topics
#     2007: 77 new topics
#     2008: 94 new topics
#     2009: 106 new topics
#     2010: 119 new topics
#     2011: 137 new topics
#     2012: 153 new topics
#     2013: 165 new topics
#     2014: 174 new topics
#     2015: 184 new topics
#     2016: 201 new topics
#     2017: 207 new topics
#     2018: 200 new topics
#     2019: 182 new topics
#     2020: 149 new topics
#     2021: 134 new topics
#     2022: 124 new topics
#     2023: 120 new topics
#     2024: 98 new topics
#     2025: 73 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 74 | 89% stable (8S 0M 1D)
#     T251 | 83% stable (10S 0M 2D)
#     T154 | 80% stable (8S 0M 2D)
#     T 70 | 75% stable (6S 0M 2D)
#     T115 | 75% stable (6S 0M 2D)
#   Top 5 most unstable:
#     T231 | 0% stable (0S 0M 23D)
#     T226 | 0% stable (0S 0M 16D)
#     T237 | 0% stable (0S 1M 12D)
#     T256 | 0% stable (0S 0M 11D)
#     T259 | 0% stable (0S 0M 18D)
#
#
# ======================================================================
# Analysis Review: MATH (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 2538 events
#   Per year:
#     2000: 90 topics
#     2001: 100 topics
#     2002: 90 topics
#     2003: 111 topics
#     2004: 113 topics
#     2005: 113 topics
#     2006: 121 topics
#     2007: 124 topics
#     2008: 126 topics
#     2009: 117 topics
#     2010: 121 topics
#     2011: 113 topics
#     2012: 119 topics
#     2013: 119 topics
#     2014: 110 topics
#     2015: 107 topics
#     2016: 101 topics
#     2017: 91 topics
#     2018: 89 topics
#     2019: 80 topics
#     2020: 84 topics
#     2021: 70 topics
#     2022: 92 topics
#     2023: 77 topics
#     2024: 60 topics
#
#   Permanently gone: 60
#     T 23 last @ 2024 (sim=0.400) | banach, spaces, vert, lipschitz, space, metric, el
#     T 28 last @ 2024 (sim=0.300) | codes, code, reed, varepsilon, list, bbb, decodabl
#     T 38 last @ 2024 (sim=0.300) | periodic, systems, bifurcation, differential, ddot
#     T 41 last @ 2024 (sim=0.400) | bmatrix, ij, rm, inequalities, leq, vdots, radius,
#     T 46 last @ 2024 (sim=0.400) | service, queueing, resetting, queues, server, netw
#     T 51 last @ 2024 (sim=0.400) | numbers, lah, fibonacci, stirling, sequences, repd
#     T 55 last @ 2024 (sim=0.400) | operatorname, quantization, cc, mathcal, lie, grou
#     T 56 last @ 2024 (sim=0.400) | test, series, time, change, statistic, detection,
#     T 57 last @ 2024 (sim=0.400) | zeta, riemann, log, function, frac, dirichlet, val
#     T 60 last @ 2024 (sim=0.400) | frames, transform, coorbit, wavelet, fourier, fram
#     ... +50 more
#
#   🔗 MERGE GROUPS: 1 events
#   Top 10 merges (most sources):
#     T 11 @ 2022 ← [11, 117] (sims=[0.7, 0.5]) | einstein, hler, ricci, metric, curvature
#
#   🆕 NEW TOPICS: 2597 events
#   Per year:
#     2001: 99 new topics
#     2002: 89 new topics
#     2003: 115 new topics
#     2004: 114 new topics
#     2005: 116 new topics
#     2006: 125 new topics
#     2007: 126 new topics
#     2008: 127 new topics
#     2009: 124 new topics
#     2010: 119 new topics
#     2011: 126 new topics
#     2012: 115 new topics
#     2013: 121 new topics
#     2014: 119 new topics
#     2015: 109 new topics
#     2016: 108 new topics
#     2017: 101 new topics
#     2018: 91 new topics
#     2019: 89 new topics
#     2020: 80 new topics
#     2021: 84 new topics
#     2022: 71 new topics
#     2023: 92 new topics
#     2024: 77 new topics
#     2025: 60 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 15 | 84% stable (21S 0M 4D)
#     T 11 | 80% stable (20S 1M 4D)
#     T  4 | 76% stable (19S 0M 6D)
#     T 18 | 73% stable (16S 0M 6D)
#     T  7 | 72% stable (18S 0M 7D)
#   Top 5 most unstable:
#     T122 | 0% stable (0S 0M 24D)
#     T140 | 0% stable (0S 0M 21D)
#     T142 | 0% stable (0S 0M 25D)
#     T144 | 0% stable (0S 0M 25D)
#     T148 | 0% stable (0S 0M 24D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 3959 events
#   Per year:
#     2000: 108 topics
#     2001: 112 topics
#     2002: 125 topics
#     2003: 122 topics
#     2004: 157 topics
#     2005: 149 topics
#     2006: 169 topics
#     2007: 175 topics
#     2008: 179 topics
#     2009: 182 topics
#     2010: 187 topics
#     2011: 191 topics
#     2012: 182 topics
#     2013: 176 topics
#     2014: 174 topics
#     2015: 175 topics
#     2016: 172 topics
#     2017: 173 topics
#     2018: 165 topics
#     2019: 148 topics
#     2020: 149 topics
#     2021: 145 topics
#     2022: 157 topics
#     2023: 151 topics
#     2024: 136 topics
#
#   Permanently gone: 136
#     T  8 last @ 2024 (sim=0.300) | beam, emittance, luminosity, csr, collider, synchr
#     T 10 last @ 2024 (sim=0.300) | trade, economic, financial, countries, firms, regi
#     T 15 last @ 2024 (sim=0.400) | dark, universe, matter, inflation, cosmological, o
#     T 21 last @ 2024 (sim=0.300) | hyperfine, 2s, e1, fm, nuclear, mathrm, isotope, 2
#     T 26 last @ 2024 (sim=0.400) | vec, four, electromagnetic, momentum, vector, maxw
#     T 27 last @ 2024 (sim=0.400) | thz, terahertz, frequency, ultrafast, spectroscopy
#     T 29 last @ 2024 (sim=0.400) | mhd, magnetic, dynamo, magnetohydrodynamics, turbu
#     T 34 last @ 2024 (sim=0.400) | graphene, polaritons, thz, phonon, plasmon, beta12
#     T 39 last @ 2024 (sim=0.200) | community, networks, communities, membership, bipa
#     T 41 last @ 2024 (sim=0.400) | earth, atmospheres, planetary, planets, atmosphere
#     ... +126 more
#
#   🔗 MERGE GROUPS: 4 events
#   Top 10 merges (most sources):
#     T 38 @ 2020 ← [38, 61, 91] (sims=[0.5, 0.5, 0.5]) | neural, learning, flow, turbulence, trai
#     T222 @ 2016 ← [222, 223] (sims=[0.5, 0.5]) | cuore, neutrinoless, beta, decay, double
#     T 24 @ 2017 ← [24, 34] (sims=[0.5, 0.5]) | plasmonic, plasmon, nanostructures, surf
#     T  9 @ 2025 ← [9, 172] (sims=[0.6, 0.5]) | students, physics, student, education, a
#
#   🆕 NEW TOPICS: 4088 events
#   Per year:
#     2001: 114 new topics
#     2002: 126 new topics
#     2003: 122 new topics
#     2004: 155 new topics
#     2005: 156 new topics
#     2006: 166 new topics
#     2007: 177 new topics
#     2008: 184 new topics
#     2009: 184 new topics
#     2010: 195 new topics
#     2011: 197 new topics
#     2012: 195 new topics
#     2013: 181 new topics
#     2014: 175 new topics
#     2015: 177 new topics
#     2016: 180 new topics
#     2017: 176 new topics
#     2018: 173 new topics
#     2019: 166 new topics
#     2020: 149 new topics
#     2021: 150 new topics
#     2022: 145 new topics
#     2023: 156 new topics
#     2024: 151 new topics
#     2025: 138 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 35 | 76% stable (13S 0M 4D)
#     T131 | 73% stable (11S 0M 4D)
#     T 32 | 65% stable (15S 0M 8D)
#     T  3 | 64% stable (16S 0M 9D)
#     T 25 | 64% stable (16S 0M 9D)
#   Top 5 most unstable:
#     T219 | 0% stable (0S 0M 16D)
#     T225 | 0% stable (0S 0M 13D)
#     T229 | 0% stable (0S 0M 20D)
#     T230 | 0% stable (0S 0M 20D)
#     T231 | 0% stable (0S 0M 17D)
