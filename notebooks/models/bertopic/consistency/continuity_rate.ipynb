# %% [markdown]
# # BERTopic: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/bertopic/temporal")
RESULT_DIR = Path("../../../../results/bertopic/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/bertopic/temporal
# Saving to: ../../../../results/bertopic/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def build_word_matrix(topic_ids, topic_words_dict, year, vocab_index):
    matrix = np.zeros((len(topic_ids), len(vocab_index)))
    for i, tid in enumerate(topic_ids):
        words = topic_words_dict.get((year, tid), [])
        for w in words:
            if w in vocab_index:
                matrix[i, vocab_index[w]] = 1.0
    return matrix

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_words = set()
    for words in topic_words.values():
        all_words.update(words)
    vocab_index = {w: i for i, w in enumerate(sorted(all_words))}

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        mat_t = build_word_matrix(topics_t, topic_words, t, vocab_index)
        mat_t1 = build_word_matrix(topics_t1, topic_words, t_next, vocab_index)
        sim_matrix = cosine_similarity(mat_t, mat_t1)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (BERTopic)
# ======================================================================
#   2000→2001: Stable=3 (6%)  Merge=0 (0%)  Disappear=44 (94%)  New=60
#   2001→2002: Stable=4 (6%)  Merge=0 (0%)  Disappear=59 (94%)  New=61
#   2002→2003: Stable=6 (9%)  Merge=0 (0%)  Disappear=59 (91%)  New=68
#   2003→2004: Stable=4 (5%)  Merge=0 (0%)  Disappear=70 (95%)  New=91
#   2004→2005: Stable=9 (9%)  Merge=0 (0%)  Disappear=86 (91%)  New=78
#   2005→2006: Stable=11 (13%)  Merge=0 (0%)  Disappear=76 (87%)  New=77
#   2006→2007: Stable=11 (12%)  Merge=0 (0%)  Disappear=77 (88%)  New=71
#   2007→2008: Stable=13 (16%)  Merge=0 (0%)  Disappear=69 (84%)  New=87
#   2008→2009: Stable=12 (12%)  Merge=0 (0%)  Disappear=88 (88%)  New=96
#   2009→2010: Stable=20 (19%)  Merge=0 (0%)  Disappear=88 (81%)  New=106
#   2010→2011: Stable=21 (17%)  Merge=0 (0%)  Disappear=105 (83%)  New=123
#   2011→2012: Stable=33 (23%)  Merge=0 (0%)  Disappear=111 (77%)  New=128
#   2012→2013: Stable=43 (27%)  Merge=2 (1%)  Disappear=116 (72%)  New=134
#   2013→2014: Stable=49 (28%)  Merge=0 (0%)  Disappear=129 (72%)  New=136
#   2014→2015: Stable=57 (31%)  Merge=0 (0%)  Disappear=128 (69%)  New=141
#   2015→2016: Stable=68 (34%)  Merge=2 (1%)  Disappear=128 (65%)  New=156
#   2016→2017: Stable=104 (46%)  Merge=2 (1%)  Disappear=119 (53%)  New=134
#   2017→2018: Stable=143 (60%)  Merge=0 (0%)  Disappear=96 (40%)  New=108
#   2018→2019: Stable=174 (69%)  Merge=2 (1%)  Disappear=75 (30%)  New=80
#   2019→2020: Stable=210 (82%)  Merge=4 (2%)  Disappear=41 (16%)  New=45
#   2020→2021: Stable=222 (86%)  Merge=0 (0%)  Disappear=35 (14%)  New=36
#   2021→2022: Stable=228 (88%)  Merge=4 (2%)  Disappear=26 (10%)  New=30
#   2022→2023: Stable=232 (89%)  Merge=2 (1%)  Disappear=26 (10%)  New=28
#   2023→2024: Stable=241 (92%)  Merge=0 (0%)  Disappear=20 (8%)  New=20
#   2024→2025: Stable=247 (95%)  Merge=0 (0%)  Disappear=14 (5%)  New=13
#
#   Overall: Stable=39.0%  Merge=0.3%  Disappear=60.6%  New=2107
#   Saved: ../../../../results/bertopic/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (BERTopic)
# ======================================================================
#   2000→2001: Stable=18 (20%)  Merge=0 (0%)  Disappear=74 (80%)  New=83
#   2001→2002: Stable=16 (16%)  Merge=0 (0%)  Disappear=85 (84%)  New=74
#   2002→2003: Stable=15 (17%)  Merge=0 (0%)  Disappear=75 (83%)  New=100
#   2003→2004: Stable=21 (18%)  Merge=0 (0%)  Disappear=94 (82%)  New=97
#   2004→2005: Stable=31 (26%)  Merge=0 (0%)  Disappear=87 (74%)  New=90
#   2005→2006: Stable=30 (25%)  Merge=0 (0%)  Disappear=91 (75%)  New=103
#   2006→2007: Stable=41 (31%)  Merge=0 (0%)  Disappear=92 (69%)  New=97
#   2007→2008: Stable=50 (36%)  Merge=0 (0%)  Disappear=88 (64%)  New=91
#   2008→2009: Stable=55 (39%)  Merge=0 (0%)  Disappear=86 (61%)  New=84
#   2009→2010: Stable=65 (47%)  Merge=0 (0%)  Disappear=74 (53%)  New=76
#   2010→2011: Stable=78 (55%)  Merge=2 (1%)  Disappear=61 (43%)  New=67
#   2011→2012: Stable=92 (63%)  Merge=0 (0%)  Disappear=54 (37%)  New=56
#   2012→2013: Stable=94 (64%)  Merge=0 (0%)  Disappear=54 (36%)  New=56
#   2013→2014: Stable=106 (71%)  Merge=2 (1%)  Disappear=42 (28%)  New=43
#   2014→2015: Stable=113 (75%)  Merge=0 (0%)  Disappear=37 (25%)  New=36
#   2015→2016: Stable=116 (78%)  Merge=0 (0%)  Disappear=33 (22%)  New=34
#   2016→2017: Stable=124 (83%)  Merge=0 (0%)  Disappear=26 (17%)  New=26
#   2017→2018: Stable=124 (83%)  Merge=0 (0%)  Disappear=26 (17%)  New=26
#   2018→2019: Stable=128 (85%)  Merge=2 (1%)  Disappear=20 (13%)  New=21
#   2019→2020: Stable=132 (88%)  Merge=0 (0%)  Disappear=18 (12%)  New=18
#   2020→2021: Stable=131 (87%)  Merge=0 (0%)  Disappear=19 (13%)  New=19
#   2021→2022: Stable=131 (87%)  Merge=0 (0%)  Disappear=19 (13%)  New=19
#   2022→2023: Stable=134 (89%)  Merge=0 (0%)  Disappear=16 (11%)  New=16
#   2023→2024: Stable=135 (90%)  Merge=0 (0%)  Disappear=15 (10%)  New=15
#   2024→2025: Stable=140 (93%)  Merge=0 (0%)  Disappear=10 (7%)  New=10
#
#   Overall: Stable=58.6%  Merge=0.2%  Disappear=41.2%  New=1357
#   Saved: ../../../../results/bertopic/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (BERTopic)
# ======================================================================
#   2000→2001: Stable=7 (6%)  Merge=0 (0%)  Disappear=101 (94%)  New=107
#   2001→2002: Stable=10 (9%)  Merge=0 (0%)  Disappear=104 (91%)  New=118
#   2002→2003: Stable=15 (12%)  Merge=0 (0%)  Disappear=113 (88%)  New=110
#   2003→2004: Stable=12 (10%)  Merge=0 (0%)  Disappear=113 (90%)  New=146
#   2004→2005: Stable=18 (11%)  Merge=0 (0%)  Disappear=140 (89%)  New=139
#   2005→2006: Stable=31 (20%)  Merge=0 (0%)  Disappear=126 (80%)  New=143
#   2006→2007: Stable=38 (22%)  Merge=0 (0%)  Disappear=136 (78%)  New=144
#   2007→2008: Stable=42 (23%)  Merge=0 (0%)  Disappear=140 (77%)  New=149
#   2008→2009: Stable=56 (29%)  Merge=0 (0%)  Disappear=135 (71%)  New=140
#   2009→2010: Stable=60 (31%)  Merge=0 (0%)  Disappear=136 (69%)  New=149
#   2010→2011: Stable=80 (38%)  Merge=0 (0%)  Disappear=129 (62%)  New=139
#   2011→2012: Stable=104 (47%)  Merge=0 (0%)  Disappear=115 (53%)  New=119
#   2012→2013: Stable=109 (49%)  Merge=0 (0%)  Disappear=114 (51%)  New=113
#   2013→2014: Stable=116 (52%)  Merge=2 (1%)  Disappear=104 (47%)  New=104
#   2014→2015: Stable=126 (57%)  Merge=0 (0%)  Disappear=95 (43%)  New=98
#   2015→2016: Stable=140 (62%)  Merge=0 (0%)  Disappear=84 (38%)  New=88
#   2016→2017: Stable=144 (63%)  Merge=0 (0%)  Disappear=84 (37%)  New=87
#   2017→2018: Stable=156 (68%)  Merge=2 (1%)  Disappear=73 (32%)  New=74
#   2018→2019: Stable=172 (74%)  Merge=0 (0%)  Disappear=59 (26%)  New=60
#   2019→2020: Stable=180 (78%)  Merge=0 (0%)  Disappear=52 (22%)  New=51
#   2020→2021: Stable=178 (77%)  Merge=4 (2%)  Disappear=49 (21%)  New=52
#   2021→2022: Stable=184 (79%)  Merge=0 (0%)  Disappear=48 (21%)  New=48
#   2022→2023: Stable=176 (76%)  Merge=0 (0%)  Disappear=56 (24%)  New=55
#   2023→2024: Stable=178 (77%)  Merge=2 (1%)  Disappear=51 (22%)  New=52
#   2024→2025: Stable=189 (82%)  Merge=0 (0%)  Disappear=42 (18%)  New=43
#
#   Overall: Stable=46.1%  Merge=0.2%  Disappear=53.7%  New=2528
#   Saved: ../../../../results/bertopic/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 1885 events
#   Per year:
#     2000: 44 topics
#     2001: 59 topics
#     2002: 59 topics
#     2003: 70 topics
#     2004: 86 topics
#     2005: 76 topics
#     2006: 77 topics
#     2007: 69 topics
#     2008: 88 topics
#     2009: 88 topics
#     2010: 105 topics
#     2011: 111 topics
#     2012: 116 topics
#     2013: 129 topics
#     2014: 128 topics
#     2015: 128 topics
#     2016: 119 topics
#     2017: 96 topics
#     2018: 75 topics
#     2019: 41 topics
#     2020: 35 topics
#     2021: 26 topics
#     2022: 26 topics
#     2023: 20 topics
#     2024: 14 topics
#
#   Permanently gone: 15
#     T218 last @ 2023 (sim=0.400) | relay, relays, coherence, channel, destination, re
#     T114 last @ 2024 (sim=0.400) | string, log, strings, suffix, length, lcs, eno, al
#     T131 last @ 2024 (sim=0.400) | hpc, computing, workflow, workflows, grid, platfor
#     T204 last @ 2024 (sim=0.200) | cellular, dapp, spectrum, coverage, incumbent, emf
#     T208 last @ 2024 (sim=0.400) | polar, codes, decoding, gldpc, sbp, pc, scl, ar, s
#     T212 last @ 2024 (sim=0.200) | lyndon, words, aperiodic, ww, word, icfl, parikh,
#     T217 last @ 2024 (sim=0.200) | wpts, power, coils, coil, meter, transfer, litz, e
#     T218 last @ 2024 (sim=0.200) | relaying, sf, relay, cooperative, communications,
#     T226 last @ 2024 (sim=0.300) | privacy, apps, gdpr, web, personal, topics, google
#     T230 last @ 2024 (sim=0.300) | alignment, sequence, dna, genome, reads, gatekeepe
#     ... +5 more
#
#   🔗 MERGE GROUPS: 9 events
#   Top 10 merges (most sources):
#     T170 @ 2013 ← [170, 237] (sims=[0.6, 0.5]) | vehicular, vanet, aomdv, vehicles, vehic
#     T153 @ 2016 ← [153, 247] (sims=[0.6, 0.5]) | clustering, clusters, means, cluster, wa
#     T 56 @ 2017 ← [56, 256] (sims=[0.9, 0.5]) | recovery, ell, signal, sparse, sensing,
#     T155 @ 2019 ← [155, 241] (sims=[0.5, 0.6]) | iot, home, devices, internet, smart, sec
#     T  8 @ 2020 ← [8, 18] (sims=[1.0, 0.6]) | adversarial, attacks, attack, robustness
#     T 12 @ 2020 ← [12, 187] (sims=[0.7, 0.6]) | driving, autonomous, traffic, vehicles,
#     T 41 @ 2022 ← [41, 227] (sims=[0.8, 0.5]) | privacy, dp, private, differentially, di
#     T 67 @ 2022 ← [67, 257] (sims=[0.9, 0.7]) | games, nash, equilibria, game, equilibri
#     T  8 @ 2023 ← [8, 18] (sims=[1.0, 0.5]) | adversarial, robustness, attacks, attack
#
#   🆕 NEW TOPICS: 2107 events
#   Per year:
#     2001: 60 new topics
#     2002: 61 new topics
#     2003: 68 new topics
#     2004: 91 new topics
#     2005: 78 new topics
#     2006: 77 new topics
#     2007: 71 new topics
#     2008: 87 new topics
#     2009: 96 new topics
#     2010: 106 new topics
#     2011: 123 new topics
#     2012: 128 new topics
#     2013: 134 new topics
#     2014: 136 new topics
#     2015: 141 new topics
#     2016: 156 new topics
#     2017: 134 new topics
#     2018: 108 new topics
#     2019: 80 new topics
#     2020: 45 new topics
#     2021: 36 new topics
#     2022: 30 new topics
#     2023: 28 new topics
#     2024: 20 new topics
#     2025: 13 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T228 | 100% stable (7S 0M 0D)
#     T 74 | 100% stable (9S 0M 0D)
#     T177 | 100% stable (11S 0M 0D)
#     T 13 | 100% stable (21S 0M 0D)
#     T 86 | 100% stable (10S 0M 0D)
#   Top 5 most unstable:
#     T249 | 10% stable (2S 0M 17D)
#     T131 | 8% stable (2S 0M 23D)
#     T216 | 7% stable (1S 0M 13D)
#     T259 | 6% stable (1S 0M 17D)
#     T206 | 6% stable (1S 0M 17D)
#
#
# ======================================================================
# Analysis Review: MATH (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 1296 events
#   Per year:
#     2000: 74 topics
#     2001: 85 topics
#     2002: 75 topics
#     2003: 94 topics
#     2004: 87 topics
#     2005: 91 topics
#     2006: 92 topics
#     2007: 88 topics
#     2008: 86 topics
#     2009: 74 topics
#     2010: 61 topics
#     2011: 54 topics
#     2012: 54 topics
#     2013: 42 topics
#     2014: 37 topics
#     2015: 33 topics
#     2016: 26 topics
#     2017: 26 topics
#     2018: 20 topics
#     2019: 18 topics
#     2020: 19 topics
#     2021: 19 topics
#     2022: 16 topics
#     2023: 15 topics
#     2024: 10 topics
#
#   Permanently gone: 10
#     T 69 last @ 2024 (sim=0.400) | hecke, mathfrak, modules, specht, algebra, algebra
#     T 85 last @ 2024 (sim=0.200) | mathsf, subseteq, leq, mathbb, geq, progressions,
#     T110 last @ 2024 (sim=0.400) | phylogenetic, phylogeny, trees, tree, duplication,
#     T123 last @ 2024 (sim=0.300) | matrices, hadamard, matrix, tt, permanent, times,
#     T131 last @ 2024 (sim=0.400) | mills, yang, instantons, connections, higgs, hler,
#     T133 last @ 2024 (sim=0.400) | nonholonomic, hamilton, hamiltonian, systems, lagr
#     T134 last @ 2024 (sim=0.400) | fractional, method, variable, numerical, order, sc
#     T138 last @ 2024 (sim=0.300) | noncommutative, quantum, connection, durdevic, tri
#     T142 last @ 2024 (sim=0.300) | motives, motivic, motive, chow, ch, prime, cor, va
#     T146 last @ 2024 (sim=0.200) | painlev, heiles, isomonodromic, integrable, prelle
#
#   🔗 MERGE GROUPS: 3 events
#   Top 10 merges (most sources):
#     T 11 @ 2011 ← [11, 117] (sims=[1.0, 0.6]) | ricci, metrics, hler, curvature, einstei
#     T 69 @ 2014 ← [69, 88] (sims=[0.8, 0.6]) | hecke, modules, lusztig, quantum, algebr
#     T 11 @ 2019 ← [11, 117] (sims=[0.9, 0.5]) | ricci, metrics, hler, curvature, metric,
#
#   🆕 NEW TOPICS: 1357 events
#   Per year:
#     2001: 83 new topics
#     2002: 74 new topics
#     2003: 100 new topics
#     2004: 97 new topics
#     2005: 90 new topics
#     2006: 103 new topics
#     2007: 97 new topics
#     2008: 91 new topics
#     2009: 84 new topics
#     2010: 76 new topics
#     2011: 67 new topics
#     2012: 56 new topics
#     2013: 56 new topics
#     2014: 43 new topics
#     2015: 36 new topics
#     2016: 34 new topics
#     2017: 26 new topics
#     2018: 26 new topics
#     2019: 21 new topics
#     2020: 18 new topics
#     2021: 19 new topics
#     2022: 19 new topics
#     2023: 16 new topics
#     2024: 15 new topics
#     2025: 10 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  3 | 100% stable (25S 0M 0D)
#     T  7 | 100% stable (25S 0M 0D)
#     T 15 | 100% stable (25S 0M 0D)
#     T 43 | 100% stable (25S 0M 0D)
#     T  9 | 96% stable (24S 0M 1D)
#   Top 5 most unstable:
#     T 63 | 16% stable (4S 0M 21D)
#     T133 | 16% stable (4S 0M 21D)
#     T127 | 15% stable (3S 0M 17D)
#     T123 | 14% stable (3S 0M 18D)
#     T142 | 8% stable (2S 0M 23D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 2399 events
#   Per year:
#     2000: 101 topics
#     2001: 104 topics
#     2002: 113 topics
#     2003: 113 topics
#     2004: 140 topics
#     2005: 126 topics
#     2006: 136 topics
#     2007: 140 topics
#     2008: 135 topics
#     2009: 136 topics
#     2010: 129 topics
#     2011: 115 topics
#     2012: 114 topics
#     2013: 104 topics
#     2014: 95 topics
#     2015: 84 topics
#     2016: 84 topics
#     2017: 73 topics
#     2018: 59 topics
#     2019: 52 topics
#     2020: 49 topics
#     2021: 48 topics
#     2022: 56 topics
#     2023: 51 topics
#     2024: 42 topics
#
#   Permanently gone: 42
#     T 64 last @ 2024 (sim=0.400) | orbits, orbital, keplerian, ggt, spacecraft, newto
#     T 68 last @ 2024 (sim=0.200) | astronomical, calendar, eclipse, hipparchus, his,
#     T 70 last @ 2024 (sim=0.200) | hamiltonian, action, rtimes, mechanics, neq, lie,
#     T 72 last @ 2024 (sim=0.400) | relativity, special, bob, morley, michelson, alice
#     T 81 last @ 2024 (sim=0.200) | graphene, carbon, conductivity, thermal, flake, ir
#     T 89 last @ 2024 (sim=0.400) | species, population, prey, predator, mbox, allee,
#     T 99 last @ 2024 (sim=0.300) | dna, rna, supercoiled, unzipping, sequence, strand
#     T116 last @ 2024 (sim=0.400) | protein, proteins, folding, text, allosteric, amin
#     T120 last @ 2024 (sim=0.100) | ski, resistance, roughness, snow, motion, bicycle,
#     T129 last @ 2024 (sim=0.300) | cloaking, cloak, bandwidth, bounds, cloaks, loss,
#     ... +32 more
#
#   🔗 MERGE GROUPS: 5 events
#   Top 10 merges (most sources):
#     T 39 @ 2014 ← [39, 103] (sims=[0.9, 0.6]) | community, communities, networks, networ
#     T 39 @ 2018 ← [39, 103] (sims=[0.9, 0.5]) | community, networks, communities, detect
#     T103 @ 2021 ← [103, 203] (sims=[0.8, 0.5]) | degree, networks, graphs, node, network,
#     T192 @ 2021 ← [192, 194] (sims=[0.7, 0.5]) | cavities, superconducting, niobium, rf,
#     T192 @ 2024 ← [192, 194] (sims=[0.9, 0.5]) | niobium, cavities, nb, superconducting,
#
#   🆕 NEW TOPICS: 2528 events
#   Per year:
#     2001: 107 new topics
#     2002: 118 new topics
#     2003: 110 new topics
#     2004: 146 new topics
#     2005: 139 new topics
#     2006: 143 new topics
#     2007: 144 new topics
#     2008: 149 new topics
#     2009: 140 new topics
#     2010: 149 new topics
#     2011: 139 new topics
#     2012: 119 new topics
#     2013: 113 new topics
#     2014: 104 new topics
#     2015: 98 new topics
#     2016: 88 new topics
#     2017: 87 new topics
#     2018: 74 new topics
#     2019: 60 new topics
#     2020: 51 new topics
#     2021: 52 new topics
#     2022: 48 new topics
#     2023: 55 new topics
#     2024: 52 new topics
#     2025: 43 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 52 | 100% stable (25S 0M 0D)
#     T 26 | 96% stable (24S 0M 1D)
#     T 65 | 96% stable (24S 0M 1D)
#     T202 | 94% stable (17S 0M 1D)
#     T 35 | 94% stable (16S 0M 1D)
#   Top 5 most unstable:
#     T138 | 0% stable (0S 0M 20D)
#     T155 | 0% stable (0S 0M 25D)
#     T178 | 0% stable (0S 0M 24D)
#     T200 | 0% stable (0S 0M 20D)
#     T218 | 0% stable (0S 0M 21D)
