# %% [markdown]
# # BERTopic: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/bertopic/temporal")
RESULT_DIR = Path("../../../../results/bertopic/consistency")
THRESHOLD_LOW = 0.2   # below → disappear
THRESHOLD_HIGH = 0.5  # [0.3, 0.7) → evolve; >= 0.7 → stable

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold Low  (disappear): {THRESHOLD_LOW}")
print(f"Threshold High (stable)   : {THRESHOLD_HIGH}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold Low  (disappear): 0.2
# Threshold High (stable)   : 0.5
# Reading from: ../../../../results/bertopic/temporal
# Saving to: ../../../../results/bertopic/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t  = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for i, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for j, tid_t1 in enumerate(topics_t1):
                words_t1 = topic_words.get((t_next, tid_t1), [])
                sim_matrix[i, j] = rbo(words_t, words_t1, p=0.9)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map
        # Disappear : sim < THRESHOLD_LOW
        # Evolve    : THRESHOLD_LOW <= sim < THRESHOLD_HIGH, single source
        # Stable    : sim >= THRESHOLD_HIGH, single source
        # Merge     : sim >= THRESHOLD_LOW AND >1 source for same t+1-topic
        assignment = {}            # topic_t → best topic_t1 (or None)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD_LOW:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_evolve, n_merge, n_disappear = 0, 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target  = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] > 1:
                category = "merge"
                n_merge += 1
            elif sim_val >= THRESHOLD_HIGH:
                category = "stable"
                n_stable += 1
            else:
                category = "evolve"
                n_evolve += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new   = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_evolve": n_evolve, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable":    round(n_stable   / total_t * 100, 2),
            "pct_evolve":    round(n_evolve   / total_t * 100, 2),
            "pct_merge":     round(n_merge    / total_t * 100, 2),
            "pct_disappear": round(n_disappear/ total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Evolve={n_evolve} ({n_evolve/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject,
        "threshold_low": THRESHOLD_LOW, "threshold_high": THRESHOLD_HIGH,
        "avg_pct_stable":    round(subj_sum["pct_stable"].mean(),    2),
        "avg_pct_evolve":    round(subj_sum["pct_evolve"].mean(),    2),
        "avg_pct_merge":     round(subj_sum["pct_merge"].mean(),     2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new":          int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Evolve={overall['avg_pct_evolve']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (BERTopic)
# ======================================================================
#   2000→2001: Stable=2 (4%)  Evolve=6 (13%)  Merge=0 (0%)  Disappear=39 (83%)  New=55
#   2001→2002: Stable=3 (5%)  Evolve=8 (13%)  Merge=0 (0%)  Disappear=52 (83%)  New=54
#   2002→2003: Stable=2 (3%)  Evolve=9 (14%)  Merge=0 (0%)  Disappear=54 (83%)  New=63
#   2003→2004: Stable=1 (1%)  Evolve=11 (15%)  Merge=0 (0%)  Disappear=62 (84%)  New=83
#   2004→2005: Stable=0 (0%)  Evolve=20 (21%)  Merge=0 (0%)  Disappear=75 (79%)  New=67
#   2005→2006: Stable=1 (1%)  Evolve=13 (15%)  Merge=2 (2%)  Disappear=71 (82%)  New=73
#   2006→2007: Stable=4 (5%)  Evolve=12 (14%)  Merge=0 (0%)  Disappear=72 (82%)  New=66
#   2007→2008: Stable=4 (5%)  Evolve=16 (20%)  Merge=3 (4%)  Disappear=59 (72%)  New=79
#   2008→2009: Stable=2 (2%)  Evolve=17 (17%)  Merge=2 (2%)  Disappear=79 (79%)  New=88
#   2009→2010: Stable=2 (2%)  Evolve=31 (29%)  Merge=0 (0%)  Disappear=75 (69%)  New=93
#   2010→2011: Stable=3 (2%)  Evolve=30 (24%)  Merge=0 (0%)  Disappear=93 (74%)  New=111
#   2011→2012: Stable=10 (7%)  Evolve=40 (28%)  Merge=4 (3%)  Disappear=90 (62%)  New=109
#   2012→2013: Stable=12 (7%)  Evolve=51 (32%)  Merge=6 (4%)  Disappear=92 (57%)  New=112
#   2013→2014: Stable=14 (8%)  Evolve=58 (33%)  Merge=8 (4%)  Disappear=98 (55%)  New=109
#   2014→2015: Stable=16 (9%)  Evolve=61 (33%)  Merge=8 (4%)  Disappear=100 (54%)  New=117
#   2015→2016: Stable=20 (10%)  Evolve=65 (33%)  Merge=14 (7%)  Disappear=99 (50%)  New=133
#   2016→2017: Stable=22 (10%)  Evolve=91 (40%)  Merge=14 (6%)  Disappear=98 (44%)  New=119
#   2017→2018: Stable=46 (19%)  Evolve=101 (42%)  Merge=16 (7%)  Disappear=76 (32%)  New=96
#   2018→2019: Stable=66 (26%)  Evolve=110 (44%)  Merge=17 (7%)  Disappear=58 (23%)  New=71
#   2019→2020: Stable=95 (37%)  Evolve=111 (44%)  Merge=19 (7%)  Disappear=30 (12%)  New=42
#   2020→2021: Stable=124 (48%)  Evolve=81 (32%)  Merge=30 (12%)  Disappear=22 (9%)  New=38
#   2021→2022: Stable=132 (51%)  Evolve=88 (34%)  Merge=19 (7%)  Disappear=19 (7%)  New=31
#   2022→2023: Stable=134 (52%)  Evolve=90 (35%)  Merge=15 (6%)  Disappear=21 (8%)  New=30
#   2023→2024: Stable=161 (62%)  Evolve=70 (27%)  Merge=15 (6%)  Disappear=15 (6%)  New=23
#   2024→2025: Stable=182 (70%)  Evolve=58 (22%)  Merge=8 (3%)  Disappear=13 (5%)  New=16
#
#   Overall: Stable=17.9%  Evolve=26.8%  Merge=3.6%  Disappear=51.7%  New=1878
#   Saved: ../../../../results/bertopic/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (BERTopic)
# ======================================================================
#   2000→2001: Stable=3 (3%)  Evolve=19 (21%)  Merge=0 (0%)  Disappear=70 (76%)  New=79
#   2001→2002: Stable=0 (0%)  Evolve=27 (27%)  Merge=0 (0%)  Disappear=74 (73%)  New=63
#   2002→2003: Stable=3 (3%)  Evolve=21 (23%)  Merge=4 (4%)  Disappear=62 (69%)  New=89
#   2003→2004: Stable=1 (1%)  Evolve=29 (25%)  Merge=5 (4%)  Disappear=80 (70%)  New=86
#   2004→2005: Stable=4 (3%)  Evolve=37 (31%)  Merge=2 (2%)  Disappear=75 (64%)  New=79
#   2005→2006: Stable=6 (5%)  Evolve=49 (40%)  Merge=6 (5%)  Disappear=60 (50%)  New=75
#   2006→2007: Stable=11 (8%)  Evolve=43 (32%)  Merge=6 (5%)  Disappear=73 (55%)  New=81
#   2007→2008: Stable=11 (8%)  Evolve=47 (34%)  Merge=16 (12%)  Disappear=64 (46%)  New=76
#   2008→2009: Stable=12 (9%)  Evolve=53 (38%)  Merge=8 (6%)  Disappear=68 (48%)  New=70
#   2009→2010: Stable=16 (12%)  Evolve=48 (35%)  Merge=4 (3%)  Disappear=71 (51%)  New=75
#   2010→2011: Stable=14 (10%)  Evolve=69 (49%)  Merge=6 (4%)  Disappear=52 (37%)  New=60
#   2011→2012: Stable=24 (16%)  Evolve=58 (40%)  Merge=8 (5%)  Disappear=56 (38%)  New=62
#   2012→2013: Stable=29 (20%)  Evolve=65 (44%)  Merge=10 (7%)  Disappear=44 (30%)  New=51
#   2013→2014: Stable=34 (23%)  Evolve=73 (49%)  Merge=8 (5%)  Disappear=35 (23%)  New=39
#   2014→2015: Stable=31 (21%)  Evolve=80 (53%)  Merge=14 (9%)  Disappear=25 (17%)  New=31
#   2015→2016: Stable=38 (26%)  Evolve=78 (52%)  Merge=8 (5%)  Disappear=25 (17%)  New=30
#   2016→2017: Stable=41 (27%)  Evolve=83 (55%)  Merge=6 (4%)  Disappear=20 (13%)  New=23
#   2017→2018: Stable=48 (32%)  Evolve=73 (49%)  Merge=12 (8%)  Disappear=17 (11%)  New=23
#   2018→2019: Stable=64 (43%)  Evolve=62 (41%)  Merge=6 (4%)  Disappear=18 (12%)  New=21
#   2019→2020: Stable=64 (43%)  Evolve=66 (44%)  Merge=4 (3%)  Disappear=16 (11%)  New=18
#   2020→2021: Stable=62 (41%)  Evolve=62 (41%)  Merge=6 (4%)  Disappear=20 (13%)  New=23
#   2021→2022: Stable=82 (55%)  Evolve=52 (35%)  Merge=6 (4%)  Disappear=10 (7%)  New=13
#   2022→2023: Stable=62 (41%)  Evolve=68 (45%)  Merge=6 (4%)  Disappear=14 (9%)  New=17
#   2023→2024: Stable=58 (39%)  Evolve=69 (46%)  Merge=10 (7%)  Disappear=13 (9%)  New=18
#   2024→2025: Stable=81 (54%)  Evolve=54 (36%)  Merge=10 (7%)  Disappear=5 (3%)  New=10
#
#   Overall: Stable=21.7%  Evolve=39.4%  Merge=4.8%  Disappear=34.1%  New=1212
#   Saved: ../../../../results/bertopic/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (BERTopic)
# ======================================================================
#   2000→2001: Stable=0 (0%)  Evolve=24 (22%)  Merge=6 (6%)  Disappear=78 (72%)  New=87
#   2001→2002: Stable=3 (3%)  Evolve=24 (21%)  Merge=0 (0%)  Disappear=87 (76%)  New=101
#   2002→2003: Stable=0 (0%)  Evolve=22 (17%)  Merge=2 (2%)  Disappear=104 (81%)  New=102
#   2003→2004: Stable=4 (3%)  Evolve=28 (22%)  Merge=0 (0%)  Disappear=93 (74%)  New=126
#   2004→2005: Stable=0 (0%)  Evolve=36 (23%)  Merge=2 (1%)  Disappear=120 (76%)  New=120
#   2005→2006: Stable=5 (3%)  Evolve=42 (27%)  Merge=4 (3%)  Disappear=106 (68%)  New=125
#   2006→2007: Stable=7 (4%)  Evolve=54 (31%)  Merge=2 (1%)  Disappear=111 (64%)  New=120
#   2007→2008: Stable=10 (5%)  Evolve=52 (29%)  Merge=8 (4%)  Disappear=112 (62%)  New=125
#   2008→2009: Stable=11 (6%)  Evolve=51 (27%)  Merge=8 (4%)  Disappear=121 (63%)  New=130
#   2009→2010: Stable=14 (7%)  Evolve=70 (36%)  Merge=0 (0%)  Disappear=112 (57%)  New=125
#   2010→2011: Stable=20 (10%)  Evolve=73 (35%)  Merge=16 (8%)  Disappear=100 (48%)  New=118
#   2011→2012: Stable=19 (9%)  Evolve=99 (45%)  Merge=17 (8%)  Disappear=84 (38%)  New=98
#   2012→2013: Stable=40 (18%)  Evolve=81 (36%)  Merge=6 (3%)  Disappear=96 (43%)  New=98
#   2013→2014: Stable=40 (18%)  Evolve=78 (35%)  Merge=18 (8%)  Disappear=86 (39%)  New=94
#   2014→2015: Stable=44 (20%)  Evolve=86 (39%)  Merge=16 (7%)  Disappear=75 (34%)  New=86
#   2015→2016: Stable=47 (21%)  Evolve=86 (38%)  Merge=16 (7%)  Disappear=75 (33%)  New=87
#   2016→2017: Stable=54 (24%)  Evolve=98 (43%)  Merge=16 (7%)  Disappear=60 (26%)  New=71
#   2017→2018: Stable=56 (24%)  Evolve=95 (41%)  Merge=14 (6%)  Disappear=66 (29%)  New=73
#   2018→2019: Stable=56 (24%)  Evolve=100 (43%)  Merge=20 (9%)  Disappear=55 (24%)  New=66
#   2019→2020: Stable=62 (27%)  Evolve=105 (45%)  Merge=19 (8%)  Disappear=46 (20%)  New=55
#   2020→2021: Stable=77 (33%)  Evolve=90 (39%)  Merge=23 (10%)  Disappear=41 (18%)  New=54
#   2021→2022: Stable=67 (29%)  Evolve=96 (41%)  Merge=21 (9%)  Disappear=48 (21%)  New=59
#   2022→2023: Stable=64 (28%)  Evolve=98 (42%)  Merge=20 (9%)  Disappear=50 (22%)  New=59
#   2023→2024: Stable=73 (32%)  Evolve=98 (42%)  Merge=16 (7%)  Disappear=44 (19%)  New=52
#   2024→2025: Stable=84 (36%)  Evolve=97 (42%)  Merge=18 (8%)  Disappear=32 (14%)  New=43
#
#   Overall: Stable=15.3%  Evolve=34.5%  Merge=5.3%  Disappear=44.8%  New=2274
#   Saved: ../../../../results/bertopic/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    trans_df   = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df   = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path   = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df     = pd.read_csv(new_path)   if new_path.stat().st_size   > 10 else pd.DataFrame()
    evo_df     = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED (sim < THRESHOLD_LOW) ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED (sim < {THRESHOLD_LOW}): {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid   = int(r["topic_id"])
            later = evo_df[(evo_df["topic_id"] == tid) & (evo_df["year"] > int(r["year_to"]))]
            if len(later) == 0:
                w = str(r["words"])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- EVOLVE (THRESHOLD_LOW <= sim < THRESHOLD_HIGH, single source) ---
    evolved = trans_df[trans_df["category"] == "evolve"]
    print(f"\n  🔄 EVOLVE ({THRESHOLD_LOW} <= sim < {THRESHOLD_HIGH}): {len(evolved)} events")
    if len(evolved) > 0:
        per_year = evolved.groupby("year_from").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

    # --- MERGE GROUPS (>1 source, sim >= THRESHOLD_LOW) ---
    print(f"\n  🔗 MERGE GROUPS (sim >= {THRESHOLD_LOW}, >1 source): {len(merge_df)} events")
    if len(merge_df) > 0:
        print("  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, "n_sources").iterrows():
            w = str(r["target_words"])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print("  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print("\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "evolve", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print("  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev {int(r['merge'])}M {int(r['disappear'])}D)")
    print("  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r.get('evolve',0))}Ev {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED (sim < 0.2): 1562 events
#   Per year:
#     2000: 39 topics
#     2001: 52 topics
#     2002: 54 topics
#     2003: 62 topics
#     2004: 75 topics
#     2005: 71 topics
#     2006: 72 topics
#     2007: 59 topics
#     2008: 79 topics
#     2009: 75 topics
#     2010: 93 topics
#     2011: 90 topics
#     2012: 92 topics
#     2013: 98 topics
#     2014: 100 topics
#     2015: 99 topics
#     2016: 98 topics
#     2017: 76 topics
#     2018: 58 topics
#     2019: 30 topics
#     2020: 22 topics
#     2021: 19 topics
#     2022: 21 topics
#     2023: 15 topics
#     2024: 13 topics
#
#   Permanently gone: 14
#     T218 last @ 2023 (sim=0.182) | relays, coherence, channel, superposition, relay,
#     T 56 last @ 2024 (sim=0.101) | octonion, sgm, qcs, sparse, amp, passing, signal,
#     T 71 last @ 2024 (sim=0.044) | fog, queue, p4, service, ndn, jsq, networking, flo
#     T103 last @ 2024 (sim=0.067) | synchronization, wireless, gateway, aco, adhoc, se
#     T106 last @ 2024 (sim=0.147) | perp, 10mu, mkern, mathrel, entropy, information,
#     T135 last @ 2024 (sim=0.125) | shootings, pandemic, disease, school, outbreaks, e
#     T204 last @ 2024 (sim=0.125) | dapp, incumbent, coverage, emfe, cellular, spectru
#     T212 last @ 2024 (sim=0.088) | lyndon, aperiodic, ww, icfl, parikh, factorization
#     T217 last @ 2024 (sim=0.098) | wpts, coils, coil, power, meter, litz, transfer, m
#     T218 last @ 2024 (sim=0.080) | sf, relaying, cooperative, communications, 6g, for
#     ... +4 more
#
#   🔄 EVOLVE (0.2 <= sim < 0.5): 1248 events
#   Per year:
#     2000: 6 topics
#     2001: 8 topics
#     2002: 9 topics
#     2003: 11 topics
#     2004: 20 topics
#     2005: 13 topics
#     2006: 12 topics
#     2007: 16 topics
#     2008: 17 topics
#     2009: 31 topics
#     2010: 30 topics
#     2011: 40 topics
#     2012: 51 topics
#     2013: 58 topics
#     2014: 61 topics
#     2015: 65 topics
#     2016: 91 topics
#     2017: 101 topics
#     2018: 110 topics
#     2019: 111 topics
#     2020: 81 topics
#     2021: 88 topics
#     2022: 90 topics
#     2023: 70 topics
#     2024: 58 topics
#
#   🔗 MERGE GROUPS (sim >= 0.2, >1 source): 97 events
#   Top 10 merges (most sources):
#     T 25 @ 2008 ← [25, 109, 243] (sims=[0.4568, 0.3686, 0.309]) | codes, trapping, kloosterman, decoding,
#     T 41 @ 2019 ← [41, 226, 227] (sims=[0.6191, 0.2703, 0.4196]) | privacy, differential, private, differen
#     T170 @ 2020 ← [145, 170, 237] (sims=[0.2686, 0.5005, 0.2461]) | v2x, vehicle, vehicular, vehicles, dsrc,
#     T 41 @ 2022 ← [41, 226, 227] (sims=[0.6975, 0.2703, 0.5492]) | privacy, dp, private, differentially, di
#     T 67 @ 2023 ← [67, 102, 257] (sims=[0.7013, 0.4659, 0.451]) | games, game, player, nash, equilibria, e
#     T 41 @ 2024 ← [41, 226, 227] (sims=[0.8651, 0.2703, 0.4625]) | privacy, dp, private, differential, diff
#     T109 @ 2006 ← [25, 109] (sims=[0.4438, 0.7258]) | codes, ldpc, decoding, turbo, bounds, st
#     T103 @ 2009 ← [103, 209] (sims=[0.3198, 0.2049]) | routing, hoc, ad, sensor, olsr, energy,
#     T 56 @ 2012 ← [56, 201] (sims=[0.3821, 0.2703]) | recovery, dbf, ell, omp, sparse, fbf, is
#     T150 @ 2012 ← [150, 245] (sims=[0.3633, 0.2703]) | scheduling, jobs, makespan, energy, spee
#
#   🆕 NEW TOPICS: 1878 events
#   Per year:
#     2001: 55 new topics
#     2002: 54 new topics
#     2003: 63 new topics
#     2004: 83 new topics
#     2005: 67 new topics
#     2006: 73 new topics
#     2007: 66 new topics
#     2008: 79 new topics
#     2009: 88 new topics
#     2010: 93 new topics
#     2011: 111 new topics
#     2012: 109 new topics
#     2013: 112 new topics
#     2014: 109 new topics
#     2015: 117 new topics
#     2016: 133 new topics
#     2017: 119 new topics
#     2018: 96 new topics
#     2019: 71 new topics
#     2020: 42 new topics
#     2021: 38 new topics
#     2022: 31 new topics
#     2023: 30 new topics
#     2024: 23 new topics
#     2025: 16 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 74 | 89% stable (8S 0Ev 1M 0D)
#     T182 | 86% stable (6S 0Ev 0M 1D)
#     T 73 | 80% stable (8S 2Ev 0M 0D)
#     T181 | 78% stable (7S 1Ev 0M 1D)
#     T112 | 75% stable (9S 2Ev 0M 1D)
#   Top 5 most unstable:
#     T232 | 0% stable (0S 6Ev 0M 15D)
#     T233 | 0% stable (0S 6Ev 1M 16D)
#     T234 | 0% stable (0S 8Ev 0M 1D)
#     T237 | 0% stable (0S 3Ev 4M 6D)
#     T259 | 0% stable (0S 1Ev 0M 17D)
#
#
# ======================================================================
# Analysis Review: MATH (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED (sim < 0.2): 1067 events
#   Per year:
#     2000: 70 topics
#     2001: 74 topics
#     2002: 62 topics
#     2003: 80 topics
#     2004: 75 topics
#     2005: 60 topics
#     2006: 73 topics
#     2007: 64 topics
#     2008: 68 topics
#     2009: 71 topics
#     2010: 52 topics
#     2011: 56 topics
#     2012: 44 topics
#     2013: 35 topics
#     2014: 25 topics
#     2015: 25 topics
#     2016: 20 topics
#     2017: 17 topics
#     2018: 18 topics
#     2019: 16 topics
#     2020: 20 topics
#     2021: 10 topics
#     2022: 14 topics
#     2023: 13 topics
#     2024: 5 topics
#
#   Permanently gone: 5
#     T 97 last @ 2024 (sim=0.155) | smectic, thin, defects, liquid, ericksen, leslie,
#     T127 last @ 2024 (sim=0.191) | reflexive, tdd, monadicity, categorical, categorie
#     T133 last @ 2024 (sim=0.170) | nonholonomic, hamilton, lepage, bracket, lagrangia
#     T137 last @ 2024 (sim=0.098) | rm, nijenhuis, inftya, hochschild, homotopy, algeb
#     T144 last @ 2024 (sim=0.170) | spin, baxterization, parametrising, graphical, dyn
#
#   🔄 EVOLVE (0.2 <= sim < 0.5): 1385 events
#   Per year:
#     2000: 19 topics
#     2001: 27 topics
#     2002: 21 topics
#     2003: 29 topics
#     2004: 37 topics
#     2005: 49 topics
#     2006: 43 topics
#     2007: 47 topics
#     2008: 53 topics
#     2009: 48 topics
#     2010: 69 topics
#     2011: 58 topics
#     2012: 65 topics
#     2013: 73 topics
#     2014: 80 topics
#     2015: 78 topics
#     2016: 83 topics
#     2017: 73 topics
#     2018: 62 topics
#     2019: 66 topics
#     2020: 62 topics
#     2021: 52 topics
#     2022: 68 topics
#     2023: 69 topics
#     2024: 54 topics
#
#   🔗 MERGE GROUPS (sim >= 0.2, >1 source): 84 events
#   Top 10 merges (most sources):
#     T 40 @ 2008 ← [40, 112, 119, 130] (sims=[0.5579, 0.2703, 0.3198, 0.376]) | lie, subalgebras, algebras, filiform, le
#     T  6 @ 2004 ← [6, 27, 40] (sims=[0.3914, 0.2703, 0.3956]) | algebras, unital, algebra, pi, tracial,
#     T 40 @ 2003 ← [6, 40] (sims=[0.3686, 0.3001]) | algebras, algebra, lie, xu, dynkin, cent
#     T 20 @ 2003 ← [9, 117] (sims=[0.2703, 0.2372]) | surfaces, umbilic, curvature, mean, line
#     T 20 @ 2004 ← [20, 117] (sims=[0.3924, 0.2703]) | curvature, minimal, surfaces, mean, surf
#     T  9 @ 2005 ← [9, 44] (sims=[0.4258, 0.2703]) | hilb, k3, bundles, moduli, curves, surfa
#     T 11 @ 2006 ← [11, 117] (sims=[0.412, 0.2731]) | ricci, manifolds, hler, manifold, hm, cu
#     T 33 @ 2006 ← [33, 127] (sims=[0.3527, 0.2211]) | category, operads, categories, operad, r
#     T 64 @ 2006 ← [64, 92] (sims=[0.3686, 0.2703]) | polynomials, orthogonal, 2n, circle, mat
#     T 13 @ 2007 ← [13, 149] (sims=[0.4878, 0.3451]) | nonlinear, dinger, schr, equation, posed
#
#   🆕 NEW TOPICS: 1212 events
#   Per year:
#     2001: 79 new topics
#     2002: 63 new topics
#     2003: 89 new topics
#     2004: 86 new topics
#     2005: 79 new topics
#     2006: 75 new topics
#     2007: 81 new topics
#     2008: 76 new topics
#     2009: 70 new topics
#     2010: 75 new topics
#     2011: 60 new topics
#     2012: 62 new topics
#     2013: 51 new topics
#     2014: 39 new topics
#     2015: 31 new topics
#     2016: 30 new topics
#     2017: 23 new topics
#     2018: 23 new topics
#     2019: 21 new topics
#     2020: 18 new topics
#     2021: 23 new topics
#     2022: 13 new topics
#     2023: 17 new topics
#     2024: 18 new topics
#     2025: 10 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  3 | 76% stable (19S 6Ev 0M 0D)
#     T 10 | 76% stable (19S 4Ev 0M 2D)
#     T  0 | 72% stable (18S 4Ev 0M 3D)
#     T106 | 69% stable (11S 1Ev 1M 3D)
#     T 11 | 68% stable (17S 6Ev 2M 0D)
#   Top 5 most unstable:
#     T137 | 0% stable (0S 11Ev 0M 14D)
#     T138 | 0% stable (0S 15Ev 1M 9D)
#     T142 | 0% stable (0S 13Ev 2M 10D)
#     T144 | 0% stable (0S 7Ev 2M 16D)
#     T146 | 0% stable (0S 17Ev 0M 8D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED (sim < 0.2): 2002 events
#   Per year:
#     2000: 78 topics
#     2001: 87 topics
#     2002: 104 topics
#     2003: 93 topics
#     2004: 120 topics
#     2005: 106 topics
#     2006: 111 topics
#     2007: 112 topics
#     2008: 121 topics
#     2009: 112 topics
#     2010: 100 topics
#     2011: 84 topics
#     2012: 96 topics
#     2013: 86 topics
#     2014: 75 topics
#     2015: 75 topics
#     2016: 60 topics
#     2017: 66 topics
#     2018: 55 topics
#     2019: 46 topics
#     2020: 41 topics
#     2021: 48 topics
#     2022: 50 topics
#     2023: 44 topics
#     2024: 32 topics
#
#   Permanently gone: 32
#     T 39 last @ 2024 (sim=0.182) | community, networks, communities, membership, bipa
#     T 56 last @ 2024 (sim=0.080) | negative, brewster, refraction, veps, metamaterial
#     T 68 last @ 2024 (sim=0.125) | calendar, astronomical, eclipse, hipparchus, catal
#     T 70 last @ 2024 (sim=0.080) | rtimes, neq, action, mathcal, relativity, mechanic
#     T 72 last @ 2024 (sim=0.137) | relativity, bob, alice, morley, sitter, michelson,
#     T 77 last @ 2024 (sim=0.124) | su, mathbb, higgs, symmetry, group, boson, supersy
#     T 89 last @ 2024 (sim=0.099) | prey, predator, mbox, allee, population, alleles,
#     T106 last @ 2024 (sim=0.181) | lines, fe, sc, ii, transitions, xvii, levels, spec
#     T113 last @ 2024 (sim=0.165) | debris, trajectory, mission, vlbi, thrust, mars, c
#     T120 last @ 2024 (sim=0.057) | ski, resistance, roughness, snow, deer, bicycle, p
#     ... +22 more
#
#   🔄 EVOLVE (0.2 <= sim < 0.5): 1783 events
#   Per year:
#     2000: 24 topics
#     2001: 24 topics
#     2002: 22 topics
#     2003: 28 topics
#     2004: 36 topics
#     2005: 42 topics
#     2006: 54 topics
#     2007: 52 topics
#     2008: 51 topics
#     2009: 70 topics
#     2010: 73 topics
#     2011: 99 topics
#     2012: 81 topics
#     2013: 78 topics
#     2014: 86 topics
#     2015: 86 topics
#     2016: 98 topics
#     2017: 95 topics
#     2018: 100 topics
#     2019: 105 topics
#     2020: 90 topics
#     2021: 96 topics
#     2022: 98 topics
#     2023: 98 topics
#     2024: 97 topics
#
#   🔗 MERGE GROUPS (sim >= 0.2, >1 source): 140 events
#   Top 10 merges (most sources):
#     T121 @ 2025 ← [121, 180, 187, 197] (sims=[0.3372, 0.2703, 0.2198, 0.2703]) | text, positron, ps, annihilation, antihy
#     T 14 @ 2012 ← [14, 33, 209] (sims=[0.7246, 0.2703, 0.2053]) | plasma, dust, dusty, waves, plasmas, wav
#     T 34 @ 2012 ← [34, 81, 225] (sims=[0.2703, 0.3372, 0.2703]) | graphene, edge, plasmon, bearded, plasmo
#     T 42 @ 2012 ← [42, 158, 220] (sims=[0.6725, 0.2703, 0.2703]) | solitons, soliton, nonlinear, lattices,
#     T158 @ 2020 ← [158, 176, 184] (sims=[0.4841, 0.2703, 0.2703]) | fiber, supercontinuum, saturable, sweepi
#     T  9 @ 2021 ← [9, 149, 172] (sims=[0.6163, 0.276, 0.2703]) | students, physics, graduate, student, ed
#     T  0 @ 2022 ← [0, 125, 172] (sims=[0.8671, 0.2703, 0.2703]) | quantum, functional, density, orbitals,
#     T 99 @ 2001 ← [57, 99] (sims=[0.2198, 0.3138]) | dna, unzipping, sequence, rna, folding,
#     T 82 @ 2001 ← [64, 151] (sims=[0.2703, 0.2703]) | gravitational, zero, instantaneous, rela
#     T 72 @ 2001 ← [72, 82] (sims=[0.3769, 0.2703]) | relativity, morley, michelson, lorentz,
#
#   🆕 NEW TOPICS: 2274 events
#   Per year:
#     2001: 87 new topics
#     2002: 101 new topics
#     2003: 102 new topics
#     2004: 126 new topics
#     2005: 120 new topics
#     2006: 125 new topics
#     2007: 120 new topics
#     2008: 125 new topics
#     2009: 130 new topics
#     2010: 125 new topics
#     2011: 118 new topics
#     2012: 98 new topics
#     2013: 98 new topics
#     2014: 94 new topics
#     2015: 86 new topics
#     2016: 87 new topics
#     2017: 71 new topics
#     2018: 73 new topics
#     2019: 66 new topics
#     2020: 55 new topics
#     2021: 54 new topics
#     2022: 59 new topics
#     2023: 59 new topics
#     2024: 52 new topics
#     2025: 43 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 35 | 82% stable (14S 2Ev 0M 1D)
#     T170 | 75% stable (6S 1Ev 0M 1D)
#     T 32 | 70% stable (16S 4Ev 0M 3D)
#     T 15 | 64% stable (16S 9Ev 0M 0D)
#     T 44 | 61% stable (14S 3Ev 1M 5D)
#   Top 5 most unstable:
#     T224 | 0% stable (0S 7Ev 1M 7D)
#     T226 | 0% stable (0S 4Ev 0M 16D)
#     T229 | 0% stable (0S 9Ev 0M 11D)
#     T230 | 0% stable (0S 10Ev 2M 8D)
#     T231 | 0% stable (0S 4Ev 0M 13D)
