# %% [markdown]
# # BERTopic: Topic Continuity Rate
#
# **Scenario 3b** — Best-match assignment approach.
#
# Each topic at t gets assigned to its **single best match** at t+1:
# - **Stable**: topic maps 1-to-1 (only one t-topic points to this t+1-topic)
# - **Merge**: multiple t-topics point to the same t+1-topic
# - **Disappear**: best match is below threshold (topic lost)
# - **New**: t+1-topic has no incoming match (emerged new)
#
# From t-side: Stable + Merge + Disappear = 100%

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/bertopic/temporal")
RESULT_DIR = Path("../../../../results/bertopic/consistency")
THRESHOLD = 0.5

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Threshold: {THRESHOLD}")
print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Threshold: 0.5
# Reading from: ../../../../results/bertopic/temporal
# Saving to: ../../../../results/bertopic/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list_1, list_2, p=0.9):
    k = min(len(list_1), len(list_2))
    if k == 0:
        return 0.0
    score = 0.0
    # print("List1 : ", list_1)
    # print("List2 : ", list_2)
    for d in range(1, k + 1):
        agreement = len(set(list_1[:d]) & set(list_2[:d])) / d
        score += (p ** (d - 1)) * agreement
    # print("Score : ", score * (1 - p))
    return score * (1 - p)

# %% [markdown]
# ## Compute Continuity Rate (Best-Match)

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Continuity Rate: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())

    all_transition_rows = []
    all_merge_rows = []
    all_new_rows = []
    summary_rows = []

    for i in range(len(years) - 1):
        t, t_next = int(years[i]), int(years[i + 1])

        topics_t = sorted([tid for (y, tid) in topic_words if y == t])
        topics_t1 = sorted([tid for (y, tid) in topic_words if y == t_next])

        if not topics_t or not topics_t1:
            continue

        sim_matrix = np.zeros((len(topics_t), len(topics_t1)))
        for i, tid_t in enumerate(topics_t):
            words_t = topic_words.get((t, tid_t), [])
            for j, tid_t1 in enumerate(topics_t1):
                words_t1 = topic_words.get((t_next, tid_t1), [])
                sim_matrix[i, j] = rbo(words_t, words_t1, p=0.9)

        # Step 1: Each topic at t gets its BEST match at t+1
        best_match_idx = np.argmax(sim_matrix, axis=1)  # index into topics_t1
        best_match_sim = np.max(sim_matrix, axis=1)

        # Step 2: Build assignment map (which t-topics point to which t1-topic)
        assignment = {}  # topic_t → best topic_t1 (or None if below threshold)
        target_counts = Counter()  # topic_t1 → how many t-topics point to it

        for idx, tid in enumerate(topics_t):
            if best_match_sim[idx] >= THRESHOLD:
                target_tid = topics_t1[best_match_idx[idx]]
                assignment[tid] = target_tid
                target_counts[target_tid] += 1
            else:
                assignment[tid] = None  # disappeared

        # Step 3: Classify each topic at t
        n_stable, n_merge, n_disappear = 0, 0, 0
        for idx, tid in enumerate(topics_t):
            target = assignment[tid]
            sim_val = float(best_match_sim[idx])
            words_t = ", ".join(topic_words.get((t, tid), []))

            if target is None:
                category = "disappear"
                n_disappear += 1
            elif target_counts[target] == 1:
                category = "stable"
                n_stable += 1
            else:
                category = "merge"
                n_merge += 1

            all_transition_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "category": category,
                "best_match_topic": target if target is not None else -1,
                "best_match_sim": round(sim_val, 6),
                "words": words_t,
            })

        # Step 4: Detect merge groups (t1-topics with >1 incoming)
        for target_tid, count in target_counts.items():
            if count > 1:
                # Find all source topics
                sources = [tid for tid, tgt in assignment.items() if tgt == target_tid]
                source_sims = []
                for src_tid in sources:
                    src_idx = topics_t.index(src_tid)
                    tgt_idx = topics_t1.index(target_tid)
                    source_sims.append(round(float(sim_matrix[src_idx, tgt_idx]), 4))

                words_t1 = ", ".join(topic_words.get((t_next, target_tid), []))
                all_merge_rows.append({
                    "subject": subject, "year_from": t, "year_to": t_next,
                    "target_topic": target_tid,
                    "n_sources": count,
                    "source_topics": str(sources),
                    "source_sims": str(source_sims),
                    "target_words": words_t1,
                })

        # Step 5: Detect new topics (t1-topics with no incoming)
        matched_t1 = set(assignment.values()) - {None}
        new_topics = [tid for tid in topics_t1 if tid not in matched_t1]
        for tid in new_topics:
            words_t1 = ", ".join(topic_words.get((t_next, tid), []))
            all_new_rows.append({
                "subject": subject, "year_from": t, "year_to": t_next,
                "topic_id": tid, "words": words_t1,
            })

        total_t = len(topics_t)
        n_new = len(new_topics)
        n_merge_groups = sum(1 for c in target_counts.values() if c > 1)

        summary_rows.append({
            "subject": subject, "year_from": t, "year_to": t_next,
            "n_topics_t": total_t, "n_topics_t1": len(topics_t1),
            "n_stable": n_stable, "n_merge": n_merge,
            "n_disappear": n_disappear, "n_merge_groups": n_merge_groups,
            "n_new": n_new,
            "pct_stable": round(n_stable / total_t * 100, 2),
            "pct_merge": round(n_merge / total_t * 100, 2),
            "pct_disappear": round(n_disappear / total_t * 100, 2),
        })

        print(f"  {t}→{t_next}: Stable={n_stable} ({n_stable/total_t:.0%})  "
              f"Merge={n_merge} ({n_merge/total_t:.0%})  "
              f"Disappear={n_disappear} ({n_disappear/total_t:.0%})  "
              f"New={n_new}")

    # Save CSVs
    pd.DataFrame(all_transition_rows).to_csv(
        RESULT_DIR / subject / "continuity_transitions.csv", index=False)
    pd.DataFrame(all_merge_rows).to_csv(
        RESULT_DIR / subject / "continuity_merges.csv", index=False)
    pd.DataFrame(all_new_rows).to_csv(
        RESULT_DIR / subject / "continuity_new_topics.csv", index=False)

    sum_df = pd.DataFrame(summary_rows)
    sum_df.to_csv(RESULT_DIR / subject / "continuity_summary.csv", index=False)

    subj_sum = sum_df[sum_df["subject"] == subject]
    overall = {
        "subject": subject, "threshold": THRESHOLD,
        "avg_pct_stable": round(subj_sum["pct_stable"].mean(), 2),
        "avg_pct_merge": round(subj_sum["pct_merge"].mean(), 2),
        "avg_pct_disappear": round(subj_sum["pct_disappear"].mean(), 2),
        "total_merge_groups": int(subj_sum["n_merge_groups"].sum()),
        "total_new": int(subj_sum["n_new"].sum()),
    }
    pd.DataFrame([overall]).to_csv(
        RESULT_DIR / subject / "continuity_overall.csv", index=False)

    print(f"\n  Overall: Stable={overall['avg_pct_stable']:.1f}%  "
          f"Merge={overall['avg_pct_merge']:.1f}%  "
          f"Disappear={overall['avg_pct_disappear']:.1f}%  "
          f"New={overall['total_new']}")
    print(f"  Saved: {RESULT_DIR / subject}")
# Out:
# ======================================================================
# Continuity Rate: CS (BERTopic)
# ======================================================================
#   2000→2001: Stable=0 (0%)  Merge=0 (0%)  Disappear=47 (100%)  New=63
#   2001→2002: Stable=0 (0%)  Merge=0 (0%)  Disappear=63 (100%)  New=65
#   2002→2003: Stable=1 (2%)  Merge=0 (0%)  Disappear=64 (98%)  New=73
#   2003→2004: Stable=0 (0%)  Merge=0 (0%)  Disappear=74 (100%)  New=95
#   2004→2005: Stable=0 (0%)  Merge=0 (0%)  Disappear=95 (100%)  New=87
#   2005→2006: Stable=1 (1%)  Merge=0 (0%)  Disappear=86 (99%)  New=87
#   2006→2007: Stable=0 (0%)  Merge=0 (0%)  Disappear=88 (100%)  New=82
#   2007→2008: Stable=0 (0%)  Merge=0 (0%)  Disappear=82 (100%)  New=100
#   2008→2009: Stable=0 (0%)  Merge=0 (0%)  Disappear=100 (100%)  New=108
#   2009→2010: Stable=0 (0%)  Merge=0 (0%)  Disappear=108 (100%)  New=126
#   2010→2011: Stable=0 (0%)  Merge=0 (0%)  Disappear=126 (100%)  New=144
#   2011→2012: Stable=0 (0%)  Merge=0 (0%)  Disappear=144 (100%)  New=161
#   2012→2013: Stable=1 (1%)  Merge=0 (0%)  Disappear=160 (99%)  New=177
#   2013→2014: Stable=1 (1%)  Merge=0 (0%)  Disappear=177 (99%)  New=184
#   2014→2015: Stable=1 (1%)  Merge=0 (0%)  Disappear=184 (99%)  New=197
#   2015→2016: Stable=0 (0%)  Merge=0 (0%)  Disappear=198 (100%)  New=225
#   2016→2017: Stable=1 (0%)  Merge=0 (0%)  Disappear=224 (100%)  New=238
#   2017→2018: Stable=5 (2%)  Merge=0 (0%)  Disappear=234 (98%)  New=246
#   2018→2019: Stable=16 (6%)  Merge=0 (0%)  Disappear=235 (94%)  New=239
#   2019→2020: Stable=29 (11%)  Merge=0 (0%)  Disappear=226 (89%)  New=228
#   2020→2021: Stable=38 (15%)  Merge=0 (0%)  Disappear=219 (85%)  New=220
#   2021→2022: Stable=41 (16%)  Merge=0 (0%)  Disappear=217 (84%)  New=219
#   2022→2023: Stable=44 (17%)  Merge=0 (0%)  Disappear=216 (83%)  New=217
#   2023→2024: Stable=45 (17%)  Merge=0 (0%)  Disappear=216 (83%)  New=216
#   2024→2025: Stable=58 (22%)  Merge=0 (0%)  Disappear=203 (78%)  New=202
#
#   Overall: Stable=4.5%  Merge=0.0%  Disappear=95.5%  New=3999
#   Saved: ../../../../results/bertopic/consistency/cs
#
# ======================================================================
# Continuity Rate: MATH (BERTopic)
# ======================================================================
#   2000→2001: Stable=0 (0%)  Merge=0 (0%)  Disappear=92 (100%)  New=101
#   2001→2002: Stable=0 (0%)  Merge=0 (0%)  Disappear=101 (100%)  New=90
#   2002→2003: Stable=0 (0%)  Merge=0 (0%)  Disappear=90 (100%)  New=115
#   2003→2004: Stable=0 (0%)  Merge=0 (0%)  Disappear=115 (100%)  New=118
#   2004→2005: Stable=1 (1%)  Merge=0 (0%)  Disappear=117 (99%)  New=120
#   2005→2006: Stable=0 (0%)  Merge=0 (0%)  Disappear=121 (100%)  New=133
#   2006→2007: Stable=1 (1%)  Merge=0 (0%)  Disappear=132 (99%)  New=137
#   2007→2008: Stable=1 (1%)  Merge=0 (0%)  Disappear=137 (99%)  New=140
#   2008→2009: Stable=0 (0%)  Merge=0 (0%)  Disappear=141 (100%)  New=139
#   2009→2010: Stable=2 (1%)  Merge=0 (0%)  Disappear=137 (99%)  New=139
#   2010→2011: Stable=2 (1%)  Merge=0 (0%)  Disappear=139 (99%)  New=144
#   2011→2012: Stable=1 (1%)  Merge=0 (0%)  Disappear=145 (99%)  New=147
#   2012→2013: Stable=3 (2%)  Merge=0 (0%)  Disappear=145 (98%)  New=147
#   2013→2014: Stable=3 (2%)  Merge=0 (0%)  Disappear=147 (98%)  New=147
#   2014→2015: Stable=5 (3%)  Merge=0 (0%)  Disappear=145 (97%)  New=144
#   2015→2016: Stable=5 (3%)  Merge=0 (0%)  Disappear=144 (97%)  New=145
#   2016→2017: Stable=8 (5%)  Merge=0 (0%)  Disappear=142 (95%)  New=142
#   2017→2018: Stable=9 (6%)  Merge=0 (0%)  Disappear=141 (94%)  New=141
#   2018→2019: Stable=9 (6%)  Merge=0 (0%)  Disappear=141 (94%)  New=141
#   2019→2020: Stable=10 (7%)  Merge=0 (0%)  Disappear=140 (93%)  New=140
#   2020→2021: Stable=10 (7%)  Merge=0 (0%)  Disappear=140 (93%)  New=140
#   2021→2022: Stable=9 (6%)  Merge=0 (0%)  Disappear=141 (94%)  New=141
#   2022→2023: Stable=7 (5%)  Merge=0 (0%)  Disappear=143 (95%)  New=143
#   2023→2024: Stable=7 (5%)  Merge=0 (0%)  Disappear=143 (95%)  New=143
#   2024→2025: Stable=19 (13%)  Merge=0 (0%)  Disappear=131 (87%)  New=131
#
#   Overall: Stable=3.0%  Merge=0.0%  Disappear=97.0%  New=3368
#   Saved: ../../../../results/bertopic/consistency/math
#
# ======================================================================
# Continuity Rate: PHYSICS (BERTopic)
# ======================================================================
#   2000→2001: Stable=0 (0%)  Merge=0 (0%)  Disappear=108 (100%)  New=114
#   2001→2002: Stable=0 (0%)  Merge=0 (0%)  Disappear=114 (100%)  New=128
#   2002→2003: Stable=0 (0%)  Merge=0 (0%)  Disappear=128 (100%)  New=125
#   2003→2004: Stable=0 (0%)  Merge=0 (0%)  Disappear=125 (100%)  New=158
#   2004→2005: Stable=0 (0%)  Merge=0 (0%)  Disappear=158 (100%)  New=157
#   2005→2006: Stable=0 (0%)  Merge=0 (0%)  Disappear=157 (100%)  New=174
#   2006→2007: Stable=0 (0%)  Merge=0 (0%)  Disappear=174 (100%)  New=182
#   2007→2008: Stable=2 (1%)  Merge=0 (0%)  Disappear=180 (99%)  New=189
#   2008→2009: Stable=0 (0%)  Merge=0 (0%)  Disappear=191 (100%)  New=196
#   2009→2010: Stable=1 (1%)  Merge=0 (0%)  Disappear=195 (99%)  New=208
#   2010→2011: Stable=2 (1%)  Merge=0 (0%)  Disappear=207 (99%)  New=217
#   2011→2012: Stable=3 (1%)  Merge=0 (0%)  Disappear=216 (99%)  New=220
#   2012→2013: Stable=3 (1%)  Merge=0 (0%)  Disappear=220 (99%)  New=219
#   2013→2014: Stable=3 (1%)  Merge=0 (0%)  Disappear=219 (99%)  New=218
#   2014→2015: Stable=5 (2%)  Merge=0 (0%)  Disappear=216 (98%)  New=219
#   2015→2016: Stable=4 (2%)  Merge=0 (0%)  Disappear=220 (98%)  New=224
#   2016→2017: Stable=5 (2%)  Merge=0 (0%)  Disappear=223 (98%)  New=226
#   2017→2018: Stable=14 (6%)  Merge=0 (0%)  Disappear=217 (94%)  New=217
#   2018→2019: Stable=10 (4%)  Merge=0 (0%)  Disappear=221 (96%)  New=222
#   2019→2020: Stable=11 (5%)  Merge=0 (0%)  Disappear=221 (95%)  New=220
#   2020→2021: Stable=15 (6%)  Merge=0 (0%)  Disappear=216 (94%)  New=217
#   2021→2022: Stable=11 (5%)  Merge=0 (0%)  Disappear=221 (95%)  New=221
#   2022→2023: Stable=12 (5%)  Merge=0 (0%)  Disappear=220 (95%)  New=219
#   2023→2024: Stable=15 (6%)  Merge=0 (0%)  Disappear=216 (94%)  New=216
#   2024→2025: Stable=19 (8%)  Merge=0 (0%)  Disappear=212 (92%)  New=213
#
#   Overall: Stable=2.4%  Merge=0.0%  Disappear=97.6%  New=4919
#   Saved: ../../../../results/bertopic/consistency/physics

# %% [markdown]
# ## Analysis Review

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Analysis Review: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    trans_df = pd.read_csv(RESULT_DIR / subject / "continuity_transitions.csv")
    merge_path = RESULT_DIR / subject / "continuity_merges.csv"
    merge_df = pd.read_csv(merge_path) if merge_path.stat().st_size > 10 else pd.DataFrame()
    new_path = RESULT_DIR / subject / "continuity_new_topics.csv"
    new_df = pd.read_csv(new_path) if new_path.stat().st_size > 10 else pd.DataFrame()
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    # --- DISAPPEARED ---
    disappeared = trans_df[trans_df["category"] == "disappear"]
    print(f"\n  📉 DISAPPEARED: {len(disappeared)} events")
    if len(disappeared) > 0:
        per_year = disappeared.groupby("year_from").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} topics")

        # Permanently gone
        perm = []
        for _, r in disappeared.iterrows():
            tid = int(r['topic_id'])
            later = evo_df[(evo_df['topic_id'] == tid) & (evo_df['year'] > int(r['year_to']))]
            if len(later) == 0:
                w = str(r['words'])[:50]
                perm.append(f"    T{tid:>3} last @ {int(r['year_from'])} (sim={r['best_match_sim']:.3f}) | {w}")
        print(f"\n  Permanently gone: {len(perm)}")
        for line in perm[:10]:
            print(line)
        if len(perm) > 10:
            print(f"    ... +{len(perm)-10} more")

    # --- MERGE GROUPS ---
    print(f"\n  🔗 MERGE GROUPS: {len(merge_df)} events")
    if len(merge_df) > 0:
        print(f"  Top 10 merges (most sources):")
        for _, r in merge_df.nlargest(10, 'n_sources').iterrows():
            w = str(r['target_words'])[:40]
            print(f"    T{int(r['target_topic']):>3} @ {int(r['year_to'])} "
                  f"← {r['source_topics']} (sims={r['source_sims']}) | {w}")

    # --- NEW TOPICS ---
    print(f"\n  🆕 NEW TOPICS: {len(new_df)} events")
    if len(new_df) > 0:
        per_year = new_df.groupby("year_to").size()
        print(f"  Per year:")
        for yr, cnt in per_year.items():
            print(f"    {int(yr)}: {cnt} new topics")

    # --- STABILITY RANKING ---
    print(f"\n  🏆 STABILITY RANKING:")
    ts = trans_df.groupby("topic_id")["category"].value_counts().unstack(fill_value=0)
    for cat in ["stable", "merge", "disappear"]:
        if cat not in ts.columns:
            ts[cat] = 0
    ts["total"] = ts.sum(axis=1)
    ts["stability_pct"] = (ts["stable"] / ts["total"] * 100).round(1)
    ts = ts.sort_values("stability_pct", ascending=False)

    print(f"  Top 5 most stable:")
    for tid, r in ts.head(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print(f"  Top 5 most unstable:")
    for tid, r in ts.tail(5).iterrows():
        print(f"    T{int(tid):>3} | {r['stability_pct']:.0f}% stable "
              f"({int(r['stable'])}S {int(r['merge'])}M {int(r['disappear'])}D)")
    print()
# Out:
# ======================================================================
# Analysis Review: CS (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 3786 events
#   Per year:
#     2000: 47 topics
#     2001: 63 topics
#     2002: 64 topics
#     2003: 74 topics
#     2004: 95 topics
#     2005: 86 topics
#     2006: 88 topics
#     2007: 82 topics
#     2008: 100 topics
#     2009: 108 topics
#     2010: 126 topics
#     2011: 144 topics
#     2012: 160 topics
#     2013: 177 topics
#     2014: 184 topics
#     2015: 198 topics
#     2016: 224 topics
#     2017: 234 topics
#     2018: 235 topics
#     2019: 226 topics
#     2020: 219 topics
#     2021: 217 topics
#     2022: 216 topics
#     2023: 216 topics
#     2024: 203 topics
#
#   Permanently gone: 204
#     T218 last @ 2023 (sim=0.113) | relays, coherence, channel, superposition, relay,
#     T  0 last @ 2024 (sim=0.480) | graphs, log, vertex, kk, graph, gg, vertices, math
#     T  4 last @ 2024 (sim=0.213) | type, calculus, logics, logic, proof, sequent, sem
#     T  9 last @ 2024 (sim=0.308) | memory, cxl, gpu, cpu, pim, performance, hardware,
#     T 10 last @ 2024 (sim=0.466) | speech, tts, sound, speaker, acoustic, audio, voic
#     T 13 last @ 2024 (sim=0.431) | mimo, channel, oam, afdm, otfs, downlink, massive,
#     T 16 last @ 2024 (sim=0.204) | sar, species, remote, underwater, sensing, images,
#     T 17 last @ 2024 (sim=0.414) | community, communities, networks, louvain, modular
#     T 18 last @ 2024 (sim=0.395) | llms, attacks, safety, jailbreak, attack, harmful,
#     T 20 last @ 2024 (sim=0.347) | neural, networks, activation, relu, functions, nor
#     ... +194 more
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 3999 events
#   Per year:
#     2001: 63 new topics
#     2002: 65 new topics
#     2003: 73 new topics
#     2004: 95 new topics
#     2005: 87 new topics
#     2006: 87 new topics
#     2007: 82 new topics
#     2008: 100 new topics
#     2009: 108 new topics
#     2010: 126 new topics
#     2011: 144 new topics
#     2012: 161 new topics
#     2013: 177 new topics
#     2014: 184 new topics
#     2015: 197 new topics
#     2016: 225 new topics
#     2017: 238 new topics
#     2018: 246 new topics
#     2019: 239 new topics
#     2020: 228 new topics
#     2021: 220 new topics
#     2022: 219 new topics
#     2023: 217 new topics
#     2024: 216 new topics
#     2025: 202 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 74 | 78% stable (7S 0M 2D)
#     T 73 | 70% stable (7S 0M 3D)
#     T  8 | 64% stable (7S 0M 4D)
#     T 76 | 57% stable (8S 0M 6D)
#     T182 | 57% stable (4S 0M 3D)
#   Top 5 most unstable:
#     T256 | 0% stable (0S 0M 11D)
#     T257 | 0% stable (0S 0M 14D)
#     T258 | 0% stable (0S 0M 8D)
#     T259 | 0% stable (0S 0M 18D)
#     T260 | 0% stable (0S 0M 8D)
#
#
# ======================================================================
# Analysis Review: MATH (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 3310 events
#   Per year:
#     2000: 92 topics
#     2001: 101 topics
#     2002: 90 topics
#     2003: 115 topics
#     2004: 117 topics
#     2005: 121 topics
#     2006: 132 topics
#     2007: 137 topics
#     2008: 141 topics
#     2009: 137 topics
#     2010: 139 topics
#     2011: 145 topics
#     2012: 145 topics
#     2013: 147 topics
#     2014: 145 topics
#     2015: 144 topics
#     2016: 142 topics
#     2017: 141 topics
#     2018: 141 topics
#     2019: 140 topics
#     2020: 140 topics
#     2021: 141 topics
#     2022: 143 topics
#     2023: 143 topics
#     2024: 131 topics
#
#   Permanently gone: 131
#     T  2 last @ 2024 (sim=0.388) | regression, inference, causal, data, estimators, e
#     T  6 last @ 2024 (sim=0.480) | algebras, mathcal, algebra, groupoid, unital, math
#     T  8 last @ 2024 (sim=0.298) | nabla, solutions, equation, regularity, begin, ell
#     T  9 last @ 2024 (sim=0.311) | fano, moduli, curves, surfaces, projective, variet
#     T 11 last @ 2024 (sim=0.344) | hler, ricci, metrics, metric, curvature, einstein,
#     T 12 last @ 2024 (sim=0.274) | anosov, entropy, maps, pseudo, diffeomorphisms, er
#     T 13 last @ 2024 (sim=0.412) | equation, dinger, schr, solutions, frac, nonlinear
#     T 15 last @ 2024 (sim=0.289) | operators, resolvent, operator, dinger, schr, spec
#     T 16 last @ 2024 (sim=0.407) | quantum, classical, entanglement, qubit, state, op
#     T 17 last @ 2024 (sim=0.381) | permutations, words, permutation, pattern, descent
#     ... +121 more
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 3368 events
#   Per year:
#     2001: 101 new topics
#     2002: 90 new topics
#     2003: 115 new topics
#     2004: 118 new topics
#     2005: 120 new topics
#     2006: 133 new topics
#     2007: 137 new topics
#     2008: 140 new topics
#     2009: 139 new topics
#     2010: 139 new topics
#     2011: 144 new topics
#     2012: 147 new topics
#     2013: 147 new topics
#     2014: 147 new topics
#     2015: 144 new topics
#     2016: 145 new topics
#     2017: 142 new topics
#     2018: 141 new topics
#     2019: 141 new topics
#     2020: 140 new topics
#     2021: 140 new topics
#     2022: 141 new topics
#     2023: 143 new topics
#     2024: 143 new topics
#     2025: 131 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T  4 | 48% stable (12S 0M 13D)
#     T  0 | 44% stable (11S 0M 14D)
#     T  1 | 32% stable (8S 0M 17D)
#     T 94 | 29% stable (6S 0M 15D)
#     T 10 | 28% stable (7S 0M 18D)
#   Top 5 most unstable:
#     T142 | 0% stable (0S 0M 25D)
#     T145 | 0% stable (0S 0M 25D)
#     T146 | 0% stable (0S 0M 25D)
#     T148 | 0% stable (0S 0M 24D)
#     T149 | 0% stable (0S 0M 23D)
#
#
# ======================================================================
# Analysis Review: PHYSICS (BERTopic)
# ======================================================================
#
#   📉 DISAPPEARED: 4795 events
#   Per year:
#     2000: 108 topics
#     2001: 114 topics
#     2002: 128 topics
#     2003: 125 topics
#     2004: 158 topics
#     2005: 157 topics
#     2006: 174 topics
#     2007: 180 topics
#     2008: 191 topics
#     2009: 195 topics
#     2010: 207 topics
#     2011: 216 topics
#     2012: 220 topics
#     2013: 219 topics
#     2014: 216 topics
#     2015: 220 topics
#     2016: 223 topics
#     2017: 217 topics
#     2018: 221 topics
#     2019: 221 topics
#     2020: 216 topics
#     2021: 221 topics
#     2022: 220 topics
#     2023: 216 topics
#     2024: 212 topics
#
#   Permanently gone: 212
#     T  0 last @ 2024 (sim=0.357) | quantum, methods, cluster, state, basis, density,
#     T  2 last @ 2024 (sim=0.406) | epidemic, vaccination, disease, covid, pandemic, i
#     T  6 last @ 2024 (sim=0.239) | crack, fracture, fatigue, materials, stress, pore,
#     T  7 last @ 2024 (sim=0.446) | quantum, bell, mechanics, theory, metaphysics, ont
#     T  8 last @ 2024 (sim=0.313) | beam, emittance, luminosity, csr, collider, synchr
#     T 10 last @ 2024 (sim=0.162) | trade, economic, financial, countries, firms, regi
#     T 11 last @ 2024 (sim=0.340) | gyrokinetic, stellarator, tokamak, divertor, plasm
#     T 12 last @ 2024 (sim=0.452) | ionization, attosecond, photoelectron, photoioniza
#     T 14 last @ 2024 (sim=0.321) | plasma, dust, ion, plasmas, waves, magnetized, cnl
#     T 15 last @ 2024 (sim=0.326) | dark, universe, matter, inflation, cosmological, o
#     ... +202 more
#
#   🔗 MERGE GROUPS: 0 events
#
#   🆕 NEW TOPICS: 4919 events
#   Per year:
#     2001: 114 new topics
#     2002: 128 new topics
#     2003: 125 new topics
#     2004: 158 new topics
#     2005: 157 new topics
#     2006: 174 new topics
#     2007: 182 new topics
#     2008: 189 new topics
#     2009: 196 new topics
#     2010: 208 new topics
#     2011: 217 new topics
#     2012: 220 new topics
#     2013: 219 new topics
#     2014: 218 new topics
#     2015: 219 new topics
#     2016: 224 new topics
#     2017: 226 new topics
#     2018: 217 new topics
#     2019: 222 new topics
#     2020: 220 new topics
#     2021: 217 new topics
#     2022: 221 new topics
#     2023: 219 new topics
#     2024: 216 new topics
#     2025: 213 new topics
#
#   🏆 STABILITY RANKING:
#   Top 5 most stable:
#     T 35 | 59% stable (10S 0M 7D)
#     T170 | 38% stable (3S 0M 5D)
#     T 13 | 35% stable (7S 0M 13D)
#     T  5 | 32% stable (6S 0M 13D)
#     T 44 | 30% stable (7S 0M 16D)
#   Top 5 most unstable:
#     T227 | 0% stable (0S 0M 17D)
#     T228 | 0% stable (0S 0M 21D)
#     T229 | 0% stable (0S 0M 20D)
#     T230 | 0% stable (0S 0M 20D)
#     T231 | 0% stable (0S 0M 17D)
