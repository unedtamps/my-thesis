# %% [markdown]
# # BERTopic: Topic Term Drift (TTD)
#
# **Scenario 3a** — Three complementary drift metrics:
# 1. **Endpoint TTD**: cosine distance from first to last year (total drift)
# 2. **Trajectory from baseline**: cosine_sim(t₀, t) per year (when drift happens)
# 3. **Year-over-year drift**: cosine_sim(t, t+1) per year (smoothness of evolution)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/bertopic/temporal")
RESULT_DIR = Path("../../../../results/bertopic/consistency")

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Reading from: ../../../../results/bertopic/temporal
# Saving to: ../../../../results/bertopic/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def rbo(list1, list2, p=0.9):
    if not list1 and not list2:
        return 1.0
    if not list1 or not list2:
        return 0.0

    # assign short (S) and long (L)
    if len(list1) <= len(list2):
        S, L = list1, list2
    else:
        S, L = list2, list1

    s, l = len(S), len(L)

    S_seen = set()
    L_seen = set()

    X = 0  # overlap
    rbo = 0.0
    disjoint = 0.0
    ext_term = 0.0

    for d in range(l):
        if d < s:
            s_item = S[d]
            S_seen.add(s_item)
        else:
            s_item = None

        l_item = L[d]
        L_seen.add(l_item)

        overlap_incr = 0

        if d < s:
            if s_item == l_item:
                overlap_incr = 1
            else:
                if s_item in L_seen:
                    overlap_incr += 1
                if l_item in S_seen:
                    overlap_incr += 1
        else:
            if l_item in S_seen:
                overlap_incr = 1

        X += overlap_incr

        if d < s:
            A_d = 2.0 * X / (len(S_seen) + len(L_seen))
        else:
            A_d = X / (d + 1)

        rbo += (1 - p) * (p ** d) * A_d

        if d < s:
            ext_term = A_d * (p ** (d + 1))
        else:
            X_s = X - overlap_incr if d == s else X_s
            disjoint += (1 - p) * (p ** d) * (
                X_s * (d + 1 - s) / ((d + 1) * s)
            )
            ext_term = (
                ((X - X_s) / (d + 1) + X_s / s)
                * (p ** (d + 1))
            )

        # optional optimization (safe)
        if p ** d < 1e-12:
            break

    return min(max(rbo + disjoint + ext_term, 0.0), 1.0)

# %% [markdown]
# ## 1. Endpoint TTD
# Total drift: `TTD = 1 - cosine_sim(words_first, words_last)`

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Endpoint TTD: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())


    rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t_first, t_last = topic_years[0], topic_years[-1]
        sim = rbo(topic_words[(t_first, tid)], topic_words[(t_last, tid)], p=0.9)

        rows.append({
            "subject": subject, "topic_id": tid,
            "first_year": t_first, "last_year": t_last,
            "n_years": len(topic_years),
            "cosine_sim": round(sim, 6),
            "ttd": round(1.0 - sim, 6),
            "words_first": ", ".join(topic_words[(t_first, tid)]),
            "words_last": ", ".join(topic_words[(t_last, tid)]),
        })

    df = pd.DataFrame(rows)
    df.to_csv(RESULT_DIR / subject / "topic_term_drift.csv", index=False)

    summary = {"subject": subject, "n_topics": len(df),
               "ttd_mean": round(df["ttd"].mean(), 6),
               "ttd_std": round(df["ttd"].std(), 6),
               "ttd_median": round(df["ttd"].median(), 6),
               "pct_stable": round((df["ttd"] < 0.5).mean() * 100, 2),
               "pct_drifted": round((df["ttd"] >= 0.5).mean() * 100, 2)}
    pd.DataFrame([summary]).to_csv(RESULT_DIR / subject / "ttd_summary.csv", index=False)

    print(f"  TTD: mean={summary['ttd_mean']:.4f} ± {summary['ttd_std']:.4f}, "
          f"median={summary['ttd_median']:.4f}")
    print(f"  Stable (TTD<0.5): {summary['pct_stable']:.1f}%  |  "
          f"Drifted (TTD≥0.5): {summary['pct_drifted']:.1f}%")

    print(f"\n  �� Top 5 most DRIFTED:")
    for _, r in df.nlargest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | "
              f"{r['words_first'][:40]}... → {r['words_last'][:40]}...")

    print(f"  🔒 Top 5 most STABLE:")
    for _, r in df.nsmallest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | {r['words_first'][:60]}")
# Out:
# ======================================================================
# Endpoint TTD: CS (BERTopic)
# ======================================================================
#   TTD: mean=0.9026 ± 0.1129, median=0.9429
#   Stable (TTD<0.5): 1.1%  |  Drifted (TTD≥0.5): 98.8%
#
#   �� Top 5 most DRIFTED:
#     T  2 | TTD=1.0000 | imagined, annotation, keywords, plsa, an... → visual, multimodal, reasoning, vision, v...
#     T  7 | TTD=1.0000 | clouds, kernels, jects, point, ob, recur... → graph, node, gnns, graphs, gnn, nodes, n...
#     T  9 | TTD=1.0000 | massively, simd, misses, grids, surface,... → gpu, memory, hardware, workloads, gpus, ...
#     T 10 | TTD=1.0000 | resonances, filter, allpass, rectangular... → speech, audio, acoustic, sound, tts, spe...
#     T 11 | TTD=1.0000 | paypal, company, anyone, email, payment,... → blockchain, contracts, smart, transactio...
#   🔒 Top 5 most STABLE:
#     T 58 | TTD=0.4191 | market, stock, trading, eurodollar, traders, price, indices,
#     T 74 | TTD=0.4507 | uavs, uav, coverage, unmanned, d2d, aerial, area, 5g, altitu
#     T  4 | TTD=0.4844 | logic, termination, programs, semantics, logics, programming
#     T112 | TTD=0.5061 | person, re, mcm, identification, component, framework, multi
#     T228 | TTD=0.6089 | out, classifiers, distribution, samples, ood, detecting, cla
#
# ======================================================================
# Endpoint TTD: MATH (BERTopic)
# ======================================================================
#   TTD: mean=0.8599 ± 0.1357, median=0.9017
#   Stable (TTD<0.5): 0.7%  |  Drifted (TTD≥0.5): 99.3%
#
#   �� Top 5 most DRIFTED:
#     T  2 | TTD=1.0000 | mdma, asthma, jack, jackknife, particula... → causal, regression, estimator, estimatio...
#     T  8 | TTD=1.0000 | damascelli, 0lu, pacella, monotonicity, ... → solutions, elliptic, regularity, nabla, ...
#     T 14 | TTD=1.0000 | scaled, self, cones, barrier, barriers, ... → optimization, problems, bilevel, program...
#     T 15 | TTD=1.0000 | gustavson, scattering, normalization, an... → magnetic, operators, spectral, schr, din...
#     T 18 | TTD=1.0000 | hoelder, rough, brownian, continuity, en... → stochastic, noise, driven, sdes, differe...
#   🔒 Top 5 most STABLE:
#     T 78 | TTD=0.4844 | cardinal, forcing, kappa, cardinals, beth, aleph, maximality
#     T 44 | TTD=0.5313 | witten, gromov, invariants, cy3, brane, calabi, tinybbb, yau
#     T  3 | TTD=0.5324 | knots, vassiliev, invariants, knot, moves, fillings, legendr
#     T128 | TTD=0.5506 | mapping, group, representation, ergodically, class, braid, g
#     T101 | TTD=0.5549 | continued, fractions, specializable, bifurcating, fraction,
#
# ======================================================================
# Endpoint TTD: PHYSICS (BERTopic)
# ======================================================================
#   TTD: mean=0.8913 ± 0.1218, median=0.9380
#   Stable (TTD<0.5): 0.4%  |  Drifted (TTD≥0.5): 99.6%
#
#   �� Top 5 most DRIFTED:
#     T  1 | TTD=1.0000 | cwt, interferograms, turbid, ridge, spat... → imaging, microscopy, resolution, image, ...
#     T  4 | TTD=1.0000 | gps, tec, cir, ionospheric, ionosphere, ... → solar, wind, coronal, cme, magnetic, obs...
#     T  5 | TTD=1.0000 | reaction, passage, pathways, exemplary, ... → learning, molecular, machine, chemical, ...
#     T 19 | TTD=1.0000 | paperless, coauthored, scientists, paper... → citation, scientific, research, science,...
#     T 20 | TTD=1.0000 | mg2sio4, nanobelts, forsterite, sio2, 6a... → perovskite, perovskites, halide, solar, ...
#   🔒 Top 5 most STABLE:
#     T 49 | TTD=0.4753 | opinion, nu, political, voter, decision, vote, voters, conse
#     T148 | TTD=0.5299 | languages, language, linguistic, texts, hamming, speakers, m
#     T130 | TTD=0.5609 | black, ah, hole, protons, scalar, wormhole, charged, spaceti
#     T 95 | TTD=0.5796 | wakefield, bunch, relativistic, accelerated, accelerator, re
#     T  7 | TTD=0.5943 | epr, quantum, common, mechanics, bell, cause, probability, i

# %% [markdown]
# ## 2. Drift Trajectory from Baseline
# For each topic: `cosine_sim(words_t₀, words_t)` per year — shows **when** drift happens

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Drift Trajectory: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())


    traj_rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t0 = topic_years[0]
        words_baseline = topic_words[(t0, tid)]

        for y in topic_years:
            words_y = topic_words[(y, tid)]
            sim = rbo(words_baseline, words_y, p=0.9)
            traj_rows.append({
                "subject": subject, "topic_id": tid,
                "baseline_year": t0, "year": y,
                "years_elapsed": y - t0,
                "cosine_sim_to_baseline": round(sim, 6),
                "drift_from_baseline": round(1.0 - sim, 6),
            })

    traj_df = pd.DataFrame(traj_rows)
    traj_df.to_csv(RESULT_DIR / subject / "ttd_trajectory.csv", index=False)

    # Average drift trajectory across all topics per year
    avg_traj = traj_df.groupby("year").agg(
        avg_sim=("cosine_sim_to_baseline", "mean"),
        avg_drift=("drift_from_baseline", "mean"),
        n_topics=("topic_id", "count")
    ).reset_index()
    avg_traj.insert(0, "subject", subject)
    avg_traj.to_csv(RESULT_DIR / subject / "ttd_trajectory_avg.csv", index=False)

    print(f"  Avg drift from baseline per year:")
    for _, r in avg_traj.iterrows():
        bar = '█' * int(r['avg_drift'] * 50)
        print(f"    {int(r['year'])}: sim={r['avg_sim']:.4f}  drift={r['avg_drift']:.4f}  {bar}")
    print(f"  Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv")
# Out:
# ======================================================================
# Drift Trajectory: CS (BERTopic)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.5012  drift=0.4988  ████████████████████████
#     2002: sim=0.3910  drift=0.6090  ██████████████████████████████
#     2003: sim=0.3208  drift=0.6792  █████████████████████████████████
#     2004: sim=0.3435  drift=0.6565  ████████████████████████████████
#     2005: sim=0.2422  drift=0.7578  █████████████████████████████████████
#     2006: sim=0.1624  drift=0.8376  █████████████████████████████████████████
#     2007: sim=0.1068  drift=0.8932  ████████████████████████████████████████████
#     2008: sim=0.1238  drift=0.8762  ███████████████████████████████████████████
#     2009: sim=0.1296  drift=0.8704  ███████████████████████████████████████████
#     2010: sim=0.1666  drift=0.8334  █████████████████████████████████████████
#     2011: sim=0.1196  drift=0.8804  ████████████████████████████████████████████
#     2012: sim=0.1169  drift=0.8831  ████████████████████████████████████████████
#     2013: sim=0.0982  drift=0.9018  █████████████████████████████████████████████
#     2014: sim=0.1086  drift=0.8914  ████████████████████████████████████████████
#     2015: sim=0.1298  drift=0.8702  ███████████████████████████████████████████
#     2016: sim=0.1341  drift=0.8659  ███████████████████████████████████████████
#     2017: sim=0.1069  drift=0.8931  ████████████████████████████████████████████
#     2018: sim=0.1226  drift=0.8774  ███████████████████████████████████████████
#     2019: sim=0.1045  drift=0.8955  ████████████████████████████████████████████
#     2020: sim=0.1053  drift=0.8947  ████████████████████████████████████████████
#     2021: sim=0.1104  drift=0.8896  ████████████████████████████████████████████
#     2022: sim=0.1056  drift=0.8944  ████████████████████████████████████████████
#     2023: sim=0.1075  drift=0.8925  ████████████████████████████████████████████
#     2024: sim=0.1009  drift=0.8991  ████████████████████████████████████████████
#     2025: sim=0.0978  drift=0.9022  █████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: MATH (BERTopic)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.3072  drift=0.6928  ██████████████████████████████████
#     2002: sim=0.1343  drift=0.8657  ███████████████████████████████████████████
#     2003: sim=0.2254  drift=0.7746  ██████████████████████████████████████
#     2004: sim=0.1647  drift=0.8353  █████████████████████████████████████████
#     2005: sim=0.1460  drift=0.8540  ██████████████████████████████████████████
#     2006: sim=0.1514  drift=0.8486  ██████████████████████████████████████████
#     2007: sim=0.1339  drift=0.8661  ███████████████████████████████████████████
#     2008: sim=0.1372  drift=0.8628  ███████████████████████████████████████████
#     2009: sim=0.1235  drift=0.8765  ███████████████████████████████████████████
#     2010: sim=0.1273  drift=0.8727  ███████████████████████████████████████████
#     2011: sim=0.1317  drift=0.8683  ███████████████████████████████████████████
#     2012: sim=0.1247  drift=0.8753  ███████████████████████████████████████████
#     2013: sim=0.1321  drift=0.8679  ███████████████████████████████████████████
#     2014: sim=0.1213  drift=0.8787  ███████████████████████████████████████████
#     2015: sim=0.1304  drift=0.8696  ███████████████████████████████████████████
#     2016: sim=0.1385  drift=0.8615  ███████████████████████████████████████████
#     2017: sim=0.1300  drift=0.8700  ███████████████████████████████████████████
#     2018: sim=0.1419  drift=0.8581  ██████████████████████████████████████████
#     2019: sim=0.1343  drift=0.8657  ███████████████████████████████████████████
#     2020: sim=0.1344  drift=0.8656  ███████████████████████████████████████████
#     2021: sim=0.1284  drift=0.8716  ███████████████████████████████████████████
#     2022: sim=0.1353  drift=0.8647  ███████████████████████████████████████████
#     2023: sim=0.1296  drift=0.8704  ███████████████████████████████████████████
#     2024: sim=0.1351  drift=0.8649  ███████████████████████████████████████████
#     2025: sim=0.1401  drift=0.8599  ██████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: PHYSICS (BERTopic)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.3640  drift=0.6360  ███████████████████████████████
#     2002: sim=0.2475  drift=0.7525  █████████████████████████████████████
#     2003: sim=0.1774  drift=0.8226  █████████████████████████████████████████
#     2004: sim=0.1810  drift=0.8190  ████████████████████████████████████████
#     2005: sim=0.1721  drift=0.8279  █████████████████████████████████████████
#     2006: sim=0.1459  drift=0.8541  ██████████████████████████████████████████
#     2007: sim=0.1221  drift=0.8779  ███████████████████████████████████████████
#     2008: sim=0.0890  drift=0.9110  █████████████████████████████████████████████
#     2009: sim=0.0944  drift=0.9056  █████████████████████████████████████████████
#     2010: sim=0.1149  drift=0.8851  ████████████████████████████████████████████
#     2011: sim=0.1169  drift=0.8831  ████████████████████████████████████████████
#     2012: sim=0.1083  drift=0.8917  ████████████████████████████████████████████
#     2013: sim=0.1027  drift=0.8973  ████████████████████████████████████████████
#     2014: sim=0.1050  drift=0.8950  ████████████████████████████████████████████
#     2015: sim=0.1120  drift=0.8880  ████████████████████████████████████████████
#     2016: sim=0.1091  drift=0.8909  ████████████████████████████████████████████
#     2017: sim=0.1088  drift=0.8912  ████████████████████████████████████████████
#     2018: sim=0.1103  drift=0.8897  ████████████████████████████████████████████
#     2019: sim=0.1088  drift=0.8912  ████████████████████████████████████████████
#     2020: sim=0.1090  drift=0.8910  ████████████████████████████████████████████
#     2021: sim=0.1056  drift=0.8944  ████████████████████████████████████████████
#     2022: sim=0.1080  drift=0.8920  ████████████████████████████████████████████
#     2023: sim=0.1087  drift=0.8913  ████████████████████████████████████████████
#     2024: sim=0.1076  drift=0.8924  ████████████████████████████████████████████
#     2025: sim=0.1087  drift=0.8913  ████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv

# %% [markdown]
# ## 3. Year-over-Year Drift
# `cosine_sim(words_t, words_t+1)` — detects **sudden jumps** vs gradual evolution

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Year-over-Year Drift: {subject.upper()}")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row['year']), int(row['topic_id']))
        topic_words[key] = parse_words(row['top_words'])

    years = sorted(evo_df['year'].unique())


    yoy_rows = []

    # Iterate by CONSECUTIVE CALENDAR YEARS
    for i in range(len(years) - 1):
        t, t1 = int(years[i]), int(years[i + 1])

        # Find topics present in BOTH years
        topics_t = {tid for (y, tid) in topic_words if y == t}
        topics_t1 = {tid for (y, tid) in topic_words if y == t1}
        common_topics = sorted(topics_t & topics_t1)

        for tid in common_topics:
            words_t = topic_words[(t, tid)]
            words_t1 = topic_words[(t1, tid)]
            sim = rbo(words_t, words_t1, p=0.9)

            yoy_rows.append({
                'subject': subject, 'topic_id': tid,
                'year_from': t, 'year_to': t1,
                'cosine_sim': round(sim, 6),
                'drift': round(1.0 - sim, 6),
            })

    yoy_df = pd.DataFrame(yoy_rows)
    yoy_df.to_csv(RESULT_DIR / subject / "ttd_year_over_year.csv", index=False)

    # Per-topic summary
    topic_yoy = yoy_df.groupby('topic_id').agg(
        avg_yoy_sim=('cosine_sim', 'mean'),
        min_yoy_sim=('cosine_sim', 'min'),
        avg_yoy_drift=('drift', 'mean'),
        max_single_jump=('drift', 'max'),
    ).reset_index()
    topic_yoy.insert(0, 'subject', subject)
    topic_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_per_topic.csv", index=False)

    # Avg across all topics per year transition
    avg_yoy = yoy_df.groupby(['year_from', 'year_to']).agg(
        avg_sim=('cosine_sim', 'mean'),
        avg_drift=('drift', 'mean'),
        n_topics=('topic_id', 'count')
    ).reset_index()
    avg_yoy.insert(0, 'subject', subject)
    avg_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_avg.csv", index=False)

    print(f"  Avg year-over-year drift (consecutive calendar years):")
    for _, r in avg_yoy.iterrows():
        bar = chr(9608) * int(r['avg_drift'] * 50)
        print(f"    {int(r['year_from'])}→{int(r['year_to'])}: sim={r['avg_sim']:.4f}  "
              f"drift={r['avg_drift']:.4f}  ({int(r['n_topics'])} topics)  {bar}")

    # Top 5 biggest single-year jumps
    print(f"\n  Top 5 biggest single-year JUMPS:")
    for _, r in yoy_df.nlargest(5, 'drift').iterrows():
        print(f"    T{int(r['topic_id']):>3} | {int(r['year_from'])}→{int(r['year_to'])} | "
              f"drift={r['drift']:.4f}")

    overall_sim = yoy_df['cosine_sim'].mean()
    overall_drift = yoy_df['drift'].mean()
    print(f"\n  Overall: avg_yoy_sim={overall_sim:.4f}  avg_yoy_drift={overall_drift:.4f}")
    print(f"  Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv")
# Out:
# ======================================================================
# Year-over-Year Drift: CS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.1271  drift=0.8729  (36 topics)  ███████████████████████████████████████████
#     2001→2002: sim=0.1403  drift=0.8597  (39 topics)  ██████████████████████████████████████████
#     2002→2003: sim=0.1427  drift=0.8573  (40 topics)  ██████████████████████████████████████████
#     2003→2004: sim=0.1245  drift=0.8755  (50 topics)  ███████████████████████████████████████████
#     2004→2005: sim=0.1258  drift=0.8742  (56 topics)  ███████████████████████████████████████████
#     2005→2006: sim=0.1458  drift=0.8542  (54 topics)  ██████████████████████████████████████████
#     2006→2007: sim=0.1425  drift=0.8575  (59 topics)  ██████████████████████████████████████████
#     2007→2008: sim=0.1564  drift=0.8436  (62 topics)  ██████████████████████████████████████████
#     2008→2009: sim=0.1455  drift=0.8545  (72 topics)  ██████████████████████████████████████████
#     2009→2010: sim=0.1740  drift=0.8260  (79 topics)  █████████████████████████████████████████
#     2010→2011: sim=0.1610  drift=0.8390  (97 topics)  █████████████████████████████████████████
#     2011→2012: sim=0.1799  drift=0.8201  (125 topics)  █████████████████████████████████████████
#     2012→2013: sim=0.1981  drift=0.8019  (147 topics)  ████████████████████████████████████████
#     2013→2014: sim=0.2101  drift=0.7899  (162 topics)  ███████████████████████████████████████
#     2014→2015: sim=0.2273  drift=0.7727  (168 topics)  ██████████████████████████████████████
#     2015→2016: sim=0.2283  drift=0.7717  (191 topics)  ██████████████████████████████████████
#     2016→2017: sim=0.2571  drift=0.7429  (219 topics)  █████████████████████████████████████
#     2017→2018: sim=0.3201  drift=0.6799  (237 topics)  █████████████████████████████████
#     2018→2019: sim=0.3783  drift=0.6217  (249 topics)  ███████████████████████████████
#     2019→2020: sim=0.4400  drift=0.5600  (255 topics)  ████████████████████████████
#     2020→2021: sim=0.4945  drift=0.5055  (256 topics)  █████████████████████████
#     2021→2022: sim=0.5089  drift=0.4911  (258 topics)  ████████████████████████
#     2022→2023: sim=0.5103  drift=0.4897  (260 topics)  ████████████████████████
#     2023→2024: sim=0.5433  drift=0.4567  (261 topics)  ██████████████████████
#     2024→2025: sim=0.5829  drift=0.4171  (260 topics)  ████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T 17 | 2000→2001 | drift=1.0000
#     T 25 | 2000→2001 | drift=1.0000
#     T 27 | 2000→2001 | drift=1.0000
#     T 36 | 2000→2001 | drift=1.0000
#     T 37 | 2000→2001 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.3480  avg_yoy_drift=0.6520
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: MATH
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.1254  drift=0.8746  (80 topics)  ███████████████████████████████████████████
#     2001→2002: sim=0.1343  drift=0.8657  (82 topics)  ███████████████████████████████████████████
#     2002→2003: sim=0.1484  drift=0.8516  (84 topics)  ██████████████████████████████████████████
#     2003→2004: sim=0.1398  drift=0.8602  (102 topics)  ███████████████████████████████████████████
#     2004→2005: sim=0.1788  drift=0.8212  (108 topics)  █████████████████████████████████████████
#     2005→2006: sim=0.2014  drift=0.7986  (114 topics)  ███████████████████████████████████████
#     2006→2007: sim=0.2050  drift=0.7950  (128 topics)  ███████████████████████████████████████
#     2007→2008: sim=0.2299  drift=0.7701  (132 topics)  ██████████████████████████████████████
#     2008→2009: sim=0.2389  drift=0.7611  (134 topics)  ██████████████████████████████████████
#     2009→2010: sim=0.2514  drift=0.7486  (135 topics)  █████████████████████████████████████
#     2010→2011: sim=0.2761  drift=0.7239  (140 topics)  ████████████████████████████████████
#     2011→2012: sim=0.2943  drift=0.7057  (146 topics)  ███████████████████████████████████
#     2012→2013: sim=0.3264  drift=0.6736  (148 topics)  █████████████████████████████████
#     2013→2014: sim=0.3424  drift=0.6576  (150 topics)  ████████████████████████████████
#     2014→2015: sim=0.3623  drift=0.6377  (149 topics)  ███████████████████████████████
#     2015→2016: sim=0.3759  drift=0.6241  (149 topics)  ███████████████████████████████
#     2016→2017: sim=0.3988  drift=0.6012  (150 topics)  ██████████████████████████████
#     2017→2018: sim=0.4164  drift=0.5836  (150 topics)  █████████████████████████████
#     2018→2019: sim=0.4338  drift=0.5662  (150 topics)  ████████████████████████████
#     2019→2020: sim=0.4473  drift=0.5527  (150 topics)  ███████████████████████████
#     2020→2021: sim=0.4545  drift=0.5455  (150 topics)  ███████████████████████████
#     2021→2022: sim=0.4866  drift=0.5134  (150 topics)  █████████████████████████
#     2022→2023: sim=0.4551  drift=0.5449  (150 topics)  ███████████████████████████
#     2023→2024: sim=0.4674  drift=0.5326  (150 topics)  ██████████████████████████
#     2024→2025: sim=0.5183  drift=0.4817  (150 topics)  ████████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T  0 | 2000→2001 | drift=1.0000
#     T  1 | 2000→2001 | drift=1.0000
#     T  9 | 2000→2001 | drift=1.0000
#     T 17 | 2000→2001 | drift=1.0000
#     T 21 | 2000→2001 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.3349  avg_yoy_drift=0.6651
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: PHYSICS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.1265  drift=0.8735  (83 topics)  ███████████████████████████████████████████
#     2001→2002: sim=0.1351  drift=0.8649  (92 topics)  ███████████████████████████████████████████
#     2002→2003: sim=0.1156  drift=0.8844  (100 topics)  ████████████████████████████████████████████
#     2003→2004: sim=0.1238  drift=0.8762  (113 topics)  ███████████████████████████████████████████
#     2004→2005: sim=0.1216  drift=0.8784  (128 topics)  ███████████████████████████████████████████
#     2005→2006: sim=0.1612  drift=0.8388  (142 topics)  █████████████████████████████████████████
#     2006→2007: sim=0.1745  drift=0.8255  (156 topics)  █████████████████████████████████████████
#     2007→2008: sim=0.1725  drift=0.8275  (164 topics)  █████████████████████████████████████████
#     2008→2009: sim=0.1759  drift=0.8241  (173 topics)  █████████████████████████████████████████
#     2009→2010: sim=0.1932  drift=0.8068  (186 topics)  ████████████████████████████████████████
#     2010→2011: sim=0.2237  drift=0.7763  (203 topics)  ██████████████████████████████████████
#     2011→2012: sim=0.2599  drift=0.7401  (215 topics)  █████████████████████████████████████
#     2012→2013: sim=0.2817  drift=0.7183  (218 topics)  ███████████████████████████████████
#     2013→2014: sim=0.2879  drift=0.7121  (219 topics)  ███████████████████████████████████
#     2014→2015: sim=0.3072  drift=0.6928  (219 topics)  ██████████████████████████████████
#     2015→2016: sim=0.3145  drift=0.6855  (223 topics)  ██████████████████████████████████
#     2016→2017: sim=0.3287  drift=0.6713  (227 topics)  █████████████████████████████████
#     2017→2018: sim=0.3403  drift=0.6597  (230 topics)  ████████████████████████████████
#     2018→2019: sim=0.3576  drift=0.6424  (231 topics)  ████████████████████████████████
#     2019→2020: sim=0.3771  drift=0.6229  (231 topics)  ███████████████████████████████
#     2020→2021: sim=0.4024  drift=0.5976  (231 topics)  █████████████████████████████
#     2021→2022: sim=0.3881  drift=0.6119  (232 topics)  ██████████████████████████████
#     2022→2023: sim=0.3847  drift=0.6153  (231 topics)  ██████████████████████████████
#     2023→2024: sim=0.3987  drift=0.6013  (230 topics)  ██████████████████████████████
#     2024→2025: sim=0.4255  drift=0.5745  (231 topics)  ████████████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T 16 | 2000→2001 | drift=1.0000
#     T 18 | 2000→2001 | drift=1.0000
#     T 23 | 2000→2001 | drift=1.0000
#     T 28 | 2000→2001 | drift=1.0000
#     T 33 | 2000→2001 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.2881  avg_yoy_drift=0.7119
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv

# %% [markdown]
# ## Inspect Individual Topics
# Two helper functions to drill into specific topics.

# %%
def show_topic_yoy(topic_id, subject):
    """
    Show year-over-year drift for a specific topic with drift labels.
    Labels: Stable (<0.3), Moderate (0.3-0.6), Aggressive (0.6-0.8), Extreme (>0.8)
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    for _, row in topic_evo.iterrows():
        tw[int(row["year"])] = parse_words(row["top_words"])

    topic_years = sorted(tw.keys())

    print(f"\n{'='*70}")
    print(f"YoY Drift: Topic {topic_id} — {subject.upper()}")
    print(f"Active: {topic_years[0]}–{topic_years[-1]} ({len(topic_years)} years)")
    print(f"{'='*70}")

    drifts = []
    for i in range(len(topic_years) - 1):
        t, t1 = topic_years[i], topic_years[i + 1]
        sim = rbo(tw[t], tw[t1], p=0.9)
        drift = 1.0 - sim
        drifts.append(drift)

        # Label
        if drift < 0.3:
            label = "🟢 Stable"
        elif drift < 0.6:
            label = "🟡 Moderate"
        elif drift < 0.8:
            label = "�� Aggressive"
        else:
            label = "🔴 Extreme"

        bar = chr(9608) * int(drift * 30)
        print(f"  {t}→{t1}: sim={sim:.4f}  drift={drift:.4f}  {bar}  {label}")

        # Show word changes
        added = set(tw[t1]) - set(tw[t])
        removed = set(tw[t]) - set(tw[t1])
        if added or removed:
            if removed:
                print(f"           − {', '.join(sorted(removed))}")
            if added:
                print(f"           + {', '.join(sorted(added))}")

    # Summary
    avg_d = np.mean(drifts)
    max_d = np.max(drifts)
    if avg_d < 0.3:
        verdict = "🟢 STABLE — vocabulary is consistent over time"
    elif avg_d < 0.5:
        verdict = "🟡 MODERATE — topic evolves gradually"
    elif avg_d < 0.7:
        verdict = "🟠 DRIFTING — significant vocabulary changes"
    else:
        verdict = "🔴 HIGHLY UNSTABLE — topic vocabulary reshuffles frequently"

    print(f"\n  Avg drift: {avg_d:.4f} | Max jump: {max_d:.4f}")
    print(f"  Verdict: {verdict}")


def show_topic_endpoint(topic_id, subject):
    """
    Show endpoint drift for a specific topic: first year vs last year.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    for _, row in topic_evo.iterrows():
        tw[int(row["year"])] = parse_words(row["top_words"])

    topic_years = sorted(tw.keys())
    t_first, t_last = topic_years[0], topic_years[-1]

    sim = rbo(tw[t_first], tw[t_last], p=0.9)
    ttd = 1.0 - sim

    # Words analysis
    w_first = set(tw[t_first])
    w_last = set(tw[t_last])
    kept = sorted(w_first & w_last)
    removed = sorted(w_first - w_last)
    added = sorted(w_last - w_first)

    if ttd < 0.3:
        verdict = "🟢 STABLE — topic maintained its core vocabulary"
    elif ttd < 0.5:
        verdict = "🟡 MODERATE — topic evolved but recognizable"
    elif ttd < 0.7:
        verdict = "🟠 SIGNIFICANT DRIFT — topic substantially changed"
    else:
        verdict = "🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced"

    print(f"\n{'='*70}")
    print(f"Endpoint Drift: Topic {topic_id} — {subject.upper()}")
    print(f"{'='*70}")
    print(f"  Active: {t_first}–{t_last} ({len(topic_years)} years)")
    print(f"  Cosine similarity: {sim:.4f}")
    print(f"  TTD (drift):       {ttd:.4f}")
    print(f"  Verdict: {verdict}")
    print(f"\n  First year ({t_first}): {', '.join(tw[t_first])}")
    print(f"  Last year  ({t_last}): {', '.join(tw[t_last])}")
    print(f"\n  🔒 Kept ({len(kept)}):    {', '.join(kept) if kept else '(none)'}")
    print(f"  ➖ Removed ({len(removed)}): {', '.join(removed) if removed else '(none)'}")
    print(f"  ➕ Added ({len(added)}):   {', '.join(added) if added else '(none)'}")


def show_topic_trajectory(topic_id, subject):
    """
    Show drift trajectory from baseline (first year) for a specific topic.
    cosine_sim(words_t0, words_t) per year — shows when drift accelerates.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    tw = {}
    for _, row in topic_evo.iterrows():
        tw[int(row["year"])] = parse_words(row["top_words"])

    topic_years = sorted(tw.keys())
    t0 = topic_years[0]
    words_baseline = tw[t0]

    print(f"\n{'='*70}")
    print(f"Drift Trajectory: Topic {topic_id} — {subject.upper()}")
    print(f"Baseline: {t0} → {', '.join(tw[t0])}")
    print(f"{'='*70}")

    prev_drift = 0.0
    for y in topic_years:
        words_y = tw[y]
        sim = rbo(words_baseline, words_y, p=0.9)
        drift = 1.0 - sim

        # Delta from previous year
        delta = drift - prev_drift
        if delta > 0.1:
            delta_label = f" ↑{delta:+.3f} ⚡"
        elif delta > 0.02:
            delta_label = f" ↑{delta:+.3f}"
        elif delta < -0.02:
            delta_label = f" ↓{delta:+.3f} 🔄"
        else:
            delta_label = f"  {delta:+.3f} —"
        prev_drift = drift

        # Shared words with baseline
        shared = sorted(set(tw[t0]) & set(tw[y]))
        n_shared = len(shared)
        n_total = len(tw[t0])

        bar = chr(9608) * int(drift * 30)
        print(f"  {y}: sim={sim:.4f}  drift={drift:.4f}  {bar}{delta_label}  "
              f"({n_shared}/{n_total} baseline words kept)")

    # Final summary
    final_sim = rbo(words_baseline, tw[topic_years[-1]], p=0.9)
    final_drift = 1.0 - final_sim
    kept = sorted(set(tw[t0]) & set(tw[topic_years[-1]]))
    lost = sorted(set(tw[t0]) - set(tw[topic_years[-1]]))

    print(f"\n  Total drift ({t0}→{topic_years[-1]}): {final_drift:.4f}")
    print(f"  Baseline words kept: {', '.join(kept) if kept else '(none)'}")
    print(f"  Baseline words lost: {', '.join(lost) if lost else '(none)'}")

# %% [markdown]
# ### Usage
# ```python
# show_topic_yoy(topic_id=5, subject="cs")
# show_topic_endpoint(topic_id=5, subject="cs")
# ```

# %%
# Example: inspect a specific topic
show_topic_yoy(topic_id=0, subject="cs")
show_topic_trajectory(topic_id=0, subject="cs")
show_topic_endpoint(topic_id=0, subject="cs")
# Out:
# ======================================================================
# YoY Drift: Topic 0 — CS
# Active: 2000–2025 (26 years)
# ======================================================================
#   2000→2001: sim=0.0387  drift=0.9613  ████████████████████████████  🔴 Extreme
#            − coloring, crossing, csp, flipturn, flipturns, polygon, polygons, polylog, rectilinear
#            + bhlevel, bits, connected, exactcolor, graphs, motwani, planar, polyhedra, triconnected
#   2001→2002: sim=0.1478  drift=0.8522  █████████████████████████  🔴 Extreme
#            − bhlevel, bits, connected, exactcolor, log, motwani, polyhedra, triconnected
#            + gg, graph, minimum, packing, problem, spanning, ssss, tree
#   2002→2003: sim=0.0882  drift=0.9118  ███████████████████████████  🔴 Extreme
#            − gg, minimum, packing, planar, problem, spanning, ssss, tree
#            + crease, edges, hbox, hinged, log, np, rm, uc
#   2003→2004: sim=0.1640  drift=0.8360  █████████████████████████  🔴 Extreme
#            − crease, edges, hbox, hinged, log, np, rm, uc
#            + eps, equiv, geq, gi, iso, planar, vec, vrn
#   2004→2005: sim=0.0983  drift=0.9017  ███████████████████████████  🔴 Extreme
#            − eps, equiv, geq, gi, graph, iso, planar, vec, vrn
#            + coloring, constriction, convex, delaunay, hh, jones, perfect, problem, venn
#   2005→2006: sim=0.1418  drift=0.8582  █████████████████████████  🔴 Extreme
#            − coloring, constriction, convex, delaunay, hh, jones, perfect, venn
#            + algorithm, digraph, forests, graph, packing, strip, vertex, vertices
#   2006→2007: sim=0.2523  drift=0.7477  ██████████████████████  �� Aggressive
#            − algorithm, forests, packing, problem, strip, vertex
#            + cal, ij, kolam, ln, paz, voronoi
#   2007→2008: sim=0.2526  drift=0.7474  ██████████████████████  �� Aggressive
#            − cal, digraph, ij, kolam, ln, paz, voronoi
#            + algorithm, chordal, hamiltonian, isomorphism, linear, planar, polynomial
#   2008→2009: sim=0.5327  drift=0.4673  ██████████████  🟡 Moderate
#            − chordal, hamiltonian, isomorphism, linear, planar, vertices
#            + approximation, girth, if, np, problem, rr
#   2009→2010: sim=0.4391  drift=0.5609  ████████████████  🟡 Moderate
#            − algorithm, approximation, girth, if, np, polynomial, rr
#            + edges, gg, log, steiner, tree, vertex, vertices
#   2010→2011: sim=0.5880  drift=0.4120  ████████████  🟡 Moderate
#            − edges, log, steiner, tree
#            + algorithm, dominating, number, set
#   2011→2012: sim=0.6729  drift=0.3271  █████████  🟡 Moderate
#            − algorithm, dominating, number, set
#            + approximation, coloring, log, tree
#   2012→2013: sim=0.6678  drift=0.3322  █████████  🟡 Moderate
#            − approximation, coloring, gg, problem, tree
#            + edge, edges, maximum, planar, set
#   2013→2014: sim=0.6540  drift=0.3460  ██████████  🟡 Moderate
#            − edge, edges, maximum, planar, set
#            + algorithm, coloring, gg, kk, problem
#   2014→2015: sim=0.7559  drift=0.2441  ███████  🟢 Stable
#            − algorithm, coloring, kk
#            + cal, edge, width
#   2015→2016: sim=0.7246  drift=0.2754  ████████  🟢 Stable
#            − cal, edge, width
#            + frac, kk, planar
#   2016→2017: sim=0.7040  drift=0.2960  ████████  🟢 Stable
#            − frac, planar
#            + edges, mathcal
#   2017→2018: sim=0.7349  drift=0.2651  ███████  🟢 Stable
#            − kk, mathcal
#            + approximation, coloring
#   2018→2019: sim=0.7331  drift=0.2669  ████████  🟢 Stable
#            − approximation, coloring, problem
#            + edge, kk, planar
#   2019→2020: sim=0.7208  drift=0.2792  ████████  🟢 Stable
#            − edge, edges, planar
#            + hh, mathcal, problem
#   2020→2021: sim=0.7160  drift=0.2840  ████████  🟢 Stable
#            − hh, mathcal, problem
#            + algorithm, cal, varepsilon
#   2021→2022: sim=0.7268  drift=0.2732  ████████  🟢 Stable
#            − algorithm, cal, varepsilon
#            + approximation, coloring, problem
#   2022→2023: sim=0.8078  drift=0.1922  █████  🟢 Stable
#            − approximation, coloring
#            + mathcal, varepsilon
#   2023→2024: sim=0.8489  drift=0.1511  ████  🟢 Stable
#            − varepsilon
#            + frac
#   2024→2025: sim=0.7936  drift=0.2064  ██████  🟢 Stable
#            − frac
#            + varepsilon
#
#   Avg drift: 0.4798 | Max jump: 0.9613
#   Verdict: 🟡 MODERATE — topic evolves gradually
#
# ======================================================================
# Drift Trajectory: Topic 0 — CS
# Baseline: 2000 → rectilinear, polygon, csp, crossing, flipturn, polylog, coloring, flipturns, polygons, log
# ======================================================================
#   2000: sim=1.0000  drift=0.0000    +0.000 —  (10/10 baseline words kept)
#   2001: sim=0.0387  drift=0.9613  ████████████████████████████ ↑+0.961 ⚡  (1/10 baseline words kept)
#   2002: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.039  (0/10 baseline words kept)
#   2003: sim=0.0387  drift=0.9613  ████████████████████████████ ↓-0.039 🔄  (1/10 baseline words kept)
#   2004: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.039  (0/10 baseline words kept)
#   2005: sim=0.0571  drift=0.9429  ████████████████████████████ ↓-0.057 🔄  (1/10 baseline words kept)
#   2006: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.057  (0/10 baseline words kept)
#   2007: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2008: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2009: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2010: sim=0.0387  drift=0.9613  ████████████████████████████ ↓-0.039 🔄  (1/10 baseline words kept)
#   2011: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.039  (0/10 baseline words kept)
#   2012: sim=0.0775  drift=0.9225  ███████████████████████████ ↓-0.077 🔄  (2/10 baseline words kept)
#   2013: sim=0.0387  drift=0.9613  ████████████████████████████ ↑+0.039  (1/10 baseline words kept)
#   2014: sim=0.0958  drift=0.9042  ███████████████████████████ ↓-0.057 🔄  (2/10 baseline words kept)
#   2015: sim=0.0387  drift=0.9613  ████████████████████████████ ↑+0.057  (1/10 baseline words kept)
#   2016: sim=0.0387  drift=0.9613  ████████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2017: sim=0.0387  drift=0.9613  ████████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2018: sim=0.0882  drift=0.9118  ███████████████████████████ ↓-0.050 🔄  (2/10 baseline words kept)
#   2019: sim=0.0387  drift=0.9613  ████████████████████████████ ↑+0.050  (1/10 baseline words kept)
#   2020: sim=0.0387  drift=0.9613  ████████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2021: sim=0.0387  drift=0.9613  ████████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2022: sim=0.0823  drift=0.9177  ███████████████████████████ ↓-0.044 🔄  (2/10 baseline words kept)
#   2023: sim=0.0387  drift=0.9613  ████████████████████████████ ↑+0.044  (1/10 baseline words kept)
#   2024: sim=0.0387  drift=0.9613  ████████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2025: sim=0.0387  drift=0.9613  ████████████████████████████  +0.000 —  (1/10 baseline words kept)
#
#   Total drift (2000→2025): 0.9613
#   Baseline words kept: log
#   Baseline words lost: coloring, crossing, csp, flipturn, flipturns, polygon, polygons, polylog, rectilinear
#
# ======================================================================
# Endpoint Drift: Topic 0 — CS
# ======================================================================
#   Active: 2000–2025 (26 years)
#   Cosine similarity: 0.0387
#   TTD (drift):       0.9613
#   Verdict: 🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced
#
#   First year (2000): rectilinear, polygon, csp, crossing, flipturn, polylog, coloring, flipturns, polygons, log
#   Last year  (2025): graphs, mathcal, vertex, graph, gg, log, vertices, varepsilon, problem, kk
#
#   🔒 Kept (1):    log
#   ➖ Removed (9): coloring, crossing, csp, flipturn, flipturns, polygon, polygons, polylog, rectilinear
#   ➕ Added (9):   gg, graph, graphs, kk, mathcal, problem, varepsilon, vertex, vertices
