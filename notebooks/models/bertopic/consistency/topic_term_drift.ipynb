# %% [markdown]
# # BERTopic: Topic Term Drift (TTD)
#
# **Scenario 3a** — Three complementary drift metrics:
# 1. **Endpoint TTD**: cosine distance from first to last year (total drift)
# 2. **Trajectory from baseline**: cosine_sim(t₀, t) per year (when drift happens)
# 3. **Year-over-year drift**: cosine_sim(t, t+1) per year (smoothness of evolution)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings("ignore")

# %%
LIST_SUBJECT = ["cs", "math", "physics"]
TEMPORAL_DIR = Path("../../../../results/bertopic/temporal")
RESULT_DIR = Path("../../../../results/bertopic/consistency")

for subject in LIST_SUBJECT:
    (RESULT_DIR / subject).mkdir(parents=True, exist_ok=True)

print(f"Reading from: {TEMPORAL_DIR}")
print(f"Saving to: {RESULT_DIR}")
# Out:
# Reading from: ../../../../results/bertopic/temporal
# Saving to: ../../../../results/bertopic/consistency

# %%
def parse_words(words_str):
    return [w.strip() for w in str(words_str).split(",")]


def words_to_vector(words, vocab_index):
    vec = np.zeros(len(vocab_index))
    for w in words:
        if w in vocab_index:
            vec[vocab_index[w]] = 1.0
    return vec


def cos_sim(v1, v2):
    """Cosine similarity between two vectors."""
    return float(cosine_similarity(v1.reshape(1, -1), v2.reshape(1, -1))[0, 0])

# %% [markdown]
# ## 1. Endpoint TTD
# Total drift: `TTD = 1 - cosine_sim(words_first, words_last)`

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Endpoint TTD: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())

    # Build global vocabulary
    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t_first, t_last = topic_years[0], topic_years[-1]
        v_first = words_to_vector(topic_words[(t_first, tid)], vocab_index)
        v_last = words_to_vector(topic_words[(t_last, tid)], vocab_index)
        sim = cos_sim(v_first, v_last)

        rows.append({
            "subject": subject, "topic_id": tid,
            "first_year": t_first, "last_year": t_last,
            "n_years": len(topic_years),
            "cosine_sim": round(sim, 6),
            "ttd": round(1.0 - sim, 6),
            "words_first": ", ".join(topic_words[(t_first, tid)]),
            "words_last": ", ".join(topic_words[(t_last, tid)]),
        })

    df = pd.DataFrame(rows)
    df.to_csv(RESULT_DIR / subject / "topic_term_drift.csv", index=False)

    summary = {"subject": subject, "n_topics": len(df),
               "ttd_mean": round(df["ttd"].mean(), 6),
               "ttd_std": round(df["ttd"].std(), 6),
               "ttd_median": round(df["ttd"].median(), 6),
               "pct_stable": round((df["ttd"] < 0.5).mean() * 100, 2),
               "pct_drifted": round((df["ttd"] >= 0.5).mean() * 100, 2)}
    pd.DataFrame([summary]).to_csv(RESULT_DIR / subject / "ttd_summary.csv", index=False)

    print(f"  TTD: mean={summary['ttd_mean']:.4f} ± {summary['ttd_std']:.4f}, "
          f"median={summary['ttd_median']:.4f}")
    print(f"  Stable (TTD<0.5): {summary['pct_stable']:.1f}%  |  "
          f"Drifted (TTD≥0.5): {summary['pct_drifted']:.1f}%")

    print(f"\n  �� Top 5 most DRIFTED:")
    for _, r in df.nlargest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | "
              f"{r['words_first'][:40]}... → {r['words_last'][:40]}...")

    print(f"  🔒 Top 5 most STABLE:")
    for _, r in df.nsmallest(5, 'ttd').iterrows():
        print(f"    T{int(r['topic_id']):>3} | TTD={r['ttd']:.4f} | {r['words_first'][:60]}")
# Out:
# ======================================================================
# Endpoint TTD: CS (BERTopic)
# ======================================================================
#   TTD: mean=0.8977 ± 0.1056, median=0.9000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   �� Top 5 most DRIFTED:
#     T  2 | TTD=1.0000 | imagined, annotation, keywords, plsa, an... → visual, multimodal, reasoning, vision, v...
#     T  7 | TTD=1.0000 | clouds, kernels, jects, point, ob, recur... → graph, node, gnns, graphs, gnn, nodes, n...
#     T  9 | TTD=1.0000 | massively, simd, misses, grids, surface,... → gpu, memory, hardware, workloads, gpus, ...
#     T 10 | TTD=1.0000 | resonances, filter, allpass, rectangular... → speech, audio, acoustic, sound, tts, spe...
#     T 11 | TTD=1.0000 | paypal, company, anyone, email, payment,... → blockchain, contracts, smart, transactio...
#   🔒 Top 5 most STABLE:
#     T 58 | TTD=0.5000 | market, stock, trading, eurodollar, traders, price, indices,
#     T 74 | TTD=0.5000 | uavs, uav, coverage, unmanned, d2d, aerial, area, 5g, altitu
#     T228 | TTD=0.5000 | out, classifiers, distribution, samples, ood, detecting, cla
#     T  4 | TTD=0.6000 | logic, termination, programs, semantics, logics, programming
#     T 67 | TTD=0.6000 | payoff, move, player, players, np, payoffs, games, common, i
#
# ======================================================================
# Endpoint TTD: MATH (BERTopic)
# ======================================================================
#   TTD: mean=0.8547 ± 0.1251, median=0.9000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   �� Top 5 most DRIFTED:
#     T  2 | TTD=1.0000 | mdma, asthma, jack, jackknife, particula... → causal, regression, estimator, estimatio...
#     T  8 | TTD=1.0000 | damascelli, 0lu, pacella, monotonicity, ... → solutions, elliptic, regularity, nabla, ...
#     T 14 | TTD=1.0000 | scaled, self, cones, barrier, barriers, ... → optimization, problems, bilevel, program...
#     T 15 | TTD=1.0000 | gustavson, scattering, normalization, an... → magnetic, operators, spectral, schr, din...
#     T 18 | TTD=1.0000 | hoelder, rough, brownian, continuity, en... → stochastic, noise, driven, sdes, differe...
#   🔒 Top 5 most STABLE:
#     T 25 | TTD=0.5000 | modular, maass, forms, ttt, selberg, period, eisenstein, cus
#     T 44 | TTD=0.5000 | witten, gromov, invariants, cy3, brane, calabi, tinybbb, yau
#     T 64 | TTD=0.5000 | askey, wilson, polynomials, bispectral, symmetric, oscillato
#     T109 | TTD=0.5000 | pinwheel, substitution, tiling, tilings, domino, tiles, nvar
#     T  3 | TTD=0.6000 | knots, vassiliev, invariants, knot, moves, fillings, legendr
#
# ======================================================================
# Endpoint TTD: PHYSICS (BERTopic)
# ======================================================================
#   TTD: mean=0.8853 ± 0.1138, median=0.9000
#   Stable (TTD<0.5): 0.0%  |  Drifted (TTD≥0.5): 100.0%
#
#   �� Top 5 most DRIFTED:
#     T  1 | TTD=1.0000 | cwt, interferograms, turbid, ridge, spat... → imaging, microscopy, resolution, image, ...
#     T  4 | TTD=1.0000 | gps, tec, cir, ionospheric, ionosphere, ... → solar, wind, coronal, cme, magnetic, obs...
#     T  5 | TTD=1.0000 | reaction, passage, pathways, exemplary, ... → learning, molecular, machine, chemical, ...
#     T 19 | TTD=1.0000 | paperless, coauthored, scientists, paper... → citation, scientific, research, science,...
#     T 20 | TTD=1.0000 | mg2sio4, nanobelts, forsterite, sio2, 6a... → perovskite, perovskites, halide, solar, ...
#   🔒 Top 5 most STABLE:
#     T 49 | TTD=0.5000 | opinion, nu, political, voter, decision, vote, voters, conse
#     T  7 | TTD=0.6000 | epr, quantum, common, mechanics, bell, cause, probability, i
#     T  8 | TTD=0.6000 | linac, beam, rfq, accelerator, emittance, collider, nlc, bun
#     T 14 | TTD=0.6000 | plasma, mix, oscillations, collisional, dusty, dust, amplitu
#     T 15 | TTD=0.6000 | frac, universe, multifractal, cosmological, partial, redshif

# %% [markdown]
# ## 2. Drift Trajectory from Baseline
# For each topic: `cosine_sim(words_t₀, words_t)` per year — shows **when** drift happens

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Drift Trajectory: {subject.upper()} (BERTopic)")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row["year"]), int(row["topic_id"]))
        topic_words[key] = parse_words(row["top_words"])

    years = sorted(evo_df["year"].unique())
    all_topics = sorted(evo_df["topic_id"].unique())

    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    traj_rows = []
    for tid in all_topics:
        topic_years = sorted([y for y in years if (y, tid) in topic_words])
        if len(topic_years) < 2:
            continue

        t0 = topic_years[0]
        v_baseline = words_to_vector(topic_words[(t0, tid)], vocab_index)

        for y in topic_years:
            v_y = words_to_vector(topic_words[(y, tid)], vocab_index)
            sim = cos_sim(v_baseline, v_y)
            traj_rows.append({
                "subject": subject, "topic_id": tid,
                "baseline_year": t0, "year": y,
                "years_elapsed": y - t0,
                "cosine_sim_to_baseline": round(sim, 6),
                "drift_from_baseline": round(1.0 - sim, 6),
            })

    traj_df = pd.DataFrame(traj_rows)
    traj_df.to_csv(RESULT_DIR / subject / "ttd_trajectory.csv", index=False)

    # Average drift trajectory across all topics per year
    avg_traj = traj_df.groupby("year").agg(
        avg_sim=("cosine_sim_to_baseline", "mean"),
        avg_drift=("drift_from_baseline", "mean"),
        n_topics=("topic_id", "count")
    ).reset_index()
    avg_traj.insert(0, "subject", subject)
    avg_traj.to_csv(RESULT_DIR / subject / "ttd_trajectory_avg.csv", index=False)

    print(f"  Avg drift from baseline per year:")
    for _, r in avg_traj.iterrows():
        bar = '█' * int(r['avg_drift'] * 50)
        print(f"    {int(r['year'])}: sim={r['avg_sim']:.4f}  drift={r['avg_drift']:.4f}  {bar}")
    print(f"  Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv")
# Out:
# ======================================================================
# Drift Trajectory: CS (BERTopic)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.4937  drift=0.5063  █████████████████████████
#     2002: sim=0.3923  drift=0.6077  ██████████████████████████████
#     2003: sim=0.3189  drift=0.6811  ██████████████████████████████████
#     2004: sim=0.3442  drift=0.6558  ████████████████████████████████
#     2005: sim=0.2517  drift=0.7483  █████████████████████████████████████
#     2006: sim=0.1727  drift=0.8273  █████████████████████████████████████████
#     2007: sim=0.1159  drift=0.8841  ████████████████████████████████████████████
#     2008: sim=0.1410  drift=0.8590  ██████████████████████████████████████████
#     2009: sim=0.1398  drift=0.8602  ███████████████████████████████████████████
#     2010: sim=0.1738  drift=0.8262  █████████████████████████████████████████
#     2011: sim=0.1306  drift=0.8694  ███████████████████████████████████████████
#     2012: sim=0.1193  drift=0.8807  ████████████████████████████████████████████
#     2013: sim=0.1135  drift=0.8865  ████████████████████████████████████████████
#     2014: sim=0.1157  drift=0.8843  ████████████████████████████████████████████
#     2015: sim=0.1338  drift=0.8662  ███████████████████████████████████████████
#     2016: sim=0.1418  drift=0.8582  ██████████████████████████████████████████
#     2017: sim=0.1109  drift=0.8891  ████████████████████████████████████████████
#     2018: sim=0.1299  drift=0.8701  ███████████████████████████████████████████
#     2019: sim=0.1082  drift=0.8918  ████████████████████████████████████████████
#     2020: sim=0.1117  drift=0.8883  ████████████████████████████████████████████
#     2021: sim=0.1171  drift=0.8829  ████████████████████████████████████████████
#     2022: sim=0.1104  drift=0.8896  ████████████████████████████████████████████
#     2023: sim=0.1115  drift=0.8885  ████████████████████████████████████████████
#     2024: sim=0.1031  drift=0.8969  ████████████████████████████████████████████
#     2025: sim=0.1027  drift=0.8973  ████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: MATH (BERTopic)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.3119  drift=0.6881  ██████████████████████████████████
#     2002: sim=0.1344  drift=0.8656  ███████████████████████████████████████████
#     2003: sim=0.2270  drift=0.7730  ██████████████████████████████████████
#     2004: sim=0.1636  drift=0.8364  █████████████████████████████████████████
#     2005: sim=0.1421  drift=0.8579  ██████████████████████████████████████████
#     2006: sim=0.1504  drift=0.8496  ██████████████████████████████████████████
#     2007: sim=0.1348  drift=0.8652  ███████████████████████████████████████████
#     2008: sim=0.1397  drift=0.8603  ███████████████████████████████████████████
#     2009: sim=0.1223  drift=0.8777  ███████████████████████████████████████████
#     2010: sim=0.1291  drift=0.8709  ███████████████████████████████████████████
#     2011: sim=0.1301  drift=0.8699  ███████████████████████████████████████████
#     2012: sim=0.1230  drift=0.8770  ███████████████████████████████████████████
#     2013: sim=0.1273  drift=0.8727  ███████████████████████████████████████████
#     2014: sim=0.1253  drift=0.8747  ███████████████████████████████████████████
#     2015: sim=0.1268  drift=0.8732  ███████████████████████████████████████████
#     2016: sim=0.1360  drift=0.8640  ███████████████████████████████████████████
#     2017: sim=0.1333  drift=0.8667  ███████████████████████████████████████████
#     2018: sim=0.1420  drift=0.8580  ██████████████████████████████████████████
#     2019: sim=0.1373  drift=0.8627  ███████████████████████████████████████████
#     2020: sim=0.1393  drift=0.8607  ███████████████████████████████████████████
#     2021: sim=0.1273  drift=0.8727  ███████████████████████████████████████████
#     2022: sim=0.1353  drift=0.8647  ███████████████████████████████████████████
#     2023: sim=0.1307  drift=0.8693  ███████████████████████████████████████████
#     2024: sim=0.1393  drift=0.8607  ███████████████████████████████████████████
#     2025: sim=0.1453  drift=0.8547  ██████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv
#
# ======================================================================
# Drift Trajectory: PHYSICS (BERTopic)
# ======================================================================
#   Avg drift from baseline per year:
#     2000: sim=1.0000  drift=0.0000
#     2001: sim=0.3658  drift=0.6342  ███████████████████████████████
#     2002: sim=0.2484  drift=0.7516  █████████████████████████████████████
#     2003: sim=0.1856  drift=0.8144  ████████████████████████████████████████
#     2004: sim=0.1835  drift=0.8165  ████████████████████████████████████████
#     2005: sim=0.1732  drift=0.8268  █████████████████████████████████████████
#     2006: sim=0.1489  drift=0.8511  ██████████████████████████████████████████
#     2007: sim=0.1264  drift=0.8736  ███████████████████████████████████████████
#     2008: sim=0.0927  drift=0.9073  █████████████████████████████████████████████
#     2009: sim=0.1036  drift=0.8964  ████████████████████████████████████████████
#     2010: sim=0.1215  drift=0.8785  ███████████████████████████████████████████
#     2011: sim=0.1187  drift=0.8813  ████████████████████████████████████████████
#     2012: sim=0.1117  drift=0.8883  ████████████████████████████████████████████
#     2013: sim=0.1140  drift=0.8860  ████████████████████████████████████████████
#     2014: sim=0.1095  drift=0.8905  ████████████████████████████████████████████
#     2015: sim=0.1116  drift=0.8884  ████████████████████████████████████████████
#     2016: sim=0.1145  drift=0.8855  ████████████████████████████████████████████
#     2017: sim=0.1113  drift=0.8887  ████████████████████████████████████████████
#     2018: sim=0.1130  drift=0.8870  ████████████████████████████████████████████
#     2019: sim=0.1142  drift=0.8858  ████████████████████████████████████████████
#     2020: sim=0.1130  drift=0.8870  ████████████████████████████████████████████
#     2021: sim=0.1103  drift=0.8897  ████████████████████████████████████████████
#     2022: sim=0.1086  drift=0.8914  ████████████████████████████████████████████
#     2023: sim=0.1113  drift=0.8887  ████████████████████████████████████████████
#     2024: sim=0.1126  drift=0.8874  ████████████████████████████████████████████
#     2025: sim=0.1147  drift=0.8853  ████████████████████████████████████████████
#   Saved: ttd_trajectory.csv, ttd_trajectory_avg.csv

# %% [markdown]
# ## 3. Year-over-Year Drift
# `cosine_sim(words_t, words_t+1)` — detects **sudden jumps** vs gradual evolution

# %%
for subject in LIST_SUBJECT:
    print(f"\n{'='*70}")
    print(f"Year-over-Year Drift: {subject.upper()}")
    print(f"{'='*70}")

    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")

    topic_words = {}
    for _, row in evo_df.iterrows():
        key = (int(row['year']), int(row['topic_id']))
        topic_words[key] = parse_words(row['top_words'])

    years = sorted(evo_df['year'].unique())

    # Build global vocabulary
    all_w = set()
    for ws in topic_words.values():
        all_w.update(ws)
    vocab_index = {w: i for i, w in enumerate(sorted(all_w))}

    yoy_rows = []

    # Iterate by CONSECUTIVE CALENDAR YEARS
    for i in range(len(years) - 1):
        t, t1 = int(years[i]), int(years[i + 1])

        # Find topics present in BOTH years
        topics_t = {tid for (y, tid) in topic_words if y == t}
        topics_t1 = {tid for (y, tid) in topic_words if y == t1}
        common_topics = sorted(topics_t & topics_t1)

        for tid in common_topics:
            v_t = words_to_vector(topic_words[(t, tid)], vocab_index)
            v_t1 = words_to_vector(topic_words[(t1, tid)], vocab_index)
            sim = cos_sim(v_t, v_t1)

            yoy_rows.append({
                'subject': subject, 'topic_id': tid,
                'year_from': t, 'year_to': t1,
                'cosine_sim': round(sim, 6),
                'drift': round(1.0 - sim, 6),
            })

    yoy_df = pd.DataFrame(yoy_rows)
    yoy_df.to_csv(RESULT_DIR / subject / "ttd_year_over_year.csv", index=False)

    # Per-topic summary
    topic_yoy = yoy_df.groupby('topic_id').agg(
        avg_yoy_sim=('cosine_sim', 'mean'),
        min_yoy_sim=('cosine_sim', 'min'),
        avg_yoy_drift=('drift', 'mean'),
        max_single_jump=('drift', 'max'),
    ).reset_index()
    topic_yoy.insert(0, 'subject', subject)
    topic_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_per_topic.csv", index=False)

    # Avg across all topics per year transition
    avg_yoy = yoy_df.groupby(['year_from', 'year_to']).agg(
        avg_sim=('cosine_sim', 'mean'),
        avg_drift=('drift', 'mean'),
        n_topics=('topic_id', 'count')
    ).reset_index()
    avg_yoy.insert(0, 'subject', subject)
    avg_yoy.to_csv(RESULT_DIR / subject / "ttd_yoy_avg.csv", index=False)

    print(f"  Avg year-over-year drift (consecutive calendar years):")
    for _, r in avg_yoy.iterrows():
        bar = chr(9608) * int(r['avg_drift'] * 50)
        print(f"    {int(r['year_from'])}→{int(r['year_to'])}: sim={r['avg_sim']:.4f}  "
              f"drift={r['avg_drift']:.4f}  ({int(r['n_topics'])} topics)  {bar}")

    # Top 5 biggest single-year jumps
    print(f"\n  Top 5 biggest single-year JUMPS:")
    for _, r in yoy_df.nlargest(5, 'drift').iterrows():
        print(f"    T{int(r['topic_id']):>3} | {int(r['year_from'])}→{int(r['year_to'])} | "
              f"drift={r['drift']:.4f}")

    overall_sim = yoy_df['cosine_sim'].mean()
    overall_drift = yoy_df['drift'].mean()
    print(f"\n  Overall: avg_yoy_sim={overall_sim:.4f}  avg_yoy_drift={overall_drift:.4f}")
    print(f"  Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv")
# Out:
# ======================================================================
# Year-over-Year Drift: CS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.1139  drift=0.8861  (36 topics)  ████████████████████████████████████████████
#     2001→2002: sim=0.1231  drift=0.8769  (39 topics)  ███████████████████████████████████████████
#     2002→2003: sim=0.1475  drift=0.8525  (40 topics)  ██████████████████████████████████████████
#     2003→2004: sim=0.1240  drift=0.8760  (50 topics)  ███████████████████████████████████████████
#     2004→2005: sim=0.1214  drift=0.8786  (56 topics)  ███████████████████████████████████████████
#     2005→2006: sim=0.1333  drift=0.8667  (54 topics)  ███████████████████████████████████████████
#     2006→2007: sim=0.1458  drift=0.8542  (59 topics)  ██████████████████████████████████████████
#     2007→2008: sim=0.1613  drift=0.8387  (62 topics)  █████████████████████████████████████████
#     2008→2009: sim=0.1542  drift=0.8458  (72 topics)  ██████████████████████████████████████████
#     2009→2010: sim=0.1797  drift=0.8203  (79 topics)  █████████████████████████████████████████
#     2010→2011: sim=0.1660  drift=0.8340  (97 topics)  █████████████████████████████████████████
#     2011→2012: sim=0.1696  drift=0.8304  (125 topics)  █████████████████████████████████████████
#     2012→2013: sim=0.1980  drift=0.8020  (147 topics)  ████████████████████████████████████████
#     2013→2014: sim=0.1981  drift=0.8019  (162 topics)  ████████████████████████████████████████
#     2014→2015: sim=0.2190  drift=0.7810  (168 topics)  ███████████████████████████████████████
#     2015→2016: sim=0.2183  drift=0.7817  (191 topics)  ███████████████████████████████████████
#     2016→2017: sim=0.2507  drift=0.7493  (219 topics)  █████████████████████████████████████
#     2017→2018: sim=0.2996  drift=0.7004  (237 topics)  ███████████████████████████████████
#     2018→2019: sim=0.3446  drift=0.6554  (249 topics)  ████████████████████████████████
#     2019→2020: sim=0.4176  drift=0.5824  (255 topics)  █████████████████████████████
#     2020→2021: sim=0.4566  drift=0.5434  (256 topics)  ███████████████████████████
#     2021→2022: sim=0.4655  drift=0.5345  (258 topics)  ██████████████████████████
#     2022→2023: sim=0.4719  drift=0.5281  (260 topics)  ██████████████████████████
#     2023→2024: sim=0.5123  drift=0.4877  (261 topics)  ████████████████████████
#     2024→2025: sim=0.5565  drift=0.4435  (260 topics)  ██████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T 17 | 2000→2001 | drift=1.0000
#     T 25 | 2000→2001 | drift=1.0000
#     T 27 | 2000→2001 | drift=1.0000
#     T 36 | 2000→2001 | drift=1.0000
#     T 37 | 2000→2001 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.3283  avg_yoy_drift=0.6717
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: MATH
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.1313  drift=0.8688  (80 topics)  ███████████████████████████████████████████
#     2001→2002: sim=0.1463  drift=0.8537  (82 topics)  ██████████████████████████████████████████
#     2002→2003: sim=0.1476  drift=0.8524  (84 topics)  ██████████████████████████████████████████
#     2003→2004: sim=0.1471  drift=0.8529  (102 topics)  ██████████████████████████████████████████
#     2004→2005: sim=0.1685  drift=0.8315  (108 topics)  █████████████████████████████████████████
#     2005→2006: sim=0.1895  drift=0.8105  (114 topics)  ████████████████████████████████████████
#     2006→2007: sim=0.1938  drift=0.8063  (128 topics)  ████████████████████████████████████████
#     2007→2008: sim=0.2189  drift=0.7811  (132 topics)  ███████████████████████████████████████
#     2008→2009: sim=0.2373  drift=0.7627  (134 topics)  ██████████████████████████████████████
#     2009→2010: sim=0.2519  drift=0.7481  (135 topics)  █████████████████████████████████████
#     2010→2011: sim=0.2700  drift=0.7300  (140 topics)  ████████████████████████████████████
#     2011→2012: sim=0.2904  drift=0.7096  (146 topics)  ███████████████████████████████████
#     2012→2013: sim=0.3081  drift=0.6919  (148 topics)  ██████████████████████████████████
#     2013→2014: sim=0.3220  drift=0.6780  (150 topics)  █████████████████████████████████
#     2014→2015: sim=0.3523  drift=0.6477  (149 topics)  ████████████████████████████████
#     2015→2016: sim=0.3678  drift=0.6322  (149 topics)  ███████████████████████████████
#     2016→2017: sim=0.3873  drift=0.6127  (150 topics)  ██████████████████████████████
#     2017→2018: sim=0.3973  drift=0.6027  (150 topics)  ██████████████████████████████
#     2018→2019: sim=0.4060  drift=0.5940  (150 topics)  █████████████████████████████
#     2019→2020: sim=0.4367  drift=0.5633  (150 topics)  ████████████████████████████
#     2020→2021: sim=0.4440  drift=0.5560  (150 topics)  ███████████████████████████
#     2021→2022: sim=0.4553  drift=0.5447  (150 topics)  ███████████████████████████
#     2022→2023: sim=0.4313  drift=0.5687  (150 topics)  ████████████████████████████
#     2023→2024: sim=0.4527  drift=0.5473  (150 topics)  ███████████████████████████
#     2024→2025: sim=0.5013  drift=0.4987  (150 topics)  ████████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T  0 | 2000→2001 | drift=1.0000
#     T  1 | 2000→2001 | drift=1.0000
#     T  9 | 2000→2001 | drift=1.0000
#     T 17 | 2000→2001 | drift=1.0000
#     T 21 | 2000→2001 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.3234  avg_yoy_drift=0.6766
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv
#
# ======================================================================
# Year-over-Year Drift: PHYSICS
# ======================================================================
#   Avg year-over-year drift (consecutive calendar years):
#     2000→2001: sim=0.1289  drift=0.8711  (83 topics)  ███████████████████████████████████████████
#     2001→2002: sim=0.1380  drift=0.8620  (92 topics)  ███████████████████████████████████████████
#     2002→2003: sim=0.1210  drift=0.8790  (100 topics)  ███████████████████████████████████████████
#     2003→2004: sim=0.1257  drift=0.8743  (113 topics)  ███████████████████████████████████████████
#     2004→2005: sim=0.1250  drift=0.8750  (128 topics)  ███████████████████████████████████████████
#     2005→2006: sim=0.1585  drift=0.8415  (142 topics)  ██████████████████████████████████████████
#     2006→2007: sim=0.1692  drift=0.8308  (156 topics)  █████████████████████████████████████████
#     2007→2008: sim=0.1689  drift=0.8311  (164 topics)  █████████████████████████████████████████
#     2008→2009: sim=0.1809  drift=0.8191  (173 topics)  ████████████████████████████████████████
#     2009→2010: sim=0.1860  drift=0.8140  (186 topics)  ████████████████████████████████████████
#     2010→2011: sim=0.2153  drift=0.7847  (203 topics)  ███████████████████████████████████████
#     2011→2012: sim=0.2442  drift=0.7558  (215 topics)  █████████████████████████████████████
#     2012→2013: sim=0.2661  drift=0.7339  (218 topics)  ████████████████████████████████████
#     2013→2014: sim=0.2685  drift=0.7315  (219 topics)  ████████████████████████████████████
#     2014→2015: sim=0.2913  drift=0.7087  (219 topics)  ███████████████████████████████████
#     2015→2016: sim=0.3009  drift=0.6991  (223 topics)  ██████████████████████████████████
#     2016→2017: sim=0.3150  drift=0.6850  (227 topics)  ██████████████████████████████████
#     2017→2018: sim=0.3217  drift=0.6783  (230 topics)  █████████████████████████████████
#     2018→2019: sim=0.3433  drift=0.6567  (231 topics)  ████████████████████████████████
#     2019→2020: sim=0.3641  drift=0.6359  (231 topics)  ███████████████████████████████
#     2020→2021: sim=0.3831  drift=0.6169  (231 topics)  ██████████████████████████████
#     2021→2022: sim=0.3793  drift=0.6207  (232 topics)  ███████████████████████████████
#     2022→2023: sim=0.3688  drift=0.6312  (231 topics)  ███████████████████████████████
#     2023→2024: sim=0.3839  drift=0.6161  (230 topics)  ██████████████████████████████
#     2024→2025: sim=0.4004  drift=0.5996  (231 topics)  █████████████████████████████
#
#   Top 5 biggest single-year JUMPS:
#     T 16 | 2000→2001 | drift=1.0000
#     T 18 | 2000→2001 | drift=1.0000
#     T 23 | 2000→2001 | drift=1.0000
#     T 28 | 2000→2001 | drift=1.0000
#     T 33 | 2000→2001 | drift=1.0000
#
#   Overall: avg_yoy_sim=0.2769  avg_yoy_drift=0.7231
#   Saved: ttd_year_over_year.csv, ttd_yoy_per_topic.csv, ttd_yoy_avg.csv

# %% [markdown]
# ## Inspect Individual Topics
# Two helper functions to drill into specific topics.

# %%
def show_topic_yoy(topic_id, subject):
    """
    Show year-over-year drift for a specific topic with drift labels.
    Labels: Stable (<0.3), Moderate (0.3-0.6), Aggressive (0.6-0.8), Extreme (>0.8)
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    all_words_set = set()
    tw = {}
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())

    print(f"\n{'='*70}")
    print(f"YoY Drift: Topic {topic_id} — {subject.upper()}")
    print(f"Active: {topic_years[0]}–{topic_years[-1]} ({len(topic_years)} years)")
    print(f"{'='*70}")

    drifts = []
    for i in range(len(topic_years) - 1):
        t, t1 = topic_years[i], topic_years[i + 1]
        v_t = words_to_vector(tw[t], vi)
        v_t1 = words_to_vector(tw[t1], vi)
        sim = cos_sim(v_t, v_t1)
        drift = 1.0 - sim
        drifts.append(drift)

        # Label
        if drift < 0.3:
            label = "🟢 Stable"
        elif drift < 0.6:
            label = "🟡 Moderate"
        elif drift < 0.8:
            label = "�� Aggressive"
        else:
            label = "🔴 Extreme"

        bar = chr(9608) * int(drift * 30)
        print(f"  {t}→{t1}: sim={sim:.4f}  drift={drift:.4f}  {bar}  {label}")

        # Show word changes
        added = set(tw[t1]) - set(tw[t])
        removed = set(tw[t]) - set(tw[t1])
        if added or removed:
            if removed:
                print(f"           − {', '.join(sorted(removed))}")
            if added:
                print(f"           + {', '.join(sorted(added))}")

    # Summary
    avg_d = np.mean(drifts)
    max_d = np.max(drifts)
    if avg_d < 0.3:
        verdict = "🟢 STABLE — vocabulary is consistent over time"
    elif avg_d < 0.5:
        verdict = "🟡 MODERATE — topic evolves gradually"
    elif avg_d < 0.7:
        verdict = "🟠 DRIFTING — significant vocabulary changes"
    else:
        verdict = "🔴 HIGHLY UNSTABLE — topic vocabulary reshuffles frequently"

    print(f"\n  Avg drift: {avg_d:.4f} | Max jump: {max_d:.4f}")
    print(f"  Verdict: {verdict}")


def show_topic_endpoint(topic_id, subject):
    """
    Show endpoint drift for a specific topic: first year vs last year.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    # Build vocabulary
    tw = {}
    all_words_set = set()
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())
    t_first, t_last = topic_years[0], topic_years[-1]

    v_first = words_to_vector(tw[t_first], vi)
    v_last = words_to_vector(tw[t_last], vi)
    sim = cos_sim(v_first, v_last)
    ttd = 1.0 - sim

    # Words analysis
    w_first = set(tw[t_first])
    w_last = set(tw[t_last])
    kept = sorted(w_first & w_last)
    removed = sorted(w_first - w_last)
    added = sorted(w_last - w_first)

    if ttd < 0.3:
        verdict = "🟢 STABLE — topic maintained its core vocabulary"
    elif ttd < 0.5:
        verdict = "🟡 MODERATE — topic evolved but recognizable"
    elif ttd < 0.7:
        verdict = "🟠 SIGNIFICANT DRIFT — topic substantially changed"
    else:
        verdict = "🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced"

    print(f"\n{'='*70}")
    print(f"Endpoint Drift: Topic {topic_id} — {subject.upper()}")
    print(f"{'='*70}")
    print(f"  Active: {t_first}–{t_last} ({len(topic_years)} years)")
    print(f"  Cosine similarity: {sim:.4f}")
    print(f"  TTD (drift):       {ttd:.4f}")
    print(f"  Verdict: {verdict}")
    print(f"\n  First year ({t_first}): {', '.join(tw[t_first])}")
    print(f"  Last year  ({t_last}): {', '.join(tw[t_last])}")
    print(f"\n  🔒 Kept ({len(kept)}):    {', '.join(kept) if kept else '(none)'}")
    print(f"  ➖ Removed ({len(removed)}): {', '.join(removed) if removed else '(none)'}")
    print(f"  ➕ Added ({len(added)}):   {', '.join(added) if added else '(none)'}")


def show_topic_trajectory(topic_id, subject):
    """
    Show drift trajectory from baseline (first year) for a specific topic.
    cosine_sim(words_t0, words_t) per year — shows when drift accelerates.
    """
    evo_df = pd.read_csv(TEMPORAL_DIR / subject / "topic_word_evolution.csv")
    topic_evo = evo_df[evo_df["topic_id"] == topic_id].sort_values("year")

    if len(topic_evo) < 2:
        print(f"Topic {topic_id} has <2 years of data in {subject}")
        return

    tw = {}
    all_words_set = set()
    for _, row in topic_evo.iterrows():
        words = parse_words(row["top_words"])
        tw[int(row["year"])] = words
        all_words_set.update(words)
    vi = {w: i for i, w in enumerate(sorted(all_words_set))}

    topic_years = sorted(tw.keys())
    t0 = topic_years[0]
    v_baseline = words_to_vector(tw[t0], vi)

    print(f"\n{'='*70}")
    print(f"Drift Trajectory: Topic {topic_id} — {subject.upper()}")
    print(f"Baseline: {t0} → {', '.join(tw[t0])}")
    print(f"{'='*70}")

    prev_drift = 0.0
    for y in topic_years:
        v_y = words_to_vector(tw[y], vi)
        sim = cos_sim(v_baseline, v_y)
        drift = 1.0 - sim

        # Delta from previous year
        delta = drift - prev_drift
        if delta > 0.1:
            delta_label = f" ↑{delta:+.3f} ⚡"
        elif delta > 0.02:
            delta_label = f" ↑{delta:+.3f}"
        elif delta < -0.02:
            delta_label = f" ↓{delta:+.3f} 🔄"
        else:
            delta_label = f"  {delta:+.3f} —"
        prev_drift = drift

        # Shared words with baseline
        shared = sorted(set(tw[t0]) & set(tw[y]))
        n_shared = len(shared)
        n_total = len(tw[t0])

        bar = chr(9608) * int(drift * 30)
        print(f"  {y}: sim={sim:.4f}  drift={drift:.4f}  {bar}{delta_label}  "
              f"({n_shared}/{n_total} baseline words kept)")

    # Final summary
    final_sim = cos_sim(v_baseline, words_to_vector(tw[topic_years[-1]], vi))
    final_drift = 1.0 - final_sim
    kept = sorted(set(tw[t0]) & set(tw[topic_years[-1]]))
    lost = sorted(set(tw[t0]) - set(tw[topic_years[-1]]))

    print(f"\n  Total drift ({t0}→{topic_years[-1]}): {final_drift:.4f}")
    print(f"  Baseline words kept: {', '.join(kept) if kept else '(none)'}")
    print(f"  Baseline words lost: {', '.join(lost) if lost else '(none)'}")

# %% [markdown]
# ### Usage
# ```python
# show_topic_yoy(topic_id=5, subject="cs")
# show_topic_endpoint(topic_id=5, subject="cs")
# ```

# %%
# Example: inspect a specific topic
show_topic_yoy(topic_id=0, subject="cs")
show_topic_trajectory(topic_id=0, subject="cs")
show_topic_endpoint(topic_id=0, subject="cs")
# Out:
# ======================================================================
# YoY Drift: Topic 0 — CS
# Active: 2000–2025 (26 years)
# ======================================================================
#   2000→2001: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − coloring, crossing, csp, flipturn, flipturns, polygon, polygons, polylog, rectilinear
#            + bhlevel, bits, connected, exactcolor, graphs, motwani, planar, polyhedra, triconnected
#   2001→2002: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − bhlevel, bits, connected, exactcolor, log, motwani, polyhedra, triconnected
#            + gg, graph, minimum, packing, problem, spanning, ssss, tree
#   2002→2003: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − gg, minimum, packing, planar, problem, spanning, ssss, tree
#            + crease, edges, hbox, hinged, log, np, rm, uc
#   2003→2004: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − crease, edges, hbox, hinged, log, np, rm, uc
#            + eps, equiv, geq, gi, iso, planar, vec, vrn
#   2004→2005: sim=0.1000  drift=0.9000  ███████████████████████████  🔴 Extreme
#            − eps, equiv, geq, gi, graph, iso, planar, vec, vrn
#            + coloring, constriction, convex, delaunay, hh, jones, perfect, problem, venn
#   2005→2006: sim=0.2000  drift=0.8000  ████████████████████████  🔴 Extreme
#            − coloring, constriction, convex, delaunay, hh, jones, perfect, venn
#            + algorithm, digraph, forests, graph, packing, strip, vertex, vertices
#   2006→2007: sim=0.4000  drift=0.6000  ██████████████████  �� Aggressive
#            − algorithm, forests, packing, problem, strip, vertex
#            + cal, ij, kolam, ln, paz, voronoi
#   2007→2008: sim=0.3000  drift=0.7000  █████████████████████  �� Aggressive
#            − cal, digraph, ij, kolam, ln, paz, voronoi
#            + algorithm, chordal, hamiltonian, isomorphism, linear, planar, polynomial
#   2008→2009: sim=0.4000  drift=0.6000  ██████████████████  �� Aggressive
#            − chordal, hamiltonian, isomorphism, linear, planar, vertices
#            + approximation, girth, if, np, problem, rr
#   2009→2010: sim=0.3000  drift=0.7000  █████████████████████  �� Aggressive
#            − algorithm, approximation, girth, if, np, polynomial, rr
#            + edges, gg, log, steiner, tree, vertex, vertices
#   2010→2011: sim=0.6000  drift=0.4000  ███████████  🟡 Moderate
#            − edges, log, steiner, tree
#            + algorithm, dominating, number, set
#   2011→2012: sim=0.6000  drift=0.4000  ███████████  🟡 Moderate
#            − algorithm, dominating, number, set
#            + approximation, coloring, log, tree
#   2012→2013: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − approximation, coloring, gg, problem, tree
#            + edge, edges, maximum, planar, set
#   2013→2014: sim=0.5000  drift=0.5000  ███████████████  🟡 Moderate
#            − edge, edges, maximum, planar, set
#            + algorithm, coloring, gg, kk, problem
#   2014→2015: sim=0.7000  drift=0.3000  █████████  🟡 Moderate
#            − algorithm, coloring, kk
#            + cal, edge, width
#   2015→2016: sim=0.7000  drift=0.3000  █████████  🟡 Moderate
#            − cal, edge, width
#            + frac, kk, planar
#   2016→2017: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − frac, planar
#            + edges, mathcal
#   2017→2018: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − kk, mathcal
#            + approximation, coloring
#   2018→2019: sim=0.7000  drift=0.3000  ████████  🟢 Stable
#            − approximation, coloring, problem
#            + edge, kk, planar
#   2019→2020: sim=0.7000  drift=0.3000  █████████  🟡 Moderate
#            − edge, edges, planar
#            + hh, mathcal, problem
#   2020→2021: sim=0.7000  drift=0.3000  █████████  🟡 Moderate
#            − hh, mathcal, problem
#            + algorithm, cal, varepsilon
#   2021→2022: sim=0.7000  drift=0.3000  █████████  🟡 Moderate
#            − algorithm, cal, varepsilon
#            + approximation, coloring, problem
#   2022→2023: sim=0.8000  drift=0.2000  █████  🟢 Stable
#            − approximation, coloring
#            + mathcal, varepsilon
#   2023→2024: sim=0.9000  drift=0.1000  ██  🟢 Stable
#            − varepsilon
#            + frac
#   2024→2025: sim=0.9000  drift=0.1000  ██  🟢 Stable
#            − frac
#            + varepsilon
#
#   Avg drift: 0.4800 | Max jump: 0.9000
#   Verdict: 🟡 MODERATE — topic evolves gradually
#
# ======================================================================
# Drift Trajectory: Topic 0 — CS
# Baseline: 2000 → rectilinear, polygon, csp, crossing, flipturn, polylog, coloring, flipturns, polygons, log
# ======================================================================
#   2000: sim=1.0000  drift=0.0000    +0.000 —  (10/10 baseline words kept)
#   2001: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.900 ⚡  (1/10 baseline words kept)
#   2002: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2003: sim=0.1000  drift=0.9000  ███████████████████████████ ↓-0.100 🔄  (1/10 baseline words kept)
#   2004: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2005: sim=0.1000  drift=0.9000  ███████████████████████████ ↓-0.100 🔄  (1/10 baseline words kept)
#   2006: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2007: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2008: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2009: sim=0.0000  drift=1.0000  ██████████████████████████████  +0.000 —  (0/10 baseline words kept)
#   2010: sim=0.1000  drift=0.9000  ███████████████████████████ ↓-0.100 🔄  (1/10 baseline words kept)
#   2011: sim=0.0000  drift=1.0000  ██████████████████████████████ ↑+0.100  (0/10 baseline words kept)
#   2012: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.200 🔄  (2/10 baseline words kept)
#   2013: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2014: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.100 🔄  (2/10 baseline words kept)
#   2015: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2016: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2017: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2018: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.100 🔄  (2/10 baseline words kept)
#   2019: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2020: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2021: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2022: sim=0.2000  drift=0.8000  ████████████████████████ ↓-0.100 🔄  (2/10 baseline words kept)
#   2023: sim=0.1000  drift=0.9000  ███████████████████████████ ↑+0.100  (1/10 baseline words kept)
#   2024: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#   2025: sim=0.1000  drift=0.9000  ███████████████████████████  +0.000 —  (1/10 baseline words kept)
#
#   Total drift (2000→2025): 0.9000
#   Baseline words kept: log
#   Baseline words lost: coloring, crossing, csp, flipturn, flipturns, polygon, polygons, polylog, rectilinear
#
# ======================================================================
# Endpoint Drift: Topic 0 — CS
# ======================================================================
#   Active: 2000–2025 (26 years)
#   Cosine similarity: 0.1000
#   TTD (drift):       0.9000
#   Verdict: 🔴 COMPLETE DRIFT — topic vocabulary almost entirely replaced
#
#   First year (2000): rectilinear, polygon, csp, crossing, flipturn, polylog, coloring, flipturns, polygons, log
#   Last year  (2025): graphs, mathcal, vertex, graph, gg, log, vertices, varepsilon, problem, kk
#
#   🔒 Kept (1):    log
#   ➖ Removed (9): coloring, crossing, csp, flipturn, flipturns, polygon, polygons, polylog, rectilinear
#   ➕ Added (9):   gg, graph, graphs, kk, mathcal, problem, varepsilon, vertex, vertices
