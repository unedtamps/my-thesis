# %%
import tomotopy as tp
import pandas as pd
import tomotopy as tp
from tqdm.notebook import tqdm

# %%
CS = "cs"
MATH = "math"
STAT = "stat"

# %%
SUBJECT = CS
LIST_SUBJECT = [CS, MATH, STAT]

# %%
df = pd.read_csv(f"dataset/arxiv_{SUBJECT}_bow.csv")
df
# Out:
#                                                     title submitted_date  \
# 0       Fault Detection using Immune-Based Systems and...     2000-10-03
# 1        Robust Classification for Imprecise Environments     2000-09-13
# 2           Tagger Evaluation Given Hierarchical Tag Sets     2000-08-09
# 3                                    Description of GADEL     2000-03-07
# 4       The dynamics of iterated transportation simula...     2000-02-22
# ...                                                   ...            ...
# 159242  Mining the Long Tail: A Comparative Study of D...     2025-09-16
# 159243  Adaptive Data-Knowledge Alignment in Genetic P...     2025-10-01
# 159244  Sobolev Training of End-to-End Optimization Pr...     2025-05-16
# 159245  Beyond Unimodal Boundaries: Generative Recomme...     2025-03-30
# 159246  Clinicians' Voice: Fundamental Considerations ...     2025-08-05
#
#                                                      text  \
# 0       ['detection', 'immune', 'system', 'formal', 'l...
# 1       ['robust', 'classification', 'imprecise', 'env...
# 2       ['tagger', 'evaluation', 'hierarchical', 'tag'...
# 3       ['description', 'gadel', 'article', 'implement...
# 4       ['dynamic', 'transportation', 'simulation', 'r...
# ...                                                   ...
# 159242  ['long_tail', 'comparative', 'study', 'data', ...
# 159243  ['adaptive', 'datum', 'knowledge', 'alignment'...
# 159244  ['sobolev', 'training', 'end', 'optimization',...
# 159245  ['unimodal', 'boundary', 'generative', 'recomm...
# 159246  ['clinician', 'fundamental', 'consideration', ...
#
#                                                  tag_text
# 0       Computational Engineering, Finance, and Scienc...
# 1                                        Machine Learning
# 2                                Computation and Language
# 3       Artificial Intelligence, Logic in Computer Sci...
# 4       Adaptation and Self-Organizing Systems, Comput...
# ...                                                   ...
# 159242  Robotics, Artificial Intelligence, Machine Lea...
# 159243  Molecular Networks, Artificial Intelligence, M...
# 159244         Machine Learning, Optimization and Control
# 159245  Information Retrieval, Artificial Intelligence...
# 159246                                   Machine Learning
#
# [159247 rows x 4 columns]

# %%
NUM_TOPICS = 50        
TRAIN_ITERATIONS = 500 
ITERATION_STEP = 50

# %% [markdown]
# # Build

# %%
if not pd.api.types.is_datetime64_any_dtype(df["submitted_date"]):
    df["submitted_date"] = pd.to_datetime(df["submitted_date"])
df['year'] = df["submitted_date"].dt.year
min_year, max_year = df['year'].min(), df['year'].max()
all_years = sorted(df['year'].unique())
num_time_steps = len(all_years)
print(f"Data found from {min_year} to {max_year} ({num_time_steps} time steps).")
year_to_timestep = {year: i for i, year in enumerate(all_years)}
df['timestep'] = df['year'].map(year_to_timestep)
# Out:
# Data found from 2000 to 2025 (26 time steps).

# %%
import ast
token_list = df["text"].explode().tolist()
tokens = [ast.literal_eval(x) for x in token_list]
processed_docs = tokens
doc_timesteps = df['timestep'].tolist()
if len(processed_docs) != len(doc_timesteps):
    raise ValueError("Mismatch between processed docs and timesteps")

# %%
dt_model = tp.DTModel(
    t=num_time_steps,        
    k=NUM_TOPICS,            
    seed=42,
    
)


for i in tqdm(range(len(processed_docs)), desc="Adding docs"):
    if processed_docs[i]:
        dt_model.add_doc(processed_docs[i], timepoint=doc_timesteps[i])

print(f"\nMemulai training untuk {TRAIN_ITERATIONS} iterasi...")
for i in range(0, TRAIN_ITERATIONS, ITERATION_STEP):
    dt_model.train(ITERATION_STEP)
    print(f"Iteration: {i + ITERATION_STEP}/{TRAIN_ITERATIONS}\tLog-likelihood: {dt_model.ll_per_word:.4f}")

dt_model.save(f"model_results/dtm/dtm_{SUBJECT}_num_topic_{NUM_TOPICS}_v1.bin")
# Out:
# Adding docs:   0%|          | 0/159247 [00:00<?, ?it/s]
# Memulai training untuk 500 iterasi...
# Iteration: 50/500	Log-likelihood: -10.0884
# Iteration: 100/500	Log-likelihood: -9.4770
# /tmp/ipykernel_67626/1232229413.py:14: RuntimeWarning: The training result may differ even with fixed seed if `workers` != 1.
#   dt_model.train(ITERATION_STEP)
# Iteration: 150/500	Log-likelihood: -9.1357
# Iteration: 200/500	Log-likelihood: -8.9092
# Iteration: 250/500	Log-likelihood: -8.7386
# Iteration: 300/500	Log-likelihood: -8.5930
# Iteration: 350/500	Log-likelihood: -8.4732
# Iteration: 400/500	Log-likelihood: -8.3728
# Iteration: 450/500	Log-likelihood: -8.2833
# Iteration: 500/500	Log-likelihood: -8.2043

# %% [markdown]
# # Visualize

# %%
model_path = f"model_results/dtm/dtm_{SUBJECT}_num_topic_{NUM_TOPICS}.bin"
loaded_dt_model = tp.DTModel.load(model_path)

# %%
import pandas as pd
import plotly.graph_objects as go
import tomotopy as tp

df["submitted_date"] = pd.to_datetime(df["submitted_date"], errors="coerce")
df["year"] = df["submitted_date"].dt.year

years = sorted(df['year'].unique())
year_to_tp = {y: i for i, y in enumerate(years)}

num_times = loaded_dt_model.num_timepoints
assert len(years) == num_times, "Mismatch antara tahun dan timepoints di model"

# %%
import numpy as np

topic_time_probs = []

for t in range(loaded_dt_model.num_timepoints):
    logits = np.array(loaded_dt_model.alpha[t])
    probs = np.exp(logits) / np.exp(logits).sum()
    topic_time_probs.append(probs)

topic_time_probs = np.array(topic_time_probs)   # shape: time × topics

# %%
df_topic_time = pd.DataFrame(
    topic_time_probs.T,
    index=[f"Topic {i}" for i in range(loaded_dt_model.k)],
    columns=all_years
)

# %%
import plotly.graph_objects as go
import numpy as np

topic_means = topic_time_probs.mean(axis=0)
top5_idx = np.argsort(topic_means)[-5:]

def get_top_words(topic, timepoint, topn=8):
    words = loaded_dt_model.get_topic_words(topic, timepoint, top_n=topn)
    return ", ".join([w for w, p in words])

fig = go.Figure()

for k in top5_idx:
    y_values = topic_time_probs[:, k]

    htext = [
        f"Year: {all_years[t]}<br>"
        f"Topic {k}<br>"
        f"Top words: {get_top_words(k, t)}<br>"
        f"Proportion: {y_values[t]:.4f}"
        for t in range(len(all_years))
    ]

    fig.add_trace(go.Scatter(
        x=all_years,
        y=y_values,
        mode="lines+markers",
        name=f"Topic {k}",
        hovertext=htext,
        hoverinfo="text"
    ))

fig.update_layout(
    title="Top 5 Topics Over Time (DTM)",
    xaxis_title="Year",
    yaxis_title="Proportion",
    hovermode="closest",
    template="plotly_white"
)

fig.show()

# %% [markdown]
# # Metrics

# %%
import pandas as pd
from gensim.utils import simple_preprocess
from gensim.corpora import Dictionary
from tqdm.notebook import tqdm
from gensim.models import CoherenceModel
import tomotopy as tp
import pandas as pd
import numpy as np

# %%
model_path = f"model_results/dtm/dtm_{SUBJECT}_num_topic_{NUM_TOPICS}.bin"
loaded_dt_model = tp.DTModel.load(model_path)

# %%
df["submitted_date"] = pd.to_datetime(df["submitted_date"])
df['year'] = df["submitted_date"].dt.year
all_years = sorted(df['year'].unique())
num_time_steps = {year: i for i, year in enumerate(all_years)}

# %%
def tokenize_for_coherence(text):
    return [
        token for token in simple_preprocess(str(text), deacc=True)
    ]
texts_for_coherence = [tokenize_for_coherence(text) for text in tqdm(df['text'], desc="Tokenizing for Coherence")]
dictionary_coherence = Dictionary(texts_for_coherence)
# Out:
# Tokenizing for Coherence:   0%|          | 0/159247 [00:00<?, ?it/s]

# %%
import numpy as np
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
from collections import Counter
from tqdm import tqdm

global_topics_words = []
top_n_words = 10
print("Extracting Global Topics...")
for topic_id in range(NUM_TOPICS):
    word_accumulator = Counter()
    for time_index in range(len(num_time_steps)):
        words_probs = loaded_dt_model.get_topic_words(
            topic_id=topic_id,
            timepoint=time_index,
            top_n=20 
        )
        
        for word, prob in words_probs:
            word_accumulator[word] += prob
            
    most_common_global = [word for word, score in word_accumulator.most_common(top_n_words)]
    global_topics_words.append(most_common_global)
    print(f"Global Topic {topic_id}: {most_common_global}")

print("Calculating Global Coherence...")
try:
    cm_global = CoherenceModel(
        topics=global_topics_words,      # List of list kata (versi global)
        texts=texts_for_coherence,              # Seluruh teks (bukan per tahun)
        dictionary=dictionary_coherence,
        coherence="c_v",
        processes=5
    )
    
    global_score = cm_global.get_coherence()
    print(f"\n=== GLOBAL COHERENCE SCORE (Aggregated): {global_score:.4f} ===")
    
    # Jika ingin melihat skor per topik
    coherence_per_topic = cm_global.get_coherence_per_topic()
    for i, score in enumerate(coherence_per_topic):
        print(f"Topic {i}: {score:.4f}")

except Exception as e:
    print(f"Error calculating global coherence: {e}")
# Out:
# Extracting Global Topics...
# Global Topic 0: ['function', 'deep', 'loss', 'attack', 'aware', 'graph', 'set', 'available', 'decision', 'hybrid']
# Global Topic 1: ['algorithm', 'neural', 'baseline', 'point', 'improvement', 'security', 'synthetic', 'visual', 'structure', 'effect']
# Global Topic 2: ['complexity', 'network', 'global', 'communication', 'metric', 'crucial', 'local', 'device', 'segmentation', 'rate']
# Global Topic 3: ['specific', 'setting', 'standard', 'sample', 'function', 'reward', 'efficient', 'code_available', 'optimal', 'algorithm']
# Global Topic 4: ['algorithm', 'code', 'condition', 'metric', 'medical', 'technology', 'object', 'signal', 'perception', 'fusion']
# Global Topic 5: ['information', 'datum', 'image', 'search', 'efficient', 'linear', 'machine_learning', 'average', 'environment', 'social']
# Global Topic 6: ['language', 'dynamic', 'view', 'finding', 'architecture', 'level', 'computation', 'open', 'available', 'self']
# Global Topic 7: ['dataset', 'behavior', 'information', 'relationship', 'edge', 'space', 'robot', 'promising', 'adversarial', 'algorithm']
# Global Topic 8: ['datum', 'network', 'rate', 'term', 'risk', 'agent', 'level', 'technology', 'phase', 'hierarchical']
# Global Topic 9: ['network', 'scheme', 'traditional', 'machine', 'complexity', 'concept', 'path', 'token', 'frequency', 'document']
# Global Topic 10: ['architecture', 'extensive', 'object', 'algorithm', 'mechanism', 'image', 'impact', 'rate', 'end', 'point']
# Global Topic 11: ['dataset', 'object', 'prompt', 'representation', 'fine_tuning', 'cross', 'environment', 'access', 'algorithm', 'length']
# Global Topic 12: ['order', 'real_world', 'field', 'estimation', 'algorithm', 'detection', 'network', 'graph', 'property', 'available']
# Global Topic 13: ['image', 'datum', 'generalization', 'gradient', 'environment', 'text', 'communication', 'property', 'class', 'condition']
# Global Topic 14: ['distribution', 'dataset', 'efficient', 'estimation', 'superior', 'additional', 'energy', 'algorithm', 'information', 'channel']
# Global Topic 15: ['structure', 'resource', 'non', 'image', 'information', 'deep', 'memory', 'human', 'consistency', 'integration']
# Global Topic 16: ['transformer', 'neural_network', 'ability', 'modeling', 'strong', 'target', 'distribution', 'decision', 'object', 'source']
# Global Topic 17: ['graph', 'development', 'metric', 'limitation', 'uncertainty', 'group', 'noise', 'field', 'action', 'potential']
# Global Topic 18: ['space', 'gap', 'control', 'communication', 'detection', 'spatial', 'convergence', 'object', 'agent', 'transfer']
# Global Topic 19: ['human', 'class', 'language', 'region', 'image', 'information', 'level', 'graph', 'term', 'edge']
# Global Topic 20: ['benchmark', 'size', 'non', 'temporal', 'objective', 'query', 'graph', 'function', 'attention', 'information']
# Global Topic 21: ['knowledge', 'sample', 'algorithm', 'network', 'design', 'output', 'semantic', 'agent', 'stage', 'error']
# Global Topic 22: ['input', 'prediction', 'scene', 'control', 'theory', 'reconstruction', 'node', 'need', 'adversarial', 'scenario']
# Global Topic 23: ['representation', 'algorithm', 'datum', 'set', 'motion', 'linear', 'environment', 'variable', 'relevant', 'development']
# Global Topic 24: ['level', 'key', 'test', 'effective', 'detection', 'power', 'end', 'environment', 'adversarial', 'algorithm']
# Global Topic 25: ['visual', 'optimization', 'function', 'single', 'module', 'classification', 'alignment', 'particular', 'video', 'label']
# Global Topic 26: ['datum', 'experimental', 'weight', 'well', 'expert', 'learning', 'term', 'paradigm', 'architecture', 'algorithm']
# Global Topic 27: ['strategy', 'context', 'target', 'effectiveness', 'capability', 'trajectory', 'channel', 'distribution', 'downstream', 'recognition']
# Global Topic 28: ['datum', 'space', 'linear', 'score', 'multi', 'energy', 'estimation', 'matrix', 'specific', 'set']
# Global Topic 29: ['graph', 'scale', 'semantic', 'accurate', 'content', 'scheme', 'deep_learning', 'area', 'set', 'previous']
# Global Topic 30: ['machine', 'efficient', 'video', 'type', 'multi', 'insight', 'shot', 'learning', 'domain', 'self']
# Global Topic 31: ['set', 'knowledge', 'network', 'label', 'multi', 'input', 'online', 'training', 'representation', 'setting']
# Global Topic 32: ['inference', 'algorithm', 'quality', 'layer', 'dimensional', 'way', 'prediction', 'end', 'neural_network', 'planning']
# Global Topic 33: ['network', 'optimal', 'design', 'human', 'neural_network', 'error', 'class', 'benchmark', 'multi', 'generative']
# Global Topic 34: ['datum', 'generation', 'interaction', 'robot', 'experimental', 'network', 'action', 'text', 'space', 'robotic']
# Global Topic 35: ['question', 'source', 'property', 'comprehensive', 'llm', 'information', 'local', 'function', 'reasoning', 'processing']
# Global Topic 36: ['multi', 'scenario', 'robustness', 'node', 'image', 'prior', 'training', 'language', 'deployment', 'embedding']
# Global Topic 37: ['algorithm', 'layer', 'graph', 'adaptive', 'representation', 'individual', 'long', 'error', 'code', 'recognition']
# Global Topic 38: ['step', 'accuracy', 'quantum', 'scale', 'deep_learning', 'multimodal', 'training', 'dynamic', 'standard', 'fundamental']
# Global Topic 39: ['network', 'robust', 'information', 'image', 'dataset', 'signal', 'previous', 'way', 'sequence', 'diffusion']
# Global Topic 40: ['training', 'privacy', 'critical', 'image', 'code', 'non', 'goal', 'deep', 'scale', 'robot']
# Global Topic 41: ['video', 'quality', 'code', 'information', 'llm', 'segmentation', 'detection', 'limited', 'channel', 'safety']
# Global Topic 42: ['real', 'learning', 'algorithm', 'constraint', 'network', 'neural_network', 'fine', 'point', 'visual', 'camera']
# Global Topic 43: ['text', 'potential', 'optimization', 'computational', 'dataset', 'training', 'map', 'attack', 'human', 'continuous']
# Global Topic 44: ['domain', 'cost', 'pre', 'pattern', 'single', 'retrieval', 'accuracy', 'representation', 'level', 'modality']
# Global Topic 45: ['tool', 'algorithm', 'training', 'design', 'operation', 'non', 'latent', 'information', 'datum', 'set']
# Global Topic 46: ['order', 'accuracy', 'distribution', 'free', 'human', 'learning', 'bias', 'noise', 'optimal', 'pipeline']
# Global Topic 47: ['classification', 'learning', 'datum', 'language', 'scheme', 'series', 'strategy', 'community', 'algorithm', 'information']
# Global Topic 48: ['dataset', 'language', 'diverse', 'instance', 'event', 'generation', 'code', 'optimization', 'input', 'clinical']
# Global Topic 49: ['algorithm', 'policy', 'prediction', 'agent', 'efficiency', 'type', 'dynamic', 'memory', 'practical', 'attention']
# Calculating Global Coherence...
#
# === GLOBAL COHERENCE SCORE (Aggregated): 0.3383 ===
# Topic 0: 0.2967
# Topic 1: 0.2824
# Topic 2: 0.3957
# Topic 3: 0.4152
# Topic 4: 0.3129
# Topic 5: 0.3059
# Topic 6: 0.3231
# Topic 7: 0.3124
# Topic 8: 0.3544
# Topic 9: 0.3001
# Topic 10: 0.3216
# Topic 11: 0.3189
# Topic 12: 0.3450
# Topic 13: 0.2973
# Topic 14: 0.3673
# Topic 15: 0.3294
# Topic 16: 0.3768
# Topic 17: 0.3266
# Topic 18: 0.3257
# Topic 19: 0.3166
# Topic 20: 0.3481
# Topic 21: 0.2993
# Topic 22: 0.2925
# Topic 23: 0.3177
# Topic 24: 0.3292
# Topic 25: 0.3683
# Topic 26: 0.3601
# Topic 27: 0.3687
# Topic 28: 0.3371
# Topic 29: 0.3074
# Topic 30: 0.3823
# Topic 31: 0.3900
# Topic 32: 0.3307
# Topic 33: 0.3171
# Topic 34: 0.3801
# Topic 35: 0.3279
# Topic 36: 0.3728
# Topic 37: 0.3059
# Topic 38: 0.3391
# Topic 39: 0.3788
# Topic 40: 0.3052
# Topic 41: 0.3536
# Topic 42: 0.3541
# Topic 43: 0.3361
# Topic 44: 0.4185
# Topic 45: 0.3109
# Topic 46: 0.3363
# Topic 47: 0.3202
# Topic 48: 0.3514
# Topic 49: 0.3502

# %%
yearly_coherence_scores = [] 
yearly_scores_dict = {}    
for time_index in tqdm(range(len(num_time_steps)), desc="Calculating coherence per year"):
    current_year = all_years[time_index]
    texts_for_coherence_year = [tokenize_for_coherence(text) for text in tqdm(df[df['year'] == current_year]['text'])]
    dictionary_year =  Dictionary(texts_for_coherence_year)
    
    topics_for_this_year = []
    
    
    for topic_id in range(NUM_TOPICS):
        words_probs = loaded_dt_model.get_topic_words(
            topic_id=topic_id,
            timepoint=time_index,
            top_n=10
        )
        word_list = [word for word, prob in words_probs]
        topics_for_this_year.append(word_list)
        
    try:
        cm = CoherenceModel(
            topics=topics_for_this_year,      
            texts=texts_for_coherence_year,
            dictionary=dictionary_year,
            coherence="c_v",
            processes=5
        )
        
        score = cm.get_coherence()
        
        print(f"  Tahun: {current_year} (t={time_index}) -> Skor Koherensi: {score:.4f}")
        
        yearly_coherence_scores.append(score)
        yearly_scores_dict[current_year] = score

    except Exception as e:
        print(f"  Tahun: {current_year} (t={time_index}) -> GAGAL MENGHITUNG: {e}")
        yearly_coherence_scores.append(np.nan) 
        yearly_scores_dict[current_year] = np.nan

if yearly_coherence_scores:
    average_coherence = np.nanmean(yearly_coherence_scores) 
    print(f"\nAverage Score: {average_coherence}")
    print("\nSkor Koherensi per Tahun (Detail):")
    print(yearly_scores_dict)
else:
    print("Tidak ada skor koherensi yang dihitung.")
# Out:
# Calculating coherence per year:   0%|          | 0/26 [00:00<?, ?it/s]
#   0%|          | 0/488 [00:00<?, ?it/s]
#   Tahun: 2000 (t=0) -> Skor Koherensi: 0.3659
#   0%|          | 0/594 [00:00<?, ?it/s]
#   Tahun: 2001 (t=1) -> Skor Koherensi: 0.2786
#   0%|          | 0/648 [00:00<?, ?it/s]
#   Tahun: 2002 (t=2) -> Skor Koherensi: 0.2962
#   0%|          | 0/825 [00:00<?, ?it/s]
#   Tahun: 2003 (t=3) -> Skor Koherensi: 0.2851
#   0%|          | 0/948 [00:00<?, ?it/s]
#   Tahun: 2004 (t=4) -> Skor Koherensi: 0.2962
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   Tahun: 2005 (t=5) -> Skor Koherensi: 0.3651
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   Tahun: 2006 (t=6) -> Skor Koherensi: 0.3763
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   Tahun: 2007 (t=7) -> Skor Koherensi: 0.3982
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   Tahun: 2008 (t=8) -> Skor Koherensi: 0.3988
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   Tahun: 2009 (t=9) -> Skor Koherensi: 0.3557
#   0%|          | 0/1362 [00:00<?, ?it/s]
#   Tahun: 2010 (t=10) -> Skor Koherensi: 0.3496
#   0%|          | 0/1622 [00:00<?, ?it/s]
#   Tahun: 2011 (t=11) -> Skor Koherensi: 0.3684
#   0%|          | 0/2254 [00:00<?, ?it/s]
#   Tahun: 2012 (t=12) -> Skor Koherensi: 0.3464
#   0%|          | 0/2719 [00:00<?, ?it/s]
#   Tahun: 2013 (t=13) -> Skor Koherensi: 0.3819
#   0%|          | 0/2989 [00:00<?, ?it/s]
#   Tahun: 2014 (t=14) -> Skor Koherensi: 0.3887
#   0%|          | 0/3346 [00:00<?, ?it/s]
#   Tahun: 2015 (t=15) -> Skor Koherensi: 0.3813
#   0%|          | 0/4281 [00:00<?, ?it/s]
#   Tahun: 2016 (t=16) -> Skor Koherensi: 0.3989
#   0%|          | 0/5534 [00:00<?, ?it/s]
#   Tahun: 2017 (t=17) -> Skor Koherensi: 0.3536
#   0%|          | 0/7471 [00:00<?, ?it/s]
#   Tahun: 2018 (t=18) -> Skor Koherensi: 0.3198
#   0%|          | 0/9550 [00:00<?, ?it/s]
#   Tahun: 2019 (t=19) -> Skor Koherensi: 0.3231
#   0%|          | 0/12356 [00:00<?, ?it/s]
#   Tahun: 2020 (t=20) -> Skor Koherensi: 0.3175
#   0%|          | 0/14101 [00:00<?, ?it/s]
#   Tahun: 2021 (t=21) -> Skor Koherensi: 0.3230
#   0%|          | 0/15005 [00:00<?, ?it/s]
#   Tahun: 2022 (t=22) -> Skor Koherensi: 0.3247
#   0%|          | 0/17863 [00:00<?, ?it/s]
#   Tahun: 2023 (t=23) -> Skor Koherensi: 0.3221
#   0%|          | 0/23746 [00:00<?, ?it/s]
#   Tahun: 2024 (t=24) -> Skor Koherensi: 0.3246
#   0%|          | 0/26545 [00:00<?, ?it/s]
#   Tahun: 2025 (t=25) -> Skor Koherensi: 0.3240
#
# Average Score: 0.3447474302577734
#
# Skor Koherensi per Tahun (Detail):
# {2000: 0.36585294677034513, 2001: 0.27861537189668584, 2002: 0.2962242470178769, 2003: 0.285110423176869, 2004: 0.2961500379654354, 2005: 0.3651190144380205, 2006: 0.3763190734026932, 2007: 0.39819305250306625, 2008: 0.39881164954347187, 2009: 0.35569187273780445, 2010: 0.3495641440396596, 2011: 0.368358486582105, 2012: 0.3463780666820756, 2013: 0.38185199713652784, 2014: 0.38866577208099146, 2015: 0.3813048184245958, 2016: 0.39887941858042164, 2017: 0.3535910067865269, 2018: 0.31981068256121153, 2019: 0.3230911479338429, 2020: 0.3175114444447714, 2021: 0.32296954754798546, 2022: 0.3246607191701411, 2023: 0.32208591702656086, 2024: 0.32459165434423426, 2025: 0.3240306739081876}
