# %%
import pandas as pd
import json

# %%
LIST_SUBJECT = [ "cs", "math", "stats", "physics", "eess"]

# %%
df = pd.read_csv("../dataset/arxiv_merged.csv")
df = df.drop_duplicates(ignore_index=True)
df
# Out:
#                                                      title  \
# 0        Knowledge Graph Construction for Stock Markets...
# 1        SetupKit: Efficient Multi-Corner Setup/Hold Ti...
# 2        A General Highly Accurate Online Planning Meth...
# 3        Insight-A: Attribution-aware for Multimodal Mi...
# 4        On the Cross-lingual Transferability of Pre-tr...
# ...                                                    ...
# 2926682  Classification of Transuranium Elements in Ter...
# 2926683  Dominating Hadwiger's Conjecture for graphs GG...
# 2926684  Fast-forwardable Lindbladians imply quantum ph...
# 2926685  Implicit-Knowledge Visual Question Answering w...
# 2926686  Reasoning under Vision: Understanding Visual-S...
#
#                                       url  \
# 0        https://arxiv.org/abs/2601.11528
# 1        https://arxiv.org/abs/2512.00044
# 2        https://arxiv.org/abs/2511.21706
# 3        https://arxiv.org/abs/2511.21705
# 4        https://arxiv.org/abs/2511.21704
# ...                                   ...
# 2926682  https://arxiv.org/abs/2510.14289
# 2926683  https://arxiv.org/abs/2510.12564
# 2926684  https://arxiv.org/abs/2510.06759
# 2926685  https://arxiv.org/abs/2510.06638
# 2926686  https://arxiv.org/abs/2510.06067
#
#                                                    authors  \
# 0        Cheonsol Lee,Youngsang Jeong,Jeongyeol Shin,Hu...
# 1        Junzhuo Zhou,Ziwen Wang,Haoxuan Xia,Yuxin Yan,...
# 2               Hui Wang,Fafa Zhang,Xiaoyu Zhang,Chaoxu Mu
# 3                 Junjie Wu,Yumeng Fu,Chen Gong,Guohong Fu
# 4        Jonatas Grosman,Cassio Almeida,Guilherme Schar...
# ...                                                    ...
# 2926682                                   Sergei K. Suslov
# 2926683                         Michael Scully,Zi-Xia Song
# 2926684  Zhong-Xia Shang,Naixu Guo,Patrick Rebentrost,A...
# 2926685  Zhihao Wen,Wenkang Wei,Yuan Fang,Xingtong Yu,H...
# 2926686  Python Song,Luke Tenyi Chang,Yun-Yun Tsai,Peng...
#
#                                                       tags  \
# 0        [{"tag": "cs.DB", "name": "Databases"}, {"tag"...
# 1        [{"tag": "cs.AR", "name": "Hardware Architectu...
# 2        [{"tag": "cs.CL", "name": "Computation and Lan...
# 3        [{"tag": "cs.CL", "name": "Computation and Lan...
# 4        [{"tag": "cs.CL", "name": "Computation and Lan...
# ...                                                    ...
# 2926682   [{"tag": "quant-ph", "name": "Quantum Physics"}]
# 2926683      [{"tag": "math.CO", "name": "Combinatorics"}]
# 2926684   [{"tag": "quant-ph", "name": "Quantum Physics"}]
# 2926685  [{"tag": "cs.CV", "name": "Computer Vision and...
# 2926686  [{"tag": "cs.CV", "name": "Computer Vision and...
#
#                                                   abstract     submitted_date  \
# 0        The stock market is inherently complex, with i...  16 November, 2025
# 1        Accurate setup/hold time characterization is c...  16 November, 2025
# 2        In goal-oriented dialogue tasks, the main chal...  16 November, 2025
# 3        AI-generated content (AIGC) technology has eme...  16 November, 2025
# 4        Using representations provided by a large pre-...  16 November, 2025
# ...                                                    ...                ...
# 2926682  We revisit the Bohr-Sommerfeld atomic model to...  15 November, 2025
# 2926683  Hadwiger's Conjecture from 1943 states that ev...  15 November, 2025
# 2926684  Quantum phase estimation (QPE) and Lindbladian...  15 November, 2025
# 2926685  Knowledge-based Visual Question Answering (KVQ...  15 November, 2025
# 2926686  CAPTCHA, originally designed to distinguish hu...  15 November, 2025
#
#         announced_date
# 0         January 2026
# 1        December 2025
# 2        November 2025
# 3        November 2025
# 4        November 2025
# ...                ...
# 2926682   October 2025
# 2926683   October 2025
# 2926684   October 2025
# 2926685   October 2025
# 2926686   October 2025
#
# [2926687 rows x 7 columns]

# %% [markdown]
# # Cleaned Text

# %%
import os
if not os.path.exists("../dataset/arxiv_dataset_clean.csv"):
    df['text'] = (df['title'].fillna("")+ ". " + df['abstract'].fillna(""))
    df= df.drop(columns=['abstract'])
    import re
    def clean_text(t):
        t = t.lower()
        t = re.sub(r"https?://\S+|www\.\S+", "", t)
        t = re.sub(r"\S+@\S+", "", t)
        t = re.sub(r"[^a-z0-9]", " ", t)
        t = re.sub(r"\b\d+\b", "", t)
        t = re.sub(r"\s+", " ", t)
        return t.strip()
    df['text'] = df["text"].apply(clean_text)
    def parse_tags(tag_str):
        try:
            tags = json.loads(tag_str)
            if isinstance(tags, list):
                return [t["tag"] for t in tags if "tag" in t]
        except Exception:
            return []
        return []


    df["tag_list"] = df["tags"].apply(parse_tags)
    df = df.explode("tag_list").reset_index(drop=True)
    df["prefix"] = df["tag_list"].apply(lambda x: x.split(".")[0] if isinstance(x, str) else None)

    def parse_tags(x):
        try:
            tags = json.loads(x.replace("'", '"'))
            return ", ".join([t["name"] for t in tags])
        except Exception:
            return ""

    df = df.assign(tag_text = df["tags"].apply(parse_tags))

    df = df.drop(columns=['url', 'announced_date', 'tags', 'authors', 'tag_list'])

    df['submitted_date'] = pd.to_datetime(df['submitted_date'], format="%d %B, %Y")
    data_compute = df[(df['submitted_date'] >= "2000-01-01") & (df['submitted_date'] <= "2025-12-31")].reset_index(drop=True)

    data_compute.to_csv("../dataset/arxiv_dataset_clean.csv", index=False)
    
df = pd.read_csv("../dataset/arxiv_dataset_clean.csv")

# %% [markdown]
# ## Data Sampling

# %%
def sampling_per_year(data, frac=0.2, min_per_year=1000):
    data["submitted_date"] = pd.to_datetime(data["submitted_date"], errors="coerce")
    data["year"] = data["submitted_date"].dt.year

    def sample_group(g):
        n = max(int(len(g) * frac), min_per_year)
        n = min(n, len(g))
        return g.sample(n=n, random_state=1337)

    return (
        data.groupby("year", group_keys=False)
            .apply(sample_group, include_groups=False)
            .reset_index(drop=True)
    )

# %% [markdown]
# ## Dataset Embeding

# %%
dataset_emb = df.copy()
for i in ['stat']:
    d = dataset_emb[df['prefix'] == i]
    d = d.drop(columns=['prefix'])
    d = d.drop_duplicates(ignore_index=False)
    print(f"Total data Before Sampling = {len(d)}")
    d = sampling_per_year(d)
    print(f"Total data After Sampling = {len(d)}")
    d.to_csv(f"../dataset/{i}/emb/v1.csv", index=False)
# Out:
# Total data Before Sampling = 122389
# Total data After Sampling = 28965

# %% [markdown]
# ## Dataset Bag of Wods

# %%
import spacy
from gensim.models import Phrases, Word2Vec
from gensim.models.phrases import Phraser



nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])

custom_blocklist = {
    # 1. ACADEMIC NOUNS 
    'study', 'paper', 'research', 'result', 'conclusion', 'method', 'methodology', 
    'approach', 'analysis', 'implementation', 'evaluation', 'experiment', 'data',
    'problem', 'solution', 'technique', 'application', 'system', 'model', 'user',
    'work', 'case', 'example', 'comparison', 'performance', 'process', 'task',
    'simulation', 'platform', 'framework', 'component', 'parameter', 'value',
    'number', 'time', 'year', 'state', 'art', 'feature', 'challenge', 'issue',
    
    # 2. ACADEMIC ADJ/VERBS 
    'propose', 'use', 'base', 'new', 'exist', 'different', 'differ',
    'various', 'significant', 'good', 'better', 'best', 'high', 'low', 'large', 
    'small', 'simple', 'complex', 'general', 'novel', 'main', 'important',
    'improve', 'demonstrate', 'present', 'show', 'discuss', 'describe', 'provide',
    'consider', 'include', 'achieve', 'obtain', 'perform', 'validate', 'compare',
    'recent', 'current', 'future', 'overall', 'multiple', 'several', 'many',
    
    # 3. CITATION/ARTIFACTS
    'et', 'al', 'fig', 'figure', 'table', 'eq', 'equation', 'vol', 'pp', 'doi',
    'http', 'https', 'url', 'www', 'section', 'ref', 'reference', 'cite'
}

def preprocesing_bow(text):
    doc = nlp(text)
    cleaned_tokens = []
    allowed_tags = ['NOUN', 'ADJ', 'PROPN']
    
    for token in doc:
        lemma = token.lemma_.lower()
        if token.pos_ in allowed_tags and not token.is_stop and len(lemma) > 2 and lemma not in custom_blocklist:
            cleaned_tokens.append(token.lemma_)
    return cleaned_tokens

def pharse_modeling(tokens):
    bigram = Phrases(tokens, min_count=5, threshold=0.5, scoring='npmi')
    trigram = Phrases(bigram[tokens], min_count=5, threshold=0.5, scoring='npmi')
    bigram_mod = Phraser(bigram)
    trigram_mod = Phraser(trigram)
    _ = [bigram_mod[doc] for doc in tokens]
    tokens_trigram = [trigram_mod[bigram_mod[doc]] for doc in tokens]
    return tokens_trigram

# %%
for i in ['stat']:
    d = df[df['prefix'] == i]
    d = d.drop(columns=['prefix'])
    d = d.drop_duplicates(ignore_index=False)
    print(f"Total Data Before Sampling {len(d)}")
    d = sampling_per_year(d)
    print(f"Total Data After Sampling {len(d)}")
    d['text'] = d['text'].apply(preprocesing_bow)
    d['text'] = pharse_modeling(d['text'].tolist())
    print(f"Done preprocess pharse modeling")
    d.to_csv(f"../dataset/{i}/bow/v1.csv", index=False)
# Out:
# Total Data Before Sampling 122389
# Total Data After Sampling 28965
# Start preprocess lemm, stopwords, pos
# Done preprocess lemm, stopwords, pos
# Start preprocess pharse modeling
# Done preprocess pharse modeling
